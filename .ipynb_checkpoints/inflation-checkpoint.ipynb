# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
cpi = pd.read_excel('SeriesReport-20230530081136_6825be.xlsx', header=11, index_col=0, usecols=[0,13])
cpi.dropna(inplace=True)
cpi = cpi.transpose()
cpi
# Out:
# Year    1913  1914  1915  1916  1917  1918  1919  1920  1921  1922  ...  \
# Annual   9.9  10.0  10.1  10.9  12.8  15.1  17.3  20.0  17.9  16.8  ...
#
# Year       2013     2014     2015     2016    2017     2018     2019     2020  \
# Annual  232.957  236.736  237.017  240.007  245.12  251.107  255.657  258.811
#
# Year      2021     2022
# Annual  270.97  292.655
#
# [1 rows x 110 columns]

# %%
all_tech = pd.read_csv('all_tech_version 1.5.csv')
all_tech
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19992/2174381710.py:1: DtypeWarning: Columns (156,215,216,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,321,322,323,324,325,326,327,328,329,330) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_tech = pd.read_csv('all_tech_version 1.5.csv')
#                                                      ID Spatial Scale  \
# 0     Lithium-ion battery storage_Cumulative Rated C...      National
# 1     Lithium-ion battery storage_Cumulative Rated P...      National
# 2     Sensible heat storage_Cumulative Rated Capacit...      National
# ...

# %%
cost_data = all_tech[all_tech['Metric']=='Price']
cost_data.set_index('ID', drop=True, inplace=True)
cost_data.dropna(axis=1, how='all', inplace=True)
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19992/2303471842.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cost_data.dropna(axis=1, how='all', inplace=True)

# %%
primary_copper = cost_data[cost_data['Technology Name']=='Primary copper production']

# %%
primary_copper
# Out:
#                                       Spatial Scale Country Code Country Name  \
# ID
# Primary copper production_Price_World        Global        World        World
#
#                                                  Technology Name Metric  \
# ID
# Primary copper production_Price_World  Primary copper production  Price
#
#                                                       Unit  \
# ID
# Primary copper production_Price_World  1998 USD/metric ton
#
#                                                   Data Source    1900    1901  \
# ID
# Primary copper production_Price_World  U.S. Geological Survey  7000.0  7000.0
#
#                                          1902  ...    2010    2011    2012  \
# ID                                             ...
# Primary copper production_Price_World  4800.0  ...  5740.0  6490.0  5750.0
#
#                                          2013    2014    2015    2016    2017  \
# ID
# ...

# %%
usgs = cost_data[cost_data['Data Source']=='U.S. Geological Survey']

# %%
usgs
# Out:
#                                                    Spatial Scale Country Code  \
# ID
# Primary copper production_Price_World                     Global        World
# Cement production_Price_World                             Global        World
# Nickel production_Price_World                             Global        World
# Sand and gravel production (construction)_Price...        Global        World
# Gold production_Price_World                               Global        World
# Sand and gravel production (industrial)_Price_W...        Global        World
#
#                                                    Country Name  \
# ID
# Primary copper production_Price_World                     World
# Cement production_Price_World                             World
# Nickel production_Price_World                             World
# Sand and gravel production (construction)_Price...        World
# Gold production_Price_World                               World
# ...

# %%
infl_1998_2022 = float(1 + (cpi[2022]-cpi[1998])/cpi[1998])
infl_1998_2022
# Out:
# 1.7954294478527606

# %%
usgs['1913']
# Out:
# ID
# Primary copper production_Price_World                        5630.0
# Cement production_Price_World                                  99.8
# Nickel production_Price_World                               15300.0
# Sand and gravel production (construction)_Price_World          4.77
# Gold production_Price_World                              10000000.0
# Sand and gravel production (industrial)_Price_World            12.6
# Name: 1913, dtype: object

# %%
for x in usgs['1913']:
    x = float(x)
    print(x*1.7954294478527606)
# Out:
# 10108.267791411043
# 179.1838588957055
# 27470.070552147237
# 8.564198466257666
# 17954294.478527606
# 22.622411042944783

# %%
set(cost_data['Data Source'])
# Out:
# {'Santa Fe Institute', 'U.S. Geological Survey'}
