# %%
# run necessary import statements
import pandas as pd
from pandas import Series, DataFrame

# %%
# create dataframe from Excel sheet and display
# use row 3 of csv (years) as column names, country names as index, recognize symbols as NA
missing_values = ['-', '^','♦']
bp = pd.read_excel('bp-stats-review-2022-all-data.xlsx', sheet_name='Coal Production - Tonnes', header=2, index_col=0, na_values=missing_values)
bp
# Out:
#                                                           1981        1982  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               40.088000   42.907000
# Mexico                                                3.032331    3.751216
# US                                                  747.316076  760.322383
# Total North America                                 790.436408  806.980599
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                           1983        1984  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               44.807000   57.402000
# Mexico                                                4.851129    5.335241
# US                                                  709.500989  812.765612
# Total North America                                 759.159118  875.502853
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                           1985        1986  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               60.853000   57.048000
# Mexico                                                5.525976    6.216795
# US                                                  801.622980  807.679881
# Total North America                                 868.001956  870.944676
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                           1987        1988  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               61.207000   70.643000
# Mexico                                                6.931471    6.345856
# US                                                  833.486976  862.066121
# Total North America                                 901.625447  939.054977
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                           1989         1990  \
# Million tonnes
# NaN                                                        NaN          NaN
# Canada                                               70.527000    68.332000
# Mexico                                                6.770534     6.929812
# US                                                  889.702153   933.561573
# Total North America                                 966.999687  1008.823385
# ...                                                        ...          ...
# w Less than 0.05%.                                         NaN          NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN          NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN          NaN
# Notes: Annual changes and shares of total are c...         NaN          NaN
# Growth rates are adjusted for leap years.                  NaN          NaN
#
#                                                     ...        2015  \
# Million tonnes                                      ...
# NaN                                                 ...         NaN
# Canada                                              ...   62.355200
# Mexico                                              ...   12.252900
# US                                                  ...  813.690756
# Total North America                                 ...  888.298856
# ...                                                 ...         ...
# w Less than 0.05%.                                  ...         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...  ...         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...  ...         NaN
# Notes: Annual changes and shares of total are c...  ...         NaN
# Growth rates are adjusted for leap years.           ...         NaN
#
#                                                           2016        2017  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               62.351500   60.596100
# Mexico                                               11.408950   12.928590
# US                                                  660.761129  702.713757
# Total North America                                 734.521579  776.238447
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                           2018        2019  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               55.047500   53.165500
# Mexico                                               11.883980    9.755420
# US                                                  685.983219  640.752957
# Total North America                                 752.914699  703.673877
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                           2020        2021  \
# Million tonnes
# NaN                                                        NaN         NaN
# Canada                                               45.284900   46.740474
# Mexico                                                7.746920    7.441824
# US                                                  485.737854  524.408300
# Total North America                                 538.769674  578.590598
# ...                                                        ...         ...
# w Less than 0.05%.                                         NaN         NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...         NaN         NaN
#  # Excludes Estonia, Latvia and Lithuania prior...         NaN         NaN
# Notes: Annual changes and shares of total are c...         NaN         NaN
# Growth rates are adjusted for leap years.                  NaN         NaN
#
#                                                       2021.1   2011-21  \
# Million tonnes
# NaN                                                      NaN       NaN
# Canada                                              0.034970 -0.036019
# Mexico                                             -0.036751 -0.092374
# US                                                  0.082570 -0.061939
# Total North America                                 0.076853 -0.060592
# ...                                                      ...       ...
# w Less than 0.05%.                                       NaN       NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...       NaN       NaN
#  # Excludes Estonia, Latvia and Lithuania prior...       NaN       NaN
# Notes: Annual changes and shares of total are c...       NaN       NaN
# Growth rates are adjusted for leap years.                NaN       NaN
#
#                                                       2021.2
# Million tonnes
# NaN                                                      NaN
# Canada                                              0.005719
# Mexico                                              0.000911
# US                                                  0.064167
# Total North America                                 0.070796
# ...                                                      ...
# w Less than 0.05%.                                       NaN
# USSR includes CIS, Georgia, Ukraine and the Bal...       NaN
#  # Excludes Estonia, Latvia and Lithuania prior...       NaN
# Notes: Annual changes and shares of total are c...       NaN
# Growth rates are adjusted for leap years.                NaN
#
# [68 rows x 44 columns]

# %%
# omit empty rows

bp = bp.dropna(how='all')

# %%
# 'Million tonnes' is not the correct column name -- rename to 'Country'
bp.index.name = 'Country Name'

# %%
# omit summary rows
omit = []
for country in bp.index:
     if 'Total' in country or 'Other' in country or 'European Union' in country or 'OECD' in country:
            bp = bp.drop(country)
bp

# %%
# drop empty rows with notes at the bottom
bp = bp.dropna(how='all')
#bp

# %%
# omit summary columns (three leftmost columns)

bp = bp.drop(columns=['2021.1', '2011-21', '2021.2'])

# %%
# total = []
# for country in bp.index:
#     tot = bp.loc[country].sum()
#     total.append(tot)
# #total

# %%
# bp['Cumulative Total'] = total
# #bp

# %%
#bp.loc['Canada'][:-1].sum()

# %%
# for col in bp.columns:
#     if col != '1981' and col != 'Cumulative Total':
#         current_yr = bp[col]
#         prev_tot = bp[str(int(col)-1)]
#         bp[col] = current_yr + prev_tot
# bp

# %%
# err = []
# for country in bp.index:
#     twenty_21 = round(bp['2021'][country], 1)
#     tot = round(bp['Cumulative Total'][country], 1)
#     if twenty_21 != tot:
#         err.append(country)
# err

# %%
# bp.loc['USSR']

# %%
### plot US coal capacity
#plt.plot(bp.loc['US'])
#plt.xticks(rotation=90)
#None

# %%
# export clean file as new csv
#bp.to_csv(path_or_buf='test.csv')

# %%
# map country codes onto data
iso = pd.read_excel('WUP2018-DataSource-UrbanAgglomeration-and-CapitalCities.xls', header=16, usecols=[1, 3, 4])
iso = iso.drop_duplicates()
iso = iso.set_index('Country or area')

# %%
iso2 = []
err = []
for country in bp.index:
    try:
        iso2.append(iso.loc[country][1])
    except KeyError:
        if country=='US':
            iso2.append(iso.loc['United States of America'][1])
        elif country=='Venezuela':
            iso2.append(iso.loc['Venezuela (Bolivarian Republic of)'][1])
        elif country=='Czech Republic':
            iso2.append(iso.loc['Czechia'][1])
        elif country=='South Korea':
            iso2.append(iso.loc['Republic of Korea'][1])
        elif country=='Vietnam':
            iso2.append(iso.loc['Viet Nam'][1])
        elif country=='USSR':
            iso2.append('SU')
        else:
            err.append(country)

if len(err) != 0:
    raise Exception('Something went wrong')

bp['Country Code'] = iso2

# %%
bp.insert(0, 'Country Name', bp.index)
bp = bp.set_index('Country Code')
bp
