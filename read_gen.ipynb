# %%
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://pcdb.santafe.edu/graph.php?curve=119
# Acrylic Fiber

# %%
acrylic_fiber = pd.read_csv('raw data/AcrylicFiber.csv')
acrylic_fiber.drop(columns=['Previous Production (Mil. lbs)', 'Price (1966 USD/lbs)'], inplace=True)
acrylic_fiber.set_index('Time (year)', inplace=True)
acrylic_fiber = acrylic_fiber.transpose()
acrylic_fiber['Technology Name'] = 'Acrylic Fiber'
acrylic_fiber['Unit'] = 'Million Pounds'
acrylic_fiber['Spatial Scale'] = 'Global'
acrylic_fiber['Data Source'] = 'Santa Fe Institute'
acrylic_fiber['Metric'] = 'Annual Production'
acrylic_fiber['ID'] = acrylic_fiber['Technology Name'] + '_' + acrylic_fiber['Metric'] + '_'+ acrylic_fiber['Unit'] + '_Global'
acrylic_fiber.set_index('ID', drop=True, inplace=True)
acrylic_fiber.columns.name = None
acrylic_fiber
# Out:
#                                                      1960   1961   1962  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  135.7  140.1  170.0
#
#                                                      1963   1964   1965  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  209.7  287.7  368.4
#
#                                                      1966   1967   1968  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  352.9  397.7  521.0
#
#                                                      1969   1970   1971  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  533.0  491.9  545.2
#
#                                                      1972 Technology Name  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  625.9   Acrylic Fiber
#
#                                                               Unit  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  Million Pounds
#
#                                                    Spatial Scale  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...        Global
#
#                                                            Data Source  \
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  Santa Fe Institute
#
#                                                                Metric
# ID
# Acrylic Fiber_Annual Production_Million Pounds_...  Annual Production

# %%
acrylic_fiber.to_csv('cleaned data/acrylic_fiber.csv')
