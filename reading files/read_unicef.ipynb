# %%
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco
import os

# %%
# https://data.unicef.org/topic/child-health/immunization/
# Immunization coverage by antigen
# https://data.unicef.org/wp-content/uploads/2016/07/wuenic2021rev_web-update.xlsx

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
file = pd.ExcelFile('raw data/wuenic2021rev_web-update.xlsx')
unicef_sheets = file.sheet_names

# %%
def read_unicef(sheet):
    unicef = pd.read_excel('raw data/wuenic2021rev_web-update.xlsx', sheet_name=sheet)
    unicef.rename(columns={'country': 'Country Name', 'vaccine': 'Technology Name'}, inplace=True)
    unicef['Technology Name'] = unicef['Technology Name'] + ' Vaccine'
    unicef['Unit'] = 'Percentage'
    unicef['Metric'] = 'Immunization Coverage'
    unicef['Data Source'] = 'UNICEF'
    unicef['Spatial Scale'] = 'National'
    iso3 = unicef['iso3']
    iso2 = []
    for iso in iso3:
        iso2.append(coco.convert(names=iso, to='iso2'))
    unicef['Country Code'] = iso2
    unicef.drop(columns={'unicef_region', 'iso3'}, inplace=True)
    unicef['ID'] = unicef['Technology Name'] + '_'+ unicef['Metric'] + '_' + '_' + unicef['Country Code']
    unicef.set_index('ID', inplace=True)
    return unicef

# %%
unicef_1 = read_unicef(unicef_sheets[0])
unicef_list = [unicef_1]

# %%
check_col = []
for col in unicef_1.columns:
    if len(col) == 4 and col != 'Unit':
        check_col.append(col)
        
for year in check_col:
    check = unicef_1[year]
    for pct in check:
        if pct > 100 or pct < 0:
            raise Exception("percentages can't be greater than 100 or less than 0")

# %%
for x in unicef_sheets[1:-1]:
    df = read_unicef(x)
    check_col = []
    for col in df.columns:
        if len(col) == 4 and col != 'Unit':
            check_col.append(col)
    for year in check_col:
        check = df[year]
        for pct in check:
            if pct > 100 or pct < 0:
                raise Exception("percentages can't be greater than 100 or less than 0")
    unicef_list.append(df)

# %%
un = pd.concat(unicef_list)
un
# Out:
#                                                              Country Name  \
# ID
# BCG Vaccine_Immunization Coverage__AF                         Afghanistan
# BCG Vaccine_Immunization Coverage__AL                             Albania
# BCG Vaccine_Immunization Coverage__DZ                             Algeria
# BCG Vaccine_Immunization Coverage__AO                              Angola
# BCG Vaccine_Immunization Coverage__AR                           Argentina
# ...                                                                   ...
# YFV Vaccine_Immunization Coverage__SL                        Sierra Leone
# YFV Vaccine_Immunization Coverage__SR                            Suriname
# YFV Vaccine_Immunization Coverage__TG                                Togo
# YFV Vaccine_Immunization Coverage__TT                 Trinidad and Tobago
# YFV Vaccine_Immunization Coverage__VE  Venezuela (Bolivarian Republic of)
#
#                                       Technology Name  2021  2020  2019  2018  \
# ID
Immunization Coverage       UNICEF
# YFV Vaccine_Immunization Coverage__VE  Immunization Coverage       UNICEF
#
#                                        Spatial Scale  Country Code
# ID
# BCG Vaccine_Immunization Coverage__AF       National            AF
# BCG Vaccine_Immunization Coverage__AL       National            AL
# BCG Vaccine_Immunization Coverage__DZ       National            DZ
# BCG Vaccine_Immunization Coverage__AO       National            AO
# BCG Vaccine_Immunization Coverage__AR       National            AR
# ...                                              ...           ...
# YFV Vaccine_Immunization Coverage__SL       National            SL
# YFV Vaccine_Immunization Coverage__SR       National            SR
# YFV Vaccine_Immunization Coverage__TG       National            TG
# YFV Vaccine_Immunization Coverage__TT       National            TT
# YFV Vaccine_Immunization Coverage__VE       National            VE
#
# [2295 rows x 49 columns]

# %%
omit = []
for col in un.columns:
    if len(col) != 4 or col == 'Unit':
        omit.append(col)
empty_rows = un.drop(columns=omit)
empty_rows.dropna(how='all', inplace=True)
na_idx = []
for country in un.index:
    if country not in empty_rows.index:
        na_idx.append(country)
un.drop(na_idx, inplace=True)
un
# Out:
#                                                              Country Name  \
# ID
# BCG Vaccine_Immunization Coverage__AF                         Afghanistan
# BCG Vaccine_Immunization Coverage__AL                             Albania
# BCG Vaccine_Immunization Coverage__DZ                             Algeria
# BCG Vaccine_Immunization Coverage__AO                              Angola
# BCG Vaccine_Immunization Coverage__AR                           Argentina
# ...                                                                   ...
# YFV Vaccine_Immunization Coverage__SL                        Sierra Leone
# YFV Vaccine_Immunization Coverage__SR                            Suriname
# YFV Vaccine_Immunization Coverage__TG                                Togo
# YFV Vaccine_Immunization Coverage__TT                 Trinidad and Tobago
# YFV Vaccine_Immunization Coverage__VE  Venezuela (Bolivarian Republic of)
#
#                                       Technology Name  2021  2020  2019  2018  \
# ID
# BCG Vaccine_Immunization Coverage__AF     BCG Vaccine  84.0  87.0  86.0  89.0
# BCG Vaccine_Immunization Coverage__AL     BCG Vaccine  99.0  98.0  99.0  99.0
# BCG Vaccine_Immunization Coverage__DZ     BCG Vaccine  99.0  99.0  99.0  99.0
# BCG Vaccine_Immunization Coverage__AO     BCG Vaccine  56.0  58.0  69.0  72.0
# BCG Vaccine_Immunization Coverage__AR     BCG Vaccine  81.0  75.0  85.0  93.0
# ...                                               ...   ...   ...   ...   ...
# YFV Vaccine_Immunization Coverage__SL     YFV Vaccine  85.0  86.0  90.0  85.0
# YFV Vaccine_Immunization Coverage__SR     YFV Vaccine  61.0  44.0  57.0  63.0
# YFV Vaccine_Immunization Coverage__TG     YFV Vaccine  66.0  66.0  71.0  68.0
# YFV Vaccine_Immunization Coverage__TT     YFV Vaccine  91.0  89.0  98.0  88.0
# YFV Vaccine_Immunization Coverage__VE     YFV Vaccine  75.0  82.0  80.0  35.0
#
#                                        2017  2016  2015  2014  ...  1984  \
# ID                                                             ...
# BCG Vaccine_Immunization Coverage__AF  84.0  78.0  76.0  74.0  ...  11.0
# BCG Vaccine_Immunization Coverage__AL  99.0  99.0  99.0  99.0  ...  90.0
# BCG Vaccine_Immunization Coverage__DZ  99.0  99.0  99.0  99.0  ...   NaN
# BCG Vaccine_Immunization Coverage__AO  69.0  40.0  64.0  72.0  ...  28.0
# BCG Vaccine_Immunization Coverage__AR  95.0  92.0  96.0  99.0  ...  78.0
# ...                                     ...   ...   ...   ...  ...   ...
# YFV Vaccine_Immunization Coverage__SL  80.0  80.0  78.0  80.0  ...   NaN
# YFV Vaccine_Immunization Coverage__SR  67.0  61.0  68.0  61.0  ...   NaN
# YFV Vaccine_Immunization Coverage__TG  73.0  68.0  71.0  75.0  ...   NaN
# YFV Vaccine_Immunization Coverage__TT  95.0  85.0  91.0  96.0  ...   NaN
# YFV Vaccine_Immunization Coverage__VE  83.0  84.0  85.0  82.0  ...   NaN
#
#                                        1983  1982  1981  1980        Unit  \
# ID
# BCG Vaccine_Immunization Coverage__AF  10.0  10.0   NaN   NaN  Percentage
# BCG Vaccine_Immunization Coverage__AL  90.0  92.0  93.0  93.0  Percentage
# BCG Vaccine_Immunization Coverage__DZ   NaN   NaN   NaN   NaN  Percentage
# BCG Vaccine_Immunization Coverage__AO  25.0   NaN   NaN   NaN  Percentage
# BCG Vaccine_Immunization Coverage__AR  70.0  77.0  70.0  62.0  Percentage
# ...                                     ...   ...   ...   ...         ...
# YFV Vaccine_Immunization Coverage__SL   NaN   NaN   NaN   NaN  Percentage
# YFV Vaccine_Immunization Coverage__SR   NaN   NaN   NaN   NaN  Percentage
# YFV Vaccine_Immunization Coverage__TG   NaN   NaN   NaN   NaN  Percentage
# YFV Vaccine_Immunization Coverage__TT   NaN   NaN   NaN   NaN  Percentage
# YFV Vaccine_Immunization Coverage__VE   NaN   NaN   NaN   NaN  Percentage
#
#                                                       Metric  Data Source  \
# ID
# BCG Vaccine_Immunization Coverage__AF  Immunization Coverage       UNICEF
# BCG Vaccine_Immunization Coverage__AL  Immunization Coverage       UNICEF
# BCG Vaccine_Immunization Coverage__DZ  Immunization Coverage       UNICEF
# BCG Vaccine_Immunization Coverage__AO  Immunization Coverage       UNICEF
# BCG Vaccine_Immunization Coverage__AR  Immunization Coverage       UNICEF
# ...                                                      ...          ...
# YFV Vaccine_Immunization Coverage__SL  Immunization Coverage       UNICEF
# YFV Vaccine_Immunization Coverage__SR  Immunization Coverage       UNICEF
# YFV Vaccine_Immunization Coverage__TG  Immunization Coverage       UNICEF
# YFV Vaccine_Immunization Coverage__TT  Immunization Coverage       UNICEF
# YFV Vaccine_Immunization Coverage__VE  Immunization Coverage       UNICEF
#
#                                        Spatial Scale  Country Code
# ID
# BCG Vaccine_Immunization Coverage__AF       National            AF
# BCG Vaccine_Immunization Coverage__AL       National            AL
# BCG Vaccine_Immunization Coverage__DZ       National            DZ
# BCG Vaccine_Immunization Coverage__AO       National            AO
# BCG Vaccine_Immunization Coverage__AR       National            AR
# ...                                              ...           ...
# YFV Vaccine_Immunization Coverage__SL       National            SL
# YFV Vaccine_Immunization Coverage__SR       National            SR
# YFV Vaccine_Immunization Coverage__TG       National            TG
# YFV Vaccine_Immunization Coverage__TT       National            TT
# YFV Vaccine_Immunization Coverage__VE       National            VE
#
# [2295 rows x 49 columns]

# %%
un.to_csv('cleaned data/unicef.csv')
