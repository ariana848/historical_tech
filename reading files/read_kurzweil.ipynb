# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
def read_kurzweil(page_no, tech_name, unit):
    file_name = 'raw data/page' + str(page_no) + '.xls'
    df = pd.read_excel(file_name, header=2, index_col=0, usecols=[0, 1])
    df = df[:-3]
    df = df.transpose()
    df['Data Source'] = 'Kurzweil'
    df['Country Name'] = 'World'
    df['Country Code'] = 'World'
    df['Spatial Scale'] = 'Global'
    df['Metric'] = 'Cumulative Total Capacity'
    df['Technology Name'] = tech_name
    df['Unit'] = unit
    df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']
    df.set_index('ID', drop=True, inplace=True)
    df.columns.name = None
    file_name = 'cleaned data/' + tech_name + '.csv'
    df.to_csv(file_name)
    return df

# %%
# https://www.singularity.com/charts/page64.html
# https://www.singularity.com/images/charts/xls/page64.xls
# Processor Performance

# %%
processing_power = read_kurzweil(64, 'Processor Performance', 'Million instructions per second (MIPS)')
processing_power
# Out:
#                                                      1971  1972  1974  1976  \
# ID
# Processor Performance_Cumulative Total Capacity...  0.035  0.08  0.33   0.4
#
#                                                     1978  1982  1985  1989  \
# ID
# Processor Performance_Cumulative Total Capacity...   0.9   2.5   5.0  17.0
#
#                                                      1993   1995  ...    2000  \
# ID                                                                ...
# Processor Performance_Cumulative Total Capacity...  100.0  800.0  ...  4000.0
#
#                                                        2001     2002  \
# ID
# Processor Performance_Cumulative Total Capacity...  10000.0  12000.0
#
#                                                     Data Source  Country Name  \
# ID
# Processor Performance_Cumulative Total Capacity...     Kurzweil         World
#
#                                                    Country Code Spatial Scale  \
# ID
# Processor Performance_Cumulative Total Capacity...        World        Global
#
#                                                                        Metric  \
# ID
# Processor Performance_Cumulative Total Capacity...  Cumulative Total Capacity
#
#                                                           Technology Name  \
# ID
# Processor Performance_Cumulative Total Capacity...  Processor Performance
#
#                                                                                       Unit
# ID
# Processor Performance_Cumulative Total Capacity...  Million instructions per second (MIPS)
#
# [1 rows x 22 columns]

# %%
# https://www.singularity.com/charts/page75.html
# https://www.singularity.com/images/charts/xls/page75.xls
# RAM

# %%
ram = read_kurzweil(75, 'Random Access Memory', 'Bits/2000 USD')
ram
# Out:
#                                                        1949     1951  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  0.02423  0.03459
#
#                                                         1955     1960  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  0.090545  0.10386
#
#                                                        1962    1965    1968  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  0.21193  1.1623  6.5123
#
#                                                       1973    1975    1976  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  11.388  104.82  170.64
#
#                                                     ...        2002  \
# ID                                                  ...
# Random Access Memory_Cumulative Total Capacity_...  ...  31469000.0
#
#                                                           2003        2004  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  36428000.0  93945000.0
#
#                                                     Data Source  Country Name  \
# ID
# Random Access Memory_Cumulative Total Capacity_...     Kurzweil         World
#
#                                                     Country Code  \
# ID
# Random Access Memory_Cumulative Total Capacity_...         World
#
#                                                     Spatial Scale  \
# ID
# Random Access Memory_Cumulative Total Capacity_...         Global
#
#                                                                        Metric  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  Cumulative Total Capacity
#
#                                                          Technology Name  \
# ID
# Random Access Memory_Cumulative Total Capacity_...  Random Access Memory
#
#                                                              Unit
# ID
# Random Access Memory_Cumulative Total Capacity_...  Bits/2000 USD
#
# [1 rows x 45 columns]

# %%
# https://www.singularity.com/charts/page61.html
# https://www.singularity.com/images/charts/xls/page61.xls
# Microprocessor Clock Speed

# %%
microprocessor_clock = read_kurzweil(61, 'Microprocessor Clock Speed', 'Hz')
microprocessor_clock
# Out:
#                                                          1976       1977  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  1350000.0  2060000.0
#
#                                                          1978       1979  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  2140000.0  2290000.0
#
#                                                          1980       1981  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  1940000.0  2410000.0
#
#                                                          1982       1983  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  2630000.0  4070000.0
#
#                                                          1984       1985  ...  \
# ID                                                                        ...
# Microprocessor Clock Speed_Cumulative Total Cap...  5190000.0  5890000.0  ...
#
#                                                             2010  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  1.151100e+10
#
#                                                             2013  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  1.934800e+10
#
#                                                             2016  Data Source  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  2.875100e+10     Kurzweil
#
#                                                     Country Name  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...         World
#
#                                                     Country Code  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...         World
#
#                                                     Spatial Scale  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...         Global
#
#                                                                        Metric  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  Cumulative Total Capacity
#
#                                                                Technology Name  \
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...  Microprocessor Clock Speed
#
#                                                     Unit
# ID
# Microprocessor Clock Speed_Cumulative Total Cap...    Hz
#
# [1 rows x 41 columns]

# %%
# https://www.singularity.com/charts/page76.html
# https://www.singularity.com/images/charts/xls/page76.xls
# Magnetic Data Storage

# %%
magnetic_data = read_kurzweil(76, 'Magnetic Data Storage', 'Bits/2000 USD')
magnetic_data
# Out:
#                                                       1952   1956    1966  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  0.2033  158.8  1437.0
#
#                                                       1970     1974     1980  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  6941.0  12380.0  20040.0
#
#                                                        1980     1981     1982  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  19910.0  15320.0  11310.0
#
#                                                        1983  ...  \
# ID                                                           ...
# Magnetic Data Storage_Cumulative Total Capacity...  14500.0  ...
#
#                                                          2002.25  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  4.812000e+09
#
#                                                          2003.17  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  6.552000e+09
#
#                                                          2004.17  Data Source  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  1.182000e+10     Kurzweil
#
#                                                     Country Name  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...         World
#
#                                                     Country Code  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...         World
#
#                                                     Spatial Scale  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...         Global
#
#                                                                        Metric  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  Cumulative Total Capacity
#
#                                                           Technology Name  \
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  Magnetic Data Storage
#
#                                                              Unit
# ID
# Magnetic Data Storage_Cumulative Total Capacity...  Bits/2000 USD
#
# [1 rows x 40 columns]

# %%
# https://www.singularity.com/charts/page63.html
# https://www.singularity.com/images/charts/xls/page63.xls
# Transistors per Microprocessor

# %%
transistors_per_microprocessor = read_kurzweil(63, 'Transistors per Microprocessor', 'Number of transistors per chip')
transistors_per_microprocessor
# Out:
#                                                       1971    1972    1974  \
# ID
# Transistors per Microprocessor_Cumulative Total...  2250.0  2500.0  5000.0
#
#                                                        1978      1982  \
# ID
# Transistors per Microprocessor_Cumulative Total...  29000.0  120000.0
#
#                                                         1985       1989  \
# ID
# Transistors per Microprocessor_Cumulative Total...  275000.0  1600000.0
#
#                                                          1993       1997  \
# ID
# Transistors per Microprocessor_Cumulative Total...  3100000.0  7500000.0
#
#                                                           1999        2000  \
# ID
# Transistors per Microprocessor_Cumulative Total...  24000000.0  42000000.0
#
#                                                            2002         2003  \
# ID
# Transistors per Microprocessor_Cumulative Total...  169000000.0  410000000.0
#
#                                                    Data Source Country Name  \
# ID
# Transistors per Microprocessor_Cumulative Total...    Kurzweil        World
#
#                                                    Country Code Spatial Scale  \
# ID
# Transistors per Microprocessor_Cumulative Total...        World        Global
#
#                                                                        Metric  \
# ID
# Transistors per Microprocessor_Cumulative Total...  Cumulative Total Capacity
#
#                                                                    Technology Name  \
# ID
# Transistors per Microprocessor_Cumulative Total...  Transistors per Microprocessor
#
#                                                                               Unit
# ID
# Transistors per Microprocessor_Cumulative Total...  Number of transistors per chip

# %%
# https://www.singularity.com/charts/page81.html
# https://www.singularity.com/images/charts/xls/page81.xls
# Internet Backbone Bandwidth

# %%
internet_backbone = read_kurzweil(81, 'Internet Backbone Bandwidth', 'Bits/second')
internet_backbone
# Out:
#                                                        1968     1972     1973  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  50000.0  50000.0  50000.0
#
#                                                        1974     1976     1979  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  50000.0  50000.0  50000.0
#
#                                                        1981     1983     1984  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  56000.0  56000.0  56000.0
#
#                                                          1985  ...  \
# ID                                                             ...
# Internet Backbone Bandwidth_Cumulative Total Ca...  1544000.0  ...
#
#                                                             2002  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  2.488000e+09
#
#                                                             2003  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  9.952000e+09
#
#                                                             2004  Data Source  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  9.952000e+09     Kurzweil
#
#                                                     Country Name  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...         World
#
#                                                     Country Code  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...         World
#
#                                                     Spatial Scale  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...         Global
#
#                                                                        Metric  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  Cumulative Total Capacity
#
#                                                                 Technology Name  \
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  Internet Backbone Bandwidth
#
#                                                            Unit
# ID
# Internet Backbone Bandwidth_Cumulative Total Ca...  Bits/second
#
# [1 rows x 35 columns]

# %%
# https://www.singularity.com/charts/page70.html
# https://www.singularity.com/images/charts/xls/page70.xls
# Computing Growth

# %%
# not stated what year the dollar is indexed to
computing_growth = read_kurzweil(70, 'Computing Growth', 'Calculations per second per $1,000')
computing_growth
# Out:
#                                                       1900     1908      1911  \
# ID
# Computing Growth_Cumulative Total Capacity_World  0.000006  0.00013  0.000058
#
#                                                       1919      1928  \
# ID
# Computing Growth_Cumulative Total Capacity_World  0.001064  0.000699
#
#                                                       1939     1940    1941  \
# ID
# Computing Growth_Cumulative Total Capacity_World  0.008547  0.01431  0.0463
#
#                                                    1943    1946  ...  \
# ID                                                               ...
# Computing Growth_Cumulative Total Capacity_World  5.308  0.7981  ...
#
#                                                        1993        1996  \
# ID
# Computing Growth_Cumulative Total Capacity_World  3549000.0  48080000.0
#
#                                                          1998  Data Source  \
# ID
# Computing Growth_Cumulative Total Capacity_World  133300000.0     Kurzweil
#
#                                                   Country Name  Country Code  \
# ID
# Computing Growth_Cumulative Total Capacity_World         World         World
#
#                                                   Spatial Scale  \
# ID
# Computing Growth_Cumulative Total Capacity_World         Global
#
#                                                                      Metric  \
# ID
# Computing Growth_Cumulative Total Capacity_World  Cumulative Total Capacity
#
#                                                    Technology Name  \
# ID
# Computing Growth_Cumulative Total Capacity_World  Computing Growth
#
#                                                                                 Unit
# ID
# Computing Growth_Cumulative Total Capacity_World  Calculations per second per $1,000
#
# [1 rows x 54 columns]
