# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://sandia.gov/ess-ssl/gesdb/public/statistics.html

# %%
path = '/Users/ariana/desktop/historical_tech/raw data'
os.chdir(path)

# %%
doe = pd.read_csv('Cummulative Sum by Year_Full Data_data.csv')
doe
# Out:
#       Year of Project Year          Technology Mid-Type        Country  \
# 0                     2007  Technology Mid-Type Unknown  United States
# 1                     2009  Technology Mid-Type Unknown         Sweden
# 2                     2011  Technology Mid-Type Unknown  United States
# 3                     2011  Technology Mid-Type Unknown  United States
# 4                     2013  Technology Mid-Type Unknown          Spain
# ...                    ...                          ...            ...
# 1620                  2018         Pumped hydro storage      Indonesia
# 1621                  2019         Pumped hydro storage      Australia
# 1622                  2020         Pumped hydro storage        Ireland
# 1623                  2020         Pumped hydro storage          Japan
# 1624                  2020         Pumped hydro storage          Japan
#
#                           Technology Broad Category  \
# 0                            Thermal energy storage
# 1                            Thermal energy storage
# 2                 Electro-mechanical energy storage
# 3     Electro-chemical battery and chemical storage
# 4     Electro-chemical battery and chemical storage
# ...                                             ...
# 1620              Electro-mechanical energy storage
# 1621              Electro-mechanical energy storage
# 1622              Electro-mechanical energy storage
# 1623              Electro-mechanical energy storage
# 1624              Electro-mechanical energy storage
#
#               Technology Sub-Type  \
# 0     Technology Sub-Type Unknown
# 1     Technology Sub-Type Unknown
# 2     Technology Sub-Type Unknown
# 3     Technology Sub-Type Unknown
# 4     Technology Sub-Type Unknown
# ...                           ...
# 1620                Open-loop PHS
# 1621  Technology Sub-Type Unknown
# 1622                Open-loop PHS
# 1623                Open-loop PHS
# 1624                Open-loop PHS
#
#             Subsystem 1 - Technology Broad Category  \
# 0                            Thermal energy storage
# 1                            Thermal energy storage
# 2                 Electro-mechanical energy storage
# 3     Electro-chemical battery and chemical storage
# 4     Electro-chemical battery and chemical storage
# ...                                             ...
# 1620              Electro-mechanical energy storage
# 1621              Electro-mechanical energy storage
# 1622              Electro-mechanical energy storage
# 1623              Electro-mechanical energy storage
# 1624              Electro-mechanical energy storage
#
#      Subsystem 1 - Technology Mid-Type Subsystem 1 - Technology Sub-Type  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 1620              Pumped hydro storage                     Open-loop PHS
# 1621              Pumped hydro storage                               NaN
# 1622              Pumped hydro storage                     Open-loop PHS
# 1623              Pumped hydro storage                     Open-loop PHS
# 1624              Pumped hydro storage                     Open-loop PHS
#
#       Discharge Duration at Rated Power (hrs)  Rated Capacity (kWh)  \
# 0                                         0.5               32000.0
# 1                                         0.0                   NaN
# 2                                         0.0                   NaN
# 3                                         0.0                   NaN
# 4                                         0.0                   NaN
# ...                                       ...                   ...
# 1620                                      0.0                   NaN
# 1621                                      6.0             1500000.0
# 1622                                      6.0                9000.0
# 1623                                      0.0                   NaN
# 1624                                      0.0                   NaN
#
#       Rated Power (kW)  Storage Capacity (kWh)
# 0                64000                 32000.0
# 1                10000                     0.0
# 2                  430                     0.0
# 3                 1500                     0.0
# 4                    0                     0.0
# ...                ...                     ...
# 1620           1040000                     0.0
# 1621            250000               1500000.0
# 1622              1500                  9000.0
# 1623            200000                     0.0
# 1624           1880000                     0.0
#
# [1625 rows x 12 columns]

# %%
doe.drop_duplicates()
# Out:
#       Year of Project Year          Technology Mid-Type        Country  \
# 0                     2007  Technology Mid-Type Unknown  United States
# 1                     2009  Technology Mid-Type Unknown         Sweden
# 2                     2011  Technology Mid-Type Unknown  United States
# 3                     2011  Technology Mid-Type Unknown  United States
# 4                     2013  Technology Mid-Type Unknown          Spain
# ...                    ...                          ...            ...
# 1620                  2018         Pumped hydro storage      Indonesia
# 1621                  2019         Pumped hydro storage      Australia
# 1622                  2020         Pumped hydro storage        Ireland
# 1623                  2020         Pumped hydro storage          Japan
# 1624                  2020         Pumped hydro storage          Japan
#
#                           Technology Broad Category  \
# 0                            Thermal energy storage
# 1                            Thermal energy storage
# 2                 Electro-mechanical energy storage
# 3     Electro-chemical battery and chemical storage
# 4     Electro-chemical battery and chemical storage
# ...                                             ...
# 1620              Electro-mechanical energy storage
# 1621              Electro-mechanical energy storage
# 1622              Electro-mechanical energy storage
# 1623              Electro-mechanical energy storage
# 1624              Electro-mechanical energy storage
#
#               Technology Sub-Type  \
# 0     Technology Sub-Type Unknown
# 1     Technology Sub-Type Unknown
# 2     Technology Sub-Type Unknown
# 3     Technology Sub-Type Unknown
# 4     Technology Sub-Type Unknown
# ...                           ...
# 1620                Open-loop PHS
# 1621  Technology Sub-Type Unknown
# 1622                Open-loop PHS
# 1623                Open-loop PHS
# 1624                Open-loop PHS
#
#             Subsystem 1 - Technology Broad Category  \
# 0                            Thermal energy storage
# 1                            Thermal energy storage
# 2                 Electro-mechanical energy storage
# 3     Electro-chemical battery and chemical storage
# 4     Electro-chemical battery and chemical storage
# ...                                             ...
# 1620              Electro-mechanical energy storage
# 1621              Electro-mechanical energy storage
# 1622              Electro-mechanical energy storage
# 1623              Electro-mechanical energy storage
# 1624              Electro-mechanical energy storage
#
#      Subsystem 1 - Technology Mid-Type Subsystem 1 - Technology Sub-Type  \
# 0                                  NaN                               NaN
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# ...                                ...                               ...
# 1620              Pumped hydro storage                     Open-loop PHS
# 1621              Pumped hydro storage                               NaN
# 1622              Pumped hydro storage                     Open-loop PHS
# 1623              Pumped hydro storage                     Open-loop PHS
# 1624              Pumped hydro storage                     Open-loop PHS
#
#       Discharge Duration at Rated Power (hrs)  Rated Capacity (kWh)  \
# 0                                         0.5               32000.0
# 1                                         0.0                   NaN
# 2                                         0.0                   NaN
# 3                                         0.0                   NaN
# 4                                         0.0                   NaN
# ...                                       ...                   ...
# 1620                                      0.0                   NaN
# 1621                                      6.0             1500000.0
# 1622                                      6.0                9000.0
# 1623                                      0.0                   NaN
# 1624                                      0.0                   NaN
#
#       Rated Power (kW)  Storage Capacity (kWh)
# 0                64000                 32000.0
# 1                10000                     0.0
# 2                  430                     0.0
# 3                 1500                     0.0
# 4                    0                     0.0
# ...                ...                     ...
# 1620           1040000                     0.0
# 1621            250000               1500000.0
# 1622              1500                  9000.0
# 1623            200000                     0.0
# 1624           1880000                     0.0
#
# [1417 rows x 12 columns]

# %%
tech_list = list(set(doe['Technology Mid-Type']))
tech_list.sort()
tech_list
# Out:
# ['Compressed air energy storage',
#  'Electro-chemical capacitor',
#  'Flow battery',
#  'Flywheel',
#  'Heat thermal storage',
#  'Hydrogen storage',
#  'Latent heat',
#  'Lead-acid battery',
#  'Lithium-ion battery',
#  'Nickel-based battery',
#  'Pumped hydro storage',
#  'Sensible heat',
#  'Sodium-based battery',
#  'Technology Mid-Type Unknown',
#  'Zinc-based battery']

# %%
doe.set_index('Year of Project Year', drop=True, inplace=True)
doe
# Out:
#                               Technology Mid-Type        Country  \
# Year of Project Year
# 2007                  Technology Mid-Type Unknown  United States
# 2009                  Technology Mid-Type Unknown         Sweden
# 2011                  Technology Mid-Type Unknown  United States
# 2011                  Technology Mid-Type Unknown  United States
# 2013                  Technology Mid-Type Unknown          Spain
# ...                                           ...            ...
# 2018                         Pumped hydro storage      Indonesia
# 2019                         Pumped hydro storage      Australia
# 2020                         Pumped hydro storage        Ireland
# 2020                         Pumped hydro storage          Japan
# 2020                         Pumped hydro storage          Japan
#
#                                           Technology Broad Category  \
# Year of Project Year
# 2007                                         Thermal energy storage
# 2009                                         Thermal energy storage
# 2011                              Electro-mechanical energy storage
# 2011                  Electro-chemical battery and chemical storage
# 2013                  Electro-chemical battery and chemical storage
# ...                                                             ...
# 2018                              Electro-mechanical energy storage
# 2019                              Electro-mechanical energy storage
# 2020                              Electro-mechanical energy storage
# 2020                              Electro-mechanical energy storage
# 2020                              Electro-mechanical energy storage
#
#                               Technology Sub-Type  \
# Year of Project Year
# 2007                  Technology Sub-Type Unknown
# 2009                  Technology Sub-Type Unknown
# 2011                  Technology Sub-Type Unknown
# 2011                  Technology Sub-Type Unknown
# 2013                  Technology Sub-Type Unknown
# ...                                           ...
# 2018                                Open-loop PHS
# 2019                  Technology Sub-Type Unknown
# 2020                                Open-loop PHS
# 2020                                Open-loop PHS
# 2020                                Open-loop PHS
#
#                             Subsystem 1 - Technology Broad Category  \
# Year of Project Year
# 2007                                         Thermal energy storage
# 2009                                         Thermal energy storage
# 2011                              Electro-mechanical energy storage
# 2011                  Electro-chemical battery and chemical storage
# 2013                  Electro-chemical battery and chemical storage
# ...                                                             ...
# 2018                              Electro-mechanical energy storage
# 2019                              Electro-mechanical energy storage
# 2020                              Electro-mechanical energy storage
# 2020                              Electro-mechanical energy storage
# 2020                              Electro-mechanical energy storage
#
#                      Subsystem 1 - Technology Mid-Type  \
# Year of Project Year
# 2007                                               NaN
# 2009                                               NaN
# 2011                                               NaN
# 2011                                               NaN
# 2013                                               NaN
# ...                                                ...
# 2018                              Pumped hydro storage
# 2019                              Pumped hydro storage
# 2020                              Pumped hydro storage
# 2020                              Pumped hydro storage
# 2020                              Pumped hydro storage
#
#                      Subsystem 1 - Technology Sub-Type  \
# Year of Project Year
# 2007                                               NaN
# 2009                                               NaN
# 2011                                               NaN
# 2011                                               NaN
# 2013                                               NaN
# ...                                                ...
# 2018                                     Open-loop PHS
# 2019                                               NaN
# 2020                                     Open-loop PHS
# 2020                                     Open-loop PHS
# 2020                                     Open-loop PHS
#
#                       Discharge Duration at Rated Power (hrs)  \
# Year of Project Year
# 2007                                                      0.5
# 2009                                                      0.0
# 2011                                                      0.0
# 2011                                                      0.0
# 2013                                                      0.0
# ...                                                       ...
# 2018                                                      0.0
# 2019                                                      6.0
# 2020                                                      6.0
# 2020                                                      0.0
# 2020                                                      0.0
#
#                       Rated Capacity (kWh)  Rated Power (kW)  \
# Year of Project Year
# 2007                               32000.0             64000
# 2009                                   NaN             10000
# 2011                                   NaN               430
# 2011                                   NaN              1500
# 2013                                   NaN                 0
# ...                                    ...               ...
# 2018                                   NaN           1040000
# 2019                             1500000.0            250000
# 2020                                9000.0              1500
# 2020                                   NaN            200000
# 2020                                   NaN           1880000
#
#                       Storage Capacity (kWh)
# Year of Project Year
# 2007                                 32000.0
# 2009                                     0.0
# 2011                                     0.0
# 2011                                     0.0
# 2013                                     0.0
# ...                                      ...
# 2018                                     0.0
# 2019                               1500000.0
# 2020                                  9000.0
# 2020                                     0.0
# 2020                                     0.0
#
# [1625 rows x 11 columns]

# %%
def read_doe(tech_name):
    df = doe[doe['Technology Mid-Type'] == tech_name]
    country_list = list(set(df['Country']))
    df_list = []
    for country in country_list:
        df_country = df[df['Country']== country]
        df_country = df_country.transpose()
        df_country['Technology Name'] = tech_name
        df_country['Country Name'] = country
        df_country.reset_index(inplace=True, drop=True)
        df_country = df_country[2:]
        df_country['Unit'] = 'kW'
        df_country['Data Source'] = 'DOE Global Energy Storage Database'
        df_country['Metric'] = 'Cumulative total capacity'
        df_country['Spatial Scale'] = 'National'
        df_country['Country Code'] = coco.convert(names=country, to='iso2')
        df_country['ID'] = df_country['Technology Name'] + '_' + df_country['Metric'] + '_' + df_country['Country Code']
        df_country.set_index('ID', drop=True, inplace=True)
        df_country.columns.name = None
        df_list.append(df_country)
        file_name = 'doe/' + tech_name + country + '.csv'
        df_country.to_csv(file_name)
    return df_list

# %%
for tech in tech_list:
    read_doe(tech)

# %%
os.chdir('/Users/ariana/desktop/historical_tech/cleaned data')
frame = pd.read_csv('frame.csv')

# %%
os.chdir('/Users/ariana/desktop/historical_tech/raw data/doe')
path = '/Users/ariana/desktop/historical_tech/raw data/doe'

# %%
df_list = [frame]
for file in os.listdir(path):
    if file[-4:] == '.csv':
        file = pd.read_csv(file)
        df_list.append(file)
doe_all = pd.concat(df_list)
doe_all
# Out:
#                                                    ID Spatial Scale  \
# 0    Lithium-ion battery_Cumulative total capacity_AI      National
# 1    Lithium-ion battery_Cumulative total capacity_AI      National
# 2    Lithium-ion battery_Cumulative total capacity_AI      National
# 3    Lithium-ion battery_Cumulative total capacity_AI      National
# 4    Lithium-ion battery_Cumulative total capacity_AI      National
# ..                                                ...           ...
# 4   Compressed air energy storage_Cumulative total...      National
# 5   Compressed air energy storage_Cumulative total...      National
# 6   Compressed air energy storage_Cumulative total...      National
# 7   Compressed air energy storage_Cumulative total...      National
# 8   Compressed air energy storage_Cumulative total...      National
#
#    Country Code Country Name                Technology Name  \
# 0            AI     Anguilla            Lithium-ion battery
# 1            AI     Anguilla            Lithium-ion battery
# 2            AI     Anguilla            Lithium-ion battery
# 3            AI     Anguilla            Lithium-ion battery
# 4            AI     Anguilla            Lithium-ion battery
# ..          ...          ...                            ...
# 4            CA       Canada  Compressed air energy storage
# 5            CA       Canada  Compressed air energy storage
# 6            CA       Canada  Compressed air energy storage
# 7            CA       Canada  Compressed air energy storage
# 8            CA       Canada  Compressed air energy storage
#
#                        Metric Unit                         Data Source 1700  \
# 0   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 1   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 2   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 3   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 4   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# ..                        ...  ...                                 ...  ...
# 4   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 5   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 6   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 7   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
# 8   Cumulative total capacity   kW  DOE Global Energy Storage Database  NaN
#
#    1701  ... 2009.3 2007.1 2010.3 2010.4 2010.5 2010.6 2010.7 1977.1 1977.2  \
# 0   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..  ...  ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 7   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 8   NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#    1986.1
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
#
# [2052 rows x 701 columns]

# %%
os.chdir('/Users/ariana/desktop/historical_tech/cleaned data')

# %%
doe_all.to_csv('doe.csv', index=False)
