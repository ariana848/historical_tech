# %%
import os
import pandas as pd
from pandas import Series, DataFrame

# %%
# https://www.genome.gov/about-genomics/fact-sheets/DNA-Sequencing-Costs-Data

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
dna = pd.read_excel('raw data/cost data/Cummulative Sum by Year_Full Data_data.xls')
dna
# Out:
#          Date  Cost per Mb  Cost per Genome
# 0  2001-09-30  5292.392885     9.526307e+07
# 1  2002-03-31  3898.635412     7.017544e+07
# 2  2002-09-30  3413.801195     6.144842e+07
# 3  2003-03-31  2986.204671     5.375168e+07
# 4  2003-10-31  2230.975235     4.015755e+07
# ..        ...          ...              ...
# 73 2021-05-31     0.005045     4.540462e+02
# 74 2021-08-31     0.006246     5.621754e+02
# 75 2021-11-30     0.006136     5.521966e+02
# 76 2022-02-28     0.005829     5.246247e+02
# 77 2022-05-31     0.005829     5.246247e+02
#
# [78 rows x 3 columns]

# %%
years = []
for idx in range(len(dna)):
    date = int(str(dna.iloc[idx]['Date'])[:4])
    years.append(date)
dna['Year'] = years
dna.drop(columns=['Date'], inplace=True)
dna.set_index('Year', drop=True, inplace=True)
dna = dna.groupby(['Year']).mean()

# %%
dna = dna.transpose()
dna['Data Source'] = 'NIH'
dna['Spatial Scale'] = 'Global'
dna['Country Code'] = 'World'
dna['Country Name'] = 'World'
dna['Metric'] = 'Price'
dna['Unit'] = ['USD/megabase','USD/genome']
dna['Technology Name'] = 'DNA Sequencing (All Methods)'
dna['ID'] = dna['Technology Name'] + '_' + dna['Metric'] + '_' + dna['Country Code']
dna.set_index('ID', drop=True, inplace=True)
dna.columns.name = None
dna
# Out:
#                                                   2001          2002  \
# ID
# DNA Sequencing (All Methods)_Price_World  5.292393e+03  3.656218e+03
# DNA Sequencing (All Methods)_Price_World  9.526307e+07  6.581193e+07
#
#                                                   2003          2004  \
# ID
# DNA Sequencing (All Methods)_Price_World  2.608590e+03  1.217731e+03
# DNA Sequencing (All Methods)_Price_World  4.695462e+07  2.191915e+07
#
#                                                   2005          2006  \
# ID
# DNA Sequencing (All Methods)_Price_World  8.843891e+02  6.423342e+02
# DNA Sequencing (All Methods)_Price_World  1.591900e+07  1.156202e+07
#
#                                                   2007          2008  \
# ID
# DNA Sequencing (All Methods)_Price_World  4.795924e+02  3.233062e+01
# DNA Sequencing (All Methods)_Price_World  8.632664e+06  1.377846e+06
#
#                                                    2009          2010  ...  \
# ID                                                                     ...
# DNA Sequencing (All Methods)_Price_World       1.571799      0.384731  ...
# DNA Sequencing (All Methods)_Price_World  141461.877669  34625.751714  ...
#
#                                                 2020       2021        2022  \
# ID
# DNA Sequencing (All Methods)_Price_World    0.007074    0.00672    0.005829
# DNA Sequencing (All Methods)_Price_World  636.678216  604.81485  524.624684
#
#                                           Data Source  Spatial Scale  \
# ID
# DNA Sequencing (All Methods)_Price_World          NIH         Global
# DNA Sequencing (All Methods)_Price_World          NIH         Global
#
#                                           Country Code  Country Name  Metric  \
# ID
# DNA Sequencing (All Methods)_Price_World         World         World   Price
# DNA Sequencing (All Methods)_Price_World         World         World   Price
#
#                                                   Unit  \
# ID
# DNA Sequencing (All Methods)_Price_World  USD/megabase
# DNA Sequencing (All Methods)_Price_World    USD/genome
#
#                                                        Technology Name
# ID
# DNA Sequencing (All Methods)_Price_World  DNA Sequencing (All Methods)
# DNA Sequencing (All Methods)_Price_World  DNA Sequencing (All Methods)
#
# [2 rows x 29 columns]

# %%
dna.to_csv('cleaned data/dna sequencing.csv')
