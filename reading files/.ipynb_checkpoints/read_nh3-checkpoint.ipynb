# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
os.chdir('/Users/ariana/desktop/historical_tech')

# %%
nh3 = pd.read_excel('raw data/Nitrogen Data Consolidated.xlsx', sheet_name='5-All Time Series', index_col=0)
nh3
# Out:
#         Afghanistan_NitrogenFertilizer_Production_ThousandTonsNeq  \
# W
# Country                                        Afghanistan
# Process                                 NitrogenFertilizer
# Measure                                         Production
# Units                                      ThousandTonsNeq
# Sources                                       FAOSTAT 2022
# ...                                                    ...
# 2018                                                14.416
# 2019                                                14.416
# 2020                                                14.416
# 2021                                                   NaN
# 2022                                                   NaN
#
#         Albania_NitrogenFertilizer_Production_ThousandTonsNeq  \
# W
# Country                                            Albania
# Process                                 NitrogenFertilizer
# ...

# %%
nh3 = nh3.transpose()
nh3
# Out:
# W                                                       Country  \
# Afghanistan_NitrogenFertilizer_Production_Thous...  Afghanistan
# Albania_NitrogenFertilizer_Production_ThousandT...      Albania
# Algeria_NitrogenFertilizer_Production_ThousandT...      Algeria
# Argentina_NitrogenFertilizer_Production_Thousan...    Argentina
# Armenia_NitrogenFertilizer_Production_ThousandT...      Armenia
# ...                                                         ...
# Yugoslavia_Cyanamide_Production_ThousandTons         Yugoslavia
# Yugoslavia_Cyanamide_Production_ThousandTonsNeq      Yugoslavia
# Yugoslavia_NitrogenFertilizer_Production_Thousa...   Yugoslavia
# Zambia_NitrogenFertilizer_Production_ThousandTo...       Zambia
# Zimbabwe_NitrogenFertilizer_Production_Thousand...     Zimbabwe
#
# W                                                              Process  \
# Afghanistan_NitrogenFertilizer_Production_Thous...  NitrogenFertilizer
# ...

# %%
country_list = sorted(list(set(nh3['Country'])))
country_list
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Bahrain',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Belgium-Luxembourg',
#  'Bolivia',
#  'BosniaandHerzegovinia',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Cameroon',
#  'Canada',
#  'China',
#  'Chinale',
#  'Colombia',
#  'CostaRica',
#  'CotedIvoire',
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'CzechRepublic',
#  'Czecholslovakia',
#  'Czechoslovakia',
#  'Denmark',
#  'Ecuador',
#  'Egypt',
#  'ElSalvador',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Guatemala',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kazhakstan',
#  'Korea',
#  'Kuwait',
#  'Latvia',
#  'Lebanon',
#  'Libya',
#  'Lithuania',
#  'Malawi',
#  'Malaysia',
#  'Manchuria',
#  'Mexico',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Nepal',
# ...

# %%
world_nh3 = nh3[nh3['Country']=='World']
world_nh3
# Out:
# W                                                  Country  \
# World_Cyanamide_Production_ThousandTons              World
# World_Cyanamide_Production_ThousandTonsNeq           World
# World_ByproductAmmonia_Production_ThousandTons       World
# World_ByproductAmmonia_Production_ThousandTonsNeq    World
# World_SyntheticAmmonia_Production_ThousandTons       World
# World_SyntheticAmmonia_Production_ThousandTonsNeq    World
# World_NitrogenFertilizer_Production_ThousandTon...   World
# World_AllAmmonia_Production_ThousandTons             World
# World_AllAmmonia_Production_ThousandTonsNeq          World
# World_NitrogenFertilizer_Production_ThousandTon...   World
# World_ElectricArc_PlantsConstructed_NumberOfPlants   World
# World_ElectricArc_TotalPlants_NumberOfPlants         World
# World_ElectricArc_CapacityConstructed_ThousandT...   World
# World_ElectricArc_TotalCapacity_ThousandTonsNeq      World
# World_Cyanamide_PlantsConstructed_NumberOfPlants     World
# ...

# %%
world_nh3 = world_nh3[(world_nh3['Process']!='NitrogenFertilizer') & (world_nh3['Process']!='AllAmmonia')]
world_nh3
# Out:
# W                                                  Country  \
# World_Cyanamide_Production_ThousandTons              World
# World_Cyanamide_Production_ThousandTonsNeq           World
# World_ByproductAmmonia_Production_ThousandTons       World
# World_ByproductAmmonia_Production_ThousandTonsNeq    World
# World_SyntheticAmmonia_Production_ThousandTons       World
# World_SyntheticAmmonia_Production_ThousandTonsNeq    World
# World_ElectricArc_PlantsConstructed_NumberOfPlants   World
# World_ElectricArc_TotalPlants_NumberOfPlants         World
# World_ElectricArc_CapacityConstructed_ThousandT...   World
# World_ElectricArc_TotalCapacity_ThousandTonsNeq      World
# World_Cyanamide_PlantsConstructed_NumberOfPlants     World
# World_Cyanamide_TotalPlants_NumberOfPlants           World
# World_Cyanamide_CapacityConstructed_ThousandTon...   World
# World_Cyanamide_TotalCapacity_ThousandTonsNeq        World
# World_HaberBosch_PlantsConstructed_NumberOfPlants    World
# ...

# %%
processes = list(set(world_nh3['Process']))
processes
# ask cameron about aggregation - are these things mutually exclusive?
# Out:
# ['ElectricArc',
#  'ByproductAmmonia',
#  'Cyanamide',
#  'SyntheticAmmonia',
#  'HaberBosch',
#  'OtherCatalyticSynthesis']

# %%
process_units = {}
for process in processes:
    df = world_nh3[world_nh3['Process']==process]
    units = list(set(df['Units']))
    process_units[process] = units
process_units
# Out:
# {'ElectricArc': ['NumberOfPlants', 'TonsNeq'],
#  'ByproductAmmonia': ['ThousandTonsNeq', 'ThousandTons'],
#  'Cyanamide': ['NumberOfPlants', 'ThousandTonsNeq', 'ThousandTons', 'TonsNeq'],
#  'SyntheticAmmonia': ['ThousandTonsNeq', 'ThousandTons'],
#  'HaberBosch': ['NumberOfPlants', 'TonsNeq'],
#  'OtherCatalyticSynthesis': ['NumberOfPlants', 'TonsNeq']}
