# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
def read_kurzweil(page_no, tech_name, unit):
    file_name = 'raw data/kurzweil/page' + str(page_no) + '.xls'
    df = pd.read_excel(file_name, header=2, usecols=[0, 1])
    df = df[:-3]
    reg_year = []
    mid_year = []
    for col in df[df.columns[0]]:
        if type(col) == float:
            mid_year.append(col)
        if type(col) == int:
            reg_year.append(col)
    if len(mid_year) != 0:
        for year in mid_year:
            four_digit_year = int(str(year)[:4])
            idx = df[df[df.columns[0]]==year].index.tolist()
            if four_digit_year in reg_year:
                df.drop(idx, inplace=True)
            else:
                df.replace({year: str(four_digit_year)}, inplace=True)
    seen = set()
    dupes = []
    for year in df[df.columns[0]]:
        if year in seen:
            dupes.append(year)
        else:
            seen.add(year)
    dup_dict = {}
    if len(dupes) != 0:
        for dup in dupes:
            dup_df = df[df[df.columns[0]]==dup]
            avg_dup_val = sum(dup_df[dup_df.columns[1]]) / len(dup_df[dup_df.columns[1]])
            dup_dict[dup] = avg_dup_val
            dup_idx = df[df[df.columns[0]]==dup].index.tolist()
            df.drop(dup_idx, inplace=True)
    df.set_index(df.columns[0], drop=True, inplace=True)
    df = df.transpose()
    for dup in dup_dict:
        df[dup] = dup_dict[dup]
    df['Data Source'] = 'Kurzweil'
    df['Country Name'] = 'World'
    df['Country Code'] = 'World'
    df['Spatial Scale'] = 'Global'
    df['Metric'] = 'Computing Capacity'
    df['Technology Name'] = tech_name
    df['Unit'] = unit
    df['ID'] = df['Technology Name'] + '_' + df['Metric'] + '_' + df['Country Code']
    df.set_index('ID', drop=True, inplace=True)
    df.columns.name = None
    file_name = 'cleaned data/' + tech_name + '.csv'
    df.to_csv(file_name)
    return df

# %%
# https://www.singularity.com/charts/page64.html
# https://www.singularity.com/images/charts/xls/page64.xls
# Processor Performance

# %%
processing_power = read_kurzweil(64, 'Processor Performance', 'million instructions/second')
processing_power
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                                                  1971  1972  1974  1976  1978  \
# ID
# Processor Performance_Computing Capacity_World  0.035  0.08  0.33   0.4   0.9
#
#                                                 1982  1985  1989   1993  \
# ID
# Processor Performance_Computing Capacity_World   2.5   5.0  17.0  100.0
#
#                                                  1995  ...    2000     2001  \
# ID                                                     ...
# Processor Performance_Computing Capacity_World  800.0  ...  4000.0  10000.0
#
#                                                    2002  Data Source  \
# ID
# Processor Performance_Computing Capacity_World  12000.0     Kurzweil
#
#                                                 Country Name Country Code  \
# ID
# Processor Performance_Computing Capacity_World         World        World
#
#                                                Spatial Scale  \
# ID
# Processor Performance_Computing Capacity_World        Global
#
#                                                             Metric  \
# ID
# Processor Performance_Computing Capacity_World  Computing Capacity
#
#                                                       Technology Name  \
# ID
# Processor Performance_Computing Capacity_World  Processor Performance
#
#                                                                        Unit
# ID
# Processor Performance_Computing Capacity_World  million instructions/second
#
# [1 rows x 22 columns]

# %%
# https://www.singularity.com/charts/page75.html
# https://www.singularity.com/images/charts/xls/page75.xls
# RAM

# %%
ram = read_kurzweil(75, 'Random Access Memory', 'bits/2000 USD')
ram
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                                                   1949     1951      1955  \
# ID
# Random Access Memory_Computing Capacity_World  0.02423  0.03459  0.090545
#
#                                                   1960     1962    1965  \
# ID
# Random Access Memory_Computing Capacity_World  0.10386  0.21193  1.1623
#
#                                                  1968    1973    1975    1976  \
# ID
# Random Access Memory_Computing Capacity_World  6.5123  11.388  104.82  170.64
#
#                                                ...        2002        2003  \
# ID                                             ...
# Random Access Memory_Computing Capacity_World  ...  31469000.0  36428000.0
#
#                                                      2004  Data Source  \
# ID
# Random Access Memory_Computing Capacity_World  93945000.0     Kurzweil
#
#                                                Country Name  Country Code  \
# ID
# Random Access Memory_Computing Capacity_World         World         World
#
#                                                Spatial Scale  \
# ID
# Random Access Memory_Computing Capacity_World         Global
#
#                                                            Metric  \
# ID
# Random Access Memory_Computing Capacity_World  Computing Capacity
#
#                                                     Technology Name  \
# ID
# Random Access Memory_Computing Capacity_World  Random Access Memory
#
#                                                         Unit
# ID
# Random Access Memory_Computing Capacity_World  bits/2000 USD
#
# [1 rows x 45 columns]

# %%
# https://www.singularity.com/charts/page61.html
# https://www.singularity.com/images/charts/xls/page61.xls
# Microprocessor Clock Speed

# %%
microprocessor_clock = read_kurzweil(61, 'Microprocessor Clock Speed', 'Hz')
microprocessor_clock
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                                                          1976       1977  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  1350000.0  2060000.0
#
#                                                          1978       1979  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  2140000.0  2290000.0
#
#                                                          1980       1981  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  1940000.0  2410000.0
#
#                                                          1982       1983  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  2630000.0  4070000.0
#
#                                                          1984       1985  ...  \
# ID                                                                        ...
# Microprocessor Clock Speed_Computing Capacity_W...  5190000.0  5890000.0  ...
#
#                                                             2010  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  1.151100e+10
#
#                                                             2013  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  1.934800e+10
#
#                                                             2016  Data Source  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  2.875100e+10     Kurzweil
#
#                                                     Country Name  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...         World
#
#                                                     Country Code  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...         World
#
#                                                     Spatial Scale  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...         Global
#
#                                                                 Metric  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  Computing Capacity
#
#                                                                Technology Name  \
# ID
# Microprocessor Clock Speed_Computing Capacity_W...  Microprocessor Clock Speed
#
#                                                     Unit
# ID
# Microprocessor Clock Speed_Computing Capacity_W...    Hz
#
# [1 rows x 41 columns]

# %%
# https://www.singularity.com/charts/page76.html
# https://www.singularity.com/images/charts/xls/page76.xls
# Magnetic Data Storage

# %%
magnetic_data = read_kurzweil(76, 'Magnetic Data Storage', 'bits/2000 USD')
magnetic_data
# Out:
#                                                   1952   1956    1966    1970  \
# ID
# Magnetic Data Storage_Computing Capacity_World  0.2033  158.8  1437.0  6941.0
#
#                                                    1974     1981     1982  \
# ID
# Magnetic Data Storage_Computing Capacity_World  12380.0  15320.0  11310.0
#
#                                                    1983     1984     1985  \
# ID
# Magnetic Data Storage_Computing Capacity_World  14500.0  41210.0  77440.0
#
#                                                 ...          2003  \
# ID                                              ...
# Magnetic Data Storage_Computing Capacity_World  ...  6.552000e+09
#
#                                                         2004     1980  \
# ID
# Magnetic Data Storage_Computing Capacity_World  1.182000e+10  19975.0
#
#                                                 Data Source  Country Name  \
# ID
# Magnetic Data Storage_Computing Capacity_World     Kurzweil         World
#
#                                                 Country Code  Spatial Scale  \
# ID
# Magnetic Data Storage_Computing Capacity_World         World         Global
#
#                                                             Metric  \
# ID
# Magnetic Data Storage_Computing Capacity_World  Computing Capacity
#
#                                                       Technology Name  \
# ID
# Magnetic Data Storage_Computing Capacity_World  Magnetic Data Storage
#
#                                                          Unit
# ID
# Magnetic Data Storage_Computing Capacity_World  bits/2000 USD
#
# [1 rows x 37 columns]

# %%
# https://www.singularity.com/charts/page63.html
# https://www.singularity.com/images/charts/xls/page63.xls
# Transistors per Microprocessor

# %%
transistors_per_microprocessor = read_kurzweil(63, 'Transistors per Microprocessor', 'no. of transistors/chip')
transistors_per_microprocessor
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                                                       1971    1972    1974  \
# ID
# Transistors per Microprocessor_Computing Capaci...  2250.0  2500.0  5000.0
#
#                                                        1978      1982  \
# ID
# Transistors per Microprocessor_Computing Capaci...  29000.0  120000.0
#
#                                                         1985       1989  \
# ID
# Transistors per Microprocessor_Computing Capaci...  275000.0  1600000.0
#
#                                                          1993       1997  \
# ID
# Transistors per Microprocessor_Computing Capaci...  3100000.0  7500000.0
#
#                                                           1999        2000  \
# ID
# Transistors per Microprocessor_Computing Capaci...  24000000.0  42000000.0
#
#                                                            2002         2003  \
# ID
# Transistors per Microprocessor_Computing Capaci...  169000000.0  410000000.0
#
#                                                    Data Source Country Name  \
# ID
# Transistors per Microprocessor_Computing Capaci...    Kurzweil        World
#
#                                                    Country Code Spatial Scale  \
# ID
# Transistors per Microprocessor_Computing Capaci...        World        Global
#
#                                                                 Metric  \
# ID
# Transistors per Microprocessor_Computing Capaci...  Computing Capacity
#
#                                                                    Technology Name  \
# ID
# Transistors per Microprocessor_Computing Capaci...  Transistors per Microprocessor
#
#                                                                        Unit
# ID
# Transistors per Microprocessor_Computing Capaci...  no. of transistors/chip

# %%
# https://www.singularity.com/charts/page81.html
# https://www.singularity.com/images/charts/xls/page81.xls
# Internet Backbone Bandwidth

# %%
internet_backbone = read_kurzweil(81, 'Internet Backbone Bandwidth', 'bits/second')
internet_backbone
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                                                        1968     1972     1973  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  50000.0  50000.0  50000.0
#
#                                                        1974     1976     1979  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  50000.0  50000.0  50000.0
#
#                                                        1981     1983     1984  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  56000.0  56000.0  56000.0
#
#                                                          1985  ...  \
# ID                                                             ...
# Internet Backbone Bandwidth_Computing Capacity_...  1544000.0  ...
#
#                                                             2002  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  2.488000e+09
#
#                                                             2003  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  9.952000e+09
#
#                                                             2004  Data Source  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  9.952000e+09     Kurzweil
#
#                                                     Country Name  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...         World
#
#                                                     Country Code  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...         World
#
#                                                     Spatial Scale  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...         Global
#
#                                                                 Metric  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  Computing Capacity
#
#                                                                 Technology Name  \
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  Internet Backbone Bandwidth
#
#                                                            Unit
# ID
# Internet Backbone Bandwidth_Computing Capacity_...  bits/second
#
# [1 rows x 35 columns]

# %%
# https://www.singularity.com/charts/page70.html
# https://www.singularity.com/images/charts/xls/page70.xls
# Computing Growth

# %%
# not stated what year the dollar is indexed to
computing_growth = read_kurzweil(70, 'Computing Growth', 'calculations per second/1000 USD')
computing_growth
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6999: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)
#                                                1900     1908      1911  \
# ID
# Computing Growth_Computing Capacity_World  0.000006  0.00013  0.000058
#
#                                                1919      1928      1939  \
# ID
# Computing Growth_Computing Capacity_World  0.001064  0.000699  0.008547
#
#                                               1940    1941   1943    1946  \
# ID
# Computing Growth_Computing Capacity_World  0.01431  0.0463  5.308  0.7981
#
#                                            ...    1973     1977      1982  \
# ID                                         ...
# Computing Growth_Computing Capacity_World  ...  2064.8  15295.0  126600.0
#
#                                            Data Source  Country Name  \
# ID
# Computing Growth_Computing Capacity_World     Kurzweil         World
#
#                                            Country Code  Spatial Scale  \
# ID
# Computing Growth_Computing Capacity_World         World         Global
#
#                                                        Metric  \
# ID
# Computing Growth_Computing Capacity_World  Computing Capacity
#
#                                             Technology Name  \
# ID
# Computing Growth_Computing Capacity_World  Computing Growth
#
#                                                                        Unit
# ID
# Computing Growth_Computing Capacity_World  calculations per second/1000 USD
#
# [1 rows x 45 columns]
