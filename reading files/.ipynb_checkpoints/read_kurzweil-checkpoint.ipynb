# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
def read_kurzweil(page_no):
    file_name = 'raw data/page' + str(page_no) + '.xls'
    df = pd.read_excel(file_name, header=2, index_col=0, usecols=[0, 1])
    df = df[:-3]
    df = df.transpose()
    return df

# %%
# https://www.singularity.com/charts/page64.html
# https://www.singularity.com/images/charts/xls/page64.xls
# Processor Performance

# %%
processor = read_kurzweil(64)
processor
# Out:
# Year   1971  1972  1974  1976  1978  1982  1985  1989   1993   1995    1997  \
# MIPS  0.035  0.08  0.33   0.4   0.9   2.5   5.0  17.0  100.0  800.0  1005.0
#
# Year    1999    2000     2001     2002
# MIPS  1500.0  4000.0  10000.0  12000.0

# %%
# https://www.singularity.com/charts/page75.html
# https://www.singularity.com/images/charts/xls/page75.xls
# RAM

# %%
ram = read_kurzweil(75)
ram
# Out:
# year                1949     1951      1955     1960     1962    1965    1968  \
# Bits per Dollar  0.02423  0.03459  0.090545  0.10386  0.21193  1.1623  6.5123
#
# year               1973    1975    1976  ...      1995      1996       1997  \
# Bits per Dollar  11.388  104.82  170.64  ...  221090.0  260990.0  1753900.0
#
# year                  1998       1999       2000        2001        2002  \
# Bits per Dollar  3783300.0  6196700.0  7366900.0  52648000.0  31469000.0
#
# year                   2003        2004
# Bits per Dollar  36428000.0  93945000.0
#
# [1 rows x 38 columns]

# %%
# https://www.singularity.com/charts/page61.html
# https://www.singularity.com/images/charts/xls/page61.xls
# Microprocessor Clock Speed

# %%
microprocessor_clock = read_kurzweil(61)
microprocessor_clock
# Out:
# Year       1976       1977       1978       1979       1980       1981  \
# Hz    1350000.0  2060000.0  2140000.0  2290000.0  1940000.0  2410000.0
#
# Year       1982       1983       1984       1985  ...          2001  \
# Hz    2630000.0  4070000.0  5190000.0  5890000.0  ...  1.684000e+09
#
# Year          2002          2003          2004          2005          2006  \
# Hz    2.317000e+09  3.088000e+09  3.990000e+09  5.173000e+09  5.631000e+09
#
# Year          2007          2010          2013          2016
# Hz    6.739000e+09  1.151100e+10  1.934800e+10  2.875100e+10
#
# [1 rows x 34 columns]

# %%
# https://www.singularity.com/charts/page76.html
# https://www.singularity.com/images/charts/xls/page76.xls
# Magnetic Data Storage

# %%
magnetic_data = read_kurzweil(76)
magnetic_data
# Out:
# Year             1952.00  1956.00  1966.00  1970.00  1974.00  1980.00  \
# Bits per Dollar   0.2033    158.8   1437.0   6941.0  12380.0  20040.0
#
# Year             1980.00  1981.00  1982.00  1983.00  ...     1996.75  \
# Bits per Dollar  19910.0  15320.0  11310.0  14500.0  ...  54050000.0
#
# Year                1997.00     1998.00      1999.00      1999.17  \
# Bits per Dollar  61560000.0  87180000.0  243600000.0  415300000.0
#
# Year                 2000.00       2001.17       2002.25       2003.17  \
# Bits per Dollar  541000000.0  2.283000e+09  4.812000e+09  6.552000e+09
#
# Year                  2004.17
# Bits per Dollar  1.182000e+10
#
# [1 rows x 33 columns]

# %%
# https://www.singularity.com/charts/page63.html
# https://www.singularity.com/images/charts/xls/page63.xls
# Transistors per Microprocessor

# %%
transistors_per_microprocessor = read_kurzweil(63)
transistors_per_microprocessor
# Out:
# Year of Introduction    1971    1972    1974     1978      1982      1985  \
# Transistors           2250.0  2500.0  5000.0  29000.0  120000.0  275000.0
#
# Year of Introduction       1989       1993       1997        1999        2000  \
# Transistors           1600000.0  3100000.0  7500000.0  24000000.0  42000000.0
#
# Year of Introduction         2002         2003
# Transistors           169000000.0  410000000.0

# %%
# https://www.singularity.com/charts/page81.html
# https://www.singularity.com/images/charts/xls/page81.xls
# Internet Backbone Bandwidth

# %%
internet_backbone = read_kurzweil(81)
internet_backbone
# Out:
# Year                1968     1972     1973     1974     1976     1979  \
# Bits per Second  50000.0  50000.0  50000.0  50000.0  50000.0  50000.0
#
# Year                1981     1983     1984       1985  ...         1994  \
# Bits per Second  56000.0  56000.0  56000.0  1544000.0  ...  145000000.0
#
# Year                    1995         1996          1998          1999  \
# Bits per Second  145000000.0  622080000.0  2.488000e+09  2.488000e+09
#
# Year                     2000          2001          2002          2003  \
# Bits per Second  2.488000e+09  2.488000e+09  2.488000e+09  9.952000e+09
#
# Year                     2004
# Bits per Second  9.952000e+09
#
# [1 rows x 28 columns]

# %%
# https://www.singularity.com/charts/page70.html
# https://www.singularity.com/images/charts/xls/page70.xls
# Computing Growth

# %%
computing_growth = read_kurzweil(70)
computing_growth
# Out:
# Year            1900     1908      1911      1919      1928      1939  \
# CPS/$1,000  0.000006  0.00013  0.000058  0.001064  0.000699  0.008547
#
# Year           1940    1941   1943    1946  ...    1980      1982      1982  \
# CPS/$1,000  0.01431  0.0463  5.308  0.7981  ...  5621.0  126600.0  126600.0
#
# Year           1983     1984      1986      1987       1993        1996  \
# CPS/$1,000  86280.0  85030.0  538200.0  232600.0  3549000.0  48080000.0
#
# Year               1998
# CPS/$1,000  133300000.0
#
# [1 rows x 47 columns]
