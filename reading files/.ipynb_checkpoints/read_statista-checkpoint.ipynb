# %%
import os
import pandas as pd
from pandas import Series, DataFrame

# %%
# https://www.statista.com/statistics/896699/number-of-satellites-launched-by-year/
# Must be a premium subscriber to access to data

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
# Does Jenna have access to see the underlying data source?
satellites = pd.read_csv('raw data/Satellite Launches.csv', index_col=0)
satellites = satellites.transpose()
satellites['Data Source'] = 'Statista'
satellites['Country Name'] = 'World'
satellites['Country Code'] = 'World'
satellites['Spatial Scale'] = 'Global'
satellites['Metric'] = 'Cumulative Total Capacity'
satellites['Technology Name'] = 'Satellite launches'
satellites['Unit'] = 'Number of orbital launches'
satellites['ID'] = satellites['Technology Name'] + '_' + satellites['Metric'] + '_' + satellites['Country Code']
satellites.set_index('ID', drop=True, inplace=True)
satellites.columns.name = None
satellites
# Out:
#                                                     1957  1958  1959  1960  \
# ID
# Satellite launches_Cumulative Total Capacity_World     4    28    23    40
#
#                                                     1961  1962  1963  1964  \
# ID
# Satellite launches_Cumulative Total Capacity_World    54    84    70   104
#
#                                                     1965  1966  ...  2017  \
# ID                                                              ...
# Satellite launches_Cumulative Total Capacity_World   132   139  ...    91
#
#                                                     2018  2019  Data Source  \
# ID
# Satellite launches_Cumulative Total Capacity_World   114    95     Statista
#
#                                                     Country Name  \
# ID
# Satellite launches_Cumulative Total Capacity_World         World
#
#                                                     Country Code  \
# ID
# ...

# %%
satellites.to_csv('cleaned data/statista.csv')
