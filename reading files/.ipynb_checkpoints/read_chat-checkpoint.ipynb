# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://data.nber.org/data-appendix/w15319/
# https://data.nber.org/data-appendix/w15319/FinalCHAT_72909.csv
# https://www.nber.org/system/files/working_papers/w15319/w15319.pdf

# %%
os.chdir('/Users/ariana/desktop/historical_tech')

# %%
chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
chat
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/774643259.py:1: DtypeWarning: Columns (46,51,55,56,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
#       country_name  year  ag_harvester  ag_milkingmachine  ag_tractor  atm  \
# 0      Afghanistan  1750           NaN                NaN         NaN  NaN
# 1      Afghanistan  1751           NaN                NaN         NaN  NaN
# 2      Afghanistan  1752           NaN                NaN         NaN  NaN
# 3      Afghanistan  1753           NaN                NaN         NaN  NaN
# 4      Afghanistan  1754           NaN                NaN         NaN  NaN
# ...            ...   ...           ...                ...         ...  ...
# 41694     Zimbabwe  2004           NaN                NaN         NaN  NaN
# 41695     Zimbabwe  2005           NaN                NaN         NaN  NaN
# 41696     Zimbabwe  2006           NaN                NaN         NaN  NaN
# 41697     Zimbabwe  2007           NaN                NaN         NaN  NaN
# 41698     Zimbabwe  2008           NaN                NaN         NaN  NaN
#
#        aviationpkm  aviationtkm  bed_acute  bed_hosp  ...  vehicle_com  \
# 0              NaN          NaN        NaN       NaN  ...          NaN
# 1              NaN          NaN        NaN       NaN  ...          NaN
# 2              NaN          NaN        NaN       NaN  ...          NaN
# 3              NaN          NaN        NaN       NaN  ...          NaN
# 4              NaN          NaN        NaN       NaN  ...          NaN
# ...            ...          ...        ...       ...  ...          ...
# 41694          NaN          NaN        NaN       NaN  ...          NaN
# 41695          NaN          NaN        NaN       NaN  ...          NaN
# 41696          NaN          NaN        NaN       NaN  ...          NaN
# 41697          NaN          NaN        NaN       NaN  ...          NaN
# 41698          NaN          NaN        NaN       NaN  ...          NaN
#
#        visitorbeds  visitorrooms  xlpopulation  xlrealgdp  pctivprimeenroll  \
# 0              NaN           NaN           NaN        NaN               NaN
# 1              NaN           NaN           NaN        NaN               NaN
# 2              NaN           NaN           NaN        NaN               NaN
# 3              NaN           NaN           NaN        NaN               NaN
# 4              NaN           NaN           NaN        NaN               NaN
# ...            ...           ...           ...        ...               ...
# 41694          NaN           NaN           NaN        NaN               NaN
# 41695          NaN           NaN           NaN        NaN               NaN
# 41696          NaN           NaN           NaN        NaN               NaN
# 41697          NaN           NaN           NaN        NaN               NaN
# 41698          NaN           NaN           NaN        NaN               NaN
#
#        pctivsecenroll  pctivprivateinv  pctivpublicinv  pctivliteracy
# 0                 NaN              NaN             NaN            NaN
# 1                 NaN              NaN             NaN            NaN
# 2                 NaN              NaN             NaN            NaN
# 3                 NaN              NaN             NaN            NaN
# 4                 NaN              NaN             NaN            NaN
# ...               ...              ...             ...            ...
# 41694             NaN              NaN             NaN            NaN
# 41695             NaN              NaN             NaN            NaN
# 41696             NaN              NaN             NaN            NaN
# 41697             NaN              NaN             NaN            NaN
# 41698             NaN              NaN             NaN            NaN
#
# [41699 rows x 113 columns]

# %%
chat_dict = pd.read_excel('raw data/chat_dictionary.xlsx', skipfooter=2)
chat_dict
# Out:
#         VARIABLE NAME                                         DEFINITION   \
# 0         ag_harvester  Number of self‐propelled machines that reap an...
# 1    ag_milkingmachine  Number of installations consisting of several ...
# 2           ag_tractor  Number of wheel and crawler tractors (excludin...
# 3                  atm  Number of electromechanical devices that permi...
# 4          aviationpkm  Civil aviation passenger‐KM traveled on schedu...
# ..                 ...                                                ...
# 106   pctivprimeenroll                     Primary school enrollment rate
# 107    pctivsecenroll                   Secondary school enrollment rate
# 108    pctivprivateinv               Private investment as a share of GDP
# 109     pctivpublicinv                Public investment as a share of GDP
# 110      pctivliteracy  Percent literate (usually calculated on the ba...
#
#                                          SOURCE
# 0                                 FAOSTAT (2004)
# 1                                 FAOSTAT (2004)
# 2                                 FAOSTAT (2004)
# 3    BIS (various years) and ECB (various years)
# 4                                Mitchell (1998)
# ..                                           ...
# 106                           Mitchell and Banks
# 107                           Mitchell and Banks
# 108                      Penn World Table (2007)
# 109                      Penn World Table (2007)
# 110                                 Banks (2004)
#
# [111 rows x 3 columns]

# %%
var_names = list(chat.columns[2:])
var_names
# Out:
# ['ag_harvester',
#  'ag_milkingmachine',
#  'ag_tractor',
#  'atm',
#  'aviationpkm',
#  'aviationtkm',
#  'bed_acute',
#  'bed_hosp',
#  'bed_longterm',
#  'cabletv',
#  'cellphone',
#  'cheque',
#  'computer',
#  'creditdebit',
#  'eft',
#  'elecprod',
#  'fert_total',
#  'internetuser',
#  'irrigatedarea',
#  'kidney_dialpat',
#  'kidney_homedialpat',
#  'loom_auto',
#  'loom_total',
#  'mail',
#  'med_catscanner',
#  'med_lithotriptor',
#  'med_mammograph',
#  'med_mriunit',
#  'med_radiationequip',
#  'newspaper',
#  'pctdaysurg_cataract',
#  'pctdaysurg_cholecyst',
#  'pctdaysurg_hernia',
#  'pctdaysurg_lapcholecyst',
#  'pctdaysurg_tonsil',
#  'pctdaysurg_varicosevein',
#  'pcthomedialysis',
#  'pctimmunizdpt',
#  'pctimmunizmeas',
#  'pctirrigated',
#  'pctmvbyarea',
#  'pest_total',
#  'pos',
#  'radio',
#  'railline',
#  'railp',
#  'railpkm',
#  'railt',
#  'railtkm',
#  'ship_all',
#  'ship_motor',
#  'ship_sail',
#  'ship_steam',
#  'ship_steammotor',
#  'shipton_all',
#  'shipton_motor',
#  'shipton_sail',
#  'shipton_steam',
#  'shipton_steammotor',
#  'spindle_mule',
#  'spindle_ring',
#  'steel_acidbess',
#  'steel_basicbess',
#  'steel_bof',
#  'steel_eaf',
#  'steel_ohf',
#  'steel_other',
#  'steel_stainless',
#  'surg_appendectomy',
#  'surg_breastcnsv',
#  'surg_cardcath',
#  'surg_cataract',
#  'surg_cholecyst',
#  'surg_corbypass',
#  'surg_corinterven',
#  'surg_corstent',
#  'surg_csection',
#  'surg_hernia',
#  'surg_hipreplace',
#  'surg_hysterectomy',
#  'surg_kneereplace',
#  'surg_lapcholecyst',
#  'surg_mastectomy',
#  'surg_pacemaker',
#  'surg_prostatetrans',
#  'surg_prostatextrans',
#  'surg_tonsil',
#  'surg_varicosevein',
#  'telegram',
#  'telephone',
#  'transplant_bonemarrow',
#  'transplant_heart',
#  'transplant_kidney',
#  'transplant_liver',
#  'transplant_lung',
#  'tv',
#  'txtlmat_artif',
#  'txtlmat_otherraw',
#  'txtlmat_synth',
#  'txtlmat_totalraw',
#  'vehicle_car',
#  'vehicle_com',
#  'visitorbeds',
#  'visitorrooms',
#  'xlpopulation',
#  'xlrealgdp',
#  'pctivprimeenroll',
#  'pctivsecenroll',
#  'pctivprivateinv',
#  'pctivpublicinv',
#  'pctivliteracy']

# %%
def read_chat(col_num, tech_name, unit='Number in Use', metric='Cumulative total capacity'):
    chat = pd.read_csv('raw data/FinalCHAT_72909.csv', usecols=[0,1,col_num])
    chat.replace('Venezuala', 'Venezuela', inplace=True)
    country_list = list(set(chat['country_name']))
    chat_df = []
    for country in country_list:
        df = chat[chat['country_name']==country]
        df.set_index('year', drop=True, inplace=True)
        df = df.transpose()
        df['Country Name'] = country
        if country == 'North Vietnam':
            country_code = 'VD'
        elif country == 'South Vietnam':
            country_code = 'VN'
        else:
            country_code = coco.convert(names=country, to='iso2')
        df['Country Code'] = country_code
        df.drop(index='country_name', inplace=True)
        chat_df.append(df)
    chat_all = pd.concat(chat_df)
    chat_all['Data Source'] = 'NBER CHAT'
    chat_all['Spatial Scale'] = 'National'
    chat_all['Unit'] = unit
    chat_all['Metric'] = metric
    chat_all['Technology Name'] = tech_name
    chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
    chat_all.set_index('ID', drop=True, inplace=True)
    chat_all.columns.name = None
    omit = []
    for col in chat_all.columns:
        if type(col) != int:
            omit.append(col)
    empty_rows = chat_all.drop(columns=omit)
    empty_rows.dropna(how='all', inplace=True)
    na_idx = []
    for country in chat_all.index:
        if country not in empty_rows.index:
            na_idx.append(country)
    chat_all.drop(na_idx, inplace=True)
    file_name = 'cleaned data/chat_' + tech_name + '.csv'
    chat_all.to_csv(file_name)
    return chat_all

# %%
ag_harvester = read_chat(2, 'Crop harvester', metric='Total Number')
ag_harvester
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Crop harvester_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_TD  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Crop harvester_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008    Country Name  \
# ID                                   ...
# Crop harvester_Total Number_BR  NaN  ...  NaN  NaN  NaN          Brazil
# Crop harvester_Total Number_TD  NaN  ...  NaN  NaN  NaN            Chad
# Crop harvester_Total Number_SR  NaN  ...  NaN  NaN  NaN        Suriname
# Crop harvester_Total Number_BO  NaN  ...  NaN  NaN  NaN         Bolivia
# Crop harvester_Total Number_DE  NaN  ...  NaN  NaN  NaN         Germany
# ...                             ...  ...  ...  ...  ...             ...
# Crop harvester_Total Number_CA  NaN  ...  NaN  NaN  NaN          Canada
# Crop harvester_Total Number_RO  NaN  ...  NaN  NaN  NaN         Romania
# Crop harvester_Total Number_GB  NaN  ...  NaN  NaN  NaN  United Kingdom
# Crop harvester_Total Number_ER  NaN  ...  NaN  NaN  NaN         Eritrea
# Crop harvester_Total Number_SL  NaN  ...  NaN  NaN  NaN    Sierra Leone
#
#                                Country Code Data Source Spatial Scale  \
# ID
# Crop harvester_Total Number_BR           BR   NBER CHAT      National
# Crop harvester_Total Number_TD           TD   NBER CHAT      National
# Crop harvester_Total Number_SR           SR   NBER CHAT      National
# Crop harvester_Total Number_BO           BO   NBER CHAT      National
# Crop harvester_Total Number_DE           DE   NBER CHAT      National
# ...                                     ...         ...           ...
# Crop harvester_Total Number_CA           CA   NBER CHAT      National
# Crop harvester_Total Number_RO           RO   NBER CHAT      National
# Crop harvester_Total Number_GB           GB   NBER CHAT      National
# Crop harvester_Total Number_ER           ER   NBER CHAT      National
# Crop harvester_Total Number_SL           SL   NBER CHAT      National
#
#                                          Unit        Metric Technology Name
# ID
# Crop harvester_Total Number_BR  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_TD  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_SR  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_BO  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_DE  Number in Use  Total Number  Crop harvester
# ...                                       ...           ...             ...
# Crop harvester_Total Number_CA  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_RO  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_GB  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_ER  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_SL  Number in Use  Total Number  Crop harvester
#
# [121 rows x 266 columns]

# %%
steam_ships = read_chat(54, 'Steam ships')
steam_ships
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                          1750 1751 1752 1753 1754 1755 1756  \
# ID
# Steam ships_Cumulative total capacity_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_RU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_MX  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_SE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_HU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NO  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                          1757 1758 1759  ... 2006 2007 2008  \
# ID                                                       ...
# Steam ships_Cumulative total capacity_DE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FI  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_RU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_AT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DK  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_MX  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_ES  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_SE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_BE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_HU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NO  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CA  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GB  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#                                             Country Name Country Code  \
# ID
# Steam ships_Cumulative total capacity_DE         Germany           DE
# Steam ships_Cumulative total capacity_IE         Ireland           IE
# Steam ships_Cumulative total capacity_FR          France           FR
# Steam ships_Cumulative total capacity_FI         Finland           FI
# Steam ships_Cumulative total capacity_RU          Russia           RU
# Steam ships_Cumulative total capacity_AT         Austria           AT
# Steam ships_Cumulative total capacity_GR          Greece           GR
# Steam ships_Cumulative total capacity_DK         Denmark           DK
# Steam ships_Cumulative total capacity_MX          Mexico           MX
# Steam ships_Cumulative total capacity_ES           Spain           ES
# Steam ships_Cumulative total capacity_SE          Sweden           SE
# Steam ships_Cumulative total capacity_BE         Belgium           BE
# Steam ships_Cumulative total capacity_CL           Chile           CL
# Steam ships_Cumulative total capacity_CU            Cuba           CU
# Steam ships_Cumulative total capacity_NL     Netherlands           NL
# Steam ships_Cumulative total capacity_HU         Hungary           HU
# Steam ships_Cumulative total capacity_IT           Italy           IT
# Steam ships_Cumulative total capacity_NO          Norway           NO
# Steam ships_Cumulative total capacity_CA          Canada           CA
# Steam ships_Cumulative total capacity_GB  United Kingdom           GB
#
#                                          Data Source Spatial Scale  \
# ID
# Steam ships_Cumulative total capacity_DE   NBER CHAT      National
# Steam ships_Cumulative total capacity_IE   NBER CHAT      National
# Steam ships_Cumulative total capacity_FR   NBER CHAT      National
# Steam ships_Cumulative total capacity_FI   NBER CHAT      National
# Steam ships_Cumulative total capacity_RU   NBER CHAT      National
# Steam ships_Cumulative total capacity_AT   NBER CHAT      National
# Steam ships_Cumulative total capacity_GR   NBER CHAT      National
# Steam ships_Cumulative total capacity_DK   NBER CHAT      National
# Steam ships_Cumulative total capacity_MX   NBER CHAT      National
# Steam ships_Cumulative total capacity_ES   NBER CHAT      National
# Steam ships_Cumulative total capacity_SE   NBER CHAT      National
# Steam ships_Cumulative total capacity_BE   NBER CHAT      National
# Steam ships_Cumulative total capacity_CL   NBER CHAT      National
# Steam ships_Cumulative total capacity_CU   NBER CHAT      National
# Steam ships_Cumulative total capacity_NL   NBER CHAT      National
# Steam ships_Cumulative total capacity_HU   NBER CHAT      National
# Steam ships_Cumulative total capacity_IT   NBER CHAT      National
# Steam ships_Cumulative total capacity_NO   NBER CHAT      National
# Steam ships_Cumulative total capacity_CA   NBER CHAT      National
# Steam ships_Cumulative total capacity_GB   NBER CHAT      National
#
#                                                    Unit  \
# ID
# Steam ships_Cumulative total capacity_DE  Number in Use
# Steam ships_Cumulative total capacity_IE  Number in Use
# Steam ships_Cumulative total capacity_FR  Number in Use
# Steam ships_Cumulative total capacity_FI  Number in Use
# Steam ships_Cumulative total capacity_RU  Number in Use
# Steam ships_Cumulative total capacity_AT  Number in Use
# Steam ships_Cumulative total capacity_GR  Number in Use
# Steam ships_Cumulative total capacity_DK  Number in Use
# Steam ships_Cumulative total capacity_MX  Number in Use
# Steam ships_Cumulative total capacity_ES  Number in Use
# Steam ships_Cumulative total capacity_SE  Number in Use
# Steam ships_Cumulative total capacity_BE  Number in Use
# Steam ships_Cumulative total capacity_CL  Number in Use
# Steam ships_Cumulative total capacity_CU  Number in Use
# Steam ships_Cumulative total capacity_NL  Number in Use
# Steam ships_Cumulative total capacity_HU  Number in Use
# Steam ships_Cumulative total capacity_IT  Number in Use
# Steam ships_Cumulative total capacity_NO  Number in Use
# Steam ships_Cumulative total capacity_CA  Number in Use
# Steam ships_Cumulative total capacity_GB  Number in Use
#
#                                                              Metric  \
# ID
# Steam ships_Cumulative total capacity_DE  Cumulative total capacity
# Steam ships_Cumulative total capacity_IE  Cumulative total capacity
# Steam ships_Cumulative total capacity_FR  Cumulative total capacity
# Steam ships_Cumulative total capacity_FI  Cumulative total capacity
# Steam ships_Cumulative total capacity_RU  Cumulative total capacity
# Steam ships_Cumulative total capacity_AT  Cumulative total capacity
# Steam ships_Cumulative total capacity_GR  Cumulative total capacity
# Steam ships_Cumulative total capacity_DK  Cumulative total capacity
# Steam ships_Cumulative total capacity_MX  Cumulative total capacity
# Steam ships_Cumulative total capacity_ES  Cumulative total capacity
# Steam ships_Cumulative total capacity_SE  Cumulative total capacity
# Steam ships_Cumulative total capacity_BE  Cumulative total capacity
# Steam ships_Cumulative total capacity_CL  Cumulative total capacity
# Steam ships_Cumulative total capacity_CU  Cumulative total capacity
# Steam ships_Cumulative total capacity_NL  Cumulative total capacity
# Steam ships_Cumulative total capacity_HU  Cumulative total capacity
# Steam ships_Cumulative total capacity_IT  Cumulative total capacity
# Steam ships_Cumulative total capacity_NO  Cumulative total capacity
# Steam ships_Cumulative total capacity_CA  Cumulative total capacity
# Steam ships_Cumulative total capacity_GB  Cumulative total capacity
#
#                                          Technology Name
# ID
# Steam ships_Cumulative total capacity_DE     Steam ships
# Steam ships_Cumulative total capacity_IE     Steam ships
# Steam ships_Cumulative total capacity_FR     Steam ships
# Steam ships_Cumulative total capacity_FI     Steam ships
# Steam ships_Cumulative total capacity_RU     Steam ships
# Steam ships_Cumulative total capacity_AT     Steam ships
# Steam ships_Cumulative total capacity_GR     Steam ships
# Steam ships_Cumulative total capacity_DK     Steam ships
# Steam ships_Cumulative total capacity_MX     Steam ships
# Steam ships_Cumulative total capacity_ES     Steam ships
# Steam ships_Cumulative total capacity_SE     Steam ships
# Steam ships_Cumulative total capacity_BE     Steam ships
# Steam ships_Cumulative total capacity_CL     Steam ships
# Steam ships_Cumulative total capacity_CU     Steam ships
# Steam ships_Cumulative total capacity_NL     Steam ships
# Steam ships_Cumulative total capacity_HU     Steam ships
# Steam ships_Cumulative total capacity_IT     Steam ships
# Steam ships_Cumulative total capacity_NO     Steam ships
# Steam ships_Cumulative total capacity_CA     Steam ships
# Steam ships_Cumulative total capacity_GB     Steam ships
#
# [20 rows x 266 columns]

# %%
telephones = read_chat(91, 'Telephones', metric='Total Number')
telephones
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Telephones_Total Number_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_TD  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Telephones_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Telephones_Total Number_TG  ...  NaN  NaN  NaN            Togo           TG
# Telephones_Total Number_BR  ...  NaN  NaN  NaN          Brazil           BR
# Telephones_Total Number_TD  ...  NaN  NaN  NaN            Chad           TD
# Telephones_Total Number_TZ  ...  NaN  NaN  NaN        Tanzania           TZ
# Telephones_Total Number_SR  ...  NaN  NaN  NaN        Suriname           SR
# ...                         ...  ...  ...  ...             ...          ...
# Telephones_Total Number_CA  ...  NaN  NaN  NaN          Canada           CA
# Telephones_Total Number_RO  ...  NaN  NaN  NaN         Romania           RO
# Telephones_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# Telephones_Total Number_ER  ...  NaN  NaN  NaN         Eritrea           ER
# Telephones_Total Number_SL  ...  NaN  NaN  NaN    Sierra Leone           SL
#
#                            Data Source Spatial Scale           Unit  \
# ID
# Telephones_Total Number_TG   NBER CHAT      National  Number in Use
# Telephones_Total Number_BR   NBER CHAT      National  Number in Use
# Telephones_Total Number_TD   NBER CHAT      National  Number in Use
# Telephones_Total Number_TZ   NBER CHAT      National  Number in Use
# Telephones_Total Number_SR   NBER CHAT      National  Number in Use
# ...                                ...           ...            ...
# Telephones_Total Number_CA   NBER CHAT      National  Number in Use
# Telephones_Total Number_RO   NBER CHAT      National  Number in Use
# Telephones_Total Number_GB   NBER CHAT      National  Number in Use
# Telephones_Total Number_ER   NBER CHAT      National  Number in Use
# Telephones_Total Number_SL   NBER CHAT      National  Number in Use
#
#                                   Metric Technology Name
# ID
# Telephones_Total Number_TG  Total Number      Telephones
# Telephones_Total Number_BR  Total Number      Telephones
# Telephones_Total Number_TD  Total Number      Telephones
# Telephones_Total Number_TZ  Total Number      Telephones
# Telephones_Total Number_SR  Total Number      Telephones
# ...                                  ...             ...
# Telephones_Total Number_CA  Total Number      Telephones
# Telephones_Total Number_RO  Total Number      Telephones
# Telephones_Total Number_GB  Total Number      Telephones
# Telephones_Total Number_ER  Total Number      Telephones
# Telephones_Total Number_SL  Total Number      Telephones
#
# [157 rows x 266 columns]

# %%
rail = read_chat(46, 'Railroad', unit='Length of railway open in kilometers',metric='Cumulative Length')
rail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:2: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   chat = pd.read_csv('raw data/FinalCHAT_72909.csv', usecols=[0,1,col_num])
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                               1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Railroad_Cumulative Length_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_MU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                            ...  ...  ...  ...  ...  ...  ...  ...  ...
# Railroad_Cumulative Length_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                               1759  ... 2006 2007 2008    Country Name  \
# ID                                  ...
# Railroad_Cumulative Length_TG  NaN  ...  NaN  NaN  NaN            Togo
# Railroad_Cumulative Length_BR  NaN  ...  NaN  NaN  NaN          Brazil
# Railroad_Cumulative Length_TZ  NaN  ...  NaN  NaN  NaN        Tanzania
# Railroad_Cumulative Length_SR  NaN  ...  NaN  NaN  NaN        Suriname
# Railroad_Cumulative Length_MU  NaN  ...  NaN  NaN  NaN       Mauritius
# ...                            ...  ...  ...  ...  ...             ...
# Railroad_Cumulative Length_CA  NaN  ...  NaN  NaN  NaN          Canada
# Railroad_Cumulative Length_RO  NaN  ...  NaN  NaN  NaN         Romania
# Railroad_Cumulative Length_GB  NaN  ...  NaN  NaN  NaN  United Kingdom
# Railroad_Cumulative Length_ER  NaN  ...  NaN  NaN  NaN         Eritrea
# Railroad_Cumulative Length_SL  NaN  ...  NaN  NaN  NaN    Sierra Leone
#
#                               Country Code Data Source Spatial Scale  \
# ID
# Railroad_Cumulative Length_TG           TG   NBER CHAT      National
# Railroad_Cumulative Length_BR           BR   NBER CHAT      National
# Railroad_Cumulative Length_TZ           TZ   NBER CHAT      National
# Railroad_Cumulative Length_SR           SR   NBER CHAT      National
# Railroad_Cumulative Length_MU           MU   NBER CHAT      National
# ...                                    ...         ...           ...
# Railroad_Cumulative Length_CA           CA   NBER CHAT      National
# Railroad_Cumulative Length_RO           RO   NBER CHAT      National
# Railroad_Cumulative Length_GB           GB   NBER CHAT      National
# Railroad_Cumulative Length_ER           ER   NBER CHAT      National
# Railroad_Cumulative Length_SL           SL   NBER CHAT      National
#
#                                                                Unit  \
# ID
# Railroad_Cumulative Length_TG  Length of railway open in kilometers
# Railroad_Cumulative Length_BR  Length of railway open in kilometers
# Railroad_Cumulative Length_TZ  Length of railway open in kilometers
# Railroad_Cumulative Length_SR  Length of railway open in kilometers
# Railroad_Cumulative Length_MU  Length of railway open in kilometers
# ...                                                             ...
# Railroad_Cumulative Length_CA  Length of railway open in kilometers
# Railroad_Cumulative Length_RO  Length of railway open in kilometers
# Railroad_Cumulative Length_GB  Length of railway open in kilometers
# Railroad_Cumulative Length_ER  Length of railway open in kilometers
# Railroad_Cumulative Length_SL  Length of railway open in kilometers
#
#                                           Metric Technology Name
# ID
# Railroad_Cumulative Length_TG  Cumulative Length        Railroad
# Railroad_Cumulative Length_BR  Cumulative Length        Railroad
# Railroad_Cumulative Length_TZ  Cumulative Length        Railroad
# Railroad_Cumulative Length_SR  Cumulative Length        Railroad
# Railroad_Cumulative Length_MU  Cumulative Length        Railroad
# ...                                          ...             ...
# Railroad_Cumulative Length_CA  Cumulative Length        Railroad
# Railroad_Cumulative Length_RO  Cumulative Length        Railroad
# Railroad_Cumulative Length_GB  Cumulative Length        Railroad
# Railroad_Cumulative Length_ER  Cumulative Length        Railroad
# Railroad_Cumulative Length_SL  Cumulative Length        Railroad
#
# [129 rows x 266 columns]

# %%
tv = read_chat(97, 'Television', metric='Total Number')
tv
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Television_Total Number_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_TD  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Television_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Television_Total Number_TG  ...  NaN  NaN  NaN            Togo           TG
# Television_Total Number_BR  ...  NaN  NaN  NaN          Brazil           BR
# Television_Total Number_TD  ...  NaN  NaN  NaN            Chad           TD
# Television_Total Number_TZ  ...  NaN  NaN  NaN        Tanzania           TZ
# Television_Total Number_SR  ...  NaN  NaN  NaN        Suriname           SR
# ...                         ...  ...  ...  ...             ...          ...
# Television_Total Number_CA  ...  NaN  NaN  NaN          Canada           CA
# Television_Total Number_RO  ...  NaN  NaN  NaN         Romania           RO
# Television_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# Television_Total Number_ER  ...  NaN  NaN  NaN         Eritrea           ER
# Television_Total Number_SL  ...  NaN  NaN  NaN    Sierra Leone           SL
#
#                            Data Source Spatial Scale           Unit  \
# ID
# Television_Total Number_TG   NBER CHAT      National  Number in Use
# Television_Total Number_BR   NBER CHAT      National  Number in Use
# Television_Total Number_TD   NBER CHAT      National  Number in Use
# Television_Total Number_TZ   NBER CHAT      National  Number in Use
# Television_Total Number_SR   NBER CHAT      National  Number in Use
# ...                                ...           ...            ...
# Television_Total Number_CA   NBER CHAT      National  Number in Use
# Television_Total Number_RO   NBER CHAT      National  Number in Use
# Television_Total Number_GB   NBER CHAT      National  Number in Use
# Television_Total Number_ER   NBER CHAT      National  Number in Use
# Television_Total Number_SL   NBER CHAT      National  Number in Use
#
#                                   Metric Technology Name
# ID
# Television_Total Number_TG  Total Number      Television
# Television_Total Number_BR  Total Number      Television
# Television_Total Number_TD  Total Number      Television
# Television_Total Number_TZ  Total Number      Television
# Television_Total Number_SR  Total Number      Television
# ...                                  ...             ...
# Television_Total Number_CA  Total Number      Television
# Television_Total Number_RO  Total Number      Television
# Television_Total Number_GB  Total Number      Television
# Television_Total Number_ER  Total Number      Television
# Television_Total Number_SL  Total Number      Television
#
# [157 rows x 266 columns]

# %%
# Radio	CHAT database (radio)
radio = read_chat(45, 'Radio', metric='Total Number')
radio
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                       1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  ...  \
# ID                                                                       ...
# Radio_Total Number_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_TD  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...                    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Radio_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#                       2006 2007 2008    Country Name Country Code Data Source  \
# ID
# Radio_Total Number_TG  NaN  NaN  NaN            Togo           TG   NBER CHAT
# Radio_Total Number_BR  NaN  NaN  NaN          Brazil           BR   NBER CHAT
# Radio_Total Number_TD  NaN  NaN  NaN            Chad           TD   NBER CHAT
# Radio_Total Number_TZ  NaN  NaN  NaN        Tanzania           TZ   NBER CHAT
# Radio_Total Number_SR  NaN  NaN  NaN        Suriname           SR   NBER CHAT
# ...                    ...  ...  ...             ...          ...         ...
# Radio_Total Number_CA  NaN  NaN  NaN          Canada           CA   NBER CHAT
# Radio_Total Number_RO  NaN  NaN  NaN         Romania           RO   NBER CHAT
# Radio_Total Number_GB  NaN  NaN  NaN  United Kingdom           GB   NBER CHAT
# Radio_Total Number_ER  NaN  NaN  NaN         Eritrea           ER   NBER CHAT
# Radio_Total Number_SL  NaN  NaN  NaN    Sierra Leone           SL   NBER CHAT
#
#                       Spatial Scale           Unit        Metric  \
# ID
# Radio_Total Number_TG      National  Number in Use  Total Number
# Radio_Total Number_BR      National  Number in Use  Total Number
# Radio_Total Number_TD      National  Number in Use  Total Number
# Radio_Total Number_TZ      National  Number in Use  Total Number
# Radio_Total Number_SR      National  Number in Use  Total Number
# ...                             ...            ...           ...
# Radio_Total Number_CA      National  Number in Use  Total Number
# Radio_Total Number_RO      National  Number in Use  Total Number
# Radio_Total Number_GB      National  Number in Use  Total Number
# Radio_Total Number_ER      National  Number in Use  Total Number
# Radio_Total Number_SL      National  Number in Use  Total Number
#
#                       Technology Name
# ID
# Radio_Total Number_TG           Radio
# Radio_Total Number_BR           Radio
# Radio_Total Number_TD           Radio
# Radio_Total Number_TZ           Radio
# Radio_Total Number_SR           Radio
# ...                               ...
# Radio_Total Number_CA           Radio
# Radio_Total Number_RO           Radio
# Radio_Total Number_GB           Radio
# Radio_Total Number_ER           Radio
# Radio_Total Number_SL           Radio
#
# [157 rows x 266 columns]

# %%
# Passenger Cars	CHAT (vehicle_car)
cars = read_chat(102, 'Passenger Cars', metric='Total Number')
cars
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Passenger Cars_Total Number_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_TD  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Passenger Cars_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008    Country Name  \
# ID                                   ...
# Passenger Cars_Total Number_TG  NaN  ...  NaN  NaN  NaN            Togo
# Passenger Cars_Total Number_BR  NaN  ...  NaN  NaN  NaN          Brazil
# Passenger Cars_Total Number_TD  NaN  ...  NaN  NaN  NaN            Chad
# Passenger Cars_Total Number_TZ  NaN  ...  NaN  NaN  NaN        Tanzania
# Passenger Cars_Total Number_SR  NaN  ...  NaN  NaN  NaN        Suriname
# ...                             ...  ...  ...  ...  ...             ...
# Passenger Cars_Total Number_CA  NaN  ...  NaN  NaN  NaN          Canada
# Passenger Cars_Total Number_RO  NaN  ...  NaN  NaN  NaN         Romania
# Passenger Cars_Total Number_GB  NaN  ...  NaN  NaN  NaN  United Kingdom
# Passenger Cars_Total Number_ER  NaN  ...  NaN  NaN  NaN         Eritrea
# Passenger Cars_Total Number_SL  NaN  ...  NaN  NaN  NaN    Sierra Leone
#
#                                Country Code Data Source Spatial Scale  \
# ID
# Passenger Cars_Total Number_TG           TG   NBER CHAT      National
# Passenger Cars_Total Number_BR           BR   NBER CHAT      National
# Passenger Cars_Total Number_TD           TD   NBER CHAT      National
# Passenger Cars_Total Number_TZ           TZ   NBER CHAT      National
# Passenger Cars_Total Number_SR           SR   NBER CHAT      National
# ...                                     ...         ...           ...
# Passenger Cars_Total Number_CA           CA   NBER CHAT      National
# Passenger Cars_Total Number_RO           RO   NBER CHAT      National
# Passenger Cars_Total Number_GB           GB   NBER CHAT      National
# Passenger Cars_Total Number_ER           ER   NBER CHAT      National
# Passenger Cars_Total Number_SL           SL   NBER CHAT      National
#
#                                          Unit        Metric Technology Name
# ID
# Passenger Cars_Total Number_TG  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_BR  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_TD  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_TZ  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_SR  Number in Use  Total Number  Passenger Cars
# ...                                       ...           ...             ...
# Passenger Cars_Total Number_CA  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_RO  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_GB  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_ER  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_SL  Number in Use  Total Number  Passenger Cars
#
# [155 rows x 266 columns]

# %%
# Telegraph Traffic	CHAT (telegram)

telegram = read_chat(90, 'Telegraph Traffic', 'Number of telegrams sent annually', 'Total Number')
telegram
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                   1750 1751 1752 1753 1754 1755 1756 1757  \
# ID
# Telegraph Traffic_Total Number_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_ZA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                                ...  ...  ...  ...  ...  ...  ...  ...
# Telegraph Traffic_Total Number_PH  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MW  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                   1758 1759  ... 2006 2007 2008  \
# ID                                           ...
# Telegraph Traffic_Total Number_TG  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_BR  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_TZ  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_DE  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_ZA  NaN  NaN  ...  NaN  NaN  NaN
# ...                                ...  ...  ...  ...  ...  ...
# Telegraph Traffic_Total Number_PH  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MW  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_CA  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_RO  NaN  NaN  ...  NaN  NaN  NaN
# Telegraph Traffic_Total Number_GB  NaN  NaN  ...  NaN  NaN  NaN
#
#                                      Country Name Country Code Data Source  \
# ID
# Telegraph Traffic_Total Number_TG            Togo           TG   NBER CHAT
# Telegraph Traffic_Total Number_BR          Brazil           BR   NBER CHAT
# Telegraph Traffic_Total Number_TZ        Tanzania           TZ   NBER CHAT
# Telegraph Traffic_Total Number_DE         Germany           DE   NBER CHAT
# Telegraph Traffic_Total Number_ZA    South Africa           ZA   NBER CHAT
# ...                                           ...          ...         ...
# Telegraph Traffic_Total Number_PH     Philippines           PH   NBER CHAT
# Telegraph Traffic_Total Number_MW          Malawi           MW   NBER CHAT
# Telegraph Traffic_Total Number_CA          Canada           CA   NBER CHAT
# Telegraph Traffic_Total Number_RO         Romania           RO   NBER CHAT
# Telegraph Traffic_Total Number_GB  United Kingdom           GB   NBER CHAT
#
#                                   Spatial Scale  \
# ID
# Telegraph Traffic_Total Number_TG      National
# Telegraph Traffic_Total Number_BR      National
# Telegraph Traffic_Total Number_TZ      National
# Telegraph Traffic_Total Number_DE      National
# Telegraph Traffic_Total Number_ZA      National
# ...                                         ...
# Telegraph Traffic_Total Number_PH      National
# Telegraph Traffic_Total Number_MW      National
# Telegraph Traffic_Total Number_CA      National
# Telegraph Traffic_Total Number_RO      National
# Telegraph Traffic_Total Number_GB      National
#
#                                                                 Unit  \
# ID
# Telegraph Traffic_Total Number_TG  Number of telegrams sent annually
# Telegraph Traffic_Total Number_BR  Number of telegrams sent annually
# Telegraph Traffic_Total Number_TZ  Number of telegrams sent annually
# Telegraph Traffic_Total Number_DE  Number of telegrams sent annually
# Telegraph Traffic_Total Number_ZA  Number of telegrams sent annually
# ...                                                              ...
# Telegraph Traffic_Total Number_PH  Number of telegrams sent annually
# Telegraph Traffic_Total Number_MW  Number of telegrams sent annually
# Telegraph Traffic_Total Number_CA  Number of telegrams sent annually
# Telegraph Traffic_Total Number_RO  Number of telegrams sent annually
# Telegraph Traffic_Total Number_GB  Number of telegrams sent annually
#
#                                          Metric    Technology Name
# ID
# Telegraph Traffic_Total Number_TG  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_BR  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_TZ  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_DE  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_ZA  Total Number  Telegraph Traffic
# ...                                         ...                ...
# Telegraph Traffic_Total Number_PH  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_MW  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_CA  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_RO  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_GB  Total Number  Telegraph Traffic
#
# [79 rows x 266 columns]

# %%
# Postal traffic	CHAT (mail)

mail = read_chat(25, 'Postal Traffic', 'Number of items mailed/received', metric='Total Number')
mail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Postal Traffic_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_MU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_ZA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Postal Traffic_Total Number_MW  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008    Country Name  \
# ID                                   ...
# Postal Traffic_Total Number_BR  NaN  ...  NaN  NaN  NaN          Brazil
# Postal Traffic_Total Number_TZ  NaN  ...  NaN  NaN  NaN        Tanzania
# Postal Traffic_Total Number_MU  NaN  ...  NaN  NaN  NaN       Mauritius
# Postal Traffic_Total Number_DE  NaN  ...  NaN  NaN  NaN         Germany
# Postal Traffic_Total Number_ZA  NaN  ...  NaN  NaN  NaN    South Africa
# ...                             ...  ...  ...  ...  ...             ...
# Postal Traffic_Total Number_MW  NaN  ...  NaN  NaN  NaN          Malawi
# Postal Traffic_Total Number_CA  NaN  ...  NaN  NaN  NaN          Canada
# Postal Traffic_Total Number_RO  NaN  ...  NaN  NaN  NaN         Romania
# Postal Traffic_Total Number_GB  NaN  ...  NaN  NaN  NaN  United Kingdom
# Postal Traffic_Total Number_SL  NaN  ...  NaN  NaN  NaN    Sierra Leone
#
#                                Country Code Data Source Spatial Scale  \
# ID
# Postal Traffic_Total Number_BR           BR   NBER CHAT      National
# Postal Traffic_Total Number_TZ           TZ   NBER CHAT      National
# Postal Traffic_Total Number_MU           MU   NBER CHAT      National
# Postal Traffic_Total Number_DE           DE   NBER CHAT      National
# Postal Traffic_Total Number_ZA           ZA   NBER CHAT      National
# ...                                     ...         ...           ...
# Postal Traffic_Total Number_MW           MW   NBER CHAT      National
# Postal Traffic_Total Number_CA           CA   NBER CHAT      National
# Postal Traffic_Total Number_RO           RO   NBER CHAT      National
# Postal Traffic_Total Number_GB           GB   NBER CHAT      National
# Postal Traffic_Total Number_SL           SL   NBER CHAT      National
#
#                                                            Unit        Metric  \
# ID
# Postal Traffic_Total Number_BR  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_TZ  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_MU  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_DE  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_ZA  Number of items mailed/received  Total Number
# ...                                                         ...           ...
# Postal Traffic_Total Number_MW  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_CA  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_RO  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_GB  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_SL  Number of items mailed/received  Total Number
#
#                                Technology Name
# ID
# Postal Traffic_Total Number_BR  Postal Traffic
# Postal Traffic_Total Number_TZ  Postal Traffic
# Postal Traffic_Total Number_MU  Postal Traffic
# Postal Traffic_Total Number_DE  Postal Traffic
# Postal Traffic_Total Number_ZA  Postal Traffic
# ...                                        ...
# Postal Traffic_Total Number_MW  Postal Traffic
# Postal Traffic_Total Number_CA  Postal Traffic
# Postal Traffic_Total Number_RO  Postal Traffic
# Postal Traffic_Total Number_GB  Postal Traffic
# Postal Traffic_Total Number_SL  Postal Traffic
#
# [81 rows x 266 columns]

# %%
# Cellphones	CHAT (cellphone)

cells = read_chat(12, 'Cellphones', unit='Number of users', metric='Total Number')
cells
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_6238/2009814995.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Cellphones_Total Number_TG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_BR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_TD  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_TZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_SR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Cellphones_Total Number_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_ER  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_SL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008    Country Name Country Code  \
# ID                          ...
# Cellphones_Total Number_TG  ...  NaN  NaN  NaN            Togo           TG
# Cellphones_Total Number_BR  ...  NaN  NaN  NaN          Brazil           BR
# Cellphones_Total Number_TD  ...  NaN  NaN  NaN            Chad           TD
# Cellphones_Total Number_TZ  ...  NaN  NaN  NaN        Tanzania           TZ
# Cellphones_Total Number_SR  ...  NaN  NaN  NaN        Suriname           SR
# ...                         ...  ...  ...  ...             ...          ...
# Cellphones_Total Number_CA  ...  NaN  NaN  NaN          Canada           CA
# Cellphones_Total Number_RO  ...  NaN  NaN  NaN         Romania           RO
# Cellphones_Total Number_GB  ...  NaN  NaN  NaN  United Kingdom           GB
# Cellphones_Total Number_ER  ...  NaN  NaN  NaN         Eritrea           ER
# Cellphones_Total Number_SL  ...  NaN  NaN  NaN    Sierra Leone           SL
#
#                            Data Source Spatial Scale             Unit  \
# ID
# Cellphones_Total Number_TG   NBER CHAT      National  Number of users
# Cellphones_Total Number_BR   NBER CHAT      National  Number of users
# Cellphones_Total Number_TD   NBER CHAT      National  Number of users
# Cellphones_Total Number_TZ   NBER CHAT      National  Number of users
# Cellphones_Total Number_SR   NBER CHAT      National  Number of users
# ...                                ...           ...              ...
# Cellphones_Total Number_CA   NBER CHAT      National  Number of users
# Cellphones_Total Number_RO   NBER CHAT      National  Number of users
# Cellphones_Total Number_GB   NBER CHAT      National  Number of users
# Cellphones_Total Number_ER   NBER CHAT      National  Number of users
# Cellphones_Total Number_SL   NBER CHAT      National  Number of users
#
#                                   Metric Technology Name
# ID
# Cellphones_Total Number_TG  Total Number      Cellphones
# Cellphones_Total Number_BR  Total Number      Cellphones
# Cellphones_Total Number_TD  Total Number      Cellphones
# Cellphones_Total Number_TZ  Total Number      Cellphones
# Cellphones_Total Number_SR  Total Number      Cellphones
# ...                                  ...             ...
# Cellphones_Total Number_CA  Total Number      Cellphones
# Cellphones_Total Number_RO  Total Number      Cellphones
# Cellphones_Total Number_GB  Total Number      Cellphones
# Cellphones_Total Number_ER  Total Number      Cellphones
# Cellphones_Total Number_SL  Total Number      Cellphones
#
# [156 rows x 266 columns]

# %%
for var_def in chat_dict[chat_dict[chat_dict.columns[0]]=='telephone'][chat_dict.columns[1]]:
    print(var_def)
# Out:
# Number of mainline telephone lines connecting a customer's equipment to the public switched telephone network as of year end

# %%
for var_idx in chat_dict[chat_dict[chat_dict.columns[0]]=='ag_harvester'].index:
    print(var_idx)
# Out:
# 0

# %%
chat_dict.iloc[89]
# Out:
# VARIABLE NAME                                             telephone
# DEFINITION        Number of mainline telephone lines connecting ...
# SOURCE                           Mitchell (1998), WORLD BANK (2007)
# Name: 89, dtype: object
