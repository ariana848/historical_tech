# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://data.nber.org/data-appendix/w15319/
# https://data.nber.org/data-appendix/w15319/FinalCHAT_72909.csv
# https://www.nber.org/system/files/working_papers/w15319/w15319.pdf

# %%
os.chdir('/Users/ariana/desktop/historical_tech')

# %%
chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
chat
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/774643259.py:1: DtypeWarning: Columns (46,51,55,56,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
#       country_name  year  ag_harvester  ag_milkingmachine  ag_tractor  atm  \
# 0      Afghanistan  1750           NaN                NaN         NaN  NaN
# 1      Afghanistan  1751           NaN                NaN         NaN  NaN
# 2      Afghanistan  1752           NaN                NaN         NaN  NaN
# 3      Afghanistan  1753           NaN                NaN         NaN  NaN
# 4      Afghanistan  1754           NaN                NaN         NaN  NaN
# ...            ...   ...           ...                ...         ...  ...
# 41694     Zimbabwe  2004           NaN                NaN         NaN  NaN
# 41695     Zimbabwe  2005           NaN                NaN         NaN  NaN
# 41696     Zimbabwe  2006           NaN                NaN         NaN  NaN
# 41697     Zimbabwe  2007           NaN                NaN         NaN  NaN
# 41698     Zimbabwe  2008           NaN                NaN         NaN  NaN
#
#        aviationpkm  aviationtkm  bed_acute  bed_hosp  ...  vehicle_com  \
# 0              NaN          NaN        NaN       NaN  ...          NaN
# 1              NaN          NaN        NaN       NaN  ...          NaN
# 2              NaN          NaN        NaN       NaN  ...          NaN
# 3              NaN          NaN        NaN       NaN  ...          NaN
# 4              NaN          NaN        NaN       NaN  ...          NaN
# ...            ...          ...        ...       ...  ...          ...
# 41694          NaN          NaN        NaN       NaN  ...          NaN
# 41695          NaN          NaN        NaN       NaN  ...          NaN
# 41696          NaN          NaN        NaN       NaN  ...          NaN
# 41697          NaN          NaN        NaN       NaN  ...          NaN
# 41698          NaN          NaN        NaN       NaN  ...          NaN
#
#        visitorbeds  visitorrooms  xlpopulation  xlrealgdp  pctivprimeenroll  \
# 0              NaN           NaN           NaN        NaN               NaN
# 1              NaN           NaN           NaN        NaN               NaN
# 2              NaN           NaN           NaN        NaN               NaN
# 3              NaN           NaN           NaN        NaN               NaN
# 4              NaN           NaN           NaN        NaN               NaN
# ...            ...           ...           ...        ...               ...
# 41694          NaN           NaN           NaN        NaN               NaN
# 41695          NaN           NaN           NaN        NaN               NaN
# 41696          NaN           NaN           NaN        NaN               NaN
# 41697          NaN           NaN           NaN        NaN               NaN
# 41698          NaN           NaN           NaN        NaN               NaN
#
#        pctivsecenroll  pctivprivateinv  pctivpublicinv  pctivliteracy
# 0                 NaN              NaN             NaN            NaN
# 1                 NaN              NaN             NaN            NaN
# 2                 NaN              NaN             NaN            NaN
# 3                 NaN              NaN             NaN            NaN
# 4                 NaN              NaN             NaN            NaN
# ...               ...              ...             ...            ...
# 41694             NaN              NaN             NaN            NaN
# 41695             NaN              NaN             NaN            NaN
# 41696             NaN              NaN             NaN            NaN
# 41697             NaN              NaN             NaN            NaN
# 41698             NaN              NaN             NaN            NaN
#
# [41699 rows x 113 columns]

# %%
chat_dict = pd.read_excel('raw data/chat_dictionary.xlsx', skipfooter=2)
chat_dict
# Out:
#         VARIABLE NAME                                         DEFINITION   \
# 0         ag_harvester  Number of self‐propelled machines that reap an...
# 1    ag_milkingmachine  Number of installations consisting of several ...
# 2           ag_tractor  Number of wheel and crawler tractors (excludin...
# 3                  atm  Number of electromechanical devices that permi...
# 4          aviationpkm  Civil aviation passenger‐KM traveled on schedu...
# ..                 ...                                                ...
# 106   pctivprimeenroll                     Primary school enrollment rate
# 107    pctivsecenroll                   Secondary school enrollment rate
# 108    pctivprivateinv               Private investment as a share of GDP
# 109     pctivpublicinv                Public investment as a share of GDP
# 110      pctivliteracy  Percent literate (usually calculated on the ba...
#
#                                          SOURCE
# 0                                 FAOSTAT (2004)
# 1                                 FAOSTAT (2004)
# 2                                 FAOSTAT (2004)
# 3    BIS (various years) and ECB (various years)
# 4                                Mitchell (1998)
# ..                                           ...
# 106                           Mitchell and Banks
# 107                           Mitchell and Banks
# 108                      Penn World Table (2007)
# 109                      Penn World Table (2007)
# 110                                 Banks (2004)
#
# [111 rows x 3 columns]

# %%
var_names = list(chat.columns[2:])
var_names
# Out:
# ['ag_harvester',
#  'ag_milkingmachine',
#  'ag_tractor',
#  'atm',
#  'aviationpkm',
#  'aviationtkm',
#  'bed_acute',
#  'bed_hosp',
#  'bed_longterm',
#  'cabletv',
#  'cellphone',
#  'cheque',
#  'computer',
#  'creditdebit',
#  'eft',
#  'elecprod',
#  'fert_total',
#  'internetuser',
#  'irrigatedarea',
#  'kidney_dialpat',
#  'kidney_homedialpat',
#  'loom_auto',
#  'loom_total',
#  'mail',
#  'med_catscanner',
#  'med_lithotriptor',
#  'med_mammograph',
#  'med_mriunit',
#  'med_radiationequip',
#  'newspaper',
#  'pctdaysurg_cataract',
#  'pctdaysurg_cholecyst',
#  'pctdaysurg_hernia',
#  'pctdaysurg_lapcholecyst',
#  'pctdaysurg_tonsil',
#  'pctdaysurg_varicosevein',
#  'pcthomedialysis',
#  'pctimmunizdpt',
#  'pctimmunizmeas',
#  'pctirrigated',
#  'pctmvbyarea',
#  'pest_total',
#  'pos',
#  'radio',
#  'railline',
#  'railp',
#  'railpkm',
#  'railt',
#  'railtkm',
#  'ship_all',
#  'ship_motor',
#  'ship_sail',
#  'ship_steam',
#  'ship_steammotor',
#  'shipton_all',
#  'shipton_motor',
#  'shipton_sail',
#  'shipton_steam',
#  'shipton_steammotor',
#  'spindle_mule',
#  'spindle_ring',
#  'steel_acidbess',
#  'steel_basicbess',
#  'steel_bof',
#  'steel_eaf',
#  'steel_ohf',
#  'steel_other',
#  'steel_stainless',
#  'surg_appendectomy',
#  'surg_breastcnsv',
#  'surg_cardcath',
#  'surg_cataract',
#  'surg_cholecyst',
#  'surg_corbypass',
#  'surg_corinterven',
#  'surg_corstent',
#  'surg_csection',
#  'surg_hernia',
#  'surg_hipreplace',
#  'surg_hysterectomy',
#  'surg_kneereplace',
#  'surg_lapcholecyst',
#  'surg_mastectomy',
#  'surg_pacemaker',
#  'surg_prostatetrans',
#  'surg_prostatextrans',
#  'surg_tonsil',
#  'surg_varicosevein',
#  'telegram',
#  'telephone',
#  'transplant_bonemarrow',
#  'transplant_heart',
#  'transplant_kidney',
#  'transplant_liver',
#  'transplant_lung',
#  'tv',
#  'txtlmat_artif',
#  'txtlmat_otherraw',
#  'txtlmat_synth',
#  'txtlmat_totalraw',
#  'vehicle_car',
#  'vehicle_com',
#  'visitorbeds',
#  'visitorrooms',
#  'xlpopulation',
#  'xlrealgdp',
#  'pctivprimeenroll',
#  'pctivsecenroll',
#  'pctivprivateinv',
#  'pctivpublicinv',
#  'pctivliteracy']

# %%
for var_def in chat_dict[chat_dict[chat_dict.columns[0]]=='railline'][chat_dict.columns[1]]:
    print(var_def)
# Out:
# Geographical/route lengths of line open at the end of the year. Narrow gauge lines generally included, but mountain railways, purely industrial lines not open to the public, and urban systems generally excluded

# %%
for var_idx in chat_dict[chat_dict[chat_dict.columns[0]]=='railline'].index:
    print(var_idx)
# Out:
# 44

# %%
chat_dict.iloc[44]
# Out:
# VARIABLE NAME                                              railline
# DEFINITION        Geographical/route lengths of line open at the...
# SOURCE                                              Mitchell (1998)
# Name: 44, dtype: object

# %%
chat_dict[]

# %%
def read_chat(col_num, tech_name, unit='Number in operation', metric='Cumulative total capacity'):
    chat = pd.read_csv('raw data/FinalCHAT_72909.csv', usecols=[0,1,col_num])
    chat.replace('Venezuala', 'Venezuela', inplace=True)
    country_list = list(set(chat['country_name']))
    chat_df = []
    for country in country_list:
        df = chat[chat['country_name']==country]
        df.set_index('year', drop=True, inplace=True)
        df = df.transpose()
        df['Country Name'] = country
        if country == 'North Vietnam':
            country_code = 'VD'
        elif country == 'South Vietnam':
            country_code = 'VN'
        else:
            country_code = coco.convert(names=country, to='iso2')
        df['Country Code'] = country_code
        df.drop(index='country_name', inplace=True)
        chat_df.append(df)
    chat_all = pd.concat(chat_df)
    chat_all['Data Source'] = 'NBER CHAT'
    chat_all['Spatial Scale'] = 'National'
    chat_all['Unit'] = unit
    chat_all['Metric'] = metric
    chat_all['Technology Name'] = tech_name
    chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
    chat_all.set_index('ID', drop=True, inplace=True)
    chat_all.columns.name = None
    omit = []
    for col in chat_all.columns:
        if type(col) != int:
            omit.append(col)
    empty_rows = chat_all.drop(columns=omit)
    empty_rows.dropna(how='all', inplace=True)
    na_idx = []
    for country in chat_all.index:
        if country not in empty_rows.index:
            na_idx.append(country)
    chat_all.drop(na_idx, inplace=True)
    file_name = 'cleaned data/chat_' + tech_name + '.csv'
    chat_all.to_csv(file_name)
    return chat_all

# %%
ag_harvester = read_chat(2, 'Crop harvester')
ag_harvester
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                             1750 1751 1752 1753 1754 1755  \
# ID
# Crop harvester_Cumulative total capacity_JO  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_SA  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_TM  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_ID  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_CF  NaN  NaN  NaN  NaN  NaN  NaN
# ...                                          ...  ...  ...  ...  ...  ...
# Crop harvester_Cumulative total capacity_SY  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_CZ  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_TD  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_IT  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Cumulative total capacity_AR  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                             1756 1757 1758 1759  ... 2006  \
# ID                                                               ...
# Crop harvester_Cumulative total capacity_JO  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_SA  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_TM  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_ID  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_CF  NaN  NaN  NaN  NaN  ...  NaN
# ...                                          ...  ...  ...  ...  ...  ...
# Crop harvester_Cumulative total capacity_SY  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_CZ  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_TD  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_IT  NaN  NaN  NaN  NaN  ...  NaN
# Crop harvester_Cumulative total capacity_AR  NaN  NaN  NaN  NaN  ...  NaN
#
#                                             2007 2008  \
# ID
# Crop harvester_Cumulative total capacity_JO  NaN  NaN
# Crop harvester_Cumulative total capacity_SA  NaN  NaN
# Crop harvester_Cumulative total capacity_TM  NaN  NaN
# Crop harvester_Cumulative total capacity_ID  NaN  NaN
# Crop harvester_Cumulative total capacity_CF  NaN  NaN
# ...                                          ...  ...
# Crop harvester_Cumulative total capacity_SY  NaN  NaN
# Crop harvester_Cumulative total capacity_CZ  NaN  NaN
# Crop harvester_Cumulative total capacity_TD  NaN  NaN
# Crop harvester_Cumulative total capacity_IT  NaN  NaN
# Crop harvester_Cumulative total capacity_AR  NaN  NaN
#
#                                                          Country Name  \
# ID
# Crop harvester_Cumulative total capacity_JO                    Jordan
# Crop harvester_Cumulative total capacity_SA              Saudi Arabia
# Crop harvester_Cumulative total capacity_TM              Turkmenistan
# Crop harvester_Cumulative total capacity_ID                 Indonesia
# Crop harvester_Cumulative total capacity_CF  Central African Republic
# ...                                                               ...
# Crop harvester_Cumulative total capacity_SY                     Syria
# Crop harvester_Cumulative total capacity_CZ            Czech Republic
# Crop harvester_Cumulative total capacity_TD                      Chad
# Crop harvester_Cumulative total capacity_IT                     Italy
# Crop harvester_Cumulative total capacity_AR                 Argentina
#
#                                             Country Code Data Source  \
# ID
# Crop harvester_Cumulative total capacity_JO           JO   NBER CHAT
# Crop harvester_Cumulative total capacity_SA           SA   NBER CHAT
# Crop harvester_Cumulative total capacity_TM           TM   NBER CHAT
# Crop harvester_Cumulative total capacity_ID           ID   NBER CHAT
# Crop harvester_Cumulative total capacity_CF           CF   NBER CHAT
# ...                                                  ...         ...
# Crop harvester_Cumulative total capacity_SY           SY   NBER CHAT
# Crop harvester_Cumulative total capacity_CZ           CZ   NBER CHAT
# Crop harvester_Cumulative total capacity_TD           TD   NBER CHAT
# Crop harvester_Cumulative total capacity_IT           IT   NBER CHAT
# Crop harvester_Cumulative total capacity_AR           AR   NBER CHAT
#
#                                             Spatial Scale  \
# ID
# Crop harvester_Cumulative total capacity_JO      National
# Crop harvester_Cumulative total capacity_SA      National
# Crop harvester_Cumulative total capacity_TM      National
# Crop harvester_Cumulative total capacity_ID      National
# Crop harvester_Cumulative total capacity_CF      National
# ...                                                   ...
# Crop harvester_Cumulative total capacity_SY      National
# Crop harvester_Cumulative total capacity_CZ      National
# Crop harvester_Cumulative total capacity_TD      National
# Crop harvester_Cumulative total capacity_IT      National
# Crop harvester_Cumulative total capacity_AR      National
#
#                                                             Unit  \
# ID
# Crop harvester_Cumulative total capacity_JO  Number in operation
# Crop harvester_Cumulative total capacity_SA  Number in operation
# Crop harvester_Cumulative total capacity_TM  Number in operation
# Crop harvester_Cumulative total capacity_ID  Number in operation
# Crop harvester_Cumulative total capacity_CF  Number in operation
# ...                                                          ...
# Crop harvester_Cumulative total capacity_SY  Number in operation
# Crop harvester_Cumulative total capacity_CZ  Number in operation
# Crop harvester_Cumulative total capacity_TD  Number in operation
# Crop harvester_Cumulative total capacity_IT  Number in operation
# Crop harvester_Cumulative total capacity_AR  Number in operation
#
#                                                                 Metric  \
# ID
# Crop harvester_Cumulative total capacity_JO  Cumulative total capacity
# Crop harvester_Cumulative total capacity_SA  Cumulative total capacity
# Crop harvester_Cumulative total capacity_TM  Cumulative total capacity
# Crop harvester_Cumulative total capacity_ID  Cumulative total capacity
# Crop harvester_Cumulative total capacity_CF  Cumulative total capacity
# ...                                                                ...
# Crop harvester_Cumulative total capacity_SY  Cumulative total capacity
# Crop harvester_Cumulative total capacity_CZ  Cumulative total capacity
# Crop harvester_Cumulative total capacity_TD  Cumulative total capacity
# Crop harvester_Cumulative total capacity_IT  Cumulative total capacity
# Crop harvester_Cumulative total capacity_AR  Cumulative total capacity
#
#                                             Technology Name
# ID
# Crop harvester_Cumulative total capacity_JO  Crop harvester
# Crop harvester_Cumulative total capacity_SA  Crop harvester
# Crop harvester_Cumulative total capacity_TM  Crop harvester
# Crop harvester_Cumulative total capacity_ID  Crop harvester
# Crop harvester_Cumulative total capacity_CF  Crop harvester
# ...                                                     ...
# Crop harvester_Cumulative total capacity_SY  Crop harvester
# Crop harvester_Cumulative total capacity_CZ  Crop harvester
# Crop harvester_Cumulative total capacity_TD  Crop harvester
# Crop harvester_Cumulative total capacity_IT  Crop harvester
# Crop harvester_Cumulative total capacity_AR  Crop harvester
#
# [121 rows x 266 columns]

# %%
steam_ships = read_chat(52, 'Steam ships')
steam_ships
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                          1750 1751 1752 1753 1754 1755 1756  \
# ID
# Steam ships_Cumulative total capacity_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NO  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                          1757 1758 1759  ... 2006 2007 2008  \
# ID                                                       ...
# Steam ships_Cumulative total capacity_DK  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_BE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GB  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_ES  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NO  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FI  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#                                             Country Name Country Code  \
# ID
# Steam ships_Cumulative total capacity_DK         Denmark           DK
# Steam ships_Cumulative total capacity_BE         Belgium           BE
# Steam ships_Cumulative total capacity_DE         Germany           DE
# Steam ships_Cumulative total capacity_GB  United Kingdom           GB
# Steam ships_Cumulative total capacity_IE         Ireland           IE
# Steam ships_Cumulative total capacity_ES           Spain           ES
# Steam ships_Cumulative total capacity_NO          Norway           NO
# Steam ships_Cumulative total capacity_FI         Finland           FI
#
#                                          Data Source Spatial Scale  \
# ID
# Steam ships_Cumulative total capacity_DK   NBER CHAT      National
# Steam ships_Cumulative total capacity_BE   NBER CHAT      National
# Steam ships_Cumulative total capacity_DE   NBER CHAT      National
# Steam ships_Cumulative total capacity_GB   NBER CHAT      National
# Steam ships_Cumulative total capacity_IE   NBER CHAT      National
# Steam ships_Cumulative total capacity_ES   NBER CHAT      National
# Steam ships_Cumulative total capacity_NO   NBER CHAT      National
# Steam ships_Cumulative total capacity_FI   NBER CHAT      National
#
#                                                          Unit  \
# ID
# Steam ships_Cumulative total capacity_DK  Number in operation
# Steam ships_Cumulative total capacity_BE  Number in operation
# Steam ships_Cumulative total capacity_DE  Number in operation
# Steam ships_Cumulative total capacity_GB  Number in operation
# Steam ships_Cumulative total capacity_IE  Number in operation
# Steam ships_Cumulative total capacity_ES  Number in operation
# Steam ships_Cumulative total capacity_NO  Number in operation
# Steam ships_Cumulative total capacity_FI  Number in operation
#
#                                                              Metric  \
# ID
# Steam ships_Cumulative total capacity_DK  Cumulative total capacity
# Steam ships_Cumulative total capacity_BE  Cumulative total capacity
# Steam ships_Cumulative total capacity_DE  Cumulative total capacity
# Steam ships_Cumulative total capacity_GB  Cumulative total capacity
# Steam ships_Cumulative total capacity_IE  Cumulative total capacity
# Steam ships_Cumulative total capacity_ES  Cumulative total capacity
# Steam ships_Cumulative total capacity_NO  Cumulative total capacity
# Steam ships_Cumulative total capacity_FI  Cumulative total capacity
#
#                                          Technology Name
# ID
# Steam ships_Cumulative total capacity_DK     Steam ships
# Steam ships_Cumulative total capacity_BE     Steam ships
# Steam ships_Cumulative total capacity_DE     Steam ships
# Steam ships_Cumulative total capacity_GB     Steam ships
# Steam ships_Cumulative total capacity_IE     Steam ships
# Steam ships_Cumulative total capacity_ES     Steam ships
# Steam ships_Cumulative total capacity_NO     Steam ships
# Steam ships_Cumulative total capacity_FI     Steam ships
#
# [8 rows x 266 columns]

# %%
telephones = read_chat(89, 'Telephones')
telephones
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_8974/2801110371.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                         1750 1751 1752 1753 1754 1755 1756  \
# ID
# Telephones_Cumulative total capacity_MX  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_PT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_LU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_FR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_IE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_NZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_NO  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_FI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_IS  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Cumulative total capacity_IT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                         1757 1758 1759  ... 2006 2007 2008  \
# ID                                                      ...
# Telephones_Cumulative total capacity_MX  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_DK  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_PT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_LU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_AU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_GB  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_FR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_IE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_NL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_NZ  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_NO  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_FI  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_IS  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Telephones_Cumulative total capacity_IT  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#                                            Country Name Country Code  \
# ID
# Telephones_Cumulative total capacity_MX          Mexico           MX
# Telephones_Cumulative total capacity_DK         Denmark           DK
# Telephones_Cumulative total capacity_PT        Portugal           PT
# Telephones_Cumulative total capacity_LU      Luxembourg           LU
# Telephones_Cumulative total capacity_AU       Australia           AU
# Telephones_Cumulative total capacity_GB  United Kingdom           GB
# Telephones_Cumulative total capacity_FR          France           FR
# Telephones_Cumulative total capacity_IE         Ireland           IE
# Telephones_Cumulative total capacity_NL     Netherlands           NL
# Telephones_Cumulative total capacity_NZ     New Zealand           NZ
# Telephones_Cumulative total capacity_NO          Norway           NO
# Telephones_Cumulative total capacity_FI         Finland           FI
# Telephones_Cumulative total capacity_IS         Iceland           IS
# Telephones_Cumulative total capacity_IT           Italy           IT
#
#                                         Data Source Spatial Scale  \
# ID
# Telephones_Cumulative total capacity_MX   NBER CHAT      National
# Telephones_Cumulative total capacity_DK   NBER CHAT      National
# Telephones_Cumulative total capacity_PT   NBER CHAT      National
# Telephones_Cumulative total capacity_LU   NBER CHAT      National
# Telephones_Cumulative total capacity_AU   NBER CHAT      National
# Telephones_Cumulative total capacity_GB   NBER CHAT      National
# Telephones_Cumulative total capacity_FR   NBER CHAT      National
# Telephones_Cumulative total capacity_IE   NBER CHAT      National
# Telephones_Cumulative total capacity_NL   NBER CHAT      National
# Telephones_Cumulative total capacity_NZ   NBER CHAT      National
# Telephones_Cumulative total capacity_NO   NBER CHAT      National
# Telephones_Cumulative total capacity_FI   NBER CHAT      National
# Telephones_Cumulative total capacity_IS   NBER CHAT      National
# Telephones_Cumulative total capacity_IT   NBER CHAT      National
#
#                                                         Unit  \
# ID
# Telephones_Cumulative total capacity_MX  Number in operation
# Telephones_Cumulative total capacity_DK  Number in operation
# Telephones_Cumulative total capacity_PT  Number in operation
# Telephones_Cumulative total capacity_LU  Number in operation
# Telephones_Cumulative total capacity_AU  Number in operation
# Telephones_Cumulative total capacity_GB  Number in operation
# Telephones_Cumulative total capacity_FR  Number in operation
# Telephones_Cumulative total capacity_IE  Number in operation
# Telephones_Cumulative total capacity_NL  Number in operation
# Telephones_Cumulative total capacity_NZ  Number in operation
# Telephones_Cumulative total capacity_NO  Number in operation
# Telephones_Cumulative total capacity_FI  Number in operation
# Telephones_Cumulative total capacity_IS  Number in operation
# Telephones_Cumulative total capacity_IT  Number in operation
#
#                                                             Metric  \
# ID
# Telephones_Cumulative total capacity_MX  Cumulative total capacity
# Telephones_Cumulative total capacity_DK  Cumulative total capacity
# Telephones_Cumulative total capacity_PT  Cumulative total capacity
# Telephones_Cumulative total capacity_LU  Cumulative total capacity
# Telephones_Cumulative total capacity_AU  Cumulative total capacity
# Telephones_Cumulative total capacity_GB  Cumulative total capacity
# Telephones_Cumulative total capacity_FR  Cumulative total capacity
# Telephones_Cumulative total capacity_IE  Cumulative total capacity
# Telephones_Cumulative total capacity_NL  Cumulative total capacity
# Telephones_Cumulative total capacity_NZ  Cumulative total capacity
# Telephones_Cumulative total capacity_NO  Cumulative total capacity
# Telephones_Cumulative total capacity_FI  Cumulative total capacity
# Telephones_Cumulative total capacity_IS  Cumulative total capacity
# Telephones_Cumulative total capacity_IT  Cumulative total capacity
#
#                                         Technology Name
# ID
# Telephones_Cumulative total capacity_MX      Telephones
# Telephones_Cumulative total capacity_DK      Telephones
# Telephones_Cumulative total capacity_PT      Telephones
# Telephones_Cumulative total capacity_LU      Telephones
# Telephones_Cumulative total capacity_AU      Telephones
# Telephones_Cumulative total capacity_GB      Telephones
# Telephones_Cumulative total capacity_FR      Telephones
# Telephones_Cumulative total capacity_IE      Telephones
# Telephones_Cumulative total capacity_NL      Telephones
# Telephones_Cumulative total capacity_NZ      Telephones
# Telephones_Cumulative total capacity_NO      Telephones
# Telephones_Cumulative total capacity_FI      Telephones
# Telephones_Cumulative total capacity_IS      Telephones
# Telephones_Cumulative total capacity_IT      Telephones
#
# [14 rows x 266 columns]

# %%
# unit unspecified, see Mitchell source data?

# rail = read_chat(44, 'Railroads')
# rail
