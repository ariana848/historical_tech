# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://data.nber.org/data-appendix/w15319/
# https://data.nber.org/data-appendix/w15319/FinalCHAT_72909.csv
# https://www.nber.org/system/files/working_papers/w15319/w15319.pdf

# %%
os.chdir('/Users/ariana/desktop/historical_tech')

# %%
chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
chat
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/774643259.py:1: DtypeWarning: Columns (46,51,55,56,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
#       country_name  year  ag_harvester  ag_milkingmachine  ag_tractor  atm  \
# 0      Afghanistan  1750           NaN                NaN         NaN  NaN
# 1      Afghanistan  1751           NaN                NaN         NaN  NaN
# 2      Afghanistan  1752           NaN                NaN         NaN  NaN
# 3      Afghanistan  1753           NaN                NaN         NaN  NaN
# 4      Afghanistan  1754           NaN                NaN         NaN  NaN
# ...            ...   ...           ...                ...         ...  ...
# 41694     Zimbabwe  2004           NaN                NaN         NaN  NaN
# 41695     Zimbabwe  2005           NaN                NaN         NaN  NaN
# 41696     Zimbabwe  2006           NaN                NaN         NaN  NaN
# 41697     Zimbabwe  2007           NaN                NaN         NaN  NaN
# 41698     Zimbabwe  2008           NaN                NaN         NaN  NaN
#
#        aviationpkm  aviationtkm  bed_acute  bed_hosp  ...  vehicle_com  \
# 0              NaN          NaN        NaN       NaN  ...          NaN
# 1              NaN          NaN        NaN       NaN  ...          NaN
# 2              NaN          NaN        NaN       NaN  ...          NaN
# 3              NaN          NaN        NaN       NaN  ...          NaN
# 4              NaN          NaN        NaN       NaN  ...          NaN
# ...            ...          ...        ...       ...  ...          ...
# 41694          NaN          NaN        NaN       NaN  ...          NaN
# 41695          NaN          NaN        NaN       NaN  ...          NaN
# 41696          NaN          NaN        NaN       NaN  ...          NaN
# 41697          NaN          NaN        NaN       NaN  ...          NaN
# 41698          NaN          NaN        NaN       NaN  ...          NaN
#
#        visitorbeds  visitorrooms  xlpopulation  xlrealgdp  pctivprimeenroll  \
# 0              NaN           NaN           NaN        NaN               NaN
# 1              NaN           NaN           NaN        NaN               NaN
# 2              NaN           NaN           NaN        NaN               NaN
# 3              NaN           NaN           NaN        NaN               NaN
# 4              NaN           NaN           NaN        NaN               NaN
# ...            ...           ...           ...        ...               ...
# 41694          NaN           NaN           NaN        NaN               NaN
# 41695          NaN           NaN           NaN        NaN               NaN
# 41696          NaN           NaN           NaN        NaN               NaN
# 41697          NaN           NaN           NaN        NaN               NaN
# 41698          NaN           NaN           NaN        NaN               NaN
#
#        pctivsecenroll  pctivprivateinv  pctivpublicinv  pctivliteracy
# 0                 NaN              NaN             NaN            NaN
# 1                 NaN              NaN             NaN            NaN
# 2                 NaN              NaN             NaN            NaN
# 3                 NaN              NaN             NaN            NaN
# 4                 NaN              NaN             NaN            NaN
# ...               ...              ...             ...            ...
# 41694             NaN              NaN             NaN            NaN
# 41695             NaN              NaN             NaN            NaN
# 41696             NaN              NaN             NaN            NaN
# 41697             NaN              NaN             NaN            NaN
# 41698             NaN              NaN             NaN            NaN
#
# [41699 rows x 113 columns]

# %%
chat_dict = pd.read_excel('raw data/chat_dictionary.xlsx', skipfooter=2)
chat_dict
# Out:
#         VARIABLE NAME                                         DEFINITION   \
# 0         ag_harvester  Number of self‐propelled machines that reap an...
# 1    ag_milkingmachine  Number of installations consisting of several ...
# 2           ag_tractor  Number of wheel and crawler tractors (excludin...
# 3                  atm  Number of electromechanical devices that permi...
# 4          aviationpkm  Civil aviation passenger‐KM traveled on schedu...
# ..                 ...                                                ...
# 106   pctivprimeenroll                     Primary school enrollment rate
# 107    pctivsecenroll                   Secondary school enrollment rate
# 108    pctivprivateinv               Private investment as a share of GDP
# 109     pctivpublicinv                Public investment as a share of GDP
# 110      pctivliteracy  Percent literate (usually calculated on the ba...
#
#                                          SOURCE
# 0                                 FAOSTAT (2004)
# 1                                 FAOSTAT (2004)
# 2                                 FAOSTAT (2004)
# 3    BIS (various years) and ECB (various years)
# 4                                Mitchell (1998)
# ..                                           ...
# 106                           Mitchell and Banks
# 107                           Mitchell and Banks
# 108                      Penn World Table (2007)
# 109                      Penn World Table (2007)
# 110                                 Banks (2004)
#
# [111 rows x 3 columns]

# %%
var_names = list(chat.columns[2:])
var_names
# Out:
# ['ag_harvester',
#  'ag_milkingmachine',
#  'ag_tractor',
#  'atm',
#  'aviationpkm',
#  'aviationtkm',
#  'bed_acute',
#  'bed_hosp',
#  'bed_longterm',
#  'cabletv',
#  'cellphone',
#  'cheque',
#  'computer',
#  'creditdebit',
#  'eft',
#  'elecprod',
#  'fert_total',
#  'internetuser',
#  'irrigatedarea',
#  'kidney_dialpat',
#  'kidney_homedialpat',
#  'loom_auto',
#  'loom_total',
#  'mail',
#  'med_catscanner',
#  'med_lithotriptor',
#  'med_mammograph',
#  'med_mriunit',
#  'med_radiationequip',
#  'newspaper',
#  'pctdaysurg_cataract',
#  'pctdaysurg_cholecyst',
#  'pctdaysurg_hernia',
#  'pctdaysurg_lapcholecyst',
#  'pctdaysurg_tonsil',
#  'pctdaysurg_varicosevein',
#  'pcthomedialysis',
#  'pctimmunizdpt',
#  'pctimmunizmeas',
#  'pctirrigated',
#  'pctmvbyarea',
#  'pest_total',
#  'pos',
#  'radio',
#  'railline',
#  'railp',
#  'railpkm',
#  'railt',
#  'railtkm',
#  'ship_all',
#  'ship_motor',
#  'ship_sail',
#  'ship_steam',
#  'ship_steammotor',
#  'shipton_all',
#  'shipton_motor',
#  'shipton_sail',
#  'shipton_steam',
#  'shipton_steammotor',
#  'spindle_mule',
#  'spindle_ring',
#  'steel_acidbess',
#  'steel_basicbess',
#  'steel_bof',
#  'steel_eaf',
#  'steel_ohf',
#  'steel_other',
#  'steel_stainless',
#  'surg_appendectomy',
#  'surg_breastcnsv',
#  'surg_cardcath',
#  'surg_cataract',
#  'surg_cholecyst',
#  'surg_corbypass',
#  'surg_corinterven',
#  'surg_corstent',
#  'surg_csection',
#  'surg_hernia',
#  'surg_hipreplace',
#  'surg_hysterectomy',
#  'surg_kneereplace',
#  'surg_lapcholecyst',
#  'surg_mastectomy',
#  'surg_pacemaker',
#  'surg_prostatetrans',
#  'surg_prostatextrans',
#  'surg_tonsil',
#  'surg_varicosevein',
#  'telegram',
#  'telephone',
#  'transplant_bonemarrow',
#  'transplant_heart',
#  'transplant_kidney',
#  'transplant_liver',
#  'transplant_lung',
#  'tv',
#  'txtlmat_artif',
#  'txtlmat_otherraw',
#  'txtlmat_synth',
#  'txtlmat_totalraw',
#  'vehicle_car',
#  'vehicle_com',
#  'visitorbeds',
#  'visitorrooms',
#  'xlpopulation',
#  'xlrealgdp',
#  'pctivprimeenroll',
#  'pctivsecenroll',
#  'pctivprivateinv',
#  'pctivpublicinv',
#  'pctivliteracy']

# %%
def read_chat(col_num, tech_name, unit='Number in operation', metric='Cumulative total capacity'):
    chat = pd.read_csv('raw data/FinalCHAT_72909.csv', usecols=[0,1,col_num])
    chat.replace('Venezuala', 'Venezuela', inplace=True)
    country_list = list(set(chat['country_name']))
    chat_df = []
    for country in country_list:
        df = chat[chat['country_name']==country]
        df.set_index('year', drop=True, inplace=True)
        df = df.transpose()
        df['Country Name'] = country
        if country == 'North Vietnam':
            country_code = 'VD'
        elif country == 'South Vietnam':
            country_code = 'VN'
        else:
            country_code = coco.convert(names=country, to='iso2')
        df['Country Code'] = country_code
        df.drop(index='country_name', inplace=True)
        chat_df.append(df)
    chat_all = pd.concat(chat_df)
    chat_all['Data Source'] = 'NBER CHAT'
    chat_all['Spatial Scale'] = 'National'
    chat_all['Unit'] = unit
    chat_all['Metric'] = metric
    chat_all['Technology Name'] = tech_name
    chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
    chat_all.set_index('ID', drop=True, inplace=True)
    chat_all.columns.name = None
    omit = []
    for col in chat_all.columns:
        if type(col) != int:
            omit.append(col)
    empty_rows = chat_all.drop(columns=omit)
    empty_rows.dropna(how='all', inplace=True)
    na_idx = []
    for country in chat_all.index:
        if country not in empty_rows.index:
            na_idx.append(country)
    chat_all.drop(na_idx, inplace=True)
    file_name = 'cleaned data/chat_' + tech_name + '.csv'
    chat_all.to_csv(file_name)
    return chat_all

# %%
ag_harvester = read_chat(2, 'Crop harvester')
ag_harvester

# %%
steam_ships = read_chat(52, 'Steam ships')
steam_ships

# %%
telephones = read_chat(89, 'Telephones')
telephones

# %%
# unit unspecified, see Mitchell source data?

rail = read_chat(44, 'Railroads')
rail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/2801110371.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/2801110371.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/2801110371.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/2801110371.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/2801110371.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_11814/2801110371.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                        1750 1751 1752 1753 1754 1755 1756  \
# ID
# Railroads_Cumulative total capacity_JP  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SK  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_RU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_IT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_HU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_IL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_BG  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_LU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_LT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_PT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_FR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_US  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_NO  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_EE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_LV  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SA  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SG  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_AU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_GR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_FI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_PL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_RO  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CH  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroads_Cumulative total capacity_IE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                        1757 1758 1759  ... 2006 2007 2008  \
# ID                                                     ...
# Railroads_Cumulative total capacity_JP  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_DE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SK  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_RU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_IT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_HU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_AT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CA  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_IL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_BG  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_LU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_LT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_ES  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_PT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_GB  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_FR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_US  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_DK  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_NO  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SI  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_EE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_LV  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SA  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_BE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SG  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_AU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_NL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_SE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CZ  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_GR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_FI  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CZ  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_PL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_TR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_RO  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_CH  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Railroads_Cumulative total capacity_IE  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#                                            Country Name Country Code  \
# ID
# Railroads_Cumulative total capacity_JP            Japan           JP
# Railroads_Cumulative total capacity_DE          Germany           DE
# Railroads_Cumulative total capacity_SK  Slovak Republic           SK
# Railroads_Cumulative total capacity_RU           Russia           RU
# Railroads_Cumulative total capacity_IT            Italy           IT
# Railroads_Cumulative total capacity_HU          Hungary           HU
# Railroads_Cumulative total capacity_AT          Austria           AT
# Railroads_Cumulative total capacity_CA           Canada           CA
# Railroads_Cumulative total capacity_IL           Israel           IL
# Railroads_Cumulative total capacity_BG         Bulgaria           BG
# Railroads_Cumulative total capacity_LU       Luxembourg           LU
# Railroads_Cumulative total capacity_LT        Lithuania           LT
# Railroads_Cumulative total capacity_ES            Spain           ES
# Railroads_Cumulative total capacity_PT         Portugal           PT
# Railroads_Cumulative total capacity_GB   United Kingdom           GB
# Railroads_Cumulative total capacity_FR           France           FR
# Railroads_Cumulative total capacity_US    United States           US
# Railroads_Cumulative total capacity_DK          Denmark           DK
# Railroads_Cumulative total capacity_NO           Norway           NO
# Railroads_Cumulative total capacity_SI         Slovenia           SI
# Railroads_Cumulative total capacity_EE          Estonia           EE
# Railroads_Cumulative total capacity_LV           Latvia           LV
# Railroads_Cumulative total capacity_SA     Saudi Arabia           SA
# Railroads_Cumulative total capacity_BE          Belgium           BE
# Railroads_Cumulative total capacity_SG        Singapore           SG
# Railroads_Cumulative total capacity_AU        Australia           AU
# Railroads_Cumulative total capacity_NL      Netherlands           NL
# Railroads_Cumulative total capacity_SE           Sweden           SE
# Railroads_Cumulative total capacity_CZ   Czechoslovakia           CZ
# Railroads_Cumulative total capacity_GR           Greece           GR
# Railroads_Cumulative total capacity_FI          Finland           FI
# Railroads_Cumulative total capacity_CZ   Czech Republic           CZ
# Railroads_Cumulative total capacity_PL           Poland           PL
# Railroads_Cumulative total capacity_TR           Turkey           TR
# Railroads_Cumulative total capacity_RO          Romania           RO
# Railroads_Cumulative total capacity_CH      Switzerland           CH
# Railroads_Cumulative total capacity_IE          Ireland           IE
#
#                                        Data Source Spatial Scale  \
# ID
# Railroads_Cumulative total capacity_JP   NBER CHAT      National
# Railroads_Cumulative total capacity_DE   NBER CHAT      National
# Railroads_Cumulative total capacity_SK   NBER CHAT      National
# Railroads_Cumulative total capacity_RU   NBER CHAT      National
# Railroads_Cumulative total capacity_IT   NBER CHAT      National
# Railroads_Cumulative total capacity_HU   NBER CHAT      National
# Railroads_Cumulative total capacity_AT   NBER CHAT      National
# Railroads_Cumulative total capacity_CA   NBER CHAT      National
# Railroads_Cumulative total capacity_IL   NBER CHAT      National
# Railroads_Cumulative total capacity_BG   NBER CHAT      National
# Railroads_Cumulative total capacity_LU   NBER CHAT      National
# Railroads_Cumulative total capacity_LT   NBER CHAT      National
# Railroads_Cumulative total capacity_ES   NBER CHAT      National
# Railroads_Cumulative total capacity_PT   NBER CHAT      National
# Railroads_Cumulative total capacity_GB   NBER CHAT      National
# Railroads_Cumulative total capacity_FR   NBER CHAT      National
# Railroads_Cumulative total capacity_US   NBER CHAT      National
# Railroads_Cumulative total capacity_DK   NBER CHAT      National
# Railroads_Cumulative total capacity_NO   NBER CHAT      National
# Railroads_Cumulative total capacity_SI   NBER CHAT      National
# Railroads_Cumulative total capacity_EE   NBER CHAT      National
# Railroads_Cumulative total capacity_LV   NBER CHAT      National
# Railroads_Cumulative total capacity_SA   NBER CHAT      National
# Railroads_Cumulative total capacity_BE   NBER CHAT      National
# Railroads_Cumulative total capacity_SG   NBER CHAT      National
# Railroads_Cumulative total capacity_AU   NBER CHAT      National
# Railroads_Cumulative total capacity_NL   NBER CHAT      National
# Railroads_Cumulative total capacity_SE   NBER CHAT      National
# Railroads_Cumulative total capacity_CZ   NBER CHAT      National
# Railroads_Cumulative total capacity_GR   NBER CHAT      National
# Railroads_Cumulative total capacity_FI   NBER CHAT      National
# Railroads_Cumulative total capacity_CZ   NBER CHAT      National
# Railroads_Cumulative total capacity_PL   NBER CHAT      National
# Railroads_Cumulative total capacity_TR   NBER CHAT      National
# Railroads_Cumulative total capacity_RO   NBER CHAT      National
# Railroads_Cumulative total capacity_CH   NBER CHAT      National
# Railroads_Cumulative total capacity_IE   NBER CHAT      National
#
#                                                        Unit  \
# ID
# Railroads_Cumulative total capacity_JP  Number in operation
# Railroads_Cumulative total capacity_DE  Number in operation
# Railroads_Cumulative total capacity_SK  Number in operation
# Railroads_Cumulative total capacity_RU  Number in operation
# Railroads_Cumulative total capacity_IT  Number in operation
# Railroads_Cumulative total capacity_HU  Number in operation
# Railroads_Cumulative total capacity_AT  Number in operation
# Railroads_Cumulative total capacity_CA  Number in operation
# Railroads_Cumulative total capacity_IL  Number in operation
# Railroads_Cumulative total capacity_BG  Number in operation
# Railroads_Cumulative total capacity_LU  Number in operation
# Railroads_Cumulative total capacity_LT  Number in operation
# Railroads_Cumulative total capacity_ES  Number in operation
# Railroads_Cumulative total capacity_PT  Number in operation
# Railroads_Cumulative total capacity_GB  Number in operation
# Railroads_Cumulative total capacity_FR  Number in operation
# Railroads_Cumulative total capacity_US  Number in operation
# Railroads_Cumulative total capacity_DK  Number in operation
# Railroads_Cumulative total capacity_NO  Number in operation
# Railroads_Cumulative total capacity_SI  Number in operation
# Railroads_Cumulative total capacity_EE  Number in operation
# Railroads_Cumulative total capacity_LV  Number in operation
# Railroads_Cumulative total capacity_SA  Number in operation
# Railroads_Cumulative total capacity_BE  Number in operation
# Railroads_Cumulative total capacity_SG  Number in operation
# Railroads_Cumulative total capacity_AU  Number in operation
# Railroads_Cumulative total capacity_NL  Number in operation
# Railroads_Cumulative total capacity_SE  Number in operation
# Railroads_Cumulative total capacity_CZ  Number in operation
# Railroads_Cumulative total capacity_GR  Number in operation
# Railroads_Cumulative total capacity_FI  Number in operation
# Railroads_Cumulative total capacity_CZ  Number in operation
# Railroads_Cumulative total capacity_PL  Number in operation
# Railroads_Cumulative total capacity_TR  Number in operation
# Railroads_Cumulative total capacity_RO  Number in operation
# Railroads_Cumulative total capacity_CH  Number in operation
# Railroads_Cumulative total capacity_IE  Number in operation
#
#                                                            Metric  \
# ID
# Railroads_Cumulative total capacity_JP  Cumulative total capacity
# Railroads_Cumulative total capacity_DE  Cumulative total capacity
# Railroads_Cumulative total capacity_SK  Cumulative total capacity
# Railroads_Cumulative total capacity_RU  Cumulative total capacity
# Railroads_Cumulative total capacity_IT  Cumulative total capacity
# Railroads_Cumulative total capacity_HU  Cumulative total capacity
# Railroads_Cumulative total capacity_AT  Cumulative total capacity
# Railroads_Cumulative total capacity_CA  Cumulative total capacity
# Railroads_Cumulative total capacity_IL  Cumulative total capacity
# Railroads_Cumulative total capacity_BG  Cumulative total capacity
# Railroads_Cumulative total capacity_LU  Cumulative total capacity
# Railroads_Cumulative total capacity_LT  Cumulative total capacity
# Railroads_Cumulative total capacity_ES  Cumulative total capacity
# Railroads_Cumulative total capacity_PT  Cumulative total capacity
# Railroads_Cumulative total capacity_GB  Cumulative total capacity
# Railroads_Cumulative total capacity_FR  Cumulative total capacity
# Railroads_Cumulative total capacity_US  Cumulative total capacity
# Railroads_Cumulative total capacity_DK  Cumulative total capacity
# Railroads_Cumulative total capacity_NO  Cumulative total capacity
# Railroads_Cumulative total capacity_SI  Cumulative total capacity
# Railroads_Cumulative total capacity_EE  Cumulative total capacity
# Railroads_Cumulative total capacity_LV  Cumulative total capacity
# Railroads_Cumulative total capacity_SA  Cumulative total capacity
# Railroads_Cumulative total capacity_BE  Cumulative total capacity
# Railroads_Cumulative total capacity_SG  Cumulative total capacity
# Railroads_Cumulative total capacity_AU  Cumulative total capacity
# Railroads_Cumulative total capacity_NL  Cumulative total capacity
# Railroads_Cumulative total capacity_SE  Cumulative total capacity
# Railroads_Cumulative total capacity_CZ  Cumulative total capacity
# Railroads_Cumulative total capacity_GR  Cumulative total capacity
# Railroads_Cumulative total capacity_FI  Cumulative total capacity
# Railroads_Cumulative total capacity_CZ  Cumulative total capacity
# Railroads_Cumulative total capacity_PL  Cumulative total capacity
# Railroads_Cumulative total capacity_TR  Cumulative total capacity
# Railroads_Cumulative total capacity_RO  Cumulative total capacity
# Railroads_Cumulative total capacity_CH  Cumulative total capacity
# Railroads_Cumulative total capacity_IE  Cumulative total capacity
#
#                                        Technology Name
# ID
# Railroads_Cumulative total capacity_JP       Railroads
# Railroads_Cumulative total capacity_DE       Railroads
# Railroads_Cumulative total capacity_SK       Railroads
# Railroads_Cumulative total capacity_RU       Railroads
# Railroads_Cumulative total capacity_IT       Railroads
# Railroads_Cumulative total capacity_HU       Railroads
# Railroads_Cumulative total capacity_AT       Railroads
# Railroads_Cumulative total capacity_CA       Railroads
# Railroads_Cumulative total capacity_IL       Railroads
# Railroads_Cumulative total capacity_BG       Railroads
# Railroads_Cumulative total capacity_LU       Railroads
# Railroads_Cumulative total capacity_LT       Railroads
# Railroads_Cumulative total capacity_ES       Railroads
# Railroads_Cumulative total capacity_PT       Railroads
# Railroads_Cumulative total capacity_GB       Railroads
# Railroads_Cumulative total capacity_FR       Railroads
# Railroads_Cumulative total capacity_US       Railroads
# Railroads_Cumulative total capacity_DK       Railroads
# Railroads_Cumulative total capacity_NO       Railroads
# Railroads_Cumulative total capacity_SI       Railroads
# Railroads_Cumulative total capacity_EE       Railroads
# Railroads_Cumulative total capacity_LV       Railroads
# Railroads_Cumulative total capacity_SA       Railroads
# Railroads_Cumulative total capacity_BE       Railroads
# Railroads_Cumulative total capacity_SG       Railroads
# Railroads_Cumulative total capacity_AU       Railroads
# Railroads_Cumulative total capacity_NL       Railroads
# Railroads_Cumulative total capacity_SE       Railroads
# Railroads_Cumulative total capacity_CZ       Railroads
# Railroads_Cumulative total capacity_GR       Railroads
# Railroads_Cumulative total capacity_FI       Railroads
# Railroads_Cumulative total capacity_CZ       Railroads
# Railroads_Cumulative total capacity_PL       Railroads
# Railroads_Cumulative total capacity_TR       Railroads
# Railroads_Cumulative total capacity_RO       Railroads
# Railroads_Cumulative total capacity_CH       Railroads
# Railroads_Cumulative total capacity_IE       Railroads
#
# [37 rows x 266 columns]

# %%
tv = read_chat(95, 'Television')
tv

# %%
# Radio	CHAT database (radio)
radio = read_chat(43, 'Radio')
radio

# %%
# Passenger Cars	CHAT (vehicle_car)
cars = read_chat(100, 'Passenger cars')
cars

# %%
# Telegraph Traffic	CHAT (telegram)

telegram = read_chat(88, 'Telegraphy', 'Number of telegrams sent annually')
telegram

# %%
# Postal traffic	CHAT (mail)

mail = read_chat(23, 'Mail', 'Number of items mailed/received')
mail

# %%
# Cellphones	CHAT (cellphone)

cells = read_chat(10, 'Cellphones', 'Number of users')
cells

# %%
for var_def in chat_dict[chat_dict[chat_dict.columns[0]]=='railline'][chat_dict.columns[1]]:
    print(var_def)
# Out:
# Geographical/route lengths of line open at the end of the year. Narrow gauge lines generally included, but mountain railways, purely industrial lines not open to the public, and urban systems generally excluded

# %%
for var_idx in chat_dict[chat_dict[chat_dict.columns[0]]=='cellphone'].index:
    print(var_idx)

# %%
chat_dict.iloc[10]
