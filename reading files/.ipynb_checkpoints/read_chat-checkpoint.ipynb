# %%
import os
import pandas as pd
from pandas import Series, DataFrame
import country_converter as coco

# %%
# https://data.nber.org/data-appendix/w15319/
# https://data.nber.org/data-appendix/w15319/FinalCHAT_72909.csv
# https://www.nber.org/system/files/working_papers/w15319/w15319.pdf

# %%
os.chdir('/Users/ariana/desktop/historical_tech')

# %%
chat = pd.read_csv('raw data/FinalCHAT_72909.csv')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/3727645712.py:1: DtypeWarning: Columns (46,51,55,56,60) have mixed types. Specify dtype option on import or set low_memory=False.
#   chat = pd.read_csv('raw data/FinalCHAT_72909.csv')

# %%
chat_dict = pd.read_excel('raw data/chat_dictionary.xlsx', skipfooter=2)
chat_dict
# Out:
#         VARIABLE NAME                                         DEFINITION   \
# 0         ag_harvester  Number of self‐propelled machines that reap an...
# 1    ag_milkingmachine  Number of installations consisting of several ...
# 2           ag_tractor  Number of wheel and crawler tractors (excludin...
# 3                  atm  Number of electromechanical devices that permi...
# 4          aviationpkm  Civil aviation passenger‐KM traveled on schedu...
# ..                 ...                                                ...
# 106   pctivprimeenroll                     Primary school enrollment rate
# 107    pctivsecenroll                   Secondary school enrollment rate
# 108    pctivprivateinv               Private investment as a share of GDP
# 109     pctivpublicinv                Public investment as a share of GDP
# 110      pctivliteracy  Percent literate (usually calculated on the ba...
#
#                                          SOURCE
# 0                                 FAOSTAT (2004)
# 1                                 FAOSTAT (2004)
# 2                                 FAOSTAT (2004)
# 3    BIS (various years) and ECB (various years)
# 4                                Mitchell (1998)
# ..                                           ...
# 106                           Mitchell and Banks
# 107                           Mitchell and Banks
# 108                      Penn World Table (2007)
# 109                      Penn World Table (2007)
# 110                                 Banks (2004)
#
# [111 rows x 3 columns]

# %%
var_names = list(chat.columns[2:])
var_names
# Out:
# ['ag_harvester',
#  'ag_milkingmachine',
#  'ag_tractor',
#  'atm',
#  'aviationpkm',
#  'aviationtkm',
#  'bed_acute',
#  'bed_hosp',
#  'bed_longterm',
#  'cabletv',
#  'cellphone',
#  'cheque',
#  'computer',
#  'creditdebit',
#  'eft',
#  'elecprod',
#  'fert_total',
#  'internetuser',
#  'irrigatedarea',
#  'kidney_dialpat',
#  'kidney_homedialpat',
#  'loom_auto',
#  'loom_total',
#  'mail',
#  'med_catscanner',
#  'med_lithotriptor',
#  'med_mammograph',
#  'med_mriunit',
#  'med_radiationequip',
#  'newspaper',
#  'pctdaysurg_cataract',
#  'pctdaysurg_cholecyst',
#  'pctdaysurg_hernia',
#  'pctdaysurg_lapcholecyst',
#  'pctdaysurg_tonsil',
#  'pctdaysurg_varicosevein',
#  'pcthomedialysis',
#  'pctimmunizdpt',
#  'pctimmunizmeas',
#  'pctirrigated',
#  'pctmvbyarea',
#  'pest_total',
#  'pos',
#  'radio',
#  'railline',
#  'railp',
#  'railpkm',
#  'railt',
#  'railtkm',
#  'ship_all',
#  'ship_motor',
#  'ship_sail',
#  'ship_steam',
#  'ship_steammotor',
#  'shipton_all',
#  'shipton_motor',
#  'shipton_sail',
#  'shipton_steam',
#  'shipton_steammotor',
#  'spindle_mule',
#  'spindle_ring',
#  'steel_acidbess',
#  'steel_basicbess',
#  'steel_bof',
#  'steel_eaf',
#  'steel_ohf',
#  'steel_other',
#  'steel_stainless',
#  'surg_appendectomy',
#  'surg_breastcnsv',
#  'surg_cardcath',
#  'surg_cataract',
#  'surg_cholecyst',
#  'surg_corbypass',
#  'surg_corinterven',
#  'surg_corstent',
#  'surg_csection',
#  'surg_hernia',
#  'surg_hipreplace',
#  'surg_hysterectomy',
#  'surg_kneereplace',
#  'surg_lapcholecyst',
#  'surg_mastectomy',
#  'surg_pacemaker',
#  'surg_prostatetrans',
#  'surg_prostatextrans',
#  'surg_tonsil',
#  'surg_varicosevein',
#  'telegram',
#  'telephone',
#  'transplant_bonemarrow',
#  'transplant_heart',
#  'transplant_kidney',
#  'transplant_liver',
#  'transplant_lung',
#  'tv',
#  'txtlmat_artif',
#  'txtlmat_otherraw',
#  'txtlmat_synth',
#  'txtlmat_totalraw',
#  'vehicle_car',
#  'vehicle_com',
#  'visitorbeds',
#  'visitorrooms',
#  'xlpopulation',
#  'xlrealgdp',
#  'pctivprimeenroll',
#  'pctivsecenroll',
#  'pctivprivateinv',
#  'pctivpublicinv',
#  'pctivliteracy']

# %%
def read_chat(col_num, tech_name, unit='Number in Use', metric='Cumulative total capacity'):
    chat = pd.read_csv('raw data/FinalCHAT_72909.csv', usecols=[0,1,col_num], dtype={col_num:float},
                      na_values=' ')
    chat.replace('Venezuala', 'Venezuela', inplace=True)
    chat = chat[chat['country_name']!='Indochina']
    country_list = list(set(chat['country_name']))
    chat_df = []
    for country in country_list:
        df = chat[chat['country_name']==country]
        df.set_index('year', drop=True, inplace=True)
        df = df.transpose()
        df['Country Name'] = country
        if country == 'North Vietnam':
            country_code = 'VD'
        elif country == 'South Vietnam':
            country_code = 'VNM'
        elif country == 'Czechoslovakia':
            country_code = 'CSK'
        else:
            country_code = coco.convert(names=country, to='iso2')
        df['Country Code'] = country_code
        df.drop(index='country_name', inplace=True)
        chat_df.append(df)
    chat_all = pd.concat(chat_df)
    chat_all['Data Source'] = 'CHAT'
    chat_all['Spatial Scale'] = 'National'
    chat_all['Unit'] = unit
    chat_all['Metric'] = metric
    chat_all['Technology Name'] = tech_name
    chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
    chat_all.set_index('ID', drop=True, inplace=True)
    chat_all.columns.name = None
    omit = []
    for col in chat_all.columns:
        if type(col) != int:
            omit.append(col)
    empty_rows = chat_all.drop(columns=omit)
    empty_rows.dropna(how='all', inplace=True)
    na_idx = []
    for country in chat_all.index:
        if country not in empty_rows.index:
            na_idx.append(country)
    chat_all.drop(na_idx, inplace=True)
    file_name = 'cleaned data/chat_' + tech_name + '.csv'
    chat_all.to_csv(file_name)
    return chat_all

# %%
ag_harvester = read_chat(2, 'Crop harvester', metric='Total Number')
ag_harvester
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Crop harvester_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_LS  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Crop harvester_Total Number_OM  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_EE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_CU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Crop harvester_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008 Country Name  \
# ID                                   ...
# Crop harvester_Total Number_BO  NaN  ...  NaN  NaN  NaN      Bolivia
# Crop harvester_Total Number_LS  NaN  ...  NaN  NaN  NaN      Lesotho
# Crop harvester_Total Number_MR  NaN  ...  NaN  NaN  NaN   Mauritania
# Crop harvester_Total Number_CI  NaN  ...  NaN  NaN  NaN  Ivory Coast
# Crop harvester_Total Number_EC  NaN  ...  NaN  NaN  NaN      Ecuador
# ...                             ...  ...  ...  ...  ...          ...
# Crop harvester_Total Number_OM  NaN  ...  NaN  NaN  NaN         Oman
# Crop harvester_Total Number_EE  NaN  ...  NaN  NaN  NaN      Estonia
# Crop harvester_Total Number_CU  NaN  ...  NaN  NaN  NaN         Cuba
# Crop harvester_Total Number_GT  NaN  ...  NaN  NaN  NaN    Guatemala
# Crop harvester_Total Number_TR  NaN  ...  NaN  NaN  NaN       Turkey
#
#                                Country Code Data Source Spatial Scale  \
# ID
# Crop harvester_Total Number_BO           BO   NBER CHAT      National
# Crop harvester_Total Number_LS           LS   NBER CHAT      National
# Crop harvester_Total Number_MR           MR   NBER CHAT      National
# Crop harvester_Total Number_CI           CI   NBER CHAT      National
# Crop harvester_Total Number_EC           EC   NBER CHAT      National
# ...                                     ...         ...           ...
# Crop harvester_Total Number_OM           OM   NBER CHAT      National
# Crop harvester_Total Number_EE           EE   NBER CHAT      National
# Crop harvester_Total Number_CU           CU   NBER CHAT      National
# Crop harvester_Total Number_GT           GT   NBER CHAT      National
# Crop harvester_Total Number_TR           TR   NBER CHAT      National
#
#                                          Unit        Metric Technology Name
# ID
# Crop harvester_Total Number_BO  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_LS  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_MR  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_CI  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_EC  Number in Use  Total Number  Crop harvester
# ...                                       ...           ...             ...
# Crop harvester_Total Number_OM  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_EE  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_CU  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_GT  Number in Use  Total Number  Crop harvester
# Crop harvester_Total Number_TR  Number in Use  Total Number  Crop harvester
#
# [119 rows x 266 columns]

# %%
steam_ships = read_chat(54, 'Steam ships')
steam_ships
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                          1750 1751 1752 1753 1754 1755 1756  \
# ID
# Steam ships_Cumulative total capacity_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GB  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_HU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FI  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CA  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_RU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_ES  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NO  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_SE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_BE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GR  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IT  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DE  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_MX  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CU  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                          1757 1758 1759  ... 2006 2007 2008  \
# ID                                                       ...
# Steam ships_Cumulative total capacity_AT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DK  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GB  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_HU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FI  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_FR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CA  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_RU  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_ES  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NO  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_SE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_BE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_GR  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_IT  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_DE  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_MX  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_NL  NaN  NaN  NaN  ...  NaN  NaN  NaN
# Steam ships_Cumulative total capacity_CU  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#                                             Country Name Country Code  \
# ID
# Steam ships_Cumulative total capacity_AT         Austria           AT
# Steam ships_Cumulative total capacity_DK         Denmark           DK
# Steam ships_Cumulative total capacity_GB  United Kingdom           GB
# Steam ships_Cumulative total capacity_IE         Ireland           IE
# Steam ships_Cumulative total capacity_HU         Hungary           HU
# Steam ships_Cumulative total capacity_FI         Finland           FI
# Steam ships_Cumulative total capacity_FR          France           FR
# Steam ships_Cumulative total capacity_CA          Canada           CA
# Steam ships_Cumulative total capacity_RU          Russia           RU
# Steam ships_Cumulative total capacity_ES           Spain           ES
# Steam ships_Cumulative total capacity_NO          Norway           NO
# Steam ships_Cumulative total capacity_SE          Sweden           SE
# Steam ships_Cumulative total capacity_BE         Belgium           BE
# Steam ships_Cumulative total capacity_GR          Greece           GR
# Steam ships_Cumulative total capacity_CL           Chile           CL
# Steam ships_Cumulative total capacity_IT           Italy           IT
# Steam ships_Cumulative total capacity_DE         Germany           DE
# Steam ships_Cumulative total capacity_MX          Mexico           MX
# Steam ships_Cumulative total capacity_NL     Netherlands           NL
# Steam ships_Cumulative total capacity_CU            Cuba           CU
#
#                                          Data Source Spatial Scale  \
# ID
# Steam ships_Cumulative total capacity_AT   NBER CHAT      National
# Steam ships_Cumulative total capacity_DK   NBER CHAT      National
# Steam ships_Cumulative total capacity_GB   NBER CHAT      National
# Steam ships_Cumulative total capacity_IE   NBER CHAT      National
# Steam ships_Cumulative total capacity_HU   NBER CHAT      National
# Steam ships_Cumulative total capacity_FI   NBER CHAT      National
# Steam ships_Cumulative total capacity_FR   NBER CHAT      National
# Steam ships_Cumulative total capacity_CA   NBER CHAT      National
# Steam ships_Cumulative total capacity_RU   NBER CHAT      National
# Steam ships_Cumulative total capacity_ES   NBER CHAT      National
# Steam ships_Cumulative total capacity_NO   NBER CHAT      National
# Steam ships_Cumulative total capacity_SE   NBER CHAT      National
# Steam ships_Cumulative total capacity_BE   NBER CHAT      National
# Steam ships_Cumulative total capacity_GR   NBER CHAT      National
# Steam ships_Cumulative total capacity_CL   NBER CHAT      National
# Steam ships_Cumulative total capacity_IT   NBER CHAT      National
# Steam ships_Cumulative total capacity_DE   NBER CHAT      National
# Steam ships_Cumulative total capacity_MX   NBER CHAT      National
# Steam ships_Cumulative total capacity_NL   NBER CHAT      National
# Steam ships_Cumulative total capacity_CU   NBER CHAT      National
#
#                                                    Unit  \
# ID
# Steam ships_Cumulative total capacity_AT  Number in Use
# Steam ships_Cumulative total capacity_DK  Number in Use
# Steam ships_Cumulative total capacity_GB  Number in Use
# Steam ships_Cumulative total capacity_IE  Number in Use
# Steam ships_Cumulative total capacity_HU  Number in Use
# Steam ships_Cumulative total capacity_FI  Number in Use
# Steam ships_Cumulative total capacity_FR  Number in Use
# Steam ships_Cumulative total capacity_CA  Number in Use
# Steam ships_Cumulative total capacity_RU  Number in Use
# Steam ships_Cumulative total capacity_ES  Number in Use
# Steam ships_Cumulative total capacity_NO  Number in Use
# Steam ships_Cumulative total capacity_SE  Number in Use
# Steam ships_Cumulative total capacity_BE  Number in Use
# Steam ships_Cumulative total capacity_GR  Number in Use
# Steam ships_Cumulative total capacity_CL  Number in Use
# Steam ships_Cumulative total capacity_IT  Number in Use
# Steam ships_Cumulative total capacity_DE  Number in Use
# Steam ships_Cumulative total capacity_MX  Number in Use
# Steam ships_Cumulative total capacity_NL  Number in Use
# Steam ships_Cumulative total capacity_CU  Number in Use
#
#                                                              Metric  \
# ID
# Steam ships_Cumulative total capacity_AT  Cumulative total capacity
# Steam ships_Cumulative total capacity_DK  Cumulative total capacity
# Steam ships_Cumulative total capacity_GB  Cumulative total capacity
# Steam ships_Cumulative total capacity_IE  Cumulative total capacity
# Steam ships_Cumulative total capacity_HU  Cumulative total capacity
# Steam ships_Cumulative total capacity_FI  Cumulative total capacity
# Steam ships_Cumulative total capacity_FR  Cumulative total capacity
# Steam ships_Cumulative total capacity_CA  Cumulative total capacity
# Steam ships_Cumulative total capacity_RU  Cumulative total capacity
# Steam ships_Cumulative total capacity_ES  Cumulative total capacity
# Steam ships_Cumulative total capacity_NO  Cumulative total capacity
# Steam ships_Cumulative total capacity_SE  Cumulative total capacity
# Steam ships_Cumulative total capacity_BE  Cumulative total capacity
# Steam ships_Cumulative total capacity_GR  Cumulative total capacity
# Steam ships_Cumulative total capacity_CL  Cumulative total capacity
# Steam ships_Cumulative total capacity_IT  Cumulative total capacity
# Steam ships_Cumulative total capacity_DE  Cumulative total capacity
# Steam ships_Cumulative total capacity_MX  Cumulative total capacity
# Steam ships_Cumulative total capacity_NL  Cumulative total capacity
# Steam ships_Cumulative total capacity_CU  Cumulative total capacity
#
#                                          Technology Name
# ID
# Steam ships_Cumulative total capacity_AT     Steam ships
# Steam ships_Cumulative total capacity_DK     Steam ships
# Steam ships_Cumulative total capacity_GB     Steam ships
# Steam ships_Cumulative total capacity_IE     Steam ships
# Steam ships_Cumulative total capacity_HU     Steam ships
# Steam ships_Cumulative total capacity_FI     Steam ships
# Steam ships_Cumulative total capacity_FR     Steam ships
# Steam ships_Cumulative total capacity_CA     Steam ships
# Steam ships_Cumulative total capacity_RU     Steam ships
# Steam ships_Cumulative total capacity_ES     Steam ships
# Steam ships_Cumulative total capacity_NO     Steam ships
# Steam ships_Cumulative total capacity_SE     Steam ships
# Steam ships_Cumulative total capacity_BE     Steam ships
# Steam ships_Cumulative total capacity_GR     Steam ships
# Steam ships_Cumulative total capacity_CL     Steam ships
# Steam ships_Cumulative total capacity_IT     Steam ships
# Steam ships_Cumulative total capacity_DE     Steam ships
# Steam ships_Cumulative total capacity_MX     Steam ships
# Steam ships_Cumulative total capacity_NL     Steam ships
# Steam ships_Cumulative total capacity_CU     Steam ships
#
# [20 rows x 266 columns]

# %%
telephones = read_chat(91, 'Telephones', metric='Total Number')
telephones
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Telephones_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_LS  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Telephones_Total Number_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_BJ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_GA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telephones_Total Number_LR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008 Country Name Country Code  \
# ID                          ...
# Telephones_Total Number_BO  ...  NaN  NaN  NaN      Bolivia           BO
# Telephones_Total Number_LS  ...  NaN  NaN  NaN      Lesotho           LS
# Telephones_Total Number_MR  ...  NaN  NaN  NaN   Mauritania           MR
# Telephones_Total Number_CI  ...  NaN  NaN  NaN  Ivory Coast           CI
# Telephones_Total Number_EC  ...  NaN  NaN  NaN      Ecuador           EC
# ...                         ...  ...  ...  ...          ...          ...
# Telephones_Total Number_GT  ...  NaN  NaN  NaN    Guatemala           GT
# Telephones_Total Number_BJ  ...  NaN  NaN  NaN        Benin           BJ
# Telephones_Total Number_TR  ...  NaN  NaN  NaN       Turkey           TR
# Telephones_Total Number_GA  ...  NaN  NaN  NaN        Gabon           GA
# Telephones_Total Number_LR  ...  NaN  NaN  NaN      Liberia           LR
#
#                            Data Source Spatial Scale           Unit  \
# ID
# Telephones_Total Number_BO   NBER CHAT      National  Number in Use
# Telephones_Total Number_LS   NBER CHAT      National  Number in Use
# Telephones_Total Number_MR   NBER CHAT      National  Number in Use
# Telephones_Total Number_CI   NBER CHAT      National  Number in Use
# Telephones_Total Number_EC   NBER CHAT      National  Number in Use
# ...                                ...           ...            ...
# Telephones_Total Number_GT   NBER CHAT      National  Number in Use
# Telephones_Total Number_BJ   NBER CHAT      National  Number in Use
# Telephones_Total Number_TR   NBER CHAT      National  Number in Use
# Telephones_Total Number_GA   NBER CHAT      National  Number in Use
# Telephones_Total Number_LR   NBER CHAT      National  Number in Use
#
#                                   Metric Technology Name
# ID
# Telephones_Total Number_BO  Total Number      Telephones
# Telephones_Total Number_LS  Total Number      Telephones
# Telephones_Total Number_MR  Total Number      Telephones
# Telephones_Total Number_CI  Total Number      Telephones
# Telephones_Total Number_EC  Total Number      Telephones
# ...                                  ...             ...
# Telephones_Total Number_GT  Total Number      Telephones
# Telephones_Total Number_BJ  Total Number      Telephones
# Telephones_Total Number_TR  Total Number      Telephones
# Telephones_Total Number_GA  Total Number      Telephones
# Telephones_Total Number_LR  Total Number      Telephones
#
# [156 rows x 266 columns]

# %%
rail = read_chat(46, 'Railroad', unit='Length of railway open in kilometers',metric='Cumulative Length')
rail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                               1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Railroad_Cumulative Length_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                            ...  ...  ...  ...  ...  ...  ...  ...  ...
# Railroad_Cumulative Length_EE  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_CU  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_BJ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Railroad_Cumulative Length_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                               1759  ... 2006 2007 2008 Country Name  \
# ID                                  ...
# Railroad_Cumulative Length_BO  NaN  ...  NaN  NaN  NaN      Bolivia
# Railroad_Cumulative Length_MR  NaN  ...  NaN  NaN  NaN   Mauritania
# Railroad_Cumulative Length_CI  NaN  ...  NaN  NaN  NaN  Ivory Coast
# Railroad_Cumulative Length_EC  NaN  ...  NaN  NaN  NaN      Ecuador
# Railroad_Cumulative Length_AT  NaN  ...  NaN  NaN  NaN      Austria
# ...                            ...  ...  ...  ...  ...          ...
# Railroad_Cumulative Length_EE  NaN  ...  NaN  NaN  NaN      Estonia
# Railroad_Cumulative Length_CU  NaN  ...  NaN  NaN  NaN         Cuba
# Railroad_Cumulative Length_GT  NaN  ...  NaN  NaN  NaN    Guatemala
# Railroad_Cumulative Length_BJ  NaN  ...  NaN  NaN  NaN        Benin
# Railroad_Cumulative Length_TR  NaN  ...  NaN  NaN  NaN       Turkey
#
#                               Country Code Data Source Spatial Scale  \
# ID
# Railroad_Cumulative Length_BO           BO   NBER CHAT      National
# Railroad_Cumulative Length_MR           MR   NBER CHAT      National
# Railroad_Cumulative Length_CI           CI   NBER CHAT      National
# Railroad_Cumulative Length_EC           EC   NBER CHAT      National
# Railroad_Cumulative Length_AT           AT   NBER CHAT      National
# ...                                    ...         ...           ...
# Railroad_Cumulative Length_EE           EE   NBER CHAT      National
# Railroad_Cumulative Length_CU           CU   NBER CHAT      National
# Railroad_Cumulative Length_GT           GT   NBER CHAT      National
# Railroad_Cumulative Length_BJ           BJ   NBER CHAT      National
# Railroad_Cumulative Length_TR           TR   NBER CHAT      National
#
#                                                                Unit  \
# ID
# Railroad_Cumulative Length_BO  Length of railway open in kilometers
# Railroad_Cumulative Length_MR  Length of railway open in kilometers
# Railroad_Cumulative Length_CI  Length of railway open in kilometers
# Railroad_Cumulative Length_EC  Length of railway open in kilometers
# Railroad_Cumulative Length_AT  Length of railway open in kilometers
# ...                                                             ...
# Railroad_Cumulative Length_EE  Length of railway open in kilometers
# Railroad_Cumulative Length_CU  Length of railway open in kilometers
# Railroad_Cumulative Length_GT  Length of railway open in kilometers
# Railroad_Cumulative Length_BJ  Length of railway open in kilometers
# Railroad_Cumulative Length_TR  Length of railway open in kilometers
#
#                                           Metric Technology Name
# ID
# Railroad_Cumulative Length_BO  Cumulative Length        Railroad
# Railroad_Cumulative Length_MR  Cumulative Length        Railroad
# Railroad_Cumulative Length_CI  Cumulative Length        Railroad
# Railroad_Cumulative Length_EC  Cumulative Length        Railroad
# Railroad_Cumulative Length_AT  Cumulative Length        Railroad
# ...                                          ...             ...
# Railroad_Cumulative Length_EE  Cumulative Length        Railroad
# Railroad_Cumulative Length_CU  Cumulative Length        Railroad
# Railroad_Cumulative Length_GT  Cumulative Length        Railroad
# Railroad_Cumulative Length_BJ  Cumulative Length        Railroad
# Railroad_Cumulative Length_TR  Cumulative Length        Railroad
#
# [128 rows x 266 columns]

# %%
tv = read_chat(97, 'Television', metric='Total Number')
tv
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Television_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_LS  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Television_Total Number_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_BJ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_GA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Television_Total Number_LR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008 Country Name Country Code  \
# ID                          ...
# Television_Total Number_BO  ...  NaN  NaN  NaN      Bolivia           BO
# Television_Total Number_LS  ...  NaN  NaN  NaN      Lesotho           LS
# Television_Total Number_MR  ...  NaN  NaN  NaN   Mauritania           MR
# Television_Total Number_CI  ...  NaN  NaN  NaN  Ivory Coast           CI
# Television_Total Number_EC  ...  NaN  NaN  NaN      Ecuador           EC
# ...                         ...  ...  ...  ...          ...          ...
# Television_Total Number_GT  ...  NaN  NaN  NaN    Guatemala           GT
# Television_Total Number_BJ  ...  NaN  NaN  NaN        Benin           BJ
# Television_Total Number_TR  ...  NaN  NaN  NaN       Turkey           TR
# Television_Total Number_GA  ...  NaN  NaN  NaN        Gabon           GA
# Television_Total Number_LR  ...  NaN  NaN  NaN      Liberia           LR
#
#                            Data Source Spatial Scale           Unit  \
# ID
# Television_Total Number_BO   NBER CHAT      National  Number in Use
# Television_Total Number_LS   NBER CHAT      National  Number in Use
# Television_Total Number_MR   NBER CHAT      National  Number in Use
# Television_Total Number_CI   NBER CHAT      National  Number in Use
# Television_Total Number_EC   NBER CHAT      National  Number in Use
# ...                                ...           ...            ...
# Television_Total Number_GT   NBER CHAT      National  Number in Use
# Television_Total Number_BJ   NBER CHAT      National  Number in Use
# Television_Total Number_TR   NBER CHAT      National  Number in Use
# Television_Total Number_GA   NBER CHAT      National  Number in Use
# Television_Total Number_LR   NBER CHAT      National  Number in Use
#
#                                   Metric Technology Name
# ID
# Television_Total Number_BO  Total Number      Television
# Television_Total Number_LS  Total Number      Television
# Television_Total Number_MR  Total Number      Television
# Television_Total Number_CI  Total Number      Television
# Television_Total Number_EC  Total Number      Television
# ...                                  ...             ...
# Television_Total Number_GT  Total Number      Television
# Television_Total Number_BJ  Total Number      Television
# Television_Total Number_TR  Total Number      Television
# Television_Total Number_GA  Total Number      Television
# Television_Total Number_LR  Total Number      Television
#
# [156 rows x 266 columns]

# %%
# Radio	CHAT database (radio)
radio = read_chat(45, 'Radio', metric='Total Number')
radio
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                       1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  ...  \
# ID                                                                       ...
# Radio_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_LS  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...                    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Radio_Total Number_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_BJ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_GA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# Radio_Total Number_LR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#                       2006 2007 2008 Country Name Country Code Data Source  \
# ID
# Radio_Total Number_BO  NaN  NaN  NaN      Bolivia           BO   NBER CHAT
# Radio_Total Number_LS  NaN  NaN  NaN      Lesotho           LS   NBER CHAT
# Radio_Total Number_MR  NaN  NaN  NaN   Mauritania           MR   NBER CHAT
# Radio_Total Number_CI  NaN  NaN  NaN  Ivory Coast           CI   NBER CHAT
# Radio_Total Number_EC  NaN  NaN  NaN      Ecuador           EC   NBER CHAT
# ...                    ...  ...  ...          ...          ...         ...
# Radio_Total Number_GT  NaN  NaN  NaN    Guatemala           GT   NBER CHAT
# Radio_Total Number_BJ  NaN  NaN  NaN        Benin           BJ   NBER CHAT
# Radio_Total Number_TR  NaN  NaN  NaN       Turkey           TR   NBER CHAT
# Radio_Total Number_GA  NaN  NaN  NaN        Gabon           GA   NBER CHAT
# Radio_Total Number_LR  NaN  NaN  NaN      Liberia           LR   NBER CHAT
#
#                       Spatial Scale           Unit        Metric  \
# ID
# Radio_Total Number_BO      National  Number in Use  Total Number
# Radio_Total Number_LS      National  Number in Use  Total Number
# Radio_Total Number_MR      National  Number in Use  Total Number
# Radio_Total Number_CI      National  Number in Use  Total Number
# Radio_Total Number_EC      National  Number in Use  Total Number
# ...                             ...            ...           ...
# Radio_Total Number_GT      National  Number in Use  Total Number
# Radio_Total Number_BJ      National  Number in Use  Total Number
# Radio_Total Number_TR      National  Number in Use  Total Number
# Radio_Total Number_GA      National  Number in Use  Total Number
# Radio_Total Number_LR      National  Number in Use  Total Number
#
#                       Technology Name
# ID
# Radio_Total Number_BO           Radio
# Radio_Total Number_LS           Radio
# Radio_Total Number_MR           Radio
# Radio_Total Number_CI           Radio
# Radio_Total Number_EC           Radio
# ...                               ...
# Radio_Total Number_GT           Radio
# Radio_Total Number_BJ           Radio
# Radio_Total Number_TR           Radio
# Radio_Total Number_GA           Radio
# Radio_Total Number_LR           Radio
#
# [156 rows x 266 columns]

# %%
# Passenger Cars	CHAT (vehicle_car)
cars = read_chat(102, 'Passenger Cars', metric='Total Number')
cars
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Passenger Cars_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_LS  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Passenger Cars_Total Number_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_BJ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_GA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Passenger Cars_Total Number_LR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008 Country Name  \
# ID                                   ...
# Passenger Cars_Total Number_BO  NaN  ...  NaN  NaN  NaN      Bolivia
# Passenger Cars_Total Number_LS  NaN  ...  NaN  NaN  NaN      Lesotho
# Passenger Cars_Total Number_MR  NaN  ...  NaN  NaN  NaN   Mauritania
# Passenger Cars_Total Number_CI  NaN  ...  NaN  NaN  NaN  Ivory Coast
# Passenger Cars_Total Number_EC  NaN  ...  NaN  NaN  NaN      Ecuador
# ...                             ...  ...  ...  ...  ...          ...
# Passenger Cars_Total Number_GT  NaN  ...  NaN  NaN  NaN    Guatemala
# Passenger Cars_Total Number_BJ  NaN  ...  NaN  NaN  NaN        Benin
# Passenger Cars_Total Number_TR  NaN  ...  NaN  NaN  NaN       Turkey
# Passenger Cars_Total Number_GA  NaN  ...  NaN  NaN  NaN        Gabon
# Passenger Cars_Total Number_LR  NaN  ...  NaN  NaN  NaN      Liberia
#
#                                Country Code Data Source Spatial Scale  \
# ID
# Passenger Cars_Total Number_BO           BO   NBER CHAT      National
# Passenger Cars_Total Number_LS           LS   NBER CHAT      National
# Passenger Cars_Total Number_MR           MR   NBER CHAT      National
# Passenger Cars_Total Number_CI           CI   NBER CHAT      National
# Passenger Cars_Total Number_EC           EC   NBER CHAT      National
# ...                                     ...         ...           ...
# Passenger Cars_Total Number_GT           GT   NBER CHAT      National
# Passenger Cars_Total Number_BJ           BJ   NBER CHAT      National
# Passenger Cars_Total Number_TR           TR   NBER CHAT      National
# Passenger Cars_Total Number_GA           GA   NBER CHAT      National
# Passenger Cars_Total Number_LR           LR   NBER CHAT      National
#
#                                          Unit        Metric Technology Name
# ID
# Passenger Cars_Total Number_BO  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_LS  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_MR  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_CI  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_EC  Number in Use  Total Number  Passenger Cars
# ...                                       ...           ...             ...
# Passenger Cars_Total Number_GT  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_BJ  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_TR  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_GA  Number in Use  Total Number  Passenger Cars
# Passenger Cars_Total Number_LR  Number in Use  Total Number  Passenger Cars
#
# [154 rows x 266 columns]

# %%
# Telegraph Traffic	CHAT (telegram)

telegram = read_chat(90, 'Telegraph Traffic', 'Number of telegrams sent annually', 'Total Number')
telegram
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                   1750 1751 1752 1753 1754 1755 1756 1757  \
# ID
# Telegraph Traffic_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_DK  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_SV  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                                ...  ...  ...  ...  ...  ...  ...  ...
# Telegraph Traffic_Total Number_ZA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_MY  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_CO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Telegraph Traffic_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                   1758 1759  ... 2006 2007 2008  Country Name  \
# ID                                           ...
# Telegraph Traffic_Total Number_CI  NaN  NaN  ...  NaN  NaN  NaN   Ivory Coast
# Telegraph Traffic_Total Number_AT  NaN  NaN  ...  NaN  NaN  NaN       Austria
# Telegraph Traffic_Total Number_MG  NaN  NaN  ...  NaN  NaN  NaN    Madagascar
# Telegraph Traffic_Total Number_DK  NaN  NaN  ...  NaN  NaN  NaN       Denmark
# Telegraph Traffic_Total Number_SV  NaN  NaN  ...  NaN  NaN  NaN   El Salvador
# ...                                ...  ...  ...  ...  ...  ...           ...
# Telegraph Traffic_Total Number_ZA  NaN  NaN  ...  NaN  NaN  NaN  South Africa
# Telegraph Traffic_Total Number_NL  NaN  NaN  ...  NaN  NaN  NaN   Netherlands
# Telegraph Traffic_Total Number_MY  NaN  NaN  ...  NaN  NaN  NaN      Malaysia
# Telegraph Traffic_Total Number_CO  NaN  NaN  ...  NaN  NaN  NaN      Colombia
# Telegraph Traffic_Total Number_TR  NaN  NaN  ...  NaN  NaN  NaN        Turkey
#
#                                   Country Code Data Source Spatial Scale  \
# ID
# Telegraph Traffic_Total Number_CI           CI   NBER CHAT      National
# Telegraph Traffic_Total Number_AT           AT   NBER CHAT      National
# Telegraph Traffic_Total Number_MG           MG   NBER CHAT      National
# Telegraph Traffic_Total Number_DK           DK   NBER CHAT      National
# Telegraph Traffic_Total Number_SV           SV   NBER CHAT      National
# ...                                        ...         ...           ...
# Telegraph Traffic_Total Number_ZA           ZA   NBER CHAT      National
# Telegraph Traffic_Total Number_NL           NL   NBER CHAT      National
# Telegraph Traffic_Total Number_MY           MY   NBER CHAT      National
# Telegraph Traffic_Total Number_CO           CO   NBER CHAT      National
# Telegraph Traffic_Total Number_TR           TR   NBER CHAT      National
#
#                                                                 Unit  \
# ID
# Telegraph Traffic_Total Number_CI  Number of telegrams sent annually
# Telegraph Traffic_Total Number_AT  Number of telegrams sent annually
# Telegraph Traffic_Total Number_MG  Number of telegrams sent annually
# Telegraph Traffic_Total Number_DK  Number of telegrams sent annually
# Telegraph Traffic_Total Number_SV  Number of telegrams sent annually
# ...                                                              ...
# Telegraph Traffic_Total Number_ZA  Number of telegrams sent annually
# Telegraph Traffic_Total Number_NL  Number of telegrams sent annually
# Telegraph Traffic_Total Number_MY  Number of telegrams sent annually
# Telegraph Traffic_Total Number_CO  Number of telegrams sent annually
# Telegraph Traffic_Total Number_TR  Number of telegrams sent annually
#
#                                          Metric    Technology Name
# ID
# Telegraph Traffic_Total Number_CI  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_AT  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_MG  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_DK  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_SV  Total Number  Telegraph Traffic
# ...                                         ...                ...
# Telegraph Traffic_Total Number_ZA  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_NL  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_MY  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_CO  Total Number  Telegraph Traffic
# Telegraph Traffic_Total Number_TR  Total Number  Telegraph Traffic
#
# [76 rows x 266 columns]

# %%
# Postal traffic	CHAT (mail)

mail = read_chat(25, 'Postal Traffic', 'Number of items mailed/received', metric='Total Number')
mail
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                                1750 1751 1752 1753 1754 1755 1756 1757 1758  \
# ID
# Postal Traffic_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_AT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_CZ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_MG  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_VN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                             ...  ...  ...  ...  ...  ...  ...  ...  ...
# Postal Traffic_Total Number_ZA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_NL  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_MY  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_CO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Postal Traffic_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                                1759  ... 2006 2007 2008    Country Name  \
# ID                                   ...
# Postal Traffic_Total Number_CI  NaN  ...  NaN  NaN  NaN     Ivory Coast
# Postal Traffic_Total Number_AT  NaN  ...  NaN  NaN  NaN         Austria
# Postal Traffic_Total Number_CZ  NaN  ...  NaN  NaN  NaN  Czech Republic
# Postal Traffic_Total Number_MG  NaN  ...  NaN  NaN  NaN      Madagascar
# Postal Traffic_Total Number_VN  NaN  ...  NaN  NaN  NaN         Vietnam
# ...                             ...  ...  ...  ...  ...             ...
# Postal Traffic_Total Number_ZA  NaN  ...  NaN  NaN  NaN    South Africa
# Postal Traffic_Total Number_NL  NaN  ...  NaN  NaN  NaN     Netherlands
# Postal Traffic_Total Number_MY  NaN  ...  NaN  NaN  NaN        Malaysia
# Postal Traffic_Total Number_CO  NaN  ...  NaN  NaN  NaN        Colombia
# Postal Traffic_Total Number_TR  NaN  ...  NaN  NaN  NaN          Turkey
#
#                                Country Code Data Source Spatial Scale  \
# ID
# Postal Traffic_Total Number_CI           CI   NBER CHAT      National
# Postal Traffic_Total Number_AT           AT   NBER CHAT      National
# Postal Traffic_Total Number_CZ           CZ   NBER CHAT      National
# Postal Traffic_Total Number_MG           MG   NBER CHAT      National
# Postal Traffic_Total Number_VN           VN   NBER CHAT      National
# ...                                     ...         ...           ...
# Postal Traffic_Total Number_ZA           ZA   NBER CHAT      National
# Postal Traffic_Total Number_NL           NL   NBER CHAT      National
# Postal Traffic_Total Number_MY           MY   NBER CHAT      National
# Postal Traffic_Total Number_CO           CO   NBER CHAT      National
# Postal Traffic_Total Number_TR           TR   NBER CHAT      National
#
#                                                            Unit        Metric  \
# ID
# Postal Traffic_Total Number_CI  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_AT  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_CZ  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_MG  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_VN  Number of items mailed/received  Total Number
# ...                                                         ...           ...
# Postal Traffic_Total Number_ZA  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_NL  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_MY  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_CO  Number of items mailed/received  Total Number
# Postal Traffic_Total Number_TR  Number of items mailed/received  Total Number
#
#                                Technology Name
# ID
# Postal Traffic_Total Number_CI  Postal Traffic
# Postal Traffic_Total Number_AT  Postal Traffic
# Postal Traffic_Total Number_CZ  Postal Traffic
# Postal Traffic_Total Number_MG  Postal Traffic
# Postal Traffic_Total Number_VN  Postal Traffic
# ...                                        ...
# Postal Traffic_Total Number_ZA  Postal Traffic
# Postal Traffic_Total Number_NL  Postal Traffic
# Postal Traffic_Total Number_MY  Postal Traffic
# Postal Traffic_Total Number_CO  Postal Traffic
# Postal Traffic_Total Number_TR  Postal Traffic
#
# [80 rows x 266 columns]

# %%
# Cellphones	CHAT (cellphone)

cells = read_chat(12, 'Cellphones', unit='Number of users', metric='Total Number')
cells
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Data Source'] = 'NBER CHAT'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Spatial Scale'] = 'National'
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Unit'] = unit
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Metric'] = metric
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['Technology Name'] = tech_name
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_33280/1758213811.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   chat_all['ID'] = chat_all['Technology Name'] + '_' + chat_all['Metric'] + '_' + chat_all['Country Code']
#                            1750 1751 1752 1753 1754 1755 1756 1757 1758 1759  \
# ID
# Cellphones_Total Number_BO  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_LS  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_MR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_CI  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_EC  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...                         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# Cellphones_Total Number_GT  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_BJ  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_TR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_GA  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Cellphones_Total Number_LR  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#                             ... 2006 2007 2008 Country Name Country Code  \
# ID                          ...
# Cellphones_Total Number_BO  ...  NaN  NaN  NaN      Bolivia           BO
# Cellphones_Total Number_LS  ...  NaN  NaN  NaN      Lesotho           LS
# Cellphones_Total Number_MR  ...  NaN  NaN  NaN   Mauritania           MR
# Cellphones_Total Number_CI  ...  NaN  NaN  NaN  Ivory Coast           CI
# Cellphones_Total Number_EC  ...  NaN  NaN  NaN      Ecuador           EC
# ...                         ...  ...  ...  ...          ...          ...
# Cellphones_Total Number_GT  ...  NaN  NaN  NaN    Guatemala           GT
# Cellphones_Total Number_BJ  ...  NaN  NaN  NaN        Benin           BJ
# Cellphones_Total Number_TR  ...  NaN  NaN  NaN       Turkey           TR
# Cellphones_Total Number_GA  ...  NaN  NaN  NaN        Gabon           GA
# Cellphones_Total Number_LR  ...  NaN  NaN  NaN      Liberia           LR
#
#                            Data Source Spatial Scale             Unit  \
# ID
# Cellphones_Total Number_BO   NBER CHAT      National  Number of users
# Cellphones_Total Number_LS   NBER CHAT      National  Number of users
# Cellphones_Total Number_MR   NBER CHAT      National  Number of users
# Cellphones_Total Number_CI   NBER CHAT      National  Number of users
# Cellphones_Total Number_EC   NBER CHAT      National  Number of users
# ...                                ...           ...              ...
# Cellphones_Total Number_GT   NBER CHAT      National  Number of users
# Cellphones_Total Number_BJ   NBER CHAT      National  Number of users
# Cellphones_Total Number_TR   NBER CHAT      National  Number of users
# Cellphones_Total Number_GA   NBER CHAT      National  Number of users
# Cellphones_Total Number_LR   NBER CHAT      National  Number of users
#
#                                   Metric Technology Name
# ID
# Cellphones_Total Number_BO  Total Number      Cellphones
# Cellphones_Total Number_LS  Total Number      Cellphones
# Cellphones_Total Number_MR  Total Number      Cellphones
# Cellphones_Total Number_CI  Total Number      Cellphones
# Cellphones_Total Number_EC  Total Number      Cellphones
# ...                                  ...             ...
# Cellphones_Total Number_GT  Total Number      Cellphones
# Cellphones_Total Number_BJ  Total Number      Cellphones
# Cellphones_Total Number_TR  Total Number      Cellphones
# Cellphones_Total Number_GA  Total Number      Cellphones
# Cellphones_Total Number_LR  Total Number      Cellphones
#
# [153 rows x 266 columns]

# %%
for var_def in chat_dict[chat_dict[chat_dict.columns[0]]=='telephone'][chat_dict.columns[1]]:
    print(var_def)
# Out:
# Number of mainline telephone lines connecting a customer's equipment to the public switched telephone network as of year end

# %%
for var_idx in chat_dict[chat_dict[chat_dict.columns[0]]=='ag_harvester'].index:
    print(var_idx)
# Out:
# 0

# %%
chat_dict.iloc[89]
# Out:
# VARIABLE NAME                                             telephone
# DEFINITION        Number of mainline telephone lines connecting ...
# SOURCE                           Mitchell (1998), WORLD BANK (2007)
# Name: 89, dtype: object
