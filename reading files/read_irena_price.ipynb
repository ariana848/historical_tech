# %%
import pandas as pd
from pandas import Series, DataFrame
import os

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
# https://www.irena.org/publications/2022/Jul/Renewable-Power-Generation-Costs-in-2021

# %%
pd.read_excel('raw data/cost data/IRENA-Datafile-RenPwrGenCosts-in-2021-v1-0.xlsx')
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                     NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
# 5         NaN         NaN         NaN
# 6         NaN         NaN         NaN
# 7         NaN         NaN         NaN
# 8         NaN         NaN         NaN
# 9         NaN         NaN         NaN
# 10        NaN         NaN         NaN
# 11        NaN         NaN         NaN
# 12        NaN         NaN         NaN
# 13        NaN         NaN         NaN
# 14        NaN         NaN         NaN
# 15        NaN         NaN         NaN
# 16        NaN         NaN         NaN
# 17        NaN         NaN         NaN
# 18        NaN         NaN         NaN
# 19        NaN         NaN         NaN
# 20        NaN         NaN         NaN
# 21        NaN         NaN         NaN
# 22        NaN         NaN         NaN
# 23        NaN         NaN         NaN
# 24        NaN         NaN         NaN
# 25        NaN         NaN         NaN
# 26        NaN         NaN         NaN
# 27        NaN         NaN         NaN
# 28        NaN         NaN         NaN
# 29        NaN         NaN         NaN
# 30        NaN         NaN         NaN
# 31        NaN         NaN         NaN
# 32        NaN         NaN         NaN
# 33        NaN         NaN         NaN
# 34        NaN         NaN         NaN
# 35        NaN         NaN         NaN
# 36        NaN         NaN         NaN
# 37        NaN         NaN         NaN
# 38        NaN         NaN         NaN
# 39        NaN         NaN         NaN
# 40        NaN         NaN         NaN
#
#                                            Unnamed: 3       Unnamed: 4
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5            Renewable Power Generation Costs in 2021              NaN
# 6                                                 NaN              NaN
# 7   This publication should be cited as: Citation:...              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# 18                                                NaN              NaN
# 19                                                NaN              NaN
# 20                                                NaN              NaN
# 21                                                NaN              NaN
# 22                                                NaN              NaN
# 23                                                NaN              NaN
# 24                                           Contents              NaN
# 25                                         Highlights              NaN
# 26                                  Executive Summary              NaN
# 27                              1. Latest cost trends              NaN
# 28                                    2. Onshore wind              NaN
# 29                                        3. Solar PV              NaN
# 30                                   4. Offshore wind              NaN
# 31                       5. Concentrating solar power              NaN
# 32                                      6. Hydropower              NaN
# 33                                      7. Geothermal              NaN
# 34                                       8. Bioenergy              NaN
# 35                                            Annex I              NaN
# 36                            Operations & Maintenace              NaN
# 37                                                NaN              NaN
# 38  This file contains data from the above mention...              NaN
# 39  Note: Monetary values in this report are expre...              NaN
# 40                                           Contact:  costs@irena.org
