# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech.csv')
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Oil Production_Annual Production_Million tonne...      National
# 1     Oil Production_Annual Production_Million tonne...      National
# 2     Oil Production_Annual Production_Million tonne...      National
# 3     Oil Production_Annual Production_Million tonne...      National
# 4     Oil Production_Annual Production_Million tonne...      National
# ...                                                 ...           ...
# 3661   Phosphate Fertilizer_Annual Production_Tonnes_ZM      National
# 3662      Potash Fertilizer_Annual Production_Tonnes_ZM      National
# 3663    Nitrogen Fertilizer_Annual Production_Tonnes_ZW      National
# 3664   Phosphate Fertilizer_Annual Production_Tonnes_ZW      National
# 3665      Potash Fertilizer_Annual Production_Tonnes_ZW      National
#
#      Country Code Country Name       Technology Name             Metric  \
# ...

# %%
dup = []
for x in all_tech['ID']:
    if x not in dup:
        dup.append(x)
    else:
        print(x)
# Out:
# Nitrogen Fertilizer_Annual Production_Tonnes_CN
# Phosphate Fertilizer_Annual Production_Tonnes_CN
# Potash Fertilizer_Annual Production_Tonnes_CN
# Nitrogen Fertilizer_Annual Production_Tonnes_CZ
# Phosphate Fertilizer_Annual Production_Tonnes_CZ
# Potash Fertilizer_Annual Production_Tonnes_CZ
# Nitrogen Fertilizer_Annual Production_Tonnes_SD
# Phosphate Fertilizer_Annual Production_Tonnes_SD
# Potash Fertilizer_Annual Production_Tonnes_SD
