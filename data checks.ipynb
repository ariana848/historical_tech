# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech.csv')
all_tech
# Out:
#                                                     ID Spatial Scale  \
# 0                  Aquaculture_Annual production_World         World
# 1                     Aquaculture_Annual production_AF      National
# 2                     Aquaculture_Annual production_AL      National
# 3                     Aquaculture_Annual production_DZ      National
# 4                     Aquaculture_Annual production_AS      National
# ...                                                ...           ...
# 7843  Phosphate Fertilizer_Annual Production_Tonnes_ZM      National
# 7844     Potash Fertilizer_Annual Production_Tonnes_ZM      National
# 7845   Nitrogen Fertilizer_Annual Production_Tonnes_ZW      National
# 7846  Phosphate Fertilizer_Annual Production_Tonnes_ZW      National
# 7847     Potash Fertilizer_Annual Production_Tonnes_ZW      National
#
#      Country Code    Country Name       Technology Name             Metric  \
# ...

# %%
dup = []
for x in all_tech['ID']:
    if x not in dup:
        dup.append(x)
    else:
        print(x)
# Out:
# Nitrogen Fertilizer_Annual Production_Tonnes_CN
# Phosphate Fertilizer_Annual Production_Tonnes_CN
# Potash Fertilizer_Annual Production_Tonnes_CN
# Nitrogen Fertilizer_Annual Production_Tonnes_SD
# Phosphate Fertilizer_Annual Production_Tonnes_SD
# Potash Fertilizer_Annual Production_Tonnes_SD
