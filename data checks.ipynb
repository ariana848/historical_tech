# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech.csv')
all_tech
# Out:
#                                                ID Country Code Country Name  \
# 0              Oil Production, Million tonnes: CA           CA       Canada
# 1              Oil Production, Million tonnes: MX           MX       Mexico
# 2              Oil Production, Million tonnes: US           US           US
# 3              Oil Production, Million tonnes: AR           AR    Argentina
# 4              Oil Production, Million tonnes: BR           BR       Brazil
# ...                                           ...          ...          ...
# 1365  Phosphate fertilizer production, Tonnes: ZM           ZM       Zambia
# 1366     Potash fertilizer production, Tonnes: ZM           ZM       Zambia
# 1367   Nitrogen fertilizer production, Tonnes: ZW           ZW     Zimbabwe
# 1368  Phosphate fertilizer production, Tonnes: ZW           ZW     Zimbabwe
# 1369     Potash fertilizer production, Tonnes: ZW           ZW     Zimbabwe
#
# ...

# %%
all_tech.duplicated('ID')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1365    False
# 1366    False
# 1367    False
# 1368    False
# 1369    False
# Length: 1370, dtype: bool
