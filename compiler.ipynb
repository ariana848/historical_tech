# %%
import pandas as pd
from pandas import Series, DataFrame
import os

# %%
path = 'cleaned data/'
clean_files = os.listdir(path)

# %%
csv = []
for file in clean_files:
     if '.csv' in file:
        name = path + file
        csv.append(name)

# %%
frame = pd.read_csv('cleaned data/frame.csv')
frame
# Out:
# Empty DataFrame
# Columns: [ID, Spatial Scale, Country Code, Country Name, Technology Name, Metric, Unit, Data Source, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, ...]
# Index: []
#
# [0 rows x 334 columns]

# %%
df_list = [frame]
for file in csv:
    file = pd.read_csv(file)
    df_list.append(file)

# %%
all_tech_df = pd.concat(df_list)
all_tech_df
# Out:
#                                                    ID Spatial Scale  \
# 0   Pumped hydro storage_Cumulative Rated Capacity_CA      National
# 1      Pumped hydro storage_Cumulative Rated Power_CA      National
# 0          Sensible heat_Cumulative Rated Capacity_IT      National
# 1             Sensible heat_Cumulative Rated Power_IT      National
# 0           Flow battery_Cumulative Rated Capacity_AG      National
# ..                                                ...           ...
# 0           Flow battery_Cumulative Rated Capacity_CH      National
# 1              Flow battery_Cumulative Rated Power_CH      National
# 0               Flywheel_Cumulative Rated Capacity_RO      National
# 1                  Flywheel_Cumulative Rated Power_RO      National
# 0                    Liquefied natural gas_Exports_US           NaN
#
#    Country Code         Country Name        Technology Name  \
# 0            CA               Canada   Pumped hydro storage
# 1            CA               Canada   Pumped hydro storage
# 0            IT                Italy          Sensible heat
# 1            IT                Italy          Sensible heat
# 0            AG  Antigua and Barbuda           Flow battery
# ..          ...                  ...                    ...
# 0            CH          Switzerland           Flow battery
# 1            CH          Switzerland           Flow battery
# 0            RO              Romania               Flywheel
# 1            RO              Romania               Flywheel
# 0            US        United States  Liquefied natural gas
#
#                        Metric                Unit  \
# 0   Cumulative Rated Capacity                 kWh
# 1      Cumulative Rated Power                  kW
# 0   Cumulative Rated Capacity                 kWh
# 1      Cumulative Rated Power                  kW
# 0   Cumulative Rated Capacity                 kWh
# ..                        ...                 ...
# 0   Cumulative Rated Capacity                 kWh
# 1      Cumulative Rated Power                  kW
# 0   Cumulative Rated Capacity                 kWh
# 1      Cumulative Rated Power                  kW
# 0                     Exports  Billion cubic feet
#
#                                Data Source  1700  1701  ...        2016  \
# 0       DOE Global Energy Storage Database   NaN   NaN  ...  3044000.00
# 1       DOE Global Energy Storage Database   NaN   NaN  ...  4574000.00
# 0       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# 1       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# 0       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# ..                                     ...   ...   ...  ...         ...
# 0       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# 1       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# 0       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# 1       DOE Global Energy Storage Database   NaN   NaN  ...         NaN
# 0   U.S. Energy Information Administration   NaN   NaN  ...      186.84
#
#       2017     2018    2019     2020     2021  2022  2023  2024  2025
# 0      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 0      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 0      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# ..     ...      ...     ...      ...      ...   ...   ...   ...   ...
# 0      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 0      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1      NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 0   707.54  1083.12  1819.4  2389.84  3560.82   NaN   NaN   NaN   NaN
#
# [7097 rows x 334 columns]

# %%
all_tech_df.set_index('ID', drop=True, inplace=True)
all_tech_df
# Out:
#                                                   Spatial Scale Country Code  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA      National           CA
# Pumped hydro storage_Cumulative Rated Power_CA         National           CA
# Sensible heat_Cumulative Rated Capacity_IT             National           IT
# Sensible heat_Cumulative Rated Power_IT                National           IT
# Flow battery_Cumulative Rated Capacity_AG              National           AG
# ...                                                         ...          ...
# Flow battery_Cumulative Rated Capacity_CH              National           CH
# Flow battery_Cumulative Rated Power_CH                 National           CH
# Flywheel_Cumulative Rated Capacity_RO                  National           RO
# Flywheel_Cumulative Rated Power_RO                     National           RO
# Liquefied natural gas_Exports_US                            NaN           US
#
#                                                           Country Name  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA               Canada
# Pumped hydro storage_Cumulative Rated Power_CA                  Canada
# Sensible heat_Cumulative Rated Capacity_IT                       Italy
# Sensible heat_Cumulative Rated Power_IT                          Italy
# Flow battery_Cumulative Rated Capacity_AG          Antigua and Barbuda
# ...                                                                ...
# Flow battery_Cumulative Rated Capacity_CH                  Switzerland
# Flow battery_Cumulative Rated Power_CH                     Switzerland
# Flywheel_Cumulative Rated Capacity_RO                          Romania
# Flywheel_Cumulative Rated Power_RO                             Romania
# Liquefied natural gas_Exports_US                         United States
#
#                                                          Technology Name  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA   Pumped hydro storage
# Pumped hydro storage_Cumulative Rated Power_CA      Pumped hydro storage
# Sensible heat_Cumulative Rated Capacity_IT                 Sensible heat
# Sensible heat_Cumulative Rated Power_IT                    Sensible heat
# Flow battery_Cumulative Rated Capacity_AG                   Flow battery
# ...                                                                  ...
# Flow battery_Cumulative Rated Capacity_CH                   Flow battery
# Flow battery_Cumulative Rated Power_CH                      Flow battery
# Flywheel_Cumulative Rated Capacity_RO                           Flywheel
# Flywheel_Cumulative Rated Power_RO                              Flywheel
# Liquefied natural gas_Exports_US                   Liquefied natural gas
#
#                                                                       Metric  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA  Cumulative Rated Capacity
# Pumped hydro storage_Cumulative Rated Power_CA        Cumulative Rated Power
# Sensible heat_Cumulative Rated Capacity_IT         Cumulative Rated Capacity
# Sensible heat_Cumulative Rated Power_IT               Cumulative Rated Power
# Flow battery_Cumulative Rated Capacity_AG          Cumulative Rated Capacity
# ...                                                                      ...
# Flow battery_Cumulative Rated Capacity_CH          Cumulative Rated Capacity
# Flow battery_Cumulative Rated Power_CH                Cumulative Rated Power
# Flywheel_Cumulative Rated Capacity_RO              Cumulative Rated Capacity
# Flywheel_Cumulative Rated Power_RO                    Cumulative Rated Power
# Liquefied natural gas_Exports_US                                     Exports
#
#                                                                  Unit  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA                 kWh
# Pumped hydro storage_Cumulative Rated Power_CA                     kW
# Sensible heat_Cumulative Rated Capacity_IT                        kWh
# Sensible heat_Cumulative Rated Power_IT                            kW
# Flow battery_Cumulative Rated Capacity_AG                         kWh
# ...                                                               ...
# Flow battery_Cumulative Rated Capacity_CH                         kWh
# Flow battery_Cumulative Rated Power_CH                             kW
# Flywheel_Cumulative Rated Capacity_RO                             kWh
# Flywheel_Cumulative Rated Power_RO                                 kW
# Liquefied natural gas_Exports_US                   Billion cubic feet
#
#                                                                               Data Source  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA      DOE Global Energy Storage Database
# Pumped hydro storage_Cumulative Rated Power_CA         DOE Global Energy Storage Database
# Sensible heat_Cumulative Rated Capacity_IT             DOE Global Energy Storage Database
# Sensible heat_Cumulative Rated Power_IT                DOE Global Energy Storage Database
# Flow battery_Cumulative Rated Capacity_AG              DOE Global Energy Storage Database
# ...                                                                                   ...
# Flow battery_Cumulative Rated Capacity_CH              DOE Global Energy Storage Database
# Flow battery_Cumulative Rated Power_CH                 DOE Global Energy Storage Database
# Flywheel_Cumulative Rated Capacity_RO                  DOE Global Energy Storage Database
# Flywheel_Cumulative Rated Power_RO                     DOE Global Energy Storage Database
# Liquefied natural gas_Exports_US                   U.S. Energy Information Administration
#
#                                                    1700  1701  1702  ...  \
# ID                                                                   ...
# Pumped hydro storage_Cumulative Rated Capacity_CA   NaN   NaN   NaN  ...
# Pumped hydro storage_Cumulative Rated Power_CA      NaN   NaN   NaN  ...
# Sensible heat_Cumulative Rated Capacity_IT          NaN   NaN   NaN  ...
# Sensible heat_Cumulative Rated Power_IT             NaN   NaN   NaN  ...
# Flow battery_Cumulative Rated Capacity_AG           NaN   NaN   NaN  ...
# ...                                                 ...   ...   ...  ...
# Flow battery_Cumulative Rated Capacity_CH           NaN   NaN   NaN  ...
# Flow battery_Cumulative Rated Power_CH              NaN   NaN   NaN  ...
# Flywheel_Cumulative Rated Capacity_RO               NaN   NaN   NaN  ...
# Flywheel_Cumulative Rated Power_RO                  NaN   NaN   NaN  ...
# Liquefied natural gas_Exports_US                    NaN   NaN   NaN  ...
#
#                                                          2016    2017  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA  3044000.00     NaN
# Pumped hydro storage_Cumulative Rated Power_CA     4574000.00     NaN
# Sensible heat_Cumulative Rated Capacity_IT                NaN     NaN
# Sensible heat_Cumulative Rated Power_IT                   NaN     NaN
# Flow battery_Cumulative Rated Capacity_AG                 NaN     NaN
# ...                                                       ...     ...
# Flow battery_Cumulative Rated Capacity_CH                 NaN     NaN
# Flow battery_Cumulative Rated Power_CH                    NaN     NaN
# Flywheel_Cumulative Rated Capacity_RO                     NaN     NaN
# Flywheel_Cumulative Rated Power_RO                        NaN     NaN
# Liquefied natural gas_Exports_US                       186.84  707.54
#
#                                                       2018    2019     2020  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA      NaN     NaN      NaN
# Pumped hydro storage_Cumulative Rated Power_CA         NaN     NaN      NaN
# Sensible heat_Cumulative Rated Capacity_IT             NaN     NaN      NaN
# Sensible heat_Cumulative Rated Power_IT                NaN     NaN      NaN
# Flow battery_Cumulative Rated Capacity_AG              NaN     NaN      NaN
# ...                                                    ...     ...      ...
# Flow battery_Cumulative Rated Capacity_CH              NaN     NaN      NaN
# Flow battery_Cumulative Rated Power_CH                 NaN     NaN      NaN
# Flywheel_Cumulative Rated Capacity_RO                  NaN     NaN      NaN
# Flywheel_Cumulative Rated Power_RO                     NaN     NaN      NaN
# Liquefied natural gas_Exports_US                   1083.12  1819.4  2389.84
#
#                                                       2021  2022  2023  2024  \
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA      NaN   NaN   NaN   NaN
# Pumped hydro storage_Cumulative Rated Power_CA         NaN   NaN   NaN   NaN
# Sensible heat_Cumulative Rated Capacity_IT             NaN   NaN   NaN   NaN
# Sensible heat_Cumulative Rated Power_IT                NaN   NaN   NaN   NaN
# Flow battery_Cumulative Rated Capacity_AG              NaN   NaN   NaN   NaN
# ...                                                    ...   ...   ...   ...
# Flow battery_Cumulative Rated Capacity_CH              NaN   NaN   NaN   NaN
# Flow battery_Cumulative Rated Power_CH                 NaN   NaN   NaN   NaN
# Flywheel_Cumulative Rated Capacity_RO                  NaN   NaN   NaN   NaN
# Flywheel_Cumulative Rated Power_RO                     NaN   NaN   NaN   NaN
# Liquefied natural gas_Exports_US                   3560.82   NaN   NaN   NaN
#
#                                                    2025
# ID
# Pumped hydro storage_Cumulative Rated Capacity_CA   NaN
# Pumped hydro storage_Cumulative Rated Power_CA      NaN
# Sensible heat_Cumulative Rated Capacity_IT          NaN
# Sensible heat_Cumulative Rated Power_IT             NaN
# Flow battery_Cumulative Rated Capacity_AG           NaN
# ...                                                 ...
# Flow battery_Cumulative Rated Capacity_CH           NaN
# Flow battery_Cumulative Rated Power_CH              NaN
# Flywheel_Cumulative Rated Capacity_RO               NaN
# Flywheel_Cumulative Rated Power_RO                  NaN
# Liquefied natural gas_Exports_US                    NaN
#
# [7097 rows x 333 columns]

# %%
for x in set(all_tech_df['Technology Name']):
    print(x)
# Out:
# Polyethylene HD
# Primary Alumninum
# On-Grid Solar Photovoltaic
# Caprolactam
# Acrylonitrile
# Phthalic Anhydride
# Coal Power
# NatGas Power
# On-Grid Nuclear
# Primary Magnesium
# Ethylene
# Low-Density Polyethylene
# Videocassette recorder
# On-Grid Mixed Hydro Plants
# Household refrigerator
# Refrigerator
# Computer
# Dryer
# Electricity access
# Internet Backbone Bandwidth
# Vinyl Chloride
# Landline
# Phosphate Fertilizer
# Nuclear Energy
# Ethylene Glycol
# Cobalt Mine Production
# Washing Machines
# Off-Grid Onshore Wind Energy
# Electronic ignition
# Microprocessor Clock Speed
# On-Grid Marine Energy
# Coal Production
# Households with only mobile phones (no landlines)
# Passenger cars
# BCG Vaccine
# On-Grid Offshore Wind Energy
# Graphite Mine Production
# CFLs
# Flywheel
# YFV Vaccine
# Refrigerators
# Liquefied natural gas
# Desalination
# Lead-acid battery
# Railroads
# Vacuum
# Dishwasher
# Cyclohexane
# Formaldehyde
# Transistors per Microprocessor
# HIB3 Vaccine
# Nuclear weapons
# FCC-Refineries
# Steam ships
# Crude Oil
# Biofuels
# Steam Locomotives
# Heat thermal storage
# Aquaculture
# Flush toilet
# Power steering
# POL3 Vaccine
# Ethyl Alcohol
# Polystyrene
# Wind Power
# Gas pipeline
# Motorcycles
# Sand and gravel production (construction)
# Maleic Anhydride
# Rare Earth Mine Production
# Central heating
# Cable TV
# Cadmium Refining
# IPV1 Vaccine
# RCV1 Vaccine
# Ethylene 2
# Sodium Chlorate
# Compressed air energy storage
# Stove
# Colour TV
# Zinc-based battery
# Smartphone usage
# Ethanolamine
# Oil Production
# Titanium Sponge
# Shipping container port infrastructure
# Primary aluminum production
# Hydroelectricity
# DTP1 Vaccine
# On-Grid Renewable Hydropower
# Laundry Dryers
# On-Grid Natural Gas
# Telephones
# Milk
# Methanol
# Primary bauxite production
# Cellular phone
# Electric Range
# Magnesium
# Iron ore
# Gas Production
# Washing machine
# High-speed rail
# Lead mine production
# Phenol
# MCV2 Vaccine
# Mail
# Internet
# Neoprene Rubber
# RTGS adoption
# Social media usage
# On-Grid Onshore Wind Energy
# HEPBB Vaccine
# Capture fisheries
# Wind Energy
# Nox pollution controls (boilers)
# Nickel production
# Styrene
# Motor Gasoline
# Lithium-ion battery
# Wet flue gas desulfurization systems
# Home air conditioning
# Disk brakes
# Hydrofluoric Acid
# Refined Cane Sugar
# Computing Growth
# Microcomputer
# Telegraphy
# Passenger Cars
# ROTAC Vaccine
# Acrylic Fiber
# PCV3 Vaccine
# Hydro Power
# Oil Refining Capacity
# On-Grid Liquid Biofuels
# Tablet
# Amazon Prime users
# Magnetic Data Storage
# Processor Performance
# Pumped hydro storage
# Oil pipeline
# Primary copper production
# Microwave
# Crop harvester
# Pentaerythritol
# DTP3 Vaccine
# Sensible heat
# Sodium
# Solar Energy
# On-Grid Biogas
# Copper Refining
# MCV1 Vaccine
# Washer
# Electric Bicycles
# Freezer
# On-Grid Geothermal Energy
# Gold production
# Copper Mining
# Cellphones
# Electro-chemical capacitor
# Urea
# Bisphenol A
# On-Grid Oil
# Sodium-based battery
# Latent heat
# Paraxylene
# Electricity
# Beer
# Raw steel production
# On-Grid Solar Thermal Energy
# Nickel-based battery
# PolyesterFiber
# Benzene
# Automatic transmission
# Television
# Sand and gravel production (industrial)
# Aniline
# Salt production
# Radial tires
# Internet Traffic
# Polyethylene LD
# Automobile
# Bicycles
# Podcasting
# Public roads
# Shale production
# Nuclear Power
# Running water
# Polyvinylchloride
# HEPB3 Vaccine
# On-Grid Solid Biofuels
# Renewable Power
# Solar Power
# Shotgun Sanger DNA Sequencing
# Radio
# Water Heater
# Satellite launches
# Flow battery
# Railroad
# Hydrogen storage
# Ebook reader
# Nitrogen Fertilizer
# Iron
# Steamships
# Random Access Memory
# Ground-Source Heat Pumps
# Cement production
# On-Grid Coal And Peat
# Lithium Mine Production
# Jet Aircraft
# Electric power
# Potash Fertilizer
# Vinyl Acetate
# Stationary Steam Engines

# %%
all_tech_df.to_csv('all_tech.csv', index=False)
