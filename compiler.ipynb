# %%
import pandas as pd
from pandas import Series, DataFrame
import os
import locale
from locale import atof

# %%
path = 'cleaned data/'
clean_files = os.listdir(path)

# %%
csv = []
for file in clean_files:
    if '.csv' in file:
        name = path + file
        csv.append(name)

# %%
frame = pd.read_csv('cleaned data/frame.csv')
frame
# Out:
# Empty DataFrame
# Columns: [ID, Spatial Scale, Country Code, Country Name, Technology Name, Metric, Unit, Data Source, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, ...]
# Index: []
#
# [0 rows x 334 columns]

# %%
locale.setlocale(locale.LC_NUMERIC, '')
# Out:
# 'en_US.UTF-8'

# %%
# don't use default na, this erroneously converts 'NA' (iso code for Namibia) to a missing value
# I manually input all the default na vals except for 'NA' to prevent this
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
df_list = [frame]
for file in csv:
    file = pd.read_csv(file, thousands=',',keep_default_na=False, 
                       na_values=['-1.#IND', '1.#QNAN', '1.#IND', '-1.#QNAN', '#N/A N/A', '#N/A', 'N/A', 'n/a', 
                                  '<NA>', '#NA', 'NULL', 'null', 'NaN', '-NaN', 'nan', '-nan', 'None', ''])
    df_list.append(file)

# %%
all_tech_df = pd.concat(df_list)
all_tech_df
# Out:
#                                                     ID Spatial Scale  \
# 0    Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1    Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 0      Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 1    Sensible Heat Storage_Cumulative Rated Capacit...      National
# 0      Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ..                                                 ...           ...
# 105       Raw steel production_Annual production_World        Global
# 0                    Space Launches_Yearly Launches_UA      National
# 0                    Space Launches_Yearly Launches_TM      National
# 0           Liquefied natural gas_Annual Production_US      National
# 0                    Space Launches_Yearly Launches_CO      National
#
#     Country Code   Country Name              Technology Name  \
# 0             TG           Togo  Lithium-Ion Battery Storage
# 1             TG           Togo  Lithium-Ion Battery Storage
# 0             ZA   South Africa        Sensible Heat Storage
# 1             ZA   South Africa        Sensible Heat Storage
# 0             DK        Denmark          Onshore Wind Energy
# ..           ...            ...                          ...
# 105        World          World         Raw steel production
# 0             UA        Ukraine               Space Launches
# 0             TM   Turkmenistan               Space Launches
# 0             US  United States        Liquefied natural gas
# 0             CO       Colombia               Space Launches
#
#                         Metric                                   Unit  \
# 0       Cumulative Rated Power                                     kW
# 1    Cumulative Rated Capacity                                    kWh
# 0       Cumulative Rated Power                                     kW
# 1    Cumulative Rated Capacity                                    kWh
# 0     Levelized Cost of Energy                           2021 USD/kWh
# ..                         ...                                    ...
# 105          Annual production                            Metric tons
# 0              Yearly Launches  Number of objects launched into space
# 0              Yearly Launches  Number of objects launched into space
# 0            Annual Production                     Billion cubic feet
# 0              Yearly Launches  Number of objects launched into space
#
#                                 Data Source  1700  1701  ...          2016  \
# 0        DOE Global Energy Storage Database   NaN   NaN  ...           NaN
# 1        DOE Global Energy Storage Database   NaN   NaN  ...           NaN
# 0        DOE Global Energy Storage Database   NaN   NaN  ...  2.550000e+05
# 1        DOE Global Energy Storage Database   NaN   NaN  ...  1.195000e+06
# 0                                     IRENA   NaN   NaN  ...  5.542823e-02
# ..                                      ...   ...   ...  ...           ...
# 105                  U.S. Geological Survey   NaN   NaN  ...           NaN
# 0                                    UNOOSA   NaN   NaN  ...           NaN
# 0                                    UNOOSA   NaN   NaN  ...           NaN
# 0    U.S. Energy Information Administration   NaN   NaN  ...  1.868400e+02
# 0                                    UNOOSA   NaN   NaN  ...           NaN
#
#              2017          2018         2019         2020     2021  2022  \
# 0    1.900000e+02  2.900000e+02          NaN          NaN      NaN   NaN
# 1    7.600000e+02  1.160000e+03          NaN          NaN      NaN   NaN
# 0    3.550000e+05  4.550000e+05          NaN          NaN      NaN   NaN
# 1    1.745000e+06  2.945000e+06          NaN          NaN      NaN   NaN
# 0    4.578779e-02  4.374012e-02     0.045337     0.039979      NaN   NaN
# ..            ...           ...          ...          ...      ...   ...
# 105           NaN           NaN          NaN          NaN      NaN   NaN
# 0             NaN           NaN          NaN          NaN      NaN   1.0
# 0             NaN           NaN          NaN          NaN      NaN   NaN
# 0    7.075400e+02  1.083120e+03  1819.400000  2389.840000  3560.82   NaN
# 0             NaN  1.000000e+00          NaN          NaN      NaN   NaN
#
#      2023  2024  2025
# 0     NaN   NaN   NaN
# 1     NaN   NaN   NaN
# 0     NaN   NaN   NaN
# 1     NaN   NaN   NaN
# 0     NaN   NaN   NaN
# ..    ...   ...   ...
# 105   NaN   NaN   NaN
# 0     NaN   NaN   NaN
# 0     NaN   NaN   NaN
# 0     NaN   NaN   NaN
# 0     NaN   NaN   NaN
#
# [7656 rows x 334 columns]

# %%
len(set(all_tech_df['Technology Name']))
# Out:
# 204

# %%
for x in set(all_tech_df['Technology Name']):
    print(x)
# Out:
# Zinc
# MCV1 Vaccine
# Radial tires
# Shale production
# Electric Bicycles
# Microprocessor Clock Speed
# Biogas
# Herbicide-Tolerant Cotton
# Telegraph Traffic
# Amazon Prime users
# Nuclear Energy
# Carbon Capture & Sequestration
# Primary bauxite production
# Vinyl Chloride
# Offshore Wind Energy
# Herbicide-Tolerant Corn
# Running water
# Liquefied Natural Gas
# Electricity
# Ammonia Synthesis
# Benzene
# Formaldehyde
# Freezer
# Hydrogen Storage
# Flywheel Battery Storage
# Styrene
# Zinc-Based Battery
# High-speed rail
# Processor Performance
# Urea
# POL3 Vaccine
# Onshore Wind Energy
# Jet Aircraft
# Flush toilet
# Submarine Cables
# Paraxylene
# Smartphone usage
# IPV1 Vaccine
# Latent Heat Storage
# Herbicide-Tolerant Soybeans
# Internet Backbone Bandwidth
# Cobalt Mine Production
# Passenger Cars
# Nuclear weapons
# DTP1 Vaccine
# Lead-Acid Battery Storage
# Lead mine production
# Compact fluorescent light bulbs
# Internet Traffic
# Sand and gravel production (industrial)
# Cyclohexane
# Space Launches
# Neoprene Rubber
# HEPB3 Vaccine
# Ground Source Heat Pumps
# Copper Refining
# Low-Density Polyethylene
# Natural Gas Power
# Maleic Anhydride
# Sand and gravel production (construction)
# Disk brakes
# Refrigerators
# Phthalic Anhydride
# Aniline
# Capture fisheries production
# Oil Refining Capacity
# Crop harvester
# Solar Thermal Energy
# Radio
# Sodium-Based Battery Storage
# Vinyl Acetate
# Oil pipeline
# High-Density Polyethylene
# Public roads
# Cement production
# Home air conditioning
# DTP3 Vaccine
# Magnetic Data Storage
# Hydrochloric Acid
# Lithium-Ion Battery Storage
# Nitric Acid
# Coal Power
# Liquid Biofuels
# Stationary Steam Engines
# Motorcycles
# Electronic ignition
# Desalination capacity
# Cadmium Refining
# Acrylonitrile
# MCV2 Vaccine
# Washing Machines
# Coal Production
# Steam Locomotives
# Iron
# Pumped Hydro Storage
# Natural gas pipeline
# Milk production
# Insect-Resistant Corn
# Electric Range
# Polystyrene
# Phosphate Fertilizer
# Ebook reader
# Caprolactam
# Telephones
# BCG Vaccine
# Compressed Air Energy Storage
# Television
# Laundry Dryers
# Cable TV
# Ethyl Alcohol
# Heat Thermal Battery Storage
# Household Internet access
# Methanol
# Dishwashers
# Computing Growth
# Acrylic Fiber
# HIB3 Vaccine
# Marine Energy
# Podcasting
# Polyester Fiber
# Hydroelectricity
# Cane Sugar Production
# Motor Gasoline
# Nitrogen Fertilizer
# Primary Magnesium
# Microcomputers
# Gold production
# Real-time gross settlement adoption
# Renewable Power
# Sodium
# Geothermal Energy
# Postal Traffic
# Automatic transmission
# Wet flue gas desulfurization systems
# Ethanolamine
# Polyvinylchloride
# Graphite Mine Production
# Households with only mobile phones (no landlines)
# Oil Production
# Phenol
# Cellphones
# Aquaculture production
# Hydrofluoric Acid
# Magnesium
# All Biofuels
# Pentaerythritol
# Concentrated Solar Power
# Beer Production
# Ethylene
# Microwaves
# Synthetic Filaments
# Salt production
# YFV Vaccine
# Copper Mining
# Vacuums
# PCV3 Vaccine
# Railroad
# Fluid Catalytic Cracking Refineries
# Primary copper production
# Home computers
# Steam ships
# Sodium Chlorate
# Transistors per Microprocessor
# Insect-Resistant Cotton
# Lithium Mine Production
# Videocassette recorder
# Solar Photovoltaic
# Caustic Soda
# Bisphenol A
# ROTAC Vaccine
# Flow Battery Storage
# Electro-Chemical Capacitor
# Stove
# Silver
# Air-Source Heat Pumps
# Random Access Memory
# Bicycles
# Social media usage
# Canals
# Solid Biofuels
# Crude Oil
# Central heating
# Titanium Sponge
# Power steering
# Potash Fertilizer
# Natural Gas Production
# Sensible Heat Storage
# Tablet
# Tin
# Ethylene Glycol
# HEPBB Vaccine
# Nox pollution controls (boilers)
# Rare Earth Mine Production
# Iron ore
# Colour TV
# Water Heater
# Liquefied natural gas
# Nickel production
# Raw steel production
# Shotgun Sanger DNA Sequencing
# Sulphuric Acid
# Primary aluminum production
# Nickel-Based Battery
# RCV1 Vaccine

# %%
all_tech_df[all_tech_df['Technology Name']=='Natural Gas Production']
# Out:
#                                                  ID Spatial Scale  \
# 126     Natural Gas Production_Annual Production_CA      National
# 127     Natural Gas Production_Annual Production_MX      National
# 128     Natural Gas Production_Annual Production_US      National
# 129     Natural Gas Production_Annual Production_AR      National
# 130     Natural Gas Production_Annual Production_BO      National
# 131     Natural Gas Production_Annual Production_BR      National
# 132     Natural Gas Production_Annual Production_CO      National
# 133     Natural Gas Production_Annual Production_PE      National
# 134     Natural Gas Production_Annual Production_TT      National
# 135     Natural Gas Production_Annual Production_VE      National
# 136     Natural Gas Production_Annual Production_DK      National
# 137     Natural Gas Production_Annual Production_DE      National
# 138     Natural Gas Production_Annual Production_IT      National
# 139     Natural Gas Production_Annual Production_NL      National
# 140     Natural Gas Production_Annual Production_NO      National
# 141     Natural Gas Production_Annual Production_PL      National
# 142     Natural Gas Production_Annual Production_RO      National
# 143     Natural Gas Production_Annual Production_UA      National
# 144     Natural Gas Production_Annual Production_GB      National
# 145     Natural Gas Production_Annual Production_AZ      National
# 146     Natural Gas Production_Annual Production_KZ      National
# 147     Natural Gas Production_Annual Production_RU      National
# 148     Natural Gas Production_Annual Production_TM      National
# 149     Natural Gas Production_Annual Production_SU      National
# 150     Natural Gas Production_Annual Production_UZ      National
# 151     Natural Gas Production_Annual Production_BH      National
# 152     Natural Gas Production_Annual Production_IR      National
# 153     Natural Gas Production_Annual Production_IQ      National
# 154     Natural Gas Production_Annual Production_KW      National
# 155     Natural Gas Production_Annual Production_OM      National
# 156     Natural Gas Production_Annual Production_QA      National
# 157     Natural Gas Production_Annual Production_SA      National
# 158     Natural Gas Production_Annual Production_SY      National
# 159     Natural Gas Production_Annual Production_AE      National
# 160     Natural Gas Production_Annual Production_YE      National
# 161     Natural Gas Production_Annual Production_DZ      National
# 162     Natural Gas Production_Annual Production_EG      National
# 163     Natural Gas Production_Annual Production_LY      National
# 164     Natural Gas Production_Annual Production_NG      National
# 165     Natural Gas Production_Annual Production_AU      National
# 166     Natural Gas Production_Annual Production_BD      National
# 167     Natural Gas Production_Annual Production_BN      National
# 168     Natural Gas Production_Annual Production_CN      National
# 169     Natural Gas Production_Annual Production_IN      National
# 170     Natural Gas Production_Annual Production_ID      National
# 171     Natural Gas Production_Annual Production_MY      National
# 172     Natural Gas Production_Annual Production_MM      National
# 173     Natural Gas Production_Annual Production_PK      National
# 174     Natural Gas Production_Annual Production_TH      National
# 175     Natural Gas Production_Annual Production_VN      National
# 176  Natural Gas Production_Annual Production_World        Global
# 0                   Natural Gas Production_Price_DE      National
# 1                   Natural Gas Production_Price_US      National
# 2                   Natural Gas Production_Price_CA      National
# 3        Natural Gas Production_Price_Rest of World        Global
#
#       Country Code          Country Name         Technology Name  \
# 126             CA                Canada  Natural Gas Production
# 127             MX                Mexico  Natural Gas Production
# 128             US                    US  Natural Gas Production
# 129             AR             Argentina  Natural Gas Production
# 130             BO               Bolivia  Natural Gas Production
# 131             BR                Brazil  Natural Gas Production
# 132             CO              Colombia  Natural Gas Production
# 133             PE                  Peru  Natural Gas Production
# 134             TT     Trinidad & Tobago  Natural Gas Production
# 135             VE             Venezuela  Natural Gas Production
# 136             DK               Denmark  Natural Gas Production
# 137             DE               Germany  Natural Gas Production
# 138             IT                 Italy  Natural Gas Production
# 139             NL           Netherlands  Natural Gas Production
# 140             NO                Norway  Natural Gas Production
# 141             PL                Poland  Natural Gas Production
# 142             RO               Romania  Natural Gas Production
# 143             UA               Ukraine  Natural Gas Production
# 144             GB        United Kingdom  Natural Gas Production
# 145             AZ            Azerbaijan  Natural Gas Production
# 146             KZ            Kazakhstan  Natural Gas Production
# 147             RU    Russian Federation  Natural Gas Production
# 148             TM          Turkmenistan  Natural Gas Production
# 149             SU                  USSR  Natural Gas Production
# 150             UZ            Uzbekistan  Natural Gas Production
# 151             BH               Bahrain  Natural Gas Production
# 152             IR                  Iran  Natural Gas Production
# 153             IQ                  Iraq  Natural Gas Production
# 154             KW                Kuwait  Natural Gas Production
# 155             OM                  Oman  Natural Gas Production
# 156             QA                 Qatar  Natural Gas Production
# 157             SA          Saudi Arabia  Natural Gas Production
# 158             SY                 Syria  Natural Gas Production
# 159             AE  United Arab Emirates  Natural Gas Production
# 160             YE                 Yemen  Natural Gas Production
# 161             DZ               Algeria  Natural Gas Production
# 162             EG                 Egypt  Natural Gas Production
# 163             LY                 Libya  Natural Gas Production
# 164             NG               Nigeria  Natural Gas Production
# 165             AU             Australia  Natural Gas Production
# 166             BD            Bangladesh  Natural Gas Production
# 167             BN                Brunei  Natural Gas Production
# 168             CN                 China  Natural Gas Production
# 169             IN                 India  Natural Gas Production
# 170             ID             Indonesia  Natural Gas Production
# 171             MY              Malaysia  Natural Gas Production
# 172             MM               Myanmar  Natural Gas Production
# 173             PK              Pakistan  Natural Gas Production
# 174             TH              Thailand  Natural Gas Production
# 175             VN               Vietnam  Natural Gas Production
# 176          World                 World  Natural Gas Production
# 0               DE               Germany  Natural Gas Production
# 1               US                    US  Natural Gas Production
# 2               CA                Canada  Natural Gas Production
# 3    Rest of World         Rest of World  Natural Gas Production
#
#                 Metric                        Unit Data Source  1700  1701  \
# 126  Annual Production        Billion cubic metres          BP   NaN   NaN
# 127  Annual Production        Billion cubic metres          BP   NaN   NaN
# 128  Annual Production        Billion cubic metres          BP   NaN   NaN
# 129  Annual Production        Billion cubic metres          BP   NaN   NaN
# 130  Annual Production        Billion cubic metres          BP   NaN   NaN
# 131  Annual Production        Billion cubic metres          BP   NaN   NaN
# 132  Annual Production        Billion cubic metres          BP   NaN   NaN
# 133  Annual Production        Billion cubic metres          BP   NaN   NaN
# 134  Annual Production        Billion cubic metres          BP   NaN   NaN
# 135  Annual Production        Billion cubic metres          BP   NaN   NaN
# 136  Annual Production        Billion cubic metres          BP   NaN   NaN
# 137  Annual Production        Billion cubic metres          BP   NaN   NaN
# 138  Annual Production        Billion cubic metres          BP   NaN   NaN
# 139  Annual Production        Billion cubic metres          BP   NaN   NaN
# 140  Annual Production        Billion cubic metres          BP   NaN   NaN
# 141  Annual Production        Billion cubic metres          BP   NaN   NaN
# 142  Annual Production        Billion cubic metres          BP   NaN   NaN
# 143  Annual Production        Billion cubic metres          BP   NaN   NaN
# 144  Annual Production        Billion cubic metres          BP   NaN   NaN
# 145  Annual Production        Billion cubic metres          BP   NaN   NaN
# 146  Annual Production        Billion cubic metres          BP   NaN   NaN
# 147  Annual Production        Billion cubic metres          BP   NaN   NaN
# 148  Annual Production        Billion cubic metres          BP   NaN   NaN
# 149  Annual Production        Billion cubic metres          BP   NaN   NaN
# 150  Annual Production        Billion cubic metres          BP   NaN   NaN
# 151  Annual Production        Billion cubic metres          BP   NaN   NaN
# 152  Annual Production        Billion cubic metres          BP   NaN   NaN
# 153  Annual Production        Billion cubic metres          BP   NaN   NaN
# 154  Annual Production        Billion cubic metres          BP   NaN   NaN
# 155  Annual Production        Billion cubic metres          BP   NaN   NaN
# 156  Annual Production        Billion cubic metres          BP   NaN   NaN
# 157  Annual Production        Billion cubic metres          BP   NaN   NaN
# 158  Annual Production        Billion cubic metres          BP   NaN   NaN
# 159  Annual Production        Billion cubic metres          BP   NaN   NaN
# 160  Annual Production        Billion cubic metres          BP   NaN   NaN
# 161  Annual Production        Billion cubic metres          BP   NaN   NaN
# 162  Annual Production        Billion cubic metres          BP   NaN   NaN
# 163  Annual Production        Billion cubic metres          BP   NaN   NaN
# 164  Annual Production        Billion cubic metres          BP   NaN   NaN
# 165  Annual Production        Billion cubic metres          BP   NaN   NaN
# 166  Annual Production        Billion cubic metres          BP   NaN   NaN
# 167  Annual Production        Billion cubic metres          BP   NaN   NaN
# 168  Annual Production        Billion cubic metres          BP   NaN   NaN
# 169  Annual Production        Billion cubic metres          BP   NaN   NaN
# 170  Annual Production        Billion cubic metres          BP   NaN   NaN
# 171  Annual Production        Billion cubic metres          BP   NaN   NaN
# 172  Annual Production        Billion cubic metres          BP   NaN   NaN
# 173  Annual Production        Billion cubic metres          BP   NaN   NaN
# 174  Annual Production        Billion cubic metres          BP   NaN   NaN
# 175  Annual Production        Billion cubic metres          BP   NaN   NaN
# 176  Annual Production        Billion cubic metres          BP   NaN   NaN
# 0                Price  US dollars per million Btu          BP   NaN   NaN
# 1                Price  US dollars per million Btu          BP   NaN   NaN
# 2                Price  US dollars per million Btu          BP   NaN   NaN
# 3                Price  US dollars per million Btu          BP   NaN   NaN
#
#      ...         2016         2017         2018         2019         2020  \
# 126  ...   165.075500   171.270600   176.796325   169.765475   165.728125
# 127  ...    43.651424    38.268444    35.191028    31.294889    30.489354
# 128  ...   727.356111   746.170711   840.936171   928.111084   915.899762
# 129  ...    37.282356    37.149888    39.423291    41.615260    38.292528
# 130  ...    18.801001    18.256278    17.053202    15.020820    14.452845
# 131  ...    24.123578    27.181422    25.162357    25.746527    24.236339
# 132  ...    11.992118    11.752476    12.376339    12.618220    12.455031
# 133  ...    14.018435    13.010747    12.811486    13.495792    12.167065
# 134  ...    31.281698    31.872928    33.961113    34.560890    29.465264
# 135  ...    37.238734    38.605388    31.619100    25.576219    21.561088
# 136  ...     4.700103     5.050029     4.292761     3.202557     1.379693
# 137  ...     6.923041     6.376161     5.541774     5.330759     4.532420
# 138  ...     5.509763     5.273059     5.189197     4.621247     3.912091
# 139  ...    44.286111    37.930556    32.325000    27.844444    20.072222
# 140  ...   115.890931   123.729222   121.286867   114.259787   111.454258
# 141  ...     4.131806     4.040000     3.981306     3.985194     3.928778
# 142  ...     9.052775    10.011401     9.957650     9.622587     8.596321
# 143  ...    19.022861    19.401426    19.685349    19.401426    19.117502
# 144  ...    41.738189    41.884648    40.638988    39.155583    39.466789
# 145  ...    18.277540    17.758627    18.755733    23.938214    25.864849
# 146  ...    31.484278    33.402992    33.081303    33.071824    33.344486
# 147  ...   589.275368   635.560863   669.112979   679.044838   637.294248
# 148  ...    63.220256    58.677483    61.516716    63.163184    66.014650
# 149  ...     0.000000     0.000000     0.000000     0.000000     0.000000
# 150  ...    53.124000    53.606802    58.285150    57.458411    47.101173
# 151  ...    14.441371    14.466323    14.647456    16.265963    16.436681
# 152  ...   199.341920   213.850070   224.898984   232.900088   249.530229
# 153  ...     9.895578    10.117798    10.573736    10.966854     7.005354
# 154  ...    16.426450    16.246640    16.850891    18.154611    16.470396
# 155  ...    31.477503    32.323414    36.332648    36.690195    36.930405
# 156  ...   174.768557   170.535881   175.202879   177.152466   174.934838
# 157  ...   105.317000   109.250209   112.100000   111.150000   113.050000
# 158  ...     3.534375     3.487250     3.468400     3.327025     2.741733
# 159  ...    59.520822    59.536688    58.082329    57.516510    55.444915
# 160  ...     0.501125     0.300667     0.099002     0.300667     0.306435
# 161  ...    91.392263    92.976538    93.843750    86.952250    81.456375
# 162  ...    40.251750    48.812649    58.558327    64.938697    58.465432
# 163  ...    14.791950    13.593800    13.185975    13.480186    12.098420
# 164  ...    42.637021    47.205619    48.269554    49.279149    49.431139
# 165  ...    93.997929   110.124627   127.401860   146.114289   145.950597
# 166  ...    26.450947    26.592672    26.581770    25.284434    23.730901
# 167  ...    12.942845    12.854908    12.565272    12.980136    12.640790
# 168  ...   137.941618   149.199484   161.418854   176.741445   194.009218
# 169  ...    26.582316    27.693324    27.491486    26.905524    23.760627
# 170  ...    75.079964    72.704988    72.801675    67.583436    59.538086
# 171  ...    76.695481    79.583109    76.118997    76.441704    68.690222
# 172  ...    18.280076    17.798892    16.971708    18.481905    17.506865
# 173  ...    34.678689    34.651498    34.200104    32.693429    30.605070
# 174  ...    37.273708    35.946515    34.728116    35.772687    32.706406
# 175  ...    10.238650     9.520690     9.659650     9.843000     8.839400
# 176  ...  3544.731094  3673.489124  3851.678504  3967.733811  3861.515368
# 0    ...     4.931313     5.624670     6.640000     5.029917     4.062832
# 1    ...     2.461839     2.960584     3.116446     2.511900     1.988582
# 2    ...     1.550455     1.579683     1.182402     1.267677     1.581569
# 3    ...     2.981202     3.388312     3.646283     2.936498     2.544328
#
#             2021  2022  2023  2024  2025
# 126   172.319192   NaN   NaN   NaN   NaN
# 127    29.241314   NaN   NaN   NaN   NaN
# 128   934.203188   NaN   NaN   NaN   NaN
# 129    38.608495   NaN   NaN   NaN   NaN
# 130    15.088104   NaN   NaN   NaN   NaN
# 131    24.332678   NaN   NaN   NaN   NaN
# 132    12.566443   NaN   NaN   NaN   NaN
# 133    11.483049   NaN   NaN   NaN   NaN
# 134    24.722997   NaN   NaN   NaN   NaN
# 135    23.977127   NaN   NaN   NaN   NaN
# 136     1.308592   NaN   NaN   NaN   NaN
# 137     4.536816   NaN   NaN   NaN   NaN
# 138     3.184141   NaN   NaN   NaN   NaN
# 139    18.100000   NaN   NaN   NaN   NaN
# 140   114.316848   NaN   NaN   NaN   NaN
# 141     3.870221   NaN   NaN   NaN   NaN
# 142     8.464479   NaN   NaN   NaN   NaN
# 143    18.582212   NaN   NaN   NaN   NaN
# 144    32.697749   NaN   NaN   NaN   NaN
# 145    31.808316   NaN   NaN   NaN   NaN
# 146    31.974209   NaN   NaN   NaN   NaN
# 147   701.667404   NaN   NaN   NaN   NaN
# 148    79.283595   NaN   NaN   NaN   NaN
# 149     0.000000   NaN   NaN   NaN   NaN
# 150    50.918805   NaN   NaN   NaN   NaN
# 151    17.228249   NaN   NaN   NaN   NaN
# 152   256.650166   NaN   NaN   NaN   NaN
# 153     9.354809   NaN   NaN   NaN   NaN
# 154    17.393453   NaN   NaN   NaN   NaN
# 155    41.792215   NaN   NaN   NaN   NaN
# 156   176.980399   NaN   NaN   NaN   NaN
# 157   117.286984   NaN   NaN   NaN   NaN
# 158     2.878132   NaN   NaN   NaN   NaN
# 159    56.994166   NaN   NaN   NaN   NaN
# 160     0.397750   NaN   NaN   NaN   NaN
# 161   100.773750   NaN   NaN   NaN   NaN
# 162    67.799431   NaN   NaN   NaN   NaN
# 163    12.396907   NaN   NaN   NaN   NaN
# 164    45.913324   NaN   NaN   NaN   NaN
# 165   147.218897   NaN   NaN   NaN   NaN
# 166    24.142775   NaN   NaN   NaN   NaN
# 167    11.534709   NaN   NaN   NaN   NaN
# 168   209.212881   NaN   NaN   NaN   NaN
# 169    28.538813   NaN   NaN   NaN   NaN
# 170    59.291943   NaN   NaN   NaN   NaN
# 171    74.190541   NaN   NaN   NaN   NaN
# 172    16.940227   NaN   NaN   NaN   NaN
# 173    32.676795   NaN   NaN   NaN   NaN
# 174    31.525941   NaN   NaN   NaN   NaN
# 175     7.121700   NaN   NaN   NaN   NaN
# 176  4036.882776   NaN   NaN   NaN   NaN
# 0       8.936670   NaN   NaN   NaN   NaN
# 1       3.839473   NaN   NaN   NaN   NaN
# 2       2.753414   NaN   NaN   NaN   NaN
# 3       5.176519   NaN   NaN   NaN   NaN
#
# [55 rows x 334 columns]

# %%
all_tech_df['Technology Name'] = all_tech_df['Technology Name'].str.title()

# %%
all_tech_df.insert(8, 'Long Technology Name', all_tech_df['Metric'] + '|' + all_tech_df['Technology Name'])
all_tech_df
# Out:
#                                                     ID Spatial Scale  \
# 0    Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1    Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 0      Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 1    Sensible Heat Storage_Cumulative Rated Capacit...      National
# 0      Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ..                                                 ...           ...
# 105       Raw steel production_Annual production_World        Global
# 0                    Space Launches_Yearly Launches_UA      National
# 0                    Space Launches_Yearly Launches_TM      National
# 0           Liquefied natural gas_Annual Production_US      National
# 0                    Space Launches_Yearly Launches_CO      National
#
#     Country Code   Country Name              Technology Name  \
# 0             TG           Togo  Lithium-Ion Battery Storage
# 1             TG           Togo  Lithium-Ion Battery Storage
# 0             ZA   South Africa        Sensible Heat Storage
# 1             ZA   South Africa        Sensible Heat Storage
# 0             DK        Denmark          Onshore Wind Energy
# ..           ...            ...                          ...
# 105        World          World         Raw Steel Production
# 0             UA        Ukraine               Space Launches
# 0             TM   Turkmenistan               Space Launches
# 0             US  United States        Liquefied Natural Gas
# 0             CO       Colombia               Space Launches
#
#                         Metric                                   Unit  \
# 0       Cumulative Rated Power                                     kW
# 1    Cumulative Rated Capacity                                    kWh
# 0       Cumulative Rated Power                                     kW
# 1    Cumulative Rated Capacity                                    kWh
# 0     Levelized Cost of Energy                           2021 USD/kWh
# ..                         ...                                    ...
# 105          Annual production                            Metric tons
# 0              Yearly Launches  Number of objects launched into space
# 0              Yearly Launches  Number of objects launched into space
# 0            Annual Production                     Billion cubic feet
# 0              Yearly Launches  Number of objects launched into space
#
#                                 Data Source  \
# 0        DOE Global Energy Storage Database
# 1        DOE Global Energy Storage Database
# 0        DOE Global Energy Storage Database
# 1        DOE Global Energy Storage Database
# 0                                     IRENA
# ..                                      ...
# 105                  U.S. Geological Survey
# 0                                    UNOOSA
# 0                                    UNOOSA
# 0    U.S. Energy Information Administration
# 0                                    UNOOSA
#
#                                   Long Technology Name  1700  ...  \
# 0    Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1    Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 0         Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 1      Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 0         Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ..                                                 ...   ...  ...
# 105             Annual production|Raw Steel Production   NaN  ...
# 0                       Yearly Launches|Space Launches   NaN  ...
# 0                       Yearly Launches|Space Launches   NaN  ...
# 0              Annual Production|Liquefied Natural Gas   NaN  ...
# 0                       Yearly Launches|Space Launches   NaN  ...
#
#              2016          2017          2018         2019         2020  \
# 0             NaN  1.900000e+02  2.900000e+02          NaN          NaN
# 1             NaN  7.600000e+02  1.160000e+03          NaN          NaN
# 0    2.550000e+05  3.550000e+05  4.550000e+05          NaN          NaN
# 1    1.195000e+06  1.745000e+06  2.945000e+06          NaN          NaN
# 0    5.542823e-02  4.578779e-02  4.374012e-02     0.045337     0.039979
# ..            ...           ...           ...          ...          ...
# 105           NaN           NaN           NaN          NaN          NaN
# 0             NaN           NaN           NaN          NaN          NaN
# 0             NaN           NaN           NaN          NaN          NaN
# 0    1.868400e+02  7.075400e+02  1.083120e+03  1819.400000  2389.840000
# 0             NaN           NaN  1.000000e+00          NaN          NaN
#
#         2021  2022  2023  2024  2025
# 0        NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN   NaN
# 0        NaN   NaN   NaN   NaN   NaN
# 1        NaN   NaN   NaN   NaN   NaN
# 0        NaN   NaN   NaN   NaN   NaN
# ..       ...   ...   ...   ...   ...
# 105      NaN   NaN   NaN   NaN   NaN
# 0        NaN   1.0   NaN   NaN   NaN
# 0        NaN   NaN   NaN   NaN   NaN
# 0    3560.82   NaN   NaN   NaN   NaN
# 0        NaN   NaN   NaN   NaN   NaN
#
# [7656 rows x 335 columns]

# %%
all_tech_df.reset_index(drop=True,inplace=True)
all_tech_df
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 7651       Raw steel production_Annual production_World        Global
# 7652                  Space Launches_Yearly Launches_UA      National
# 7653                  Space Launches_Yearly Launches_TM      National
# 7654         Liquefied natural gas_Annual Production_US      National
# 7655                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 7651        World          World         Raw Steel Production
# 7652           UA        Ukraine               Space Launches
# 7653           TM   Turkmenistan               Space Launches
# 7654           US  United States        Liquefied Natural Gas
# 7655           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0        Cumulative Rated Power                                     kW
# 1     Cumulative Rated Capacity                                    kWh
# 2        Cumulative Rated Power                                     kW
# 3     Cumulative Rated Capacity                                    kWh
# 4      Levelized Cost of Energy                           2021 USD/kWh
# ...                         ...                                    ...
# 7651          Annual production                            Metric tons
# 7652            Yearly Launches  Number of objects launched into space
# 7653            Yearly Launches  Number of objects launched into space
# 7654          Annual Production                     Billion cubic feet
# 7655            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  \
# 0         DOE Global Energy Storage Database
# 1         DOE Global Energy Storage Database
# 2         DOE Global Energy Storage Database
# 3         DOE Global Energy Storage Database
# 4                                      IRENA
# ...                                      ...
# 7651                  U.S. Geological Survey
# 7652                                  UNOOSA
# 7653                                  UNOOSA
# 7654  U.S. Energy Information Administration
# 7655                                  UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 7651             Annual production|Raw Steel Production   NaN  ...
# 7652                     Yearly Launches|Space Launches   NaN  ...
# 7653                     Yearly Launches|Space Launches   NaN  ...
# 7654            Annual Production|Liquefied Natural Gas   NaN  ...
# 7655                     Yearly Launches|Space Launches   NaN  ...
#
#               2016          2017          2018         2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02          NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03          NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05          NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06          NaN          NaN
# 4     5.542823e-02  4.578779e-02  4.374012e-02     0.045337     0.039979
# ...            ...           ...           ...          ...          ...
# 7651           NaN           NaN           NaN          NaN          NaN
# 7652           NaN           NaN           NaN          NaN          NaN
# 7653           NaN           NaN           NaN          NaN          NaN
# 7654  1.868400e+02  7.075400e+02  1.083120e+03  1819.400000  2389.840000
# 7655           NaN           NaN  1.000000e+00          NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 7651      NaN   NaN   NaN   NaN   NaN
# 7652      NaN   1.0   NaN   NaN   NaN
# 7653      NaN   NaN   NaN   NaN   NaN
# 7654  3560.82   NaN   NaN   NaN   NaN
# 7655      NaN   NaN   NaN   NaN   NaN
#
# [7656 rows x 335 columns]

# %%
omit = []
for col in all_tech_df.columns:
    if len(col) != 4 or col == 'Unit':
         omit.append(col)
empty_rows = all_tech_df.drop(columns=omit)
empty_rows.dropna(how='all', inplace=True)
na_idx = []
for idx in all_tech_df.index:
    if idx not in empty_rows.index:
        na_idx.append(idx)
all_tech_df.drop(na_idx, inplace=True)
all_tech_df
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 7651       Raw steel production_Annual production_World        Global
# 7652                  Space Launches_Yearly Launches_UA      National
# 7653                  Space Launches_Yearly Launches_TM      National
# 7654         Liquefied natural gas_Annual Production_US      National
# 7655                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 7651        World          World         Raw Steel Production
# 7652           UA        Ukraine               Space Launches
# 7653           TM   Turkmenistan               Space Launches
# 7654           US  United States        Liquefied Natural Gas
# 7655           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0        Cumulative Rated Power                                     kW
# 1     Cumulative Rated Capacity                                    kWh
# 2        Cumulative Rated Power                                     kW
# 3     Cumulative Rated Capacity                                    kWh
# 4      Levelized Cost of Energy                           2021 USD/kWh
# ...                         ...                                    ...
# 7651          Annual production                            Metric tons
# 7652            Yearly Launches  Number of objects launched into space
# 7653            Yearly Launches  Number of objects launched into space
# 7654          Annual Production                     Billion cubic feet
# 7655            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  \
# 0         DOE Global Energy Storage Database
# 1         DOE Global Energy Storage Database
# 2         DOE Global Energy Storage Database
# 3         DOE Global Energy Storage Database
# 4                                      IRENA
# ...                                      ...
# 7651                  U.S. Geological Survey
# 7652                                  UNOOSA
# 7653                                  UNOOSA
# 7654  U.S. Energy Information Administration
# 7655                                  UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 7651             Annual production|Raw Steel Production   NaN  ...
# 7652                     Yearly Launches|Space Launches   NaN  ...
# 7653                     Yearly Launches|Space Launches   NaN  ...
# 7654            Annual Production|Liquefied Natural Gas   NaN  ...
# 7655                     Yearly Launches|Space Launches   NaN  ...
#
#               2016          2017          2018         2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02          NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03          NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05          NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06          NaN          NaN
# 4     5.542823e-02  4.578779e-02  4.374012e-02     0.045337     0.039979
# ...            ...           ...           ...          ...          ...
# 7651           NaN           NaN           NaN          NaN          NaN
# 7652           NaN           NaN           NaN          NaN          NaN
# 7653           NaN           NaN           NaN          NaN          NaN
# 7654  1.868400e+02  7.075400e+02  1.083120e+03  1819.400000  2389.840000
# 7655           NaN           NaN  1.000000e+00          NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 7651      NaN   NaN   NaN   NaN   NaN
# 7652      NaN   1.0   NaN   NaN   NaN
# 7653      NaN   NaN   NaN   NaN   NaN
# 7654  3560.82   NaN   NaN   NaN   NaN
# 7655      NaN   NaN   NaN   NaN   NaN
#
# [7648 rows x 335 columns]

# %%
all_tech_df['Metric'] = all_tech_df['Metric'].str.title()

# %%
all_tech_df['Metric'] = all_tech_df['Metric'].str.strip()

# %%
set(all_tech_df['Metric'])
# Out:
# {'Annual Production',
#  'Average Capacity Of Unit Additions',
#  'Computing Capacity',
#  'Cumulative Acreage',
#  'Cumulative Length',
#  'Cumulative Rated Capacity',
#  'Cumulative Rated Power',
#  'Cumulative Total Capacity',
#  'Installed Capacity',
#  'Installed Electricity Capacity',
#  'Levelized Cost Of Energy',
#  'Net Total Capacity',
#  'Number Of Weapons',
#  'Price',
#  'Share Of Boilers',
#  'Share Of Households',
#  'Share Of Market',
#  'Share Of Population',
#  'Total Capacity',
#  'Total Installed Cost',
#  'Total Length',
#  'Total Number',
#  'Yearly Launches'}

# %%
all_tech_df.to_csv('all_tech_version 2.0.csv', index=False)

# %%
all_tech_df = all_tech_df[all_tech_df['Metric']!='Price']
all_tech_df
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 7651       Raw steel production_Annual production_World        Global
# 7652                  Space Launches_Yearly Launches_UA      National
# 7653                  Space Launches_Yearly Launches_TM      National
# 7654         Liquefied natural gas_Annual Production_US      National
# 7655                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 7651        World          World         Raw Steel Production
# 7652           UA        Ukraine               Space Launches
# 7653           TM   Turkmenistan               Space Launches
# 7654           US  United States        Liquefied Natural Gas
# 7655           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0        Cumulative Rated Power                                     kW
# 1     Cumulative Rated Capacity                                    kWh
# 2        Cumulative Rated Power                                     kW
# 3     Cumulative Rated Capacity                                    kWh
# 4      Levelized Cost Of Energy                           2021 USD/kWh
# ...                         ...                                    ...
# 7651          Annual Production                            Metric tons
# 7652            Yearly Launches  Number of objects launched into space
# 7653            Yearly Launches  Number of objects launched into space
# 7654          Annual Production                     Billion cubic feet
# 7655            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  \
# 0         DOE Global Energy Storage Database
# 1         DOE Global Energy Storage Database
# 2         DOE Global Energy Storage Database
# 3         DOE Global Energy Storage Database
# 4                                      IRENA
# ...                                      ...
# 7651                  U.S. Geological Survey
# 7652                                  UNOOSA
# 7653                                  UNOOSA
# 7654  U.S. Energy Information Administration
# 7655                                  UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 7651             Annual production|Raw Steel Production   NaN  ...
# 7652                     Yearly Launches|Space Launches   NaN  ...
# 7653                     Yearly Launches|Space Launches   NaN  ...
# 7654            Annual Production|Liquefied Natural Gas   NaN  ...
# 7655                     Yearly Launches|Space Launches   NaN  ...
#
#               2016          2017          2018         2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02          NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03          NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05          NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06          NaN          NaN
# 4     5.542823e-02  4.578779e-02  4.374012e-02     0.045337     0.039979
# ...            ...           ...           ...          ...          ...
# 7651           NaN           NaN           NaN          NaN          NaN
# 7652           NaN           NaN           NaN          NaN          NaN
# 7653           NaN           NaN           NaN          NaN          NaN
# 7654  1.868400e+02  7.075400e+02  1.083120e+03  1819.400000  2389.840000
# 7655           NaN           NaN  1.000000e+00          NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 7651      NaN   NaN   NaN   NaN   NaN
# 7652      NaN   1.0   NaN   NaN   NaN
# 7653      NaN   NaN   NaN   NaN   NaN
# 7654  3560.82   NaN   NaN   NaN   NaN
# 7655      NaN   NaN   NaN   NaN   NaN
#
# [7596 rows x 335 columns]

# %%
all_tech_df.to_csv('all_tech_version 1.5.csv', index=False)

# %%
no_country = []
for tech in set(all_tech_df['Technology Name']):
    countries = list(set(all_tech_df[all_tech_df['Technology Name'] == tech]['Country Name']))
    id_ = list(all_tech_df[all_tech_df['Technology Name'] == tech]['ID'])
    if len(countries) <= 2:
        no_country.extend(id_)

# %%
all_tech_w_countrylvl = all_tech_df.set_index('ID', drop=True)
all_tech_w_countrylvl.drop(index=no_country, inplace=True)
all_tech_w_countrylvl
# Out:
#                                                    Spatial Scale Country Code  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...      National           TG
# Lithium-Ion Battery Storage_Cumulative Rated Ca...      National           TG
# Sensible Heat Storage_Cumulative Rated Power_ZA         National           ZA
# Sensible Heat Storage_Cumulative Rated Capacity_ZA      National           ZA
# Onshore Wind Energy_Levelized Cost of Energy_DK         National           DK
# ...                                                          ...          ...
# Raw steel production_Annual production_ZW               National           ZW
# Raw steel production_Annual production_World              Global        World
# Space Launches_Yearly Launches_UA                       National           UA
# Space Launches_Yearly Launches_TM                       National           TM
# Space Launches_Yearly Launches_CO                       National           CO
#
#                                                     Country Name  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...          Togo
# Lithium-Ion Battery Storage_Cumulative Rated Ca...          Togo
# Sensible Heat Storage_Cumulative Rated Power_ZA     South Africa
# Sensible Heat Storage_Cumulative Rated Capacity_ZA  South Africa
# Onshore Wind Energy_Levelized Cost of Energy_DK          Denmark
# ...                                                          ...
# Raw steel production_Annual production_ZW               Zimbabwe
# Raw steel production_Annual production_World               World
# Space Launches_Yearly Launches_UA                        Ukraine
# Space Launches_Yearly Launches_TM                   Turkmenistan
# Space Launches_Yearly Launches_CO                       Colombia
#
#                                                                 Technology Name  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...  Lithium-Ion Battery Storage
# Lithium-Ion Battery Storage_Cumulative Rated Ca...  Lithium-Ion Battery Storage
# Sensible Heat Storage_Cumulative Rated Power_ZA           Sensible Heat Storage
# Sensible Heat Storage_Cumulative Rated Capacity_ZA        Sensible Heat Storage
# Onshore Wind Energy_Levelized Cost of Energy_DK             Onshore Wind Energy
# ...                                                                         ...
# Raw steel production_Annual production_ZW                  Raw Steel Production
# Raw steel production_Annual production_World               Raw Steel Production
# Space Launches_Yearly Launches_UA                                Space Launches
# Space Launches_Yearly Launches_TM                                Space Launches
# Space Launches_Yearly Launches_CO                                Space Launches
#
#                                                                        Metric  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...     Cumulative Rated Power
# Lithium-Ion Battery Storage_Cumulative Rated Ca...  Cumulative Rated Capacity
# Sensible Heat Storage_Cumulative Rated Power_ZA        Cumulative Rated Power
# Sensible Heat Storage_Cumulative Rated Capacity_ZA  Cumulative Rated Capacity
# Onshore Wind Energy_Levelized Cost of Energy_DK      Levelized Cost Of Energy
# ...                                                                       ...
# Raw steel production_Annual production_ZW                   Annual Production
# Raw steel production_Annual production_World                Annual Production
# Space Launches_Yearly Launches_UA                             Yearly Launches
# Space Launches_Yearly Launches_TM                             Yearly Launches
# Space Launches_Yearly Launches_CO                             Yearly Launches
#
#                                                                                      Unit  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...                                     kW
# Lithium-Ion Battery Storage_Cumulative Rated Ca...                                    kWh
# Sensible Heat Storage_Cumulative Rated Power_ZA                                        kW
# Sensible Heat Storage_Cumulative Rated Capacity_ZA                                    kWh
# Onshore Wind Energy_Levelized Cost of Energy_DK                              2021 USD/kWh
# ...                                                                                   ...
# Raw steel production_Annual production_ZW                                     Metric tons
# Raw steel production_Annual production_World                                  Metric tons
# Space Launches_Yearly Launches_UA                   Number of objects launched into space
# Space Launches_Yearly Launches_TM                   Number of objects launched into space
# Space Launches_Yearly Launches_CO                   Number of objects launched into space
#
#                                                                            Data Source  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...  DOE Global Energy Storage Database
# Lithium-Ion Battery Storage_Cumulative Rated Ca...  DOE Global Energy Storage Database
# Sensible Heat Storage_Cumulative Rated Power_ZA     DOE Global Energy Storage Database
# Sensible Heat Storage_Cumulative Rated Capacity_ZA  DOE Global Energy Storage Database
# Onshore Wind Energy_Levelized Cost of Energy_DK                                  IRENA
# ...                                                                                ...
# Raw steel production_Annual production_ZW                       U.S. Geological Survey
# Raw steel production_Annual production_World                    U.S. Geological Survey
# Space Launches_Yearly Launches_UA                                               UNOOSA
# Space Launches_Yearly Launches_TM                                               UNOOSA
# Space Launches_Yearly Launches_CO                                               UNOOSA
#
#                                                                                  Long Technology Name  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...  Cumulative Rated Power|Lithium-Ion Battery Sto...
# Lithium-Ion Battery Storage_Cumulative Rated Ca...  Cumulative Rated Capacity|Lithium-Ion Battery ...
# Sensible Heat Storage_Cumulative Rated Power_ZA          Cumulative Rated Power|Sensible Heat Storage
# Sensible Heat Storage_Cumulative Rated Capacity_ZA    Cumulative Rated Capacity|Sensible Heat Storage
# Onshore Wind Energy_Levelized Cost of Energy_DK          Levelized Cost of Energy|Onshore Wind Energy
# ...                                                                                               ...
# Raw steel production_Annual production_ZW                      Annual production|Raw Steel Production
# Raw steel production_Annual production_World                   Annual production|Raw Steel Production
# Space Launches_Yearly Launches_UA                                      Yearly Launches|Space Launches
# Space Launches_Yearly Launches_TM                                      Yearly Launches|Space Launches
# Space Launches_Yearly Launches_CO                                      Yearly Launches|Space Launches
#
#                                                     1700  1701  ...  \
# ID                                                              ...
# Lithium-Ion Battery Storage_Cumulative Rated Po...   NaN   NaN  ...
# Lithium-Ion Battery Storage_Cumulative Rated Ca...   NaN   NaN  ...
# Sensible Heat Storage_Cumulative Rated Power_ZA      NaN   NaN  ...
# Sensible Heat Storage_Cumulative Rated Capacity_ZA   NaN   NaN  ...
# Onshore Wind Energy_Levelized Cost of Energy_DK      NaN   NaN  ...
# ...                                                  ...   ...  ...
# Raw steel production_Annual production_ZW            NaN   NaN  ...
# Raw steel production_Annual production_World         NaN   NaN  ...
# Space Launches_Yearly Launches_UA                    NaN   NaN  ...
# Space Launches_Yearly Launches_TM                    NaN   NaN  ...
# Space Launches_Yearly Launches_CO                    NaN   NaN  ...
#
#                                                             2016  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...           NaN
# Lithium-Ion Battery Storage_Cumulative Rated Ca...           NaN
# Sensible Heat Storage_Cumulative Rated Power_ZA     2.550000e+05
# Sensible Heat Storage_Cumulative Rated Capacity_ZA  1.195000e+06
# Onshore Wind Energy_Levelized Cost of Energy_DK     5.542823e-02
# ...                                                          ...
# Raw steel production_Annual production_ZW                    NaN
# Raw steel production_Annual production_World                 NaN
# Space Launches_Yearly Launches_UA                            NaN
# Space Launches_Yearly Launches_TM                            NaN
# Space Launches_Yearly Launches_CO                            NaN
#
#                                                             2017  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...  1.900000e+02
# Lithium-Ion Battery Storage_Cumulative Rated Ca...  7.600000e+02
# Sensible Heat Storage_Cumulative Rated Power_ZA     3.550000e+05
# Sensible Heat Storage_Cumulative Rated Capacity_ZA  1.745000e+06
# Onshore Wind Energy_Levelized Cost of Energy_DK     4.578779e-02
# ...                                                          ...
# Raw steel production_Annual production_ZW                    NaN
# Raw steel production_Annual production_World                 NaN
# Space Launches_Yearly Launches_UA                            NaN
# Space Launches_Yearly Launches_TM                            NaN
# Space Launches_Yearly Launches_CO                            NaN
#
#                                                             2018      2019  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...  2.900000e+02       NaN
# Lithium-Ion Battery Storage_Cumulative Rated Ca...  1.160000e+03       NaN
# Sensible Heat Storage_Cumulative Rated Power_ZA     4.550000e+05       NaN
# Sensible Heat Storage_Cumulative Rated Capacity_ZA  2.945000e+06       NaN
# Onshore Wind Energy_Levelized Cost of Energy_DK     4.374012e-02  0.045337
# ...                                                          ...       ...
# Raw steel production_Annual production_ZW                    NaN       NaN
# Raw steel production_Annual production_World                 NaN       NaN
# Space Launches_Yearly Launches_UA                            NaN       NaN
# Space Launches_Yearly Launches_TM                            NaN       NaN
# Space Launches_Yearly Launches_CO                   1.000000e+00       NaN
#
#                                                         2020  2021  2022  \
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...       NaN   NaN   NaN
# Lithium-Ion Battery Storage_Cumulative Rated Ca...       NaN   NaN   NaN
# Sensible Heat Storage_Cumulative Rated Power_ZA          NaN   NaN   NaN
# Sensible Heat Storage_Cumulative Rated Capacity_ZA       NaN   NaN   NaN
# Onshore Wind Energy_Levelized Cost of Energy_DK     0.039979   NaN   NaN
# ...                                                      ...   ...   ...
# Raw steel production_Annual production_ZW                NaN   NaN   NaN
# Raw steel production_Annual production_World             NaN   NaN   NaN
# Space Launches_Yearly Launches_UA                        NaN   NaN   1.0
# Space Launches_Yearly Launches_TM                        NaN   NaN   NaN
# Space Launches_Yearly Launches_CO                        NaN   NaN   NaN
#
#                                                     2023  2024  2025
# ID
# Lithium-Ion Battery Storage_Cumulative Rated Po...   NaN   NaN   NaN
# Lithium-Ion Battery Storage_Cumulative Rated Ca...   NaN   NaN   NaN
# Sensible Heat Storage_Cumulative Rated Power_ZA      NaN   NaN   NaN
# Sensible Heat Storage_Cumulative Rated Capacity_ZA   NaN   NaN   NaN
# Onshore Wind Energy_Levelized Cost of Energy_DK      NaN   NaN   NaN
# ...                                                  ...   ...   ...
# Raw steel production_Annual production_ZW            NaN   NaN   NaN
# Raw steel production_Annual production_World         NaN   NaN   NaN
# Space Launches_Yearly Launches_UA                    NaN   NaN   NaN
# Space Launches_Yearly Launches_TM                    NaN   NaN   NaN
# Space Launches_Yearly Launches_CO                    NaN   NaN   NaN
#
# [7474 rows x 334 columns]

# %%
all_tech_w_countrylvl.to_csv('all_tech_with_country-level.csv', index=False)
