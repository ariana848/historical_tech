# %%
import pandas as pd
from pandas import Series, DataFrame
import os

# %%
path = 'cleaned data/'
clean_files = os.listdir(path)

# %%
csv = []
for file in clean_files:
     if '.csv' in file:
        name = path + file
        csv.append(name)

# %%
frame = pd.read_csv('cleaned data/frame.csv')
frame
# Out:
# Empty DataFrame
# Columns: [ID, Spatial Scale, Country Code, Country Name, Technology Name, Metric, Unit, Data Source, 1700, 1701, 1702, 1703, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1716, 1717, 1718, 1719, 1720, 1721, 1722, 1723, 1724, 1725, 1726, 1727, 1728, 1729, 1730, 1731, 1732, 1733, 1734, 1735, 1736, 1737, 1738, 1739, 1740, 1741, 1742, 1743, 1744, 1745, 1746, 1747, 1748, 1749, 1750, 1751, 1752, 1753, 1754, 1755, 1756, 1757, 1758, 1759, 1760, 1761, 1762, 1763, 1764, 1765, 1766, 1767, 1768, 1769, 1770, 1771, 1772, 1773, 1774, 1775, 1776, 1777, 1778, 1779, 1780, 1781, 1782, 1783, 1784, 1785, 1786, 1787, 1788, 1789, 1790, 1791, ...]
# Index: []
#
# [0 rows x 334 columns]

# %%
df_list = [frame]
for file in csv:
    file = pd.read_csv(file)
    df_list.append(file)

# %%
all_tech_df = pd.concat(df_list)
all_tech_df
# Out:
#                                                     ID Spatial Scale  \
# 0    Lithium-ion battery storage_Cumulative Rated C...      National
# 1    Lithium-ion battery storage_Cumulative Rated P...      National
# 0    Sensible heat storage_Cumulative Rated Capacit...      National
# 1      Sensible heat storage_Cumulative Rated Power_ZA      National
# 0    Pumped hydro storage_Cumulative Rated Capacity_CA      National
# ..                                                 ...           ...
# 104          Raw steel production_Annual production_VN      National
# 105          Raw steel production_Annual production_YU      National
# 106          Raw steel production_Annual production_ZW      National
# 107       Raw steel production_Annual production_World        Global
# 0                     Liquefied natural gas_Exports_US           NaN
#
#     Country Code   Country Name              Technology Name  \
# 0             TG           Togo  Lithium-ion battery storage
# ...

# %%
all_tech_df.set_index('ID', drop=True, inplace=True)
all_tech_df
# Out:
#                                                    Spatial Scale Country Code  \
# ID
# Lithium-ion battery storage_Cumulative Rated Ca...      National           TG
# Lithium-ion battery storage_Cumulative Rated Po...      National           TG
# Sensible heat storage_Cumulative Rated Capacity_ZA      National           ZA
# Sensible heat storage_Cumulative Rated Power_ZA         National           ZA
# Pumped hydro storage_Cumulative Rated Capacity_CA       National           CA
# ...                                                          ...          ...
# Raw steel production_Annual production_VN               National           VN
# Raw steel production_Annual production_YU               National           YU
# Raw steel production_Annual production_ZW               National           ZW
# Raw steel production_Annual production_World              Global        World
# Liquefied natural gas_Exports_US                             NaN           US
#
# ...

# %%
for x in set(all_tech_df['Technology Name']):
    print(x)
# Out:
# Nickel-based battery
# Shotgun Sanger DNA Sequencing
# Liquefied natural gas
# Lead-acid battery storage
# Aquaculture production
# Potash Fertilizer
# Electro-chemical capacitor
# Steamships
# Hydrogen storage
# Flow battery storage
# Home computers
# Lithium-ion battery storage
# Oil Production
# Motorcycles
# FCC-Refineries
# Iron
# Iron ore
# Coal Production
# Railroad
# On-Grid Renewable Hydropower
# On-Grid Onshore Wind Energy
# DTP1 Vaccine
# Cyclohexane
# Electricity
# Radio
# Sodium Chlorate
# Laundry Dryers
# Capture fisheries production
# Compressed air energy storage
# Sand and gravel production (industrial)
# POL3 Vaccine
# CFLs
# Steam Locomotives
# Primary bauxite production
# On-Grid Offshore Wind Energy
# Colour TV
# Nuclear weapons
# Biofuels
# Salt production
# Passenger cars
# Natural gas pipeline
# On-Grid Solid Biofuels
# Vinyl Chloride
# Electricity access
# Copper Mining
# Bicycles
# Disk brakes
# Stove
# Polystyrene
# Telegraph Traffic
# MCV1 Vaccine
# ...

# %%
all_tech_df[all_tech_df['Technology Name']=='Nuclear Energy']
# Out:
#                                        Spatial Scale Country Code  \
# ID
# Nuclear Energy_Annual Production_CA         National           CA
# Nuclear Energy_Annual Production_MX         National           MX
# Nuclear Energy_Annual Production_US         National           US
# Nuclear Energy_Annual Production_AR         National           AR
# Nuclear Energy_Annual Production_BR         National           BR
# ...                                              ...          ...
# Nuclear Energy_Annual Production_LK         National           LK
# Nuclear Energy_Annual Production_TW         National           TW
# Nuclear Energy_Annual Production_TH         National           TH
# Nuclear Energy_Annual Production_VN         National           VN
# Nuclear Energy_Annual Production_World      National        World
#
#                                        Country Name Technology Name  \
# ID
# Nuclear Energy_Annual Production_CA          Canada  Nuclear Energy
# ...

# %%
all_tech_df.to_csv('all_tech.csv', index=False)
