# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 2.0.csv')
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 7643       Raw steel production_Annual production_World        Global
# 7644                  Space Launches_Yearly Launches_UA      National
# 7645                  Space Launches_Yearly Launches_TM      National
# 7646         Liquefied natural gas_Annual Production_US      National
# 7647                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 7643        World          World         Raw Steel Production
# 7644           UA        Ukraine               Space Launches
# 7645           TM   Turkmenistan               Space Launches
# 7646           US  United States        Liquefied Natural Gas
# 7647           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0        Cumulative Rated Power                                     kW
# 1     Cumulative Rated Capacity                                    kWh
# 2        Cumulative Rated Power                                     kW
# 3     Cumulative Rated Capacity                                    kWh
# 4      Levelized Cost Of Energy                           2021 USD/kWh
# ...                         ...                                    ...
# 7643          Annual Production                            Metric tons
# 7644            Yearly Launches  Number of objects launched into space
# 7645            Yearly Launches  Number of objects launched into space
# 7646          Annual Production                     Billion cubic feet
# 7647            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  \
# 0         DOE Global Energy Storage Database
# 1         DOE Global Energy Storage Database
# 2         DOE Global Energy Storage Database
# 3         DOE Global Energy Storage Database
# 4                                      IRENA
# ...                                      ...
# 7643                  U.S. Geological Survey
# 7644                                  UNOOSA
# 7645                                  UNOOSA
# 7646  U.S. Energy Information Administration
# 7647                                  UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 7643             Annual production|Raw Steel Production   NaN  ...
# 7644                     Yearly Launches|Space Launches   NaN  ...
# 7645                     Yearly Launches|Space Launches   NaN  ...
# 7646            Annual Production|Liquefied Natural Gas   NaN  ...
# 7647                     Yearly Launches|Space Launches   NaN  ...
#
#               2016          2017          2018         2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02          NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03          NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05          NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06          NaN          NaN
# 4     5.542823e-02  4.578779e-02  4.374012e-02     0.045337     0.039979
# ...            ...           ...           ...          ...          ...
# 7643           NaN           NaN           NaN          NaN          NaN
# 7644           NaN           NaN           NaN          NaN          NaN
# 7645           NaN           NaN           NaN          NaN          NaN
# 7646  1.868400e+02  7.075400e+02  1.083120e+03  1819.400000  2389.840000
# 7647           NaN           NaN  1.000000e+00          NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 7643      NaN   NaN   NaN   NaN   NaN
# 7644      NaN   1.0   NaN   NaN   NaN
# 7645      NaN   NaN   NaN   NaN   NaN
# 7646  3560.82   NaN   NaN   NaN   NaN
# 7647      NaN   NaN   NaN   NaN   NaN
#
# [7648 rows x 335 columns]

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
tech_list
# Out:
# ['Acrylic Fiber',
#  'Acrylonitrile',
#  'Air-Source Heat Pumps',
#  'All Biofuels',
#  'Amazon Prime Users',
#  'Ammonia Synthesis',
#  'Aniline',
#  'Aquaculture Production',
#  'Automatic Transmission',
#  'Bcg Vaccine',
#  'Beer Production',
#  'Benzene',
#  'Bicycles',
#  'Biogas',
#  'Bisphenol A',
#  'Cable Tv',
#  'Cadmium Refining',
#  'Canals',
#  'Cane Sugar Production',
#  'Caprolactam',
#  'Capture Fisheries Production',
#  'Carbon Capture & Sequestration',
#  'Caustic Soda',
#  'Cellphones',
#  'Cement Production',
#  'Central Heating',
#  'Coal Power',
#  'Coal Production',
#  'Cobalt Mine Production',
#  'Colour Tv',
#  'Compact Fluorescent Light Bulbs',
#  'Compressed Air Energy Storage',
#  'Computing Growth',
#  'Concentrated Solar Power',
#  'Copper Mining',
#  'Copper Refining',
#  'Crop Harvester',
#  'Crude Oil',
#  'Cyclohexane',
#  'Desalination Capacity',
#  'Dishwashers',
#  'Disk Brakes',
#  'Dtp1 Vaccine',
#  'Dtp3 Vaccine',
#  'Ebook Reader',
#  'Electric Bicycles',
#  'Electric Range',
#  'Electricity',
#  'Electro-Chemical Capacitor',
#  'Electronic Ignition',
#  'Ethanolamine',
#  'Ethyl Alcohol',
#  'Ethylene',
#  'Ethylene Glycol',
#  'Flow Battery Storage',
#  'Fluid Catalytic Cracking Refineries',
#  'Flush Toilet',
#  'Flywheel Battery Storage',
#  'Formaldehyde',
#  'Freezer',
#  'Geothermal Energy',
#  'Gold Production',
#  'Graphite Mine Production',
#  'Ground Source Heat Pumps',
#  'Heat Thermal Battery Storage',
#  'Hepb3 Vaccine',
#  'Hepbb Vaccine',
#  'Herbicide-Tolerant Corn',
#  'Herbicide-Tolerant Cotton',
#  'Herbicide-Tolerant Soybeans',
#  'Hib3 Vaccine',
#  'High-Density Polyethylene',
#  'High-Speed Rail',
#  'Home Air Conditioning',
#  'Home Computers',
#  'Household Internet Access',
#  'Households With Only Mobile Phones (No Landlines)',
#  'Hydrochloric Acid',
#  'Hydroelectricity',
#  'Hydrofluoric Acid',
#  'Hydrogen Storage',
#  'Insect-Resistant Corn',
#  'Insect-Resistant Cotton',
#  'Internet Backbone Bandwidth',
#  'Internet Traffic',
#  'Ipv1 Vaccine',
#  'Iron',
#  'Iron Ore',
#  'Jet Aircraft',
#  'Latent Heat Storage',
#  'Laundry Dryers',
#  'Lead Mine Production',
#  'Lead-Acid Battery Storage',
#  'Liquefied Natural Gas',
#  'Liquid Biofuels',
#  'Lithium Mine Production',
#  'Lithium-Ion Battery Storage',
#  'Low-Density Polyethylene',
#  'Magnesium',
#  'Magnetic Data Storage',
#  'Maleic Anhydride',
#  'Marine Energy',
#  'Mcv1 Vaccine',
#  'Mcv2 Vaccine',
#  'Methanol',
#  'Microcomputers',
#  'Microprocessor Clock Speed',
#  'Microwaves',
#  'Milk Production',
#  'Motor Gasoline',
#  'Motorcycles',
#  'Natural Gas Pipeline',
#  'Natural Gas Power',
#  'Natural Gas Production',
#  'Neoprene Rubber',
#  'Nickel Production',
#  'Nickel-Based Battery',
#  'Nitric Acid',
#  'Nitrogen Fertilizer',
#  'Nox Pollution Controls (Boilers)',
#  'Nuclear Energy',
#  'Nuclear Weapons',
#  'Offshore Wind Energy',
#  'Oil Pipeline',
#  'Oil Production',
#  'Oil Refining Capacity',
#  'Onshore Wind Energy',
#  'Paraxylene',
#  'Passenger Cars',
#  'Pcv3 Vaccine',
#  'Pentaerythritol',
#  'Phenol',
#  'Phosphate Fertilizer',
#  'Phthalic Anhydride',
#  'Podcasting',
#  'Pol3 Vaccine',
#  'Polyester Fiber',
#  'Polystyrene',
#  'Polyvinylchloride',
#  'Postal Traffic',
#  'Potash Fertilizer',
#  'Power Steering',
#  'Primary Aluminum Production',
#  'Primary Bauxite Production',
#  'Primary Copper Production',
#  'Primary Magnesium',
#  'Processor Performance',
#  'Public Roads',
#  'Pumped Hydro Storage',
#  'Radial Tires',
#  'Radio',
#  'Railroad',
#  'Random Access Memory',
#  'Rare Earth Mine Production',
#  'Raw Steel Production',
#  'Rcv1 Vaccine',
#  'Real-Time Gross Settlement Adoption',
#  'Refrigerators',
#  'Renewable Power',
#  'Rotac Vaccine',
#  'Running Water',
#  'Salt Production',
#  'Sand And Gravel Production (Construction)',
#  'Sand And Gravel Production (Industrial)',
#  'Sensible Heat Storage',
#  'Shale Production',
#  'Shotgun Sanger Dna Sequencing',
#  'Silver',
#  'Smartphone Usage',
#  'Social Media Usage',
#  'Sodium',
#  'Sodium Chlorate',
#  'Sodium-Based Battery Storage',
#  'Solar Photovoltaic',
#  'Solar Thermal Energy',
#  'Solid Biofuels',
#  'Space Launches',
#  'Stationary Steam Engines',
#  'Steam Locomotives',
#  'Steam Ships',
#  'Stove',
#  'Styrene',
#  'Submarine Cables',
#  'Sulphuric Acid',
#  'Synthetic Filaments',
#  'Tablet',
#  'Telegraph Traffic',
#  'Telephones',
#  'Television',
#  'Tin',
#  'Titanium Sponge',
#  'Transistors Per Microprocessor',
#  'Urea',
#  'Vacuums',
#  'Videocassette Recorder',
#  'Vinyl Acetate',
#  'Vinyl Chloride',
#  'Washing Machines',
#  'Water Heater',
#  'Wet Flue Gas Desulfurization Systems',
#  'Yfv Vaccine',
#  'Zinc',
#  'Zinc-Based Battery']

# %%
len(tech_list)
# Out:
# 203

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)
# Out:
# Bcg Vaccine
# Hydrogen Storage
# Silver
# Steam Ships
# Tin
# Yfv Vaccine

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
tech_country_dict
# Out:
# {'Acrylic Fiber': ['World'],
#  'Acrylonitrile': ['World'],
#  'Air-Source Heat Pumps': ['United States'],
#  'All Biofuels': ['China',
#   'Indonesia',
#   'United Kingdom',
#   'Colombia',
#   'Sweden',
#   'Netherlands',
#   'Brazil',
#   'Poland',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Belgium',
#   'South Korea',
#   'Italy',
#   'Argentina',
#   'Mexico',
#   'Portugal',
#   'Thailand',
#   'Canada',
#   'France',
#   'India',
#   'US',
#   'Spain',
#   'Finland'],
#  'Amazon Prime Users': ['United States'],
#  'Ammonia Synthesis': ['Canada',
#   'France',
#   'Germany',
#   'Belgium',
#   'Japan',
#   'World',
#   'Italy',
#   'USA',
#   'Poland',
#   'USSR',
#   'Czechoslovakia',
#   'Sweden',
#   'Netherlands'],
#  'Aniline': ['World'],
#  'Aquaculture Production': ['Denmark',
#   'Burundi',
#   'North Macedonia',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Turks and Caicos Islands',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Turkiye',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Northern Mariana Islands',
#   'Costa Rica',
#   'French Polynesia',
#   'Portugal',
#   'Cameroon',
#   'Hong Kong SAR, China',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Korea, Rep.',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   'Saudi Arabia',
#   'Guam',
#   'Togo',
#   'St. Vincent and the Grenadines',
#   'Belize',
#   'Indonesia',
#   'Vietnam',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'Aruba',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Ghana',
#   'Micronesia, Fed. Sts.',
#   "Korea, Dem. People's Rep.",
#   'Syrian Arab Republic',
#   'Bangladesh',
#   'Mali',
#   'Tuvalu',
#   'Switzerland',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Faroe Islands',
#   'Japan',
#   'Italy',
#   'Mauritius',
#   'Barbados',
#   'World',
#   'Russian Federation',
#   'Nicaragua',
#   'Samoa',
#   'Tunisia',
#   'Tanzania',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Bahamas, The',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Venezuela, RB',
#   'West Bank and Gaza',
#   'China',
#   'Lebanon',
#   'Moldova',
#   'New Caledonia',
#   'Curacao',
#   'Sudan',
#   'Congo, Dem. Rep.',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Lao PDR',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Belarus',
#   'Bhutan',
#   'Iceland',
#   'Lithuania',
#   'British Virgin Islands',
#   'Grenada',
#   'Poland',
#   'Yemen, Rep.',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Congo, Rep.',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Puerto Rico',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Tajikistan',
#   'Zambia',
#   'Bahrain',
#   'Timor-Leste',
#   'Egypt, Arab Rep.',
#   'Iran, Islamic Rep.',
#   'Kenya',
#   'New Zealand',
#   'Gambia, The',
#   'Nigeria',
#   'Mozambique',
#   'Libya',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'St. Lucia',
#   'Kyrgyz Republic',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Virgin Islands (U.S.)',
#   'Madagascar',
#   'Morocco',
#   'Slovak Republic',
#   'Turkmenistan',
#   'St. Kitts and Nevis',
#   'American Samoa',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Serbia',
#   'Dominican Republic',
#   'Nauru',
#   'Bolivia'],
#  'Automatic Transmission': ['United States'],
#  'Bcg Vaccine': ['Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Yemen',
#   'Venezuela (Bolivarian Republic of)',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Micronesia (Federated States of)',
#   'Equatorial Guinea',
#   'Austria',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Viet Nam',
#   'Comoros',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Mauritius',
#   'Türkiye',
#   'Democratic Republic of the Congo',
#   'Russian Federation',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Monaco',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Sweden',
#   'Guinea-Bissau',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Lithuania',
#   'Poland',
#   'Malaysia',
#   'Tonga',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Marshall Islands',
#   'Eritrea',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Egypt',
#   'Tajikistan',
#   'Zambia',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Libya',
#   'Republic of Korea',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Djibouti',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Congo',
#   'Dominican Republic',
#   'Nauru'],
#  'Beer Production': ['Denmark',
#   'Burundi',
#   'Bulgaria',
#   'Colombia',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Australia',
#   'Austria',
#   'Singapore',
#   'Costa Rica',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Georgia',
#   'Angola',
#   'Vietnam',
#   'Indonesia',
#   'Ecuador',
#   'Hungary',
#   'Ghana',
#   'Korea',
#   'Switzerland',
#   'Panama',
#   'Southern Vietnam',
#   'Armenia',
#   'Brazil',
#   'Czechoslovakia',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Nicaragua',
#   'Tanzania',
#   'Guatemala',
#   'Spain',
#   'Zaire',
#   'Latvia',
#   'Ireland',
#   'Thailand',
#   'Finland',
#   'Ethiopia',
#   'South Africa',
#   'China',
#   'Moldova',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'Paraguay',
#   'Netherlands',
#   'Uruguay',
#   'Turkey',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Poland',
#   'Germany',
#   'Kyrgistan',
#   'Malaysia',
#   'Belgium',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Jamaica',
#   'Venezuela',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Zambia',
#   'Egypt',
#   'Tajikistan',
#   'Kenya',
#   'New Zealand',
#   'Nigeria',
#   'Mozambique',
#   'USA',
#   'Kazakhstan',
#   'UK',
#   'East Germany',
#   'Zimbabwe',
#   'Morocco',
#   'Turkmenistan',
#   'West Germany',
#   'Czech Republic',
#   'Ukraine',
#   'Peru',
#   'Russia',
#   'Rwanda',
#   'Uzbekistan',
#   'Serbia',
#   'Ivory Coast',
#   'Congo',
#   'Dominican Republic',
#   'Macedonia',
#   'Bolivia',
#   'Yugoslavia'],
#  'Benzene': ['World'],
#  'Bicycles': ['World'],
#  'Biogas': ['Denmark',
#   'Bulgaria',
#   'Colombia',
#   'Bosnia and Herzegovina',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Australia',
#   'Réunion',
#   'Austria',
#   'Luxembourg',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Israel',
#   'Honduras',
#   'India',
#   'Martinique',
#   'Indonesia',
#   'Sri Lanka',
#   'Ecuador',
#   'Hungary',
#   'Viet Nam',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'United Arab Emirates',
#   'Philippines',
#   'Faroe Islands',
#   'Japan',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Samoa',
#   'Chinese Taipei',
#   'Guatemala',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Thailand',
#   'South Africa',
#   'China',
#   'Lebanon',
#   'Republic of Moldova',
#   'Greece',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Sweden',
#   'Uruguay',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Iceland',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Puerto Rico',
#   'Canada',
#   'France',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Egypt',
#   'Kenya',
#   'New Zealand',
#   'Republic of North Macedonia',
#   'State of Palestine',
#   'Republic of Korea',
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Cyprus',
#   'Qatar',
#   'Bolivia (Plurinational State of)',
#   'Morocco',
#   'Iran (Islamic Republic of)',
#   'United States of America',
#   'Guadeloupe',
#   'Ukraine',
#   'Peru',
#   'Serbia'],
#  'Bisphenol A': ['World'],
#  'Cable Tv': ['United States'],
#  'Cadmium Refining': ['South Africa',
#   'China',
#   'Bulgaria',
#   'United Kingdom',
#   'Congo (Kinshasa)',
#   'Netherlands',
#   'United States',
#   'Norway',
#   'U.S.S.R.',
#   'Kazakhstan',
#   'Turkey',
#   'Brazil',
#   'Poland',
#   'Yugoslavia',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Belgium',
#   'Japan',
#   'Italy',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'World',
#   'Korea, Republic of',
#   'Ukraine',
#   'Peru',
#   'Canada',
#   'France',
#   'Thailand',
#   'Algeria',
#   'Russia',
#   'Namibia',
#   'India',
#   'Korea, North',
#   'Spain',
#   'Macedonia',
#   'Finland',
#   'Serbia and Montenegro'],
#  'Canals': ['United States'],
#  'Cane Sugar Production': ['Ethiopia',
#   'South Africa',
#   'Vietnam',
#   'Mozambique',
#   'China',
#   'Indonesia',
#   'USA',
#   'Swaziland',
#   'Iran',
#   'Sudan',
#   'Taiwan',
#   'Bangladesh',
#   'El Salvador',
#   'Turkey',
#   'Trinidad & Tobago',
#   'Panama',
#   'Cuba',
#   'Zimbabwe',
#   'Pakistan',
#   'Madagascar',
#   'Morocco',
#   'Philippines',
#   'Japan',
#   'Haiti',
#   'Mauritius',
#   'Barbados',
#   'Costa Rica',
#   'Jamaica',
#   'Mexico',
#   'Nicaragua',
#   'Tanzania',
#   'Malawi',
#   'Honduras',
#   'Guatemala',
#   'India',
#   'Egypt',
#   'Ivory Coast',
#   'Dominican Republic',
#   'Spain',
#   'Kenya',
#   'Myanmar',
#   'Thailand'],
#  'Caprolactam': ['World'],
#  'Capture Fisheries Production': ['Denmark',
#   'Burundi',
#   'North Macedonia',
#   'Fiji',
#   'Liechtenstein',
#   'Bulgaria',
#   'Macao SAR, China',
#   'Botswana',
#   'St. Martin (French part)',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Norway',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Sint Maarten (Dutch part)',
#   'Brunei Darussalam',
#   'Guinea',
#   'Turks and Caicos Islands',
#   'Greenland',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Turkiye',
#   'Luxembourg',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Northern Mariana Islands',
#   'Costa Rica',
#   'French Polynesia',
#   'Bermuda',
#   'Portugal',
#   'Cameroon',
#   'Hong Kong SAR, China',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Korea, Rep.',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   'Saudi Arabia',
#   'Guam',
#   'Togo',
#   'St. Vincent and the Grenadines',
#   'Belize',
#   'Indonesia',
#   'Vietnam',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'Aruba',
#   'San Marino',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Comoros',
#   'Ghana',
#   'Micronesia, Fed. Sts.',
#   "Korea, Dem. People's Rep.",
#   'Syrian Arab Republic',
#   'Bangladesh',
#   'Mali',
#   'Tuvalu',
#   'Switzerland',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Faroe Islands',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Cayman Islands',
#   'Mauritius',
#   'Barbados',
#   'World',
#   'Russian Federation',
#   'Nicaragua',
#   'Samoa',
#   'Tunisia',
#   'Tanzania',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Bahamas, The',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Venezuela, RB',
#   'West Bank and Gaza',
#   'China',
#   'Lebanon',
#   'Moldova',
#   'New Caledonia',
#   'Curacao',
#   'Monaco',
#   'Sudan',
#   'Congo, Dem. Rep.',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Lao PDR',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Iceland',
#   'Lithuania',
#   'British Virgin Islands',
#   'Grenada',
#   'Poland',
#   'Yemen, Rep.',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Congo, Rep.',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Puerto Rico',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Tajikistan',
#   'Zambia',
#   'Bahrain',
#   'Timor-Leste',
#   'Egypt, Arab Rep.',
#   'Sao Tome and Principe',
#   'Iran, Islamic Rep.',
#   'Kenya',
#   'New Zealand',
#   'Gambia, The',
#   'Nigeria',
#   'Mozambique',
#   'Libya',
#   'Gibraltar',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Palau',
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'St. Lucia',
#   'Kyrgyz Republic',
#   'Djibouti',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Virgin Islands (U.S.)',
#   'Mongolia',
#   'Madagascar',
#   'Morocco',
#   'Slovak Republic',
#   'Turkmenistan',
#   'Isle of Man',
#   'St. Kitts and Nevis',
#   'American Samoa',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Serbia',
#   'Dominican Republic',
#   'Nauru',
#   'Bolivia'],
#  'Carbon Capture & Sequestration': ['World'],
#  'Caustic Soda': ['Canada',
#   'Algeria',
#   'South Korea',
#   'China',
#   'Japan',
#   'India',
#   'Turkey',
#   'Egypt',
#   'United States of America',
#   'Brazil',
#   'Argentina',
#   'Mexico',
#   'Pakistan',
#   'Australia',
#   'Israel'],
#  'Cellphones': ['Denmark',
#   'Burundi',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Central African Republic',
#   'Yemen',
#   'Syria',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Guinea',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'South Korea',
#   'Luxembourg',
#   'Cambodia',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Saudi Arabia',
#   'Angola',
#   'Togo',
#   'Vietnam',
#   'Belize',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Chad',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Ghana',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Laos',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Democratic Republic of the Congo',
#   'World',
#   'Tunisia',
#   'Nicaragua',
#   'Tanzania',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Iraq',
#   'Lesotho',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Moldova',
#   'Lebanon',
#   'Bosnia-Herzegovina',
#   'Swaziland',
#   'Iran',
#   'Sudan',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'United States',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Paraguay',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Turkey',
#   'Mauritania',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Gambia',
#   'Poland',
#   'Iceland',
#   'Burma',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Venezuela',
#   'Eritrea',
#   'France',
#   'Canada',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Zambia',
#   'Egypt',
#   'Tajikistan',
#   'Hong Kong',
#   'Kenya',
#   'New Zealand',
#   'Nigeria',
#   'Mozambique',
#   'Libya',
#   'Republic of the Congo',
#   'Kazakhstan',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Madagascar',
#   'Slovak Republic',
#   'Morocco',
#   'Turkmenistan',
#   'Czech Republic',
#   'Ukraine',
#   'Peru',
#   'Russia',
#   'Rwanda',
#   'Uzbekistan',
#   'Ivory Coast',
#   'Dominican Republic',
#   'Macedonia',
#   'Bolivia'],
#  'Cement Production': ['United States', 'World'],
#  'Central Heating': ['United States'],
#  'Coal Power': ['World'],
#  'Coal Production': ['South Africa',
#   'Vietnam',
#   'China',
#   'Bulgaria',
#   'Indonesia',
#   'United Kingdom',
#   'Colombia',
#   'Greece',
#   'Hungary',
#   'USSR',
#   'Asia',
#   'Kazakhstan',
#   'Turkey',
#   'Brazil',
#   'Poland',
#   'Zimbabwe',
#   'Rest of World',
#   'Pakistan',
#   'Australia',
#   'Mongolia',
#   'Germany',
#   'South Korea',
#   'Japan',
#   'Czech Republic',
#   'Romania',
#   'Russian Federation',
#   'Mexico',
#   'World',
#   'Europe',
#   'Venezuela',
#   'Ukraine',
#   'Canada',
#   'India',
#   'US',
#   'North America',
#   'Uzbekistan',
#   'Serbia',
#   'Spain',
#   'Thailand',
#   'New Zealand'],
#  'Cobalt Mine Production': ['Canada',
#   'Madagascar',
#   'Morocco',
#   'South Africa',
#   'Philippines',
#   'China',
#   'New Caledonia',
#   'World',
#   'Papua New Guinea',
#   'Zambia',
#   'Cuba',
#   'Democratic Republic of Congo',
#   'Russian Federation',
#   'Australia'],
#  'Colour Tv': ['United States'],
#  'Compact Fluorescent Light Bulbs': ['World'],
#  'Compressed Air Energy Storage': ['Germany',
#   'Canada',
#   'China',
#   'United Kingdom',
#   'Switzerland',
#   'Netherlands',
#   'United States'],
#  'Computing Growth': ['World'],
#  'Concentrated Solar Power': ['World'],
#  'Copper Mining': ['South Africa',
#   'Vietnam',
#   'China',
#   'Bulgaria',
#   'Indonesia',
#   'Botswana',
#   'Mozambique',
#   'United Kingdom',
#   'Colombia',
#   'Ecuador',
#   'Iran',
#   'Congo (Kinshasa)',
#   'Oman',
#   'Sweden',
#   'United States',
#   'Norway',
#   'U.S.S.R.',
#   'Kazakhstan',
#   'Papua New Guinea',
#   'Turkey',
#   'Cyprus',
#   'Chile',
#   'Cuba',
#   'Laos',
#   'Mauritania',
#   'Armenia',
#   'Slovakia',
#   'Brazil',
#   'Poland',
#   'Czechoslovakia',
#   'Yugoslavia',
#   'Zimbabwe',
#   'Pakistan',
#   'Burma',
#   'Australia',
#   'Mongolia',
#   'Germany',
#   'Malaysia',
#   'Morocco',
#   'Philippines',
#   'Nepal',
#   'Japan',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Serbia and Montenegro',
#   'Portugal',
#   'Korea, Republic of',
#   'World',
#   'Tanzania',
#   'Peru',
#   'Canada',
#   'France',
#   'Russia',
#   'Honduras',
#   'Albania',
#   'Namibia',
#   'India',
#   'Zambia',
#   'Uzbekistan',
#   'Serbia',
#   'Korea, North',
#   'Dominican Republic',
#   'Georgia',
#   'Macedonia',
#   'Spain',
#   'Bolivia',
#   'Finland',
#   'Saudi Arabia'],
#  'Copper Refining': ['South Africa',
#   'Vietnam',
#   'China',
#   'Bulgaria',
#   'Indonesia',
#   'United Kingdom',
#   'Iran',
#   'Congo (Kinshasa)',
#   'Oman',
#   'Hungary',
#   'Sweden',
#   'United States',
#   'Taiwan',
#   'Norway',
#   'U.S.S.R.',
#   'Kazakhstan',
#   'Turkey',
#   'Cyprus',
#   'Chile',
#   'Laos',
#   'Slovakia',
#   'Brazil',
#   'Poland',
#   'Czechoslovakia',
#   'Yugoslavia',
#   'Zimbabwe',
#   'Burma',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Mongolia',
#   'Belgium',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Czech Republic',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'World',
#   'Portugal',
#   'Korea, Republic of',
#   'Ukraine',
#   'Peru',
#   'Canada',
#   'France',
#   'Thailand',
#   'Russia',
#   'Albania',
#   'India',
#   'Egypt',
#   'Zambia',
#   'Uzbekistan',
#   'Serbia',
#   'Korea, North',
#   'Spain',
#   'Finland',
#   'Serbia and Montenegro'],
#  'Crop Harvester': ['Denmark',
#   'Burundi',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Central African Republic',
#   'Yemen',
#   'Syria',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Guinea',
#   'Australia',
#   'Austria',
#   'South Korea',
#   'Cambodia',
#   'Uganda',
#   'Costa Rica',
#   'Portugal',
#   'Israel',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Saudi Arabia',
#   'Vietnam',
#   'Belize',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Chad',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Ghana',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Czechoslovakia',
#   'Pakistan',
#   'Suriname',
#   'United Arab Emirates',
#   'Senegal',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Tunisia',
#   'Albania',
#   'Guatemala',
#   'Iraq',
#   'Lesotho',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Thailand',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Moldova',
#   'Lebanon',
#   'Bosnia-Herzegovina',
#   'Iran',
#   'Sudan',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'United States',
#   'Netherlands',
#   'Uruguay',
#   'Papua New Guinea',
#   'Turkey',
#   'Mauritania',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Gambia',
#   'Poland',
#   'Iceland',
#   'Burma',
#   'Germany',
#   'Belgium',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Venezuela',
#   'Eritrea',
#   'France',
#   'Canada',
#   'Algeria',
#   'Azerbaijan',
#   'Zambia',
#   'Egypt',
#   'Tajikistan',
#   'Kenya',
#   'New Zealand',
#   'Libya',
#   'Republic of the Congo',
#   'Kazakhstan',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Madagascar',
#   'Slovak Republic',
#   'Morocco',
#   'Turkmenistan',
#   'Czech Republic',
#   'Ukraine',
#   'Russia',
#   'Uzbekistan',
#   'Ivory Coast',
#   'Macedonia',
#   'Bolivia'],
#  'Crude Oil': ['Nigeria',
#   'China',
#   'Indonesia',
#   'Colombia',
#   'USA',
#   'Libya',
#   'Ecuador',
#   'Iran',
#   'Republic of the Congo',
#   'Oman',
#   'Democratic Republic of Congo',
#   'Hungary',
#   'Netherlands',
#   'Taiwan',
#   'Syria',
#   'Norway',
#   'Saudi Arabia',
#   'Turkey',
#   'Trinidad & Tobago',
#   'UK',
#   'Chile',
#   'Cuba',
#   'Qatar',
#   'Brazil',
#   'Poland',
#   'Yugoslavia',
#   'Pakistan',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Morocco',
#   'Kuwait',
#   'Philippines',
#   'Japan',
#   'West Germany',
#   'Italy',
#   'Brunei',
#   'Romania',
#   'World',
#   'Argentina',
#   'Tunisia',
#   'Mexico',
#   'Venezuela',
#   'Cameroon',
#   'Thailand',
#   'Canada',
#   'Peru',
#   'Israel',
#   'Russia',
#   'Algeria',
#   'Gabon',
#   'India',
#   'Egypt',
#   'Bahrain',
#   'Iraq',
#   'Ivory Coast',
#   'Myanmar',
#   'Bolivia',
#   'UAE',
#   'New Zealand',
#   'Angola'],
#  'Cyclohexane': ['World'],
#  'Desalination Capacity': ['World'],
#  'Dishwashers': ['United States'],
#  'Disk Brakes': ['United States'],
#  'Dtp1 Vaccine': ['Denmark',
#   'Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Yemen',
#   'Norway',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Micronesia (Federated States of)',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Luxembourg',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'San Marino',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Viet Nam',
#   'Comoros',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Barbados',
#   'Democratic Republic of the Congo',
#   'Russian Federation',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Lebanon',
#   'Monaco',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Guinea-Bissau',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Iceland',
#   'Lithuania',
#   'Grenada',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Egypt',
#   'Tajikistan',
#   'Bahrain',
#   'Zambia',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Kenya',
#   'New Zealand',
#   'Bahamas',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Libya',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Djibouti',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Congo',
#   'Dominican Republic',
#   'Nauru'],
#  'Dtp3 Vaccine': ['Denmark',
#   'Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Yemen',
#   'Norway',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Micronesia (Federated States of)',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Luxembourg',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'San Marino',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Viet Nam',
#   'Comoros',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Barbados',
#   'Democratic Republic of the Congo',
#   'Russian Federation',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Lebanon',
#   'Monaco',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Guinea-Bissau',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Iceland',
#   'Lithuania',
#   'Grenada',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Egypt',
#   'Tajikistan',
#   'Bahrain',
#   'Zambia',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Kenya',
#   'New Zealand',
#   'Bahamas',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Libya',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Djibouti',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Congo',
#   'Dominican Republic',
#   'Nauru'],
#  'Ebook Reader': ['United States'],
#  'Electric Bicycles': ['World', 'China'],
#  'Electric Range': ['United States'],
#  'Electricity': ['Denmark',
#   'North Macedonia',
#   'Bulgaria',
#   'Colombia',
#   'Norway',
#   'Trinidad & Tobago',
#   'Chile',
#   'Australia',
#   'Austria',
#   'Luxembourg',
#   'South Korea',
#   'Singapore',
#   'Portugal',
#   'Israel',
#   'India',
#   'US',
#   'Saudi Arabia',
#   'Vietnam',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Bangladesh',
#   'Switzerland',
#   'Slovakia',
#   'Brazil',
#   'Pakistan',
#   'Kuwait',
#   'United Arab Emirates',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Russian Federation',
#   'World',
#   'China Hong Kong SAR',
#   'Iraq',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Thailand',
#   'South Africa',
#   'China',
#   'Iran',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Turkey',
#   'Belarus',
#   'Lithuania',
#   'Iceland',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Venezuela',
#   'Canada',
#   'France',
#   'Algeria',
#   'Azerbaijan',
#   'Egypt',
#   'New Zealand',
#   'Taiwan',
#   'Kazakhstan',
#   'Cyprus',
#   'Qatar',
#   'Morocco',
#   'Turkmenistan',
#   'Czech Republic',
#   'Ukraine',
#   'Peru',
#   'Uzbekistan'],
#  'Electro-Chemical Capacitor': ['South Korea',
#   'China',
#   'Italy',
#   'Spain',
#   'Ireland',
#   'United States'],
#  'Electronic Ignition': ['United States'],
#  'Ethanolamine': ['World'],
#  'Ethyl Alcohol': ['World'],
#  'Ethylene': ['World'],
#  'Ethylene Glycol': ['World'],
#  'Flow Battery Storage': ['Denmark',
#   'Antigua and Barbuda',
#   'South Africa',
#   'Indonesia',
#   'China',
#   'United Kingdom',
#   'Slovenia',
#   'Netherlands',
#   'United States',
#   'Kazakhstan',
#   'Switzerland',
#   'Australia',
#   'Austria',
#   'Germany',
#   'South Korea',
#   'Japan',
#   'Italy',
#   'Czech Republic',
#   'French Polynesia',
#   'Portugal',
#   'Israel',
#   'Canada',
#   'Russia',
#   'India',
#   'New Zealand'],
#  'Fluid Catalytic Cracking Refineries': ['US', 'World'],
#  'Flush Toilet': ['United States'],
#  'Flywheel Battery Storage': ['Germany',
#   'France',
#   'Canada',
#   'Kenya',
#   'South Korea',
#   'United Kingdom',
#   'Antarctica',
#   'Czech Republic',
#   'Netherlands',
#   'Romania',
#   'Spain',
#   'Mexico',
#   'Ireland',
#   'United States',
#   'Australia'],
#  'Formaldehyde': ['World'],
#  'Freezer': ['United States'],
#  'Geothermal Energy': ['Ethiopia',
#   'China',
#   'Indonesia',
#   'Hungary',
#   'Croatia',
#   'El Salvador',
#   'Chile',
#   'Iceland',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Türkiye',
#   'United States of America',
#   'Guadeloupe',
#   'Costa Rica',
#   'Romania',
#   'World',
#   'Argentina',
#   'Mexico',
#   'Nicaragua',
#   'Portugal',
#   'Russian Federation',
#   'Chinese Taipei',
#   'France',
#   'Honduras',
#   'Guatemala',
#   'Kenya',
#   'Thailand',
#   'New Zealand'],
#  'Gold Production': ['Ghana',
#   'Korea',
#   'Phillipines',
#   'South Africa',
#   'South Korea',
#   'China',
#   'Fiji',
#   'Japan',
#   'India',
#   'Papua New Guinea',
#   'New Zealand',
#   'Zaire',
#   'World',
#   'Zimbabwe',
#   'United States',
#   'Australia'],
#  'Graphite Mine Production': ['Canada',
#   'Madagascar',
#   'China',
#   'Mozambique',
#   'India',
#   'Sri Lanka',
#   'Turkey',
#   'World',
#   'Brazil',
#   'Russian Federation',
#   'Mexico',
#   'Ukraine',
#   'Norway'],
#  'Ground Source Heat Pumps': ['World'],
#  'Heat Thermal Battery Storage': ['France',
#   'Morocco',
#   'Germany',
#   'South Africa',
#   'China',
#   'India',
#   'United Kingdom',
#   'Chile',
#   'Spain',
#   'United States',
#   'Australia'],
#  'Hepb3 Vaccine': ['Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Yemen',
#   'Norway',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Micronesia (Federated States of)',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Luxembourg',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'San Marino',
#   'Ecuador',
#   'Oman',
#   'Liberia',
#   'Viet Nam',
#   'Comoros',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Barbados',
#   'Democratic Republic of the Congo',
#   'Russian Federation',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Niger',
#   'Thailand',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Lebanon',
#   'Monaco',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Guinea-Bissau',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Lithuania',
#   'Poland',
#   'Grenada',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Egypt',
#   'Tajikistan',
#   'Bahrain',
#   'Zambia',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Kenya',
#   'New Zealand',
#   'Bahamas',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Libya',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Djibouti',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Congo',
#   'Dominican Republic',
#   'Nauru'],
#  'Hepbb Vaccine': ['Fiji',
#   'Bulgaria',
#   'Colombia',
#   'Maldives',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Brunei Darussalam',
#   'Micronesia (Federated States of)',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Singapore',
#   'Costa Rica',
#   'Portugal',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Belize',
#   'Indonesia',
#   'Ecuador',
#   'Oman',
#   'Viet Nam',
#   'Tuvalu',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'Philippines',
#   'Türkiye',
#   'Tunisia',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Latvia',
#   'Thailand',
#   'Antigua and Barbuda',
#   'Kyrgyzstan',
#   'China',
#   'Lebanon',
#   'Republic of Moldova',
#   'Solomon Islands',
#   'Croatia',
#   'United States',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Lithuania',
#   'Poland',
#   'Grenada',
#   'Malaysia',
#   'Tonga',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Marshall Islands',
#   'Algeria',
#   'Azerbaijan',
#   'Egypt',
#   'Tajikistan',
#   'Bahrain',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'State of Palestine',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Kazakhstan',
#   'Djibouti',
#   'Qatar',
#   'Mongolia',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Dominican Republic',
#   'Nauru'],
#  'Herbicide-Tolerant Corn': ['United States'],
#  'Herbicide-Tolerant Cotton': ['United States'],
#  'Herbicide-Tolerant Soybeans': ['United States'],
#  'Hib3 Vaccine': ['Denmark',
#   'Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Yemen',
#   'Norway',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Micronesia (Federated States of)',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Luxembourg',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'San Marino',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Viet Nam',
#   'Comoros',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Barbados',
#   'Democratic Republic of the Congo',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'Lebanon',
#   'Monaco',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Guinea-Bissau',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Iceland',
#   'Lithuania',
#   'Grenada',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Egypt',
#   'Tajikistan',
#   'Bahrain',
#   'Zambia',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Kenya',
#   'New Zealand',
#   'Bahamas',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Libya',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Djibouti',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Congo',
#   'Dominican Republic',
#   'Nauru'],
#  'High-Density Polyethylene': ['World'],
#  'High-Speed Rail': ['World'],
#  'Home Air Conditioning': ['United States'],
#  'Home Computers': ['United States'],
#  'Household Internet Access': ['United States'],
#  'Households With Only Mobile Phones (No Landlines)': ['United States'],
#  'Hydrochloric Acid': ['Canada',
#   'Algeria',
#   'Phillipines',
#   'South Africa',
#   'South Korea',
#   'China',
#   'Indonesia',
#   'Japan',
#   'India',
#   'Egypt',
#   'United States of America',
#   'Iran',
#   'Australia'],
#  'Hydroelectricity': ['Denmark',
#   'North Macedonia',
#   'Bulgaria',
#   'Colombia',
#   'USSR',
#   'Norway',
#   'Trinidad & Tobago',
#   'Chile',
#   'Australia',
#   'Austria',
#   'Luxembourg',
#   'South Korea',
#   'Singapore',
#   'Portugal',
#   'Israel',
#   'India',
#   'US',
#   'Saudi Arabia',
#   'Vietnam',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Bangladesh',
#   'Switzerland',
#   'Slovakia',
#   'Brazil',
#   'Pakistan',
#   'Kuwait',
#   'United Arab Emirates',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Russian Federation',
#   'World',
#   'China Hong Kong SAR',
#   'Iraq',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Thailand',
#   'South Africa',
#   'China',
#   'Iran',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Turkey',
#   'Belarus',
#   'Lithuania',
#   'Iceland',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Venezuela',
#   'Canada',
#   'France',
#   'Algeria',
#   'Azerbaijan',
#   'Egypt',
#   'New Zealand',
#   'Taiwan',
#   'Kazakhstan',
#   'Cyprus',
#   'Qatar',
#   'Morocco',
#   'Turkmenistan',
#   'Czech Republic',
#   'Ukraine',
#   'Peru',
#   'Uzbekistan'],
#  'Hydrofluoric Acid': ['World'],
#  'Hydrogen Storage': ['Denmark',
#   'Germany',
#   'France',
#   'Canada',
#   'Italy',
#   'Thailand'],
#  'Insect-Resistant Corn': ['United States'],
#  'Insect-Resistant Cotton': ['United States'],
#  'Internet Backbone Bandwidth': ['World'],
#  'Internet Traffic': ['World'],
#  'Ipv1 Vaccine': ['Denmark',
#   'Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Maldives',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Yemen',
#   'Norway',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Brunei Darussalam',
#   'Guinea',
#   'Micronesia (Federated States of)',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'Luxembourg',
#   'Niue',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Myanmar',
#   'Angola',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'United Kingdom',
#   'San Marino',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Viet Nam',
#   'Comoros',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'South Sudan',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Barbados',
#   'Democratic Republic of the Congo',
#   'Russian Federation',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'Saint Lucia',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Latvia',
#   'Seychelles',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Antigua and Barbuda',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Lebanon',
#   'Monaco',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Guinea-Bissau',
#   'Sweden',
#   'United States',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Iceland',
#   'Lithuania',
#   'Grenada',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Marshall Islands',
#   'Eritrea',
#   'Canada',
#   'France',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Gabon',
#   'Egypt',
#   'Tajikistan',
#   'Bahrain',
#   'Zambia',
#   'Timor-Leste',
#   'Sao Tome and Principe',
#   'Kenya',
#   'New Zealand',
#   'Bahamas',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Libya',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   "Cote d'Ivoire",
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Djibouti',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Morocco',
#   'Turkmenistan',
#   'Iran (Islamic Republic of)',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Congo',
#   'Dominican Republic',
#   'Nauru'],
#  'Iron': ['United States'],
#  'Iron Ore': ['South Africa',
#   'Nigeria',
#   'China',
#   'Bulgaria',
#   'Indonesia',
#   'United Kingdom',
#   'Vietnam',
#   'Colombia',
#   'Iran',
#   'Greece',
#   'Liberia',
#   'Sweden',
#   'Bosnia and Herzegovina',
#   'United States',
#   'Norway',
#   'U.S.S.R.',
#   'Kazakhstan',
#   'Turkey',
#   'Chile',
#   'Cuba',
#   'Mauritania',
#   'Slovakia',
#   'Brazil',
#   'Poland',
#   'Czechoslovakia',
#   'Yugoslavia',
#   'Zimbabwe',
#   'Pakistan',
#   'Australia',
#   'Mongolia',
#   'Austria',
#   'Germany',
#   'Malaysia',
#   'Morocco',
#   'Japan',
#   'Uganda',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Tunisia',
#   'Portugal',
#   'Korea, Republic of',
#   'World',
#   'Tanzania',
#   'Ukraine',
#   'Peru',
#   'Canada',
#   'France',
#   'Venezuela',
#   'Algeria',
#   'Russia',
#   'Albania',
#   'Azerbaijan',
#   'Guatemala',
#   'India',
#   'Egypt',
#   'Korea, North',
#   'Spain',
#   'Macedonia',
#   'Kenya',
#   'Bolivia',
#   'Thailand',
#   'New Zealand',
#   'Serbia and Montenegro'],
#  'Jet Aircraft': ['Boeing'],
#  'Latent Heat Storage': ['Canada',
#   'United Kingdom',
#   'Ireland',
#   'United States'],
#  'Laundry Dryers': ['US', 'World'],
#  'Lead Mine Production': ['South Africa',
#   'Nigeria',
#   'China',
#   'Bulgaria',
#   'Vietnam',
#   'United Kingdom',
#   'Colombia',
#   'Ecuador',
#   'Iran',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Bosnia and Herzegovina',
#   'United States',
#   'Norway',
#   'U.S.S.R.',
#   'Kazakhstan',
#   'Turkey',
#   'Chile',
#   'Slovakia',
#   'Brazil',
#   'Poland',
#   'Czechoslovakia',
#   'Yugoslavia',
#   'Greenland',
#   'Burma',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Morocco',
#   'Japan',
#   'Italy',
#   'Czech Republic',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Serbia and Montenegro',
#   'Tunisia',
#   'Korea, Republic of',
#   'World',
#   'Peru',
#   'Canada',
#   'France',
#   'Thailand',
#   'Algeria',
#   'Honduras',
#   'Russia',
#   'Namibia',
#   'Guatemala',
#   'India',
#   'Ireland',
#   'Tajikistan',
#   'Uzbekistan',
#   'Serbia',
#   'Korea, North',
#   'Zambia',
#   'Georgia',
#   'Spain',
#   'Macedonia',
#   'Kenya',
#   'Bolivia',
#   'Finland',
#   'Saudi Arabia'],
#  'Lead-Acid Battery Storage': ['Germany',
#   'Madagascar',
#   'South Africa',
#   'South Korea',
#   'Japan',
#   'Cape Verde',
#   'India',
#   'United Kingdom',
#   'New Zealand',
#   'Antarctica',
#   'Spain',
#   'Brazil',
#   'Vanuatu',
#   'Kenya',
#   'Ireland',
#   'United States',
#   'Australia',
#   'Taiwan'],
#  'Liquefied Natural Gas': ['Japan', 'United States'],
#  'Liquid Biofuels': ['Denmark',
#   'France',
#   'Germany',
#   'Belgium',
#   'New Caledonia',
#   'Italy',
#   'Türkiye',
#   'Republic of Korea',
#   'United States of America',
#   'Solomon Islands',
#   'Spain',
#   'Brazil',
#   'Poland',
#   'Vanuatu',
#   'Sweden',
#   'Slovenia',
#   'Netherlands',
#   'Austria'],
#  'Lithium Mine Production': ['China',
#   'World',
#   'US',
#   'Chile',
#   'Brazil',
#   'Argentina',
#   'Zimbabwe',
#   'Portugal',
#   'Australia'],
#  'Lithium-Ion Battery Storage': ['Denmark',
#   'Togo',
#   'Nigeria',
#   'China',
#   'United Kingdom',
#   'Anguilla',
#   'Hungary',
#   'Sweden',
#   'United States',
#   'Taiwan',
#   'Netherlands',
#   'Benin',
#   'Switzerland',
# ...
#  'Sensible Heat Storage': ['United Arab Emirates',
#   'Morocco',
#   'South Africa',
#   'China',
#   'India',
#   'Italy',
#   'Chile',
#   'Spain',
#   'United States',
#   'Israel'],
#  'Shale Production': ['United States'],
#  'Shotgun Sanger Dna Sequencing': ['World'],
#  'Silver': ['South Africa',
#   'Korea',
#   'Australia',
#   'South Korea',
#   'Indonesia',
#   'Namibia',
#   'China',
#   'Japan',
#   'Phillipine',
#   'Zaire',
#   'Myanmar',
#   'New Zealand'],
#  'Smartphone Usage': ['United States'],
#  'Social Media Usage': ['United States'],
#  'Sodium': ['World'],
#  'Sodium Chlorate': ['World'],
#  'Sodium-Based Battery Storage': ['Canada',
#   'France',
#   'United Arab Emirates',
#   'Germany',
#   'South Korea',
#   'China',
#   'Japan',
#   'United Kingdom',
#   'Italy',
#   'Martinique',
#   'Equatorial Guinea',
#   'Maldives',
#   'Greece',
#   'French Guiana',
#   'United States',
#   'Australia'],
#  'Solar Photovoltaic': ['Denmark',
#   'Burundi',
#   'Fiji',
#   'Bulgaria',
#   'Botswana',
#   'Montserrat',
#   'Anguilla',
#   'Colombia',
#   'Bosnia and Herzegovina',
#   'Norway',
#   'Bonaire, Sint Eustatius and Saba',
#   'Venezuela (Bolivarian Republic of)',
#   'Andorra',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Brunei Darussalam',
#   'Guinea',
#   'Turks and Caicos Islands',
#   'Micronesia (Federated States of)',
#   'Australia',
#   'Réunion',
#   'Austria',
#   'Luxembourg',
#   'Niue',
#   'Saint Martin (French Part)',
#   'Cambodia',
#   'Cabo Verde',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'French Polynesia',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Israel',
#   'Honduras',
#   'India',
#   'Martinique',
#   'Curaçao',
#   'Guyana',
#   'French Guiana',
#   'Myanmar',
#   "Lao People's Democratic Republic",
#   'Saint Vincent and the Grenadines',
#   'Guam',
#   'Saudi Arabia',
#   'Togo',
#   'Belize',
#   'Indonesia',
#   'United Kingdom',
#   'Chad',
#   'Sri Lanka',
#   'Aruba',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Viet Nam',
#   'Ghana',
#   'Syrian Arab Republic',
#   'Tuvalu',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Panama',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'Montenegro',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'Philippines',
#   'Faroe Islands',
#   'Japan',
#   'Italy',
#   'Türkiye',
#   'Cayman Islands',
#   'Mauritius',
#   'Barbados',
#   'Russian Federation',
#   'Tunisia',
#   'Nicaragua',
#   'Samoa',
#   'World',
#   'Saint Lucia',
#   'Chinese Taipei',
#   'Albania',
#   'Namibia',
#   'Tokelau',
#   'Guatemala',
#   'Cook Islands',
#   "Democratic People's Republic of Korea",
#   'Iraq',
#   'Lesotho',
#   'Eswatini',
#   'Spain',
#   'Latvia',
#   'Seychelles',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Antigua and Barbuda',
#   'South Africa',
#   'China',
#   'Lebanon',
#   'New Caledonia',
#   'Sudan',
#   'Republic of Moldova',
#   'Greece',
#   'Solomon Islands',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'United States',
#   'Netherlands',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Kiribati',
#   'Cuba',
#   'Mauritania',
#   'Belarus',
#   'Bhutan',
#   'Gambia',
#   'Lithuania',
#   'British Virgin Islands',
#   'Grenada',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Tonga',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Romania',
#   'Puerto Rico',
#   'Marshall Islands',
#   'France',
#   'Canada',
#   'Malawi',
#   'Azerbaijan',
#   'Burkina Faso',
#   'Egypt',
#   'Zambia',
#   'Bahrain',
#   'Kenya',
#   'New Zealand',
#   'Bahamas',
#   'Republic of North Macedonia',
#   'Nigeria',
#   'Mozambique',
#   'State of Palestine',
#   'Republic of Korea',
#   'Palau',
#   'Dominica',
#   'Mayotte',
#   'Czechia',
#   'Kazakhstan',
#   'Malta',
#   'Cyprus',
#   'Qatar',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Bolivia (Plurinational State of)',
#   'Madagascar',
#   'Kosovo',
#   'Morocco',
#   'Saint Barthélemy',
#   'Iran (Islamic Republic of)',
#   'American Samoa',
#   'United States of America',
#   'Guadeloupe',
#   'Vanuatu',
#   'Ukraine',
#   'Peru',
#   'United States Virgin Islands',
#   'Rwanda',
#   'Uzbekistan',
#   'Saint Kitts and Nevis',
#   'Serbia',
#   'Dominican Republic',
#   'Nauru'],
#  'Solar Thermal Energy': ['South Africa',
#   'China',
#   'Republic of Korea',
#   'Chile',
#   'Australia',
#   'Kuwait',
#   'Germany',
#   'Morocco',
#   'United Arab Emirates',
#   'Italy',
#   'Türkiye',
#   'United States of America',
#   'Romania',
#   'Mexico',
#   'Israel',
#   'France',
#   'Algeria',
#   'India',
#   'Egypt',
#   'Spain',
#   'Thailand',
#   'Saudi Arabia'],
#  'Solid Biofuels': ['Denmark',
#   'Fiji',
#   'Bulgaria',
#   'Colombia',
#   'Bosnia and Herzegovina',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Australia',
#   'Réunion',
#   'Austria',
#   'Luxembourg',
#   'Cambodia',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'United Republic of Tanzania',
#   'Portugal',
#   'Honduras',
#   'India',
#   'Martinique',
#   'Guyana',
#   'French Guiana',
#   "Lao People's Democratic Republic",
#   'Angola',
#   'Belize',
#   'Indonesia',
#   'Sri Lanka',
#   'Chad',
#   'Ecuador',
#   'Hungary',
#   'Viet Nam',
#   'Slovakia',
#   'Brazil',
#   'Pakistan',
#   'Senegal',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Mauritius',
#   'Türkiye',
#   'Russian Federation',
#   'Nicaragua',
#   'Samoa',
#   'Chinese Taipei',
#   'Namibia',
#   'Guatemala',
#   'Eswatini',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Thailand',
#   'Ethiopia',
#   'South Africa',
#   'China',
#   'Sudan',
#   'Greece',
#   'Paraguay',
#   'Slovenia',
#   'Croatia',
#   'Netherlands',
#   'Sweden',
#   'Uruguay',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Poland',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Nepal',
#   'Estonia',
#   'Trinidad and Tobago',
#   'Jamaica',
#   'Argentina',
#   'Mexico',
#   'Romania',
#   'Puerto Rico',
#   'Canada',
#   'France',
#   'Malawi',
#   'Egypt',
#   'Zambia',
#   'Kenya',
#   'New Zealand',
#   'Republic of North Macedonia',
#   'Mozambique',
#   'Republic of Korea',
#   'Czechia',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Bolivia (Plurinational State of)',
#   'United States of America',
#   'Guadeloupe',
#   'Ukraine',
#   'Peru',
#   'Rwanda',
#   'Serbia',
#   'Congo',
#   'Dominican Republic'],
#  'Space Launches': ['Denmark',
#   'Bulgaria',
#   'Colombia',
#   'Norway',
#   'Chile',
#   'Jordan',
#   'Australia',
#   'Austria',
#   'South Korea',
#   'Luxembourg',
#   'Singapore',
#   'Costa Rica',
#   'Portugal',
#   'Israel',
#   'India',
#   'Saudi Arabia',
#   'Angola',
#   'Vietnam',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Ecuador',
#   'Hungary',
#   'Ghana',
#   'Bangladesh',
#   'Switzerland',
#   'Laos',
#   'Slovakia',
#   'Armenia',
#   'Brazil',
#   'Pakistan',
#   'United Arab Emirates',
#   'Philippines',
#   'Japan',
#   'Italy',
#   'Mauritius',
#   'World',
#   'Tunisia',
#   'Guatemala',
#   'Spain',
#   'Latvia',
#   'Thailand',
#   'Finland',
#   'Ethiopia',
#   'South Africa',
#   'China',
#   'Moldova',
#   'Monaco',
#   'Iran',
#   'Greece',
#   'Paraguay',
#   'Slovenia',
#   'Sweden',
#   'Netherlands',
#   'United States',
#   'North Korea',
#   'Uruguay',
#   'Turkey',
#   'Papua New Guinea',
#   'Belarus',
#   'Lithuania',
#   'Poland',
#   'Bhutan',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Nepal',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Venezuela',
#   'France',
#   'Canada',
#   'Algeria',
#   'Azerbaijan',
#   'Egypt',
#   'Kenya',
#   'New Zealand',
#   'Nigeria',
#   'Taiwan',
#   'Czechia',
#   'Kazakhstan',
#   'Qatar',
#   'Mongolia',
#   'Morocco',
#   'Turkmenistan',
#   'Ukraine',
#   'Peru',
#   'Russia',
#   'Rwanda',
#   'Bolivia'],
#  'Stationary Steam Engines': ['World'],
#  'Steam Locomotives': ['World'],
#  'Steam Ships': ['Denmark',
#   'United Kingdom',
#   'Greece',
#   'Hungary',
#   'Sweden',
#   'Netherlands',
#   'Norway',
#   'Chile',
#   'Cuba',
#   'Austria',
#   'Germany',
#   'Belgium',
#   'Italy',
#   'Mexico',
#   'France',
#   'Canada',
#   'Russia',
#   'Spain',
#   'Ireland',
#   'Finland'],
#  'Stove': ['United States'],
#  'Styrene': ['World'],
#  'Submarine Cables': ['World'],
#  'Sulphuric Acid': ['Denmark',
#   'Indonesia',
#   'Bulgaria',
#   'China',
#   'United Kingdom',
#   'Colombia',
#   'Iran',
#   'Hungary',
#   'Greece',
#   'Sweden',
#   'Netherlands',
#   'Norway',
#   'Phillipines',
#   'Turkey',
#   'Switzerland',
#   'Chile',
#   'East Germany',
#   'Cuba',
#   'Poland',
#   'Brazil',
#   'Czechoslovakia',
#   'Pakistan',
#   'Australia',
#   'Austria',
#   'Germany',
#   'Morocco',
#   'Finland',
#   'Belgium',
#   'South Korea',
#   'Japan',
#   'Italy',
#   'West Germany',
#   'United States of America',
#   'Romania',
#   'Argentina',
#   'Tunisia',
#   'Mexico',
#   'Portugal',
#   'Venezuela',
#   'Israel',
#   'Peru',
#   'Canada',
#   'France',
#   'Algeria',
#   'Russia',
#   'India',
#   'Egypt',
#   'Zambia',
#   'Zaire',
#   'Ireland',
#   'Thailand',
#   'Yugoslavia'],
#  'Synthetic Filaments': ['South Africa',
#   'China',
#   'Indonesia',
#   'United Kingdom',
#   'Colombia',
#   'Iran',
#   'Sweden',
#   'Netherlands',
#   'Norway',
#   'Phillipines',
#   'Turkey',
#   'Switzerland',
#   'East Germany',
#   'Brazil',
#   'Poland',
#   'Czechoslovakia',
#   'Pakistan',
#   'Australia',
#   'Austria',
#   'Malaysia',
#   'Germany',
#   'Belgium',
#   'South Korea',
#   'Japan',
#   'West Germany',
#   'Italy',
#   'United States of America',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Thailand',
#   'France',
#   'Canada',
#   'Russia',
#   'India',
#   'Egypt',
#   'Spain',
#   'Finland',
#   'Yugoslavia'],
#  'Tablet': ['United States'],
#  'Telegraph Traffic': ['Denmark',
#   'Togo',
#   'South Africa',
#   'Nigeria',
#   'Mozambique',
#   'Lebanon',
#   'China',
#   'United Kingdom',
#   'Sri Lanka',
#   'Indonesia',
#   'Tanzania',
#   'Colombia',
#   'Sudan',
#   'Hungary',
#   'Greece',
#   'Sweden',
#   'United States',
#   'Taiwan',
#   'Syria',
#   'Norway',
#   'Ghana',
#   'Uruguay',
#   'Netherlands',
#   'El Salvador',
#   'Turkey',
#   'Switzerland',
#   'Chile',
#   'Brazil',
#   'Poland',
#   'Zimbabwe',
#   'Czechoslovakia',
#   'Pakistan',
#   'Burma',
#   'Australia',
#   'Austria',
#   'Madagascar',
#   'Germany',
#   'Morocco',
#   'Malaysia',
#   'Belgium',
#   'Philippines',
#   'South Korea',
#   'Japan',
#   'Uganda',
#   'Italy',
#   'Singapore',
#   'Democratic Republic of the Congo',
#   'Romania',
#   'Argentina',
#   'Tunisia',
#   'Mexico',
#   'Portugal',
#   'Venezuela',
#   'Cameroon',
#   'Peru',
#   'France',
#   'Canada',
#   'Thailand',
#   'Algeria',
#   'Russia',
#   'Malawi',
#   'Israel',
#   'India',
#   'South Vietnam',
#   'Zambia',
#   'Egypt',
#   'Guyana',
#   'Serbia',
#   'Ivory Coast',
#   'Iraq',
#   'Spain',
#   'Kenya',
#   'Ireland',
#   'Finland',
#   'New Zealand',
#   'Angola'],
#  'Telephones': ['Denmark',
#   'Burundi',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Central African Republic',
#   'Yemen',
#   'Syria',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Guinea',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'South Korea',
#   'Luxembourg',
#   'Cambodia',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Saudi Arabia',
#   'Angola',
#   'Togo',
#   'Vietnam',
#   'Belize',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Chad',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Ghana',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Laos',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Czechoslovakia',
#   'Pakistan',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Democratic Republic of the Congo',
#   'Tunisia',
#   'Nicaragua',
#   'Tanzania',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Iraq',
#   'Lesotho',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Moldova',
#   'Lebanon',
#   'Bosnia-Herzegovina',
#   'Swaziland',
#   'Iran',
#   'Sudan',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'United States',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Paraguay',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Turkey',
#   'Mauritania',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Gambia',
#   'Poland',
#   'Iceland',
#   'Burma',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Venezuela',
#   'Eritrea',
#   'France',
#   'Canada',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'South Vietnam',
#   'Gabon',
#   'Zambia',
#   'Egypt',
#   'Tajikistan',
#   'Hong Kong',
#   'Kenya',
#   'New Zealand',
#   'Nigeria',
#   'Mozambique',
#   'Libya',
#   'Republic of the Congo',
#   'Taiwan',
#   'Kazakhstan',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Madagascar',
#   'Slovak Republic',
#   'Morocco',
#   'Turkmenistan',
#   'Czech Republic',
#   'Ukraine',
#   'Peru',
#   'Russia',
#   'Rwanda',
#   'Uzbekistan',
#   'Ivory Coast',
#   'Dominican Republic',
#   'Macedonia',
#   'Bolivia'],
#  'Television': ['Denmark',
#   'Burundi',
#   'Bulgaria',
#   'Botswana',
#   'Colombia',
#   'Central African Republic',
#   'Yemen',
#   'Syria',
#   'Norway',
#   'El Salvador',
#   'Chile',
#   'Jordan',
#   'Guinea',
#   'Australia',
#   'Equatorial Guinea',
#   'Austria',
#   'South Korea',
#   'Luxembourg',
#   'Cambodia',
#   'Uganda',
#   'Singapore',
#   'Costa Rica',
#   'Portugal',
#   'Cameroon',
#   'Israel',
#   'Honduras',
#   'India',
#   'Guyana',
#   'Georgia',
#   'Saudi Arabia',
#   'Angola',
#   'Togo',
#   'Vietnam',
#   'Belize',
#   'Indonesia',
#   'United Kingdom',
#   'Sri Lanka',
#   'Chad',
#   'Ecuador',
#   'Oman',
#   'Hungary',
#   'Liberia',
#   'Ghana',
#   'Bangladesh',
#   'Mali',
#   'Switzerland',
#   'Laos',
#   'Panama',
#   'Armenia',
#   'Brazil',
#   'Czechoslovakia',
#   'Pakistan',
#   'Suriname',
#   'Kuwait',
#   'United Arab Emirates',
#   'Senegal',
#   'Philippines',
#   'Japan',
#   'Somalia',
#   'Italy',
#   'Mauritius',
#   'Democratic Republic of the Congo',
#   'Tunisia',
#   'Nicaragua',
#   'Tanzania',
#   'Albania',
#   'Namibia',
#   'Guatemala',
#   'Iraq',
#   'Lesotho',
#   'Latvia',
#   'Spain',
#   'Ireland',
#   'Finland',
#   'Niger',
#   'Thailand',
#   'Ethiopia',
#   'South Africa',
#   'Kyrgyzstan',
#   'China',
#   'Moldova',
#   'Lebanon',
#   'Bosnia-Herzegovina',
#   'Swaziland',
#   'Iran',
#   'Sudan',
#   'Greece',
#   'Sweden',
#   'Slovenia',
#   'Croatia',
#   'United States',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Paraguay',
#   'Uruguay',
#   'Benin',
#   'Papua New Guinea',
#   'Turkey',
#   'Mauritania',
#   'Cuba',
#   'Belarus',
#   'Lithuania',
#   'Gambia',
#   'Poland',
#   'Iceland',
#   'Burma',
#   'Germany',
#   'Malaysia',
#   'Belgium',
#   'Nepal',
#   'Haiti',
#   'Estonia',
#   'Romania',
#   'Argentina',
#   'Mexico',
#   'Afghanistan',
#   'Venezuela',
#   'Eritrea',
#   'France',
#   'Canada',
#   'Malawi',
#   'Algeria',
#   'Azerbaijan',
#   'Burkina Faso',
#   'South Vietnam',
#   'Gabon',
#   'Zambia',
#   'Egypt',
#   'Tajikistan',
#   'Hong Kong',
#   'Kenya',
#   'New Zealand',
#   'Nigeria',
#   'Mozambique',
#   'Libya',
#   'Republic of the Congo',
#   'Taiwan',
#   'Kazakhstan',
#   'Sierra Leone',
#   'Zimbabwe',
#   'Mongolia',
#   'Madagascar',
#   'Slovak Republic',
#   'Morocco',
#   'Turkmenistan',
#   'Czech Republic',
#   'Ukraine',
#   'Peru',
#   'Russia',
#   'Rwanda',
#   'Uzbekistan',
#   'Ivory Coast',
#   'Dominican Republic',
#   'Macedonia',
#   'Bolivia'],
#  'Tin': ['Malaysia',
#   'Nigeria',
#   'Indonesia',
#   'China',
#   'Brazil',
#   'Bolivia',
#   'Thailand',
#   'Australia'],
#  'Titanium Sponge': ['World'],
#  'Transistors Per Microprocessor': ['World'],
#  'Urea': ['World'],
#  'Vacuums': ['United States'],
#  'Videocassette Recorder': ['United States'],
#  'Vinyl Acetate': ['World'],
#  'Vinyl Chloride': ['World'],
#  'Washing Machines': ['US', 'World'],
#  'Water Heater': ['United States'],
#  'Wet Flue Gas Desulfurization Systems': ['Japan',
#   'Germany',
#   'United States',
#   'World'],
#  'Yfv Vaccine': ['Togo',
#   'Nigeria',
#   'Chad',
#   'Colombia',
#   'Ecuador',
#   'Liberia',
#   "Cote d'Ivoire",
#   'Paraguay',
#   'Central African Republic',
#   'Guinea-Bissau',
#   'Ghana',
#   'Venezuela (Bolivarian Republic of)',
#   'Mali',
#   'Benin',
#   'Panama',
#   'Brazil',
#   'Gambia',
#   'Guinea',
#   'Sierra Leone',
#   'Equatorial Guinea',
#   'Suriname',
#   'Bolivia (Plurinational State of)',
#   'Senegal',
#   'Trinidad and Tobago',
#   'Democratic Republic of the Congo',
#   'Argentina',
#   'Cameroon',
#   'Peru',
#   'Burkina Faso',
#   'Gabon',
#   'Guyana',
#   'Congo',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Niger',
#   'Angola'],
#  'Zinc': ['Canada',
#   'Algeria',
#   'Korea',
#   'South Korea',
#   'China',
#   'Japan',
#   'India',
#   'Zambia',
#   'United States of America',
#   'Zaire',
#   'Brazil',
#   'Argentina',
#   'Mexico',
#   'North Korea',
#   'Australia',
#   'Peru'],
#  'Zinc-Based Battery': ['Madagascar', 'United States', 'Indonesia']}

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict
# Out:
# {'Acrylic Fiber': 1,
#  'Acrylonitrile': 1,
#  'Air-Source Heat Pumps': 1,
#  'Amazon Prime Users': 1,
#  'Aniline': 1,
#  'Automatic Transmission': 1,
#  'Benzene': 1,
#  'Bicycles': 1,
#  'Bisphenol A': 1,
#  'Cable Tv': 1,
#  'Canals': 1,
#  'Caprolactam': 1,
#  'Carbon Capture & Sequestration': 1,
#  'Central Heating': 1,
#  'Coal Power': 1,
#  'Colour Tv': 1,
#  'Compact Fluorescent Light Bulbs': 1,
#  'Computing Growth': 1,
#  'Concentrated Solar Power': 1,
#  'Cyclohexane': 1,
#  'Desalination Capacity': 1,
#  'Dishwashers': 1,
#  'Disk Brakes': 1,
#  'Ebook Reader': 1,
#  'Electric Range': 1,
#  'Electronic Ignition': 1,
#  'Ethanolamine': 1,
#  'Ethyl Alcohol': 1,
#  'Ethylene': 1,
#  'Ethylene Glycol': 1,
#  'Flush Toilet': 1,
#  'Formaldehyde': 1,
#  'Freezer': 1,
#  'Ground Source Heat Pumps': 1,
#  'Herbicide-Tolerant Corn': 1,
#  'Herbicide-Tolerant Cotton': 1,
#  'Herbicide-Tolerant Soybeans': 1,
#  'High-Density Polyethylene': 1,
#  'High-Speed Rail': 1,
#  'Home Air Conditioning': 1,
#  'Home Computers': 1,
#  'Household Internet Access': 1,
#  'Households With Only Mobile Phones (No Landlines)': 1,
#  'Hydrofluoric Acid': 1,
#  'Insect-Resistant Corn': 1,
#  'Insect-Resistant Cotton': 1,
#  'Internet Backbone Bandwidth': 1,
#  'Internet Traffic': 1,
#  'Iron': 1,
#  'Jet Aircraft': 1,
#  'Low-Density Polyethylene': 1,
#  'Magnesium': 1,
#  'Magnetic Data Storage': 1,
#  'Maleic Anhydride': 1,
#  'Methanol': 1,
#  'Microcomputers': 1,
#  'Microprocessor Clock Speed': 1,
#  'Microwaves': 1,
#  'Motor Gasoline': 1,
#  'Motorcycles': 1,
#  'Natural Gas Pipeline': 1,
#  'Natural Gas Power': 1,
#  'Neoprene Rubber': 1,
#  'Nox Pollution Controls (Boilers)': 1,
#  'Oil Pipeline': 1,
#  'Paraxylene': 1,
#  'Pentaerythritol': 1,
#  'Phenol': 1,
#  'Phthalic Anhydride': 1,
#  'Podcasting': 1,
#  'Polyester Fiber': 1,
#  'Polystyrene': 1,
#  'Polyvinylchloride': 1,
#  'Power Steering': 1,
#  'Primary Magnesium': 1,
#  'Processor Performance': 1,
#  'Public Roads': 1,
#  'Radial Tires': 1,
#  'Random Access Memory': 1,
#  'Real-Time Gross Settlement Adoption': 1,
#  'Running Water': 1,
#  'Shale Production': 1,
#  'Shotgun Sanger Dna Sequencing': 1,
#  'Smartphone Usage': 1,
#  'Social Media Usage': 1,
#  'Sodium': 1,
#  'Sodium Chlorate': 1,
#  'Stationary Steam Engines': 1,
#  'Steam Locomotives': 1,
#  'Stove': 1,
#  'Styrene': 1,
#  'Submarine Cables': 1,
#  'Tablet': 1,
#  'Titanium Sponge': 1,
#  'Transistors Per Microprocessor': 1,
#  'Urea': 1,
#  'Vacuums': 1,
#  'Videocassette Recorder': 1,
#  'Vinyl Acetate': 1,
#  'Vinyl Chloride': 1,
#  'Water Heater': 1,
#  'Cement Production': 2,
#  'Electric Bicycles': 2,
#  'Fluid Catalytic Cracking Refineries': 2,
#  'Laundry Dryers': 2,
#  'Liquefied Natural Gas': 2,
#  'Primary Copper Production': 2,
#  'Refrigerators': 2,
#  'Sand And Gravel Production (Construction)': 2,
#  'Sand And Gravel Production (Industrial)': 2,
#  'Washing Machines': 2,
#  'Zinc-Based Battery': 3,
#  'Latent Heat Storage': 4,
#  'Nickel-Based Battery': 4,
#  'Wet Flue Gas Desulfurization Systems': 4,
#  'Electro-Chemical Capacitor': 6,
#  'Hydrogen Storage': 6,
#  'Compressed Air Energy Storage': 7,
#  'Nuclear Weapons': 8,
#  'Tin': 8,
#  'Lithium Mine Production': 9,
#  'Nitric Acid': 9,
#  'Rare Earth Mine Production': 9,
#  'Sensible Heat Storage': 10,
#  'Heat Thermal Battery Storage': 11,
#  'Nickel Production': 12,
#  'Silver': 12,
#  'Ammonia Synthesis': 13,
#  'Graphite Mine Production': 13,
#  'Hydrochloric Acid': 13,
#  'Cobalt Mine Production': 14,
#  'Caustic Soda': 15,
#  'Flywheel Battery Storage': 15,
#  'Gold Production': 16,
#  'Sodium-Based Battery Storage': 16,
#  'Zinc': 16,
#  'Lead-Acid Battery Storage': 18,
#  'Liquid Biofuels': 18,
#  'Marine Energy': 19,
#  'Offshore Wind Energy': 19,
#  'Steam Ships': 20,
#  'Solar Thermal Energy': 22,
#  'All Biofuels': 24,
#  'Flow Battery Storage': 25,
#  'Geothermal Energy': 32,
#  'Yfv Vaccine': 36,
#  'Primary Bauxite Production': 37,
#  'Cadmium Refining': 39,
#  'Synthetic Filaments': 39,
#  'Coal Production': 40,
#  'Cane Sugar Production': 42,
#  'Pumped Hydro Storage': 44,
#  'Lithium-Ion Battery Storage': 47,
#  'Oil Production': 51,
#  'Natural Gas Production': 52,
#  'Sulphuric Acid': 52,
#  'Copper Refining': 58,
#  'Primary Aluminum Production': 58,
#  'Crude Oil': 61,
#  'Lead Mine Production': 63,
#  'Iron Ore': 64,
#  'Copper Mining': 69,
#  'Oil Refining Capacity': 75,
#  'Telegraph Traffic': 76,
#  'Electricity': 80,
#  'Postal Traffic': 80,
#  'Hydroelectricity': 81,
#  'Nuclear Energy': 81,
#  'Renewable Power': 81,
#  'Space Launches': 92,
#  'Biogas': 95,
#  'Milk Production': 98,
#  'Beer Production': 102,
#  'Solid Biofuels': 102,
#  'Hepbb Vaccine': 105,
#  'Raw Steel Production': 106,
#  'Crop Harvester': 118,
#  'Rotac Vaccine': 118,
#  'Salt Production': 125,
#  'Railroad': 128,
#  'Cellphones': 153,
#  'Pcv3 Vaccine': 153,
#  'Passenger Cars': 155,
#  'Radio': 155,
#  'Telephones': 155,
#  'Television': 155,
#  'Bcg Vaccine': 168,
#  'Potash Fertilizer': 169,
#  'Nitrogen Fertilizer': 172,
#  'Phosphate Fertilizer': 172,
#  'Rcv1 Vaccine': 173,
#  'Mcv2 Vaccine': 183,
#  'Hepb3 Vaccine': 191,
#  'Hib3 Vaccine': 193,
#  'Solar Photovoltaic': 193,
#  'Dtp1 Vaccine': 195,
#  'Dtp3 Vaccine': 195,
#  'Ipv1 Vaccine': 195,
#  'Mcv1 Vaccine': 195,
#  'Pol3 Vaccine': 195,
#  'Aquaculture Production': 196,
#  'Capture Fisheries Production': 216,
#  'Onshore Wind Energy': 227}

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)
# Out:
# Zinc-Based Battery
# Latent Heat Storage
# Nickel-Based Battery
# Wet Flue Gas Desulfurization Systems
# Electro-Chemical Capacitor
# Hydrogen Storage
# Compressed Air Energy Storage
# Nuclear Weapons
# Tin
# Lithium Mine Production
# Nitric Acid
# Rare Earth Mine Production
# Sensible Heat Storage
# Heat Thermal Battery Storage
# Nickel Production
# Silver
# Ammonia Synthesis
# Graphite Mine Production
# Hydrochloric Acid
# Cobalt Mine Production
# Caustic Soda
# Flywheel Battery Storage
# Gold Production
# Sodium-Based Battery Storage
# Zinc
# Lead-Acid Battery Storage
# Liquid Biofuels
# Marine Energy
# Offshore Wind Energy
# Steam Ships
# Solar Thermal Energy
# All Biofuels
# Flow Battery Storage
# Geothermal Energy
# Yfv Vaccine
# Primary Bauxite Production
# Cadmium Refining
# Synthetic Filaments
# Coal Production
# Cane Sugar Production
# Pumped Hydro Storage
# Lithium-Ion Battery Storage
# Oil Production
# Natural Gas Production
# Sulphuric Acid
# Copper Refining
# Primary Aluminum Production
# Crude Oil
# Lead Mine Production
# Iron Ore
# Copper Mining
# Oil Refining Capacity
# Telegraph Traffic
# Electricity
# Postal Traffic
# Hydroelectricity
# Nuclear Energy
# Renewable Power
# Space Launches
# Biogas
# Milk Production
# Beer Production
# Solid Biofuels
# Hepbb Vaccine
# Raw Steel Production
# Crop Harvester
# Rotac Vaccine
# Salt Production
# Railroad
# Cellphones
# Pcv3 Vaccine
# Passenger Cars
# Radio
# Telephones
# Television
# Bcg Vaccine
# Potash Fertilizer
# Nitrogen Fertilizer
# Phosphate Fertilizer
# Rcv1 Vaccine
# Mcv2 Vaccine
# Hepb3 Vaccine
# Hib3 Vaccine
# Solar Photovoltaic
# Dtp1 Vaccine
# Dtp3 Vaccine
# Ipv1 Vaccine
# Mcv1 Vaccine
# Pol3 Vaccine
# Aquaculture Production
# Capture Fisheries Production
# Onshore Wind Energy

# %%
cost_data = all_tech[(all_tech['Metric']=='Price') | (all_tech['Metric']=='Total Installed Cost') | (all_tech['Metric']=='Levelized Cost of Energy')]
cost_list = list(set(cost_data['Technology Name']))
len(cost_list)
# Out:
# 52

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-1972'

# %%
time_span('Ammonia Synthesis')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1905-2022'

# %%
time_span('Aquaculture Production')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-2020'

# %%
timespan_dict = {}
for tech in tech_list:
    timespan_dict[tech] = time_span(tech)
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_53425/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)

# %%
timespan_dict
# Out:
# {'Acrylic Fiber': '1960-1972',
#  'Acrylonitrile': '1959-1972',
#  'Air-Source Heat Pumps': '2003-2022',
#  'All Biofuels': '1990-2021',
#  'Amazon Prime Users': '2014-2018',
#  'Ammonia Synthesis': '1905-2022',
#  'Aniline': '1961-1972',
#  'Aquaculture Production': '1960-2020',
#  'Automatic Transmission': '1910-1984',
#  'Bcg Vaccine': '1980-2021',
#  'Beer Production': '1750-2007',
#  'Benzene': '1952-1968',
#  'Bicycles': '1861-2007',
#  'Biogas': '2000-2021',
#  'Bisphenol A': '1959-1972',
#  'Cable Tv': '1968-1997',
#  'Cadmium Refining': '1990-2012',
#  'Canals': '1794-1861',
#  'Cane Sugar Production': '1750-2010',
#  'Caprolactam': '1962-1972',
#  'Capture Fisheries Production': '1960-2020',
#  'Carbon Capture & Sequestration': '1971-2019',
#  'Caustic Soda': '1899-2008',
#  'Cellphones': '1975-2010',
#  'Cement Production': '1900-2019',
#  'Central Heating': '1900-1970',
#  'Coal Power': '1908-2000',
#  'Coal Production': '1981-2021',
#  'Cobalt Mine Production': '1995-2021',
#  'Colour Tv': '1966-2005',
#  'Compact Fluorescent Light Bulbs': '1990-2003',
#  'Compressed Air Energy Storage': '1991-2020',
#  'Computing Growth': '1900-1998',
#  'Concentrated Solar Power': '1985-2022',
#  'Copper Mining': '1990-2011',
#  'Copper Refining': '1990-2011',
#  'Crop Harvester': '1961-2001',
#  'Crude Oil': '1860-2021',
#  'Cyclohexane': '1956-1972',
#  'Desalination Capacity': '1960-2020',
#  'Dishwashers': '1922-2011',
#  'Disk Brakes': '1966-1984',
#  'Dtp1 Vaccine': '1980-2021',
#  'Dtp3 Vaccine': '1980-2021',
#  'Ebook Reader': '2009-2018',
#  'Electric Bicycles': '1997-2010',
#  'Electric Range': '1933-1986',
#  'Electricity': '1985-2021',
#  'Electro-Chemical Capacitor': '2012-2016',
#  'Electronic Ignition': '1962-1984',
#  'Ethanolamine': '1955-1972',
#  'Ethyl Alcohol': '1958-1972',
#  'Ethylene': '1953-1968',
#  'Ethylene Glycol': '1960-1972',
#  'Flow Battery Storage': '2000-2018',
#  'Fluid Catalytic Cracking Refineries': '1940-2007',
#  'Flush Toilet': '1860-1989',
#  'Flywheel Battery Storage': '2006-2020',
#  'Formaldehyde': '1962-1972',
#  'Freezer': '1950-2011',
#  'Geothermal Energy': '2000-2021',
#  'Gold Production': '1851-2018',
#  'Graphite Mine Production': '1995-2021',
#  'Ground Source Heat Pumps': '1995-2020',
#  'Heat Thermal Battery Storage': '2007-2017',
#  'Hepb3 Vaccine': '1989-2021',
#  'Hepbb Vaccine': '2000-2021',
#  'Herbicide-Tolerant Corn': '1996-2022',
#  'Herbicide-Tolerant Cotton': '1996-2022',
#  'Herbicide-Tolerant Soybeans': '1996-2022',
#  'Hib3 Vaccine': '1991-2021',
#  'High-Density Polyethylene': '1958-1972',
#  'High-Speed Rail': '1964-2021',
#  'Home Air Conditioning': '1957-2011',
#  'Home Computers': '1992-2016',
#  'Household Internet Access': '1993-2016',
#  'Households With Only Mobile Phones (No Landlines)': '2013-2018',
#  'Hydrochloric Acid': '1929-2003',
#  'Hydroelectricity': '1965-2021',
#  'Hydrofluoric Acid': '1962-1972',
#  'Hydrogen Storage': '2012-2017',
#  'Insect-Resistant Corn': '1996-2022',
#  'Insect-Resistant Cotton': '1996-2022',
#  'Internet Backbone Bandwidth': '1968-2004',
#  'Internet Traffic': '1984-2014',
#  'Ipv1 Vaccine': '2015-2021',
#  'Iron': '1933-1970',
#  'Iron Ore': '1990-2011',
#  'Jet Aircraft': '1958-2007',
#  'Latent Heat Storage': '1991-2017',
#  'Laundry Dryers': '1920-2006',
#  'Lead Mine Production': '1990-2012',
#  'Lead-Acid Battery Storage': '1987-2020',
#  'Liquefied Natural Gas': '1984-2021',
#  'Liquid Biofuels': '2001-2021',
#  'Lithium Mine Production': '1995-2021',
#  'Lithium-Ion Battery Storage': '2008-2021',
#  'Low-Density Polyethylene': '1958-1972',
#  'Magnesium': '1954-1972',
#  'Magnetic Data Storage': '1952-2004',
#  'Maleic Anhydride': '1959-1972',
#  'Marine Energy': '2000-2021',
#  'Mcv1 Vaccine': '1980-2021',
#  'Mcv2 Vaccine': '2000-2021',
#  'Methanol': '1957-1972',
#  'Microcomputers': '1984-2016',
#  'Microprocessor Clock Speed': '1976-2016',
#  'Microwaves': '1975-2017',
#  'Milk Production': '1889-2010',
#  'Motor Gasoline': '1946-1968',
#  'Motorcycles': '1900-2008',
#  'Natural Gas Pipeline': '1960-2021',
#  'Natural Gas Power': '1903-2000',
#  'Natural Gas Production': '1970-2021',
#  'Neoprene Rubber': '1960-1972',
#  'Nickel Production': '1889-2018',
#  'Nickel-Based Battery': '2003-2015',
#  'Nitric Acid': '1929-2003',
#  'Nitrogen Fertilizer': '1961-2020',
#  'Nox Pollution Controls (Boilers)': '1990-2005',
#  'Nuclear Energy': '1965-2021',
#  'Nuclear Weapons': '1945-2010',
#  'Offshore Wind Energy': '2000-2021',
#  'Oil Pipeline': '2001-2021',
#  'Oil Production': '1965-2021',
#  'Oil Refining Capacity': '1965-2021',
#  'Onshore Wind Energy': '1983-2022',
#  'Paraxylene': '1957-1968',
#  'Passenger Cars': '1895-2005',
#  'Pcv3 Vaccine': '2008-2021',
#  'Pentaerythritol': '1952-1972',
#  'Phenol': '1959-1972',
#  'Phosphate Fertilizer': '1961-2020',
#  'Phthalic Anhydride': '1955-1972',
#  'Podcasting': '2006-2015',
#  'Pol3 Vaccine': '1980-2021',
#  'Polyester Fiber': '1960-1972',
#  'Polystyrene': '1943-1968',
#  'Polyvinylchloride': '1946-1968',
#  'Postal Traffic': '1830-2000',
#  'Potash Fertilizer': '1961-2020',
#  'Power Steering': '1951-1984',
#  'Primary Aluminum Production': '1990-2012',
#  'Primary Bauxite Production': '1990-2012',
#  'Primary Copper Production': '1900-2018',
#  'Primary Magnesium': '1929-1968',
#  'Processor Performance': '1971-2002',
#  'Public Roads': '1900-2020',
#  'Pumped Hydro Storage': '1944-2020',
#  'Radial Tires': '1972-1984',
#  'Radio': '1815-2000',
#  'Railroad': '1825-2004',
#  'Random Access Memory': '1949-2004',
#  'Rare Earth Mine Production': '1995-2021',
#  'Raw Steel Production': '1990-2011',
#  'Rcv1 Vaccine': '1980-2021',
#  'Real-Time Gross Settlement Adoption': '1970-2005',
#  'Refrigerators': '1918-2009',
#  'Renewable Power': '1965-2021',
#  'Rotac Vaccine': '2006-2021',
#  'Running Water': '1890-1989',
#  'Salt Production': '1990-2012',
#  'Sand And Gravel Production (Construction)': '1902-2019',
#  'Sand And Gravel Production (Industrial)': '1902-2019',
#  'Sensible Heat Storage': '1982-2018',
#  'Shale Production': '2007-2019',
#  'Shotgun Sanger Dna Sequencing': '2001-2009',
#  'Silver': '1874-2008',
#  'Smartphone Usage': '2011-2019',
#  'Social Media Usage': '2005-2019',
#  'Sodium': '1957-1972',
#  'Sodium Chlorate': '1958-1972',
#  'Sodium-Based Battery Storage': '1999-2019',
#  'Solar Photovoltaic': '2000-2021',
#  'Solar Thermal Energy': '2000-2021',
#  'Solid Biofuels': '2000-2021',
#  'Space Launches': '1957-2022',
#  'Stationary Steam Engines': '1720-1920',
#  'Steam Locomotives': '1830-1920',
#  'Steam Ships': '1814-1998',
#  'Stove': '1900-2011',
#  'Styrene': '1958-1972',
#  'Submarine Cables': '1989-2021',
#  'Sulphuric Acid': '1860-2003',
#  'Synthetic Filaments': '1910-2003',
#  'Tablet': '2010-2017',
#  'Telegraph Traffic': '1830-2000',
#  'Telephones': '1876-2003',
#  'Television': '1946-2002',
#  'Tin': '1910-2003',
#  'Titanium Sponge': '1950-1968',
#  'Transistors Per Microprocessor': '1971-2003',
#  'Urea': '1961-1972',
#  'Vacuums': '1922-1978',
#  'Videocassette Recorder': '1992-2011',
#  'Vinyl Acetate': '1960-1972',
#  'Vinyl Chloride': '1962-1972',
#  'Washing Machines': '1920-2008',
#  'Water Heater': '1933-1986',
#  'Wet Flue Gas Desulfurization Systems': '1972-1999',
#  'Yfv Vaccine': '1997-2021',
#  'Zinc': '1860-2008',
#  'Zinc-Based Battery': '2013-2020'}

# %%
timespan_dict_lower = {}
for item in timespan_dict:
    timespan_dict_lower[item.lower()] = timespan_dict[item]
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air-source heat pumps': '2003-2022',
#  'all biofuels': '1990-2021',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2022',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'biogas': '2000-2021',
#  'bisphenol a': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1990-2012',
#  'canals': '1794-1861',
#  'cane sugar production': '1750-2010',
#  'caprolactam': '1962-1972',
#  'capture fisheries production': '1960-2020',
#  'carbon capture & sequestration': '1971-2019',
#  'caustic soda': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement production': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt mine production': '1995-2021',
#  'colour tv': '1966-2005',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'copper mining': '1990-2011',
#  'copper refining': '1990-2011',
#  'crop harvester': '1961-2001',
#  'crude oil': '1860-2021',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanolamine': '1955-1972',
#  'ethyl alcohol': '1958-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold production': '1851-2018',
#  'graphite mine production': '1995-2021',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1990-2011',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead mine production': '1990-2012',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1995-2021',
#  'lithium-ion battery storage': '2008-2021',
#  'low-density polyethylene': '1958-1972',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwaves': '1975-2017',
#  'milk production': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel production': '1889-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2005',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1990-2012',
#  'primary bauxite production': '1990-2012',
#  'primary copper production': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1995-2021',
#  'raw steel production': '1990-2011',
#  'rcv1 vaccine': '1980-2021',
#  'real-time gross settlement adoption': '1970-2005',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'running water': '1890-1989',
#  'salt production': '1990-2012',
#  'sand and gravel production (construction)': '1902-2019',
#  'sand and gravel production (industrial)': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'space launches': '1957-2022',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steam ships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sulphuric acid': '1860-2003',
#  'synthetic filaments': '1910-2003',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'television': '1946-2002',
#  'tin': '1910-2003',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'urea': '1961-1972',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc-based battery': '2013-2020'}

# %%
timespan_dict_lower = dict(sorted(timespan_dict_lower.items(), key=lambda item: item[0])) 
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air-source heat pumps': '2003-2022',
#  'all biofuels': '1990-2021',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2022',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'biogas': '2000-2021',
#  'bisphenol a': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1990-2012',
#  'canals': '1794-1861',
#  'cane sugar production': '1750-2010',
#  'caprolactam': '1962-1972',
#  'capture fisheries production': '1960-2020',
#  'carbon capture & sequestration': '1971-2019',
#  'caustic soda': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement production': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt mine production': '1995-2021',
#  'colour tv': '1966-2005',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'copper mining': '1990-2011',
#  'copper refining': '1990-2011',
#  'crop harvester': '1961-2001',
#  'crude oil': '1860-2021',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanolamine': '1955-1972',
#  'ethyl alcohol': '1958-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold production': '1851-2018',
#  'graphite mine production': '1995-2021',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1990-2011',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead mine production': '1990-2012',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1995-2021',
#  'lithium-ion battery storage': '2008-2021',
#  'low-density polyethylene': '1958-1972',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwaves': '1975-2017',
#  'milk production': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel production': '1889-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2005',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1990-2012',
#  'primary bauxite production': '1990-2012',
#  'primary copper production': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1995-2021',
#  'raw steel production': '1990-2011',
#  'rcv1 vaccine': '1980-2021',
#  'real-time gross settlement adoption': '1970-2005',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'running water': '1890-1989',
#  'salt production': '1990-2012',
#  'sand and gravel production (construction)': '1902-2019',
#  'sand and gravel production (industrial)': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'space launches': '1957-2022',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steam ships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sulphuric acid': '1860-2003',
#  'synthetic filaments': '1910-2003',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'television': '1946-2002',
#  'tin': '1910-2003',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'urea': '1961-1972',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc-based battery': '2013-2020'}

# %%
for item in timespan_dict_lower:
    print(timespan_dict_lower[item])
# Out:
# 1960-1972
# 1959-1972
# 2003-2022
# 1990-2021
# 2014-2018
# 1905-2022
# 1961-1972
# 1960-2020
# 1910-1984
# 1980-2021
# 1750-2007
# 1952-1968
# 1861-2007
# 2000-2021
# 1959-1972
# 1968-1997
# 1990-2012
# 1794-1861
# 1750-2010
# 1962-1972
# 1960-2020
# 1971-2019
# 1899-2008
# 1975-2010
# 1900-2019
# 1900-1970
# 1908-2000
# 1981-2021
# 1995-2021
# 1966-2005
# 1990-2003
# 1991-2020
# 1900-1998
# 1985-2022
# 1990-2011
# 1990-2011
# 1961-2001
# 1860-2021
# 1956-1972
# 1960-2020
# 1922-2011
# 1966-1984
# 1980-2021
# 1980-2021
# 2009-2018
# 1997-2010
# 1933-1986
# 1985-2021
# 2012-2016
# 1962-1984
# 1955-1972
# 1958-1972
# 1953-1968
# 1960-1972
# 2000-2018
# 1940-2007
# 1860-1989
# 2006-2020
# 1962-1972
# 1950-2011
# 2000-2021
# 1851-2018
# 1995-2021
# 1995-2020
# 2007-2017
# 1989-2021
# 2000-2021
# 1996-2022
# 1996-2022
# 1996-2022
# 1991-2021
# 1958-1972
# 1964-2021
# 1957-2011
# 1992-2016
# 1993-2016
# 2013-2018
# 1929-2003
# 1965-2021
# 1962-1972
# 2012-2017
# 1996-2022
# 1996-2022
# 1968-2004
# 1984-2014
# 2015-2021
# 1933-1970
# 1990-2011
# 1958-2007
# 1991-2017
# 1920-2006
# 1990-2012
# 1987-2020
# 1984-2021
# 2001-2021
# 1995-2021
# 2008-2021
# 1958-1972
# 1954-1972
# 1952-2004
# 1959-1972
# 2000-2021
# 1980-2021
# 2000-2021
# 1957-1972
# 1984-2016
# 1976-2016
# 1975-2017
# 1889-2010
# 1946-1968
# 1900-2008
# 1960-2021
# 1903-2000
# 1970-2021
# 1960-1972
# 1889-2018
# 2003-2015
# 1929-2003
# 1961-2020
# 1990-2005
# 1965-2021
# 1945-2010
# 2000-2021
# 2001-2021
# 1965-2021
# 1965-2021
# 1983-2022
# 1957-1968
# 1895-2005
# 2008-2021
# 1952-1972
# 1959-1972
# 1961-2020
# 1955-1972
# 2006-2015
# 1980-2021
# 1960-1972
# 1943-1968
# 1946-1968
# 1830-2000
# 1961-2020
# 1951-1984
# 1990-2012
# 1990-2012
# 1900-2018
# 1929-1968
# 1971-2002
# 1900-2020
# 1944-2020
# 1972-1984
# 1815-2000
# 1825-2004
# 1949-2004
# 1995-2021
# 1990-2011
# 1980-2021
# 1970-2005
# 1918-2009
# 1965-2021
# 2006-2021
# 1890-1989
# 1990-2012
# 1902-2019
# 1902-2019
# 1982-2018
# 2007-2019
# 2001-2009
# 1874-2008
# 2011-2019
# 2005-2019
# 1957-1972
# 1958-1972
# 1999-2019
# 2000-2021
# 2000-2021
# 2000-2021
# 1957-2022
# 1720-1920
# 1830-1920
# 1814-1998
# 1900-2011
# 1958-1972
# 1989-2021
# 1860-2003
# 1910-2003
# 2010-2017
# 1830-2000
# 1876-2003
# 1946-2002
# 1910-2003
# 1950-1968
# 1971-2003
# 1961-1972
# 1922-1978
# 1992-2011
# 1960-1972
# 1962-1972
# 1920-2008
# 1933-1986
# 1972-1999
# 1997-2021
# 1860-2008
# 2013-2020

# %%
def metric(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    metric = set(tech_df['Metric'])
    return metric

# %%
metric_dict = {}
for tech in tech_list:
    metric_dict[tech] = metric(tech)
metric_dict
# Out:
# {'Acrylic Fiber': {'Annual Production', 'Price'},
#  'Acrylonitrile': {'Annual Production', 'Price'},
#  'Air-Source Heat Pumps': {'Annual Production'},
#  'All Biofuels': {'Annual Production'},
#  'Amazon Prime Users': {'Share Of Households'},
#  'Ammonia Synthesis': {'Annual Production'},
#  'Aniline': {'Annual Production', 'Price'},
#  'Aquaculture Production': {'Annual Production'},
#  'Automatic Transmission': {'Share Of Market'},
#  'Bcg Vaccine': {'Share Of Population'},
#  'Beer Production': {'Annual Production'},
#  'Benzene': {'Annual Production', 'Price'},
#  'Bicycles': {'Cumulative Total Capacity'},
#  'Biogas': {'Installed Electricity Capacity'},
#  'Bisphenol A': {'Annual Production', 'Price'},
#  'Cable Tv': {'Share Of Households'},
#  'Cadmium Refining': {'Annual Production'},
#  'Canals': {'Total Length'},
#  'Cane Sugar Production': {'Annual Production'},
#  'Caprolactam': {'Annual Production', 'Price'},
#  'Capture Fisheries Production': {'Annual Production'},
#  'Carbon Capture & Sequestration': {'Installed Capacity'},
#  'Caustic Soda': {'Annual Production'},
#  'Cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'Cement Production': {'Annual Production', 'Price'},
#  'Central Heating': {'Share Of Households'},
#  'Coal Power': {'Cumulative Total Capacity'},
#  'Coal Production': {'Annual Production', 'Price'},
#  'Cobalt Mine Production': {'Annual Production'},
#  'Colour Tv': {'Share Of Households'},
#  'Compact Fluorescent Light Bulbs': {'Cumulative Total Capacity'},
#  'Compressed Air Energy Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Computing Growth': {'Computing Capacity'},
#  'Concentrated Solar Power': {'Installed Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Copper Mining': {'Annual Production'},
#  'Copper Refining': {'Annual Production'},
#  'Crop Harvester': {'Total Number'},
#  'Crude Oil': {'Annual Production', 'Price'},
#  'Cyclohexane': {'Annual Production', 'Price'},
#  'Desalination Capacity': {'Total Capacity'},
#  'Dishwashers': {'Share Of Households'},
#  'Disk Brakes': {'Share Of Market'},
#  'Dtp1 Vaccine': {'Share Of Population'},
#  'Dtp3 Vaccine': {'Share Of Population'},
#  'Ebook Reader': {'Share Of Population'},
#  'Electric Bicycles': {'Cumulative Total Capacity'},
#  'Electric Range': {'Share Of Households'},
#  'Electricity': {'Annual Production'},
#  'Electro-Chemical Capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Electronic Ignition': {'Share Of Market'},
#  'Ethanolamine': {'Annual Production', 'Price'},
#  'Ethyl Alcohol': {'Annual Production', 'Price'},
#  'Ethylene': {'Annual Production', 'Price'},
#  'Ethylene Glycol': {'Annual Production', 'Price'},
#  'Flow Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Fluid Catalytic Cracking Refineries': {'Average Capacity Of Unit Additions',
#   'Net Total Capacity'},
#  'Flush Toilet': {'Share Of Households'},
#  'Flywheel Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Formaldehyde': {'Annual Production', 'Price'},
#  'Freezer': {'Share Of Households'},
#  'Geothermal Energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Gold Production': {'Annual Production', 'Price'},
#  'Graphite Mine Production': {'Annual Production'},
#  'Ground Source Heat Pumps': {'Cumulative Total Capacity'},
#  'Heat Thermal Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Hepb3 Vaccine': {'Share Of Population'},
#  'Hepbb Vaccine': {'Share Of Population'},
#  'Herbicide-Tolerant Corn': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Cotton': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Soybeans': {'Cumulative Acreage'},
#  'Hib3 Vaccine': {'Share Of Population'},
#  'High-Density Polyethylene': {'Annual Production', 'Price'},
#  'High-Speed Rail': {'Cumulative Total Capacity'},
#  'Home Air Conditioning': {'Share Of Households'},
#  'Home Computers': {'Share Of Households'},
#  'Household Internet Access': {'Share Of Households'},
#  'Households With Only Mobile Phones (No Landlines)': {'Share Of Households'},
#  'Hydrochloric Acid': {'Annual Production'},
#  'Hydroelectricity': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Hydrofluoric Acid': {'Annual Production', 'Price'},
#  'Hydrogen Storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'Insect-Resistant Corn': {'Cumulative Acreage'},
#  'Insect-Resistant Cotton': {'Cumulative Acreage'},
#  'Internet Backbone Bandwidth': {'Computing Capacity'},
#  'Internet Traffic': {'Computing Capacity'},
#  'Ipv1 Vaccine': {'Share Of Population'},
#  'Iron': {'Share Of Households'},
#  'Iron Ore': {'Annual Production'},
#  'Jet Aircraft': {'Cumulative Total Capacity'},
#  'Latent Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Laundry Dryers': {'Cumulative Total Capacity'},
#  'Lead Mine Production': {'Annual Production'},
#  'Lead-Acid Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Liquefied Natural Gas': {'Annual Production', 'Price'},
#  'Liquid Biofuels': {'Installed Electricity Capacity'},
#  'Lithium Mine Production': {'Annual Production'},
#  'Lithium-Ion Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Low-Density Polyethylene': {'Annual Production', 'Price'},
#  'Magnesium': {'Annual Production', 'Price'},
#  'Magnetic Data Storage': {'Computing Capacity'},
#  'Maleic Anhydride': {'Annual Production', 'Price'},
#  'Marine Energy': {'Installed Electricity Capacity'},
#  'Mcv1 Vaccine': {'Share Of Population'},
#  'Mcv2 Vaccine': {'Share Of Population'},
#  'Methanol': {'Annual Production', 'Price'},
#  'Microcomputers': {'Share Of Households'},
#  'Microprocessor Clock Speed': {'Computing Capacity'},
#  'Microwaves': {'Share Of Households'},
#  'Milk Production': {'Annual Production'},
#  'Motor Gasoline': {'Annual Production', 'Price'},
#  'Motorcycles': {'Cumulative Total Capacity'},
#  'Natural Gas Pipeline': {'Total Length'},
#  'Natural Gas Power': {'Cumulative Total Capacity'},
#  'Natural Gas Production': {'Annual Production', 'Price'},
#  'Neoprene Rubber': {'Annual Production', 'Price'},
#  'Nickel Production': {'Annual Production', 'Price'},
#  'Nickel-Based Battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Nitric Acid': {'Annual Production'},
#  'Nitrogen Fertilizer': {'Annual Production'},
#  'Nox Pollution Controls (Boilers)': {'Share Of Boilers'},
#  'Nuclear Energy': {'Annual Production'},
#  'Nuclear Weapons': {'Number Of Weapons'},
#  'Offshore Wind Energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Oil Pipeline': {'Total Length'},
#  'Oil Production': {'Annual Production'},
#  'Oil Refining Capacity': {'Cumulative Total Capacity'},
#  'Onshore Wind Energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Paraxylene': {'Annual Production', 'Price'},
#  'Passenger Cars': {'Cumulative Total Capacity', 'Total Number'},
#  'Pcv3 Vaccine': {'Share Of Population'},
#  'Pentaerythritol': {'Annual Production', 'Price'},
#  'Phenol': {'Annual Production', 'Price'},
#  'Phosphate Fertilizer': {'Annual Production'},
#  'Phthalic Anhydride': {'Annual Production', 'Price'},
#  'Podcasting': {'Share Of Population'},
#  'Pol3 Vaccine': {'Share Of Population'},
#  'Polyester Fiber': {'Annual Production', 'Price'},
#  'Polystyrene': {'Annual Production', 'Price'},
#  'Polyvinylchloride': {'Annual Production', 'Price'},
#  'Postal Traffic': {'Total Number'},
#  'Potash Fertilizer': {'Annual Production'},
#  'Power Steering': {'Share Of Market'},
#  'Primary Aluminum Production': {'Annual Production'},
#  'Primary Bauxite Production': {'Annual Production'},
#  'Primary Copper Production': {'Annual Production', 'Price'},
#  'Primary Magnesium': {'Annual Production', 'Price'},
#  'Processor Performance': {'Computing Capacity'},
#  'Public Roads': {'Total Length'},
#  'Pumped Hydro Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Radial Tires': {'Share Of Market'},
#  'Radio': {'Total Number'},
#  'Railroad': {'Cumulative Length'},
#  'Random Access Memory': {'Computing Capacity'},
#  'Rare Earth Mine Production': {'Annual Production'},
#  'Raw Steel Production': {'Annual Production'},
#  'Rcv1 Vaccine': {'Share Of Population'},
#  'Real-Time Gross Settlement Adoption': {'Share Of Market'},
#  'Refrigerators': {'Cumulative Total Capacity'},
#  'Renewable Power': {'Annual Production'},
#  'Rotac Vaccine': {'Share Of Population'},
#  'Running Water': {'Share Of Households'},
#  'Salt Production': {'Annual Production'},
#  'Sand And Gravel Production (Construction)': {'Annual Production', 'Price'},
#  'Sand And Gravel Production (Industrial)': {'Annual Production', 'Price'},
#  'Sensible Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Shale Production': {'Annual Production'},
#  'Shotgun Sanger Dna Sequencing': {'Price', 'Total Number'},
#  'Silver': {'Annual Production'},
#  'Smartphone Usage': {'Share Of Population'},
#  'Social Media Usage': {'Share Of Population'},
#  'Sodium': {'Annual Production', 'Price'},
#  'Sodium Chlorate': {'Annual Production', 'Price'},
#  'Sodium-Based Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Solar Photovoltaic': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Solar Thermal Energy': {'Installed Electricity Capacity'},
#  'Solid Biofuels': {'Installed Electricity Capacity'},
#  'Space Launches': {'Yearly Launches'},
#  'Stationary Steam Engines': {'Cumulative Total Capacity'},
#  'Steam Locomotives': {'Cumulative Total Capacity'},
#  'Steam Ships': {'Cumulative Total Capacity'},
#  'Stove': {'Share Of Households'},
#  'Styrene': {'Annual Production', 'Price'},
#  'Submarine Cables': {'Cumulative Length'},
#  'Sulphuric Acid': {'Annual Production'},
#  'Synthetic Filaments': {'Annual Production'},
#  'Tablet': {'Share Of Population'},
#  'Telegraph Traffic': {'Total Number'},
#  'Telephones': {'Total Number'},
#  'Television': {'Total Number'},
#  'Tin': {'Annual Production'},
#  'Titanium Sponge': {'Annual Production', 'Price'},
#  'Transistors Per Microprocessor': {'Computing Capacity'},
#  'Urea': {'Annual Production', 'Price'},
#  'Vacuums': {'Share Of Households'},
#  'Videocassette Recorder': {'Share Of Households'},
#  'Vinyl Acetate': {'Annual Production', 'Price'},
#  'Vinyl Chloride': {'Annual Production', 'Price'},
#  'Washing Machines': {'Cumulative Total Capacity'},
#  'Water Heater': {'Share Of Households'},
#  'Wet Flue Gas Desulfurization Systems': {'Cumulative Total Capacity'},
#  'Yfv Vaccine': {'Share Of Population'},
#  'Zinc': {'Annual Production'},
#  'Zinc-Based Battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = {}
for item in metric_dict:
    metric_dict_lower[item.lower()] = metric_dict[item]
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual Production', 'Price'},
#  'acrylonitrile': {'Annual Production', 'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'all biofuels': {'Annual Production'},
#  'amazon prime users': {'Share Of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual Production', 'Price'},
#  'aquaculture production': {'Annual Production'},
#  'automatic transmission': {'Share Of Market'},
#  'bcg vaccine': {'Share Of Population'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual Production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'biogas': {'Installed Electricity Capacity'},
#  'bisphenol a': {'Annual Production', 'Price'},
#  'cable tv': {'Share Of Households'},
#  'cadmium refining': {'Annual Production'},
#  'canals': {'Total Length'},
#  'cane sugar production': {'Annual Production'},
#  'caprolactam': {'Annual Production', 'Price'},
#  'capture fisheries production': {'Annual Production'},
#  'carbon capture & sequestration': {'Installed Capacity'},
#  'caustic soda': {'Annual Production'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement production': {'Annual Production', 'Price'},
#  'central heating': {'Share Of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt mine production': {'Annual Production'},
#  'colour tv': {'Share Of Households'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'copper mining': {'Annual Production'},
#  'copper refining': {'Annual Production'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Annual Production', 'Price'},
#  'cyclohexane': {'Annual Production', 'Price'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share Of Households'},
#  'disk brakes': {'Share Of Market'},
#  'dtp1 vaccine': {'Share Of Population'},
#  'dtp3 vaccine': {'Share Of Population'},
#  'ebook reader': {'Share Of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share Of Households'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share Of Market'},
#  'ethanolamine': {'Annual Production', 'Price'},
#  'ethyl alcohol': {'Annual Production', 'Price'},
#  'ethylene': {'Annual Production', 'Price'},
#  'ethylene glycol': {'Annual Production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'fluid catalytic cracking refineries': {'Average Capacity Of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share Of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual Production', 'Price'},
#  'freezer': {'Share Of Households'},
#  'geothermal energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'gold production': {'Annual Production', 'Price'},
#  'graphite mine production': {'Annual Production'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'hepb3 vaccine': {'Share Of Population'},
#  'hepbb vaccine': {'Share Of Population'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'hib3 vaccine': {'Share Of Population'},
#  'high-density polyethylene': {'Annual Production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share Of Households'},
#  'home computers': {'Share Of Households'},
#  'household internet access': {'Share Of Households'},
#  'households with only mobile phones (no landlines)': {'Share Of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'hydrofluoric acid': {'Annual Production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'ipv1 vaccine': {'Share Of Population'},
#  'iron': {'Share Of Households'},
#  'iron ore': {'Annual Production'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead mine production': {'Annual Production'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production', 'Price'},
#  'liquid biofuels': {'Installed Electricity Capacity'},
#  'lithium mine production': {'Annual Production'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'low-density polyethylene': {'Annual Production', 'Price'},
#  'magnesium': {'Annual Production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual Production', 'Price'},
#  'marine energy': {'Installed Electricity Capacity'},
#  'mcv1 vaccine': {'Share Of Population'},
#  'mcv2 vaccine': {'Share Of Population'},
#  'methanol': {'Annual Production', 'Price'},
#  'microcomputers': {'Share Of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwaves': {'Share Of Households'},
#  'milk production': {'Annual Production'},
#  'motor gasoline': {'Annual Production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual Production', 'Price'},
#  'nickel production': {'Annual Production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nox pollution controls (boilers)': {'Share Of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Number Of Weapons'},
#  'offshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Cumulative Total Capacity'},
#  'onshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'paraxylene': {'Annual Production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity', 'Total Number'},
#  'pcv3 vaccine': {'Share Of Population'},
#  'pentaerythritol': {'Annual Production', 'Price'},
#  'phenol': {'Annual Production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual Production', 'Price'},
#  'podcasting': {'Share Of Population'},
#  'pol3 vaccine': {'Share Of Population'},
#  'polyester fiber': {'Annual Production', 'Price'},
#  'polystyrene': {'Annual Production', 'Price'},
#  'polyvinylchloride': {'Annual Production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'power steering': {'Share Of Market'},
#  'primary aluminum production': {'Annual Production'},
#  'primary bauxite production': {'Annual Production'},
#  'primary copper production': {'Annual Production', 'Price'},
#  'primary magnesium': {'Annual Production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'radial tires': {'Share Of Market'},
#  'radio': {'Total Number'},
#  'railroad': {'Cumulative Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual Production'},
#  'raw steel production': {'Annual Production'},
#  'rcv1 vaccine': {'Share Of Population'},
#  'real-time gross settlement adoption': {'Share Of Market'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'rotac vaccine': {'Share Of Population'},
#  'running water': {'Share Of Households'},
#  'salt production': {'Annual Production'},
#  'sand and gravel production (construction)': {'Annual Production', 'Price'},
#  'sand and gravel production (industrial)': {'Annual Production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual Production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production'},
#  'smartphone usage': {'Share Of Population'},
#  'social media usage': {'Share Of Population'},
#  'sodium': {'Annual Production', 'Price'},
#  'sodium chlorate': {'Annual Production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'solar photovoltaic': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed Electricity Capacity'},
#  'solid biofuels': {'Installed Electricity Capacity'},
#  'space launches': {'Yearly Launches'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steam ships': {'Cumulative Total Capacity'},
#  'stove': {'Share Of Households'},
#  'styrene': {'Annual Production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filaments': {'Annual Production'},
#  'tablet': {'Share Of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'television': {'Total Number'},
#  'tin': {'Annual Production'},
#  'titanium sponge': {'Annual Production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'urea': {'Annual Production', 'Price'},
#  'vacuums': {'Share Of Households'},
#  'videocassette recorder': {'Share Of Households'},
#  'vinyl acetate': {'Annual Production', 'Price'},
#  'vinyl chloride': {'Annual Production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share Of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share Of Population'},
#  'zinc': {'Annual Production'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = dict(sorted(metric_dict_lower.items(), key=lambda item: item[0])) 
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual Production', 'Price'},
#  'acrylonitrile': {'Annual Production', 'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'all biofuels': {'Annual Production'},
#  'amazon prime users': {'Share Of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual Production', 'Price'},
#  'aquaculture production': {'Annual Production'},
#  'automatic transmission': {'Share Of Market'},
#  'bcg vaccine': {'Share Of Population'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual Production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'biogas': {'Installed Electricity Capacity'},
#  'bisphenol a': {'Annual Production', 'Price'},
#  'cable tv': {'Share Of Households'},
#  'cadmium refining': {'Annual Production'},
#  'canals': {'Total Length'},
#  'cane sugar production': {'Annual Production'},
#  'caprolactam': {'Annual Production', 'Price'},
#  'capture fisheries production': {'Annual Production'},
#  'carbon capture & sequestration': {'Installed Capacity'},
#  'caustic soda': {'Annual Production'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement production': {'Annual Production', 'Price'},
#  'central heating': {'Share Of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt mine production': {'Annual Production'},
#  'colour tv': {'Share Of Households'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'copper mining': {'Annual Production'},
#  'copper refining': {'Annual Production'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Annual Production', 'Price'},
#  'cyclohexane': {'Annual Production', 'Price'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share Of Households'},
#  'disk brakes': {'Share Of Market'},
#  'dtp1 vaccine': {'Share Of Population'},
#  'dtp3 vaccine': {'Share Of Population'},
#  'ebook reader': {'Share Of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share Of Households'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share Of Market'},
#  'ethanolamine': {'Annual Production', 'Price'},
#  'ethyl alcohol': {'Annual Production', 'Price'},
#  'ethylene': {'Annual Production', 'Price'},
#  'ethylene glycol': {'Annual Production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'fluid catalytic cracking refineries': {'Average Capacity Of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share Of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual Production', 'Price'},
#  'freezer': {'Share Of Households'},
#  'geothermal energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'gold production': {'Annual Production', 'Price'},
#  'graphite mine production': {'Annual Production'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'hepb3 vaccine': {'Share Of Population'},
#  'hepbb vaccine': {'Share Of Population'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'hib3 vaccine': {'Share Of Population'},
#  'high-density polyethylene': {'Annual Production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share Of Households'},
#  'home computers': {'Share Of Households'},
#  'household internet access': {'Share Of Households'},
#  'households with only mobile phones (no landlines)': {'Share Of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'hydrofluoric acid': {'Annual Production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'ipv1 vaccine': {'Share Of Population'},
#  'iron': {'Share Of Households'},
#  'iron ore': {'Annual Production'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead mine production': {'Annual Production'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production', 'Price'},
#  'liquid biofuels': {'Installed Electricity Capacity'},
#  'lithium mine production': {'Annual Production'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'low-density polyethylene': {'Annual Production', 'Price'},
#  'magnesium': {'Annual Production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual Production', 'Price'},
#  'marine energy': {'Installed Electricity Capacity'},
#  'mcv1 vaccine': {'Share Of Population'},
#  'mcv2 vaccine': {'Share Of Population'},
#  'methanol': {'Annual Production', 'Price'},
#  'microcomputers': {'Share Of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwaves': {'Share Of Households'},
#  'milk production': {'Annual Production'},
#  'motor gasoline': {'Annual Production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual Production', 'Price'},
#  'nickel production': {'Annual Production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nox pollution controls (boilers)': {'Share Of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Number Of Weapons'},
#  'offshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Cumulative Total Capacity'},
#  'onshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'paraxylene': {'Annual Production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity', 'Total Number'},
#  'pcv3 vaccine': {'Share Of Population'},
#  'pentaerythritol': {'Annual Production', 'Price'},
#  'phenol': {'Annual Production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual Production', 'Price'},
#  'podcasting': {'Share Of Population'},
#  'pol3 vaccine': {'Share Of Population'},
#  'polyester fiber': {'Annual Production', 'Price'},
#  'polystyrene': {'Annual Production', 'Price'},
#  'polyvinylchloride': {'Annual Production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'power steering': {'Share Of Market'},
#  'primary aluminum production': {'Annual Production'},
#  'primary bauxite production': {'Annual Production'},
#  'primary copper production': {'Annual Production', 'Price'},
#  'primary magnesium': {'Annual Production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'radial tires': {'Share Of Market'},
#  'radio': {'Total Number'},
#  'railroad': {'Cumulative Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual Production'},
#  'raw steel production': {'Annual Production'},
#  'rcv1 vaccine': {'Share Of Population'},
#  'real-time gross settlement adoption': {'Share Of Market'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'rotac vaccine': {'Share Of Population'},
#  'running water': {'Share Of Households'},
#  'salt production': {'Annual Production'},
#  'sand and gravel production (construction)': {'Annual Production', 'Price'},
#  'sand and gravel production (industrial)': {'Annual Production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual Production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production'},
#  'smartphone usage': {'Share Of Population'},
#  'social media usage': {'Share Of Population'},
#  'sodium': {'Annual Production', 'Price'},
#  'sodium chlorate': {'Annual Production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'solar photovoltaic': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed Electricity Capacity'},
#  'solid biofuels': {'Installed Electricity Capacity'},
#  'space launches': {'Yearly Launches'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steam ships': {'Cumulative Total Capacity'},
#  'stove': {'Share Of Households'},
#  'styrene': {'Annual Production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filaments': {'Annual Production'},
#  'tablet': {'Share Of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'television': {'Total Number'},
#  'tin': {'Annual Production'},
#  'titanium sponge': {'Annual Production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'urea': {'Annual Production', 'Price'},
#  'vacuums': {'Share Of Households'},
#  'videocassette recorder': {'Share Of Households'},
#  'vinyl acetate': {'Annual Production', 'Price'},
#  'vinyl chloride': {'Annual Production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share Of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share Of Population'},
#  'zinc': {'Annual Production'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
for item in metric_dict_lower:
    print(item)
# Out:
# acrylic fiber
# acrylonitrile
# air-source heat pumps
# all biofuels
# amazon prime users
# ammonia synthesis
# aniline
# aquaculture production
# automatic transmission
# bcg vaccine
# beer production
# benzene
# bicycles
# biogas
# bisphenol a
# cable tv
# cadmium refining
# canals
# cane sugar production
# caprolactam
# capture fisheries production
# carbon capture & sequestration
# caustic soda
# cellphones
# cement production
# central heating
# coal power
# coal production
# cobalt mine production
# colour tv
# compact fluorescent light bulbs
# compressed air energy storage
# computing growth
# concentrated solar power
# copper mining
# copper refining
# crop harvester
# crude oil
# cyclohexane
# desalination capacity
# dishwashers
# disk brakes
# dtp1 vaccine
# dtp3 vaccine
# ebook reader
# electric bicycles
# electric range
# electricity
# electro-chemical capacitor
# electronic ignition
# ethanolamine
# ethyl alcohol
# ethylene
# ethylene glycol
# flow battery storage
# fluid catalytic cracking refineries
# flush toilet
# flywheel battery storage
# formaldehyde
# freezer
# geothermal energy
# gold production
# graphite mine production
# ground source heat pumps
# heat thermal battery storage
# hepb3 vaccine
# hepbb vaccine
# herbicide-tolerant corn
# herbicide-tolerant cotton
# herbicide-tolerant soybeans
# hib3 vaccine
# high-density polyethylene
# high-speed rail
# home air conditioning
# home computers
# household internet access
# households with only mobile phones (no landlines)
# hydrochloric acid
# hydroelectricity
# hydrofluoric acid
# hydrogen storage
# insect-resistant corn
# insect-resistant cotton
# internet backbone bandwidth
# internet traffic
# ipv1 vaccine
# iron
# iron ore
# jet aircraft
# latent heat storage
# laundry dryers
# lead mine production
# lead-acid battery storage
# liquefied natural gas
# liquid biofuels
# lithium mine production
# lithium-ion battery storage
# low-density polyethylene
# magnesium
# magnetic data storage
# maleic anhydride
# marine energy
# mcv1 vaccine
# mcv2 vaccine
# methanol
# microcomputers
# microprocessor clock speed
# microwaves
# milk production
# motor gasoline
# motorcycles
# natural gas pipeline
# natural gas power
# natural gas production
# neoprene rubber
# nickel production
# nickel-based battery
# nitric acid
# nitrogen fertilizer
# nox pollution controls (boilers)
# nuclear energy
# nuclear weapons
# offshore wind energy
# oil pipeline
# oil production
# oil refining capacity
# onshore wind energy
# paraxylene
# passenger cars
# pcv3 vaccine
# pentaerythritol
# phenol
# phosphate fertilizer
# phthalic anhydride
# podcasting
# pol3 vaccine
# polyester fiber
# polystyrene
# polyvinylchloride
# postal traffic
# potash fertilizer
# power steering
# primary aluminum production
# primary bauxite production
# primary copper production
# primary magnesium
# processor performance
# public roads
# pumped hydro storage
# radial tires
# radio
# railroad
# random access memory
# rare earth mine production
# raw steel production
# rcv1 vaccine
# real-time gross settlement adoption
# refrigerators
# renewable power
# rotac vaccine
# running water
# salt production
# sand and gravel production (construction)
# sand and gravel production (industrial)
# sensible heat storage
# shale production
# shotgun sanger dna sequencing
# silver
# smartphone usage
# social media usage
# sodium
# sodium chlorate
# sodium-based battery storage
# solar photovoltaic
# solar thermal energy
# solid biofuels
# space launches
# stationary steam engines
# steam locomotives
# steam ships
# stove
# styrene
# submarine cables
# sulphuric acid
# synthetic filaments
# tablet
# telegraph traffic
# telephones
# television
# tin
# titanium sponge
# transistors per microprocessor
# urea
# vacuums
# videocassette recorder
# vinyl acetate
# vinyl chloride
# washing machines
# water heater
# wet flue gas desulfurization systems
# yfv vaccine
# zinc
# zinc-based battery
