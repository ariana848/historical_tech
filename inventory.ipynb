# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech.csv')
all_tech
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_43176/3737900983.py:1: DtypeWarning: Columns (214,215,217,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_tech = pd.read_csv('all_tech.csv')
#      Spatial Scale Country Code   Country Name              Technology Name  \
# 0         National           TG           Togo  Lithium-ion battery storage
# 1         National           TG           Togo  Lithium-ion battery storage
# 2         National           ZA   South Africa        Sensible heat storage
# 3         National           ZA   South Africa        Sensible heat storage
# 4         National           CA         Canada         Pumped hydro storage
# ...            ...          ...            ...                          ...
# 7498      National           VN        Vietnam         Raw steel production
# 7499      National           YU     Yugoslavia         Raw steel production
# 7500      National           ZW       Zimbabwe         Raw steel production
# 7501        Global        World          World         Raw steel production
# 7502           NaN           US  United States        Liquefied natural gas
#
#                          Metric                Unit  \
# 0     Cumulative Rated Capacity                 kWh
# 1        Cumulative Rated Power                  kW
# 2     Cumulative Rated Capacity                 kWh
# 3        Cumulative Rated Power                  kW
# 4     Cumulative Rated Capacity                 kWh
# ...                         ...                 ...
# 7498          Annual production         Metric tons
# 7499          Annual production         Metric tons
# 7500          Annual production         Metric tons
# 7501          Annual production         Metric tons
# 7502                    Exports  Billion cubic feet
#
#                                  Data Source  1700  1701  1702  ...  \
# 0         DOE Global Energy Storage Database   NaN   NaN   NaN  ...
# 1         DOE Global Energy Storage Database   NaN   NaN   NaN  ...
# 2         DOE Global Energy Storage Database   NaN   NaN   NaN  ...
# 3         DOE Global Energy Storage Database   NaN   NaN   NaN  ...
# 4         DOE Global Energy Storage Database   NaN   NaN   NaN  ...
# ...                                      ...   ...   ...   ...  ...
# 7498                  U.S. Geological Survey   NaN   NaN   NaN  ...
# 7499                  U.S. Geological Survey   NaN   NaN   NaN  ...
# 7500                  U.S. Geological Survey   NaN   NaN   NaN  ...
# 7501                  U.S. Geological Survey   NaN   NaN   NaN  ...
# 7502  U.S. Energy Information Administration   NaN   NaN   NaN  ...
#
#             2017        2018    2019     2020     2021  2022  2023  2024  \
# 0         760.00     1160.00     NaN      NaN      NaN   NaN   NaN   NaN
# 1         190.00      290.00     NaN      NaN      NaN   NaN   NaN   NaN
# 2     1745000.00  2945000.00     NaN      NaN      NaN   NaN   NaN   NaN
# 3      355000.00   455000.00     NaN      NaN      NaN   NaN   NaN   NaN
# 4            NaN         NaN     NaN      NaN      NaN   NaN   NaN   NaN
# ...          ...         ...     ...      ...      ...   ...   ...   ...
# 7498         NaN         NaN     NaN      NaN      NaN   NaN   NaN   NaN
# 7499         NaN         NaN     NaN      NaN      NaN   NaN   NaN   NaN
# 7500         NaN         NaN     NaN      NaN      NaN   NaN   NaN   NaN
# 7501         NaN         NaN     NaN      NaN      NaN   NaN   NaN   NaN
# 7502      707.54     1083.12  1819.4  2389.84  3560.82   NaN   NaN   NaN
#
#       2025  Unnamed: 0
# 0      NaN         NaN
# 1      NaN         NaN
# 2      NaN         NaN
# 3      NaN         NaN
# 4      NaN         NaN
# ...    ...         ...
# 7498   NaN         NaN
# 7499   NaN         NaN
# 7500   NaN         NaN
# 7501   NaN         NaN
# 7502   NaN         NaN
#
# [7503 rows x 334 columns]

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
len(tech_list)
tech_list
# Out:
# ['Acrylic Fiber',
#  'Acrylonitrile',
#  'Amazon Prime users',
#  'Aniline',
#  'Aquaculture production',
#  'Automatic transmission',
#  'BCG Vaccine',
#  'Beer production',
#  'Benzene',
#  'Bicycles',
#  'Biofuels',
#  'Bisphenol A',
#  'CFLs',
#  'Cable TV',
#  'Cadmium Refining',
#  'Caprolactam',
#  'Capture fisheries production',
#  'Cellphones',
#  'Cement production',
#  'Central heating',
#  'Coal Power',
#  'Coal Production',
#  'Cobalt Mine Production',
#  'Colour TV',
#  'Compressed air energy storage',
#  'Computing Growth',
#  'Copper Mining',
#  'Copper Refining',
#  'Crop harvester',
#  'Crude Oil',
#  'Cyclohexane',
#  'DTP1 Vaccine',
#  'DTP3 Vaccine',
#  'Desalination capacity',
#  'Dishwashers',
#  'Disk brakes',
#  'Ebook reader',
#  'Electric Bicycles',
#  'Electric Range',
#  'Electricity',
#  'Electro-chemical capacitor',
#  'Electronic ignition',
#  'Ethanolamine',
#  'Ethyl Alcohol',
#  'Ethylene',
#  'Ethylene Glycol',
#  'FCC-Refineries',
#  'Flow battery storage',
#  'Flush toilet',
#  'Flywheel battery storage',
#  'Formaldehyde',
#  'Freezer',
#  'Gold production',
#  'Graphite Mine Production',
#  'Ground Source Heat Pumps',
#  'HEPB3 Vaccine',
#  'HEPBB Vaccine',
#  'HIB3 Vaccine',
#  'Heat thermal battery storage',
#  'High-speed rail',
#  'Home air conditioning',
#  'Home computers',
#  'Household Internet access',
#  'Households with only mobile phones (no landlines)',
#  'Hydro Power',
#  'Hydroelectricity',
#  'Hydrofluoric Acid',
#  'Hydrogen storage',
#  'IPV1 Vaccine',
#  'Internet Backbone Bandwidth',
#  'Internet Traffic',
#  'Iron',
#  'Iron ore',
#  'Jet Aircraft',
#  'Latent heat storage',
#  'Laundry Dryers',
#  'Lead mine production',
#  'Lead-acid battery storage',
#  'Liquefied natural gas',
#  'Lithium Mine Production',
#  'Lithium-ion battery storage',
#  'MCV1 Vaccine',
#  'MCV2 Vaccine',
#  'Magnesium',
#  'Magnetic Data Storage',
#  'Maleic Anhydride',
#  'Methanol',
#  'Microcomputers',
#  'Microprocessor Clock Speed',
#  'Microwaves',
#  'Milk production',
#  'Motor Gasoline',
#  'Motorcycles',
#  'NatGas Power',
#  'Natural Gas Production',
#  'Natural gas pipeline',
#  'Neoprene Rubber',
#  'Nickel production',
#  'Nickel-based battery',
#  'Nitrogen Fertilizer',
#  'Nox pollution controls (boilers)',
#  'Nuclear Energy',
#  'Nuclear Power',
#  'Nuclear weapons',
#  'Off-Grid Onshore Wind Energy',
#  'Oil Production',
#  'Oil Refining Capacity',
#  'Oil pipeline',
#  'On-Grid Biogas',
#  'On-Grid Coal And Peat',
#  'On-Grid Geothermal Energy',
#  'On-Grid Liquid Biofuels',
#  'On-Grid Marine Energy',
#  'On-Grid Mixed Hydro Plants',
#  'On-Grid Natural Gas',
#  'On-Grid Nuclear',
#  'On-Grid Offshore Wind Energy',
#  'On-Grid Oil',
#  'On-Grid Onshore Wind Energy',
#  'On-Grid Renewable Hydropower',
#  'On-Grid Solar Photovoltaic',
#  'On-Grid Solar Thermal Energy',
#  'On-Grid Solid Biofuels',
#  'PCV3 Vaccine',
#  'POL3 Vaccine',
#  'Paraxylene',
#  'Passenger Cars',
#  'Passenger cars',
#  'Pentaerythritol',
#  'Phenol',
#  'Phosphate Fertilizer',
#  'Phthalic Anhydride',
#  'Podcasting',
#  'Polyester Fiber',
#  'Polyethylene HD',
#  'Polyethylene LD',
#  'Polystyrene',
#  'Polyvinylchloride',
#  'Postal Traffic',
#  'Potash Fertilizer',
#  'Power steering',
#  'Primary Magnesium',
#  'Primary aluminum production',
#  'Primary bauxite production',
#  'Primary copper production',
#  'Processor Performance',
#  'Public roads',
#  'Pumped hydro storage',
#  'RCV1 Vaccine',
#  'ROTAC Vaccine',
#  'RTGS adoption',
#  'Radial tires',
#  'Radio',
#  'Railroad',
#  'Random Access Memory',
#  'Rare Earth Mine Production',
#  'Raw steel production',
#  'Refined Cane Sugar Production',
#  'Refrigerators',
#  'Renewable Power',
#  'Running water',
#  'Salt production',
#  'Sand and gravel production (construction)',
#  'Sand and gravel production (industrial)',
#  'Sensible heat storage',
#  'Shale production',
#  'Shipping container port infrastructure',
#  'Shotgun Sanger DNA Sequencing',
#  'Smartphone usage',
#  'Social media usage',
#  'Sodium',
#  'Sodium Chlorate',
#  'Sodium-based battery storage',
#  'Stationary Steam Engines',
#  'Steam Locomotives',
#  'Steam ships',
#  'Steamships',
#  'Stove',
#  'Styrene',
#  'Tablet',
#  'Telegraph Traffic',
#  'Telephones',
#  'Television',
#  'Titanium Sponge',
#  'Transistors per Microprocessor',
#  'Urea',
#  'Vacuums',
#  'Videocassette recorder',
#  'Vinyl Acetate',
#  'Vinyl Chloride',
#  'Washing Machines',
#  'Water Heater',
#  'Wet flue gas desulfurization systems',
#  'Wind Power',
#  'YFV Vaccine',
#  'Zinc-based battery']

# %%
len(tech_list)
# Out:
# 196

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    if len(countries) > 2:
        tech_country_dict[tech] = len(countries)
    else:
        tech_country_dict[tech] = countries

# %%
for val in tech_country_dict:
    if type(tech_country_dict[val]) != int:
        print(val, tech_country_dict[val])

# %%
multi_list = []
for val in tech_country_dict:
    if type(tech_country_dict[val]) == int:
        multi_list.append(val)
len(multi_list)

# %%
cost_data = all_tech[all_tech['Metric']=='Price']
for x in list(set(cost_data['Technology Name'])):
    print(x)
