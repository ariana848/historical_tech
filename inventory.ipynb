# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 2.0.csv')
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8741   Raw steel production_Annual production_not found      National
# 8742                  Space Launches_Yearly Launches_UA      National
# 8743                  Space Launches_Yearly Launches_TM      National
# 8744         Liquefied natural gas_Annual Production_US      National
# 8745                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 8741    not found          World         Raw Steel Production
# 8742           UA        Ukraine               Space Launches
# 8743           TM   Turkmenistan               Space Launches
# 8744           US  United States        Liquefied Natural Gas
# 8745           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0        Cumulative Rated Power                                     kW
# 1     Cumulative Rated Capacity                                    kWh
# 2        Cumulative Rated Power                                     kW
# 3     Cumulative Rated Capacity                                    kWh
# 4      Levelized Cost Of Energy                           2021 USD/kWh
# ...                         ...                                    ...
# 8741          Annual Production                            Metric tons
# 8742            Yearly Launches  Number of objects launched into space
# 8743            Yearly Launches  Number of objects launched into space
# 8744          Annual Production                     Billion cubic feet
# 8745            Yearly Launches  Number of objects launched into space
#
#      Data Source                               Long Technology Name  1700  \
# 0          GESDB  Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN
# 1          GESDB  Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN
# 2          GESDB       Cumulative Rated Power|Sensible Heat Storage   NaN
# 3          GESDB    Cumulative Rated Capacity|Sensible Heat Storage   NaN
# 4          IRENA       Levelized Cost of Energy|Onshore Wind Energy   NaN
# ...          ...                                                ...   ...
# 8741        USGS             Annual production|Raw Steel Production   NaN
# 8742      UNOOSA                     Yearly Launches|Space Launches   NaN
# 8743      UNOOSA                     Yearly Launches|Space Launches   NaN
# 8744         EIA            Annual Production|Liquefied Natural Gas   NaN
# 8745      UNOOSA                     Yearly Launches|Space Launches   NaN
#
#       ...          2016          2017          2018         2019         2020  \
# 0     ...           NaN  1.900000e+02  2.900000e+02          NaN          NaN
# 1     ...           NaN  7.600000e+02  1.160000e+03          NaN          NaN
# 2     ...  2.550000e+05  3.550000e+05  4.550000e+05          NaN          NaN
# 3     ...  1.195000e+06  1.745000e+06  2.945000e+06          NaN          NaN
# 4     ...  5.542823e-02  4.578779e-02  4.374012e-02     0.045337     0.039979
# ...   ...           ...           ...           ...          ...          ...
# 8741  ...           NaN           NaN           NaN          NaN          NaN
# 8742  ...           NaN           NaN           NaN          NaN          NaN
# 8743  ...           NaN           NaN           NaN          NaN          NaN
# 8744  ...  1.868400e+02  7.075400e+02  1.083120e+03  1819.400000  2389.840000
# 8745  ...           NaN           NaN  1.000000e+00          NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 8741      NaN   NaN   NaN   NaN   NaN
# 8742      NaN   1.0   NaN   NaN   NaN
# 8743      NaN   NaN   NaN   NaN   NaN
# 8744  3560.82   NaN   NaN   NaN   NaN
# 8745      NaN   NaN   NaN   NaN   NaN
#
# [8746 rows x 335 columns]

# %%
source_dict = {}
for source in sorted(list(set(all_tech['Data Source']))):
    tech_list = list(set(all_tech[all_tech['Data Source']==source]['Technology Name']))
    source_dict[source] = tech_list
for source in source_dict['USGS']:
    print(source)
# Out:
# Rare Earth Mine Production
# Primary Copper Production
# Primary Aluminum Production
# Sand And Gravel Production (Industrial)
# Silver
# Iron Ore
# Lead Mine Production
# Graphite Mine Production
# Copper Mining
# Raw Steel Production
# Zinc
# Copper Refining
# Cadmium Refining
# Tin
# Lithium Mine Production
# Primary Bauxite Production
# Salt Production
# Cement Production
# Nickel Production
# Sand And Gravel Production (Construction)
# Gold Production

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
for x in tech_list:
    print(x)
# Out:
# Acrylic Fiber
# Acrylonitrile
# Air Conditioning Machines
# Air-Source Heat Pumps
# All Biofuels
# Amazon Prime Users
# Ammonia Synthesis
# Aniline
# Aquaculture Production
# Automatic Transmission
# Bcg Vaccine
# Beer
# Beer Production
# Benzene
# Bicycles
# Bicycles And Other Cycles
# Biogas
# Bisphenol A
# Cable Tv
# Cadmium Refining
# Canals
# Cane Sugar Production
# Caprolactam
# Capture Fisheries Production
# Carbon Capture & Sequestration
# Caustic Soda
# Cellphones
# Cement Production
# Central Heating
# Coal Power
# Coal Production
# Cobalt Mine Production
# Colour Tv
# Combined Refrigerators-Freezers
# Compact Fluorescent Light Bulbs
# Compressed Air Energy Storage
# Computing Growth
# Concentrated Solar Power
# Copper Mining
# Copper Refining
# Corn Production
# Cotton Seed Production
# Cow'S Milk Production
# Crop Harvester
# Crude Oil
# Cyclohexane
# Desalination Capacity
# Dishwashers
# Disk Brakes
# Dtp1 Vaccine
# Dtp3 Vaccine
# Ebook Reader
# Electric Bicycles
# Electric Range
# Electric Water Heaters And Immersion Heaters
# Electricity
# Electro-Chemical Capacitor
# Electronic Ignition
# Ethanolamine
# Ethyl Alcohol
# Ethylene
# Ethylene Glycol
# Flow Battery Storage
# Fluid Catalytic Cracking Refineries
# Flush Toilet
# Flywheel Battery Storage
# Formaldehyde
# Freezer
# Geothermal Energy
# Gold Production
# Graphite Mine Production
# Ground Source Heat Pumps
# Heat Thermal Battery Storage
# Hepb3 Vaccine
# Hepbb Vaccine
# Herbicide-Tolerant Corn
# Herbicide-Tolerant Cotton
# Herbicide-Tolerant Soybeans
# Hib3 Vaccine
# High-Density Polyethylene
# High-Speed Rail
# Home Air Conditioning
# Home Computers
# Household Internet Access
# Household Refrigerators And Freezers
# Household Washing And Drying Machines
# Households With Only Mobile Phones (No Landlines)
# Hydrochloric Acid
# Hydroelectricity
# Hydrofluoric Acid
# Hydrogen Storage
# Insect-Resistant Corn
# Insect-Resistant Cotton
# Internet Backbone Bandwidth
# Internet Traffic
# Ipv1 Vaccine
# Iron
# Iron Ore
# Jet Aircraft
# Latent Heat Storage
# Laundry Dryers
# Lead Mine Production
# Lead-Acid Battery Storage
# Liquefied Natural Gas
# Liquid Biofuels
# Lithium Mine Production
# Lithium-Ion Battery Storage
# Low-Density Polyethylene
# Magnesium
# Magnetic Data Storage
# Maleic Anhydride
# Marine Energy
# Mcv1 Vaccine
# Mcv2 Vaccine
# Methanol
# Microcomputers
# Microprocessor Clock Speed
# Microwave Ovens
# Microwaves
# Milk Production
# Motor Gasoline
# Motorcycles
# Motorcycles And Scooters
# Natural Gas Pipeline
# Natural Gas Power
# Natural Gas Production
# Neoprene Rubber
# Nickel Production
# Nickel-Based Battery
# Nitric Acid
# Nitrogen Fertilizer
# Nitrogenous Fertilizers
# Nox Pollution Controls (Boilers)
# Nuclear Energy
# Nuclear Weapons
# Offshore Wind Energy
# Oil Pipeline
# Oil Production
# Oil Refining Capacity
# Onshore Wind Energy
# Paraxylene
# Passenger Cars
# Pcv3 Vaccine
# Pentaerythritol
# Phenol
# Phosphate Fertilizer
# Phthalic Anhydride
# Podcasting
# Pol3 Vaccine
# Polyester Fiber
# Polystyrene
# Polyvinylchloride
# Postal Traffic
# Potash Fertilizer
# Potassic Fertilizers
# Power Steering
# Primary Aluminum Production
# Primary Bauxite Production
# Primary Copper Production
# Primary Magnesium
# Processor Performance
# Public Roads
# Pumped Hydro Storage
# Radial Tires
# Radio
# Radio Receivers
# Railroad
# Random Access Memory
# Rare Earth Mine Production
# Raw Steel Production
# Rcv1 Vaccine
# Real-Time Gross Settlement Adoption
# Refined Copper
# Refrigerators
# Renewable Power
# Rotac Vaccine
# Running Water
# Salt Production
# Sand And Gravel Production (Construction)
# Sand And Gravel Production (Industrial)
# Sensible Heat Storage
# Shale Production
# Shotgun Sanger Dna Sequencing
# Silver
# Smartphone Usage
# Social Media Usage
# Sodium
# Sodium Chlorate
# Sodium-Based Battery Storage
# Solar Photovoltaic
# Solar Thermal Energy
# Solid Biofuels
# Soybean Production
# Space Launches
# Stationary Steam Engines
# Steam Locomotives
# Steam Ships
# Stove
# Styrene
# Submarine Cables
# Sugar Cane Production
# Sulphuric Acid
# Synthetic Filament Tow And Staple Fibers
# Synthetic Filament Yarn
# Synthetic Filaments
# Tablet
# Telegraph Traffic
# Telephones
# Telephones And Videophones
# Television
# Television Receivers
# Tin
# Titanium Sponge
# Transistors Per Microprocessor
# Turbo-Jets Of A Thrust Not Exceeding 25 Kn
# Urea
# Vacuum Cleaners
# Vacuums
# Videocassette Recorder
# Vinyl Acetate
# Vinyl Chloride
# Washing Machines
# Water Heater
# Wet Flue Gas Desulfurization Systems
# Yfv Vaccine
# Zinc
# Zinc-Based Battery

# %%
len(tech_list)
# Out:
# 227

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)
# Out:
# Air Conditioning Machines
# Bcg Vaccine
# Beer
# Bicycles And Other Cycles
# Household Refrigerators And Freezers
# Hydrogen Storage
# Motorcycles And Scooters
# Nitrogenous Fertilizers
# Potassic Fertilizers
# Radio Receivers
# Refined Copper
# Steam Ships
# Synthetic Filament Tow And Staple Fibers
# Synthetic Filament Yarn
# Telephones And Videophones
# Television Receivers
# Turbo-Jets Of A Thrust Not Exceeding 25 Kn
# Vacuum Cleaners
# Yfv Vaccine

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
tech_country_dict
# Out:
# {'Acrylic Fiber': ['World'],
#  'Acrylonitrile': ['World'],
#  'Air Conditioning Machines': ['Chile',
#   'Ecuador',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Estonia',
#   'Bosnia and Herzegovina',
#   'Poland',
#   'United Kingdom',
#   'Greece',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Finland',
#   'Slovakia',
#   'Iraq',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Italy',
#   'Ireland',
#   'Denmark',
#   'Bulgaria',
#   'Czechia',
#   'Slovenia'],
#  'Air-Source Heat Pumps': ['United States'],
#  'All Biofuels': ['Belgium',
#   'Indonesia',
#   'France',
#   'Australia',
#   'South Korea',
#   'Spain',
#   'Colombia',
#   'Mexico',
#   'Portugal',
#   'Thailand',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'US',
#   'Austria',
#   'Germany',
#   'Argentina',
#   'Finland',
#   'Canada',
#   'Netherlands',
#   'Brazil',
#   'China',
#   'Sweden',
#   'Italy',
#   'World'],
#  'Amazon Prime Users': ['United States'],
#  'Ammonia Synthesis': ['USSR',
#   'Germany',
#   'Italy',
#   'Czechoslovakia',
#   'Canada',
#   'Belgium',
#   'Netherlands',
#   'Poland',
#   'France',
#   'World',
#   'Japan',
#   'USA',
#   'Sweden'],
#  'Aniline': ['World'],
#  'Aquaculture Production': ['Philippines',
#   'American Samoa',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'St. Vincent and the Grenadines',
#   'Japan',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Poland',
#   'India',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Tuvalu',
#   'Canada',
#   'Eswatini',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Turks and Caicos Islands',
#   'Panama',
#   'Virgin Islands (U.S.)',
#   'Italy',
#   'Iceland',
#   'West Bank and Gaza',
#   'World',
#   'Congo, Rep.',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Belarus',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Yemen, Rep.',
#   'Indonesia',
#   'St. Lucia',
#   'Botswana',
#   'Australia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Puerto Rico',
#   'Kenya',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'United Kingdom',
#   'Austria',
#   'St. Kitts and Nevis',
#   'Burkina Faso',
#   'Germany',
#   'Venezuela, RB',
#   'Uruguay',
#   'Malawi',
#   'Iraq',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Northern Mariana Islands',
#   'Uzbekistan',
#   'Angola',
#   'Gambia, The',
#   'Bolivia',
#   'Uganda',
#   'Belize',
#   'Lao PDR',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Korea, Rep.',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Faroe Islands',
#   'Algeria',
#   'Micronesia, Fed. Sts.',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   "Korea, Dem. People's Rep.",
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Tanzania',
#   'Eritrea',
#   'Kazakhstan',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Tajikistan',
#   'Seychelles',
#   'Morocco',
#   'Paraguay',
#   'Bahamas, The',
#   'Madagascar',
#   'Sri Lanka',
#   'Palau',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Solomon Islands',
#   'North Macedonia',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'Turkiye',
#   'South Africa',
#   'Papua New Guinea',
#   'Barbados',
#   'Kuwait',
#   'French Polynesia',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Congo, Dem. Rep.',
#   'Honduras',
#   'Vanuatu',
#   'New Caledonia',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Curacao',
#   'Lebanon',
#   'Antigua and Barbuda',
#   'British Virgin Islands',
#   'Albania',
#   'Argentina',
#   'Aruba',
#   'Bahrain',
#   'Finland',
#   'Iran, Islamic Rep.',
#   'Malta',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Guam',
#   'Netherlands',
#   'Kyrgyz Republic',
#   'Nicaragua',
#   'Switzerland',
#   'Egypt, Arab Rep.',
#   'Mali',
#   'United Arab Emirates',
#   'Benin',
#   'Russian Federation',
#   'Slovak Republic',
#   'Moldova',
#   'United States',
#   'Hong Kong SAR, China',
#   'Liberia'],
#  'Automatic Transmission': ['United States'],
#  'Bcg Vaccine': ['Philippines',
#   'Republic of North Macedonia',
#   'Lesotho',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Pakistan',
#   'Tuvalu',
#   'Eswatini',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Panama',
#   'Saint Kitts and Nevis',
#   'Somalia',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Belarus',
#   'Saint Lucia',
#   'Niue',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'State of Palestine',
#   'Micronesia (Federated States of)',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Uzbekistan',
#   'Angola',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Monaco',
#   'Syrian Arab Republic',
#   'Armenia',
#   'Rwanda',
#   'Yemen',
#   'Togo',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Cook Islands',
#   'Djibouti',
#   'Tajikistan',
#   'Seychelles',
#   'Mauritania',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'Solomon Islands',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'South Africa',
#   "Democratic People's Republic of Korea",
#   'Papua New Guinea',
#   'United Republic of Tanzania',
#   'Kuwait',
#   'Cuba',
#   'France',
#   'Burundi',
#   'Honduras',
#   'Vanuatu',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Gambia',
#   'Comoros',
#   'Albania',
#   'Argentina',
#   'Finland',
#   'Malta',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Nicaragua',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'United Arab Emirates',
#   'Türkiye',
#   'Benin',
#   'Russian Federation',
#   'Democratic Republic of the Congo',
#   'Liberia',
#   'Maldives'],
#  'Beer': ['Chile',
#   'Dominican Republic',
#   'Peru',
#   'United Republic of Tanzania',
#   'Ecuador',
#   'Latvia',
#   'Belgium',
#   'France',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Kenya',
#   'Nepal',
#   'Mexico',
#   'Portugal',
#   'Estonia',
#   'Bosnia and Herzegovina',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'United Kingdom',
#   'Georgia',
#   'Greece',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Albania',
#   'Burkina Faso',
#   'Germany',
#   'Slovenia',
#   'Zimbabwe',
#   'Finland',
#   'Slovakia',
#   'Uruguay',
#   'Chad',
#   'Cyprus',
#   'Canada',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Mozambique',
#   'Serbia',
#   'The former Yugoslav Republic of Macedonia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Panama',
#   'Uganda',
#   'Italy',
#   'Madagascar',
#   'Ireland',
#   'Norway',
#   'Denmark',
#   'Bulgaria',
#   'Czechia',
#   'Montenegro'],
#  'Beer Production': ['Philippines',
#   'Belgium',
#   'Japan',
#   'Portugal',
#   'Estonia',
#   'Costa Rica',
#   'Poland',
#   'India',
#   'East Germany',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Czech Republic',
#   'Zimbabwe',
#   'Guatemala',
#   'Canada',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Egypt',
#   'Singapore',
#   'Panama',
#   'Italy',
#   'Macedonia',
#   'Ireland',
#   'Belarus',
#   'Ethiopia',
#   'Ghana',
#   'Indonesia',
#   'Korea',
#   'Australia',
#   'Hungary',
#   'Ivory Coast',
#   'Kenya',
#   'Thailand',
#   'Austria',
#   'Burkina Faso',
#   'Germany',
#   'Uruguay',
#   'Malawi',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'China',
#   'Yugoslavia',
#   'Uzbekistan',
#   'Angola',
#   'Russia',
#   'Bolivia',
#   'Cameroon',
#   'Chile',
#   'Jamaica',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Algeria',
#   'Romania',
#   'Colombia',
#   'Mexico',
#   'Armenia',
#   'Rwanda',
#   'New Zealand',
#   'Gabon',
#   'Zaire',
#   'Turkmenistan',
#   'Israel',
#   'Tanzania',
#   'Kazakhstan',
#   'Mozambique',
#   'Serbia',
#   'Tajikistan',
#   'Morocco',
#   'Kyrgistan',
#   'Paraguay',
#   'Czechoslovakia',
#   'West Germany',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'USA',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Peru',
#   'South Africa',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'UK',
#   'Honduras',
#   'Southern Vietnam',
#   'Venezuela',
#   'Finland',
#   'Argentina',
#   'Switzerland',
#   'Nicaragua',
#   'Netherlands',
#   'Moldova'],
#  'Benzene': ['World'],
#  'Bicycles': ['World'],
#  'Bicycles And Other Cycles': ['Chile',
#   'Ecuador',
#   'El Salvador',
#   'Belgium',
#   'France',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Bosnia and Herzegovina',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Greece',
#   'Germany',
#   'Bangladesh',
#   'Iran (Islamic Republic of)',
#   'Finland',
#   'Slovakia',
#   'Iraq',
#   'Canada',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Serbia',
#   'Azerbaijan',
#   'Croatia',
#   'Uzbekistan',
#   'Sweden',
#   'Italy',
#   'Ireland',
#   'Denmark',
#   'Bulgaria',
#   'Czechia'],
#  'Biogas': ['Philippines',
#   'Republic of North Macedonia',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Portugal',
#   'Estonia',
#   'Guadeloupe',
#   'Costa Rica',
#   'Poland',
#   'India',
#   'Malaysia',
#   'Greece',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Canada',
#   'Azerbaijan',
#   'Croatia',
#   'Sweden',
#   'Egypt',
#   'Jordan',
#   'Panama',
#   'Italy',
#   'Iceland',
#   'Ireland',
#   'Réunion',
#   'Czechia',
#   'Belarus',
#   'Luxembourg',
#   'Ghana',
#   'Indonesia',
#   'Australia',
#   'Hungary',
#   'Puerto Rico',
#   'Kenya',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'State of Palestine',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Chile',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Faroe Islands',
#   'Romania',
#   'Samoa',
#   'Colombia',
#   'Mexico',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Chinese Taipei',
#   'Israel',
#   'Kazakhstan',
#   'Slovakia',
#   'Serbia',
#   'United States of America',
#   'Martinique',
#   'Morocco',
#   'Paraguay',
#   'Sri Lanka',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Bulgaria',
#   'Slovenia',
#   'Peru',
#   'South Africa',
#   'United Republic of Tanzania',
#   'Cuba',
#   'France',
#   'Spain',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Honduras',
#   'Lebanon',
#   'Argentina',
#   'Finland',
#   'Malta',
#   'Netherlands',
#   'Switzerland',
#   'Republic of Korea',
#   'United Arab Emirates',
#   'Türkiye'],
#  'Bisphenol A': ['World'],
#  'Cable Tv': ['United States'],
#  'Cadmium Refining': ['Peru',
#   'South Africa',
#   'Serbia and Montenegro',
#   'Belgium',
#   'Algeria',
#   'Australia',
#   'France',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Namibia',
#   'Mexico',
#   'Thailand',
#   'Korea, North',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Austria',
#   'Germany',
#   'U.S.S.R.',
#   'Argentina',
#   'Finland',
#   'Kazakhstan',
#   'Canada',
#   'Netherlands',
#   'Brazil',
#   'China',
#   'Turkey',
#   'Yugoslavia',
#   'Russia',
#   'Italy',
#   'Macedonia',
#   'Ukraine',
#   'World',
#   'Norway',
#   'Korea, Republic of',
#   'United States',
#   'Bulgaria',
#   'Congo (Kinshasa)'],
#  'Canals': ['United States'],
#  'Cane Sugar Production': ['Dominican Republic',
#   'Philippines',
#   'Jamaica',
#   'South Africa',
#   'Barbados',
#   'Ethiopia',
#   'El Salvador',
#   'Trinidad & Tobago',
#   'Cuba',
#   'Indonesia',
#   'Mauritius',
#   'Japan',
#   'Spain',
#   'Ivory Coast',
#   'Honduras',
#   'Kenya',
#   'Mexico',
#   'Thailand',
#   'Myanmar',
#   'Costa Rica',
#   'India',
#   'Taiwan',
#   'Swaziland',
#   'Bangladesh',
#   'Zimbabwe',
#   'Tanzania',
#   'Guatemala',
#   'Pakistan',
#   'Malawi',
#   'Nicaragua',
#   'Turkey',
#   'China',
#   'Mozambique',
#   'Vietnam',
#   'Haiti',
#   'Egypt',
#   'Sudan',
#   'Morocco',
#   'Panama',
#   'Madagascar',
#   'Iran',
#   'USA'],
#  'Caprolactam': ['World'],
#  'Capture Fisheries Production': ['Philippines',
#   'American Samoa',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'St. Vincent and the Grenadines',
#   'Japan',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Gibraltar',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Tuvalu',
#   'Canada',
#   'Eswatini',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Turks and Caicos Islands',
#   'Panama',
#   'Somalia',
#   'Virgin Islands (U.S.)',
#   'Italy',
#   'Iceland',
#   'West Bank and Gaza',
#   'World',
#   'Congo, Rep.',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Sint Maarten (Dutch part)',
#   'Belarus',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Yemen, Rep.',
#   'Indonesia',
#   'St. Lucia',
#   'Botswana',
#   'Australia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Puerto Rico',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bermuda',
#   'Bosnia and Herzegovina',
#   'United Kingdom',
#   'Austria',
#   'St. Kitts and Nevis',
#   'Burkina Faso',
#   'Germany',
#   'Venezuela, RB',
#   'Uruguay',
#   'Malawi',
#   'Iraq',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Northern Mariana Islands',
#   'Uzbekistan',
#   'Angola',
#   'Gambia, The',
#   'Andorra',
#   'Bolivia',
#   'Uganda',
#   'Belize',
#   'Lao PDR',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Korea, Rep.',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Faroe Islands',
#   'Algeria',
#   'Micronesia, Fed. Sts.',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Macao SAR, China',
#   'Monaco',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Syrian Arab Republic',
#   'Togo',
#   'Isle of Man',
#   "Korea, Dem. People's Rep.",
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Tanzania',
#   'Eritrea',
#   'Kazakhstan',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Djibouti',
#   'Tajikistan',
#   'Seychelles',
#   'Mauritania',
#   'Morocco',
#   'Paraguay',
#   'Bahamas, The',
#   'Madagascar',
#   'Sri Lanka',
#   'Palau',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Solomon Islands',
#   'North Macedonia',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'Turkiye',
#   'South Africa',
#   'Papua New Guinea',
#   'St. Martin (French part)',
#   'Barbados',
#   'Kuwait',
#   'French Polynesia',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Congo, Dem. Rep.',
#   'Honduras',
#   'Vanuatu',
#   'New Caledonia',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Curacao',
#   'Lebanon',
#   'Cayman Islands',
#   'Comoros',
#   'Antigua and Barbuda',
#   'British Virgin Islands',
#   'Albania',
#   'Liechtenstein',
#   'Argentina',
#   'Aruba',
#   'Bahrain',
#   'Finland',
#   'Iran, Islamic Rep.',
#   'Malta',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Guam',
#   'Netherlands',
#   'Kyrgyz Republic',
#   'Nicaragua',
#   'Switzerland',
#   'Egypt, Arab Rep.',
#   'Mali',
#   'United Arab Emirates',
#   'Benin',
#   'Russian Federation',
#   'Greenland',
#   'Slovak Republic',
#   'Moldova',
#   'United States',
#   'Hong Kong SAR, China',
#   'San Marino',
#   'Liberia',
#   'Maldives'],
#  'Carbon Capture & Sequestration': ['World'],
#  'Caustic Soda': ['Ecuador',
#   'El Salvador',
#   'Belgium',
#   'Algeria',
#   'France',
#   'Australia',
#   'Japan',
#   'Romania',
#   'South Korea',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Greece',
#   'Germany',
#   'Bangladesh',
#   'Israel',
#   'Finland',
#   'Argentina',
#   'Slovakia',
#   'Pakistan',
#   'Iraq',
#   'Netherlands',
#   'Canada',
#   'Brazil',
#   'Turkey',
#   'China',
#   'United States of America',
#   'Azerbaijan',
#   'Croatia',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Italy',
#   'Ireland',
#   'Norway',
#   'Denmark',
#   'Czechia'],
#  'Cellphones': ['Philippines',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'South Korea',
#   'Japan',
#   'Libya',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'Costa Rica',
#   'Poland',
#   'Mongolia',
#   'India',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Czech Republic',
#   'Bangladesh',
#   'Suriname',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Pakistan',
#   'Canada',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Nigeria',
#   'Croatia',
#   'Sweden',
#   'Laos',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Panama',
#   'Somalia',
#   'Italy',
#   'Iceland',
#   'Macedonia',
#   'World',
#   'Ireland',
#   'Belarus',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Ivory Coast',
#   'Syria',
#   'Kenya',
#   'Thailand',
#   'Bosnia-Herzegovina',
#   'United Kingdom',
#   'Austria',
#   'Burkina Faso',
#   'Swaziland',
#   'Germany',
#   'Uruguay',
#   'Malawi',
#   'Iraq',
#   'Kyrgyzstan',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Turkey',
#   'Saudi Arabia',
#   'Haiti',
#   'Burma',
#   'Uzbekistan',
#   'Angola',
#   'Russia',
#   'Bolivia',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Hong Kong',
#   'Chile',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Algeria',
#   'Romania',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'New Zealand',
#   'Rwanda',
#   'Armenia',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Tanzania',
#   'Eritrea',
#   'Kazakhstan',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Tajikistan',
#   'Morocco',
#   'Mauritania',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'Iran',
#   'Norway',
#   'Denmark',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Peru',
#   'South Africa',
#   'Papua New Guinea',
#   'Kuwait',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Guinea-Bissau',
#   'Republic of the Congo',
#   'Equatorial Guinea',
#   'Gambia',
#   'Lebanon',
#   'Albania',
#   'Venezuela',
#   'Argentina',
#   'Finland',
#   'Sierra Leone',
#   'Switzerland',
#   'Nicaragua',
#   'Netherlands',
#   'Mali',
#   'United Arab Emirates',
#   'Benin',
#   'Democratic Republic of the Congo',
#   'Slovak Republic',
#   'Moldova',
#   'United States',
#   'Liberia'],
#  'Cement Production': ['World', 'United States'],
#  'Central Heating': ['United States'],
#  'Coal Power': ['World'],
#  'Coal Production': ['South Africa',
#   'Indonesia',
#   'Australia',
#   'South Korea',
#   'Romania',
#   'Japan',
#   'Spain',
#   'Hungary',
#   'Europe',
#   'USSR',
#   'Colombia',
#   'Mexico',
#   'Thailand',
#   'New Zealand',
#   'Asia',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Mongolia',
#   'US',
#   'Greece',
#   'Czech Republic',
#   'Germany',
#   'Venezuela',
#   'Zimbabwe',
#   'North America',
#   'Kazakhstan',
#   'Pakistan',
#   'Canada',
#   'Brazil',
#   'Turkey',
#   'China',
#   'Serbia',
#   'Vietnam',
#   'Uzbekistan',
#   'Russian Federation',
#   'Ukraine',
#   'World',
#   'Rest of World',
#   'Bulgaria'],
#  'Cobalt Mine Production': ['Democratic Republic of Congo',
#   'Philippines',
#   'Russian Federation',
#   'South Africa',
#   'Papua New Guinea',
#   'Morocco',
#   'New Caledonia',
#   'Cuba',
#   'Canada',
#   'Madagascar',
#   'World',
#   'China',
#   'Australia',
#   'Zambia'],
#  'Colour Tv': ['United States'],
#  'Combined Refrigerators-Freezers': ['Chile',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Bosnia and Herzegovina',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Iran (Islamic Republic of)',
#   'Finland',
#   'Iraq',
#   'Brazil',
#   'Lithuania',
#   'United States of America',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Italy',
#   'Denmark'],
#  'Compact Fluorescent Light Bulbs': ['World'],
#  'Compressed Air Energy Storage': ['Germany',
#   'Netherlands',
#   'Switzerland',
#   'United Kingdom',
#   'China',
#   'Canada',
#   'United States'],
#  'Computing Growth': ['World'],
#  'Concentrated Solar Power': ['World'],
#  'Copper Mining': ['Chile',
#   'Dominican Republic',
#   'Peru',
#   'Philippines',
#   'South Africa',
#   'Papua New Guinea',
#   'Ecuador',
#   'Serbia and Montenegro',
#   'Cuba',
#   'Indonesia',
#   'Zimbabwe',
#   'Botswana',
#   'Australia',
#   'France',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Colombia',
#   'Honduras',
#   'Namibia',
#   'Nepal',
#   'Mexico',
#   'Portugal',
#   'Armenia',
#   'Korea, North',
#   'Mongolia',
#   'Poland',
#   'India',
#   'United Kingdom',
#   'Malaysia',
#   'Georgia',
#   'Albania',
#   'Germany',
#   'U.S.S.R.',
#   'Argentina',
#   'Finland',
#   'Kazakhstan',
#   'Oman',
#   'Slovakia',
#   'Cyprus',
#   'Pakistan',
#   'Tanzania',
#   'Canada',
#   'Brazil',
#   'China',
#   'Turkey',
#   'Mozambique',
#   'Saudi Arabia',
#   'Serbia',
#   'Vietnam',
#   'Yugoslavia',
#   'Burma',
#   'Zambia',
#   'Uzbekistan',
#   'Sweden',
#   'Laos',
#   'Russia',
#   'Bolivia',
#   'Mauritania',
#   'Morocco',
#   'Czechoslovakia',
#   'Macedonia',
#   'Iran',
#   'World',
#   'Norway',
#   'Korea, Republic of',
#   'United States',
#   'Bulgaria',
#   'Congo (Kinshasa)'],
#  'Copper Refining': ['Chile',
#   'Philippines',
#   'Peru',
#   'South Africa',
#   'Serbia and Montenegro',
#   'Belgium',
#   'Indonesia',
#   'Australia',
#   'France',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Thailand',
#   'Korea, North',
#   'Mongolia',
#   'Poland',
#   'India',
#   'United Kingdom',
#   'Austria',
#   'Albania',
#   'Czech Republic',
#   'Taiwan',
#   'Germany',
#   'U.S.S.R.',
#   'Argentina',
#   'Finland',
#   'Kazakhstan',
#   'Oman',
#   'Slovakia',
#   'Cyprus',
#   'Zimbabwe',
#   'Canada',
#   'Brazil',
#   'China',
#   'Turkey',
#   'Serbia',
#   'Vietnam',
#   'Zambia',
#   'Yugoslavia',
#   'Burma',
#   'Uzbekistan',
#   'Sweden',
#   'Laos',
#   'Egypt',
#   'Russia',
#   'Italy',
#   'Czechoslovakia',
#   'Iran',
#   'Ukraine',
#   'Norway',
#   'World',
#   'Korea, Republic of',
#   'United States',
#   'Bulgaria',
#   'Congo (Kinshasa)'],
#  'Corn Production': ['Philippines',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Myanmar',
#   'Costa Rica',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Pakistan',
#   'Canada',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   "Côte d'Ivoire",
#   'Egypt',
#   'Jordan',
#   'Panama',
#   'Italy',
#   'Ireland',
#   'Netherlands (Kingdom of the)',
#   'Czechia',
#   'Belarus',
#   'Saint Lucia',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Puerto Rico',
#   'Kenya',
#   'Trinidad and Tobago',
#   'China, mainland',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Angola',
#   'Belize',
#   'Cameroon',
#   'Chile',
#   'Jamaica',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   'Yemen',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'United States of America',
#   'Tajikistan',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'North Macedonia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'South Africa',
#   'United Republic of Tanzania',
#   'Barbados',
#   'Kuwait',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Vanuatu',
#   'New Caledonia',
#   'Guinea-Bissau',
#   'Gambia',
#   'Lebanon',
#   'Antigua and Barbuda',
#   'Albania',
#   'Argentina',
#   'Sierra Leone',
#   'Nicaragua',
#   'Palestine',
#   'Switzerland',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'Türkiye',
#   'Benin',
#   'Russian Federation'],
#  'Cotton Seed Production': ['Philippines',
#   'Peru',
#   'South Africa',
#   'Ecuador',
#   'Ethiopia',
#   'El Salvador',
#   'Ghana',
#   'Algeria',
#   'Indonesia',
#   'Australia',
#   'Romania',
#   'Afghanistan',
#   'Senegal',
#   'Spain',
#   'Burundi',
#   'Niger',
#   'Colombia',
#   'Honduras',
#   'Kenya',
#   'Namibia',
#   'China, mainland',
#   'Mexico',
#   'Nepal',
#   'Syrian Arab Republic',
#   'Thailand',
#   'Yemen',
#   'Togo',
#   'Myanmar',
#   'Costa Rica',
#   'India',
#   'Gambia',
#   'Greece',
#   'Bolivia (Plurinational State of)',
#   'Turkmenistan',
#   'Cambodia',
#   'Albania',
#   'Burkina Faso',
#   'Bangladesh',
#   'Iran (Islamic Republic of)',
#   'Argentina',
#   'Israel',
#   'Kazakhstan',
#   'Zimbabwe',
#   'Chad',
#   'Kyrgyzstan',
#   'Malawi',
#   'Nicaragua',
#   'Pakistan',
#   'Brazil',
#   'Mozambique',
#   'Guinea',
#   'United States of America',
#   'Azerbaijan',
#   "Lao People's Democratic Republic",
#   'Nigeria',
#   'Mali',
#   "Côte d'Ivoire",
#   'Egypt',
#   'Tajikistan',
#   'Türkiye',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Tunisia',
#   'Bulgaria',
#   'Cameroon'],
#  "Cow'S Milk Production": ['Philippines',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Zimbabwe',
#   'Cyprus',
#   'Pakistan',
#   'Canada',
#   'China, Hong Kong SAR',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   "Côte d'Ivoire",
#   'Egypt',
#   'Jordan',
#   'Singapore',
#   'Panama',
#   'Italy',
#   'Iceland',
#   'Ireland',
#   'Netherlands (Kingdom of the)',
#   'Czechia',
#   'Belarus',
#   'Saint Lucia',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Puerto Rico',
#   'Kenya',
#   'Trinidad and Tobago',
#   'China, mainland',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Angola',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Mexico',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   'Yemen',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'United States of America',
#   'Tajikistan',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'North Macedonia',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Peru',
#   'South Africa',
#   'United Republic of Tanzania',
#   'Barbados',
#   'Kuwait',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Honduras',
#   'New Caledonia',
#   'Guinea-Bissau',
#   'Gambia',
#   'Lebanon',
#   'Antigua and Barbuda',
#   'Albania',
#   'Argentina',
#   'Finland',
#   'Malta',
#   'Nicaragua',
#   'Palestine',
#   'Switzerland',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'Türkiye',
#   'Benin',
#   'Russian Federation'],
#  'Crop Harvester': ['Philippines',
#   'Lesotho',
#   'Belgium',
#   'South Korea',
#   'Japan',
#   'Libya',
#   'Portugal',
#   'Estonia',
#   'Costa Rica',
#   'Poland',
#   'Mongolia',
#   'India',
#   'Georgia',
#   'Greece',
#   'Czech Republic',
#   'Suriname',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Pakistan',
#   'Canada',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Panama',
#   'Italy',
#   'Iceland',
#   'Macedonia',
#   'Ireland',
#   'Belarus',
#   'Ethiopia',
#   'Ghana',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Senegal',
#   'Hungary',
#   'Ivory Coast',
#   'Syria',
#   'Kenya',
#   'Thailand',
#   'Bosnia-Herzegovina',
#   'United Kingdom',
#   'Austria',
#   'Germany',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Turkey',
#   'Saudi Arabia',
#   'Burma',
#   'Uzbekistan',
#   'Russia',
#   'Bolivia',
#   'Uganda',
#   'Belize',
#   'Guyana',
#   'Chile',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Algeria',
#   'Romania',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'New Zealand',
#   'Armenia',
#   'Yemen',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Chad',
#   'Guinea',
#   'Tajikistan',
#   'Morocco',
#   'Mauritania',
#   'Czechoslovakia',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'Iran',
#   'Norway',
#   'Denmark',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'South Africa',
#   'Papua New Guinea',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Republic of the Congo',
#   'Gambia',
#   'Lebanon',
#   'Albania',
#   'Venezuela',
#   'Argentina',
#   'Finland',
#   'Sierra Leone',
#   'Switzerland',
#   'Netherlands',
#   'Mali',
#   'United Arab Emirates',
#   'Slovak Republic',
#   'Moldova',
#   'United States'],
#  'Crude Oil': ['Philippines',
#   'Chile',
#   'Peru',
#   'Ecuador',
#   'Qatar',
#   'Kuwait',
#   'Trinidad & Tobago',
#   'Cuba',
#   'Algeria',
#   'Indonesia',
#   'Australia',
#   'Romania',
#   'Japan',
#   'UAE',
#   'Libya',
#   'Hungary',
#   'UK',
#   'Ivory Coast',
#   'Syria',
#   'Colombia',
#   'Mexico',
#   'Thailand',
#   'New Zealand',
#   'Republic of the Congo',
#   'Myanmar',
#   'Poland',
#   'India',
#   'Gabon',
#   'Austria',
#   'Taiwan',
#   'Democratic Republic of Congo',
#   'Germany',
#   'Venezuela',
#   'Israel',
#   'Argentina',
#   'Bahrain',
#   'Oman',
#   'Pakistan',
#   'Iraq',
#   'Netherlands',
#   'Canada',
#   'Brazil',
#   'Turkey',
#   'China',
#   'Saudi Arabia',
#   'Yugoslavia',
#   'Nigeria',
#   'Angola',
#   'Egypt',
#   'Brunei',
#   'Russia',
#   'Bolivia',
#   'Morocco',
#   'Italy',
#   'West Germany',
#   'World',
#   'Iran',
#   'Norway',
#   'USA',
#   'Tunisia',
#   'Cameroon'],
#  'Cyclohexane': ['World'],
#  'Desalination Capacity': ['World'],
#  'Dishwashers': ['United States'],
#  'Disk Brakes': ['United States'],
#  'Dtp1 Vaccine': ['Philippines',
#   'Republic of North Macedonia',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Tuvalu',
#   'Canada',
#   'Eswatini',
#   'Zambia',
#   'Azerbaijan',
#   'Bahamas',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Panama',
#   'Saint Kitts and Nevis',
#   'Somalia',
#   'Italy',
#   'Iceland',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Belarus',
#   'Saint Lucia',
#   'Niue',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'United Kingdom',
#   'State of Palestine',
#   'Micronesia (Federated States of)',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Venezuela (Bolivarian Republic of)',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Uzbekistan',
#   'Angola',
#   'Andorra',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Monaco',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Cook Islands',
#   'Djibouti',
#   'Tajikistan',
#   'Seychelles',
#   'Mauritania',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Palau',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Solomon Islands',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'South Africa',
#   "Democratic People's Republic of Korea",
#   'Papua New Guinea',
#   'Barbados',
#   'Kuwait',
#   'United Republic of Tanzania',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Vanuatu',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Gambia',
#   'Lebanon',
#   'Comoros',
#   'Antigua and Barbuda',
#   'Albania',
#   'Argentina',
#   'Bahrain',
#   'Finland',
#   'Malta',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Netherlands',
#   'Nicaragua',
#   'Switzerland',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'United Arab Emirates',
#   'Türkiye',
#   'Benin',
#   'Russian Federation',
#   'Democratic Republic of the Congo',
#   'United States',
#   'San Marino',
#   'Liberia',
#   'Maldives'],
#  'Dtp3 Vaccine': ['Philippines',
#   'Republic of North Macedonia',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Tuvalu',
#   'Canada',
#   'Eswatini',
#   'Zambia',
#   'Azerbaijan',
#   'Bahamas',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Panama',
#   'Saint Kitts and Nevis',
#   'Somalia',
#   'Italy',
#   'Iceland',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Belarus',
#   'Saint Lucia',
#   'Niue',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'United Kingdom',
#   'State of Palestine',
#   'Micronesia (Federated States of)',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Venezuela (Bolivarian Republic of)',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Uzbekistan',
#   'Angola',
#   'Andorra',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Monaco',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Cook Islands',
#   'Djibouti',
#   'Tajikistan',
#   'Seychelles',
#   'Mauritania',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Palau',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Solomon Islands',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'South Africa',
#   "Democratic People's Republic of Korea",
#   'Papua New Guinea',
#   'Barbados',
#   'Kuwait',
#   'United Republic of Tanzania',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Vanuatu',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Gambia',
#   'Lebanon',
#   'Comoros',
#   'Antigua and Barbuda',
#   'Albania',
#   'Argentina',
#   'Bahrain',
#   'Finland',
#   'Malta',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Netherlands',
#   'Nicaragua',
#   'Switzerland',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'United Arab Emirates',
#   'Türkiye',
#   'Benin',
#   'Russian Federation',
#   'Democratic Republic of the Congo',
#   'United States',
#   'San Marino',
#   'Liberia',
#   'Maldives'],
#  'Ebook Reader': ['United States'],
#  'Electric Bicycles': ['World', 'China'],
#  'Electric Range': ['United States'],
#  'Electric Water Heaters And Immersion Heaters': ['Romania',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Estonia',
#   'Bosnia and Herzegovina',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Greece',
#   'Germany',
#   'Finland',
#   'Slovakia',
#   'Iraq',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'United States of America',
#   'The former Yugoslav Republic of Macedonia',
#   'Azerbaijan',
#   'Croatia',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Italy',
#   'Ireland',
#   'Norway',
#   'Denmark',
#   'Bulgaria'],
#  'Electricity': ['Philippines',
#   'Trinidad & Tobago',
#   'Belgium',
#   'South Korea',
#   'Japan',
#   'Portugal',
#   'Estonia',
#   'Poland',
#   'India',
#   'Malaysia',
#   'Greece',
#   'Czech Republic',
#   'Bangladesh',
#   'Oman',
#   'Cyprus',
#   'Pakistan',
#   'Canada',
#   'Vietnam',
#   'Azerbaijan',
#   'Croatia',
#   'Sweden',
#   'Egypt',
#   'Singapore',
#   'Italy',
#   'Iceland',
#   'Ireland',
#   'World',
#   'Belarus',
#   'Luxembourg',
#   'Indonesia',
#   'Australia',
#   'Hungary',
#   'Thailand',
#   'United Kingdom',
#   'Austria',
#   'Germany',
#   'Iraq',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'China',
#   'Saudi Arabia',
#   'Uzbekistan',
#   'Chile',
#   'Ecuador',
#   'Latvia',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Colombia',
#   'Mexico',
#   'New Zealand',
#   'Turkmenistan',
#   'Israel',
#   'Slovakia',
#   'Kazakhstan',
#   'China Hong Kong SAR',
#   'Morocco',
#   'Sri Lanka',
#   'Ukraine',
#   'Iran',
#   'Norway',
#   'Denmark',
#   'North Macedonia',
#   'Bulgaria',
#   'Slovenia',
#   'Peru',
#   'South Africa',
#   'Kuwait',
#   'France',
#   'Spain',
#   'US',
#   'Taiwan',
#   'Venezuela',
#   'Argentina',
#   'Finland',
#   'Netherlands',
#   'Switzerland',
#   'United Arab Emirates',
#   'Russian Federation'],
#  'Electro-Chemical Capacitor': ['Italy',
#   'Ireland',
#   'China',
#   'South Korea',
#   'United States',
#   'Spain'],
#  'Electronic Ignition': ['United States'],
#  'Ethanolamine': ['World'],
#  'Ethyl Alcohol': ['World'],
#  'Ethylene': ['World'],
#  'Ethylene Glycol': ['World'],
#  'Flow Battery Storage': ['South Africa',
#   'French Polynesia',
#   'Indonesia',
#   'South Korea',
#   'Australia',
#   'Japan',
#   'Portugal',
#   'New Zealand',
#   'United Kingdom',
#   'India',
#   'Antigua and Barbuda',
#   'Austria',
#   'Czech Republic',
#   'Germany',
#   'Israel',
#   'Kazakhstan',
#   'Switzerland',
#   'Canada',
#   'Netherlands',
#   'China',
#   'Russia',
#   'Italy',
#   'Denmark',
#   'United States',
#   'Slovenia'],
#  'Fluid Catalytic Cracking Refineries': ['World', 'US'],
#  'Flush Toilet': ['United States'],
#  'Flywheel Battery Storage': ['Germany',
#   'Kenya',
#   'Mexico',
#   'Canada',
#   'Netherlands',
#   'Ireland',
#   'United Kingdom',
#   'South Korea',
#   'France',
#   'Romania',
#   'United States',
#   'Australia',
#   'Antarctica',
#   'Spain',
#   'Czech Republic'],
#  'Formaldehyde': ['World'],
#  'Freezer': ['United States'],
#  'Geothermal Energy': ['Chile',
#   'Philippines',
#   'Ethiopia',
#   'El Salvador',
#   'Indonesia',
#   'Australia',
#   'France',
#   'Japan',
#   'Romania',
#   'Hungary',
#   'Honduras',
#   'Kenya',
#   'Mexico',
#   'Portugal',
#   'Thailand',
#   'New Zealand',
#   'Guadeloupe',
#   'Costa Rica',
#   'Chinese Taipei',
#   'Austria',
#   'Germany',
#   'Argentina',
#   'Guatemala',
#   'Nicaragua',
#   'China',
#   'United States of America',
#   'Croatia',
#   'Türkiye',
#   'Russian Federation',
#   'Italy',
#   'Iceland',
#   'World'],
#  'Gold Production': ['South Africa',
#   'Zimbabwe',
#   'Papua New Guinea',
#   'New Zealand',
#   'Ghana',
#   'Fiji',
#   'Korea',
#   'World',
#   'China',
#   'South Korea',
#   'Australia',
#   'Japan',
#   'Zaire',
#   'India',
#   'United States',
#   'Phillipines'],
#  'Graphite Mine Production': ['Russian Federation',
#   'Mexico',
#   'Madagascar',
#   'Canada',
#   'Brazil',
#   'China',
#   'India',
#   'Mozambique',
#   'Norway',
#   'Sri Lanka',
#   'Turkey',
#   'Ukraine',
#   'World',
#   'United States'],
#  'Ground Source Heat Pumps': ['World'],
#  'Heat Thermal Battery Storage': ['Chile',
#   'Germany',
#   'South Africa',
#   'Morocco',
#   'United Kingdom',
#   'China',
#   'Australia',
#   'France',
#   'India',
#   'United States',
#   'Spain'],
#  'Hepb3 Vaccine': ['Philippines',
#   'Republic of North Macedonia',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Tuvalu',
#   'Canada',
#   'Eswatini',
#   'Zambia',
#   'Azerbaijan',
#   'Bahamas',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Panama',
#   'Saint Kitts and Nevis',
#   'Somalia',
#   'Italy',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Belarus',
#   'Saint Lucia',
#   'Niue',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'United Kingdom',
#   'State of Palestine',
#   'Micronesia (Federated States of)',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Venezuela (Bolivarian Republic of)',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Uzbekistan',
#   'Angola',
#   'Andorra',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Monaco',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Cook Islands',
#   'Djibouti',
#   'Tajikistan',
#   'Seychelles',
#   'Mauritania',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Palau',
#   'Ukraine',
#   'Norway',
#   'Solomon Islands',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   'South Africa',
#   "Democratic People's Republic of Korea",
#   'Papua New Guinea',
#   'Barbados',
#   'Kuwait',
#   'United Republic of Tanzania',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Vanuatu',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Gambia',
#   'Lebanon',
#   'Comoros',
#   'Antigua and Barbuda',
#   'Albania',
#   'Argentina',
#   'Bahrain',
#   'Malta',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Netherlands',
#   'Nicaragua',
#   'Switzerland',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'United Arab Emirates',
#   'Türkiye',
#   'Benin',
#   'Russian Federation',
#   'Democratic Republic of the Congo',
#   'United States',
#   'San Marino',
#   'Liberia',
#   'Maldives'],
#  'Hepbb Vaccine': ['Philippines',
#   'Republic of North Macedonia',
#   'Republic of Moldova',
#   'Tonga',
#   'Marshall Islands',
#   'Namibia',
#   'Portugal',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Malaysia',
#   'Georgia',
#   'Suriname',
#   'Grenada',
#   'Oman',
#   'Guatemala',
#   'Tuvalu',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   'Egypt',
#   'Singapore',
#   'Dominica',
#   'Panama',
#   'Saint Kitts and Nevis',
#   'Belarus',
#   'Saint Lucia',
#   'Niue',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Sao Tome and Principe',
#   'Thailand',
#   'State of Palestine',
#   'Micronesia (Federated States of)',
#   'Viet Nam',
#   'Venezuela (Bolivarian Republic of)',
#   'Iran (Islamic Republic of)',
#   'Kyrgyzstan',
#   'Iraq',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Uzbekistan',
#   'Andorra',
#   'Belize',
#   'Guyana',
#   'Chile',
#   'Nauru',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Colombia',
#   'Mexico',
#   'Armenia',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Kazakhstan',
#   'Serbia',
#   'Cook Islands',
#   'Djibouti',
#   'Tajikistan',
#   'Morocco',
#   'Palau',
#   'Ukraine',
#   'Solomon Islands',
#   'Tunisia',
#   'Bulgaria',
#   'Dominican Republic',
#   'Timor-Leste',
#   'Peru',
#   "Democratic People's Republic of Korea",
#   'Papua New Guinea',
#   'Kuwait',
#   'Cuba',
#   'Honduras',
#   'Vanuatu',
#   'Gambia',
#   'Lebanon',
#   'Antigua and Barbuda',
#   'Albania',
#   'Argentina',
#   'Bahrain',
#   "Cote d'Ivoire",
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'United Arab Emirates',
#   'Türkiye',
#   'Benin',
#   'United States',
#   'Maldives'],
#  'Herbicide-Tolerant Corn': ['United States'],
#  'Herbicide-Tolerant Cotton': ['United States'],
#  'Herbicide-Tolerant Soybeans': ['United States'],
#  'Hib3 Vaccine': ['Philippines',
#   'Republic of North Macedonia',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Republic of Moldova',
#   'Tonga',
#   'Libya',
#   'Marshall Islands',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'South Sudan',
#   'Myanmar',
#   'Costa Rica',
#   'Mongolia',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Grenada',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Cyprus',
#   'Pakistan',
#   'Tuvalu',
#   'Canada',
#   'Eswatini',
#   'Zambia',
#   'Azerbaijan',
#   'Bahamas',
#   'Croatia',
#   'Nigeria',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Dominica',
#   'Panama',
#   'Saint Kitts and Nevis',
#   'Somalia',
#   'Italy',
#   'Iceland',
#   'Ireland',
#   'Czechia',
#   'Montenegro',
#   'Belarus',
#   'Saint Lucia',
#   'Niue',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Fiji',
#   'Saint Vincent and the Grenadines',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Kiribati',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'United Kingdom',
#   'State of Palestine',
#   'Micronesia (Federated States of)',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Venezuela (Bolivarian Republic of)',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Iraq',
#   'Malawi',
#   'Brazil',
#   'Lithuania',
#   'Saudi Arabia',
#   'Brunei Darussalam',
#   'Haiti',
#   'Uzbekistan',
#   'Angola',
#   'Andorra',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Nauru',
#   'Cabo Verde',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Qatar',
#   'Algeria',
#   'Romania',
#   'Samoa',
#   'Bhutan',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'Monaco',
#   'Syrian Arab Republic',
#   'Armenia',
#   'New Zealand',
#   'Rwanda',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Eritrea',
#   'Kazakhstan',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Serbia',
#   'Cook Islands',
#   'Djibouti',
#   'Tajikistan',
#   'Seychelles',
#   'Mauritania',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Palau',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Solomon Islands',
# ...
#   'Türkiye',
#   'Morocco',
#   'Italy'],
#  'Solid Biofuels': ['Philippines',
#   'Republic of North Macedonia',
#   'French Guiana',
#   'Belgium',
#   'Mauritius',
#   'Japan',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'Guadeloupe',
#   'Costa Rica',
#   'Poland',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Greece',
#   'Zimbabwe',
#   'Guatemala',
#   'Pakistan',
#   'Canada',
#   'Eswatini',
#   'Zambia',
#   'Croatia',
#   'Sweden',
#   'Egypt',
#   'Sudan',
#   'Singapore',
#   'Italy',
#   'Ireland',
#   'Réunion',
#   'Czechia',
#   'Belarus',
#   'Luxembourg',
#   'Ethiopia',
#   'Fiji',
#   'Indonesia',
#   'Australia',
#   'Senegal',
#   'Hungary',
#   'Puerto Rico',
#   'Kenya',
#   'Trinidad and Tobago',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Germany',
#   'Uruguay',
#   'Malawi',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Angola',
#   'Uganda',
#   'Belize',
#   'Guyana',
#   'Chile',
#   'Jamaica',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Romania',
#   'Samoa',
#   'Colombia',
#   'Mexico',
#   'New Zealand',
#   'Rwanda',
#   'Chinese Taipei',
#   'Cambodia',
#   'Slovakia',
#   'Chad',
#   'Mozambique',
#   'Serbia',
#   'United States of America',
#   'Martinique',
#   'Paraguay',
#   'Sri Lanka',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Peru',
#   'South Africa',
#   'United Republic of Tanzania',
#   'Cuba',
#   'France',
#   'Spain',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Honduras',
#   'Argentina',
#   'Finland',
#   'Sierra Leone',
#   'Netherlands',
#   'Nicaragua',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Türkiye',
#   'Russian Federation'],
#  'Soybean Production': ['Philippines',
#   'Japan',
#   'Republic of Moldova',
#   'Nepal',
#   'Myanmar',
#   'Poland',
#   'India',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Bangladesh',
#   'Suriname',
#   'Zimbabwe',
#   'Pakistan',
#   'Canada',
#   'Zambia',
#   'Azerbaijan',
#   'Croatia',
#   'Nigeria',
#   "Côte d'Ivoire",
#   'Egypt',
#   'Panama',
#   'Italy',
#   'Czechia',
#   'Ethiopia',
#   'Indonesia',
#   'Australia',
#   'Hungary',
#   'China, mainland',
#   'Thailand',
#   'Bosnia and Herzegovina',
#   'Bolivia (Plurinational State of)',
#   'Austria',
#   'Viet Nam',
#   'Burkina Faso',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Uruguay',
#   'Kyrgyzstan',
#   'Malawi',
#   'Brazil',
#   'Angola',
#   'Belize',
#   'Cameroon',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Romania',
#   'Bhutan',
#   'Colombia',
#   'Mexico',
#   'Syrian Arab Republic',
#   'Rwanda',
#   'Togo',
#   'Cambodia',
#   'Kazakhstan',
#   'Slovakia',
#   'Serbia',
#   'United States of America',
#   'Tajikistan',
#   'Morocco',
#   'Paraguay',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'North Macedonia',
#   'Bulgaria',
#   'Slovenia',
#   'Timor-Leste',
#   'Peru',
#   'South Africa',
#   'United Republic of Tanzania',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Albania',
#   'Argentina',
#   'Nicaragua',
#   'Switzerland',
#   'Republic of Korea',
#   "Lao People's Democratic Republic",
#   'Mali',
#   'Türkiye',
#   'Russian Federation'],
#  'Space Launches': ['Philippines',
#   'Belgium',
#   'Mauritius',
#   'South Korea',
#   'Japan',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'Costa Rica',
#   'Poland',
#   'Mongolia',
#   'India',
#   'Malaysia',
#   'North Korea',
#   'Greece',
#   'Bangladesh',
#   'Guatemala',
#   'Pakistan',
#   'Canada',
#   'Vietnam',
#   'Azerbaijan',
#   'Nigeria',
#   'Sweden',
#   'Laos',
#   'Egypt',
#   'Jordan',
#   'Singapore',
#   'Italy',
#   'World',
#   'Czechia',
#   'Belarus',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Indonesia',
#   'Australia',
#   'Hungary',
#   'Kenya',
#   'Thailand',
#   'United Kingdom',
#   'Austria',
#   'Germany',
#   'Uruguay',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'China',
#   'Saudi Arabia',
#   'Angola',
#   'Russia',
#   'Bolivia',
#   'Chile',
#   'Latvia',
#   'Qatar',
#   'Ecuador',
#   'Algeria',
#   'Romania',
#   'Bhutan',
#   'Colombia',
#   'Mexico',
#   'Monaco',
#   'New Zealand',
#   'Rwanda',
#   'Armenia',
#   'Turkmenistan',
#   'Israel',
#   'Slovakia',
#   'Kazakhstan',
#   'Morocco',
#   'Paraguay',
#   'Sri Lanka',
#   'Iran',
#   'Ukraine',
#   'Norway',
#   'Denmark',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Peru',
#   'South Africa',
#   'Papua New Guinea',
#   'France',
#   'Spain',
#   'Taiwan',
#   'Venezuela',
#   'Finland',
#   'Argentina',
#   'Netherlands',
#   'Switzerland',
#   'United Arab Emirates',
#   'Moldova',
#   'United States'],
#  'Stationary Steam Engines': ['World'],
#  'Steam Locomotives': ['World'],
#  'Steam Ships': ['Chile',
#   'Cuba',
#   'Belgium',
#   'France',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'United Kingdom',
#   'Greece',
#   'Austria',
#   'Germany',
#   'Finland',
#   'Canada',
#   'Netherlands',
#   'Sweden',
#   'Russia',
#   'Italy',
#   'Ireland',
#   'Norway',
#   'Denmark'],
#  'Stove': ['United States'],
#  'Styrene': ['World'],
#  'Submarine Cables': ['World'],
#  'Sugar Cane Production': ['Dominican Republic',
#   'Jamaica',
#   'Peru',
#   'Philippines',
#   'South Africa',
#   'Cabo Verde',
#   'Barbados',
#   'Ecuador',
#   'El Salvador',
#   'Ethiopia',
#   'Fiji',
#   'Ghana',
#   'Indonesia',
#   'Mauritius',
#   'Zimbabwe',
#   'Australia',
#   'Japan',
#   'Afghanistan',
#   'Senegal',
#   'Burundi',
#   'Bhutan',
#   'Niger',
#   'Puerto Rico',
#   'Honduras',
#   'Kenya',
#   'Nepal',
#   'Trinidad and Tobago',
#   'China, mainland',
#   'Mexico',
#   'Portugal',
#   'Thailand',
#   'Rwanda',
#   'Myanmar',
#   'Costa Rica',
#   'India',
#   'Congo',
#   'Malaysia',
#   'Lebanon',
#   'Bolivia (Plurinational State of)',
#   'Viet Nam',
#   'Cambodia',
#   'Burkina Faso',
#   'Bangladesh',
#   'Iran (Islamic Republic of)',
#   'Argentina',
#   'Grenada',
#   'Suriname',
#   'Oman',
#   'Uruguay',
#   'Chad',
#   'Malawi',
#   'Pakistan',
#   'Nicaragua',
#   'Brazil',
#   'Mozambique',
#   'Guinea',
#   'United States of America',
#   "Lao People's Democratic Republic",
#   'Nigeria',
#   'Mali',
#   "Côte d'Ivoire",
#   'Egypt',
#   'Morocco',
#   'Panama',
#   'Paraguay',
#   'Belize',
#   'Madagascar',
#   'Sri Lanka'],
#  'Sulphuric Acid': ['Chile',
#   'Peru',
#   'Cuba',
#   'Indonesia',
#   'Algeria',
#   'Belgium',
#   'France',
#   'Australia',
#   'Japan',
#   'South Korea',
#   'Romania',
#   'Hungary',
#   'Colombia',
#   'Mexico',
#   'Thailand',
#   'Portugal',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'East Germany',
#   'Zaire',
#   'Greece',
#   'Austria',
#   'Germany',
#   'Israel',
#   'Venezuela',
#   'Argentina',
#   'Finland',
#   'Pakistan',
#   'Canada',
#   'Switzerland',
#   'Brazil',
#   'Turkey',
#   'China',
#   'United States of America',
#   'Zambia',
#   'Netherlands',
#   'Yugoslavia',
#   'Sweden',
#   'Egypt',
#   'Russia',
#   'Morocco',
#   'Italy',
#   'Czechoslovakia',
#   'West Germany',
#   'Iran',
#   'Ireland',
#   'Norway',
#   'Denmark',
#   'Tunisia',
#   'Bulgaria',
#   'Phillipines'],
#  'Synthetic Filament Tow And Staple Fibers': ['Chile',
#   'Ecuador',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Mexico',
#   'Portugal',
#   'Poland',
#   'United Kingdom',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Finland',
#   'Slovakia',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Azerbaijan',
#   'Uzbekistan',
#   'Sweden',
#   'Italy',
#   'Ireland',
#   'Denmark',
#   'Czechia'],
#  'Synthetic Filament Yarn': ['Chile',
#   'Ecuador',
#   'Latvia',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Portugal',
#   'Estonia',
#   'Poland',
#   'Greece',
#   'Germany',
#   'Iran (Islamic Republic of)',
#   'Finland',
#   'Slovakia',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Azerbaijan',
#   'Uzbekistan',
#   'Sweden',
#   'Italy',
#   'Ireland',
#   'Denmark',
#   'Bulgaria',
#   'Czechia'],
#  'Synthetic Filaments': ['South Africa',
#   'Belgium',
#   'Indonesia',
#   'South Korea',
#   'Australia',
#   'Romania',
#   'France',
#   'Japan',
#   'Spain',
#   'Colombia',
#   'Mexico',
#   'Thailand',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'East Germany',
#   'Malaysia',
#   'Austria',
#   'Germany',
#   'Finland',
#   'Argentina',
#   'Pakistan',
#   'Netherlands',
#   'Canada',
#   'Brazil',
#   'China',
#   'Turkey',
#   'United States of America',
#   'Switzerland',
#   'Yugoslavia',
#   'Sweden',
#   'Egypt',
#   'Russia',
#   'Italy',
#   'Czechoslovakia',
#   'West Germany',
#   'Iran',
#   'Norway',
#   'Phillipines'],
#  'Tablet': ['United States'],
#  'Telegraph Traffic': ['Philippines',
#   'Chile',
#   'Peru',
#   'South Africa',
#   'El Salvador',
#   'Ghana',
#   'Indonesia',
#   'Algeria',
#   'Belgium',
#   'Australia',
#   'France',
#   'Japan',
#   'South Korea',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Ivory Coast',
#   'Syria',
#   'Kenya',
#   'Colombia',
#   'Mexico',
#   'Portugal',
#   'Thailand',
#   'New Zealand',
#   'Togo',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Malaysia',
#   'Lebanon',
#   'Greece',
#   'Austria',
#   'Taiwan',
#   'Germany',
#   'Venezuela',
#   'Israel',
#   'Tanzania',
#   'Argentina',
#   'Finland',
#   'Uruguay',
#   'Zimbabwe',
#   'Malawi',
#   'Pakistan',
#   'Iraq',
#   'Switzerland',
#   'Canada',
#   'Brazil',
#   'South Vietnam',
#   'Netherlands',
#   'Mozambique',
#   'Zambia',
#   'Serbia',
#   'China',
#   'Turkey',
#   'Nigeria',
#   'Burma',
#   'Sweden',
#   'Angola',
#   'Egypt',
#   'Sudan',
#   'Russia',
#   'Singapore',
#   'Democratic Republic of the Congo',
#   'Morocco',
#   'Uganda',
#   'Italy',
#   'Czechoslovakia',
#   'Madagascar',
#   'Sri Lanka',
#   'Ireland',
#   'Norway',
#   'Denmark',
#   'United States',
#   'Tunisia',
#   'Cameroon',
#   'Guyana'],
#  'Telephones': ['Philippines',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'South Korea',
#   'Japan',
#   'Libya',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'Costa Rica',
#   'Poland',
#   'Mongolia',
#   'India',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Czech Republic',
#   'Bangladesh',
#   'Suriname',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Pakistan',
#   'Canada',
#   'South Vietnam',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Nigeria',
#   'Croatia',
#   'Sweden',
#   'Laos',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Panama',
#   'Somalia',
#   'Italy',
#   'Iceland',
#   'Macedonia',
#   'Ireland',
#   'Belarus',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Ivory Coast',
#   'Syria',
#   'Kenya',
#   'Thailand',
#   'Bosnia-Herzegovina',
#   'United Kingdom',
#   'Austria',
#   'Burkina Faso',
#   'Swaziland',
#   'Germany',
#   'Uruguay',
#   'Malawi',
#   'Iraq',
#   'Kyrgyzstan',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Turkey',
#   'Saudi Arabia',
#   'Haiti',
#   'Burma',
#   'Uzbekistan',
#   'Angola',
#   'Russia',
#   'Bolivia',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Hong Kong',
#   'Chile',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Algeria',
#   'Romania',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'New Zealand',
#   'Rwanda',
#   'Armenia',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Tanzania',
#   'Eritrea',
#   'Kazakhstan',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Tajikistan',
#   'Morocco',
#   'Mauritania',
#   'Paraguay',
#   'Czechoslovakia',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'Iran',
#   'Norway',
#   'Denmark',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Peru',
#   'South Africa',
#   'Papua New Guinea',
#   'Kuwait',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Guinea-Bissau',
#   'Republic of the Congo',
#   'Equatorial Guinea',
#   'Gambia',
#   'Lebanon',
#   'Albania',
#   'Taiwan',
#   'Venezuela',
#   'Argentina',
#   'Finland',
#   'Sierra Leone',
#   'Switzerland',
#   'Nicaragua',
#   'Netherlands',
#   'Mali',
#   'United Arab Emirates',
#   'Benin',
#   'Democratic Republic of the Congo',
#   'Slovak Republic',
#   'Moldova',
#   'United States',
#   'Liberia'],
#  'Telephones And Videophones': ['Chile',
#   'Japan',
#   'Romania',
#   'Spain',
#   'Hungary',
#   'Portugal',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Germany',
#   'Bangladesh',
#   'Iran (Islamic Republic of)',
#   'Finland',
#   'Iraq',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Italy',
#   'Denmark',
#   'Bulgaria',
#   'Czechia'],
#  'Television': ['Philippines',
#   'Lesotho',
#   'Belgium',
#   'Mauritius',
#   'South Korea',
#   'Japan',
#   'Libya',
#   'Namibia',
#   'Nepal',
#   'Portugal',
#   'Estonia',
#   'Costa Rica',
#   'Poland',
#   'Mongolia',
#   'India',
#   'Malaysia',
#   'Georgia',
#   'Greece',
#   'Czech Republic',
#   'Bangladesh',
#   'Suriname',
#   'Zimbabwe',
#   'Oman',
#   'Guatemala',
#   'Pakistan',
#   'Canada',
#   'South Vietnam',
#   'Vietnam',
#   'Zambia',
#   'Azerbaijan',
#   'Nigeria',
#   'Croatia',
#   'Sweden',
#   'Laos',
#   'Egypt',
#   'Sudan',
#   'Jordan',
#   'Singapore',
#   'Panama',
#   'Somalia',
#   'Italy',
#   'Iceland',
#   'Macedonia',
#   'Ireland',
#   'Belarus',
#   'Luxembourg',
#   'Ethiopia',
#   'Ghana',
#   'Indonesia',
#   'Botswana',
#   'Australia',
#   'Afghanistan',
#   'Senegal',
#   'Hungary',
#   'Ivory Coast',
#   'Syria',
#   'Kenya',
#   'Thailand',
#   'Bosnia-Herzegovina',
#   'United Kingdom',
#   'Austria',
#   'Burkina Faso',
#   'Swaziland',
#   'Germany',
#   'Uruguay',
#   'Malawi',
#   'Iraq',
#   'Kyrgyzstan',
#   'Brazil',
#   'China',
#   'Lithuania',
#   'Turkey',
#   'Saudi Arabia',
#   'Haiti',
#   'Burma',
#   'Uzbekistan',
#   'Angola',
#   'Russia',
#   'Bolivia',
#   'Uganda',
#   'Belize',
#   'Cameroon',
#   'Guyana',
#   'Hong Kong',
#   'Chile',
#   'Ecuador',
#   'Latvia',
#   'El Salvador',
#   'Algeria',
#   'Romania',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Mexico',
#   'New Zealand',
#   'Rwanda',
#   'Armenia',
#   'Togo',
#   'Yemen',
#   'Gabon',
#   'Turkmenistan',
#   'Cambodia',
#   'Israel',
#   'Tanzania',
#   'Eritrea',
#   'Kazakhstan',
#   'Chad',
#   'Mozambique',
#   'Guinea',
#   'Tajikistan',
#   'Morocco',
#   'Mauritania',
#   'Paraguay',
#   'Czechoslovakia',
#   'Madagascar',
#   'Sri Lanka',
#   'Ukraine',
#   'Iran',
#   'Norway',
#   'Denmark',
#   'Tunisia',
#   'Bulgaria',
#   'Slovenia',
#   'Dominican Republic',
#   'Peru',
#   'South Africa',
#   'Papua New Guinea',
#   'Kuwait',
#   'Cuba',
#   'France',
#   'Spain',
#   'Burundi',
#   'Honduras',
#   'Guinea-Bissau',
#   'Republic of the Congo',
#   'Equatorial Guinea',
#   'Gambia',
#   'Lebanon',
#   'Albania',
#   'Taiwan',
#   'Venezuela',
#   'Argentina',
#   'Finland',
#   'Sierra Leone',
#   'Switzerland',
#   'Nicaragua',
#   'Netherlands',
#   'Mali',
#   'United Arab Emirates',
#   'Benin',
#   'Democratic Republic of the Congo',
#   'Slovak Republic',
#   'Moldova',
#   'United States',
#   'Liberia'],
#  'Television Receivers': ['Ecuador',
#   'Japan',
#   'Spain',
#   'Hungary',
#   'Portugal',
#   'Mongolia',
#   'Poland',
#   'Germany',
#   'Bangladesh',
#   'Finland',
#   'Slovakia',
#   'Iraq',
#   'Brazil',
#   'Turkey',
#   'Lithuania',
#   'Azerbaijan',
#   'Nigeria',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Italy',
#   'Denmark',
#   'Bulgaria',
#   'Czechia'],
#  'Tin': ['Bolivia',
#   'Thailand',
#   'Indonesia',
#   'Brazil',
#   'China',
#   'Australia',
#   'Malaysia',
#   'United States',
#   'World',
#   'Nigeria'],
#  'Titanium Sponge': ['World'],
#  'Transistors Per Microprocessor': ['World'],
#  'Turbo-Jets Of A Thrust Not Exceeding 25 Kn': ['United Kingdom'],
#  'Urea': ['World'],
#  'Vacuum Cleaners': ['Chile',
#   'Ecuador',
#   'France',
#   'Japan',
#   'Romania',
#   'Hungary',
#   'Portugal',
#   'Poland',
#   'United Kingdom',
#   'India',
#   'Bolivia (Plurinational State of)',
#   'Germany',
#   'Finland',
#   'Netherlands',
#   'Brazil',
#   'Turkey',
#   'Uzbekistan',
#   'Sweden',
#   'Egypt',
#   'Italy',
#   'Ireland',
#   'Denmark'],
#  'Vacuums': ['United States'],
#  'Videocassette Recorder': ['United States'],
#  'Vinyl Acetate': ['World'],
#  'Vinyl Chloride': ['World'],
#  'Washing Machines': ['World', 'US'],
#  'Water Heater': ['United States'],
#  'Wet Flue Gas Desulfurization Systems': ['World',
#   'Germany',
#   'Japan',
#   'United States'],
#  'Yfv Vaccine': ['Peru',
#   'Ecuador',
#   'Ghana',
#   'Senegal',
#   'Niger',
#   'Colombia',
#   'Central African Republic',
#   'Kenya',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Guinea-Bissau',
#   'Equatorial Guinea',
#   'Togo',
#   'Congo',
#   'Gabon',
#   'Gambia',
#   'Bolivia (Plurinational State of)',
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Suriname',
#   'Argentina',
#   'Chad',
#   "Cote d'Ivoire",
#   'Sierra Leone',
#   'Brazil',
#   'Guinea',
#   'Nigeria',
#   'Angola',
#   'Mali',
#   'Benin',
#   'Democratic Republic of the Congo',
#   'Panama',
#   'Paraguay',
#   'Cameroon',
#   'Guyana',
#   'Liberia'],
#  'Zinc': ['Peru',
#   'Mexico',
#   'Argentina',
#   'Korea',
#   'Canada',
#   'Algeria',
#   'World',
#   'China',
#   'Australia',
#   'Brazil',
#   'Japan',
#   'United States',
#   'Zaire',
#   'Zambia',
#   'North Korea',
#   'India',
#   'South Korea',
#   'United States of America'],
#  'Zinc-Based Battery': ['Indonesia', 'United States', 'Madagascar']}

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict
# Out:
# {'Acrylic Fiber': 1,
#  'Acrylonitrile': 1,
#  'Air-Source Heat Pumps': 1,
#  'Amazon Prime Users': 1,
#  'Aniline': 1,
#  'Automatic Transmission': 1,
#  'Benzene': 1,
#  'Bicycles': 1,
#  'Bisphenol A': 1,
#  'Cable Tv': 1,
#  'Canals': 1,
#  'Caprolactam': 1,
#  'Carbon Capture & Sequestration': 1,
#  'Central Heating': 1,
#  'Coal Power': 1,
#  'Colour Tv': 1,
#  'Compact Fluorescent Light Bulbs': 1,
#  'Computing Growth': 1,
#  'Concentrated Solar Power': 1,
#  'Cyclohexane': 1,
#  'Desalination Capacity': 1,
#  'Dishwashers': 1,
#  'Disk Brakes': 1,
#  'Ebook Reader': 1,
#  'Electric Range': 1,
#  'Electronic Ignition': 1,
#  'Ethanolamine': 1,
#  'Ethyl Alcohol': 1,
#  'Ethylene': 1,
#  'Ethylene Glycol': 1,
#  'Flush Toilet': 1,
#  'Formaldehyde': 1,
#  'Freezer': 1,
#  'Ground Source Heat Pumps': 1,
#  'Herbicide-Tolerant Corn': 1,
#  'Herbicide-Tolerant Cotton': 1,
#  'Herbicide-Tolerant Soybeans': 1,
#  'High-Density Polyethylene': 1,
#  'High-Speed Rail': 1,
#  'Home Air Conditioning': 1,
#  'Home Computers': 1,
#  'Household Internet Access': 1,
#  'Households With Only Mobile Phones (No Landlines)': 1,
#  'Hydrofluoric Acid': 1,
#  'Insect-Resistant Corn': 1,
#  'Insect-Resistant Cotton': 1,
#  'Internet Backbone Bandwidth': 1,
#  'Internet Traffic': 1,
#  'Iron': 1,
#  'Jet Aircraft': 1,
#  'Low-Density Polyethylene': 1,
#  'Magnesium': 1,
#  'Magnetic Data Storage': 1,
#  'Maleic Anhydride': 1,
#  'Methanol': 1,
#  'Microcomputers': 1,
#  'Microprocessor Clock Speed': 1,
#  'Microwaves': 1,
#  'Motor Gasoline': 1,
#  'Motorcycles': 1,
#  'Natural Gas Pipeline': 1,
#  'Natural Gas Power': 1,
#  'Neoprene Rubber': 1,
#  'Nox Pollution Controls (Boilers)': 1,
#  'Oil Pipeline': 1,
#  'Paraxylene': 1,
#  'Pentaerythritol': 1,
#  'Phenol': 1,
#  'Phthalic Anhydride': 1,
#  'Podcasting': 1,
#  'Polyester Fiber': 1,
#  'Polystyrene': 1,
#  'Polyvinylchloride': 1,
#  'Power Steering': 1,
#  'Primary Magnesium': 1,
#  'Processor Performance': 1,
#  'Public Roads': 1,
#  'Radial Tires': 1,
#  'Random Access Memory': 1,
#  'Real-Time Gross Settlement Adoption': 1,
#  'Running Water': 1,
#  'Shale Production': 1,
#  'Shotgun Sanger Dna Sequencing': 1,
#  'Smartphone Usage': 1,
#  'Social Media Usage': 1,
#  'Sodium': 1,
#  'Sodium Chlorate': 1,
#  'Stationary Steam Engines': 1,
#  'Steam Locomotives': 1,
#  'Stove': 1,
#  'Styrene': 1,
#  'Submarine Cables': 1,
#  'Tablet': 1,
#  'Titanium Sponge': 1,
#  'Transistors Per Microprocessor': 1,
#  'Turbo-Jets Of A Thrust Not Exceeding 25 Kn': 1,
#  'Urea': 1,
#  'Vacuums': 1,
#  'Videocassette Recorder': 1,
#  'Vinyl Acetate': 1,
#  'Vinyl Chloride': 1,
#  'Water Heater': 1,
#  'Cement Production': 2,
#  'Electric Bicycles': 2,
#  'Fluid Catalytic Cracking Refineries': 2,
#  'Laundry Dryers': 2,
#  'Liquefied Natural Gas': 2,
#  'Primary Copper Production': 2,
#  'Refrigerators': 2,
#  'Sand And Gravel Production (Construction)': 2,
#  'Sand And Gravel Production (Industrial)': 2,
#  'Washing Machines': 2,
#  'Zinc-Based Battery': 3,
#  'Latent Heat Storage': 4,
#  'Nickel-Based Battery': 4,
#  'Wet Flue Gas Desulfurization Systems': 4,
#  'Electro-Chemical Capacitor': 6,
#  'Hydrogen Storage': 6,
#  'Compressed Air Energy Storage': 7,
#  'Nuclear Weapons': 8,
#  'Nitric Acid': 9,
#  'Lithium Mine Production': 10,
#  'Rare Earth Mine Production': 10,
#  'Sensible Heat Storage': 10,
#  'Tin': 10,
#  'Heat Thermal Battery Storage': 11,
#  'Microwave Ovens': 11,
#  'Nickel Production': 12,
#  'Ammonia Synthesis': 13,
#  'Hydrochloric Acid': 13,
#  'Cobalt Mine Production': 14,
#  'Graphite Mine Production': 14,
#  'Silver': 14,
#  'Flywheel Battery Storage': 15,
#  'Gold Production': 16,
#  'Potassic Fertilizers': 16,
#  'Sodium-Based Battery Storage': 16,
#  'Lead-Acid Battery Storage': 18,
#  'Liquid Biofuels': 18,
#  'Zinc': 18,
#  'Marine Energy': 19,
#  'Offshore Wind Energy': 19,
#  'Steam Ships': 20,
#  'Combined Refrigerators-Freezers': 22,
#  'Refined Copper': 22,
#  'Solar Thermal Energy': 22,
#  'Vacuum Cleaners': 22,
#  'Radio Receivers': 23,
#  'Household Washing And Drying Machines': 24,
#  'Synthetic Filament Tow And Staple Fibers': 24,
#  'Telephones And Videophones': 24,
#  'Television Receivers': 24,
#  'All Biofuels': 25,
#  'Flow Battery Storage': 25,
#  'Motorcycles And Scooters': 25,
#  'Household Refrigerators And Freezers': 26,
#  'Synthetic Filament Yarn': 27,
#  'Electric Water Heaters And Immersion Heaters': 30,
#  'Geothermal Energy': 32,
#  'Nitrogenous Fertilizers': 32,
#  'Air Conditioning Machines': 35,
#  'Yfv Vaccine': 36,
#  'Bicycles And Other Cycles': 37,
#  'Primary Bauxite Production': 38,
#  'Cadmium Refining': 39,
#  'Synthetic Filaments': 39,
#  'Coal Production': 40,
#  'Caustic Soda': 41,
#  'Cane Sugar Production': 42,
#  'Pumped Hydro Storage': 44,
#  'Lithium-Ion Battery Storage': 47,
#  'Oil Production': 51,
#  'Natural Gas Production': 52,
#  'Sulphuric Acid': 52,
#  'Copper Refining': 58,
#  'Primary Aluminum Production': 58,
#  'Beer': 60,
#  'Crude Oil': 61,
#  'Lead Mine Production': 63,
#  'Iron Ore': 64,
#  'Cotton Seed Production': 66,
#  'Sugar Cane Production': 68,
#  'Copper Mining': 69,
#  'Oil Refining Capacity': 75,
#  'Telegraph Traffic': 76,
#  'Electricity': 80,
#  'Postal Traffic': 80,
#  'Hydroelectricity': 81,
#  'Nuclear Energy': 81,
#  'Renewable Power': 81,
#  'Soybean Production': 85,
#  'Space Launches': 92,
#  'Biogas': 95,
#  'Milk Production': 98,
#  'Beer Production': 102,
#  'Solid Biofuels': 102,
#  'Hepbb Vaccine': 105,
#  'Raw Steel Production': 106,
#  'Crop Harvester': 118,
#  'Rotac Vaccine': 118,
#  'Salt Production': 125,
#  'Railroad': 128,
#  'Corn Production': 141,
#  "Cow'S Milk Production": 149,
#  'Cellphones': 153,
#  'Pcv3 Vaccine': 153,
#  'Radio': 155,
#  'Telephones': 155,
#  'Television': 155,
#  'Passenger Cars': 161,
#  'Bcg Vaccine': 168,
#  'Potash Fertilizer': 169,
#  'Nitrogen Fertilizer': 172,
#  'Phosphate Fertilizer': 172,
#  'Rcv1 Vaccine': 173,
#  'Mcv2 Vaccine': 183,
#  'Hepb3 Vaccine': 191,
#  'Hib3 Vaccine': 193,
#  'Solar Photovoltaic': 193,
#  'Dtp1 Vaccine': 195,
#  'Dtp3 Vaccine': 195,
#  'Ipv1 Vaccine': 195,
#  'Mcv1 Vaccine': 195,
#  'Pol3 Vaccine': 195,
#  'Aquaculture Production': 196,
#  'Capture Fisheries Production': 216,
#  'Onshore Wind Energy': 227}

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)
# Out:
# Zinc-Based Battery
# Latent Heat Storage
# Nickel-Based Battery
# Wet Flue Gas Desulfurization Systems
# Electro-Chemical Capacitor
# Hydrogen Storage
# Compressed Air Energy Storage
# Nuclear Weapons
# Nitric Acid
# Lithium Mine Production
# Rare Earth Mine Production
# Sensible Heat Storage
# Tin
# Heat Thermal Battery Storage
# Microwave Ovens
# Nickel Production
# Ammonia Synthesis
# Hydrochloric Acid
# Cobalt Mine Production
# Graphite Mine Production
# Silver
# Flywheel Battery Storage
# Gold Production
# Potassic Fertilizers
# Sodium-Based Battery Storage
# Lead-Acid Battery Storage
# Liquid Biofuels
# Zinc
# Marine Energy
# Offshore Wind Energy
# Steam Ships
# Combined Refrigerators-Freezers
# Refined Copper
# Solar Thermal Energy
# Vacuum Cleaners
# Radio Receivers
# Household Washing And Drying Machines
# Synthetic Filament Tow And Staple Fibers
# Telephones And Videophones
# Television Receivers
# All Biofuels
# Flow Battery Storage
# Motorcycles And Scooters
# Household Refrigerators And Freezers
# Synthetic Filament Yarn
# Electric Water Heaters And Immersion Heaters
# Geothermal Energy
# Nitrogenous Fertilizers
# Air Conditioning Machines
# Yfv Vaccine
# Bicycles And Other Cycles
# Primary Bauxite Production
# Cadmium Refining
# Synthetic Filaments
# Coal Production
# Caustic Soda
# Cane Sugar Production
# Pumped Hydro Storage
# Lithium-Ion Battery Storage
# Oil Production
# Natural Gas Production
# Sulphuric Acid
# Copper Refining
# Primary Aluminum Production
# Beer
# Crude Oil
# Lead Mine Production
# Iron Ore
# Cotton Seed Production
# Sugar Cane Production
# Copper Mining
# Oil Refining Capacity
# Telegraph Traffic
# Electricity
# Postal Traffic
# Hydroelectricity
# Nuclear Energy
# Renewable Power
# Soybean Production
# Space Launches
# Biogas
# Milk Production
# Beer Production
# Solid Biofuels
# Hepbb Vaccine
# Raw Steel Production
# Crop Harvester
# Rotac Vaccine
# Salt Production
# Railroad
# Corn Production
# Cow'S Milk Production
# Cellphones
# Pcv3 Vaccine
# Radio
# Telephones
# Television
# Passenger Cars
# Bcg Vaccine
# Potash Fertilizer
# Nitrogen Fertilizer
# Phosphate Fertilizer
# Rcv1 Vaccine
# Mcv2 Vaccine
# Hepb3 Vaccine
# Hib3 Vaccine
# Solar Photovoltaic
# Dtp1 Vaccine
# Dtp3 Vaccine
# Ipv1 Vaccine
# Mcv1 Vaccine
# Pol3 Vaccine
# Aquaculture Production
# Capture Fisheries Production
# Onshore Wind Energy

# %%
cost_data = all_tech[(all_tech['Metric']=='Price') | (all_tech['Metric']=='Total Installed Cost') | (all_tech['Metric']=='Levelized Cost of Energy')]
cost_list = list(set(cost_data['Technology Name']))
print(len(cost_list))
cost_list
# Out:
# 92
# ['All Biofuels',
#  'Magnesium',
#  'Styrene',
#  'Polyester Fiber',
#  'Coal Production',
#  'Radio Receivers',
#  'Sodium Chlorate',
#  'Synthetic Filament Yarn',
#  'Corn Production',
#  'Beer',
#  'Vinyl Chloride',
#  'Vinyl Acetate',
#  'Cotton Seed Production',
#  'Maleic Anhydride',
#  'Turbo-Jets Of A Thrust Not Exceeding 25 Kn',
#  'Salt Production',
#  'Cement Production',
#  'Solar Photovoltaic',
#  'Nickel Production',
#  'Natural Gas Production',
#  'Bicycles And Other Cycles',
#  'Combined Refrigerators-Freezers',
#  'Primary Copper Production',
#  'Sugar Cane Production',
#  'Cyclohexane',
#  'Phthalic Anhydride',
#  'Urea',
#  'Household Refrigerators And Freezers',
#  'Ethylene Glycol',
#  'Graphite Mine Production',
#  'Onshore Wind Energy',
#  'Refined Copper',
#  'Vacuum Cleaners',
#  'Potassic Fertilizers',
#  'Benzene',
#  'Caprolactam',
#  'Liquefied Natural Gas',
#  'Polyvinylchloride',
#  'Ethylene',
#  'Phenol',
#  'Offshore Wind Energy',
#  'Primary Bauxite Production',
#  'Synthetic Filament Tow And Staple Fibers',
#  'Geothermal Energy',
#  'Ethyl Alcohol',
#  'Microwave Ovens',
#  'Titanium Sponge',
#  'Bisphenol A',
#  'Primary Aluminum Production',
#  "Cow'S Milk Production",
#  'Sand And Gravel Production (Industrial)',
#  'Passenger Cars',
#  'Caustic Soda',
#  'Household Washing And Drying Machines',
#  'Shotgun Sanger Dna Sequencing',
#  'Aniline',
#  'Acrylic Fiber',
#  'Crude Oil',
#  'Motor Gasoline',
#  'Hydrofluoric Acid',
#  'Neoprene Rubber',
#  'Cadmium Refining',
#  'Tin',
#  'Lithium Mine Production',
#  'Formaldehyde',
#  'Methanol',
#  'High-Density Polyethylene',
#  'Television Receivers',
#  'Gold Production',
#  'Low-Density Polyethylene',
#  'Primary Magnesium',
#  'Rare Earth Mine Production',
#  'Concentrated Solar Power',
#  'Acrylonitrile',
#  'Telephones And Videophones',
#  'Silver',
#  'Iron Ore',
#  'Lead Mine Production',
#  'Ethanolamine',
#  'Pentaerythritol',
#  'Electric Water Heaters And Immersion Heaters',
#  'Nitrogenous Fertilizers',
#  'Raw Steel Production',
#  'Zinc',
#  'Hydroelectricity',
#  'Motorcycles And Scooters',
#  'Sodium',
#  'Polystyrene',
#  'Air Conditioning Machines',
#  'Sand And Gravel Production (Construction)',
#  'Soybean Production',
#  'Paraxylene']

# %%
for tech in cost_list:
    tech_df = all_tech[all_tech['Technology Name']==tech]
    cap_price_tech = []
    tech_metrics = list(set(tech_df['Metric']))
    sources = list(set(tech_df['Data Source']))
    if len(tech_metrics) > 1 and len(sources) > 1:
        print(tech, sources)
# Out:
# All Biofuels ['BP', 'IRENA']
# Solar Photovoltaic ['IRENASTAT', 'IRENA']
# Nickel Production ['USGS', 'Mitchell']
# Graphite Mine Production ['BP', 'USGS']
# Onshore Wind Energy ['IRENASTAT', 'IRENA']
# Liquefied Natural Gas ['BP', 'EIA']
# Offshore Wind Energy ['IRENASTAT', 'IRENA']
# Geothermal Energy ['IRENASTAT', 'IRENA']
# Passenger Cars ['UN Industrial Statistics Database', 'CHAT', 'Wilson & Grubler']
# Caustic Soda ['UN Industrial Statistics Database', 'Mitchell']
# Crude Oil ['BP', 'PCDB', 'Mitchell']
# Tin ['USGS', 'Mitchell']
# Lithium Mine Production ['BP', 'USGS']
# Gold Production ['USGS', 'Mitchell']
# Rare Earth Mine Production ['BP', 'USGS']
# Concentrated Solar Power ['IPCC', 'IRENA']
# Silver ['USGS', 'Mitchell']
# Zinc ['USGS', 'Mitchell']
# Hydroelectricity ['BP', 'IRENA']

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-1972'

# %%
time_span('Ammonia Synthesis')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1905-2022'

# %%
time_span('Aquaculture Production')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-2020'

# %%
timespan_dict = {}
for tech in tech_list:
    timespan_dict[tech] = time_span(tech)
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_81081/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)

# %%
timespan_dict
# Out:
# {'Acrylic Fiber': '1960-1972',
#  'Acrylonitrile': '1959-1972',
#  'Air Conditioning Machines': '1995-2016',
#  'Air-Source Heat Pumps': '2003-2022',
#  'All Biofuels': '1990-2021',
#  'Amazon Prime Users': '2014-2018',
#  'Ammonia Synthesis': '1905-2022',
#  'Aniline': '1961-1972',
#  'Aquaculture Production': '1960-2020',
#  'Automatic Transmission': '1910-1984',
#  'Bcg Vaccine': '1980-2021',
#  'Beer': '1995-2016',
#  'Beer Production': '1750-2007',
#  'Benzene': '1952-1968',
#  'Bicycles': '1861-2007',
#  'Bicycles And Other Cycles': '1995-2016',
#  'Biogas': '2000-2021',
#  'Bisphenol A': '1959-1972',
#  'Cable Tv': '1968-1997',
#  'Cadmium Refining': '1900-2019',
#  'Canals': '1794-1861',
#  'Cane Sugar Production': '1750-2010',
#  'Caprolactam': '1962-1972',
#  'Capture Fisheries Production': '1960-2020',
#  'Carbon Capture & Sequestration': '1971-2019',
#  'Caustic Soda': '1899-2016',
#  'Cellphones': '1975-2010',
#  'Cement Production': '1900-2019',
#  'Central Heating': '1900-1970',
#  'Coal Power': '1908-2000',
#  'Coal Production': '1981-2021',
#  'Cobalt Mine Production': '1995-2021',
#  'Colour Tv': '1966-2005',
#  'Combined Refrigerators-Freezers': '1995-2016',
#  'Compact Fluorescent Light Bulbs': '1990-2003',
#  'Compressed Air Energy Storage': '1991-2020',
#  'Computing Growth': '1900-1998',
#  'Concentrated Solar Power': '1985-2022',
#  'Copper Mining': '1990-2011',
#  'Copper Refining': '1990-2011',
#  'Corn Production': '1991-2022',
#  'Cotton Seed Production': '1991-2022',
#  "Cow'S Milk Production": '1991-2022',
#  'Crop Harvester': '1961-2001',
#  'Crude Oil': '1860-2021',
#  'Cyclohexane': '1956-1972',
#  'Desalination Capacity': '1960-2020',
#  'Dishwashers': '1922-2011',
#  'Disk Brakes': '1966-1984',
#  'Dtp1 Vaccine': '1980-2021',
#  'Dtp3 Vaccine': '1980-2021',
#  'Ebook Reader': '2009-2018',
#  'Electric Bicycles': '1997-2010',
#  'Electric Range': '1933-1986',
#  'Electric Water Heaters And Immersion Heaters': '1995-2016',
#  'Electricity': '1985-2021',
#  'Electro-Chemical Capacitor': '2012-2016',
#  'Electronic Ignition': '1962-1984',
#  'Ethanolamine': '1955-1972',
#  'Ethyl Alcohol': '1958-1972',
#  'Ethylene': '1953-1968',
#  'Ethylene Glycol': '1960-1972',
#  'Flow Battery Storage': '2000-2018',
#  'Fluid Catalytic Cracking Refineries': '1940-2007',
#  'Flush Toilet': '1860-1989',
#  'Flywheel Battery Storage': '2006-2020',
#  'Formaldehyde': '1962-1972',
#  'Freezer': '1950-2011',
#  'Geothermal Energy': '2000-2021',
#  'Gold Production': '1851-2018',
#  'Graphite Mine Production': '1900-2021',
#  'Ground Source Heat Pumps': '1995-2020',
#  'Heat Thermal Battery Storage': '2007-2017',
#  'Hepb3 Vaccine': '1989-2021',
#  'Hepbb Vaccine': '2000-2021',
#  'Herbicide-Tolerant Corn': '1996-2022',
#  'Herbicide-Tolerant Cotton': '1996-2022',
#  'Herbicide-Tolerant Soybeans': '1996-2022',
#  'Hib3 Vaccine': '1991-2021',
#  'High-Density Polyethylene': '1958-1972',
#  'High-Speed Rail': '1964-2021',
#  'Home Air Conditioning': '1957-2011',
#  'Home Computers': '1992-2016',
#  'Household Internet Access': '1993-2016',
#  'Household Refrigerators And Freezers': '1995-2016',
#  'Household Washing And Drying Machines': '1995-2016',
#  'Households With Only Mobile Phones (No Landlines)': '2013-2018',
#  'Hydrochloric Acid': '1929-2003',
#  'Hydroelectricity': '1965-2021',
#  'Hydrofluoric Acid': '1962-1972',
#  'Hydrogen Storage': '2012-2017',
#  'Insect-Resistant Corn': '1996-2022',
#  'Insect-Resistant Cotton': '1996-2022',
#  'Internet Backbone Bandwidth': '1968-2004',
#  'Internet Traffic': '1984-2014',
#  'Ipv1 Vaccine': '2015-2021',
#  'Iron': '1933-1970',
#  'Iron Ore': '1900-2019',
#  'Jet Aircraft': '1958-2007',
#  'Latent Heat Storage': '1991-2017',
#  'Laundry Dryers': '1920-2006',
#  'Lead Mine Production': '1900-2018',
#  'Lead-Acid Battery Storage': '1987-2020',
#  'Liquefied Natural Gas': '1984-2021',
#  'Liquid Biofuels': '2001-2021',
#  'Lithium Mine Production': '1900-2021',
#  'Lithium-Ion Battery Storage': '2008-2021',
#  'Low-Density Polyethylene': '1958-1972',
#  'Magnesium': '1954-1972',
#  'Magnetic Data Storage': '1952-2004',
#  'Maleic Anhydride': '1959-1972',
#  'Marine Energy': '2000-2021',
#  'Mcv1 Vaccine': '1980-2021',
#  'Mcv2 Vaccine': '2000-2021',
#  'Methanol': '1957-1972',
#  'Microcomputers': '1984-2016',
#  'Microprocessor Clock Speed': '1976-2016',
#  'Microwave Ovens': '1995-2016',
#  'Microwaves': '1975-2017',
#  'Milk Production': '1889-2010',
#  'Motor Gasoline': '1946-1968',
#  'Motorcycles': '1900-2008',
#  'Motorcycles And Scooters': '1996-2016',
#  'Natural Gas Pipeline': '1960-2021',
#  'Natural Gas Power': '1903-2000',
#  'Natural Gas Production': '1970-2021',
#  'Neoprene Rubber': '1960-1972',
#  'Nickel Production': '1889-2018',
#  'Nickel-Based Battery': '2003-2015',
#  'Nitric Acid': '1929-2003',
#  'Nitrogen Fertilizer': '1961-2020',
#  'Nitrogenous Fertilizers': '1995-2016',
#  'Nox Pollution Controls (Boilers)': '1990-2005',
#  'Nuclear Energy': '1965-2021',
#  'Nuclear Weapons': '1945-2010',
#  'Offshore Wind Energy': '2000-2021',
#  'Oil Pipeline': '2001-2021',
#  'Oil Production': '1965-2021',
#  'Oil Refining Capacity': '1965-2021',
#  'Onshore Wind Energy': '1983-2022',
#  'Paraxylene': '1957-1968',
#  'Passenger Cars': '1895-2016',
#  'Pcv3 Vaccine': '2008-2021',
#  'Pentaerythritol': '1952-1972',
#  'Phenol': '1959-1972',
#  'Phosphate Fertilizer': '1961-2020',
#  'Phthalic Anhydride': '1955-1972',
#  'Podcasting': '2006-2015',
#  'Pol3 Vaccine': '1980-2021',
#  'Polyester Fiber': '1960-1972',
#  'Polystyrene': '1943-1968',
#  'Polyvinylchloride': '1946-1968',
#  'Postal Traffic': '1830-2000',
#  'Potash Fertilizer': '1961-2020',
#  'Potassic Fertilizers': '1999-2016',
#  'Power Steering': '1951-1984',
#  'Primary Aluminum Production': '1900-2019',
#  'Primary Bauxite Production': '1900-2019',
#  'Primary Copper Production': '1900-2018',
#  'Primary Magnesium': '1929-1968',
#  'Processor Performance': '1971-2002',
#  'Public Roads': '1900-2020',
#  'Pumped Hydro Storage': '1944-2020',
#  'Radial Tires': '1972-1984',
#  'Radio': '1815-2000',
#  'Radio Receivers': '1995-2016',
#  'Railroad': '1825-2004',
#  'Random Access Memory': '1949-2004',
#  'Rare Earth Mine Production': '1900-2021',
#  'Raw Steel Production': '1900-2019',
#  'Rcv1 Vaccine': '1980-2021',
#  'Real-Time Gross Settlement Adoption': '1970-2005',
#  'Refined Copper': '1995-2016',
#  'Refrigerators': '1918-2009',
#  'Renewable Power': '1965-2021',
#  'Rotac Vaccine': '2006-2021',
#  'Running Water': '1890-1989',
#  'Salt Production': '1900-2017',
#  'Sand And Gravel Production (Construction)': '1902-2019',
#  'Sand And Gravel Production (Industrial)': '1902-2019',
#  'Sensible Heat Storage': '1982-2018',
#  'Shale Production': '2007-2019',
#  'Shotgun Sanger Dna Sequencing': '2001-2009',
#  'Silver': '1874-2018',
#  'Smartphone Usage': '2011-2019',
#  'Social Media Usage': '2005-2019',
#  'Sodium': '1957-1972',
#  'Sodium Chlorate': '1958-1972',
#  'Sodium-Based Battery Storage': '1999-2019',
#  'Solar Photovoltaic': '2000-2021',
#  'Solar Thermal Energy': '2000-2021',
#  'Solid Biofuels': '2000-2021',
#  'Soybean Production': '1991-2022',
#  'Space Launches': '1957-2022',
#  'Stationary Steam Engines': '1720-1920',
#  'Steam Locomotives': '1830-1920',
#  'Steam Ships': '1814-1998',
#  'Stove': '1900-2011',
#  'Styrene': '1958-1972',
#  'Submarine Cables': '1989-2021',
#  'Sugar Cane Production': '1991-2022',
#  'Sulphuric Acid': '1860-2003',
#  'Synthetic Filament Tow And Staple Fibers': '1995-2016',
#  'Synthetic Filament Yarn': '1995-2016',
#  'Synthetic Filaments': '1910-2003',
#  'Tablet': '2010-2017',
#  'Telegraph Traffic': '1830-2000',
#  'Telephones': '1876-2003',
#  'Telephones And Videophones': '1995-2016',
#  'Television': '1946-2002',
#  'Television Receivers': '1997-2016',
#  'Tin': '1900-2019',
#  'Titanium Sponge': '1950-1968',
#  'Transistors Per Microprocessor': '1971-2003',
#  'Turbo-Jets Of A Thrust Not Exceeding 25 Kn': '1995-1999',
#  'Urea': '1961-1972',
#  'Vacuum Cleaners': '1995-2016',
#  'Vacuums': '1922-1978',
#  'Videocassette Recorder': '1992-2011',
#  'Vinyl Acetate': '1960-1972',
#  'Vinyl Chloride': '1962-1972',
#  'Washing Machines': '1920-2008',
#  'Water Heater': '1933-1986',
#  'Wet Flue Gas Desulfurization Systems': '1972-1999',
#  'Yfv Vaccine': '1997-2021',
#  'Zinc': '1860-2019',
#  'Zinc-Based Battery': '2013-2020'}

# %%
timespan_dict_lower = {}
for item in timespan_dict:
    timespan_dict_lower[item.lower()] = timespan_dict[item]
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air conditioning machines': '1995-2016',
#  'air-source heat pumps': '2003-2022',
#  'all biofuels': '1990-2021',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2022',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer': '1995-2016',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'bicycles and other cycles': '1995-2016',
#  'biogas': '2000-2021',
#  'bisphenol a': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1900-2019',
#  'canals': '1794-1861',
#  'cane sugar production': '1750-2010',
#  'caprolactam': '1962-1972',
#  'capture fisheries production': '1960-2020',
#  'carbon capture & sequestration': '1971-2019',
#  'caustic soda': '1899-2016',
#  'cellphones': '1975-2010',
#  'cement production': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt mine production': '1995-2021',
#  'colour tv': '1966-2005',
#  'combined refrigerators-freezers': '1995-2016',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'copper mining': '1990-2011',
#  'copper refining': '1990-2011',
#  'corn production': '1991-2022',
#  'cotton seed production': '1991-2022',
#  "cow's milk production": '1991-2022',
#  'crop harvester': '1961-2001',
#  'crude oil': '1860-2021',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electric water heaters and immersion heaters': '1995-2016',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanolamine': '1955-1972',
#  'ethyl alcohol': '1958-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold production': '1851-2018',
#  'graphite mine production': '1900-2021',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'household refrigerators and freezers': '1995-2016',
#  'household washing and drying machines': '1995-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1900-2019',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead mine production': '1900-2018',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1900-2021',
#  'lithium-ion battery storage': '2008-2021',
#  'low-density polyethylene': '1958-1972',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwave ovens': '1995-2016',
#  'microwaves': '1975-2017',
#  'milk production': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'motorcycles and scooters': '1996-2016',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel production': '1889-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nitrogenous fertilizers': '1995-2016',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2016',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'potassic fertilizers': '1999-2016',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1900-2019',
#  'primary bauxite production': '1900-2019',
#  'primary copper production': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'radio receivers': '1995-2016',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1900-2021',
#  'raw steel production': '1900-2019',
#  'rcv1 vaccine': '1980-2021',
#  'real-time gross settlement adoption': '1970-2005',
#  'refined copper': '1995-2016',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'running water': '1890-1989',
#  'salt production': '1900-2017',
#  'sand and gravel production (construction)': '1902-2019',
#  'sand and gravel production (industrial)': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2018',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'soybean production': '1991-2022',
#  'space launches': '1957-2022',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steam ships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sugar cane production': '1991-2022',
#  'sulphuric acid': '1860-2003',
#  'synthetic filament tow and staple fibers': '1995-2016',
#  'synthetic filament yarn': '1995-2016',
#  'synthetic filaments': '1910-2003',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'telephones and videophones': '1995-2016',
#  'television': '1946-2002',
#  'television receivers': '1997-2016',
#  'tin': '1900-2019',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'turbo-jets of a thrust not exceeding 25 kn': '1995-1999',
#  'urea': '1961-1972',
#  'vacuum cleaners': '1995-2016',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2019',
#  'zinc-based battery': '2013-2020'}

# %%
timespan_dict_lower = dict(sorted(timespan_dict_lower.items(), key=lambda item: item[0])) 
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air conditioning machines': '1995-2016',
#  'air-source heat pumps': '2003-2022',
#  'all biofuels': '1990-2021',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2022',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer': '1995-2016',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'bicycles and other cycles': '1995-2016',
#  'biogas': '2000-2021',
#  'bisphenol a': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1900-2019',
#  'canals': '1794-1861',
#  'cane sugar production': '1750-2010',
#  'caprolactam': '1962-1972',
#  'capture fisheries production': '1960-2020',
#  'carbon capture & sequestration': '1971-2019',
#  'caustic soda': '1899-2016',
#  'cellphones': '1975-2010',
#  'cement production': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt mine production': '1995-2021',
#  'colour tv': '1966-2005',
#  'combined refrigerators-freezers': '1995-2016',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'copper mining': '1990-2011',
#  'copper refining': '1990-2011',
#  'corn production': '1991-2022',
#  'cotton seed production': '1991-2022',
#  "cow's milk production": '1991-2022',
#  'crop harvester': '1961-2001',
#  'crude oil': '1860-2021',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electric water heaters and immersion heaters': '1995-2016',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanolamine': '1955-1972',
#  'ethyl alcohol': '1958-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold production': '1851-2018',
#  'graphite mine production': '1900-2021',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'household refrigerators and freezers': '1995-2016',
#  'household washing and drying machines': '1995-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1900-2019',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead mine production': '1900-2018',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1900-2021',
#  'lithium-ion battery storage': '2008-2021',
#  'low-density polyethylene': '1958-1972',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwave ovens': '1995-2016',
#  'microwaves': '1975-2017',
#  'milk production': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'motorcycles and scooters': '1996-2016',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel production': '1889-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nitrogenous fertilizers': '1995-2016',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2016',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'potassic fertilizers': '1999-2016',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1900-2019',
#  'primary bauxite production': '1900-2019',
#  'primary copper production': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'radio receivers': '1995-2016',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1900-2021',
#  'raw steel production': '1900-2019',
#  'rcv1 vaccine': '1980-2021',
#  'real-time gross settlement adoption': '1970-2005',
#  'refined copper': '1995-2016',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'running water': '1890-1989',
#  'salt production': '1900-2017',
#  'sand and gravel production (construction)': '1902-2019',
#  'sand and gravel production (industrial)': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2018',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'soybean production': '1991-2022',
#  'space launches': '1957-2022',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steam ships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sugar cane production': '1991-2022',
#  'sulphuric acid': '1860-2003',
#  'synthetic filament tow and staple fibers': '1995-2016',
#  'synthetic filament yarn': '1995-2016',
#  'synthetic filaments': '1910-2003',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'telephones and videophones': '1995-2016',
#  'television': '1946-2002',
#  'television receivers': '1997-2016',
#  'tin': '1900-2019',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'turbo-jets of a thrust not exceeding 25 kn': '1995-1999',
#  'urea': '1961-1972',
#  'vacuum cleaners': '1995-2016',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2019',
#  'zinc-based battery': '2013-2020'}

# %%
for item in timespan_dict_lower:
    print(timespan_dict_lower[item])
# Out:
# 1960-1972
# 1959-1972
# 1995-2016
# 2003-2022
# 1990-2021
# 2014-2018
# 1905-2022
# 1961-1972
# 1960-2020
# 1910-1984
# 1980-2021
# 1995-2016
# 1750-2007
# 1952-1968
# 1861-2007
# 1995-2016
# 2000-2021
# 1959-1972
# 1968-1997
# 1900-2019
# 1794-1861
# 1750-2010
# 1962-1972
# 1960-2020
# 1971-2019
# 1899-2016
# 1975-2010
# 1900-2019
# 1900-1970
# 1908-2000
# 1981-2021
# 1995-2021
# 1966-2005
# 1995-2016
# 1990-2003
# 1991-2020
# 1900-1998
# 1985-2022
# 1990-2011
# 1990-2011
# 1991-2022
# 1991-2022
# 1991-2022
# 1961-2001
# 1860-2021
# 1956-1972
# 1960-2020
# 1922-2011
# 1966-1984
# 1980-2021
# 1980-2021
# 2009-2018
# 1997-2010
# 1933-1986
# 1995-2016
# 1985-2021
# 2012-2016
# 1962-1984
# 1955-1972
# 1958-1972
# 1953-1968
# 1960-1972
# 2000-2018
# 1940-2007
# 1860-1989
# 2006-2020
# 1962-1972
# 1950-2011
# 2000-2021
# 1851-2018
# 1900-2021
# 1995-2020
# 2007-2017
# 1989-2021
# 2000-2021
# 1996-2022
# 1996-2022
# 1996-2022
# 1991-2021
# 1958-1972
# 1964-2021
# 1957-2011
# 1992-2016
# 1993-2016
# 1995-2016
# 1995-2016
# 2013-2018
# 1929-2003
# 1965-2021
# 1962-1972
# 2012-2017
# 1996-2022
# 1996-2022
# 1968-2004
# 1984-2014
# 2015-2021
# 1933-1970
# 1900-2019
# 1958-2007
# 1991-2017
# 1920-2006
# 1900-2018
# 1987-2020
# 1984-2021
# 2001-2021
# 1900-2021
# 2008-2021
# 1958-1972
# 1954-1972
# 1952-2004
# 1959-1972
# 2000-2021
# 1980-2021
# 2000-2021
# 1957-1972
# 1984-2016
# 1976-2016
# 1995-2016
# 1975-2017
# 1889-2010
# 1946-1968
# 1900-2008
# 1996-2016
# 1960-2021
# 1903-2000
# 1970-2021
# 1960-1972
# 1889-2018
# 2003-2015
# 1929-2003
# 1961-2020
# 1995-2016
# 1990-2005
# 1965-2021
# 1945-2010
# 2000-2021
# 2001-2021
# 1965-2021
# 1965-2021
# 1983-2022
# 1957-1968
# 1895-2016
# 2008-2021
# 1952-1972
# 1959-1972
# 1961-2020
# 1955-1972
# 2006-2015
# 1980-2021
# 1960-1972
# 1943-1968
# 1946-1968
# 1830-2000
# 1961-2020
# 1999-2016
# 1951-1984
# 1900-2019
# 1900-2019
# 1900-2018
# 1929-1968
# 1971-2002
# 1900-2020
# 1944-2020
# 1972-1984
# 1815-2000
# 1995-2016
# 1825-2004
# 1949-2004
# 1900-2021
# 1900-2019
# 1980-2021
# 1970-2005
# 1995-2016
# 1918-2009
# 1965-2021
# 2006-2021
# 1890-1989
# 1900-2017
# 1902-2019
# 1902-2019
# 1982-2018
# 2007-2019
# 2001-2009
# 1874-2018
# 2011-2019
# 2005-2019
# 1957-1972
# 1958-1972
# 1999-2019
# 2000-2021
# 2000-2021
# 2000-2021
# 1991-2022
# 1957-2022
# 1720-1920
# 1830-1920
# 1814-1998
# 1900-2011
# 1958-1972
# 1989-2021
# 1991-2022
# 1860-2003
# 1995-2016
# 1995-2016
# 1910-2003
# 2010-2017
# 1830-2000
# 1876-2003
# 1995-2016
# 1946-2002
# 1997-2016
# 1900-2019
# 1950-1968
# 1971-2003
# 1995-1999
# 1961-1972
# 1995-2016
# 1922-1978
# 1992-2011
# 1960-1972
# 1962-1972
# 1920-2008
# 1933-1986
# 1972-1999
# 1997-2021
# 1860-2019
# 2013-2020

# %%
def metric(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    metric = set(tech_df['Metric'])
    return metric

# %%
metric_dict = {}
for tech in tech_list:
    metric_dict[tech] = metric(tech)
metric_dict
# Out:
# {'Acrylic Fiber': {'Annual Production', 'Price'},
#  'Acrylonitrile': {'Annual Production', 'Price'},
#  'Air Conditioning Machines': {'Price'},
#  'Air-Source Heat Pumps': {'Annual Production'},
#  'All Biofuels': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Amazon Prime Users': {'Share Of Households'},
#  'Ammonia Synthesis': {'Annual Production'},
#  'Aniline': {'Annual Production', 'Price'},
#  'Aquaculture Production': {'Annual Production'},
#  'Automatic Transmission': {'Share Of Market'},
#  'Bcg Vaccine': {'Share Of Population'},
#  'Beer': {'Price'},
#  'Beer Production': {'Annual Production'},
#  'Benzene': {'Annual Production', 'Price'},
#  'Bicycles': {'Cumulative Total Capacity'},
#  'Bicycles And Other Cycles': {'Price'},
#  'Biogas': {'Installed Electricity Capacity'},
#  'Bisphenol A': {'Annual Production', 'Price'},
#  'Cable Tv': {'Share Of Households'},
#  'Cadmium Refining': {'Annual Production', 'Price'},
#  'Canals': {'Total Length'},
#  'Cane Sugar Production': {'Annual Production'},
#  'Caprolactam': {'Annual Production', 'Price'},
#  'Capture Fisheries Production': {'Annual Production'},
#  'Carbon Capture & Sequestration': {'Installed Capacity'},
#  'Caustic Soda': {'Annual Production', 'Price'},
#  'Cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'Cement Production': {'Annual Production', 'Price'},
#  'Central Heating': {'Share Of Households'},
#  'Coal Power': {'Cumulative Total Capacity'},
#  'Coal Production': {'Annual Production', 'Price'},
#  'Cobalt Mine Production': {'Annual Production'},
#  'Colour Tv': {'Share Of Households'},
#  'Combined Refrigerators-Freezers': {'Price'},
#  'Compact Fluorescent Light Bulbs': {'Cumulative Total Capacity'},
#  'Compressed Air Energy Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Computing Growth': {'Computing Capacity'},
#  'Concentrated Solar Power': {'Installed Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Copper Mining': {'Annual Production'},
#  'Copper Refining': {'Annual Production'},
#  'Corn Production': {'Price'},
#  'Cotton Seed Production': {'Price'},
#  "Cow'S Milk Production": {'Price'},
#  'Crop Harvester': {'Total Number'},
#  'Crude Oil': {'Annual Production', 'Price'},
#  'Cyclohexane': {'Annual Production', 'Price'},
#  'Desalination Capacity': {'Total Capacity'},
#  'Dishwashers': {'Share Of Households'},
#  'Disk Brakes': {'Share Of Market'},
#  'Dtp1 Vaccine': {'Share Of Population'},
#  'Dtp3 Vaccine': {'Share Of Population'},
#  'Ebook Reader': {'Share Of Population'},
#  'Electric Bicycles': {'Cumulative Total Capacity'},
#  'Electric Range': {'Share Of Households'},
#  'Electric Water Heaters And Immersion Heaters': {'Price'},
#  'Electricity': {'Annual Production'},
#  'Electro-Chemical Capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Electronic Ignition': {'Share Of Market'},
#  'Ethanolamine': {'Annual Production', 'Price'},
#  'Ethyl Alcohol': {'Annual Production', 'Price'},
#  'Ethylene': {'Annual Production', 'Price'},
#  'Ethylene Glycol': {'Annual Production', 'Price'},
#  'Flow Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Fluid Catalytic Cracking Refineries': {'Average Capacity Of Unit Additions',
#   'Net Total Capacity'},
#  'Flush Toilet': {'Share Of Households'},
#  'Flywheel Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Formaldehyde': {'Annual Production', 'Price'},
#  'Freezer': {'Share Of Households'},
#  'Geothermal Energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Gold Production': {'Annual Production', 'Price'},
#  'Graphite Mine Production': {'Annual Production', 'Price'},
#  'Ground Source Heat Pumps': {'Cumulative Total Capacity'},
#  'Heat Thermal Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Hepb3 Vaccine': {'Share Of Population'},
#  'Hepbb Vaccine': {'Share Of Population'},
#  'Herbicide-Tolerant Corn': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Cotton': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Soybeans': {'Cumulative Acreage'},
#  'Hib3 Vaccine': {'Share Of Population'},
#  'High-Density Polyethylene': {'Annual Production', 'Price'},
#  'High-Speed Rail': {'Cumulative Total Capacity'},
#  'Home Air Conditioning': {'Share Of Households'},
#  'Home Computers': {'Share Of Households'},
#  'Household Internet Access': {'Share Of Households'},
#  'Household Refrigerators And Freezers': {'Price'},
#  'Household Washing And Drying Machines': {'Price'},
#  'Households With Only Mobile Phones (No Landlines)': {'Share Of Households'},
#  'Hydrochloric Acid': {'Annual Production'},
#  'Hydroelectricity': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Hydrofluoric Acid': {'Annual Production', 'Price'},
#  'Hydrogen Storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'Insect-Resistant Corn': {'Cumulative Acreage'},
#  'Insect-Resistant Cotton': {'Cumulative Acreage'},
#  'Internet Backbone Bandwidth': {'Computing Capacity'},
#  'Internet Traffic': {'Computing Capacity'},
#  'Ipv1 Vaccine': {'Share Of Population'},
#  'Iron': {'Share Of Households'},
#  'Iron Ore': {'Annual Production', 'Price'},
#  'Jet Aircraft': {'Cumulative Total Capacity'},
#  'Latent Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Laundry Dryers': {'Cumulative Total Capacity'},
#  'Lead Mine Production': {'Annual Production', 'Price'},
#  'Lead-Acid Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Liquefied Natural Gas': {'Annual Production', 'Price'},
#  'Liquid Biofuels': {'Installed Electricity Capacity'},
#  'Lithium Mine Production': {'Annual Production', 'Price'},
#  'Lithium-Ion Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Low-Density Polyethylene': {'Annual Production', 'Price'},
#  'Magnesium': {'Annual Production', 'Price'},
#  'Magnetic Data Storage': {'Computing Capacity'},
#  'Maleic Anhydride': {'Annual Production', 'Price'},
#  'Marine Energy': {'Installed Electricity Capacity'},
#  'Mcv1 Vaccine': {'Share Of Population'},
#  'Mcv2 Vaccine': {'Share Of Population'},
#  'Methanol': {'Annual Production', 'Price'},
#  'Microcomputers': {'Share Of Households'},
#  'Microprocessor Clock Speed': {'Computing Capacity'},
#  'Microwave Ovens': {'Price'},
#  'Microwaves': {'Share Of Households'},
#  'Milk Production': {'Annual Production'},
#  'Motor Gasoline': {'Annual Production', 'Price'},
#  'Motorcycles': {'Cumulative Total Capacity'},
#  'Motorcycles And Scooters': {'Price'},
#  'Natural Gas Pipeline': {'Total Length'},
#  'Natural Gas Power': {'Cumulative Total Capacity'},
#  'Natural Gas Production': {'Annual Production', 'Price'},
#  'Neoprene Rubber': {'Annual Production', 'Price'},
#  'Nickel Production': {'Annual Production', 'Price'},
#  'Nickel-Based Battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Nitric Acid': {'Annual Production'},
#  'Nitrogen Fertilizer': {'Annual Production'},
#  'Nitrogenous Fertilizers': {'Price'},
#  'Nox Pollution Controls (Boilers)': {'Share Of Boilers'},
#  'Nuclear Energy': {'Annual Production'},
#  'Nuclear Weapons': {'Number Of Weapons'},
#  'Offshore Wind Energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Oil Pipeline': {'Total Length'},
#  'Oil Production': {'Annual Production'},
#  'Oil Refining Capacity': {'Cumulative Total Capacity'},
#  'Onshore Wind Energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Paraxylene': {'Annual Production', 'Price'},
#  'Passenger Cars': {'Cumulative Total Capacity', 'Price', 'Total Number'},
#  'Pcv3 Vaccine': {'Share Of Population'},
#  'Pentaerythritol': {'Annual Production', 'Price'},
#  'Phenol': {'Annual Production', 'Price'},
#  'Phosphate Fertilizer': {'Annual Production'},
#  'Phthalic Anhydride': {'Annual Production', 'Price'},
#  'Podcasting': {'Share Of Population'},
#  'Pol3 Vaccine': {'Share Of Population'},
#  'Polyester Fiber': {'Annual Production', 'Price'},
#  'Polystyrene': {'Annual Production', 'Price'},
#  'Polyvinylchloride': {'Annual Production', 'Price'},
#  'Postal Traffic': {'Total Number'},
#  'Potash Fertilizer': {'Annual Production'},
#  'Potassic Fertilizers': {'Price'},
#  'Power Steering': {'Share Of Market'},
#  'Primary Aluminum Production': {'Annual Production', 'Price'},
#  'Primary Bauxite Production': {'Annual Production', 'Price'},
#  'Primary Copper Production': {'Annual Production', 'Price'},
#  'Primary Magnesium': {'Annual Production', 'Price'},
#  'Processor Performance': {'Computing Capacity'},
#  'Public Roads': {'Total Length'},
#  'Pumped Hydro Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Radial Tires': {'Share Of Market'},
#  'Radio': {'Total Number'},
#  'Radio Receivers': {'Price'},
#  'Railroad': {'Cumulative Length'},
#  'Random Access Memory': {'Computing Capacity'},
#  'Rare Earth Mine Production': {'Annual Production', 'Price'},
#  'Raw Steel Production': {'Annual Production', 'Price'},
#  'Rcv1 Vaccine': {'Share Of Population'},
#  'Real-Time Gross Settlement Adoption': {'Share Of Market'},
#  'Refined Copper': {'Price'},
#  'Refrigerators': {'Cumulative Total Capacity'},
#  'Renewable Power': {'Annual Production'},
#  'Rotac Vaccine': {'Share Of Population'},
#  'Running Water': {'Share Of Households'},
#  'Salt Production': {'Annual Production', 'Price'},
#  'Sand And Gravel Production (Construction)': {'Annual Production', 'Price'},
#  'Sand And Gravel Production (Industrial)': {'Annual Production', 'Price'},
#  'Sensible Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Shale Production': {'Annual Production'},
#  'Shotgun Sanger Dna Sequencing': {'Price', 'Total Number'},
#  'Silver': {'Annual Production', 'Price'},
#  'Smartphone Usage': {'Share Of Population'},
#  'Social Media Usage': {'Share Of Population'},
#  'Sodium': {'Annual Production', 'Price'},
#  'Sodium Chlorate': {'Annual Production', 'Price'},
#  'Sodium-Based Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Solar Photovoltaic': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'Solar Thermal Energy': {'Installed Electricity Capacity'},
#  'Solid Biofuels': {'Installed Electricity Capacity'},
#  'Soybean Production': {'Price'},
#  'Space Launches': {'Yearly Launches'},
#  'Stationary Steam Engines': {'Cumulative Total Capacity'},
#  'Steam Locomotives': {'Cumulative Total Capacity'},
#  'Steam Ships': {'Cumulative Total Capacity'},
#  'Stove': {'Share Of Households'},
#  'Styrene': {'Annual Production', 'Price'},
#  'Submarine Cables': {'Cumulative Length'},
#  'Sugar Cane Production': {'Price'},
#  'Sulphuric Acid': {'Annual Production'},
#  'Synthetic Filament Tow And Staple Fibers': {'Price'},
#  'Synthetic Filament Yarn': {'Price'},
#  'Synthetic Filaments': {'Annual Production'},
#  'Tablet': {'Share Of Population'},
#  'Telegraph Traffic': {'Total Number'},
#  'Telephones': {'Total Number'},
#  'Telephones And Videophones': {'Price'},
#  'Television': {'Total Number'},
#  'Television Receivers': {'Price'},
#  'Tin': {'Annual Production', 'Price'},
#  'Titanium Sponge': {'Annual Production', 'Price'},
#  'Transistors Per Microprocessor': {'Computing Capacity'},
#  'Turbo-Jets Of A Thrust Not Exceeding 25 Kn': {'Price'},
#  'Urea': {'Annual Production', 'Price'},
#  'Vacuum Cleaners': {'Price'},
#  'Vacuums': {'Share Of Households'},
#  'Videocassette Recorder': {'Share Of Households'},
#  'Vinyl Acetate': {'Annual Production', 'Price'},
#  'Vinyl Chloride': {'Annual Production', 'Price'},
#  'Washing Machines': {'Cumulative Total Capacity'},
#  'Water Heater': {'Share Of Households'},
#  'Wet Flue Gas Desulfurization Systems': {'Cumulative Total Capacity'},
#  'Yfv Vaccine': {'Share Of Population'},
#  'Zinc': {'Annual Production', 'Price'},
#  'Zinc-Based Battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = {}
for item in metric_dict:
    metric_dict_lower[item.lower()] = metric_dict[item]
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual Production', 'Price'},
#  'acrylonitrile': {'Annual Production', 'Price'},
#  'air conditioning machines': {'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'all biofuels': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'amazon prime users': {'Share Of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual Production', 'Price'},
#  'aquaculture production': {'Annual Production'},
#  'automatic transmission': {'Share Of Market'},
#  'bcg vaccine': {'Share Of Population'},
#  'beer': {'Price'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual Production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'bicycles and other cycles': {'Price'},
#  'biogas': {'Installed Electricity Capacity'},
#  'bisphenol a': {'Annual Production', 'Price'},
#  'cable tv': {'Share Of Households'},
#  'cadmium refining': {'Annual Production', 'Price'},
#  'canals': {'Total Length'},
#  'cane sugar production': {'Annual Production'},
#  'caprolactam': {'Annual Production', 'Price'},
#  'capture fisheries production': {'Annual Production'},
#  'carbon capture & sequestration': {'Installed Capacity'},
#  'caustic soda': {'Annual Production', 'Price'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement production': {'Annual Production', 'Price'},
#  'central heating': {'Share Of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt mine production': {'Annual Production'},
#  'colour tv': {'Share Of Households'},
#  'combined refrigerators-freezers': {'Price'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'copper mining': {'Annual Production'},
#  'copper refining': {'Annual Production'},
#  'corn production': {'Price'},
#  'cotton seed production': {'Price'},
#  "cow's milk production": {'Price'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Annual Production', 'Price'},
#  'cyclohexane': {'Annual Production', 'Price'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share Of Households'},
#  'disk brakes': {'Share Of Market'},
#  'dtp1 vaccine': {'Share Of Population'},
#  'dtp3 vaccine': {'Share Of Population'},
#  'ebook reader': {'Share Of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share Of Households'},
#  'electric water heaters and immersion heaters': {'Price'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share Of Market'},
#  'ethanolamine': {'Annual Production', 'Price'},
#  'ethyl alcohol': {'Annual Production', 'Price'},
#  'ethylene': {'Annual Production', 'Price'},
#  'ethylene glycol': {'Annual Production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'fluid catalytic cracking refineries': {'Average Capacity Of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share Of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual Production', 'Price'},
#  'freezer': {'Share Of Households'},
#  'geothermal energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'gold production': {'Annual Production', 'Price'},
#  'graphite mine production': {'Annual Production', 'Price'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'hepb3 vaccine': {'Share Of Population'},
#  'hepbb vaccine': {'Share Of Population'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'hib3 vaccine': {'Share Of Population'},
#  'high-density polyethylene': {'Annual Production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share Of Households'},
#  'home computers': {'Share Of Households'},
#  'household internet access': {'Share Of Households'},
#  'household refrigerators and freezers': {'Price'},
#  'household washing and drying machines': {'Price'},
#  'households with only mobile phones (no landlines)': {'Share Of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'hydrofluoric acid': {'Annual Production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'ipv1 vaccine': {'Share Of Population'},
#  'iron': {'Share Of Households'},
#  'iron ore': {'Annual Production', 'Price'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead mine production': {'Annual Production', 'Price'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production', 'Price'},
#  'liquid biofuels': {'Installed Electricity Capacity'},
#  'lithium mine production': {'Annual Production', 'Price'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'low-density polyethylene': {'Annual Production', 'Price'},
#  'magnesium': {'Annual Production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual Production', 'Price'},
#  'marine energy': {'Installed Electricity Capacity'},
#  'mcv1 vaccine': {'Share Of Population'},
#  'mcv2 vaccine': {'Share Of Population'},
#  'methanol': {'Annual Production', 'Price'},
#  'microcomputers': {'Share Of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwave ovens': {'Price'},
#  'microwaves': {'Share Of Households'},
#  'milk production': {'Annual Production'},
#  'motor gasoline': {'Annual Production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'motorcycles and scooters': {'Price'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual Production', 'Price'},
#  'nickel production': {'Annual Production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nitrogenous fertilizers': {'Price'},
#  'nox pollution controls (boilers)': {'Share Of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Number Of Weapons'},
#  'offshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Cumulative Total Capacity'},
#  'onshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'paraxylene': {'Annual Production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity', 'Price', 'Total Number'},
#  'pcv3 vaccine': {'Share Of Population'},
#  'pentaerythritol': {'Annual Production', 'Price'},
#  'phenol': {'Annual Production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual Production', 'Price'},
#  'podcasting': {'Share Of Population'},
#  'pol3 vaccine': {'Share Of Population'},
#  'polyester fiber': {'Annual Production', 'Price'},
#  'polystyrene': {'Annual Production', 'Price'},
#  'polyvinylchloride': {'Annual Production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'potassic fertilizers': {'Price'},
#  'power steering': {'Share Of Market'},
#  'primary aluminum production': {'Annual Production', 'Price'},
#  'primary bauxite production': {'Annual Production', 'Price'},
#  'primary copper production': {'Annual Production', 'Price'},
#  'primary magnesium': {'Annual Production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'radial tires': {'Share Of Market'},
#  'radio': {'Total Number'},
#  'radio receivers': {'Price'},
#  'railroad': {'Cumulative Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual Production', 'Price'},
#  'raw steel production': {'Annual Production', 'Price'},
#  'rcv1 vaccine': {'Share Of Population'},
#  'real-time gross settlement adoption': {'Share Of Market'},
#  'refined copper': {'Price'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'rotac vaccine': {'Share Of Population'},
#  'running water': {'Share Of Households'},
#  'salt production': {'Annual Production', 'Price'},
#  'sand and gravel production (construction)': {'Annual Production', 'Price'},
#  'sand and gravel production (industrial)': {'Annual Production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual Production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production', 'Price'},
#  'smartphone usage': {'Share Of Population'},
#  'social media usage': {'Share Of Population'},
#  'sodium': {'Annual Production', 'Price'},
#  'sodium chlorate': {'Annual Production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'solar photovoltaic': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed Electricity Capacity'},
#  'solid biofuels': {'Installed Electricity Capacity'},
#  'soybean production': {'Price'},
#  'space launches': {'Yearly Launches'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steam ships': {'Cumulative Total Capacity'},
#  'stove': {'Share Of Households'},
#  'styrene': {'Annual Production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sugar cane production': {'Price'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filament tow and staple fibers': {'Price'},
#  'synthetic filament yarn': {'Price'},
#  'synthetic filaments': {'Annual Production'},
#  'tablet': {'Share Of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'telephones and videophones': {'Price'},
#  'television': {'Total Number'},
#  'television receivers': {'Price'},
#  'tin': {'Annual Production', 'Price'},
#  'titanium sponge': {'Annual Production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'turbo-jets of a thrust not exceeding 25 kn': {'Price'},
#  'urea': {'Annual Production', 'Price'},
#  'vacuum cleaners': {'Price'},
#  'vacuums': {'Share Of Households'},
#  'videocassette recorder': {'Share Of Households'},
#  'vinyl acetate': {'Annual Production', 'Price'},
#  'vinyl chloride': {'Annual Production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share Of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share Of Population'},
#  'zinc': {'Annual Production', 'Price'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = dict(sorted(metric_dict_lower.items(), key=lambda item: item[0])) 
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual Production', 'Price'},
#  'acrylonitrile': {'Annual Production', 'Price'},
#  'air conditioning machines': {'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'all biofuels': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'amazon prime users': {'Share Of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual Production', 'Price'},
#  'aquaculture production': {'Annual Production'},
#  'automatic transmission': {'Share Of Market'},
#  'bcg vaccine': {'Share Of Population'},
#  'beer': {'Price'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual Production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'bicycles and other cycles': {'Price'},
#  'biogas': {'Installed Electricity Capacity'},
#  'bisphenol a': {'Annual Production', 'Price'},
#  'cable tv': {'Share Of Households'},
#  'cadmium refining': {'Annual Production', 'Price'},
#  'canals': {'Total Length'},
#  'cane sugar production': {'Annual Production'},
#  'caprolactam': {'Annual Production', 'Price'},
#  'capture fisheries production': {'Annual Production'},
#  'carbon capture & sequestration': {'Installed Capacity'},
#  'caustic soda': {'Annual Production', 'Price'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement production': {'Annual Production', 'Price'},
#  'central heating': {'Share Of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt mine production': {'Annual Production'},
#  'colour tv': {'Share Of Households'},
#  'combined refrigerators-freezers': {'Price'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'copper mining': {'Annual Production'},
#  'copper refining': {'Annual Production'},
#  'corn production': {'Price'},
#  'cotton seed production': {'Price'},
#  "cow's milk production": {'Price'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Annual Production', 'Price'},
#  'cyclohexane': {'Annual Production', 'Price'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share Of Households'},
#  'disk brakes': {'Share Of Market'},
#  'dtp1 vaccine': {'Share Of Population'},
#  'dtp3 vaccine': {'Share Of Population'},
#  'ebook reader': {'Share Of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share Of Households'},
#  'electric water heaters and immersion heaters': {'Price'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share Of Market'},
#  'ethanolamine': {'Annual Production', 'Price'},
#  'ethyl alcohol': {'Annual Production', 'Price'},
#  'ethylene': {'Annual Production', 'Price'},
#  'ethylene glycol': {'Annual Production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'fluid catalytic cracking refineries': {'Average Capacity Of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share Of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual Production', 'Price'},
#  'freezer': {'Share Of Households'},
#  'geothermal energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'gold production': {'Annual Production', 'Price'},
#  'graphite mine production': {'Annual Production', 'Price'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'hepb3 vaccine': {'Share Of Population'},
#  'hepbb vaccine': {'Share Of Population'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'hib3 vaccine': {'Share Of Population'},
#  'high-density polyethylene': {'Annual Production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share Of Households'},
#  'home computers': {'Share Of Households'},
#  'household internet access': {'Share Of Households'},
#  'household refrigerators and freezers': {'Price'},
#  'household washing and drying machines': {'Price'},
#  'households with only mobile phones (no landlines)': {'Share Of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'hydrofluoric acid': {'Annual Production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'ipv1 vaccine': {'Share Of Population'},
#  'iron': {'Share Of Households'},
#  'iron ore': {'Annual Production', 'Price'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead mine production': {'Annual Production', 'Price'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production', 'Price'},
#  'liquid biofuels': {'Installed Electricity Capacity'},
#  'lithium mine production': {'Annual Production', 'Price'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'low-density polyethylene': {'Annual Production', 'Price'},
#  'magnesium': {'Annual Production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual Production', 'Price'},
#  'marine energy': {'Installed Electricity Capacity'},
#  'mcv1 vaccine': {'Share Of Population'},
#  'mcv2 vaccine': {'Share Of Population'},
#  'methanol': {'Annual Production', 'Price'},
#  'microcomputers': {'Share Of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwave ovens': {'Price'},
#  'microwaves': {'Share Of Households'},
#  'milk production': {'Annual Production'},
#  'motor gasoline': {'Annual Production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'motorcycles and scooters': {'Price'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual Production', 'Price'},
#  'nickel production': {'Annual Production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nitrogenous fertilizers': {'Price'},
#  'nox pollution controls (boilers)': {'Share Of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Number Of Weapons'},
#  'offshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Cumulative Total Capacity'},
#  'onshore wind energy': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'paraxylene': {'Annual Production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity', 'Price', 'Total Number'},
#  'pcv3 vaccine': {'Share Of Population'},
#  'pentaerythritol': {'Annual Production', 'Price'},
#  'phenol': {'Annual Production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual Production', 'Price'},
#  'podcasting': {'Share Of Population'},
#  'pol3 vaccine': {'Share Of Population'},
#  'polyester fiber': {'Annual Production', 'Price'},
#  'polystyrene': {'Annual Production', 'Price'},
#  'polyvinylchloride': {'Annual Production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'potassic fertilizers': {'Price'},
#  'power steering': {'Share Of Market'},
#  'primary aluminum production': {'Annual Production', 'Price'},
#  'primary bauxite production': {'Annual Production', 'Price'},
#  'primary copper production': {'Annual Production', 'Price'},
#  'primary magnesium': {'Annual Production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'radial tires': {'Share Of Market'},
#  'radio': {'Total Number'},
#  'radio receivers': {'Price'},
#  'railroad': {'Cumulative Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual Production', 'Price'},
#  'raw steel production': {'Annual Production', 'Price'},
#  'rcv1 vaccine': {'Share Of Population'},
#  'real-time gross settlement adoption': {'Share Of Market'},
#  'refined copper': {'Price'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'rotac vaccine': {'Share Of Population'},
#  'running water': {'Share Of Households'},
#  'salt production': {'Annual Production', 'Price'},
#  'sand and gravel production (construction)': {'Annual Production', 'Price'},
#  'sand and gravel production (industrial)': {'Annual Production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual Production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production', 'Price'},
#  'smartphone usage': {'Share Of Population'},
#  'social media usage': {'Share Of Population'},
#  'sodium': {'Annual Production', 'Price'},
#  'sodium chlorate': {'Annual Production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'solar photovoltaic': {'Installed Electricity Capacity',
#   'Levelized Cost Of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed Electricity Capacity'},
#  'solid biofuels': {'Installed Electricity Capacity'},
#  'soybean production': {'Price'},
#  'space launches': {'Yearly Launches'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steam ships': {'Cumulative Total Capacity'},
#  'stove': {'Share Of Households'},
#  'styrene': {'Annual Production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sugar cane production': {'Price'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filament tow and staple fibers': {'Price'},
#  'synthetic filament yarn': {'Price'},
#  'synthetic filaments': {'Annual Production'},
#  'tablet': {'Share Of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'telephones and videophones': {'Price'},
#  'television': {'Total Number'},
#  'television receivers': {'Price'},
#  'tin': {'Annual Production', 'Price'},
#  'titanium sponge': {'Annual Production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'turbo-jets of a thrust not exceeding 25 kn': {'Price'},
#  'urea': {'Annual Production', 'Price'},
#  'vacuum cleaners': {'Price'},
#  'vacuums': {'Share Of Households'},
#  'videocassette recorder': {'Share Of Households'},
#  'vinyl acetate': {'Annual Production', 'Price'},
#  'vinyl chloride': {'Annual Production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share Of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share Of Population'},
#  'zinc': {'Annual Production', 'Price'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
for item in metric_dict_lower:
    print(item)
# Out:
# acrylic fiber
# acrylonitrile
# air conditioning machines
# air-source heat pumps
# all biofuels
# amazon prime users
# ammonia synthesis
# aniline
# aquaculture production
# automatic transmission
# bcg vaccine
# beer
# beer production
# benzene
# bicycles
# bicycles and other cycles
# biogas
# bisphenol a
# cable tv
# cadmium refining
# canals
# cane sugar production
# caprolactam
# capture fisheries production
# carbon capture & sequestration
# caustic soda
# cellphones
# cement production
# central heating
# coal power
# coal production
# cobalt mine production
# colour tv
# combined refrigerators-freezers
# compact fluorescent light bulbs
# compressed air energy storage
# computing growth
# concentrated solar power
# copper mining
# copper refining
# corn production
# cotton seed production
# cow's milk production
# crop harvester
# crude oil
# cyclohexane
# desalination capacity
# dishwashers
# disk brakes
# dtp1 vaccine
# dtp3 vaccine
# ebook reader
# electric bicycles
# electric range
# electric water heaters and immersion heaters
# electricity
# electro-chemical capacitor
# electronic ignition
# ethanolamine
# ethyl alcohol
# ethylene
# ethylene glycol
# flow battery storage
# fluid catalytic cracking refineries
# flush toilet
# flywheel battery storage
# formaldehyde
# freezer
# geothermal energy
# gold production
# graphite mine production
# ground source heat pumps
# heat thermal battery storage
# hepb3 vaccine
# hepbb vaccine
# herbicide-tolerant corn
# herbicide-tolerant cotton
# herbicide-tolerant soybeans
# hib3 vaccine
# high-density polyethylene
# high-speed rail
# home air conditioning
# home computers
# household internet access
# household refrigerators and freezers
# household washing and drying machines
# households with only mobile phones (no landlines)
# hydrochloric acid
# hydroelectricity
# hydrofluoric acid
# hydrogen storage
# insect-resistant corn
# insect-resistant cotton
# internet backbone bandwidth
# internet traffic
# ipv1 vaccine
# iron
# iron ore
# jet aircraft
# latent heat storage
# laundry dryers
# lead mine production
# lead-acid battery storage
# liquefied natural gas
# liquid biofuels
# lithium mine production
# lithium-ion battery storage
# low-density polyethylene
# magnesium
# magnetic data storage
# maleic anhydride
# marine energy
# mcv1 vaccine
# mcv2 vaccine
# methanol
# microcomputers
# microprocessor clock speed
# microwave ovens
# microwaves
# milk production
# motor gasoline
# motorcycles
# motorcycles and scooters
# natural gas pipeline
# natural gas power
# natural gas production
# neoprene rubber
# nickel production
# nickel-based battery
# nitric acid
# nitrogen fertilizer
# nitrogenous fertilizers
# nox pollution controls (boilers)
# nuclear energy
# nuclear weapons
# offshore wind energy
# oil pipeline
# oil production
# oil refining capacity
# onshore wind energy
# paraxylene
# passenger cars
# pcv3 vaccine
# pentaerythritol
# phenol
# phosphate fertilizer
# phthalic anhydride
# podcasting
# pol3 vaccine
# polyester fiber
# polystyrene
# polyvinylchloride
# postal traffic
# potash fertilizer
# potassic fertilizers
# power steering
# primary aluminum production
# primary bauxite production
# primary copper production
# primary magnesium
# processor performance
# public roads
# pumped hydro storage
# radial tires
# radio
# radio receivers
# railroad
# random access memory
# rare earth mine production
# raw steel production
# rcv1 vaccine
# real-time gross settlement adoption
# refined copper
# refrigerators
# renewable power
# rotac vaccine
# running water
# salt production
# sand and gravel production (construction)
# sand and gravel production (industrial)
# sensible heat storage
# shale production
# shotgun sanger dna sequencing
# silver
# smartphone usage
# social media usage
# sodium
# sodium chlorate
# sodium-based battery storage
# solar photovoltaic
# solar thermal energy
# solid biofuels
# soybean production
# space launches
# stationary steam engines
# steam locomotives
# steam ships
# stove
# styrene
# submarine cables
# sugar cane production
# sulphuric acid
# synthetic filament tow and staple fibers
# synthetic filament yarn
# synthetic filaments
# tablet
# telegraph traffic
# telephones
# telephones and videophones
# television
# television receivers
# tin
# titanium sponge
# transistors per microprocessor
# turbo-jets of a thrust not exceeding 25 kn
# urea
# vacuum cleaners
# vacuums
# videocassette recorder
# vinyl acetate
# vinyl chloride
# washing machines
# water heater
# wet flue gas desulfurization systems
# yfv vaccine
# zinc
# zinc-based battery
