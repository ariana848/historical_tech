# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 2.0.csv')
all_tech
# Out:
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4       Onshore Wind Energy_Levelized Cost of Energy_DK      National
# ...                                                 ...           ...
# 8842             Tin Production_Annual production_World        Global
# 8843        Objects Launched Into Space_Total Number_UA      National
# 8844        Objects Launched Into Space_Total Number_TM      National
# 8845         Liquefied Natural Gas_Annual Production_US      National
# 8846        Objects Launched Into Space_Total Number_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              DK        Denmark          Onshore Wind Energy
# ...           ...            ...                          ...
# 8842        World          World               Tin Production
# 8843           UA        Ukraine  Objects Launched Into Space
# 8844           TM   Turkmenistan  Objects Launched Into Space
# 8845           US  United States        Liquefied Natural Gas
# 8846           CO       Colombia  Objects Launched Into Space
#
#                          Metric                Unit Data Source  \
# 0        Cumulative Rated Power                  kW       GESDB
# 1     Cumulative Rated Capacity                 kWh       GESDB
# 2        Cumulative Rated Power                  kW       GESDB
# 3     Cumulative Rated Capacity                 kWh       GESDB
# 4      Levelized Cost of Energy        2022 USD/kWh       IRENA
# ...                         ...                 ...         ...
# 8842          Annual production         metric tons        USGS
# 8843               Total Number                   -      UNOOSA
# 8844               Total Number                   -      UNOOSA
# 8845          Annual Production  billion cubic feet         EIA
# 8846               Total Number                   -      UNOOSA
#
#                                    Long Technology Name  1700  ...  \
# 0     Cumulative Rated Power|Lithium-Ion Battery Sto...   NaN  ...
# 1     Cumulative Rated Capacity|Lithium-Ion Battery ...   NaN  ...
# 2          Cumulative Rated Power|Sensible Heat Storage   NaN  ...
# 3       Cumulative Rated Capacity|Sensible Heat Storage   NaN  ...
# 4          Levelized Cost of Energy|Onshore Wind Energy   NaN  ...
# ...                                                 ...   ...  ...
# 8842                   Annual production|Tin Production   NaN  ...
# 8843           Total Number|Objects Launched Into Space   NaN  ...
# 8844           Total Number|Objects Launched Into Space   NaN  ...
# 8845            Annual Production|Liquefied Natural Gas   NaN  ...
# 8846           Total Number|Objects Launched Into Space   NaN  ...
#
#               2016          2017          2018           2019         2020  \
# 0              NaN  1.900000e+02  2.900000e+02            NaN          NaN
# 1              NaN  7.600000e+02  1.160000e+03            NaN          NaN
# 2     2.550000e+05  3.550000e+05  4.550000e+05            NaN          NaN
# 3     1.195000e+06  1.745000e+06  2.945000e+06            NaN          NaN
# 4     5.929609e-02  4.898293e-02  4.679236e-02       0.048501     0.042769
# ...            ...           ...           ...            ...          ...
# 8842  5.226023e+05  5.767229e+05  5.462801e+05  500615.785555          NaN
# 8843           NaN           NaN           NaN            NaN          NaN
# 8844           NaN           NaN           NaN            NaN          NaN
# 8845  1.868400e+02  7.075400e+02  1.083120e+03    1819.400000  2389.840000
# 8846           NaN           NaN  1.000000e+00            NaN          NaN
#
#          2021  2022  2023  2024  2025
# 0         NaN   NaN   NaN   NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN
# ...       ...   ...   ...   ...   ...
# 8842      NaN   NaN   NaN   NaN   NaN
# 8843      NaN   1.0   NaN   NaN   NaN
# 8844      NaN   NaN   NaN   NaN   NaN
# 8845  3560.82   NaN   NaN   NaN   NaN
# 8846      NaN   NaN   NaN   NaN   NaN
#
# [8847 rows x 335 columns]

# %%
source_dict = {}
for source in sorted(list(set(all_tech['Data Source']))):
    tech_list = list(set(all_tech[all_tech['Data Source']==source]['Technology Name']))
    source_dict[source] = tech_list
for source in source_dict['UN Industrial Commodity Statistics Database']:
    print(source)
# Out:
# Bicycles and Other Cycles
# Synthetic Filament Tow and Staple Fibers
# Nitrogenous Fertilizers
# Household Washing and Drying Machines
# Motorcycles and Scooters
# Beer
# Caustic Soda
# Vacuum Cleaners
# Electric Water Heaters and Immersion Heaters
# Cars
# Television Receivers
# Radio Receivers
# Refined Copper
# Combined Refrigerators-Freezers
# Potassic Fertilizers
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Air Conditioning Machines
# Synthetic Filament Yarn
# Household Refrigerators and Freezers
# Telephones and Videophones
# Microwave Ovens

# %%
len(list(set(all_tech['Data Source'])))
# Out:
# 34

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
for x in tech_list:
    print(x)
# Out:
# Acrylic Fiber
# Acrylonitrile
# Air Conditioning Machines
# Air-Source Heat Pumps
# Amazon Prime Users
# Ammonia Synthesis
# Aniline
# Aquaculture Production
# Artificial and Synthetic Fibers
# Automatic Transmission
# BCG Vaccine
# Beer
# Beer Production
# Benzene
# Bicycles
# Bicycles and Other Cycles
# Bioenergy
# Biofuels Production
# Biogas
# BisphenolA
# Cable TV
# Cadmium Refining
# Canals
# Capillary DNA Sequencing
# Caprolactam
# Capture Fisheries
# Carbon Capture and Sequestration
# Cars
# Caustic Soda
# Caustic Soda Acid
# Cellphones
# Cement
# Central Heating
# Coal Power
# Coal Production
# Cobalt
# Colour TV
# Combined Refrigerators-Freezers
# Compact Fluorescent Light Bulbs
# Compressed Air Energy Storage
# Computing Growth
# Concentrated Solar Power
# Concentrating Solar Power
# Copper|Mining
# Copper|Refining
# Corn Production
# Cotton Seed Production
# Cow's Milk Production
# Crop Harvester
# Crude Oil
# Crude Petroleum
# Cyclohexane
# DNA Sequencing (All Methods)
# DTP1 Vaccine
# DTP3 Vaccine
# Desalination Capacity
# Dishwashers
# Disk Brakes
# Ebook Reader
# Electric Bicycles
# Electric Range
# Electric Water Heaters and Immersion Heaters
# Electricity
# Electro-Chemical Capacitor
# Electronic Ignition
# Ethanol
# Ethanolamine
# Ethylene
# Ethylene Glycol
# Flow Battery Storage
# Fluid Catalytic Cracking Refineries
# Flush Toilet
# Flywheel Battery Storage
# Formaldehyde
# Freezer
# Geothermal Energy
# Gold
# Gold Production
# Graphite
# Ground Source Heat Pumps
# HEPB3 Vaccine
# HEPBB Vaccine
# HIB3 Vaccine
# Heat Thermal Battery Storage
# Herbicide-Tolerant Corn
# Herbicide-Tolerant Cotton
# Herbicide-Tolerant Soybeans
# High-Density Polyethylene
# High-Speed Rail
# Home Air Conditioning
# Home Computers
# Household Internet Access
# Household Refrigerators and Freezers
# Household Washing and Drying Machines
# Households With Only Mobile Phones (No Landlines)
# Hydrochloric Acid
# Hydroelectricity
# Hydrofluoric Acid
# Hydrogen Storage
# Hydropower
# IPV1 Vaccine
# Insect-Resistant Corn
# Insect-Resistant Cotton
# Internet Backbone Bandwidth
# Internet Traffic
# Iron
# Iron Ore
# Jet Aircraft
# Latent Heat Storage
# Laundry Dryers
# Lead
# Lead-Acid Battery Storage
# Liquefied Natural Gas
# Liquefied Natural Gas (LNG)
# Liquid Biofuels
# Lithium Mine Production
# Lithium-Ion Battery Storage
# Low-Density Polyethylene
# MCV1 Vaccine
# MCV2 Vaccine
# Magnesium
# Magnetic Data Storage
# Maleic Anhydride
# Marine Energy
# Methanol
# Microcomputers
# Microprocessor Clock Speed
# Microwave Ovens
# Microwaves
# Milk
# Motor Gasoline
# Motorcycles
# Motorcycles and Scooters
# Natural Gas Pipeline
# Natural Gas Power
# Natural Gas Production
# Neoprene Rubber
# Nickel
# Nickel Production
# Nickel-Based Battery
# Nitric Acid
# Nitrogen Fertilizer
# Nitrogenous Fertilizers
# Nox Pollution Controls (Boilers)
# Nuclear Energy
# Nuclear Weapons
# Objects Launched Into Space
# Offshore Wind Energy
# Oil Pipeline
# Oil Production
# Oil Refining Capacity
# Onshore Wind Energy
# PCV3 Vaccine
# POL3 Vaccine
# Paraxylene
# Passenger Cars
# Passenger Vehicles
# Pentaerythritol
# Phenol
# Phosphate Fertilizer
# Phthalic Anhydride
# Podcasting
# Polyester Fiber
# Polystyrene
# Polyvinylchloride
# Postal Traffic
# Potash Fertilizer
# Potassic Fertilizers
# Power Steering
# Primary Aluminum Production
# Primary Bauxite Production
# Primary Copper
# Primary Magnesium
# Processor Performance
# Public Roads
# Pumped Hydro Storage
# RCV1 Vaccine
# ROTAC Vaccine
# Radial Tires
# Radio
# Radio Receivers
# Railroad
# Random Access Memory
# Rare Earth Mine Production
# Raw Steel Production
# Real-Time Gross Settlement Adoption
# Refined Copper
# Refrigerators
# Renewable Power
# Running Water
# Salt Production
# Sand and Gravel|Construction
# Sand and Gravel|Industrial
# Sensible Heat Storage
# Shale Production
# Shotgun Sanger DNA Sequencing
# Silver
# Silver Production
# Smartphone Usage
# Social Media Usage
# Sodium
# Sodium Chlorate
# Sodium-Based Battery Storage
# Solar Photovoltaic
# Solar Thermal Energy
# Solid Biofuels
# Soybean Production
# Space Launches
# Stationary Steam Engines
# Steam Locomotives
# Steamships
# Stove
# Styrene
# Submarine Cables
# Sugar Cane Production
# Sugar Output
# Sulphuric Acid
# Synthetic Filament Tow and Staple Fibers
# Synthetic Filament Yarn
# Synthetic Filaments
# Tablet
# Telegraph Traffic
# Telephones
# Telephones and Videophones
# Television
# Television Receivers
# Tin
# Tin Production
# Titanium Sponge
# Transistors per Microprocessor
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Urea
# Vacuum Cleaners
# Vacuums
# Videocassette Recorder
# Vinyl Acetate
# Vinyl Chloride
# Washing Machines
# Water Heater
# Wet Flue Gas Desulfurization Systems
# YFV Vaccine
# Zinc
# Zinc Production
# Zinc-Based Battery

# %%
len(tech_list)
# Out:
# 244

# %%
print(len(list(set(all_tech['Unit']))))
sorted(list(set(all_tech['Unit'])))
# Out:
# 59
# ['%',
#  '-',
#  '2022 USD',
#  '2022 USD/barrel',
#  '2022 USD/gal',
#  '2022 USD/kW',
#  '2022 USD/kWh',
#  '2022 USD/lb',
#  '2022 USD/metric ton',
#  'Cost (USD/Kilobase)',
#  'GB/month',
#  'GW',
#  'GWe',
#  'Hz',
#  'MW',
#  'MWt',
#  'TWh',
#  'Thousand 2022 USD/kg',
#  'USD/genome',
#  'USD/kilobase',
#  'USD/megabase',
#  'USD/metric ton',
#  'USD/million Btu',
#  'Yearly Production (Gbase)',
#  'billion barrels',
#  'billion cubic feet',
#  'billion cubic metres',
#  'billion pounds',
#  'bits/2000 USD',
#  'bits/2022 USD',
#  'bits/second',
#  'calculations per second/thousand USD',
#  'cumulative acres planted',
#  'kW',
#  'kWh',
#  'kilobase',
#  'kilometers',
#  'metric tons',
#  'miles',
#  'million USD/unit',
#  'million cubic meters/day',
#  'million gallons',
#  'million instructions/second',
#  'million metric tons',
#  'million pounds',
#  'million tons',
#  'net tons',
#  'no. of transistors/chip',
#  'petajoules',
#  'producer price index',
#  'short tons',
#  'thousand USD/hectolitre',
#  'thousand USD/metric ton',
#  'thousand USD/unit',
#  'thousand barrels/day',
#  'thousand hectolitres',
#  'thousand metric tons',
#  'thousand tons',
#  'thousand tons of nitrogen equivalent']

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)
# Out:
# Air Conditioning Machines
# BCG Vaccine
# Beer
# Bicycles and Other Cycles
# Cars
# Caustic Soda
# Gold
# Household Refrigerators and Freezers
# Hydrogen Storage
# Liquefied Natural Gas (LNG)
# Motorcycles and Scooters
# Nitrogenous Fertilizers
# Potassic Fertilizers
# Radio Receivers
# Refined Copper
# Silver
# Steamships
# Synthetic Filament Tow and Staple Fibers
# Synthetic Filament Yarn
# Synthetic Filaments
# Telephones and Videophones
# Television Receivers
# Tin
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Vacuum Cleaners
# YFV Vaccine

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
tech_country_dict
# Out:
# {'Acrylic Fiber': ['World'],
#  'Acrylonitrile': ['World'],
#  'Air Conditioning Machines': ['Bulgaria',
#   'Japan',
#   'Turkey',
#   'Brazil',
#   'Greece',
#   'Denmark',
#   'Iran (Islamic Republic of)',
#   'Sudan',
#   'Estonia',
#   'Azerbaijan',
#   'Mexico',
#   'Sweden',
#   'Netherlands',
#   'Italy',
#   'Germany',
#   'Nigeria',
#   'Poland',
#   'Romania',
#   'Finland',
#   'United Kingdom',
#   'Iraq',
#   'Ireland',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Slovenia',
#   'Ecuador',
#   'Croatia',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Bosnia and Herzegovina',
#   'Spain',
#   'Czechia',
#   'Egypt'],
#  'Air-Source Heat Pumps': ['United States'],
#  'Amazon Prime Users': ['United States'],
#  'Ammonia Synthesis': ['Japan',
#   'Czechoslovakia',
#   'World',
#   'Canada',
#   'Sweden',
#   'Belgium',
#   'USSR',
#   'Netherlands',
#   'Germany',
#   'USA',
#   'Poland',
#   'France',
#   'Italy'],
#  'Aniline': ['World'],
#  'Aquaculture Production': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'American Samoa',
#   'Paraguay',
#   'St. Vincent and the Grenadines',
#   'Denmark',
#   'Brunei Darussalam',
#   'Hong Kong SAR, China',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Netherlands',
#   'Northern Mariana Islands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Bahrain',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Togo',
#   'Thailand',
#   'Norway',
#   'Marshall Islands',
#   'Haiti',
#   'Montenegro',
#   'Ethiopia',
#   'Venezuela, RB',
#   'Botswana',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Yemen, Rep.',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Turkmenistan',
#   'Bolivia',
#   'Faroe Islands',
#   'West Bank and Gaza',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'British Virgin Islands',
#   'French Polynesia',
#   'Mauritius',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'St. Lucia',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Trinidad and Tobago',
#   'Indonesia',
#   'Liberia',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'New Caledonia',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Spain',
#   'Kiribati',
#   'Czechia',
#   'Puerto Rico',
#   'Slovak Republic',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Egypt, Arab Rep.',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'South Sudan',
#   'Lesotho',
#   'Iran, Islamic Rep.',
#   'India',
#   'Gambia, The',
#   'Dominican Republic',
#   'Kuwait',
#   'Virgin Islands (U.S.)',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Bahamas, The',
#   'Curacao',
#   'Honduras',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Vanuatu',
#   'Palau',
#   'United Kingdom',
#   'Turks and Caicos Islands',
#   "Korea, Dem. People's Rep.",
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Congo, Dem. Rep.',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Micronesia, Fed. Sts.',
#   'St. Kitts and Nevis',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Bulgaria',
#   'Turkiye',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'Lao PDR',
#   'Korea, Rep.',
#   'United States',
#   'Dominica',
#   'Niger',
#   'Eswatini',
#   'Aruba',
#   'Guam',
#   'North Macedonia',
#   'Ukraine',
#   'Congo, Rep.',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Burkina Faso',
#   'Iraq',
#   'Kyrgyz Republic',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Papua New Guinea',
#   'World',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   'Solomon Islands',
#   'Angola',
#   'Vietnam',
#   'Moldova',
#   'Nepal',
#   'Tanzania'],
#  'Artificial and Synthetic Fibers': ['United States of America',
#   'Argentina',
#   'Mexico',
#   'Brazil',
#   'Canada',
#   'Colombia'],
#  'Automatic Transmission': ['United States'],
#  'BCG Vaccine': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Brunei Darussalam',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Saint Kitts and Nevis',
#   'Mali',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Peru',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Togo',
#   'Marshall Islands',
#   'Haiti',
#   'Montenegro',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Micronesia (Federated States of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Mauritania',
#   'Turkmenistan',
#   'Mexico',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Cook Islands',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'State of Palestine',
#   'Chad',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Yemen',
#   'Kiribati',
#   'Czechia',
#   'Kyrgyzstan',
#   'Morocco',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'South Sudan',
#   'Lesotho',
#   'India',
#   'Comoros',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Belize',
#   'Philippines',
#   'Monaco',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Tonga',
#   'Bulgaria',
#   'United Republic of Tanzania',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'Dominica',
#   'Niger',
#   'Eswatini',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Niue',
#   'Uruguay',
#   'Democratic Republic of the Congo',
#   'Papua New Guinea',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   "Democratic People's Republic of Korea",
#   'Angola',
#   'Solomon Islands',
#   'Egypt',
#   'Nepal'],
#  'Beer': ['Bulgaria',
#   'Turkey',
#   'Brazil',
#   'Belgium',
#   'The former Yugoslav Republic of Macedonia',
#   'United Republic of Tanzania',
#   'Greece',
#   'Denmark',
#   'Mongolia',
#   'Estonia',
#   'India',
#   'Dominican Republic',
#   'Azerbaijan',
#   'France',
#   'Panama',
#   'Mexico',
#   'Canada',
#   'Sweden',
#   'Netherlands',
#   'Albania',
#   'Peru',
#   'Germany',
#   'Italy',
#   'Latvia',
#   'Georgia',
#   'Nigeria',
#   'Poland',
#   'Zimbabwe',
#   'Romania',
#   'Burkina Faso',
#   'Finland',
#   'Bolivia (Plurinational State of)',
#   'United Kingdom',
#   'Chad',
#   'Madagascar',
#   'Uganda',
#   'Serbia',
#   'Ireland',
#   'Kenya',
#   'Congo',
#   'Portugal',
#   'Austria',
#   'Slovakia',
#   'Uzbekistan',
#   'Cyprus',
#   'Slovenia',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Mozambique',
#   'Bosnia and Herzegovina',
#   'Norway',
#   'Spain',
#   'Czechia',
#   'Egypt',
#   'Montenegro',
#   'Nepal'],
#  'Beer Production': ['Japan',
#   'Denmark',
#   'Korea',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Tajikistan',
#   'China',
#   'Netherlands',
#   'Peru',
#   'Italy',
#   'Germany',
#   'New Zealand',
#   'Nicaragua',
#   'Jamaica',
#   'Kenya',
#   'USA',
#   'Congo',
#   'Uzbekistan',
#   'Burundi',
#   'Lithuania',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Ethiopia',
#   'Czech Republic',
#   'Turkey',
#   'Argentina',
#   'Brazil',
#   'Belgium',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Estonia',
#   'Bolivia',
#   'Mexico',
#   'Canada',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Finland',
#   'Australia',
#   'Indonesia',
#   'Portugal',
#   'West Germany',
#   'Malawi',
#   'El Salvador',
#   'Costa Rica',
#   'Hungary',
#   'Spain',
#   'Morocco',
#   'Switzerland',
#   'Gabon',
#   'Southern Vietnam',
#   'India',
#   'Dominican Republic',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Sweden',
#   'Honduras',
#   'South Africa',
#   'Malaysia',
#   'Ghana',
#   'East Germany',
#   'Ivory Coast',
#   'Colombia',
#   'Ireland',
#   'Armenia',
#   'Austria',
#   'Macedonia',
#   'Philippines',
#   'Cuba',
#   'Russia',
#   'Bulgaria',
#   'Czechoslovakia',
#   'Cameroon',
#   'Israel',
#   'Kyrgistan',
#   'Venezuela',
#   'Ukraine',
#   'Zaire',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Burkina Faso',
#   'UK',
#   'Serbia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Mozambique',
#   'Vietnam',
#   'Rwanda',
#   'Yugoslavia',
#   'Angola',
#   'Moldova',
#   'Egypt',
#   'Paraguay',
#   'Tanzania'],
#  'Benzene': ['World'],
#  'Bicycles': ['World'],
#  'Bicycles and Other Cycles': ['Bulgaria',
#   'Japan',
#   'Turkey',
#   'Brazil',
#   'Bangladesh',
#   'Belgium',
#   'Greece',
#   'Denmark',
#   'Iran (Islamic Republic of)',
#   'India',
#   'France',
#   'Azerbaijan',
#   'Mexico',
#   'Canada',
#   'Sweden',
#   'Netherlands',
#   'Germany',
#   'Italy',
#   'Poland',
#   'Romania',
#   'Finland',
#   'United Kingdom',
#   'Iraq',
#   'Serbia',
#   'Ireland',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Ecuador',
#   'Croatia',
#   'El Salvador',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Bosnia and Herzegovina',
#   'Spain',
#   'Czechia'],
#  'Bioenergy': ['World'],
#  'Biofuels Production': ['Argentina',
#   'Brazil',
#   'Belgium',
#   'India',
#   'France',
#   'Mexico',
#   'South Korea',
#   'Canada',
#   'Sweden',
#   'China',
#   'Netherlands',
#   'Germany',
#   'Italy',
#   'Poland',
#   'Finland',
#   'United Kingdom',
#   'Australia',
#   'Indonesia',
#   'Colombia',
#   'Portugal',
#   'Austria',
#   'US',
#   'Thailand',
#   'Spain'],
#  'Biogas': ['Japan',
#   'Türkiye',
#   'Denmark',
#   'France',
#   'Azerbaijan',
#   'Lebanon',
#   'China',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Kenya',
#   'Lithuania',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Kazakhstan',
#   'Estonia',
#   'Faroe Islands',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Mauritius',
#   'Romania',
#   'Syrian Arab Republic',
#   'Guadeloupe',
#   'Finland',
#   'State of Palestine',
#   'Republic of Korea',
#   'Australia',
#   'Indonesia',
#   'Pakistan',
#   'Portugal',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Hungary',
#   'Spain',
#   'Czechia',
#   'Puerto Rico',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Jordan',
#   'India',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Sweden',
#   'Samoa',
#   'Honduras',
#   'Luxembourg',
#   'Martinique',
#   'South Africa',
#   'Ghana',
#   'Malaysia',
#   'Republic of Moldova',
#   'Réunion',
#   'Viet Nam',
#   'Colombia',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Bulgaria',
#   'United Republic of Tanzania',
#   'Israel',
#   'Ukraine',
#   'Latvia',
#   'Poland',
#   'Burkina Faso',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Serbia',
#   'Chinese Taipei',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Egypt',
#   'Paraguay'],
#  'BisphenolA': ['World'],
#  'Cable TV': ['United States'],
#  'Cadmium Refining': ['Argentina',
#   'Bulgaria',
#   'Japan',
#   'Namibia',
#   'Turkey',
#   'Brazil',
#   'Congo (Kinshasa)',
#   'Belgium',
#   'Kazakhstan',
#   'United States',
#   'India',
#   'France',
#   'Korea, Republic of',
#   'Mexico',
#   'Algeria',
#   'Canada',
#   'China',
#   'Ukraine',
#   'Netherlands',
#   'South Africa',
#   'Peru',
#   'Germany',
#   'Italy',
#   'Poland',
#   'Romania',
#   'Serbia and Montenegro',
#   'Finland',
#   'United Kingdom',
#   'Australia',
#   'Korea, North',
#   'Austria',
#   'Macedonia',
#   'World',
#   'Thailand',
#   'Yugoslavia',
#   'Norway',
#   'Spain',
#   'U.S.S.R.',
#   'Russia'],
#  'Canals': ['United States'],
#  'Capillary DNA Sequencing': ['World'],
#  'Caprolactam': ['World'],
#  'Capture Fisheries': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'American Samoa',
#   'Paraguay',
#   'St. Vincent and the Grenadines',
#   'Denmark',
#   'Brunei Darussalam',
#   'Hong Kong SAR, China',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Netherlands',
#   'Northern Mariana Islands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Bahrain',
#   'Nicaragua',
#   'St. Martin (French part)',
#   'Eritrea',
#   'Uganda',
#   'Macao SAR, China',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Togo',
#   'Norway',
#   'Marshall Islands',
#   'Haiti',
#   'Montenegro',
#   'Ethiopia',
#   'Venezuela, RB',
#   'Botswana',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Yemen, Rep.',
#   'Mongolia',
#   'Isle of Man',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Mauritania',
#   'Bolivia',
#   'Faroe Islands',
#   'Turkmenistan',
#   'West Bank and Gaza',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'British Virgin Islands',
#   'French Polynesia',
#   'Mauritius',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'St. Lucia',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Trinidad and Tobago',
#   'Indonesia',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'New Caledonia',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Spain',
#   'Kiribati',
#   'Czechia',
#   'Puerto Rico',
#   'Slovak Republic',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Cayman Islands',
#   'Gabon',
#   'Egypt, Arab Rep.',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'South Sudan',
#   'Lesotho',
#   'Iran, Islamic Rep.',
#   'Gibraltar',
#   'India',
#   'Gambia, The',
#   'Comoros',
#   'Dominican Republic',
#   'Kuwait',
#   'Virgin Islands (U.S.)',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Bahamas, The',
#   'Curacao',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Vanuatu',
#   'Palau',
#   'United Kingdom',
#   'Sint Maarten (Dutch part)',
#   'Turks and Caicos Islands',
#   "Korea, Dem. People's Rep.",
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Congo, Dem. Rep.',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Micronesia, Fed. Sts.',
#   'St. Kitts and Nevis',
#   'Monaco',
#   'Bosnia and Herzegovina',
#   'Bermuda',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Andorra',
#   'Bulgaria',
#   'Turkiye',
#   'San Marino',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'Greenland',
#   'Korea, Rep.',
#   'Lao PDR',
#   'United States',
#   'Dominica',
#   'Niger',
#   'Liechtenstein',
#   'Eswatini',
#   'Aruba',
#   'Guam',
#   'North Macedonia',
#   'Ukraine',
#   'Congo, Rep.',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Burkina Faso',
#   'Iraq',
#   'Kyrgyz Republic',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Papua New Guinea',
#   'World',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   'Solomon Islands',
#   'Angola',
#   'Vietnam',
#   'Moldova',
#   'Nepal',
#   'Tanzania'],
#  'Carbon Capture and Sequestration': ['World'],
#  'Cars': ['Japan',
#   'Turkey',
#   'Brazil',
#   'Bangladesh',
#   'Iran (Islamic Republic of)',
#   'Denmark',
#   'Estonia',
#   'India',
#   'Azerbaijan',
#   'Mexico',
#   'Sweden',
#   'Netherlands',
#   'Germany',
#   'Nigeria',
#   'Poland',
#   'Romania',
#   'Finland',
#   'Bolivia (Plurinational State of)',
#   'United Kingdom',
#   'Viet Nam',
#   'Ireland',
#   'Kenya',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Ecuador',
#   'Uruguay',
#   'Hungary',
#   'Chile',
#   'Spain',
#   'Czechia',
#   'Egypt'],
#  'Caustic Soda': ['Japan',
#   'Turkey',
#   'Brazil',
#   'Bangladesh',
#   'Belgium',
#   'Greece',
#   'Denmark',
#   'India',
#   'France',
#   'Azerbaijan',
#   'Mexico',
#   'Sweden',
#   'Netherlands',
#   'Italy',
#   'Germany',
#   'Poland',
#   'Romania',
#   'Finland',
#   'United Kingdom',
#   'Iraq',
#   'Ireland',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Ecuador',
#   'Croatia',
#   'El Salvador',
#   'Hungary',
#   'Norway',
#   'Spain',
#   'Czechia',
#   'Egypt'],
#  'Caustic Soda Acid': ['United States of America',
#   'Argentina',
#   'Japan',
#   'Turkey',
#   'South Korea',
#   'Brazil',
#   'Mexico',
#   'Canada',
#   'Algeria',
#   'China',
#   'Australia',
#   'Israel',
#   'Egypt',
#   'Pakistan',
#   'India'],
#  'Cellphones': ['Guyana',
#   'Japan',
#   'Paraguay',
#   'Denmark',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Syria',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Peru',
#   'New Zealand',
#   'Germany',
#   'Italy',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Kenya',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Togo',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Haiti',
#   'Iran',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Burma',
#   'Argentina',
#   'Turkey',
#   'Czech Republic',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Turkmenistan',
#   'Bolivia',
#   'Mauritania',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Finland',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Indonesia',
#   'Liberia',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'El Salvador',
#   'Costa Rica',
#   'Yemen',
#   'Hungary',
#   'Spain',
#   'Kyrgyzstan',
#   'Slovak Republic',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Bangladesh',
#   'Afghanistan',
#   'Bosnia-Herzegovina',
#   'Lesotho',
#   'India',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Panama',
#   'Guatemala',
#   'South Korea',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Honduras',
#   'Luxembourg',
#   'South Africa',
#   'Albania',
#   'Malaysia',
#   'Ghana',
#   'Sierra Leone',
#   'Republic of the Congo',
#   'Laos',
#   'United Kingdom',
#   'Ivory Coast',
#   'Colombia',
#   'Swaziland',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Austria',
#   'Belize',
#   'Macedonia',
#   'Philippines',
#   'Cuba',
#   'Suriname',
#   'Russia',
#   'Bulgaria',
#   'Hong Kong',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Niger',
#   'Venezuela',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Burkina Faso',
#   'Iraq',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Papua New Guinea',
#   'World',
#   'Democratic Republic of the Congo',
#   'Mozambique',
#   'Rwanda',
#   'Oman',
#   'Vietnam',
#   'Angola',
#   'Moldova',
#   'Egypt',
#   'Nepal',
#   'Tanzania'],
#  'Cement': ['World', 'United States'],
#  'Central Heating': ['United States'],
#  'Coal Power': ['World'],
#  'Coal Production': ['Bulgaria',
#   'Czech Republic',
#   'Turkey',
#   'Japan',
#   'Brazil',
#   'North America',
#   'Greece',
#   'USSR',
#   'Mongolia',
#   'Kazakhstan',
#   'India',
#   'Mexico',
#   'South Korea',
#   'Canada',
#   'China',
#   'Venezuela',
#   'Ukraine',
#   'Russian Federation',
#   'South Africa',
#   'Germany',
#   'Zimbabwe',
#   'Poland',
#   'New Zealand',
#   'Romania',
#   'Rest of World',
#   'United Kingdom',
#   'Europe',
#   'Australia',
#   'Indonesia',
#   'Colombia',
#   'Serbia',
#   'Pakistan',
#   'Uzbekistan',
#   'Hungary',
#   'World',
#   'Vietnam',
#   'US',
#   'Thailand',
#   'Spain',
#   'Asia'],
#  'Cobalt': ['World', 'United States'],
#  'Colour TV': ['United States'],
#  'Combined Refrigerators-Freezers': ['Japan',
#   'Brazil',
#   'Iran (Islamic Republic of)',
#   'Denmark',
#   'India',
#   'Mexico',
#   'Sweden',
#   'Italy',
#   'Poland',
#   'Romania',
#   'United States of America',
#   'Finland',
#   'United Kingdom',
#   'Iraq',
#   'Portugal',
#   'Uzbekistan',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Bosnia and Herzegovina',
#   'Spain',
#   'Egypt'],
#  'Compact Fluorescent Light Bulbs': ['World'],
#  'Compressed Air Energy Storage': ['United Kingdom',
#   'United States',
#   'Canada',
#   'China',
#   'Netherlands',
#   'Switzerland',
#   'Germany'],
#  'Computing Growth': ['World'],
#  'Concentrated Solar Power': ['World'],
#  'Concentrating Solar Power': ['World'],
#  'Copper|Mining': ['Argentina',
#   'Bulgaria',
#   'Czechoslovakia',
#   'Japan',
#   'Namibia',
#   'Brazil',
#   'Congo (Kinshasa)',
#   'Turkey',
#   'Mongolia',
#   'Kazakhstan',
#   'United States',
#   'Mauritania',
#   'Bolivia',
#   'India',
#   'Dominican Republic',
#   'France',
#   'Zambia',
#   'Korea, Republic of',
#   'Mexico',
#   'Canada',
#   'Sweden',
#   'China',
#   'Honduras',
#   'South Africa',
#   'Albania',
#   'Malaysia',
#   'Germany',
#   'Peru',
#   'Poland',
#   'Georgia',
#   'Russia',
#   'Zimbabwe',
#   'Romania',
#   'Serbia and Montenegro',
#   'Laos',
#   'Finland',
#   'United Kingdom',
#   'Australia',
#   'Indonesia',
#   'Korea, North',
#   'Colombia',
#   'Serbia',
#   'Pakistan',
#   'Armenia',
#   'Portugal',
#   'Saudi Arabia',
#   'Slovakia',
#   'Uzbekistan',
#   'Cyprus',
#   'Ecuador',
#   'Macedonia',
#   'Philippines',
#   'Papua New Guinea',
#   'World',
#   'Chile',
#   'Mozambique',
#   'Oman',
#   'Vietnam',
#   'Norway',
#   'Spain',
#   'U.S.S.R.',
#   'Yugoslavia',
#   'Iran',
#   'Morocco',
#   'Cuba',
#   'Nepal',
#   'Tanzania',
#   'Botswana',
#   'Burma'],
#  'Copper|Refining': ['Argentina',
#   'Bulgaria',
#   'Czech Republic',
#   'Czechoslovakia',
#   'Japan',
#   'Brazil',
#   'Congo (Kinshasa)',
#   'Turkey',
#   'Belgium',
#   'Mongolia',
#   'Kazakhstan',
#   'United States',
#   'India',
#   'Zambia',
#   'France',
#   'Korea, Republic of',
#   'Mexico',
#   'Canada',
#   'Sweden',
#   'China',
#   'Ukraine',
#   'South Africa',
#   'Albania',
#   'Peru',
#   'Germany',
#   'Italy',
#   'Poland',
#   'Zimbabwe',
#   'Romania',
#   'Serbia and Montenegro',
#   'Laos',
#   'Finland',
#   'Taiwan',
#   'United Kingdom',
#   'Australia',
#   'Indonesia',
#   'Korea, North',
#   'Serbia',
#   'Portugal',
#   'Slovakia',
#   'Austria',
#   'Uzbekistan',
#   'Cyprus',
#   'Philippines',
#   'Hungary',
#   'Chile',
#   'Oman',
#   'Thailand',
#   'Vietnam',
#   'Norway',
#   'Spain',
#   'U.S.S.R.',
#   'Yugoslavia',
#   'World',
#   'Iran',
#   'Egypt',
#   'Russia',
#   'Burma'],
#  'Corn Production': ['Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Brunei Darussalam',
#   'Central African Republic',
#   "Côte d'Ivoire",
#   'Netherlands (Kingdom of the)',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Togo',
#   'Thailand',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Kazakhstan',
#   'Senegal',
#   'Turkmenistan',
#   'Mexico',
#   'Canada',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Romania',
#   'Syrian Arab Republic',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Trinidad and Tobago',
#   'Pakistan',
#   'Portugal',
#   'China, mainland',
#   'Malawi',
#   'New Caledonia',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Yemen',
#   'Spain',
#   'Czechia',
#   'Kyrgyzstan',
#   'Puerto Rico',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Afghanistan',
#   'India',
#   'Dominican Republic',
#   'Kuwait',
#   'Palestine',
#   'Panama',
#   'Algeria',
#   'Fiji',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Suriname',
#   'Bulgaria',
#   'United Republic of Tanzania',
#   'Cameroon',
#   'Israel',
#   'Niger',
#   'North Macedonia',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   'Angola',
#   'Egypt',
#   'Nepal'],
#  'Cotton Seed Production': ['Argentina',
#   'Bulgaria',
#   'Guinea',
#   'Namibia',
#   'Paraguay',
#   'Brazil',
#   'Türkiye',
#   'Bangladesh',
#   'Myanmar',
#   'Afghanistan',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Cameroon',
#   'Israel',
#   'Kazakhstan',
#   "Côte d'Ivoire",
#   'Senegal',
#   'Turkmenistan',
#   'India',
#   'Azerbaijan',
#   'Niger',
#   'Mexico',
#   'Mali',
#   'Algeria',
#   'Tajikistan',
#   'Honduras',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Peru',
#   'Zimbabwe',
#   'Nigeria',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Romania',
#   'Syrian Arab Republic',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Indonesia',
#   'Colombia',
#   'Tunisia',
#   'Pakistan',
#   'Kenya',
#   'China, mainland',
#   'Burundi',
#   'Malawi',
#   'Morocco',
#   'Ecuador',
#   'El Salvador',
#   'Costa Rica',
#   'Cambodia',
#   'Philippines',
#   'Togo',
#   'Mozambique',
#   'Yemen',
#   'Thailand',
#   'Spain',
#   'Kyrgyzstan',
#   'Egypt',
#   'Ethiopia',
#   'Nepal',
#   'Gambia'],
#  "Cow's Milk Production": ['Guyana',
#   'Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Denmark',
#   'Brunei Darussalam',
#   "Côte d'Ivoire",
#   'Netherlands (Kingdom of the)',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Togo',
#   'Thailand',
#   'Norway',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Turkmenistan',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Trinidad and Tobago',
#   'Pakistan',
#   'Portugal',
#   'China, mainland',
#   'Malawi',
#   'New Caledonia',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Yemen',
#   'Hungary',
#   'Spain',
#   'China, Hong Kong SAR',
#   'Czechia',
#   'Kyrgyzstan',
#   'Puerto Rico',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Bangladesh',
#   'Afghanistan',
#   'India',
#   'Dominican Republic',
#   'Kuwait',
#   'Malta',
#   'Palestine',
#   'Panama',
#   'Algeria',
#   'Sweden',
#   'Fiji',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Republic of Moldova',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Suriname',
#   'Bulgaria',
#   'United Republic of Tanzania',
#   'Cameroon',
#   'Israel',
#   'Niger',
#   'North Macedonia',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Mozambique',
#   'Rwanda',
#   'Angola',
#   'Egypt',
#   'Nepal'],
#  'Crop Harvester': ['Guyana',
#   'Japan',
#   'Denmark',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Syria',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Netherlands',
#   'New Zealand',
#   'Germany',
#   'Italy',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Kenya',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Iran',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Burma',
#   'Argentina',
#   'Turkey',
#   'Czech Republic',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Turkmenistan',
#   'Bolivia',
#   'Mauritania',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Romania',
#   'Finland',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Indonesia',
#   'Pakistan',
#   'Portugal',
#   'El Salvador',
#   'Costa Rica',
#   'Yemen',
#   'Hungary',
#   'Spain',
#   'Kyrgyzstan',
#   'Slovak Republic',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Guinea',
#   'Jordan',
#   'Bosnia-Herzegovina',
#   'Lesotho',
#   'India',
#   'United Arab Emirates',
#   'Panama',
#   'Guatemala',
#   'South Korea',
#   'Algeria',
#   'Sweden',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Sierra Leone',
#   'Republic of the Congo',
#   'United Kingdom',
#   'Ivory Coast',
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Austria',
#   'Belize',
#   'Macedonia',
#   'Philippines',
#   'Cuba',
#   'Suriname',
#   'Russia',
#   'Bulgaria',
#   'Czechoslovakia',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Venezuela',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Iraq',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Papua New Guinea',
#   'Oman',
#   'Vietnam',
#   'Moldova',
#   'Egypt'],
#  'Crude Oil': ['World'],
#  'Crude Petroleum': ['Argentina',
#   'Turkey',
#   'Japan',
#   'Brazil',
#   'Myanmar',
#   'Cameroon',
#   'Israel',
#   'Egypt',
#   'Bolivia',
#   'India',
#   'Kuwait',
#   'Syria',
#   'Mexico',
#   'Algeria',
#   'Canada',
#   'China',
#   'Venezuela',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'New Zealand',
#   'Poland',
#   'Democratic Republic of Congo',
#   'Republic of the Congo',
#   'Bahrain',
#   'Nigeria',
#   'Romania',
#   'Italy',
#   'Taiwan',
#   'Iraq',
#   'Ivory Coast',
#   'UK',
#   'Australia',
#   'Indonesia',
#   'Libya',
#   'Colombia',
#   'UAE',
#   'Tunisia',
#   'USA',
#   'Trinidad & Tobago',
#   'Pakistan',
#   'Austria',
#   'Brunei',
#   'Saudi Arabia',
#   'West Germany',
#   'Ecuador',
#   'Philippines',
#   'Qatar',
#   'Hungary',
#   'Chile',
#   'Oman',
#   'Thailand',
#   'Yugoslavia',
#   'Angola',
#   'Norway',
#   'Iran',
#   'Morocco',
#   'Cuba',
#   'Russia',
#   'Gabon'],
#  'Cyclohexane': ['World'],
#  'DNA Sequencing (All Methods)': ['World'],
#  'DTP1 Vaccine': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Denmark',
#   'Brunei Darussalam',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Saint Kitts and Nevis',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Bahrain',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Togo',
#   'Norway',
#   'Marshall Islands',
#   'Haiti',
#   'Bahamas',
#   'Montenegro',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Micronesia (Federated States of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Mauritania',
#   'Turkmenistan',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Cook Islands',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'State of Palestine',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Yemen',
#   'Spain',
#   'Kiribati',
#   'Czechia',
#   'Kyrgyzstan',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'South Sudan',
#   'Lesotho',
#   'India',
#   'Comoros',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Palau',
#   'United Kingdom',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Monaco',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Andorra',
#   'Bulgaria',
#   'San Marino',
#   'United Republic of Tanzania',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Dominica',
#   'Niger',
#   'Eswatini',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Niue',
#   'Uruguay',
#   'Democratic Republic of the Congo',
#   'Papua New Guinea',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   "Democratic People's Republic of Korea",
#   'Angola',
#   'Solomon Islands',
#   'Egypt',
#   'Nepal'],
#  'DTP3 Vaccine': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Denmark',
#   'Brunei Darussalam',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Saint Kitts and Nevis',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Bahrain',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Togo',
#   'Norway',
#   'Marshall Islands',
#   'Haiti',
#   'Bahamas',
#   'Montenegro',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Micronesia (Federated States of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Mauritania',
#   'Turkmenistan',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Cook Islands',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'State of Palestine',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Yemen',
#   'Spain',
#   'Kiribati',
#   'Czechia',
#   'Kyrgyzstan',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'South Sudan',
#   'Lesotho',
#   'India',
#   'Comoros',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Palau',
#   'United Kingdom',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Monaco',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Andorra',
#   'Bulgaria',
#   'San Marino',
#   'United Republic of Tanzania',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Dominica',
#   'Niger',
#   'Eswatini',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Niue',
#   'Uruguay',
#   'Democratic Republic of the Congo',
#   'Papua New Guinea',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   "Democratic People's Republic of Korea",
#   'Angola',
#   'Solomon Islands',
#   'Egypt',
#   'Nepal'],
#  'Desalination Capacity': ['World'],
#  'Dishwashers': ['United States'],
#  'Disk Brakes': ['United States'],
#  'Ebook Reader': ['United States'],
#  'Electric Bicycles': ['World', 'China'],
#  'Electric Range': ['United States'],
#  'Electric Water Heaters and Immersion Heaters': ['Bulgaria',
#   'Turkey',
#   'Brazil',
#   'The former Yugoslav Republic of Macedonia',
#   'Greece',
#   'Denmark',
#   'Estonia',
#   'India',
#   'Azerbaijan',
#   'Mexico',
#   'Sweden',
#   'Netherlands',
#   'Italy',
#   'Germany',
#   'Poland',
#   'Romania',
#   'United States of America',
#   'Finland',
#   'United Kingdom',
#   'Iraq',
#   'Ireland',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Croatia',
#   'Hungary',
#   'Bosnia and Herzegovina',
#   'Norway',
#   'Spain',
#   'Egypt'],
#  'Electricity': ['Japan',
#   'Denmark',
#   'France',
#   'Azerbaijan',
#   'China',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Uzbekistan',
#   'Lithuania',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Iran',
#   'Argentina',
#   'Czech Republic',
#   'Turkey',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Kazakhstan',
#   'Estonia',
#   'Turkmenistan',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Romania',
#   'Singapore',
#   'Finland',
#   'Taiwan',
#   'Australia',
#   'Indonesia',
#   'Pakistan',
#   'Portugal',
#   'Cyprus',
#   'Qatar',
#   'Hungary',
#   'Spain',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Bangladesh',
#   'India',
#   'Kuwait',
#   'United Arab Emirates',
#   'South Korea',
#   'Algeria',
#   'Sweden',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Malaysia',
#   'United Kingdom',
#   'Colombia',
#   'Ireland',
#   'Trinidad & Tobago',
#   'Slovakia',
#   'Austria',
#   'Philippines',
#   'Bulgaria',
#   'Israel',
#   'North Macedonia',
#   'Venezuela',
#   'Ukraine',
#   'Latvia',
#   'Poland',
#   'Iraq',
#   'China Hong Kong SAR',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'World',
#   'Oman',
#   'US',
#   'Vietnam',
#   'Egypt'],
#  'Electro-Chemical Capacitor': ['South Korea',
#   'Spain',
#   'China',
#   'United States',
#   'Ireland',
#   'Italy'],
#  'Electronic Ignition': ['United States'],
#  'Ethanol': ['World'],
#  'Ethanolamine': ['World'],
#  'Ethylene': ['World'],
#  'Ethylene Glycol': ['World'],
#  'Flow Battery Storage': ['Japan',
#   'Czech Republic',
#   'Denmark',
#   'Israel',
#   'Kazakhstan',
#   'United States',
#   'India',
#   'South Korea',
#   'Canada',
#   'China',
#   'Netherlands',
#   'French Polynesia',
#   'South Africa',
#   'Antigua and Barbuda',
#   'Germany',
#   'New Zealand',
#   'Italy',
#   'United Kingdom',
#   'Australia',
#   'Indonesia',
#   'Portugal',
#   'Austria',
#   'Slovenia',
#   'Switzerland',
#   'Russia'],
#  'Fluid Catalytic Cracking Refineries': ['World', 'US'],
#  'Flush Toilet': ['United States'],
#  'Flywheel Battery Storage': ['Romania',
#   'Czech Republic',
#   'Antarctica',
#   'Mexico',
#   'South Korea',
#   'United Kingdom',
#   'Canada',
#   'Spain',
#   'Australia',
#   'Netherlands',
#   'Kenya',
#   'United States',
#   'Ireland',
#   'France',
#   'Germany'],
#  'Formaldehyde': ['World'],
#  'Freezer': ['United States'],
#  'Geothermal Energy': ['Argentina',
#   'Japan',
#   'Türkiye',
#   'France',
#   'Iceland',
#   'Guatemala',
#   'Mexico',
#   'China',
#   'Honduras',
#   'Russian Federation',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Romania',
#   'United States of America',
#   'Guadeloupe',
#   'Nicaragua',
#   'Australia',
#   'Indonesia',
#   'Kenya',
#   'Portugal',
#   'Chinese Taipei',
#   'Austria',
#   'El Salvador',
#   'Croatia',
#   'Costa Rica',
#   'Philippines',
#   'World',
#   'Chile',
#   'Hungary',
#   'Thailand',
#   'Ethiopia'],
#  'Gold': ['Japan',
#   'India',
#   'South Korea',
#   'Papua New Guinea',
#   'Zimbabwe',
#   'China',
#   'Fiji',
#   'Australia',
#   'Korea',
#   'Zaire',
#   'South Africa',
#   'Ghana',
#   'New Zealand',
#   'Phillipines'],
#  'Gold Production': ['World', 'United States'],
#  'Graphite': ['World', 'United States'],
#  'Ground Source Heat Pumps': ['World'],
#  'HEPB3 Vaccine': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Brunei Darussalam',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Saint Kitts and Nevis',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Bahrain',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Togo',
#   'Norway',
#   'Marshall Islands',
#   'Haiti',
#   'Bahamas',
#   'Montenegro',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Micronesia (Federated States of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Mauritania',
#   'Turkmenistan',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Cook Islands',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'State of Palestine',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Yemen',
#   'Spain',
#   'Kiribati',
#   'Czechia',
#   'Kyrgyzstan',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'South Sudan',
#   'Lesotho',
#   'India',
#   'Comoros',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Palau',
#   'United Kingdom',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Monaco',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Andorra',
#   'Bulgaria',
#   'San Marino',
#   'United Republic of Tanzania',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Dominica',
#   'Niger',
#   'Eswatini',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Niue',
#   'Uruguay',
#   'Democratic Republic of the Congo',
#   'Papua New Guinea',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   "Democratic People's Republic of Korea",
#   'Angola',
#   'Solomon Islands',
#   'Egypt',
#   'Nepal'],
#  'HEPBB Vaccine': ['Guyana',
#   'Bhutan',
#   'Türkiye',
#   'Brunei Darussalam',
#   'Azerbaijan',
#   'Saint Kitts and Nevis',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Cabo Verde',
#   'Peru',
#   'Bahrain',
#   'Tunisia',
#   'Uzbekistan',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Marshall Islands',
#   'Gambia',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Myanmar',
#   'Iran (Islamic Republic of)',
#   'Micronesia (Federated States of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Turkmenistan',
#   'Mexico',
#   'Saint Lucia',
#   'Nigeria',
#   'Cook Islands',
#   'Romania',
#   'Singapore',
#   'State of Palestine',
#   'Republic of Korea',
#   'Indonesia',
#   'Tuvalu',
#   'Sao Tome and Principe',
#   'Portugal',
#   'El Salvador',
#   'Qatar',
#   'Costa Rica',
#   'Timor-Leste',
#   'Kiribati',
#   'Kyrgyzstan',
#   'Morocco',
#   'Benin',
#   'Grenada',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'India',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Albania',
#   'Malaysia',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Palau',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Armenia',
#   'Belize',
#   'Philippines',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Andorra',
#   'Bulgaria',
#   'Israel',
#   'United States',
#   'Dominica',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Niue',
#   'Papua New Guinea',
#   'Solomon Islands',
#   'Oman',
#   "Democratic People's Republic of Korea",
#   'Egypt'],
#  'HIB3 Vaccine': ['Guyana',
#   'Bhutan',
#   'Japan',
#   'Paraguay',
#   'Türkiye',
#   'Denmark',
#   'Brunei Darussalam',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Saint Kitts and Nevis',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'Guinea-Bissau',
#   'Cabo Verde',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'Bahrain',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Djibouti',
#   'Thailand',
#   'Togo',
#   'Norway',
#   'Marshall Islands',
#   'Haiti',
#   'Bahamas',
#   'Montenegro',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Micronesia (Federated States of)',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Mauritania',
#   'Turkmenistan',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Saint Lucia',
#   'Nigeria',
#   'Cook Islands',
#   'Romania',
#   'Singapore',
#   'Syrian Arab Republic',
#   'Finland',
#   'State of Palestine',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Republic of Korea',
#   'Indonesia',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Trinidad and Tobago',
#   'Tuvalu',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'Cyprus',
#   'El Salvador',
#   'Costa Rica',
#   'Qatar',
#   'Timor-Leste',
#   'Hungary',
#   'Yemen',
#   'Spain',
#   'Kiribati',
#   'Czechia',
#   'Kyrgyzstan',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Grenada',
#   'Bangladesh',
#   'Nauru',
#   'Afghanistan',
#   "Cote d'Ivoire",
#   'Maldives',
#   'South Sudan',
#   'Lesotho',
#   'India',
#   'Comoros',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Malta',
#   'Panama',
#   'Guatemala',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Luxembourg',
#   'South Africa',
#   'Albania',
#   'Ghana',
#   'Malaysia',
#   'Sierra Leone',
#   'Republic of Moldova',
#   'Vanuatu',
#   'Palau',
#   'United Kingdom',
#   'Viet Nam',
#   'Saint Vincent and the Grenadines',
#   'Colombia',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Slovakia',
#   'Austria',
#   'Barbados',
#   'Belize',
#   'Philippines',
#   'Monaco',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Tonga',
#   'Suriname',
#   'Andorra',
#   'Bulgaria',
#   'San Marino',
#   'United Republic of Tanzania',
#   'Seychelles',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Dominica',
#   'Niger',
#   'Eswatini',
#   'Ukraine',
#   'Antigua and Barbuda',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
# ...
#   'Burkina Faso',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Venezuela (Bolivarian Republic of)',
#   'Iraq',
#   'Serbia',
#   'Saudi Arabia',
#   'Chinese Taipei',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Niue',
#   'Uruguay',
#   'Papua New Guinea',
#   'World',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   "Democratic People's Republic of Korea",
#   'Solomon Islands',
#   'Egypt',
#   'Nepal'],
#  'Solar Thermal Energy': ['Türkiye',
#   'Israel',
#   'Egypt',
#   'India',
#   'France',
#   'Kuwait',
#   'United Arab Emirates',
#   'Mexico',
#   'Algeria',
#   'China',
#   'South Africa',
#   'Germany',
#   'Italy',
#   'Romania',
#   'United States of America',
#   'Republic of Korea',
#   'Australia',
#   'Saudi Arabia',
#   'Chile',
#   'Thailand',
#   'Spain',
#   'Morocco'],
#  'Solid Biofuels': ['Guyana',
#   'Japan',
#   'Türkiye',
#   'Denmark',
#   'Nepal',
#   'Zambia',
#   'France',
#   'China',
#   'Netherlands',
#   'Peru',
#   'Germany',
#   'Italy',
#   'New Zealand',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Uganda',
#   'Jamaica',
#   'Kenya',
#   'Congo',
#   'Cambodia',
#   'Lithuania',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Ethiopia',
#   'Republic of North Macedonia',
#   'Argentina',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Senegal',
#   'Estonia',
#   'Mexico',
#   'Canada',
#   'Mauritius',
#   'Romania',
#   'Singapore',
#   'Guadeloupe',
#   'Finland',
#   'Chad',
#   'Australia',
#   'Republic of Korea',
#   'Trinidad and Tobago',
#   'Indonesia',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'El Salvador',
#   'Costa Rica',
#   'Hungary',
#   'Spain',
#   'Czechia',
#   'Puerto Rico',
#   'Sri Lanka',
#   'India',
#   'Dominican Republic',
#   'Guatemala',
#   'Sweden',
#   'Fiji',
#   'Samoa',
#   'Honduras',
#   'Luxembourg',
#   'Russian Federation',
#   'Martinique',
#   'South Africa',
#   'Malaysia',
#   'Sierra Leone',
#   'Réunion',
#   'Viet Nam',
#   'Colombia',
#   'Ireland',
#   'Slovakia',
#   'Austria',
#   'Belize',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Bulgaria',
#   'United Republic of Tanzania',
#   'Sudan',
#   'Eswatini',
#   'French Guiana',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   "Lao People's Democratic Republic",
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Serbia',
#   'Chinese Taipei',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Mozambique',
#   'Rwanda',
#   'Angola',
#   'Egypt',
#   'Paraguay'],
#  'Soybean Production': ['Bhutan',
#   'Japan',
#   'Türkiye',
#   'Nepal',
#   "Côte d'Ivoire",
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Mali',
#   'Tajikistan',
#   'Peru',
#   'Germany',
#   'Italy',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Burundi',
#   'Cambodia',
#   'Togo',
#   'Thailand',
#   'Ethiopia',
#   'Argentina',
#   'Brazil',
#   'Myanmar',
#   'Greece',
#   'Iran (Islamic Republic of)',
#   'Kazakhstan',
#   'Mexico',
#   'Canada',
#   'Nigeria',
#   'Romania',
#   'Syrian Arab Republic',
#   'Madagascar',
#   'Australia',
#   'Republic of Korea',
#   'Indonesia',
#   'Pakistan',
#   'China, mainland',
#   'Malawi',
#   'El Salvador',
#   'Timor-Leste',
#   'Hungary',
#   'Spain',
#   'Czechia',
#   'Kyrgyzstan',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Bangladesh',
#   'India',
#   'Panama',
#   'Honduras',
#   'Russian Federation',
#   'South Africa',
#   'Albania',
#   'Malaysia',
#   'Republic of Moldova',
#   'Viet Nam',
#   'Colombia',
#   'Slovakia',
#   'Austria',
#   'Belize',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Suriname',
#   'Bulgaria',
#   'United Republic of Tanzania',
#   'Cameroon',
#   'North Macedonia',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'Serbia',
#   'Slovenia',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Rwanda',
#   'Angola',
#   'Egypt',
#   'Paraguay'],
#  'Space Launches': ['World'],
#  'Stationary Steam Engines': ['World'],
#  'Steam Locomotives': ['World'],
#  'Steamships': ['Belgium',
#   'Greece',
#   'Denmark',
#   'France',
#   'Mexico',
#   'Canada',
#   'Sweden',
#   'Netherlands',
#   'Italy',
#   'Germany',
#   'Finland',
#   'United Kingdom',
#   'Ireland',
#   'Austria',
#   'Hungary',
#   'Chile',
#   'Norway',
#   'Spain',
#   'Cuba',
#   'Russia'],
#  'Stove': ['United States'],
#  'Styrene': ['World'],
#  'Submarine Cables': ['World'],
#  'Sugar Cane Production': ['Argentina',
#   'Bhutan',
#   'Guinea',
#   'Japan',
#   'Paraguay',
#   'Brazil',
#   'Grenada',
#   'Bangladesh',
#   'Myanmar',
#   'Afghanistan',
#   'Iran (Islamic Republic of)',
#   "Côte d'Ivoire",
#   'Senegal',
#   'India',
#   'Dominican Republic',
#   'Niger',
#   'Panama',
#   'Mexico',
#   'Mali',
#   'Lebanon',
#   'Fiji',
#   'Honduras',
#   'Cabo Verde',
#   'Mauritius',
#   'South Africa',
#   'Ghana',
#   'Malaysia',
#   'Peru',
#   'Nigeria',
#   'Zimbabwe',
#   "Lao People's Democratic Republic",
#   'Burkina Faso',
#   'United States of America',
#   'Bolivia (Plurinational State of)',
#   'Nicaragua',
#   'Viet Nam',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Trinidad and Tobago',
#   'Indonesia',
#   'Jamaica',
#   'Kenya',
#   'Pakistan',
#   'Congo',
#   'Portugal',
#   'China, mainland',
#   'Burundi',
#   'Barbados',
#   'Malawi',
#   'Morocco',
#   'Belize',
#   'Ecuador',
#   'Costa Rica',
#   'Cambodia',
#   'El Salvador',
#   'Philippines',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   'Suriname',
#   'Thailand',
#   'Uruguay',
#   'Puerto Rico',
#   'Egypt',
#   'Ethiopia',
#   'Nepal',
#   'Sri Lanka'],
#  'Sugar Output': ['Japan',
#   'Turkey',
#   'Bangladesh',
#   'Myanmar',
#   'Sudan',
#   'India',
#   'Dominican Republic',
#   'Panama',
#   'Guatemala',
#   'Mexico',
#   'China',
#   'Honduras',
#   'South Africa',
#   'Mauritius',
#   'Zimbabwe',
#   'Taiwan',
#   'Nicaragua',
#   'Ivory Coast',
#   'Madagascar',
#   'Indonesia',
#   'Swaziland',
#   'Jamaica',
#   'Kenya',
#   'USA',
#   'Trinidad & Tobago',
#   'Pakistan',
#   'Malawi',
#   'Morocco',
#   'Barbados',
#   'El Salvador',
#   'Philippines',
#   'Costa Rica',
#   'Mozambique',
#   'Vietnam',
#   'Thailand',
#   'Spain',
#   'Haiti',
#   'Iran',
#   'Egypt',
#   'Cuba',
#   'Ethiopia',
#   'Tanzania'],
#  'Sulphuric Acid': ['Japan',
#   'Czechoslovakia',
#   'Bulgaria',
#   'Argentina',
#   'Turkey',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Denmark',
#   'Israel',
#   'Cuba',
#   'Phillipines',
#   'India',
#   'France',
#   'Zambia',
#   'Mexico',
#   'South Korea',
#   'Canada',
#   'Algeria',
#   'Sweden',
#   'China',
#   'Venezuela',
#   'Zaire',
#   'Netherlands',
#   'Peru',
#   'Italy',
#   'Germany',
#   'Poland',
#   'Romania',
#   'United States of America',
#   'Finland',
#   'United Kingdom',
#   'East Germany',
#   'Australia',
#   'Indonesia',
#   'Colombia',
#   'Tunisia',
#   'Pakistan',
#   'Ireland',
#   'Portugal',
#   'West Germany',
#   'Austria',
#   'Morocco',
#   'Hungary',
#   'Chile',
#   'Yugoslavia',
#   'Thailand',
#   'Norway',
#   'Iran',
#   'Egypt',
#   'Switzerland',
#   'Russia'],
#  'Synthetic Filament Tow and Staple Fibers': ['Turkey',
#   'Brazil',
#   'Iran (Islamic Republic of)',
#   'Denmark',
#   'Azerbaijan',
#   'Mexico',
#   'Sweden',
#   'Netherlands',
#   'Italy',
#   'Germany',
#   'Poland',
#   'Romania',
#   'Finland',
#   'United Kingdom',
#   'Ireland',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Ecuador',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Spain',
#   'Czechia'],
#  'Synthetic Filament Yarn': ['Bulgaria',
#   'Japan',
#   'Turkey',
#   'Brazil',
#   'Greece',
#   'Denmark',
#   'Iran (Islamic Republic of)',
#   'Estonia',
#   'Azerbaijan',
#   'Sweden',
#   'Netherlands',
#   'Italy',
#   'Latvia',
#   'Germany',
#   'Poland',
#   'Romania',
#   'Finland',
#   'Ireland',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Ecuador',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Spain',
#   'Czechia'],
#  'Synthetic Filaments': ['Japan',
#   'Czechoslovakia',
#   'Turkey',
#   'Belgium',
#   'India',
#   'Phillipines',
#   'France',
#   'South Korea',
#   'Sweden',
#   'China',
#   'Netherlands',
#   'South Africa',
#   'Malaysia',
#   'Italy',
#   'Germany',
#   'Poland',
#   'Romania',
#   'Finland',
#   'United Kingdom',
#   'East Germany',
#   'Australia',
#   'Indonesia',
#   'Pakistan',
#   'West Germany',
#   'Austria',
#   'Yugoslavia',
#   'Thailand',
#   'Norway',
#   'Spain',
#   'Iran',
#   'Egypt',
#   'Switzerland',
#   'Russia'],
#  'Tablet': ['United States'],
#  'Telegraph Traffic': ['Guyana',
#   'Argentina',
#   'Turkey',
#   'Japan',
#   'Czechoslovakia',
#   'Brazil',
#   'Belgium',
#   'Tanzania',
#   'Greece',
#   'Denmark',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'Egypt',
#   'United States',
#   'India',
#   'Zambia',
#   'France',
#   'Syria',
#   'Mexico',
#   'South Korea',
#   'Lebanon',
#   'Algeria',
#   'Canada',
#   'Sweden',
#   'China',
#   'Venezuela',
#   'Netherlands',
#   'South Africa',
#   'Malaysia',
#   'New Zealand',
#   'Germany',
#   'Poland',
#   'Italy',
#   'Ghana',
#   'Zimbabwe',
#   'Peru',
#   'Romania',
#   'Singapore',
#   'Nigeria',
#   'Finland',
#   'United Kingdom',
#   'Taiwan',
#   'Iraq',
#   'Ivory Coast',
#   'Madagascar',
#   'Australia',
#   'Uganda',
#   'Indonesia',
#   'Colombia',
#   'Serbia',
#   'Pakistan',
#   'Ireland',
#   'Kenya',
#   'Portugal',
#   'Tunisia',
#   'Austria',
#   'Malawi',
#   'El Salvador',
#   'Uruguay',
#   'Philippines',
#   'Democratic Republic of the Congo',
#   'Hungary',
#   'Mozambique',
#   'Togo',
#   'Thailand',
#   'South Vietnam',
#   'Norway',
#   'Spain',
#   'Chile',
#   'Angola',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Russia',
#   'Burma'],
#  'Telephones': ['Guyana',
#   'Japan',
#   'Paraguay',
#   'Denmark',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Syria',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Peru',
#   'New Zealand',
#   'Germany',
#   'Italy',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Kenya',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Togo',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Haiti',
#   'Iran',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Burma',
#   'Argentina',
#   'Turkey',
#   'Czech Republic',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Turkmenistan',
#   'Bolivia',
#   'Mauritania',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Finland',
#   'Taiwan',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Indonesia',
#   'Liberia',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'El Salvador',
#   'Costa Rica',
#   'Yemen',
#   'Hungary',
#   'Spain',
#   'Kyrgyzstan',
#   'Slovak Republic',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Bangladesh',
#   'Afghanistan',
#   'Bosnia-Herzegovina',
#   'Lesotho',
#   'India',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Panama',
#   'Guatemala',
#   'South Korea',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Honduras',
#   'Luxembourg',
#   'South Africa',
#   'Albania',
#   'Malaysia',
#   'Ghana',
#   'Sierra Leone',
#   'Republic of the Congo',
#   'Laos',
#   'United Kingdom',
#   'Ivory Coast',
#   'Colombia',
#   'Swaziland',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Austria',
#   'Belize',
#   'Macedonia',
#   'Philippines',
#   'South Vietnam',
#   'Cuba',
#   'Suriname',
#   'Russia',
#   'Bulgaria',
#   'Czechoslovakia',
#   'Hong Kong',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Niger',
#   'Venezuela',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Burkina Faso',
#   'Iraq',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Papua New Guinea',
#   'Democratic Republic of the Congo',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   'Vietnam',
#   'Angola',
#   'Moldova',
#   'Egypt',
#   'Nepal',
#   'Tanzania'],
#  'Telephones and Videophones': ['Bulgaria',
#   'Japan',
#   'Turkey',
#   'Brazil',
#   'Bangladesh',
#   'Iran (Islamic Republic of)',
#   'Denmark',
#   'India',
#   'Sweden',
#   'Germany',
#   'Italy',
#   'Poland',
#   'Romania',
#   'Finland',
#   'United Kingdom',
#   'Iraq',
#   'Portugal',
#   'Uzbekistan',
#   'Hungary',
#   'Chile',
#   'Lithuania',
#   'Spain',
#   'Czechia',
#   'Egypt'],
#  'Television': ['Guyana',
#   'Japan',
#   'Paraguay',
#   'Denmark',
#   'Central African Republic',
#   'Zambia',
#   'France',
#   'Azerbaijan',
#   'Syria',
#   'Mali',
#   'Lebanon',
#   'Tajikistan',
#   'China',
#   'Guinea-Bissau',
#   'Netherlands',
#   'Peru',
#   'New Zealand',
#   'Germany',
#   'Italy',
#   'Nicaragua',
#   'Eritrea',
#   'Uganda',
#   'Tunisia',
#   'Kenya',
#   'Uzbekistan',
#   'Burundi',
#   'Cambodia',
#   'Lithuania',
#   'Togo',
#   'Chile',
#   'Thailand',
#   'Norway',
#   'Haiti',
#   'Iran',
#   'Ethiopia',
#   'Gambia',
#   'Botswana',
#   'Burma',
#   'Argentina',
#   'Turkey',
#   'Czech Republic',
#   'Namibia',
#   'Brazil',
#   'Belgium',
#   'Greece',
#   'Mongolia',
#   'Kazakhstan',
#   'Senegal',
#   'Estonia',
#   'Turkmenistan',
#   'Bolivia',
#   'Mauritania',
#   'Iceland',
#   'Mexico',
#   'Canada',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Nigeria',
#   'Romania',
#   'Singapore',
#   'Finland',
#   'Taiwan',
#   'Chad',
#   'Australia',
#   'Madagascar',
#   'Indonesia',
#   'Liberia',
#   'Pakistan',
#   'Portugal',
#   'Malawi',
#   'El Salvador',
#   'Costa Rica',
#   'Yemen',
#   'Hungary',
#   'Spain',
#   'Kyrgyzstan',
#   'Slovak Republic',
#   'Morocco',
#   'Switzerland',
#   'Sri Lanka',
#   'Gabon',
#   'Benin',
#   'Guinea',
#   'Jordan',
#   'Bangladesh',
#   'Afghanistan',
#   'Bosnia-Herzegovina',
#   'Lesotho',
#   'India',
#   'Dominican Republic',
#   'Kuwait',
#   'United Arab Emirates',
#   'Panama',
#   'Guatemala',
#   'South Korea',
#   'Algeria',
#   'Somalia',
#   'Sweden',
#   'Honduras',
#   'Luxembourg',
#   'South Africa',
#   'Albania',
#   'Malaysia',
#   'Ghana',
#   'Sierra Leone',
#   'Republic of the Congo',
#   'Laos',
#   'United Kingdom',
#   'Ivory Coast',
#   'Colombia',
#   'Swaziland',
#   'Libya',
#   'Ireland',
#   'Armenia',
#   'Austria',
#   'Belize',
#   'Macedonia',
#   'Philippines',
#   'South Vietnam',
#   'Cuba',
#   'Suriname',
#   'Russia',
#   'Bulgaria',
#   'Czechoslovakia',
#   'Hong Kong',
#   'Cameroon',
#   'Israel',
#   'Sudan',
#   'United States',
#   'Niger',
#   'Venezuela',
#   'Ukraine',
#   'Zimbabwe',
#   'Latvia',
#   'Poland',
#   'Georgia',
#   'Burkina Faso',
#   'Iraq',
#   'Saudi Arabia',
#   'Slovenia',
#   'Belarus',
#   'Ecuador',
#   'Croatia',
#   'Uruguay',
#   'Papua New Guinea',
#   'Democratic Republic of the Congo',
#   'Mozambique',
#   'Oman',
#   'Rwanda',
#   'Vietnam',
#   'Angola',
#   'Moldova',
#   'Egypt',
#   'Nepal',
#   'Tanzania'],
#  'Television Receivers': ['Bulgaria',
#   'Japan',
#   'Turkey',
#   'Brazil',
#   'Bangladesh',
#   'Denmark',
#   'Mongolia',
#   'Azerbaijan',
#   'Sweden',
#   'Italy',
#   'Germany',
#   'Poland',
#   'Nigeria',
#   'Finland',
#   'Iraq',
#   'Portugal',
#   'Slovakia',
#   'Uzbekistan',
#   'Ecuador',
#   'Hungary',
#   'Lithuania',
#   'Spain',
#   'Czechia',
#   'Egypt'],
#  'Tin': ['Brazil',
#   'Thailand',
#   'China',
#   'Australia',
#   'Indonesia',
#   'Malaysia',
#   'Nigeria',
#   'Bolivia'],
#  'Tin Production': ['World', 'United States'],
#  'Titanium Sponge': ['World'],
#  'Transistors per Microprocessor': ['World'],
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': ['United Kingdom'],
#  'Urea': ['World'],
#  'Vacuum Cleaners': ['Japan',
#   'Turkey',
#   'Brazil',
#   'Denmark',
#   'India',
#   'France',
#   'Sweden',
#   'Netherlands',
#   'Germany',
#   'Italy',
#   'Poland',
#   'Romania',
#   'Finland',
#   'Bolivia (Plurinational State of)',
#   'United Kingdom',
#   'Ireland',
#   'Portugal',
#   'Uzbekistan',
#   'Ecuador',
#   'Hungary',
#   'Chile',
#   'Egypt'],
#  'Vacuums': ['United States'],
#  'Videocassette Recorder': ['United States'],
#  'Vinyl Acetate': ['World'],
#  'Vinyl Chloride': ['World'],
#  'Washing Machines': ['World', 'US'],
#  'Water Heater': ['United States'],
#  'Wet Flue Gas Desulfurization Systems': ['World',
#   'United States',
#   'Japan',
#   'Germany'],
#  'YFV Vaccine': ['Guyana',
#   'Benin',
#   'Argentina',
#   'Guinea',
#   'Brazil',
#   "Cote d'Ivoire",
#   'Cameroon',
#   'Central African Republic',
#   'Senegal',
#   'Niger',
#   'Panama',
#   'Mali',
#   'Equatorial Guinea',
#   'Guinea-Bissau',
#   'Ghana',
#   'Peru',
#   'Nigeria',
#   'Sierra Leone',
#   'Burkina Faso',
#   'Bolivia (Plurinational State of)',
#   'Venezuela (Bolivarian Republic of)',
#   'Chad',
#   'Trinidad and Tobago',
#   'Liberia',
#   'Sao Tome and Principe',
#   'Colombia',
#   'Kenya',
#   'Congo',
#   'Ecuador',
#   'Suriname',
#   'Democratic Republic of the Congo',
#   'Togo',
#   'Angola',
#   'Paraguay',
#   'Gambia',
#   'Gabon'],
#  'Zinc': ['United States of America',
#   'Japan',
#   'Argentina',
#   'Mexico',
#   'Brazil',
#   'South Korea',
#   'Canada',
#   'Algeria',
#   'North Korea',
#   'China',
#   'Australia',
#   'Korea',
#   'Zaire',
#   'Peru',
#   'India',
#   'Zambia'],
#  'Zinc Production': ['World', 'United States'],
#  'Zinc-Based Battery': ['Madagascar', 'United States', 'Indonesia']}

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict
# Out:
# {'Acrylic Fiber': 1,
#  'Acrylonitrile': 1,
#  'Air-Source Heat Pumps': 1,
#  'Amazon Prime Users': 1,
#  'Aniline': 1,
#  'Automatic Transmission': 1,
#  'Benzene': 1,
#  'Bicycles': 1,
#  'Bioenergy': 1,
#  'BisphenolA': 1,
#  'Cable TV': 1,
#  'Canals': 1,
#  'Capillary DNA Sequencing': 1,
#  'Caprolactam': 1,
#  'Carbon Capture and Sequestration': 1,
#  'Central Heating': 1,
#  'Coal Power': 1,
#  'Colour TV': 1,
#  'Compact Fluorescent Light Bulbs': 1,
#  'Computing Growth': 1,
#  'Concentrated Solar Power': 1,
#  'Concentrating Solar Power': 1,
#  'Crude Oil': 1,
#  'Cyclohexane': 1,
#  'DNA Sequencing (All Methods)': 1,
#  'Desalination Capacity': 1,
#  'Dishwashers': 1,
#  'Disk Brakes': 1,
#  'Ebook Reader': 1,
#  'Electric Range': 1,
#  'Electronic Ignition': 1,
#  'Ethanol': 1,
#  'Ethanolamine': 1,
#  'Ethylene': 1,
#  'Ethylene Glycol': 1,
#  'Flush Toilet': 1,
#  'Formaldehyde': 1,
#  'Freezer': 1,
#  'Ground Source Heat Pumps': 1,
#  'Herbicide-Tolerant Corn': 1,
#  'Herbicide-Tolerant Cotton': 1,
#  'Herbicide-Tolerant Soybeans': 1,
#  'High-Density Polyethylene': 1,
#  'High-Speed Rail': 1,
#  'Home Air Conditioning': 1,
#  'Home Computers': 1,
#  'Household Internet Access': 1,
#  'Households With Only Mobile Phones (No Landlines)': 1,
#  'Hydrofluoric Acid': 1,
#  'Hydropower': 1,
#  'Insect-Resistant Corn': 1,
#  'Insect-Resistant Cotton': 1,
#  'Internet Backbone Bandwidth': 1,
#  'Internet Traffic': 1,
#  'Iron': 1,
#  'Jet Aircraft': 1,
#  'Liquefied Natural Gas': 1,
#  'Liquefied Natural Gas (LNG)': 1,
#  'Low-Density Polyethylene': 1,
#  'Magnesium': 1,
#  'Magnetic Data Storage': 1,
#  'Maleic Anhydride': 1,
#  'Methanol': 1,
#  'Microcomputers': 1,
#  'Microprocessor Clock Speed': 1,
#  'Microwaves': 1,
#  'Motor Gasoline': 1,
#  'Motorcycles': 1,
#  'Natural Gas Pipeline': 1,
#  'Natural Gas Power': 1,
#  'Neoprene Rubber': 1,
#  'Nox Pollution Controls (Boilers)': 1,
#  'Oil Pipeline': 1,
#  'Paraxylene': 1,
#  'Pentaerythritol': 1,
#  'Phenol': 1,
#  'Phthalic Anhydride': 1,
#  'Podcasting': 1,
#  'Polyester Fiber': 1,
#  'Polystyrene': 1,
#  'Polyvinylchloride': 1,
#  'Power Steering': 1,
#  'Primary Magnesium': 1,
#  'Processor Performance': 1,
#  'Public Roads': 1,
#  'Radial Tires': 1,
#  'Random Access Memory': 1,
#  'Real-Time Gross Settlement Adoption': 1,
#  'Running Water': 1,
#  'Shale Production': 1,
#  'Shotgun Sanger DNA Sequencing': 1,
#  'Smartphone Usage': 1,
#  'Social Media Usage': 1,
#  'Sodium': 1,
#  'Sodium Chlorate': 1,
#  'Space Launches': 1,
#  'Stationary Steam Engines': 1,
#  'Steam Locomotives': 1,
#  'Stove': 1,
#  'Styrene': 1,
#  'Submarine Cables': 1,
#  'Tablet': 1,
#  'Titanium Sponge': 1,
#  'Transistors per Microprocessor': 1,
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': 1,
#  'Urea': 1,
#  'Vacuums': 1,
#  'Videocassette Recorder': 1,
#  'Vinyl Acetate': 1,
#  'Vinyl Chloride': 1,
#  'Water Heater': 1,
#  'Cement': 2,
#  'Cobalt': 2,
#  'Electric Bicycles': 2,
#  'Fluid Catalytic Cracking Refineries': 2,
#  'Gold Production': 2,
#  'Graphite': 2,
#  'Laundry Dryers': 2,
#  'Lithium Mine Production': 2,
#  'Nickel Production': 2,
#  'Primary Copper': 2,
#  'Rare Earth Mine Production': 2,
#  'Refrigerators': 2,
#  'Sand and Gravel|Construction': 2,
#  'Sand and Gravel|Industrial': 2,
#  'Silver Production': 2,
#  'Tin Production': 2,
#  'Washing Machines': 2,
#  'Zinc Production': 2,
#  'Zinc-Based Battery': 3,
#  'Latent Heat Storage': 4,
#  'Nickel-Based Battery': 4,
#  'Wet Flue Gas Desulfurization Systems': 4,
#  'Artificial and Synthetic Fibers': 6,
#  'Electro-Chemical Capacitor': 6,
#  'Hydrogen Storage': 6,
#  'Compressed Air Energy Storage': 7,
#  'Nuclear Weapons': 8,
#  'Tin': 8,
#  'Nitric Acid': 9,
#  'Nickel': 10,
#  'Sensible Heat Storage': 10,
#  'Heat Thermal Battery Storage': 11,
#  'Microwave Ovens': 11,
#  'Silver': 12,
#  'Ammonia Synthesis': 13,
#  'Hydrochloric Acid': 13,
#  'Gold': 14,
#  'Caustic Soda Acid': 15,
#  'Flywheel Battery Storage': 15,
#  'Potassic Fertilizers': 16,
#  'Sodium-Based Battery Storage': 16,
#  'Zinc': 16,
#  'Lead-Acid Battery Storage': 18,
#  'Liquid Biofuels': 18,
#  'Marine Energy': 19,
#  'Offshore Wind Energy': 19,
#  'Steamships': 20,
#  'Combined Refrigerators-Freezers': 22,
#  'Refined Copper': 22,
#  'Solar Thermal Energy': 22,
#  'Vacuum Cleaners': 22,
#  'Radio Receivers': 23,
#  'Biofuels Production': 24,
#  'Household Washing and Drying Machines': 24,
#  'Synthetic Filament Tow and Staple Fibers': 24,
#  'Telephones and Videophones': 24,
#  'Television Receivers': 24,
#  'Flow Battery Storage': 25,
#  'Motorcycles and Scooters': 25,
#  'Household Refrigerators and Freezers': 26,
#  'Synthetic Filament Yarn': 27,
#  'Electric Water Heaters and Immersion Heaters': 30,
#  'Cars': 32,
#  'Caustic Soda': 32,
#  'Geothermal Energy': 32,
#  'Nitrogenous Fertilizers': 32,
#  'Synthetic Filaments': 33,
#  'Air Conditioning Machines': 35,
#  'YFV Vaccine': 36,
#  'Bicycles and Other Cycles': 37,
#  'Primary Bauxite Production': 38,
#  'Cadmium Refining': 39,
#  'Coal Production': 40,
#  'Sugar Output': 42,
#  'Pumped Hydro Storage': 44,
#  'Lithium-Ion Battery Storage': 47,
#  'Oil Production': 51,
#  'Natural Gas Production': 52,
#  'Sulphuric Acid': 52,
#  'Copper|Refining': 58,
#  'Primary Aluminum Production': 58,
#  'Beer': 60,
#  'Crude Petroleum': 60,
#  'Lead': 63,
#  'Iron Ore': 64,
#  'Cotton Seed Production': 66,
#  'Sugar Cane Production': 68,
#  'Copper|Mining': 69,
#  'Oil Refining Capacity': 75,
#  'Telegraph Traffic': 76,
#  'Electricity': 80,
#  'Postal Traffic': 80,
#  'Hydroelectricity': 81,
#  'Nuclear Energy': 81,
#  'Renewable Power': 81,
#  'Soybean Production': 85,
#  'Objects Launched Into Space': 92,
#  'Biogas': 95,
#  'Milk': 98,
#  'Beer Production': 102,
#  'Solid Biofuels': 102,
#  'HEPBB Vaccine': 105,
#  'Raw Steel Production': 106,
#  'Crop Harvester': 118,
#  'ROTAC Vaccine': 118,
#  'Salt Production': 125,
#  'Railroad': 128,
#  'Corn Production': 141,
#  "Cow's Milk Production": 149,
#  'Cellphones': 153,
#  'PCV3 Vaccine': 153,
#  'Passenger Vehicles': 153,
#  'Passenger Cars': 155,
#  'Radio': 155,
#  'Telephones': 155,
#  'Television': 155,
#  'BCG Vaccine': 168,
#  'Potash Fertilizer': 169,
#  'Nitrogen Fertilizer': 172,
#  'Phosphate Fertilizer': 172,
#  'RCV1 Vaccine': 173,
#  'MCV2 Vaccine': 183,
#  'HEPB3 Vaccine': 191,
#  'HIB3 Vaccine': 193,
#  'Solar Photovoltaic': 193,
#  'DTP1 Vaccine': 195,
#  'DTP3 Vaccine': 195,
#  'IPV1 Vaccine': 195,
#  'MCV1 Vaccine': 195,
#  'POL3 Vaccine': 195,
#  'Aquaculture Production': 196,
#  'Capture Fisheries': 216,
#  'Onshore Wind Energy': 227}

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)
# Out:
# Zinc-Based Battery
# Latent Heat Storage
# Nickel-Based Battery
# Wet Flue Gas Desulfurization Systems
# Artificial and Synthetic Fibers
# Electro-Chemical Capacitor
# Hydrogen Storage
# Compressed Air Energy Storage
# Nuclear Weapons
# Tin
# Nitric Acid
# Nickel
# Sensible Heat Storage
# Heat Thermal Battery Storage
# Microwave Ovens
# Silver
# Ammonia Synthesis
# Hydrochloric Acid
# Gold
# Caustic Soda Acid
# Flywheel Battery Storage
# Potassic Fertilizers
# Sodium-Based Battery Storage
# Zinc
# Lead-Acid Battery Storage
# Liquid Biofuels
# Marine Energy
# Offshore Wind Energy
# Steamships
# Combined Refrigerators-Freezers
# Refined Copper
# Solar Thermal Energy
# Vacuum Cleaners
# Radio Receivers
# Biofuels Production
# Household Washing and Drying Machines
# Synthetic Filament Tow and Staple Fibers
# Telephones and Videophones
# Television Receivers
# Flow Battery Storage
# Motorcycles and Scooters
# Household Refrigerators and Freezers
# Synthetic Filament Yarn
# Electric Water Heaters and Immersion Heaters
# Cars
# Caustic Soda
# Geothermal Energy
# Nitrogenous Fertilizers
# Synthetic Filaments
# Air Conditioning Machines
# YFV Vaccine
# Bicycles and Other Cycles
# Primary Bauxite Production
# Cadmium Refining
# Coal Production
# Sugar Output
# Pumped Hydro Storage
# Lithium-Ion Battery Storage
# Oil Production
# Natural Gas Production
# Sulphuric Acid
# Copper|Refining
# Primary Aluminum Production
# Beer
# Crude Petroleum
# Lead
# Iron Ore
# Cotton Seed Production
# Sugar Cane Production
# Copper|Mining
# Oil Refining Capacity
# Telegraph Traffic
# Electricity
# Postal Traffic
# Hydroelectricity
# Nuclear Energy
# Renewable Power
# Soybean Production
# Objects Launched Into Space
# Biogas
# Milk
# Beer Production
# Solid Biofuels
# HEPBB Vaccine
# Raw Steel Production
# Crop Harvester
# ROTAC Vaccine
# Salt Production
# Railroad
# Corn Production
# Cow's Milk Production
# Cellphones
# PCV3 Vaccine
# Passenger Vehicles
# Passenger Cars
# Radio
# Telephones
# Television
# BCG Vaccine
# Potash Fertilizer
# Nitrogen Fertilizer
# Phosphate Fertilizer
# RCV1 Vaccine
# MCV2 Vaccine
# HEPB3 Vaccine
# HIB3 Vaccine
# Solar Photovoltaic
# DTP1 Vaccine
# DTP3 Vaccine
# IPV1 Vaccine
# MCV1 Vaccine
# POL3 Vaccine
# Aquaculture Production
# Capture Fisheries
# Onshore Wind Energy

# %%
cost_data = all_tech[(all_tech['Metric']=='Price') | (all_tech['Metric']=='Total Installed Cost') | (all_tech['Metric']=='Levelized Cost of Energy')]
cost_list = list(set(cost_data['Technology Name']))
print(len(cost_list))
for x in cost_list:
    print(x)
# Out:
# 96
# Synthetic Filament Tow and Staple Fibers
# Nitrogenous Fertilizers
# Maleic Anhydride
# Urea
# Soybean Production
# Caprolactam
# Motor Gasoline
# Formaldehyde
# Acrylonitrile
# Lead
# Magnesium
# Low-Density Polyethylene
# Space Launches
# Sand and Gravel|Industrial
# BisphenolA
# Titanium Sponge
# Phthalic Anhydride
# Aniline
# DNA Sequencing (All Methods)
# Capillary DNA Sequencing
# Methanol
# Primary Bauxite Production
# Cyclohexane
# Silver Production
# Gold Production
# Graphite
# Cobalt
# Household Washing and Drying Machines
# Neoprene Rubber
# Phenol
# Zinc Production
# Polyester Fiber
# Tin Production
# Ethylene
# Acrylic Fiber
# Solar Photovoltaic
# Hydropower
# Polyvinylchloride
# Coal Production
# Radio Receivers
# Cow's Milk Production
# Primary Copper
# Cadmium Refining
# Natural Gas Production
# Sodium
# Benzene
# Combined Refrigerators-Freezers
# Styrene
# Potassic Fertilizers
# Primary Magnesium
# Sodium Chlorate
# Sugar Cane Production
# Rare Earth Mine Production
# Bicycles and Other Cycles
# Polystyrene
# Shotgun Sanger DNA Sequencing
# Raw Steel Production
# Caustic Soda
# Concentrating Solar Power
# Corn Production
# Ethanolamine
# Cars
# Television Receivers
# Bioenergy
# Sand and Gravel|Construction
# High-Density Polyethylene
# Iron Ore
# Salt Production
# Turbo-Jets of a Thrust Not Exceeding 25 kN
# Air Conditioning Machines
# Hydrofluoric Acid
# Crude Oil
# Telephones and Videophones
# Household Refrigerators and Freezers
# Liquefied Natural Gas (LNG)
# Microwave Ovens
# Pentaerythritol
# Nickel Production
# Geothermal Energy
# Ethylene Glycol
# Motorcycles and Scooters
# Beer
# Ethanol
# Vacuum Cleaners
# Electric Water Heaters and Immersion Heaters
# Primary Aluminum Production
# Paraxylene
# Vinyl Acetate
# Cotton Seed Production
# Refined Copper
# Lithium Mine Production
# Vinyl Chloride
# Offshore Wind Energy
# Synthetic Filament Yarn
# Cement
# Onshore Wind Energy

# %%
for tech in cost_list:
    tech_df = all_tech[all_tech['Technology Name']==tech]
    sources = list(set(tech_df['Data Source']))
    if len(sources) > 1:
        print(tech, sources)
# Out:
# Solar Photovoltaic ['IRENASTAT', 'IRENA']
# Geothermal Energy ['IRENASTAT', 'IRENA']
# Offshore Wind Energy ['IRENASTAT', 'IRENA']
# Onshore Wind Energy ['IRENASTAT', 'IRENA']

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-1972'

# %%
time_span('Ammonia Synthesis')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1905-2022'

# %%
time_span('Aquaculture Production')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-2020'

# %%
timespan_dict = {}
for tech in tech_list:
    timespan_dict[tech] = time_span(tech)
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_56189/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)

# %%
timespan_dict
# Out:
# {'Acrylic Fiber': '1960-1972',
#  'Acrylonitrile': '1959-1972',
#  'Air Conditioning Machines': '1995-2016',
#  'Air-Source Heat Pumps': '2003-2022',
#  'Amazon Prime Users': '2014-2018',
#  'Ammonia Synthesis': '1905-2022',
#  'Aniline': '1961-1972',
#  'Aquaculture Production': '1960-2020',
#  'Artificial and Synthetic Fibers': '1910-2003',
#  'Automatic Transmission': '1910-1984',
#  'BCG Vaccine': '1980-2021',
#  'Beer': '1995-2016',
#  'Beer Production': '1750-2007',
#  'Benzene': '1952-1968',
#  'Bicycles': '1861-2007',
#  'Bicycles and Other Cycles': '1995-2016',
#  'Bioenergy': '2010-2021',
#  'Biofuels Production': '1990-2021',
#  'Biogas': '2000-2021',
#  'BisphenolA': '1959-1972',
#  'Cable TV': '1968-1997',
#  'Cadmium Refining': '1900-2019',
#  'Canals': '1794-1861',
#  'Capillary DNA Sequencing': '2000-2008',
#  'Caprolactam': '1962-1972',
#  'Capture Fisheries': '1960-2020',
#  'Carbon Capture and Sequestration': '1971-2019',
#  'Cars': '1995-2016',
#  'Caustic Soda': '1995-2016',
#  'Caustic Soda Acid': '1899-2008',
#  'Cellphones': '1975-2010',
#  'Cement': '1900-2019',
#  'Central Heating': '1900-1970',
#  'Coal Power': '1908-2000',
#  'Coal Production': '1981-2021',
#  'Cobalt': '1900-2019',
#  'Colour TV': '1966-2005',
#  'Combined Refrigerators-Freezers': '1995-2016',
#  'Compact Fluorescent Light Bulbs': '1990-2003',
#  'Compressed Air Energy Storage': '1991-2020',
#  'Computing Growth': '1900-1998',
#  'Concentrated Solar Power': '1985-2022',
#  'Concentrating Solar Power': '2010-2021',
#  'Copper|Mining': '1990-2011',
#  'Copper|Refining': '1990-2011',
#  'Corn Production': '1991-2022',
#  'Cotton Seed Production': '1991-2022',
#  "Cow's Milk Production": '1991-2022',
#  'Crop Harvester': '1961-2001',
#  'Crude Oil': '1861-2021',
#  'Crude Petroleum': '1860-2008',
#  'Cyclohexane': '1956-1972',
#  'DNA Sequencing (All Methods)': '2001-2022',
#  'DTP1 Vaccine': '1980-2021',
#  'DTP3 Vaccine': '1980-2021',
#  'Desalination Capacity': '1960-2020',
#  'Dishwashers': '1922-2011',
#  'Disk Brakes': '1966-1984',
#  'Ebook Reader': '2009-2018',
#  'Electric Bicycles': '1997-2010',
#  'Electric Range': '1933-1986',
#  'Electric Water Heaters and Immersion Heaters': '1995-2016',
#  'Electricity': '1985-2021',
#  'Electro-Chemical Capacitor': '2012-2016',
#  'Electronic Ignition': '1962-1984',
#  'Ethanol': '1958-1972',
#  'Ethanolamine': '1955-1972',
#  'Ethylene': '1953-1968',
#  'Ethylene Glycol': '1960-1972',
#  'Flow Battery Storage': '2000-2018',
#  'Fluid Catalytic Cracking Refineries': '1940-2007',
#  'Flush Toilet': '1860-1989',
#  'Flywheel Battery Storage': '2006-2020',
#  'Formaldehyde': '1962-1972',
#  'Freezer': '1950-2011',
#  'Geothermal Energy': '2000-2021',
#  'Gold': '1851-2008',
#  'Gold Production': '1900-2018',
#  'Graphite': '1900-2019',
#  'Ground Source Heat Pumps': '1995-2020',
#  'HEPB3 Vaccine': '1989-2021',
#  'HEPBB Vaccine': '2000-2021',
#  'HIB3 Vaccine': '1991-2021',
#  'Heat Thermal Battery Storage': '2007-2017',
#  'Herbicide-Tolerant Corn': '1996-2022',
#  'Herbicide-Tolerant Cotton': '1996-2022',
#  'Herbicide-Tolerant Soybeans': '1996-2022',
#  'High-Density Polyethylene': '1958-1972',
#  'High-Speed Rail': '1964-2021',
#  'Home Air Conditioning': '1957-2011',
#  'Home Computers': '1992-2016',
#  'Household Internet Access': '1993-2016',
#  'Household Refrigerators and Freezers': '1995-2016',
#  'Household Washing and Drying Machines': '1995-2016',
#  'Households With Only Mobile Phones (No Landlines)': '2013-2018',
#  'Hydrochloric Acid': '1929-2003',
#  'Hydroelectricity': '1965-2021',
#  'Hydrofluoric Acid': '1962-1972',
#  'Hydrogen Storage': '2012-2017',
#  'Hydropower': '2010-2021',
#  'IPV1 Vaccine': '2015-2021',
#  'Insect-Resistant Corn': '1996-2022',
#  'Insect-Resistant Cotton': '1996-2022',
#  'Internet Backbone Bandwidth': '1968-2004',
#  'Internet Traffic': '1984-2014',
#  'Iron': '1933-1970',
#  'Iron Ore': '1900-2019',
#  'Jet Aircraft': '1958-2007',
#  'Latent Heat Storage': '1991-2017',
#  'Laundry Dryers': '1920-2006',
#  'Lead': '1900-2018',
#  'Lead-Acid Battery Storage': '1987-2020',
#  'Liquefied Natural Gas': '1985-2021',
#  'Liquefied Natural Gas (LNG)': '1984-2021',
#  'Liquid Biofuels': '2001-2021',
#  'Lithium Mine Production': '1900-2019',
#  'Lithium-Ion Battery Storage': '2008-2021',
#  'Low-Density Polyethylene': '1958-1972',
#  'MCV1 Vaccine': '1980-2021',
#  'MCV2 Vaccine': '2000-2021',
#  'Magnesium': '1954-1972',
#  'Magnetic Data Storage': '1952-2004',
#  'Maleic Anhydride': '1959-1972',
#  'Marine Energy': '2000-2021',
#  'Methanol': '1957-1972',
#  'Microcomputers': '1984-2016',
#  'Microprocessor Clock Speed': '1976-2016',
#  'Microwave Ovens': '1995-2016',
#  'Microwaves': '1975-2017',
#  'Milk': '1889-2010',
#  'Motor Gasoline': '1946-1968',
#  'Motorcycles': '1900-2008',
#  'Motorcycles and Scooters': '1996-2016',
#  'Natural Gas Pipeline': '1960-2021',
#  'Natural Gas Power': '1903-2000',
#  'Natural Gas Production': '1970-2021',
#  'Neoprene Rubber': '1960-1972',
#  'Nickel': '1889-2008',
#  'Nickel Production': '1900-2018',
#  'Nickel-Based Battery': '2003-2015',
#  'Nitric Acid': '1929-2003',
#  'Nitrogen Fertilizer': '1961-2020',
#  'Nitrogenous Fertilizers': '1995-2016',
#  'Nox Pollution Controls (Boilers)': '1990-2005',
#  'Nuclear Energy': '1965-2021',
#  'Nuclear Weapons': '1945-2010',
#  'Objects Launched Into Space': '1957-2022',
#  'Offshore Wind Energy': '2000-2021',
#  'Oil Pipeline': '2001-2021',
#  'Oil Production': '1965-2021',
#  'Oil Refining Capacity': '1965-2021',
#  'Onshore Wind Energy': '1983-2022',
#  'PCV3 Vaccine': '2008-2021',
#  'POL3 Vaccine': '1980-2021',
#  'Paraxylene': '1957-1968',
#  'Passenger Cars': '1895-2005',
#  'Passenger Vehicles': '1895-2003',
#  'Pentaerythritol': '1952-1972',
#  'Phenol': '1959-1972',
#  'Phosphate Fertilizer': '1961-2020',
#  'Phthalic Anhydride': '1955-1972',
#  'Podcasting': '2006-2015',
#  'Polyester Fiber': '1960-1972',
#  'Polystyrene': '1943-1968',
#  'Polyvinylchloride': '1946-1968',
#  'Postal Traffic': '1830-2000',
#  'Potash Fertilizer': '1961-2020',
#  'Potassic Fertilizers': '1999-2016',
#  'Power Steering': '1951-1984',
#  'Primary Aluminum Production': '1900-2019',
#  'Primary Bauxite Production': '1900-2019',
#  'Primary Copper': '1900-2018',
#  'Primary Magnesium': '1929-1968',
#  'Processor Performance': '1971-2002',
#  'Public Roads': '1900-2020',
#  'Pumped Hydro Storage': '1944-2020',
#  'RCV1 Vaccine': '1980-2021',
#  'ROTAC Vaccine': '2006-2021',
#  'Radial Tires': '1972-1984',
#  'Radio': '1815-2000',
#  'Radio Receivers': '1995-2016',
#  'Railroad': '1825-2004',
#  'Random Access Memory': '1949-2004',
#  'Rare Earth Mine Production': '1900-2019',
#  'Raw Steel Production': '1900-2019',
#  'Real-Time Gross Settlement Adoption': '1970-2005',
#  'Refined Copper': '1995-2016',
#  'Refrigerators': '1918-2009',
#  'Renewable Power': '1965-2021',
#  'Running Water': '1890-1989',
#  'Salt Production': '1900-2017',
#  'Sand and Gravel|Construction': '1902-2019',
#  'Sand and Gravel|Industrial': '1902-2019',
#  'Sensible Heat Storage': '1982-2018',
#  'Shale Production': '2007-2019',
#  'Shotgun Sanger DNA Sequencing': '2001-2009',
#  'Silver': '1874-2008',
#  'Silver Production': '1900-2018',
#  'Smartphone Usage': '2011-2019',
#  'Social Media Usage': '2005-2019',
#  'Sodium': '1957-1972',
#  'Sodium Chlorate': '1958-1972',
#  'Sodium-Based Battery Storage': '1999-2019',
#  'Solar Photovoltaic': '2000-2021',
#  'Solar Thermal Energy': '2000-2021',
#  'Solid Biofuels': '2000-2021',
#  'Soybean Production': '1991-2022',
#  'Space Launches': '1957-2018',
#  'Stationary Steam Engines': '1720-1920',
#  'Steam Locomotives': '1830-1920',
#  'Steamships': '1814-1998',
#  'Stove': '1900-2011',
#  'Styrene': '1958-1972',
#  'Submarine Cables': '1989-2021',
#  'Sugar Cane Production': '1991-2022',
#  'Sugar Output': '1750-2010',
#  'Sulphuric Acid': '1860-2003',
#  'Synthetic Filament Tow and Staple Fibers': '1995-2016',
#  'Synthetic Filament Yarn': '1995-2016',
#  'Synthetic Filaments': '1910-1999',
#  'Tablet': '2010-2017',
#  'Telegraph Traffic': '1830-2000',
#  'Telephones': '1876-2003',
#  'Telephones and Videophones': '1995-2016',
#  'Television': '1946-2002',
#  'Television Receivers': '1997-2016',
#  'Tin': '1910-2003',
#  'Tin Production': '1900-2019',
#  'Titanium Sponge': '1950-1968',
#  'Transistors per Microprocessor': '1971-2003',
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': '1995-1999',
#  'Urea': '1961-1972',
#  'Vacuum Cleaners': '1995-2016',
#  'Vacuums': '1922-1978',
#  'Videocassette Recorder': '1992-2011',
#  'Vinyl Acetate': '1960-1972',
#  'Vinyl Chloride': '1962-1972',
#  'Washing Machines': '1920-2008',
#  'Water Heater': '1933-1986',
#  'Wet Flue Gas Desulfurization Systems': '1972-1999',
#  'YFV Vaccine': '1997-2021',
#  'Zinc': '1860-2008',
#  'Zinc Production': '1900-2019',
#  'Zinc-Based Battery': '2013-2020'}

# %%
timespan_dict_lower = {}
for item in timespan_dict:
    timespan_dict_lower[item.lower()] = timespan_dict[item]
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air conditioning machines': '1995-2016',
#  'air-source heat pumps': '2003-2022',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2022',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'artificial and synthetic fibers': '1910-2003',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer': '1995-2016',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'bicycles and other cycles': '1995-2016',
#  'bioenergy': '2010-2021',
#  'biofuels production': '1990-2021',
#  'biogas': '2000-2021',
#  'bisphenola': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1900-2019',
#  'canals': '1794-1861',
#  'capillary dna sequencing': '2000-2008',
#  'caprolactam': '1962-1972',
#  'capture fisheries': '1960-2020',
#  'carbon capture and sequestration': '1971-2019',
#  'cars': '1995-2016',
#  'caustic soda': '1995-2016',
#  'caustic soda acid': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt': '1900-2019',
#  'colour tv': '1966-2005',
#  'combined refrigerators-freezers': '1995-2016',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'concentrating solar power': '2010-2021',
#  'copper|mining': '1990-2011',
#  'copper|refining': '1990-2011',
#  'corn production': '1991-2022',
#  'cotton seed production': '1991-2022',
#  "cow's milk production": '1991-2022',
#  'crop harvester': '1961-2001',
#  'crude oil': '1861-2021',
#  'crude petroleum': '1860-2008',
#  'cyclohexane': '1956-1972',
#  'dna sequencing (all methods)': '2001-2022',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electric water heaters and immersion heaters': '1995-2016',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanol': '1958-1972',
#  'ethanolamine': '1955-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold': '1851-2008',
#  'gold production': '1900-2018',
#  'graphite': '1900-2019',
#  'ground source heat pumps': '1995-2020',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'hib3 vaccine': '1991-2021',
#  'heat thermal battery storage': '2007-2017',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'household refrigerators and freezers': '1995-2016',
#  'household washing and drying machines': '1995-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'hydropower': '2010-2021',
#  'ipv1 vaccine': '2015-2021',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'iron': '1933-1970',
#  'iron ore': '1900-2019',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead': '1900-2018',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1985-2021',
#  'liquefied natural gas (lng)': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1900-2019',
#  'lithium-ion battery storage': '2008-2021',
#  'low-density polyethylene': '1958-1972',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwave ovens': '1995-2016',
#  'microwaves': '1975-2017',
#  'milk': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'motorcycles and scooters': '1996-2016',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel': '1889-2008',
#  'nickel production': '1900-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nitrogenous fertilizers': '1995-2016',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'objects launched into space': '1957-2022',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'pcv3 vaccine': '2008-2021',
#  'pol3 vaccine': '1980-2021',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2005',
#  'passenger vehicles': '1895-2003',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'potassic fertilizers': '1999-2016',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1900-2019',
#  'primary bauxite production': '1900-2019',
#  'primary copper': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'rcv1 vaccine': '1980-2021',
#  'rotac vaccine': '2006-2021',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'radio receivers': '1995-2016',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1900-2019',
#  'raw steel production': '1900-2019',
#  'real-time gross settlement adoption': '1970-2005',
#  'refined copper': '1995-2016',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'running water': '1890-1989',
#  'salt production': '1900-2017',
#  'sand and gravel|construction': '1902-2019',
#  'sand and gravel|industrial': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'silver production': '1900-2018',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'soybean production': '1991-2022',
#  'space launches': '1957-2018',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steamships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sugar cane production': '1991-2022',
#  'sugar output': '1750-2010',
#  'sulphuric acid': '1860-2003',
#  'synthetic filament tow and staple fibers': '1995-2016',
#  'synthetic filament yarn': '1995-2016',
#  'synthetic filaments': '1910-1999',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'telephones and videophones': '1995-2016',
#  'television': '1946-2002',
#  'television receivers': '1997-2016',
#  'tin': '1910-2003',
#  'tin production': '1900-2019',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'turbo-jets of a thrust not exceeding 25 kn': '1995-1999',
#  'urea': '1961-1972',
#  'vacuum cleaners': '1995-2016',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc production': '1900-2019',
#  'zinc-based battery': '2013-2020'}

# %%
timespan_dict_lower = dict(sorted(timespan_dict_lower.items(), key=lambda item: item[0])) 
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air conditioning machines': '1995-2016',
#  'air-source heat pumps': '2003-2022',
#  'amazon prime users': '2014-2018',
#  'ammonia synthesis': '1905-2022',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'artificial and synthetic fibers': '1910-2003',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer': '1995-2016',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'bicycles and other cycles': '1995-2016',
#  'bioenergy': '2010-2021',
#  'biofuels production': '1990-2021',
#  'biogas': '2000-2021',
#  'bisphenola': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1900-2019',
#  'canals': '1794-1861',
#  'capillary dna sequencing': '2000-2008',
#  'caprolactam': '1962-1972',
#  'capture fisheries': '1960-2020',
#  'carbon capture and sequestration': '1971-2019',
#  'cars': '1995-2016',
#  'caustic soda': '1995-2016',
#  'caustic soda acid': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt': '1900-2019',
#  'colour tv': '1966-2005',
#  'combined refrigerators-freezers': '1995-2016',
#  'compact fluorescent light bulbs': '1990-2003',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'concentrating solar power': '2010-2021',
#  'copper|mining': '1990-2011',
#  'copper|refining': '1990-2011',
#  'corn production': '1991-2022',
#  'cotton seed production': '1991-2022',
#  "cow's milk production": '1991-2022',
#  'crop harvester': '1961-2001',
#  'crude oil': '1861-2021',
#  'crude petroleum': '1860-2008',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dna sequencing (all methods)': '2001-2022',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electric water heaters and immersion heaters': '1995-2016',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanol': '1958-1972',
#  'ethanolamine': '1955-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'flow battery storage': '2000-2018',
#  'fluid catalytic cracking refineries': '1940-2007',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold': '1851-2008',
#  'gold production': '1900-2018',
#  'graphite': '1900-2019',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-density polyethylene': '1958-1972',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'household refrigerators and freezers': '1995-2016',
#  'household washing and drying machines': '1995-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'hydropower': '2010-2021',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1900-2019',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead': '1900-2018',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1985-2021',
#  'liquefied natural gas (lng)': '1984-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1900-2019',
#  'lithium-ion battery storage': '2008-2021',
#  'low-density polyethylene': '1958-1972',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwave ovens': '1995-2016',
#  'microwaves': '1975-2017',
#  'milk': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'motorcycles and scooters': '1996-2016',
#  'natural gas pipeline': '1960-2021',
#  'natural gas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel': '1889-2008',
#  'nickel production': '1900-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nitrogenous fertilizers': '1995-2016',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'objects launched into space': '1957-2022',
#  'offshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'onshore wind energy': '1983-2022',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2005',
#  'passenger vehicles': '1895-2003',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'potassic fertilizers': '1999-2016',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1900-2019',
#  'primary bauxite production': '1900-2019',
#  'primary copper': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'radial tires': '1972-1984',
#  'radio': '1815-2000',
#  'radio receivers': '1995-2016',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1900-2019',
#  'raw steel production': '1900-2019',
#  'rcv1 vaccine': '1980-2021',
#  'real-time gross settlement adoption': '1970-2005',
#  'refined copper': '1995-2016',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'running water': '1890-1989',
#  'salt production': '1900-2017',
#  'sand and gravel|construction': '1902-2019',
#  'sand and gravel|industrial': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'silver production': '1900-2018',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'soybean production': '1991-2022',
#  'space launches': '1957-2018',
#  'stationary steam engines': '1720-1920',
#  'steam locomotives': '1830-1920',
#  'steamships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sugar cane production': '1991-2022',
#  'sugar output': '1750-2010',
#  'sulphuric acid': '1860-2003',
#  'synthetic filament tow and staple fibers': '1995-2016',
#  'synthetic filament yarn': '1995-2016',
#  'synthetic filaments': '1910-1999',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'telephones and videophones': '1995-2016',
#  'television': '1946-2002',
#  'television receivers': '1997-2016',
#  'tin': '1910-2003',
#  'tin production': '1900-2019',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'turbo-jets of a thrust not exceeding 25 kn': '1995-1999',
#  'urea': '1961-1972',
#  'vacuum cleaners': '1995-2016',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc production': '1900-2019',
#  'zinc-based battery': '2013-2020'}

# %%
for item in timespan_dict_lower:
    print(timespan_dict_lower[item])
# Out:
# 1960-1972
# 1959-1972
# 1995-2016
# 2003-2022
# 2014-2018
# 1905-2022
# 1961-1972
# 1960-2020
# 1910-2003
# 1910-1984
# 1980-2021
# 1995-2016
# 1750-2007
# 1952-1968
# 1861-2007
# 1995-2016
# 2010-2021
# 1990-2021
# 2000-2021
# 1959-1972
# 1968-1997
# 1900-2019
# 1794-1861
# 2000-2008
# 1962-1972
# 1960-2020
# 1971-2019
# 1995-2016
# 1995-2016
# 1899-2008
# 1975-2010
# 1900-2019
# 1900-1970
# 1908-2000
# 1981-2021
# 1900-2019
# 1966-2005
# 1995-2016
# 1990-2003
# 1991-2020
# 1900-1998
# 1985-2022
# 2010-2021
# 1990-2011
# 1990-2011
# 1991-2022
# 1991-2022
# 1991-2022
# 1961-2001
# 1861-2021
# 1860-2008
# 1956-1972
# 1960-2020
# 1922-2011
# 1966-1984
# 2001-2022
# 1980-2021
# 1980-2021
# 2009-2018
# 1997-2010
# 1933-1986
# 1995-2016
# 1985-2021
# 2012-2016
# 1962-1984
# 1958-1972
# 1955-1972
# 1953-1968
# 1960-1972
# 2000-2018
# 1940-2007
# 1860-1989
# 2006-2020
# 1962-1972
# 1950-2011
# 2000-2021
# 1851-2008
# 1900-2018
# 1900-2019
# 1995-2020
# 2007-2017
# 1989-2021
# 2000-2021
# 1996-2022
# 1996-2022
# 1996-2022
# 1991-2021
# 1958-1972
# 1964-2021
# 1957-2011
# 1992-2016
# 1993-2016
# 1995-2016
# 1995-2016
# 2013-2018
# 1929-2003
# 1965-2021
# 1962-1972
# 2012-2017
# 2010-2021
# 1996-2022
# 1996-2022
# 1968-2004
# 1984-2014
# 2015-2021
# 1933-1970
# 1900-2019
# 1958-2007
# 1991-2017
# 1920-2006
# 1900-2018
# 1987-2020
# 1985-2021
# 1984-2021
# 2001-2021
# 1900-2019
# 2008-2021
# 1958-1972
# 1954-1972
# 1952-2004
# 1959-1972
# 2000-2021
# 1980-2021
# 2000-2021
# 1957-1972
# 1984-2016
# 1976-2016
# 1995-2016
# 1975-2017
# 1889-2010
# 1946-1968
# 1900-2008
# 1996-2016
# 1960-2021
# 1903-2000
# 1970-2021
# 1960-1972
# 1889-2008
# 1900-2018
# 2003-2015
# 1929-2003
# 1961-2020
# 1995-2016
# 1990-2005
# 1965-2021
# 1945-2010
# 1957-2022
# 2000-2021
# 2001-2021
# 1965-2021
# 1965-2021
# 1983-2022
# 1957-1968
# 1895-2005
# 1895-2003
# 2008-2021
# 1952-1972
# 1959-1972
# 1961-2020
# 1955-1972
# 2006-2015
# 1980-2021
# 1960-1972
# 1943-1968
# 1946-1968
# 1830-2000
# 1961-2020
# 1999-2016
# 1951-1984
# 1900-2019
# 1900-2019
# 1900-2018
# 1929-1968
# 1971-2002
# 1900-2020
# 1944-2020
# 1972-1984
# 1815-2000
# 1995-2016
# 1825-2004
# 1949-2004
# 1900-2019
# 1900-2019
# 1980-2021
# 1970-2005
# 1995-2016
# 1918-2009
# 1965-2021
# 2006-2021
# 1890-1989
# 1900-2017
# 1902-2019
# 1902-2019
# 1982-2018
# 2007-2019
# 2001-2009
# 1874-2008
# 1900-2018
# 2011-2019
# 2005-2019
# 1957-1972
# 1958-1972
# 1999-2019
# 2000-2021
# 2000-2021
# 2000-2021
# 1991-2022
# 1957-2018
# 1720-1920
# 1830-1920
# 1814-1998
# 1900-2011
# 1958-1972
# 1989-2021
# 1991-2022
# 1750-2010
# 1860-2003
# 1995-2016
# 1995-2016
# 1910-1999
# 2010-2017
# 1830-2000
# 1876-2003
# 1995-2016
# 1946-2002
# 1997-2016
# 1910-2003
# 1900-2019
# 1950-1968
# 1971-2003
# 1995-1999
# 1961-1972
# 1995-2016
# 1922-1978
# 1992-2011
# 1960-1972
# 1962-1972
# 1920-2008
# 1933-1986
# 1972-1999
# 1997-2021
# 1860-2008
# 1900-2019
# 2013-2020

# %%
def metric(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    metric = set(tech_df['Metric'])
    return metric

# %%
metric_dict = {}
for tech in tech_list:
    metric_dict[tech] = metric(tech)
metric_dict
# Out:
# {'Acrylic Fiber': {'Annual production', 'Price'},
#  'Acrylonitrile': {'Annual production', 'Price'},
#  'Air Conditioning Machines': {'Price'},
#  'Air-Source Heat Pumps': {'Annual Production'},
#  'Amazon Prime Users': {'Share of Households'},
#  'Ammonia Synthesis': {'Annual Production'},
#  'Aniline': {'Annual production', 'Price'},
#  'Aquaculture Production': {'Annual production'},
#  'Artificial and Synthetic Fibers': {'Annual Production'},
#  'Automatic Transmission': {'Share of Market'},
#  'BCG Vaccine': {'Share of Population'},
#  'Beer': {'Price'},
#  'Beer Production': {'Annual Production'},
#  'Benzene': {'Annual production', 'Price'},
#  'Bicycles': {'Cumulative Total Capacity'},
#  'Bicycles and Other Cycles': {'Price'},
#  'Bioenergy': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'Biofuels Production': {'Annual Production'},
#  'Biogas': {'Installed electricity capacity'},
#  'BisphenolA': {'Annual production', 'Price'},
#  'Cable TV': {'Share of Households'},
#  'Cadmium Refining': {'Annual production', 'Price'},
#  'Canals': {'Total Length'},
#  'Capillary DNA Sequencing': {'Annual production', 'Price'},
#  'Caprolactam': {'Annual production', 'Price'},
#  'Capture Fisheries': {'Annual production'},
#  'Carbon Capture and Sequestration': {'Installed Capacity'},
#  'Cars': {'Price'},
#  'Caustic Soda': {'Price'},
#  'Caustic Soda Acid': {'Annual Production'},
#  'Cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'Cement': {'Annual production', 'Price'},
#  'Central Heating': {'Share of Households'},
#  'Coal Power': {'Cumulative Total Capacity'},
#  'Coal Production': {'Annual Production', 'Price'},
#  'Cobalt': {'Annual production', 'Price'},
#  'Colour TV': {'Share of Households'},
#  'Combined Refrigerators-Freezers': {'Price'},
#  'Compact Fluorescent Light Bulbs': {'Cumulative Total Capacity'},
#  'Compressed Air Energy Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Computing Growth': {'Computing Capacity'},
#  'Concentrated Solar Power': {'Installed Capacity'},
#  'Concentrating Solar Power': {'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Copper|Mining': {'Annual production'},
#  'Copper|Refining': {'Annual production'},
#  'Corn Production': {'Price'},
#  'Cotton Seed Production': {'Price'},
#  "Cow's Milk Production": {'Price'},
#  'Crop Harvester': {'Total Number'},
#  'Crude Oil': {'Price'},
#  'Crude Petroleum': {'Annual Production'},
#  'Cyclohexane': {'Annual production', 'Price'},
#  'DNA Sequencing (All Methods)': {'Price'},
#  'DTP1 Vaccine': {'Share of Population'},
#  'DTP3 Vaccine': {'Share of Population'},
#  'Desalination Capacity': {'Total Capacity'},
#  'Dishwashers': {'Share of Households'},
#  'Disk Brakes': {'Share of Market'},
#  'Ebook Reader': {'Share of Population'},
#  'Electric Bicycles': {'Cumulative Total Capacity'},
#  'Electric Range': {'Share of Households'},
#  'Electric Water Heaters and Immersion Heaters': {'Price'},
#  'Electricity': {'Annual Production'},
#  'Electro-Chemical Capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Electronic Ignition': {'Share of Market'},
#  'Ethanol': {'Annual production', 'Price'},
#  'Ethanolamine': {'Annual production', 'Price'},
#  'Ethylene': {'Annual production', 'Price'},
#  'Ethylene Glycol': {'Annual production', 'Price'},
#  'Flow Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Fluid Catalytic Cracking Refineries': {'Average Capacity of Unit Additions',
#   'Net Total Capacity'},
#  'Flush Toilet': {'Share of Households'},
#  'Flywheel Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Formaldehyde': {'Annual production', 'Price'},
#  'Freezer': {'Share of Households'},
#  'Geothermal Energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Gold': {'Annual Production'},
#  'Gold Production': {'Annual production', 'Price'},
#  'Graphite': {'Annual production', 'Price'},
#  'Ground Source Heat Pumps': {'Cumulative Total Capacity'},
#  'HEPB3 Vaccine': {'Share of Population'},
#  'HEPBB Vaccine': {'Share of Population'},
#  'HIB3 Vaccine': {'Share of Population'},
#  'Heat Thermal Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Herbicide-Tolerant Corn': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Cotton': {'Cumulative Acreage'},
#  'Herbicide-Tolerant Soybeans': {'Cumulative Acreage'},
#  'High-Density Polyethylene': {'Annual production', 'Price'},
#  'High-Speed Rail': {'Cumulative Total Capacity'},
#  'Home Air Conditioning': {'Share of Households'},
#  'Home Computers': {'Share of Households'},
#  'Household Internet Access': {'Share of Households'},
#  'Household Refrigerators and Freezers': {'Price'},
#  'Household Washing and Drying Machines': {'Price'},
#  'Households With Only Mobile Phones (No Landlines)': {'Share of Households'},
#  'Hydrochloric Acid': {'Annual Production'},
#  'Hydroelectricity': {'Annual Production'},
#  'Hydrofluoric Acid': {'Annual production', 'Price'},
#  'Hydrogen Storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'Hydropower': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'IPV1 Vaccine': {'Share of Population'},
#  'Insect-Resistant Corn': {'Cumulative Acreage'},
#  'Insect-Resistant Cotton': {'Cumulative Acreage'},
#  'Internet Backbone Bandwidth': {'Computing Capacity'},
#  'Internet Traffic': {'Computing Capacity'},
#  'Iron': {'Share of Households'},
#  'Iron Ore': {'Annual production', 'Price'},
#  'Jet Aircraft': {'Cumulative Total Capacity'},
#  'Latent Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Laundry Dryers': {'Cumulative Total Capacity'},
#  'Lead': {'Annual production', 'Price'},
#  'Lead-Acid Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Liquefied Natural Gas': {'Annual Production'},
#  'Liquefied Natural Gas (LNG)': {'Price'},
#  'Liquid Biofuels': {'Installed electricity capacity'},
#  'Lithium Mine Production': {'Annual production', 'Price'},
#  'Lithium-Ion Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Low-Density Polyethylene': {'Annual production', 'Price'},
#  'MCV1 Vaccine': {'Share of Population'},
#  'MCV2 Vaccine': {'Share of Population'},
#  'Magnesium': {'Annual production', 'Price'},
#  'Magnetic Data Storage': {'Computing Capacity'},
#  'Maleic Anhydride': {'Annual production', 'Price'},
#  'Marine Energy': {'Installed electricity capacity'},
#  'Methanol': {'Annual production', 'Price'},
#  'Microcomputers': {'Share of Households'},
#  'Microprocessor Clock Speed': {'Computing Capacity'},
#  'Microwave Ovens': {'Price'},
#  'Microwaves': {'Share of Households'},
#  'Milk': {'Annual Production'},
#  'Motor Gasoline': {'Annual production', 'Price'},
#  'Motorcycles': {'Cumulative Total Capacity'},
#  'Motorcycles and Scooters': {'Price'},
#  'Natural Gas Pipeline': {'Total Length'},
#  'Natural Gas Power': {'Cumulative Total Capacity'},
#  'Natural Gas Production': {'Annual Production', 'Price'},
#  'Neoprene Rubber': {'Annual production', 'Price'},
#  'Nickel': {'Annual Production'},
#  'Nickel Production': {'Annual production', 'Price'},
#  'Nickel-Based Battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Nitric Acid': {'Annual Production'},
#  'Nitrogen Fertilizer': {'Annual Production'},
#  'Nitrogenous Fertilizers': {'Price'},
#  'Nox Pollution Controls (Boilers)': {'Share of Boilers'},
#  'Nuclear Energy': {'Annual Production'},
#  'Nuclear Weapons': {'Total Number'},
#  'Objects Launched Into Space': {'Total Number'},
#  'Offshore Wind Energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Oil Pipeline': {'Total Length'},
#  'Oil Production': {'Annual Production'},
#  'Oil Refining Capacity': {'Total Capacity'},
#  'Onshore Wind Energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'PCV3 Vaccine': {'Share of Population'},
#  'POL3 Vaccine': {'Share of Population'},
#  'Paraxylene': {'Annual production', 'Price'},
#  'Passenger Cars': {'Cumulative Total Capacity', 'Total Number'},
#  'Passenger Vehicles': {'Total Number'},
#  'Pentaerythritol': {'Annual production', 'Price'},
#  'Phenol': {'Annual production', 'Price'},
#  'Phosphate Fertilizer': {'Annual Production'},
#  'Phthalic Anhydride': {'Annual production', 'Price'},
#  'Podcasting': {'Share of Population'},
#  'Polyester Fiber': {'Annual production', 'Price'},
#  'Polystyrene': {'Annual production', 'Price'},
#  'Polyvinylchloride': {'Annual production', 'Price'},
#  'Postal Traffic': {'Total Number'},
#  'Potash Fertilizer': {'Annual Production'},
#  'Potassic Fertilizers': {'Price'},
#  'Power Steering': {'Share of Market'},
#  'Primary Aluminum Production': {'Annual production', 'Price'},
#  'Primary Bauxite Production': {'Annual production', 'Price'},
#  'Primary Copper': {'Annual production', 'Price'},
#  'Primary Magnesium': {'Annual production', 'Price'},
#  'Processor Performance': {'Computing Capacity'},
#  'Public Roads': {'Total Length'},
#  'Pumped Hydro Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'RCV1 Vaccine': {'Share of Population'},
#  'ROTAC Vaccine': {'Share of Population'},
#  'Radial Tires': {'Share of Market'},
#  'Radio': {'Total Number'},
#  'Radio Receivers': {'Price'},
#  'Railroad': {'Total Length'},
#  'Random Access Memory': {'Computing Capacity'},
#  'Rare Earth Mine Production': {'Annual production', 'Price'},
#  'Raw Steel Production': {'Annual production', 'Price'},
#  'Real-Time Gross Settlement Adoption': {'Share of Market'},
#  'Refined Copper': {'Price'},
#  'Refrigerators': {'Cumulative Total Capacity'},
#  'Renewable Power': {'Annual Production'},
#  'Running Water': {'Share of Households'},
#  'Salt Production': {'Annual production', 'Price'},
#  'Sand and Gravel|Construction': {'Annual production', 'Price'},
#  'Sand and Gravel|Industrial': {'Annual production', 'Price'},
#  'Sensible Heat Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Shale Production': {'Annual production'},
#  'Shotgun Sanger DNA Sequencing': {'Price', 'Total Number'},
#  'Silver': {'Annual Production'},
#  'Silver Production': {'Annual production', 'Price'},
#  'Smartphone Usage': {'Share of Population'},
#  'Social Media Usage': {'Share of Population'},
#  'Sodium': {'Annual production', 'Price'},
#  'Sodium Chlorate': {'Annual production', 'Price'},
#  'Sodium-Based Battery Storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'Solar Photovoltaic': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'Solar Thermal Energy': {'Installed electricity capacity'},
#  'Solid Biofuels': {'Installed electricity capacity'},
#  'Soybean Production': {'Price'},
#  'Space Launches': {'Price'},
#  'Stationary Steam Engines': {'Cumulative Total Capacity'},
#  'Steam Locomotives': {'Cumulative Total Capacity'},
#  'Steamships': {'Total Number'},
#  'Stove': {'Share of Households'},
#  'Styrene': {'Annual production', 'Price'},
#  'Submarine Cables': {'Cumulative Length'},
#  'Sugar Cane Production': {'Price'},
#  'Sugar Output': {'Annual Production'},
#  'Sulphuric Acid': {'Annual Production'},
#  'Synthetic Filament Tow and Staple Fibers': {'Price'},
#  'Synthetic Filament Yarn': {'Price'},
#  'Synthetic Filaments': {'Annual Production'},
#  'Tablet': {'Share of Population'},
#  'Telegraph Traffic': {'Total Number'},
#  'Telephones': {'Total Number'},
#  'Telephones and Videophones': {'Price'},
#  'Television': {'Total Number'},
#  'Television Receivers': {'Price'},
#  'Tin': {'Annual Production'},
#  'Tin Production': {'Annual production', 'Price'},
#  'Titanium Sponge': {'Annual production', 'Price'},
#  'Transistors per Microprocessor': {'Computing Capacity'},
#  'Turbo-Jets of a Thrust Not Exceeding 25 kN': {'Price'},
#  'Urea': {'Annual production', 'Price'},
#  'Vacuum Cleaners': {'Price'},
#  'Vacuums': {'Share of Households'},
#  'Videocassette Recorder': {'Share of Households'},
#  'Vinyl Acetate': {'Annual production', 'Price'},
#  'Vinyl Chloride': {'Annual production', 'Price'},
#  'Washing Machines': {'Cumulative Total Capacity'},
#  'Water Heater': {'Share of Households'},
#  'Wet Flue Gas Desulfurization Systems': {'Cumulative Total Capacity'},
#  'YFV Vaccine': {'Share of Population'},
#  'Zinc': {'Annual Production'},
#  'Zinc Production': {'Annual production', 'Price'},
#  'Zinc-Based Battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = {}
for item in metric_dict:
    metric_dict_lower[item.lower()] = metric_dict[item]
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual production', 'Price'},
#  'acrylonitrile': {'Annual production', 'Price'},
#  'air conditioning machines': {'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'amazon prime users': {'Share of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual production', 'Price'},
#  'aquaculture production': {'Annual production'},
#  'artificial and synthetic fibers': {'Annual Production'},
#  'automatic transmission': {'Share of Market'},
#  'bcg vaccine': {'Share of Population'},
#  'beer': {'Price'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'bicycles and other cycles': {'Price'},
#  'bioenergy': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'biofuels production': {'Annual Production'},
#  'biogas': {'Installed electricity capacity'},
#  'bisphenola': {'Annual production', 'Price'},
#  'cable tv': {'Share of Households'},
#  'cadmium refining': {'Annual production', 'Price'},
#  'canals': {'Total Length'},
#  'capillary dna sequencing': {'Annual production', 'Price'},
#  'caprolactam': {'Annual production', 'Price'},
#  'capture fisheries': {'Annual production'},
#  'carbon capture and sequestration': {'Installed Capacity'},
#  'cars': {'Price'},
#  'caustic soda': {'Price'},
#  'caustic soda acid': {'Annual Production'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement': {'Annual production', 'Price'},
#  'central heating': {'Share of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt': {'Annual production', 'Price'},
#  'colour tv': {'Share of Households'},
#  'combined refrigerators-freezers': {'Price'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity'},
#  'concentrating solar power': {'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'copper|mining': {'Annual production'},
#  'copper|refining': {'Annual production'},
#  'corn production': {'Price'},
#  'cotton seed production': {'Price'},
#  "cow's milk production": {'Price'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Price'},
#  'crude petroleum': {'Annual Production'},
#  'cyclohexane': {'Annual production', 'Price'},
#  'dna sequencing (all methods)': {'Price'},
#  'dtp1 vaccine': {'Share of Population'},
#  'dtp3 vaccine': {'Share of Population'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share of Households'},
#  'disk brakes': {'Share of Market'},
#  'ebook reader': {'Share of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share of Households'},
#  'electric water heaters and immersion heaters': {'Price'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share of Market'},
#  'ethanol': {'Annual production', 'Price'},
#  'ethanolamine': {'Annual production', 'Price'},
#  'ethylene': {'Annual production', 'Price'},
#  'ethylene glycol': {'Annual production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'fluid catalytic cracking refineries': {'Average Capacity of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual production', 'Price'},
#  'freezer': {'Share of Households'},
#  'geothermal energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'gold': {'Annual Production'},
#  'gold production': {'Annual production', 'Price'},
#  'graphite': {'Annual production', 'Price'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'hepb3 vaccine': {'Share of Population'},
#  'hepbb vaccine': {'Share of Population'},
#  'hib3 vaccine': {'Share of Population'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'high-density polyethylene': {'Annual production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share of Households'},
#  'home computers': {'Share of Households'},
#  'household internet access': {'Share of Households'},
#  'household refrigerators and freezers': {'Price'},
#  'household washing and drying machines': {'Price'},
#  'households with only mobile phones (no landlines)': {'Share of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production'},
#  'hydrofluoric acid': {'Annual production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'hydropower': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'ipv1 vaccine': {'Share of Population'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'iron': {'Share of Households'},
#  'iron ore': {'Annual production', 'Price'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead': {'Annual production', 'Price'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production'},
#  'liquefied natural gas (lng)': {'Price'},
#  'liquid biofuels': {'Installed electricity capacity'},
#  'lithium mine production': {'Annual production', 'Price'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'low-density polyethylene': {'Annual production', 'Price'},
#  'mcv1 vaccine': {'Share of Population'},
#  'mcv2 vaccine': {'Share of Population'},
#  'magnesium': {'Annual production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual production', 'Price'},
#  'marine energy': {'Installed electricity capacity'},
#  'methanol': {'Annual production', 'Price'},
#  'microcomputers': {'Share of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwave ovens': {'Price'},
#  'microwaves': {'Share of Households'},
#  'milk': {'Annual Production'},
#  'motor gasoline': {'Annual production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'motorcycles and scooters': {'Price'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual production', 'Price'},
#  'nickel': {'Annual Production'},
#  'nickel production': {'Annual production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nitrogenous fertilizers': {'Price'},
#  'nox pollution controls (boilers)': {'Share of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Total Number'},
#  'objects launched into space': {'Total Number'},
#  'offshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Total Capacity'},
#  'onshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'pcv3 vaccine': {'Share of Population'},
#  'pol3 vaccine': {'Share of Population'},
#  'paraxylene': {'Annual production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity', 'Total Number'},
#  'passenger vehicles': {'Total Number'},
#  'pentaerythritol': {'Annual production', 'Price'},
#  'phenol': {'Annual production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual production', 'Price'},
#  'podcasting': {'Share of Population'},
#  'polyester fiber': {'Annual production', 'Price'},
#  'polystyrene': {'Annual production', 'Price'},
#  'polyvinylchloride': {'Annual production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'potassic fertilizers': {'Price'},
#  'power steering': {'Share of Market'},
#  'primary aluminum production': {'Annual production', 'Price'},
#  'primary bauxite production': {'Annual production', 'Price'},
#  'primary copper': {'Annual production', 'Price'},
#  'primary magnesium': {'Annual production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'rcv1 vaccine': {'Share of Population'},
#  'rotac vaccine': {'Share of Population'},
#  'radial tires': {'Share of Market'},
#  'radio': {'Total Number'},
#  'radio receivers': {'Price'},
#  'railroad': {'Total Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual production', 'Price'},
#  'raw steel production': {'Annual production', 'Price'},
#  'real-time gross settlement adoption': {'Share of Market'},
#  'refined copper': {'Price'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'running water': {'Share of Households'},
#  'salt production': {'Annual production', 'Price'},
#  'sand and gravel|construction': {'Annual production', 'Price'},
#  'sand and gravel|industrial': {'Annual production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production'},
#  'silver production': {'Annual production', 'Price'},
#  'smartphone usage': {'Share of Population'},
#  'social media usage': {'Share of Population'},
#  'sodium': {'Annual production', 'Price'},
#  'sodium chlorate': {'Annual production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'solar photovoltaic': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed electricity capacity'},
#  'solid biofuels': {'Installed electricity capacity'},
#  'soybean production': {'Price'},
#  'space launches': {'Price'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steamships': {'Total Number'},
#  'stove': {'Share of Households'},
#  'styrene': {'Annual production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sugar cane production': {'Price'},
#  'sugar output': {'Annual Production'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filament tow and staple fibers': {'Price'},
#  'synthetic filament yarn': {'Price'},
#  'synthetic filaments': {'Annual Production'},
#  'tablet': {'Share of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'telephones and videophones': {'Price'},
#  'television': {'Total Number'},
#  'television receivers': {'Price'},
#  'tin': {'Annual Production'},
#  'tin production': {'Annual production', 'Price'},
#  'titanium sponge': {'Annual production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'turbo-jets of a thrust not exceeding 25 kn': {'Price'},
#  'urea': {'Annual production', 'Price'},
#  'vacuum cleaners': {'Price'},
#  'vacuums': {'Share of Households'},
#  'videocassette recorder': {'Share of Households'},
#  'vinyl acetate': {'Annual production', 'Price'},
#  'vinyl chloride': {'Annual production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share of Population'},
#  'zinc': {'Annual Production'},
#  'zinc production': {'Annual production', 'Price'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
metric_dict_lower = dict(sorted(metric_dict_lower.items(), key=lambda item: item[0])) 
metric_dict_lower
# Out:
# {'acrylic fiber': {'Annual production', 'Price'},
#  'acrylonitrile': {'Annual production', 'Price'},
#  'air conditioning machines': {'Price'},
#  'air-source heat pumps': {'Annual Production'},
#  'amazon prime users': {'Share of Households'},
#  'ammonia synthesis': {'Annual Production'},
#  'aniline': {'Annual production', 'Price'},
#  'aquaculture production': {'Annual production'},
#  'artificial and synthetic fibers': {'Annual Production'},
#  'automatic transmission': {'Share of Market'},
#  'bcg vaccine': {'Share of Population'},
#  'beer': {'Price'},
#  'beer production': {'Annual Production'},
#  'benzene': {'Annual production', 'Price'},
#  'bicycles': {'Cumulative Total Capacity'},
#  'bicycles and other cycles': {'Price'},
#  'bioenergy': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'biofuels production': {'Annual Production'},
#  'biogas': {'Installed electricity capacity'},
#  'bisphenola': {'Annual production', 'Price'},
#  'cable tv': {'Share of Households'},
#  'cadmium refining': {'Annual production', 'Price'},
#  'canals': {'Total Length'},
#  'capillary dna sequencing': {'Annual production', 'Price'},
#  'caprolactam': {'Annual production', 'Price'},
#  'capture fisheries': {'Annual production'},
#  'carbon capture and sequestration': {'Installed Capacity'},
#  'cars': {'Price'},
#  'caustic soda': {'Price'},
#  'caustic soda acid': {'Annual Production'},
#  'cellphones': {'Cumulative Total Capacity', 'Total Number'},
#  'cement': {'Annual production', 'Price'},
#  'central heating': {'Share of Households'},
#  'coal power': {'Cumulative Total Capacity'},
#  'coal production': {'Annual Production', 'Price'},
#  'cobalt': {'Annual production', 'Price'},
#  'colour tv': {'Share of Households'},
#  'combined refrigerators-freezers': {'Price'},
#  'compact fluorescent light bulbs': {'Cumulative Total Capacity'},
#  'compressed air energy storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'computing growth': {'Computing Capacity'},
#  'concentrated solar power': {'Installed Capacity'},
#  'concentrating solar power': {'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'copper|mining': {'Annual production'},
#  'copper|refining': {'Annual production'},
#  'corn production': {'Price'},
#  'cotton seed production': {'Price'},
#  "cow's milk production": {'Price'},
#  'crop harvester': {'Total Number'},
#  'crude oil': {'Price'},
#  'crude petroleum': {'Annual Production'},
#  'cyclohexane': {'Annual production', 'Price'},
#  'desalination capacity': {'Total Capacity'},
#  'dishwashers': {'Share of Households'},
#  'disk brakes': {'Share of Market'},
#  'dna sequencing (all methods)': {'Price'},
#  'dtp1 vaccine': {'Share of Population'},
#  'dtp3 vaccine': {'Share of Population'},
#  'ebook reader': {'Share of Population'},
#  'electric bicycles': {'Cumulative Total Capacity'},
#  'electric range': {'Share of Households'},
#  'electric water heaters and immersion heaters': {'Price'},
#  'electricity': {'Annual Production'},
#  'electro-chemical capacitor': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'electronic ignition': {'Share of Market'},
#  'ethanol': {'Annual production', 'Price'},
#  'ethanolamine': {'Annual production', 'Price'},
#  'ethylene': {'Annual production', 'Price'},
#  'ethylene glycol': {'Annual production', 'Price'},
#  'flow battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'fluid catalytic cracking refineries': {'Average Capacity of Unit Additions',
#   'Net Total Capacity'},
#  'flush toilet': {'Share of Households'},
#  'flywheel battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'formaldehyde': {'Annual production', 'Price'},
#  'freezer': {'Share of Households'},
#  'geothermal energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'gold': {'Annual Production'},
#  'gold production': {'Annual production', 'Price'},
#  'graphite': {'Annual production', 'Price'},
#  'ground source heat pumps': {'Cumulative Total Capacity'},
#  'heat thermal battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'hepb3 vaccine': {'Share of Population'},
#  'hepbb vaccine': {'Share of Population'},
#  'herbicide-tolerant corn': {'Cumulative Acreage'},
#  'herbicide-tolerant cotton': {'Cumulative Acreage'},
#  'herbicide-tolerant soybeans': {'Cumulative Acreage'},
#  'hib3 vaccine': {'Share of Population'},
#  'high-density polyethylene': {'Annual production', 'Price'},
#  'high-speed rail': {'Cumulative Total Capacity'},
#  'home air conditioning': {'Share of Households'},
#  'home computers': {'Share of Households'},
#  'household internet access': {'Share of Households'},
#  'household refrigerators and freezers': {'Price'},
#  'household washing and drying machines': {'Price'},
#  'households with only mobile phones (no landlines)': {'Share of Households'},
#  'hydrochloric acid': {'Annual Production'},
#  'hydroelectricity': {'Annual Production'},
#  'hydrofluoric acid': {'Annual production', 'Price'},
#  'hydrogen storage': {'Cumulative Rated Capacity', 'Cumulative Rated Power'},
#  'hydropower': {'Levelized Cost of Energy', 'Total Installed Cost'},
#  'insect-resistant corn': {'Cumulative Acreage'},
#  'insect-resistant cotton': {'Cumulative Acreage'},
#  'internet backbone bandwidth': {'Computing Capacity'},
#  'internet traffic': {'Computing Capacity'},
#  'ipv1 vaccine': {'Share of Population'},
#  'iron': {'Share of Households'},
#  'iron ore': {'Annual production', 'Price'},
#  'jet aircraft': {'Cumulative Total Capacity'},
#  'latent heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'laundry dryers': {'Cumulative Total Capacity'},
#  'lead': {'Annual production', 'Price'},
#  'lead-acid battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'liquefied natural gas': {'Annual Production'},
#  'liquefied natural gas (lng)': {'Price'},
#  'liquid biofuels': {'Installed electricity capacity'},
#  'lithium mine production': {'Annual production', 'Price'},
#  'lithium-ion battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'low-density polyethylene': {'Annual production', 'Price'},
#  'magnesium': {'Annual production', 'Price'},
#  'magnetic data storage': {'Computing Capacity'},
#  'maleic anhydride': {'Annual production', 'Price'},
#  'marine energy': {'Installed electricity capacity'},
#  'mcv1 vaccine': {'Share of Population'},
#  'mcv2 vaccine': {'Share of Population'},
#  'methanol': {'Annual production', 'Price'},
#  'microcomputers': {'Share of Households'},
#  'microprocessor clock speed': {'Computing Capacity'},
#  'microwave ovens': {'Price'},
#  'microwaves': {'Share of Households'},
#  'milk': {'Annual Production'},
#  'motor gasoline': {'Annual production', 'Price'},
#  'motorcycles': {'Cumulative Total Capacity'},
#  'motorcycles and scooters': {'Price'},
#  'natural gas pipeline': {'Total Length'},
#  'natural gas power': {'Cumulative Total Capacity'},
#  'natural gas production': {'Annual Production', 'Price'},
#  'neoprene rubber': {'Annual production', 'Price'},
#  'nickel': {'Annual Production'},
#  'nickel production': {'Annual production', 'Price'},
#  'nickel-based battery': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'nitric acid': {'Annual Production'},
#  'nitrogen fertilizer': {'Annual Production'},
#  'nitrogenous fertilizers': {'Price'},
#  'nox pollution controls (boilers)': {'Share of Boilers'},
#  'nuclear energy': {'Annual Production'},
#  'nuclear weapons': {'Total Number'},
#  'objects launched into space': {'Total Number'},
#  'offshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'oil pipeline': {'Total Length'},
#  'oil production': {'Annual Production'},
#  'oil refining capacity': {'Total Capacity'},
#  'onshore wind energy': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'paraxylene': {'Annual production', 'Price'},
#  'passenger cars': {'Cumulative Total Capacity', 'Total Number'},
#  'passenger vehicles': {'Total Number'},
#  'pcv3 vaccine': {'Share of Population'},
#  'pentaerythritol': {'Annual production', 'Price'},
#  'phenol': {'Annual production', 'Price'},
#  'phosphate fertilizer': {'Annual Production'},
#  'phthalic anhydride': {'Annual production', 'Price'},
#  'podcasting': {'Share of Population'},
#  'pol3 vaccine': {'Share of Population'},
#  'polyester fiber': {'Annual production', 'Price'},
#  'polystyrene': {'Annual production', 'Price'},
#  'polyvinylchloride': {'Annual production', 'Price'},
#  'postal traffic': {'Total Number'},
#  'potash fertilizer': {'Annual Production'},
#  'potassic fertilizers': {'Price'},
#  'power steering': {'Share of Market'},
#  'primary aluminum production': {'Annual production', 'Price'},
#  'primary bauxite production': {'Annual production', 'Price'},
#  'primary copper': {'Annual production', 'Price'},
#  'primary magnesium': {'Annual production', 'Price'},
#  'processor performance': {'Computing Capacity'},
#  'public roads': {'Total Length'},
#  'pumped hydro storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'radial tires': {'Share of Market'},
#  'radio': {'Total Number'},
#  'radio receivers': {'Price'},
#  'railroad': {'Total Length'},
#  'random access memory': {'Computing Capacity'},
#  'rare earth mine production': {'Annual production', 'Price'},
#  'raw steel production': {'Annual production', 'Price'},
#  'rcv1 vaccine': {'Share of Population'},
#  'real-time gross settlement adoption': {'Share of Market'},
#  'refined copper': {'Price'},
#  'refrigerators': {'Cumulative Total Capacity'},
#  'renewable power': {'Annual Production'},
#  'rotac vaccine': {'Share of Population'},
#  'running water': {'Share of Households'},
#  'salt production': {'Annual production', 'Price'},
#  'sand and gravel|construction': {'Annual production', 'Price'},
#  'sand and gravel|industrial': {'Annual production', 'Price'},
#  'sensible heat storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'shale production': {'Annual production'},
#  'shotgun sanger dna sequencing': {'Price', 'Total Number'},
#  'silver': {'Annual Production'},
#  'silver production': {'Annual production', 'Price'},
#  'smartphone usage': {'Share of Population'},
#  'social media usage': {'Share of Population'},
#  'sodium': {'Annual production', 'Price'},
#  'sodium chlorate': {'Annual production', 'Price'},
#  'sodium-based battery storage': {'Cumulative Rated Capacity',
#   'Cumulative Rated Power'},
#  'solar photovoltaic': {'Installed electricity capacity',
#   'Levelized Cost of Energy',
#   'Total Installed Cost'},
#  'solar thermal energy': {'Installed electricity capacity'},
#  'solid biofuels': {'Installed electricity capacity'},
#  'soybean production': {'Price'},
#  'space launches': {'Price'},
#  'stationary steam engines': {'Cumulative Total Capacity'},
#  'steam locomotives': {'Cumulative Total Capacity'},
#  'steamships': {'Total Number'},
#  'stove': {'Share of Households'},
#  'styrene': {'Annual production', 'Price'},
#  'submarine cables': {'Cumulative Length'},
#  'sugar cane production': {'Price'},
#  'sugar output': {'Annual Production'},
#  'sulphuric acid': {'Annual Production'},
#  'synthetic filament tow and staple fibers': {'Price'},
#  'synthetic filament yarn': {'Price'},
#  'synthetic filaments': {'Annual Production'},
#  'tablet': {'Share of Population'},
#  'telegraph traffic': {'Total Number'},
#  'telephones': {'Total Number'},
#  'telephones and videophones': {'Price'},
#  'television': {'Total Number'},
#  'television receivers': {'Price'},
#  'tin': {'Annual Production'},
#  'tin production': {'Annual production', 'Price'},
#  'titanium sponge': {'Annual production', 'Price'},
#  'transistors per microprocessor': {'Computing Capacity'},
#  'turbo-jets of a thrust not exceeding 25 kn': {'Price'},
#  'urea': {'Annual production', 'Price'},
#  'vacuum cleaners': {'Price'},
#  'vacuums': {'Share of Households'},
#  'videocassette recorder': {'Share of Households'},
#  'vinyl acetate': {'Annual production', 'Price'},
#  'vinyl chloride': {'Annual production', 'Price'},
#  'washing machines': {'Cumulative Total Capacity'},
#  'water heater': {'Share of Households'},
#  'wet flue gas desulfurization systems': {'Cumulative Total Capacity'},
#  'yfv vaccine': {'Share of Population'},
#  'zinc': {'Annual Production'},
#  'zinc production': {'Annual production', 'Price'},
#  'zinc-based battery': {'Cumulative Rated Capacity', 'Cumulative Rated Power'}}

# %%
for item in metric_dict_lower:
    print(item)
# Out:
# acrylic fiber
# acrylonitrile
# air conditioning machines
# air-source heat pumps
# amazon prime users
# ammonia synthesis
# aniline
# aquaculture production
# artificial and synthetic fibers
# automatic transmission
# bcg vaccine
# beer
# beer production
# benzene
# bicycles
# bicycles and other cycles
# bioenergy
# biofuels production
# biogas
# bisphenola
# cable tv
# cadmium refining
# canals
# capillary dna sequencing
# caprolactam
# capture fisheries
# carbon capture and sequestration
# cars
# caustic soda
# caustic soda acid
# cellphones
# cement
# central heating
# coal power
# coal production
# cobalt
# colour tv
# combined refrigerators-freezers
# compact fluorescent light bulbs
# compressed air energy storage
# computing growth
# concentrated solar power
# concentrating solar power
# copper|mining
# copper|refining
# corn production
# cotton seed production
# cow's milk production
# crop harvester
# crude oil
# crude petroleum
# cyclohexane
# desalination capacity
# dishwashers
# disk brakes
# dna sequencing (all methods)
# dtp1 vaccine
# dtp3 vaccine
# ebook reader
# electric bicycles
# electric range
# electric water heaters and immersion heaters
# electricity
# electro-chemical capacitor
# electronic ignition
# ethanol
# ethanolamine
# ethylene
# ethylene glycol
# flow battery storage
# fluid catalytic cracking refineries
# flush toilet
# flywheel battery storage
# formaldehyde
# freezer
# geothermal energy
# gold
# gold production
# graphite
# ground source heat pumps
# heat thermal battery storage
# hepb3 vaccine
# hepbb vaccine
# herbicide-tolerant corn
# herbicide-tolerant cotton
# herbicide-tolerant soybeans
# hib3 vaccine
# high-density polyethylene
# high-speed rail
# home air conditioning
# home computers
# household internet access
# household refrigerators and freezers
# household washing and drying machines
# households with only mobile phones (no landlines)
# hydrochloric acid
# hydroelectricity
# hydrofluoric acid
# hydrogen storage
# hydropower
# insect-resistant corn
# insect-resistant cotton
# internet backbone bandwidth
# internet traffic
# ipv1 vaccine
# iron
# iron ore
# jet aircraft
# latent heat storage
# laundry dryers
# lead
# lead-acid battery storage
# liquefied natural gas
# liquefied natural gas (lng)
# liquid biofuels
# lithium mine production
# lithium-ion battery storage
# low-density polyethylene
# magnesium
# magnetic data storage
# maleic anhydride
# marine energy
# mcv1 vaccine
# mcv2 vaccine
# methanol
# microcomputers
# microprocessor clock speed
# microwave ovens
# microwaves
# milk
# motor gasoline
# motorcycles
# motorcycles and scooters
# natural gas pipeline
# natural gas power
# natural gas production
# neoprene rubber
# nickel
# nickel production
# nickel-based battery
# nitric acid
# nitrogen fertilizer
# nitrogenous fertilizers
# nox pollution controls (boilers)
# nuclear energy
# nuclear weapons
# objects launched into space
# offshore wind energy
# oil pipeline
# oil production
# oil refining capacity
# onshore wind energy
# paraxylene
# passenger cars
# passenger vehicles
# pcv3 vaccine
# pentaerythritol
# phenol
# phosphate fertilizer
# phthalic anhydride
# podcasting
# pol3 vaccine
# polyester fiber
# polystyrene
# polyvinylchloride
# postal traffic
# potash fertilizer
# potassic fertilizers
# power steering
# primary aluminum production
# primary bauxite production
# primary copper
# primary magnesium
# processor performance
# public roads
# pumped hydro storage
# radial tires
# radio
# radio receivers
# railroad
# random access memory
# rare earth mine production
# raw steel production
# rcv1 vaccine
# real-time gross settlement adoption
# refined copper
# refrigerators
# renewable power
# rotac vaccine
# running water
# salt production
# sand and gravel|construction
# sand and gravel|industrial
# sensible heat storage
# shale production
# shotgun sanger dna sequencing
# silver
# silver production
# smartphone usage
# social media usage
# sodium
# sodium chlorate
# sodium-based battery storage
# solar photovoltaic
# solar thermal energy
# solid biofuels
# soybean production
# space launches
# stationary steam engines
# steam locomotives
# steamships
# stove
# styrene
# submarine cables
# sugar cane production
# sugar output
# sulphuric acid
# synthetic filament tow and staple fibers
# synthetic filament yarn
# synthetic filaments
# tablet
# telegraph traffic
# telephones
# telephones and videophones
# television
# television receivers
# tin
# tin production
# titanium sponge
# transistors per microprocessor
# turbo-jets of a thrust not exceeding 25 kn
# urea
# vacuum cleaners
# vacuums
# videocassette recorder
# vinyl acetate
# vinyl chloride
# washing machines
# water heater
# wet flue gas desulfurization systems
# yfv vaccine
# zinc
# zinc production
# zinc-based battery
