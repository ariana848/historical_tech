# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 2.0.csv')
all_tech
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_24341/1178174242.py:1: DtypeWarning: Columns (157,216,217,219,226,227,231,249,250,253,254,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,319,321,322,323,324,325,326,327,328,329,330,331) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_tech = pd.read_csv('all_tech_version 2.0.csv')
#                                                      ID Spatial Scale  \
# 0     Lithium-Ion Battery Storage_Cumulative Rated P...      National
# 1     Lithium-Ion Battery Storage_Cumulative Rated C...      National
# 2       Sensible Heat Storage_Cumulative Rated Power_ZA      National
# 3     Sensible Heat Storage_Cumulative Rated Capacit...      National
# 4        Pumped Hydro Storage_Cumulative Rated Power_CA      National
# ...                                                 ...           ...
# 7563       Raw steel production_Annual production_World        Global
# 7564                  Space Launches_Yearly Launches_UA      National
# 7565                  Space Launches_Yearly Launches_TM      National
# 7566         Liquefied natural gas_Annual Production_US           NaN
# 7567                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-Ion Battery Storage
# 1              TG           Togo  Lithium-Ion Battery Storage
# 2              ZA   South Africa        Sensible Heat Storage
# 3              ZA   South Africa        Sensible Heat Storage
# 4              CA         Canada         Pumped Hydro Storage
# ...           ...            ...                          ...
# 7563        World          World         Raw steel production
# 7564           UA        Ukraine               Space Launches
# 7565           TM   Turkmenistan               Space Launches
# 7566           US  United States        Liquefied natural gas
# 7567           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0        Cumulative Rated Power                                     kW
# 1     Cumulative Rated Capacity                                    kWh
# 2        Cumulative Rated Power                                     kW
# 3     Cumulative Rated Capacity                                    kWh
# 4        Cumulative Rated Power                                     kW
# ...                         ...                                    ...
# 7563          Annual production                            Metric tons
# 7564            Yearly Launches  Number of objects launched into space
# 7565            Yearly Launches  Number of objects launched into space
# 7566          Annual Production                     Billion cubic feet
# 7567            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  \
# 0         DOE Global Energy Storage Database
# 1         DOE Global Energy Storage Database
# 2         DOE Global Energy Storage Database
# 3         DOE Global Energy Storage Database
# 4         DOE Global Energy Storage Database
# ...                                      ...
# 7563                  U.S. Geological Survey
# 7564                                  UNOOSA
# 7565                                  UNOOSA
# 7566  U.S. Energy Information Administration
# 7567                                  UNOOSA
#
#                                    Long Technology Name  1700  ...     2016  \
# 0     Cumulative Rated Power | Lithium-Ion Battery S...   NaN  ...      NaN
# 1     Cumulative Rated Capacity | Lithium-Ion Batter...   NaN  ...      NaN
# 2        Cumulative Rated Power | Sensible Heat Storage   NaN  ...   255000
# 3     Cumulative Rated Capacity | Sensible Heat Storage   NaN  ...   255000
# 4         Cumulative Rated Power | Pumped Hydro Storage   NaN  ...  4574000
# ...                                                 ...   ...  ...      ...
# 7563           Annual production | Raw steel production   NaN  ...      NaN
# 7564                   Yearly Launches | Space Launches   NaN  ...      NaN
# 7565                   Yearly Launches | Space Launches   NaN  ...      NaN
# 7566          Annual Production | Liquefied natural gas   NaN  ...   186.84
# 7567                   Yearly Launches | Space Launches   NaN  ...      NaN
#
#         2017     2018    2019     2020     2021  2022  2023  2024  2025
# 0        190      290     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1        190      290     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 2     355000   455000     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 3     355000   455000     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 4        NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# ...      ...      ...     ...      ...      ...   ...   ...   ...   ...
# 7563     NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 7564     NaN      NaN     NaN      NaN      NaN   1.0   NaN   NaN   NaN
# 7565     NaN      NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 7566  707.54  1083.12  1819.4  2389.84  3560.82   NaN   NaN   NaN   NaN
# 7567     NaN      1.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
#
# [7568 rows x 335 columns]

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
tech_list
# Out:
# ['Acrylic Fiber',
#  'Acrylonitrile',
#  'Air-Source Heat Pumps',
#  'All Biofuels',
#  'Amazon Prime users',
#  'Ammonia Synthesis',
#  'Aniline',
#  'Aquaculture production',
#  'Automatic transmission',
#  'BCG Vaccine',
#  'Beer Production',
#  'Benzene',
#  'Bicycles',
#  'Biogas',
#  'Bisphenol A',
#  'Cable TV',
#  'Cadmium Refining',
#  'Canals',
#  'Cane Sugar Production',
#  'Caprolactam',
#  'Capture fisheries production',
#  'Carbon Capture & Sequestration',
#  'Caustic Soda',
#  'Cellphones',
#  'Cement production',
#  'Central heating',
#  'Coal Power',
#  'Coal Production',
#  'Cobalt Mine Production',
#  'Colour TV',
#  'Compact fluorescent light bulbs',
#  'Compressed Air Energy Storage',
#  'Computing Growth',
#  'Concentrated Solar Power',
#  'Copper Mining',
#  'Copper Refining',
#  'Crop harvester',
#  'Crude Oil',
#  'Cyclohexane',
#  'DTP1 Vaccine',
#  'DTP3 Vaccine',
#  'Desalination capacity',
#  'Dishwashers',
#  'Disk brakes',
#  'Ebook reader',
#  'Electric Bicycles',
#  'Electric Range',
#  'Electricity',
#  'Electro-Chemical Capacitor',
#  'Electronic ignition',
#  'Ethanolamine',
#  'Ethyl Alcohol',
#  'Ethylene',
#  'Ethylene Glycol',
#  'Flow Battery Storage',
#  'Fluid Catalytic Cracking Refineries',
#  'Flush toilet',
#  'Flywheel Battery Storage',
#  'Formaldehyde',
#  'Freezer',
#  'Geothermal Energy',
#  'Gold production',
#  'Graphite Mine Production',
#  'Ground Source Heat Pumps',
#  'HEPB3 Vaccine',
#  'HEPBB Vaccine',
#  'HIB3 Vaccine',
#  'Heat Thermal Battery Storage',
#  'Herbicide-Tolerant Corn',
#  'Herbicide-Tolerant Cotton',
#  'Herbicide-Tolerant Soybeans',
#  'High-Density Polyethylene',
#  'High-speed rail',
#  'Home air conditioning',
#  'Home computers',
#  'Household Internet access',
#  'Households with only mobile phones (no landlines)',
#  'Hydrochloric Acid',
#  'Hydroelectricity',
#  'Hydrofluoric Acid',
#  'Hydrogen Storage',
#  'IPV1 Vaccine',
#  'Insect-Resistant Corn',
#  'Insect-Resistant Cotton',
#  'Internet Backbone Bandwidth',
#  'Internet Traffic',
#  'Iron',
#  'Iron ore',
#  'Jet Aircraft',
#  'Latent Heat Storage',
#  'Laundry Dryers',
#  'Lead mine production',
#  'Lead-Acid Battery Storage',
#  'Liquefied natural gas',
#  'Liquid Biofuels',
#  'Lithium Mine Production',
#  'Lithium-Ion Battery Storage',
#  'Low-Density Polyethylene',
#  'MCV1 Vaccine',
#  'MCV2 Vaccine',
#  'Magnesium',
#  'Magnetic Data Storage',
#  'Maleic Anhydride',
#  'Marine Energy',
#  'Methanol',
#  'Microcomputers',
#  'Microprocessor Clock Speed',
#  'Microwaves',
#  'Milk production',
#  'Motor Gasoline',
#  'Motorcycles',
#  'Natural Gas Power',
#  'Natural Gas Production',
#  'Natural gas pipeline',
#  'Neoprene Rubber',
#  'Nickel production',
#  'Nickel-Based Battery',
#  'Nitric Acid',
#  'Nitrogen Fertilizer',
#  'Nox pollution controls (boilers)',
#  'Nuclear Energy',
#  'Nuclear weapons',
#  'Offshore Wind Energy',
#  'Oil Production',
#  'Oil Refining Capacity',
#  'Oil pipeline',
#  'Onshore Wind Energy',
#  'PCV3 Vaccine',
#  'POL3 Vaccine',
#  'Paraxylene',
#  'Passenger Cars',
#  'Pentaerythritol',
#  'Phenol',
#  'Phosphate Fertilizer',
#  'Phthalic Anhydride',
#  'Podcasting',
#  'Polyester Fiber',
#  'Polystyrene',
#  'Polyvinylchloride',
#  'Postal Traffic',
#  'Potash Fertilizer',
#  'Power steering',
#  'Primary Magnesium',
#  'Primary aluminum production',
#  'Primary bauxite production',
#  'Primary copper production',
#  'Processor Performance',
#  'Public roads',
#  'Pumped Hydro Storage',
#  'RCV1 Vaccine',
#  'ROTAC Vaccine',
#  'Radial tires',
#  'Radio',
#  'Railroad',
#  'Random Access Memory',
#  'Rare Earth Mine Production',
#  'Raw steel production',
#  'Real-time gross settlement adoption',
#  'Refrigerators',
#  'Renewable Power',
#  'Running water',
#  'Salt production',
#  'Sand and gravel production (construction)',
#  'Sand and gravel production (industrial)',
#  'Sensible Heat Storage',
#  'Shale production',
#  'Shotgun Sanger DNA Sequencing',
#  'Silver',
#  'Smartphone usage',
#  'Social media usage',
#  'Sodium',
#  'Sodium Chlorate',
#  'Sodium-Based Battery Storage',
#  'Solar Photovoltaic',
#  'Solar Thermal Energy',
#  'Solid Biofuels',
#  'Space Launches',
#  'Stationary Steam Engines',
#  'Steam Locomotives',
#  'Steam ships',
#  'Stove',
#  'Styrene',
#  'Submarine Cables',
#  'Sulphuric Acid',
#  'Synthetic Filaments',
#  'Tablet',
#  'Telegraph Traffic',
#  'Telephones',
#  'Television',
#  'Tin',
#  'Titanium Sponge',
#  'Transistors per Microprocessor',
#  'Urea',
#  'Vacuums',
#  'Videocassette recorder',
#  'Vinyl Acetate',
#  'Vinyl Chloride',
#  'Washing Machines',
#  'Water Heater',
#  'Wet flue gas desulfurization systems',
#  'YFV Vaccine',
#  'Zinc',
#  'Zinc-Based Battery']

# %%
len(tech_list)
# Out:
# 203

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
tech_country_dict

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)

# %%
cost_data = all_tech[all_tech['Metric']=='Price']
for x in list(set(cost_data['Technology Name'])):
    print(x)
# Out:
# Maleic Anhydride
# Sodium
# Ethyl Alcohol
# Shotgun Sanger DNA Sequencing
# Aniline
# Nickel production
# Urea
# Caprolactam
# Polystyrene
# Polyester Fiber
# Sand and gravel production (industrial)
# Titanium Sponge
# High-Density Polyethylene
# Neoprene Rubber
# Acrylonitrile
# Ethylene Glycol
# Pentaerythritol
# Low-Density Polyethylene
# Styrene
# Ethylene
# Ethanolamine
# Sand and gravel production (construction)
# Polyvinylchloride
# Cyclohexane
# Methanol
# Hydrofluoric Acid
# Magnesium
# Phenol
# Sodium Chlorate
# Cement production
# Crude Oil
# Primary Magnesium
# Formaldehyde
# Phthalic Anhydride
# Vinyl Chloride
# Gold production
# Bisphenol A
# Motor Gasoline
# Vinyl Acetate
# Primary copper production
# Benzene
# Acrylic Fiber
# Paraxylene

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')

# %%
time_span('Ammonia Synthesis')

# %%
time_span('Aquaculture production')

# %%
timespan_dict = {}
for tech in tech_list:
    timespan_dict[tech] = time_span(tech)

# %%
timespan_dict

# %%
timespan_dict_lower = {}
for item in timespan_dict:
    timespan_dict_lower[item.lower()] = timespan_dict[item]
timespan_dict_lower

# %%
timespan_dict_lower = dict(sorted(timespan_dict_lower.items(), key=lambda item: item[0])) 
timespan_dict_lower

# %%
for item in timespan_dict_lower:
    print(timespan_dict_lower[item])

# %%
def metric(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    metric = set(tech_df['Metric'])
    return metric

# %%
metric_dict = {}
for tech in tech_list:
    metric_dict[tech] = metric(tech)
metric_dict

# %%
metric_dict_lower = {}
for item in metric_dict:
    metric_dict_lower[item.lower()] = metric_dict[item]
metric_dict_lower

# %%
metric_dict_lower = dict(sorted(metric_dict_lower.items(), key=lambda item: item[0])) 
metric_dict_lower

# %%
for item in metric_dict_lower:
    print(item)
