# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 1.5.csv')
all_tech
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/2174381710.py:1: DtypeWarning: Columns (156,215,216,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,321,322,323,324,325,326,327,328,329,330) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_tech = pd.read_csv('all_tech_version 1.5.csv')
#                                                      ID Spatial Scale  \
# 0     Lithium-ion battery storage_Cumulative Rated C...      National
# 1     Lithium-ion battery storage_Cumulative Rated P...      National
# 2     Sensible heat storage_Cumulative Rated Capacit...      National
# 3       Sensible heat storage_Cumulative Rated Power_ZA      National
# 4     Pumped hydro storage_Cumulative Rated Capacity_CA      National
# ...                                                 ...           ...
# 7577       Raw steel production_Annual production_World        Global
# 7578                  Space Launches_Yearly Launches_UA      National
# 7579                  Space Launches_Yearly Launches_TM      National
# 7580                   Liquefied natural gas_Exports_US           NaN
# 7581                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-ion battery storage
# 1              TG           Togo  Lithium-ion battery storage
# 2              ZA   South Africa        Sensible heat storage
# 3              ZA   South Africa        Sensible heat storage
# 4              CA         Canada         Pumped hydro storage
# ...           ...            ...                          ...
# 7577        World          World         Raw steel production
# 7578           UA        Ukraine               Space Launches
# 7579           TM   Turkmenistan               Space Launches
# 7580           US  United States        Liquefied natural gas
# 7581           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0     Cumulative Rated Capacity                                    kWh
# 1        Cumulative Rated Power                                     kW
# 2     Cumulative Rated Capacity                                    kWh
# 3        Cumulative Rated Power                                     kW
# 4     Cumulative Rated Capacity                                    kWh
# ...                         ...                                    ...
# 7577          Annual production                            Metric tons
# 7578            Yearly Launches  Number of objects launched into space
# 7579            Yearly Launches  Number of objects launched into space
# 7580                    Exports                     Billion cubic feet
# 7581            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  1700  1701  ...       2016  \
# 0         DOE Global Energy Storage Database   NaN   NaN  ...        NaN
# 1         DOE Global Energy Storage Database   NaN   NaN  ...        NaN
# 2         DOE Global Energy Storage Database   NaN   NaN  ...  1195000.0
# 3         DOE Global Energy Storage Database   NaN   NaN  ...   255000.0
# 4         DOE Global Energy Storage Database   NaN   NaN  ...  3044000.0
# ...                                      ...   ...   ...  ...        ...
# 7577                  U.S. Geological Survey   NaN   NaN  ...        NaN
# 7578                                  UNOOSA   NaN   NaN  ...        NaN
# 7579                                  UNOOSA   NaN   NaN  ...        NaN
# 7580  U.S. Energy Information Administration   NaN   NaN  ...     186.84
# 7581                                  UNOOSA   NaN   NaN  ...        NaN
#
#            2017       2018    2019     2020     2021  2022  2023  2024  2025
# 0         760.0     1160.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1         190.0      290.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 2     1745000.0  2945000.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 3      355000.0   455000.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 4           NaN        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# ...         ...        ...     ...      ...      ...   ...   ...   ...   ...
# 7577        NaN        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 7578        NaN        NaN     NaN      NaN      NaN   1.0   NaN   NaN   NaN
# 7579        NaN        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 7580     707.54    1083.12  1819.4  2389.84  3560.82   NaN   NaN   NaN   NaN
# 7581        NaN        1.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
#
# [7582 rows x 334 columns]

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
tech_list
# Out:
# ['Acrylic Fiber',
#  'Acrylonitrile',
#  'Air-Source Heat Pumps',
#  'All Biofuels',
#  'Amazon Prime users',
#  'Aniline',
#  'Aquaculture production',
#  'Automatic transmission',
#  'BCG Vaccine',
#  'Beer Production',
#  'Benzene',
#  'Bicycles',
#  'Biogas',
#  'Bisphenol A',
#  'CFLs',
#  'Cable TV',
#  'Cadmium Refining',
#  'Canals',
#  'Cane Sugar Production',
#  'Caprolactam',
#  'Capture fisheries production',
#  'Carbon Capture & Sequestration',
#  'Caustic Soda',
#  'Cellphones',
#  'Cement production',
#  'Central heating',
#  'Coal Power',
#  'Coal Production',
#  'Cobalt Mine Production',
#  'Colour TV',
#  'Compressed air energy storage',
#  'Computing Growth',
#  'Concentrated Solar Power',
#  'Copper Mining',
#  'Copper Refining',
#  'Crop harvester',
#  'Crude Oil',
#  'Cyclohexane',
#  'DTP1 Vaccine',
#  'DTP3 Vaccine',
#  'Desalination capacity',
#  'Dishwashers',
#  'Disk brakes',
#  'Ebook reader',
#  'Electric Bicycles',
#  'Electric Range',
#  'Electricity',
#  'Electro-chemical capacitor',
#  'Electronic ignition',
#  'Ethanolamine',
#  'Ethyl Alcohol',
#  'Ethylene',
#  'Ethylene Glycol',
#  'FCC-Refineries',
#  'Flow battery storage',
#  'Flush toilet',
#  'Flywheel battery storage',
#  'Formaldehyde',
#  'Freezer',
#  'Geothermal Energy',
#  'Gold production',
#  'Graphite Mine Production',
#  'Ground Source Heat Pumps',
#  'HEPB3 Vaccine',
#  'HEPBB Vaccine',
#  'HIB3 Vaccine',
#  'Heat thermal battery storage',
#  'Herbicide-Tolerant Corn',
#  'Herbicide-Tolerant Cotton',
#  'Herbicide-Tolerant Soybeans',
#  'High-speed rail',
#  'Home air conditioning',
#  'Home computers',
#  'Household Internet access',
#  'Households with only mobile phones (no landlines)',
#  'Hydrochloric Acid',
#  'Hydroelectricity',
#  'Hydrofluoric Acid',
#  'Hydrogen storage',
#  'IPV1 Vaccine',
#  'Insect-Resistant Corn',
#  'Insect-Resistant Cotton',
#  'Internet Backbone Bandwidth',
#  'Internet Traffic',
#  'Iron',
#  'Iron ore',
#  'Jet Aircraft',
#  'Latent heat storage',
#  'Laundry Dryers',
#  'Lead mine production',
#  'Lead-acid battery storage',
#  'Liquefied natural gas',
#  'Liquid Biofuels',
#  'Lithium Mine Production',
#  'Lithium-ion battery storage',
#  'MCV1 Vaccine',
#  'MCV2 Vaccine',
#  'Magnesium',
#  'Magnetic Data Storage',
#  'Maleic Anhydride',
#  'Marine Energy',
#  'Methanol',
#  'Microcomputers',
#  'Microprocessor Clock Speed',
#  'Microwaves',
#  'Milk production',
#  'Motor Gasoline',
#  'Motorcycles',
#  'NatGas Power',
#  'Natural Gas Production',
#  'Natural gas pipeline',
#  'Neoprene Rubber',
#  'Nickel production',
#  'Nickel-based battery',
#  'Nitric Acid',
#  'Nitrogen Fertilizer',
#  'Nox pollution controls (boilers)',
#  'Nuclear Energy',
#  'Nuclear weapons',
#  'Off-Grid Onshore Wind Energy',
#  'Oil Production',
#  'Oil Refining Capacity',
#  'Oil pipeline',
#  'On-Grid Offshore Wind Energy',
#  'On-Grid Onshore Wind Energy',
#  'PCV3 Vaccine',
#  'POL3 Vaccine',
#  'Paraxylene',
#  'Passenger Cars',
#  'Pentaerythritol',
#  'Phenol',
#  'Phosphate Fertilizer',
#  'Phthalic Anhydride',
#  'Podcasting',
#  'Polyester Fiber',
#  'Polyethylene HD',
#  'Polyethylene LD',
#  'Polystyrene',
#  'Polyvinylchloride',
#  'Postal Traffic',
#  'Potash Fertilizer',
#  'Power steering',
#  'Primary Magnesium',
#  'Primary aluminum production',
#  'Primary bauxite production',
#  'Primary copper production',
#  'Processor Performance',
#  'Public roads',
#  'Pumped hydro storage',
#  'RCV1 Vaccine',
#  'ROTAC Vaccine',
#  'RTGS adoption',
#  'Radial tires',
#  'Radio',
#  'Railroad',
#  'Random Access Memory',
#  'Rare Earth Mine Production',
#  'Raw steel production',
#  'Refrigerators',
#  'Renewable Power',
#  'Running water',
#  'Salt production',
#  'Sand and gravel production (construction)',
#  'Sand and gravel production (industrial)',
#  'Sensible heat storage',
#  'Shale production',
#  'Shipping container port infrastructure',
#  'Shotgun Sanger DNA Sequencing',
#  'Silver',
#  'Smartphone usage',
#  'Social media usage',
#  'Sodium',
#  'Sodium Chlorate',
#  'Sodium-based battery storage',
#  'Solar Photovoltaic',
#  'Solar Thermal Energy',
#  'Solid Biofuels',
#  'Space Launches',
#  'Stationary Steam Engines',
#  'Steam Locomotives',
#  'Steam ships',
#  'Stove',
#  'Styrene',
#  'Submarine Cables',
#  'Sulphuric Acid',
#  'Synthetic Filaments',
#  'Tablet',
#  'Telegraph Traffic',
#  'Telephones',
#  'Television',
#  'Tin',
#  'Titanium Sponge',
#  'Transistors per Microprocessor',
#  'Urea',
#  'Vacuums',
#  'Videocassette recorder',
#  'Vinyl Acetate',
#  'Vinyl Chloride',
#  'Washing Machines',
#  'Water Heater',
#  'Wet flue gas desulfurization systems',
#  'YFV Vaccine',
#  'Zinc',
#  'Zinc-based battery']

# %%
len(tech_list)
# Out:
# 204

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)
# Out:
# BCG Vaccine
# Hydrogen storage
# Off-Grid Onshore Wind Energy
# Silver
# Steam ships
# Tin
# YFV Vaccine

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
tech_country_dict
# Out:
# {'Acrylic Fiber': ['World'],
#  'Acrylonitrile': ['World'],
#  'Air-Source Heat Pumps': ['United States'],
#  'All Biofuels': ['Austria',
#   'India',
#   'China',
#   'Belgium',
#   'Germany',
#   'Finland',
#   'United Kingdom',
#   'Indonesia',
#   'Australia',
#   'Netherlands',
#   'Sweden',
#   'Brazil',
#   'Spain',
#   'US',
#   'Italy',
#   'Colombia',
#   'Portugal',
#   'France',
#   'Thailand',
#   'Mexico',
#   'South Korea',
#   'Argentina',
#   'Canada',
#   'Poland'],
#  'Amazon Prime users': ['United States'],
#  'Aniline': ['World'],
#  'Aquaculture production': ['Samoa',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Eswatini',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Puerto Rico',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Virgin Islands (U.S.)',
#   'Eritrea',
#   'Lao PDR',
#   'Serbia',
#   'Liberia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'Gambia, The',
#   'France',
#   'Micronesia, Fed. Sts.',
#   'Mexico',
#   'Guinea-Bissau',
#   'Lesotho',
#   'Burundi',
#   'Ukraine',
#   'Haiti',
#   'Poland',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Vietnam',
#   'Paraguay',
#   'Belgium',
#   'Turks and Caicos Islands',
#   'Indonesia',
#   'Chile',
#   'Nauru',
#   'Northern Mariana Islands',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Montenegro',
#   'St. Lucia',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'West Bank and Gaza',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   'Jordan',
#   'New Caledonia',
#   'Afghanistan',
#   'Iran, Islamic Rep.',
#   'British Virgin Islands',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Lithuania',
#   'Myanmar',
#   'Aruba',
#   'Slovenia',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'St. Vincent and the Grenadines',
#   'Bahamas, The',
#   'Venezuela, RB',
#   'Oman',
#   "Cote d'Ivoire",
#   'World',
#   'Jamaica',
#   'Switzerland',
#   'Tanzania',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Hong Kong SAR, China',
#   'Brazil',
#   "Korea, Dem. People's Rep.",
#   'Kuwait',
#   'Guam',
#   'Sierra Leone',
#   'Uruguay',
#   'French Polynesia',
#   'Albania',
#   'Slovak Republic',
#   'North Macedonia',
#   'Kyrgyz Republic',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'Yemen, Rep.',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'St. Kitts and Nevis',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Moldova',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Curacao',
#   'Saudi Arabia',
#   'Congo, Rep.',
#   'Faroe Islands',
#   'Australia',
#   'Solomon Islands',
#   'Cyprus',
#   'Rwanda',
#   'American Samoa',
#   'Italy',
#   'Turkiye',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Korea, Rep.',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Congo, Dem. Rep.',
#   'Egypt, Arab Rep.',
#   'Malta',
#   'Tunisia',
#   'Gabon'],
#  'Automatic transmission': ['United States'],
#  'BCG Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Eritrea',
#   'Comoros',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Micronesia (Federated States of)',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Yemen',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Sweden',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Senegal',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Zambia',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Jamaica',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Sierra Leone',
#   'Uruguay',
#   'Albania',
#   'Namibia',
#   'Iraq',
#   'Congo',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Monaco',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Bolivia (Plurinational State of)',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Mauritania',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'State of Palestine',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Malta',
#   'Tunisia',
#   'Cook Islands',
#   'Gabon'],
#  'Beer Production': ['Bulgaria',
#   'India',
#   'Tajikistan',
#   'Belarus',
#   'Hungary',
#   'Costa Rica',
#   'Zaire',
#   'Singapore',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Kenya',
#   'Cuba',
#   'Kazakhstan',
#   'Uzbekistan',
#   'Serbia',
#   'Norway',
#   'Ivory Coast',
#   'Romania',
#   'Ghana',
#   'France',
#   'Mexico',
#   'Burundi',
#   'Kyrgistan',
#   'Ukraine',
#   'Egypt',
#   'Poland',
#   'Vietnam',
#   'Paraguay',
#   'Belgium',
#   'Indonesia',
#   'Chile',
#   'Southern Vietnam',
#   'Armenia',
#   'Czech Republic',
#   'Georgia',
#   'Honduras',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Zimbabwe',
#   'Spain',
#   'Russia',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Korea',
#   'Thailand',
#   'Azerbaijan',
#   'West Germany',
#   'Croatia',
#   'Peru',
#   'Ethiopia',
#   'East Germany',
#   'Malaysia',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Germany',
#   'Zambia',
#   'Tanzania',
#   'Jamaica',
#   'Switzerland',
#   'Venezuela',
#   'Guatemala',
#   'Angola',
#   'USA',
#   'Dominican Republic',
#   'Brazil',
#   'Uruguay',
#   'Congo',
#   'El Salvador',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'UK',
#   'New Zealand',
#   'Finland',
#   'Moldova',
#   'Mozambique',
#   'Nicaragua',
#   'Macedonia',
#   'Algeria',
#   'Australia',
#   'Turkey',
#   'Rwanda',
#   'Yugoslavia',
#   'Italy',
#   'Cameroon',
#   'Ireland',
#   'Czechoslovakia',
#   'Denmark',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'Burkina Faso',
#   'Gabon'],
#  'Benzene': ['World'],
#  'Bicycles': ['World'],
#  'Biogas': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Costa Rica',
#   'United Arab Emirates',
#   'Japan',
#   'Slovakia',
#   'Kenya',
#   'Cuba',
#   'Kazakhstan',
#   'Puerto Rico',
#   'Republic of North Macedonia',
#   'Serbia',
#   'Norway',
#   'Czechia',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'Guadeloupe',
#   'France',
#   'Mexico',
#   'Ukraine',
#   'Egypt',
#   'Poland',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'Chinese Taipei',
#   'Armenia',
#   'Honduras',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Spain',
#   'Iceland',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'United States of America',
#   'Jordan',
#   'Croatia',
#   'Sri Lanka',
#   'Réunion',
#   'Peru',
#   'Malaysia',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Germany',
#   'Martinique',
#   'Lebanon',
#   'Switzerland',
#   'Bosnia and Herzegovina',
#   'Guatemala',
#   'Brazil',
#   'Uruguay',
#   'Mauritius',
#   'El Salvador',
#   'Qatar',
#   'Argentina',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Faroe Islands',
#   'Türkiye',
#   'Australia',
#   'Viet Nam',
#   'Cyprus',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Ireland',
#   'Denmark',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'State of Palestine',
#   'Burkina Faso',
#   'Malta'],
#  'Bisphenol A': ['World'],
#  'CFLs': ['World'],
#  'Cable TV': ['United States'],
#  'Cadmium Refining': ['Austria',
#   'Bulgaria',
#   'India',
#   'China',
#   'Belgium',
#   'Germany',
#   'Finland',
#   'United Kingdom',
#   'Korea, Republic of',
#   'Congo (Kinshasa)',
#   'Macedonia',
#   'Japan',
#   'Algeria',
#   'World',
#   'Australia',
#   'Kazakhstan',
#   'Turkey',
#   'Netherlands',
#   'Korea, North',
#   'South Africa',
#   'Brazil',
#   'Spain',
#   'Norway',
#   'United States',
#   'Yugoslavia',
#   'Germany: Eastern states',
#   'Italy',
#   'Russia',
#   'Romania',
#   'Serbia and Montenegro',
#   'France',
#   'Thailand',
#   'Germany: Western states',
#   'Mexico',
#   'U.S.S.R.',
#   'Namibia',
#   'Argentina',
#   'Ukraine',
#   'Canada',
#   'Peru',
#   'Poland'],
#  'Canals': ['United States'],
#  'Cane Sugar Production': ['Madagascar',
#   'Myanmar',
#   'Philippines',
#   'Vietnam',
#   'India',
#   'China',
#   'Sudan',
#   'Costa Rica',
#   'Indonesia',
#   'Mozambique',
#   'Nicaragua',
#   'Japan',
#   'Barbados',
#   'Tanzania',
#   'Jamaica',
#   'Iran',
#   'Trinidad & Tobago',
#   'Kenya',
#   'Honduras',
#   'Cuba',
#   'Turkey',
#   'Guatemala',
#   'USA',
#   'Dominican Republic',
#   'South Africa',
#   'Zimbabwe',
#   'Spain',
#   'Ivory Coast',
#   'Pakistan',
#   'Thailand',
#   'Mexico',
#   'Morocco',
#   'Mauritius',
#   'El Salvador',
#   'Bangladesh',
#   'Malawi',
#   'Egypt',
#   'Taiwan',
#   'Ethiopia',
#   'Haiti',
#   'Panama',
#   'Swaziland'],
#  'Caprolactam': ['World'],
#  'Capture fisheries production': ['Samoa',
#   'Bermuda',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Isle of Man',
#   'Singapore',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Puerto Rico',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Virgin Islands (U.S.)',
#   'Eritrea',
#   'Comoros',
#   'Lao PDR',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'Gambia, The',
#   'France',
#   'Micronesia, Fed. Sts.',
#   'Mexico',
#   'Guinea-Bissau',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Haiti',
#   'Poland',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Vietnam',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'San Marino',
#   'Turks and Caicos Islands',
#   'Indonesia',
#   'Chile',
#   'Nauru',
#   'Northern Mariana Islands',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'Gibraltar',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Montenegro',
#   'St. Lucia',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'West Bank and Gaza',
#   'Azerbaijan',
#   'Sint Maarten (Dutch part)',
#   'Antigua and Barbuda',
#   'Jordan',
#   'New Caledonia',
#   'Afghanistan',
#   'Iran, Islamic Rep.',
#   'British Virgin Islands',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Lithuania',
#   'Myanmar',
#   'Aruba',
#   'Slovenia',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'St. Vincent and the Grenadines',
#   'Bahamas, The',
#   'Venezuela, RB',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'World',
#   'Jamaica',
#   'Switzerland',
#   'Tanzania',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Liechtenstein',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Hong Kong SAR, China',
#   'Brazil',
#   "Korea, Dem. People's Rep.",
#   'Kuwait',
#   'Guam',
#   'Sierra Leone',
#   'Uruguay',
#   'French Polynesia',
#   'St. Martin (French part)',
#   'Albania',
#   'Slovak Republic',
#   'Cayman Islands',
#   'North Macedonia',
#   'Kyrgyz Republic',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Mauritius',
#   'Qatar',
#   'Andorra',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'Yemen, Rep.',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'St. Kitts and Nevis',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Moldova',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Curacao',
#   'Saudi Arabia',
#   'Congo, Rep.',
#   'Faroe Islands',
#   'Australia',
#   'Monaco',
#   'Solomon Islands',
#   'Macao SAR, China',
#   'Cyprus',
#   'Rwanda',
#   'American Samoa',
#   'Italy',
#   'Greenland',
#   'Turkiye',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Korea, Rep.',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Congo, Dem. Rep.',
#   'Egypt, Arab Rep.',
#   'Malta',
#   'Tunisia',
#   'Gabon'],
#  'Carbon Capture & Sequestration': ['World'],
#  'Caustic Soda': ['United States of America',
#   'Japan',
#   'Israel',
#   'Mexico',
#   'Brazil',
#   'Algeria',
#   'India',
#   'China',
#   'South Korea',
#   'Canada',
#   'Argentina',
#   'Australia',
#   'Pakistan',
#   'Turkey',
#   'Egypt'],
#  'Cellphones': ['Bulgaria',
#   'India',
#   'Tajikistan',
#   'South Vietnam',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Kenya',
#   'Togo',
#   'Cuba',
#   'Syria',
#   'Uzbekistan',
#   'Kazakhstan',
#   'Papua New Guinea',
#   'Eritrea',
#   'Burma',
#   'Somalia',
#   'Liberia',
#   'Norway',
#   'Ivory Coast',
#   'Guyana',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'South Korea',
#   'Lesotho',
#   'Burundi',
#   'Bosnia-Herzegovina',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   'Poland',
#   'Vietnam',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'Yemen',
#   'Armenia',
#   'Czech Republic',
#   'Honduras',
#   'Georgia',
#   'Guinea',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'South Africa',
#   'Zimbabwe',
#   'Laos',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Russia',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Indochina',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Lithuania',
#   'Hong Kong',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   'Tanzania',
#   'World',
#   'Switzerland',
#   'South Yemen',
#   'Botswana',
#   'Gambia',
#   'Venezuela',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Dominican Republic',
#   'Kuwait',
#   'Brazil',
#   'Sierra Leone',
#   'Uruguay',
#   'Albania',
#   'Slovak Republic',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Mauritius',
#   'Equatorial Guinea',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Swaziland',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Moldova',
#   'Mozambique',
#   'Nicaragua',
#   'Macedonia',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Rwanda',
#   'Italy',
#   'Cameroon',
#   'Ireland',
#   'Czechoslovakia',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Israel',
#   'Morocco',
#   'Republic of the Congo',
#   'Estonia',
#   'Bangladesh',
#   'Burkina Faso',
#   'Tunisia',
#   'Gabon'],
#  'Cement production': ['World', 'United States'],
#  'Central heating': ['United States'],
#  'Coal Power': ['World'],
#  'Coal Production': ['Vietnam',
#   'Bulgaria',
#   'India',
#   'China',
#   'Germany',
#   'Hungary',
#   'Greece',
#   'New Zealand',
#   'United Kingdom',
#   'Indonesia',
#   'Mongolia',
#   'Japan',
#   'World',
#   'Russian Federation',
#   'Czech Republic',
#   'Australia',
#   'Kazakhstan',
#   'Turkey',
#   'Venezuela',
#   'Uzbekistan',
#   'Serbia',
#   'South Africa',
#   'Brazil',
#   'Zimbabwe',
#   'Spain',
#   'US',
#   'Pakistan',
#   'USSR',
#   'Colombia',
#   'Romania',
#   'Thailand',
#   'Mexico',
#   'South Korea',
#   'Ukraine',
#   'Canada',
#   'Poland'],
#  'Cobalt Mine Production': ['Madagascar',
#   'Democratic Republic of Congo',
#   'South Africa',
#   'Philippines',
#   'Morocco',
#   'World',
#   'China',
#   'New Caledonia',
#   'Russian Federation',
#   'Zambia',
#   'Australia',
#   'Cuba',
#   'Canada',
#   'Papua New Guinea'],
#  'Colour TV': ['United States'],
#  'Compressed air energy storage': ['Switzerland',
#   'United States',
#   'China',
#   'Germany',
#   'United Kingdom',
#   'Canada',
#   'Netherlands'],
#  'Computing Growth': ['World'],
#  'Concentrated Solar Power': ['World'],
#  'Copper Mining': ['Malaysia',
#   'Philippines',
#   'Vietnam',
#   'Bulgaria',
#   'Nepal',
#   'India',
#   'China',
#   'Germany',
#   'Zambia',
#   'Finland',
#   'United Kingdom',
#   'Korea, Republic of',
#   'Indonesia',
#   'Congo (Kinshasa)',
#   'Mozambique',
#   'Chile',
#   'Bolivia',
#   'Japan',
#   'Macedonia',
#   'Mongolia',
#   'Oman',
#   'Tanzania',
#   'Slovakia',
#   'Saudi Arabia',
#   'Armenia',
#   'Iran',
#   'World',
#   'Botswana',
#   'Australia',
#   'Georgia',
#   'Honduras',
#   'Cuba',
#   'Kazakhstan',
#   'Turkey',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Sweden',
#   'Korea, North',
#   'Dominican Republic',
#   'Serbia',
#   'South Africa',
#   'Cyprus',
#   'Brazil',
#   'Burma',
#   'Laos',
#   'Zimbabwe',
#   'Spain',
#   'Norway',
#   'United States',
#   'Yugoslavia',
#   'Pakistan',
#   'Albania',
#   'Colombia',
#   'Romania',
#   'Ecuador',
#   'Russia',
#   'Serbia and Montenegro',
#   'Portugal',
#   'France',
#   'Czechoslovakia',
#   'Mauritania',
#   'Mexico',
#   'U.S.S.R.',
#   'Morocco',
#   'Namibia',
#   'Argentina',
#   'Canada',
#   'Peru',
#   'Poland'],
#  'Copper Refining': ['Philippines',
#   'Austria',
#   'Bulgaria',
#   'Vietnam',
#   'India',
#   'China',
#   'Belgium',
#   'Germany',
#   'Hungary',
#   'Zambia',
#   'Finland',
#   'United Kingdom',
#   'Korea, Republic of',
#   'Indonesia',
#   'Congo (Kinshasa)',
#   'Chile',
#   'Mongolia',
#   'Japan',
#   'Oman',
#   'Slovakia',
#   'World',
#   'Iran',
#   'Czech Republic',
#   'Australia',
#   'Kazakhstan',
#   'Turkey',
#   'Uzbekistan',
#   'Sweden',
#   'Korea, North',
#   'Serbia',
#   'South Africa',
#   'Cyprus',
#   'Brazil',
#   'Burma',
#   'Laos',
#   'Zimbabwe',
#   'Spain',
#   'Norway',
#   'United States',
#   'Yugoslavia',
#   'Italy',
#   'Albania',
#   'Russia',
#   'Romania',
#   'Serbia and Montenegro',
#   'Portugal',
#   'France',
#   'Czechoslovakia',
#   'Thailand',
#   'Mexico',
#   'U.S.S.R.',
#   'Argentina',
#   'Ukraine',
#   'Canada',
#   'Egypt',
#   'Taiwan',
#   'Peru',
#   'Poland'],
#  'Crop harvester': ['Bulgaria',
#   'India',
#   'Tajikistan',
#   'South Vietnam',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Costa Rica',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Kenya',
#   'Cuba',
#   'Kazakhstan',
#   'Syria',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Eritrea',
#   'Burma',
#   'Norway',
#   'Ivory Coast',
#   'Guyana',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'South Korea',
#   'Lesotho',
#   'Burundi',
#   'Bosnia-Herzegovina',
#   'Ukraine',
#   'Egypt',
#   'Poland',
#   'Vietnam',
#   'Belgium',
#   'Indonesia',
#   'Chile',
#   'Yemen',
#   'Armenia',
#   'Czech Republic',
#   'Georgia',
#   'Guinea',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'South Africa',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Russia',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Jordan',
#   'Croatia',
#   'Uganda',
#   'Indochina',
#   'Sri Lanka',
#   'Ethiopia',
#   'Central African Republic',
#   'Madagascar',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   'Switzerland',
#   'South Yemen',
#   'Botswana',
#   'Gambia',
#   'Venezuela',
#   'Chad',
#   'Guatemala',
#   'Brazil',
#   'Sierra Leone',
#   'Uruguay',
#   'Albania',
#   'Slovak Republic',
#   'Iraq',
#   'El Salvador',
#   'Argentina',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Moldova',
#   'Macedonia',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Italy',
#   'Ireland',
#   'Czechoslovakia',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Israel',
#   'Morocco',
#   'Republic of the Congo',
#   'Estonia',
#   'Tunisia'],
#  'Crude Oil': ['Myanmar',
#   'Philippines',
#   'Austria',
#   'India',
#   'China',
#   'Democratic Republic of the Congo',
#   'UK',
#   'Germany',
#   'Hungary',
#   'New Zealand',
#   'Libya',
#   'Indonesia',
#   'Zaire',
#   'Chile',
#   'UAE',
#   'Bolivia',
#   'Japan',
#   'Oman',
#   'Algeria',
#   'World',
#   'Saudi Arabia',
#   'Iran',
#   'Trinidad & Tobago',
#   'Australia',
#   'Cuba',
#   'Syria',
#   'Turkey',
#   'Venezuela',
#   'Nigeria',
#   'Netherlands',
#   'Angola',
#   'USA',
#   'Bahrain',
#   'Brazil',
#   'Kuwait',
#   'Brunei',
#   'Norway',
#   'Yugoslavia',
#   'Ivory Coast',
#   'Italy',
#   'Pakistan',
#   'Russia',
#   'Colombia',
#   'Romania',
#   'Cameroon',
#   'Ecuador',
#   'Thailand',
#   'Israel',
#   'Mexico',
#   'Morocco',
#   'Republic of the Congo',
#   'Iraq',
#   'Qatar',
#   'West Germany',
#   'Argentina',
#   'Canada',
#   'Tunisia',
#   'Taiwan',
#   'Peru',
#   'Egypt',
#   'Gabon',
#   'Poland'],
#  'Cyclohexane': ['World'],
#  'DTP1 Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Eritrea',
#   'Comoros',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Micronesia (Federated States of)',
#   'San Marino',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Yemen',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Jamaica',
#   'Switzerland',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Sierra Leone',
#   'Uruguay',
#   'Bahamas',
#   'Albania',
#   'Namibia',
#   'Congo',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Iraq',
#   'Mauritius',
#   'Andorra',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Australia',
#   'Monaco',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Cyprus',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'State of Palestine',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Malta',
#   'Tunisia',
#   'Cook Islands',
#   'Gabon'],
#  'DTP3 Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Eritrea',
#   'Comoros',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Micronesia (Federated States of)',
#   'San Marino',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Yemen',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Jamaica',
#   'Switzerland',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Sierra Leone',
#   'Uruguay',
#   'Bahamas',
#   'Albania',
#   'Namibia',
#   'Congo',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Iraq',
#   'Mauritius',
#   'Andorra',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Australia',
#   'Monaco',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Cyprus',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'State of Palestine',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Malta',
#   'Tunisia',
#   'Cook Islands',
#   'Gabon'],
#  'Desalination capacity': ['World'],
#  'Dishwashers': ['United States'],
#  'Disk brakes': ['United States'],
#  'Ebook reader': ['United States'],
#  'Electric Bicycles': ['World', 'China'],
#  'Electric Range': ['United States'],
#  'Electricity': ['Bulgaria',
#   'India',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Trinidad & Tobago',
#   'Kazakhstan',
#   'Uzbekistan',
#   'Norway',
#   'Pakistan',
#   'Romania',
#   'France',
#   'Mexico',
#   'South Korea',
#   'Ukraine',
#   'Egypt',
#   'Poland',
#   'Vietnam',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'China Hong Kong SAR',
#   'Czech Republic',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Spain',
#   'Iceland',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Croatia',
#   'Sri Lanka',
#   'Peru',
#   'Malaysia',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Germany',
#   'Oman',
#   'World',
#   'Switzerland',
#   'Russian Federation',
#   'Venezuela',
#   'Brazil',
#   'Kuwait',
#   'US',
#   'North Macedonia',
#   'Iraq',
#   'Qatar',
#   'Argentina',
#   'Canada',
#   'Taiwan',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Cyprus',
#   'Italy',
#   'Ireland',
#   'Denmark',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'Bangladesh'],
#  'Electro-chemical capacitor': ['South Korea',
#   'China',
#   'United States',
#   'Spain',
#   'Italy',
#   'Ireland'],
#  'Electronic ignition': ['United States'],
#  'Ethanolamine': ['World'],
#  'Ethyl Alcohol': ['World'],
#  'Ethylene': ['World'],
#  'Ethylene Glycol': ['World'],
#  'FCC-Refineries': ['World', 'US'],
#  'Flow battery storage': ['Austria',
#   'Slovenia',
#   'India',
#   'China',
#   'Germany',
#   'New Zealand',
#   'United Kingdom',
#   'Indonesia',
#   'Japan',
#   'Switzerland',
#   'Czech Republic',
#   'Australia',
#   'Kazakhstan',
#   'Netherlands',
#   'South Africa',
#   'United States',
#   'Italy',
#   'French Polynesia',
#   'Russia',
#   'Portugal',
#   'Antigua and Barbuda',
#   'Denmark',
#   'Israel',
#   'South Korea',
#   'Canada'],
#  'Flush toilet': ['United States'],
#  'Flywheel battery storage': ['Mexico',
#   'Antarctica',
#   'South Korea',
#   'United States',
#   'Spain',
#   'Germany',
#   'Czech Republic',
#   'Netherlands',
#   'Kenya',
#   'Australia',
#   'United Kingdom',
#   'Canada',
#   'Romania',
#   'Ireland',
#   'France'],
#  'Formaldehyde': ['World'],
#  'Freezer': ['United States'],
#  'Geothermal Energy': ['Philippines',
#   'Austria',
#   'China',
#   'Germany',
#   'Hungary',
#   'New Zealand',
#   'Costa Rica',
#   'Indonesia',
#   'Nicaragua',
#   'Chile',
#   'Japan',
#   'Chinese Taipei',
#   'Russian Federation',
#   'Türkiye',
#   'Kenya',
#   'Australia',
#   'Honduras',
#   'Guatemala',
#   'Iceland',
#   'Italy',
#   'Romania',
#   'Guadeloupe',
#   'Portugal',
#   'France',
#   'Thailand',
#   'United States of America',
#   'Mexico',
#   'El Salvador',
#   'Argentina',
#   'Croatia',
#   'Ethiopia'],
#  'Gold production': ['Japan',
#   'South Africa',
#   'Zimbabwe',
#   'World',
#   'South Korea',
#   'China',
#   'India',
#   'United States',
#   'Phillipines',
#   'Australia',
#   'New Zealand',
#   'Fiji',
#   'Ghana',
#   'Papua New Guinea',
#   'Zaire',
#   'Korea'],
#  'Graphite Mine Production': ['Madagascar',
#   'Mexico',
#   'Brazil',
#   'World',
#   'India',
#   'China',
#   'Norway',
#   'Russian Federation',
#   'Turkey',
#   'Ukraine',
#   'Canada',
#   'Sri Lanka',
#   'Mozambique'],
#  'Ground Source Heat Pumps': ['World'],
#  'HEPB3 Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Eritrea',
#   'Comoros',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Micronesia (Federated States of)',
#   'San Marino',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Yemen',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Jamaica',
#   'Switzerland',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Sierra Leone',
#   'Uruguay',
#   'Bahamas',
#   'Albania',
#   'Namibia',
#   'Congo',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Iraq',
#   'Mauritius',
#   'Andorra',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Australia',
#   'Monaco',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Cyprus',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'State of Palestine',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Malta',
#   'Tunisia',
#   'Cook Islands',
#   'Gabon'],
#  'HEPBB Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Turkmenistan',
#   'Sao Tome and Principe',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Serbia',
#   'Guyana',
#   'Fiji',
#   'Romania',
#   'Mexico',
#   'Saint Lucia',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Micronesia (Federated States of)',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Djibouti',
#   'Kiribati',
#   'United States',
#   'Senegal',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Afghanistan',
#   'Croatia',
#   'Benin',
#   'Peru',
#   'Malaysia',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Latvia',
#   'Palau',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Gambia',
#   'Guatemala',
#   'Bahrain',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Albania',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Qatar',
#   'Andorra',
#   'Argentina',
#   'Panama',
#   'Philippines',
#   'China',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Cabo Verde',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Republic of Korea',
#   'Marshall Islands',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'State of Palestine',
#   'Timor-Leste',
#   'Tunisia',
#   'Cook Islands'],
#  'HIB3 Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Eritrea',
#   'Comoros',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Micronesia (Federated States of)',
#   'San Marino',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Yemen',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Jamaica',
#   'Switzerland',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Sierra Leone',
#   'Uruguay',
#   'Bahamas',
#   'Albania',
#   'Namibia',
#   'Congo',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Iraq',
#   'Mauritius',
#   'Andorra',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Australia',
#   'Monaco',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Cyprus',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'State of Palestine',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Malta',
#   'Tunisia',
#   'Cook Islands',
#   'Gabon'],
#  'Heat thermal battery storage': ['South Africa',
#   'Morocco',
#   'India',
#   'China',
#   'United States',
#   'Spain',
#   'Germany',
#   'Australia',
#   'United Kingdom',
#   'France',
#   'Chile'],
#  'Herbicide-Tolerant Corn': ['United States'],
#  'Herbicide-Tolerant Cotton': ['United States'],
#  'Herbicide-Tolerant Soybeans': ['United States'],
#  'High-speed rail': ['World'],
#  'Home air conditioning': ['United States'],
#  'Home computers': ['United States'],
#  'Household Internet access': ['United States'],
#  'Households with only mobile phones (no landlines)': ['United States'],
#  'Hydrochloric Acid': ['United States of America',
#   'Japan',
#   'South Africa',
#   'Algeria',
#   'South Korea',
#   'China',
#   'Iran',
#   'India',
#   'Phillipines',
#   'Australia',
#   'Canada',
#   'Egypt',
#   'Indonesia'],
#  'Hydroelectricity': ['Bulgaria',
#   'India',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Trinidad & Tobago',
#   'Kazakhstan',
#   'Uzbekistan',
#   'Norway',
#   'Pakistan',
#   'Romania',
#   'France',
#   'Mexico',
#   'South Korea',
#   'Ukraine',
#   'Egypt',
#   'Poland',
#   'Vietnam',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'China Hong Kong SAR',
#   'Czech Republic',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Spain',
#   'Iceland',
#   'USSR',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Croatia',
#   'Sri Lanka',
#   'Peru',
#   'Malaysia',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Germany',
#   'Oman',
#   'World',
#   'Switzerland',
#   'Russian Federation',
#   'Venezuela',
#   'Brazil',
#   'Kuwait',
#   'US',
#   'North Macedonia',
#   'Iraq',
#   'Qatar',
#   'Argentina',
#   'Canada',
#   'Taiwan',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Cyprus',
#   'Italy',
#   'Ireland',
#   'Denmark',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'Bangladesh'],
#  'Hydrofluoric Acid': ['World'],
#  'Hydrogen storage': ['Denmark',
#   'Germany',
#   'Italy',
#   'Canada',
#   'France',
#   'Thailand'],
#  'IPV1 Vaccine': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tajikistan',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'Seychelles',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Eswatini',
#   'Sao Tome and Principe',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Eritrea',
#   'Comoros',
#   'Serbia',
#   'Liberia',
#   'Somalia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Maldives',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Micronesia (Federated States of)',
#   'San Marino',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Yemen',
#   'Armenia',
#   'Georgia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'Djibouti',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   "Cote d'Ivoire",
#   'Jamaica',
#   'Switzerland',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Bahrain',
#   'Dominican Republic',
#   'Brazil',
#   'Kuwait',
#   'Sierra Leone',
#   'Uruguay',
#   'Bahamas',
#   'Albania',
#   'Namibia',
#   'Congo',
#   'El Salvador',
#   'Equatorial Guinea',
#   'Iraq',
#   'Mauritius',
#   'Andorra',
#   'Qatar',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Australia',
#   'Monaco',
#   'Solomon Islands',
#   'Viet Nam',
#   'Niue',
#   'Cyprus',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Cameroon',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'South Sudan',
#   'Bangladesh',
#   'State of Palestine',
#   'Timor-Leste',
#   'Burkina Faso',
#   'Malta',
#   'Tunisia',
#   'Cook Islands',
#   'Gabon'],
#  'Insect-Resistant Corn': ['United States'],
#  'Insect-Resistant Cotton': ['United States'],
#  'Internet Backbone Bandwidth': ['World'],
#  'Internet Traffic': ['World'],
#  'Iron': ['United States'],
#  'Iron ore': ['Malaysia',
#   'Vietnam',
#   'Austria',
#   'Bulgaria',
#   'India',
#   'China',
#   'Germany',
#   'Greece',
#   'New Zealand',
#   'United Kingdom',
#   'Korea, Republic of',
#   'Indonesia',
#   'Chile',
#   'Bolivia',
#   'Japan',
#   'Macedonia',
#   'Mongolia',
#   'Algeria',
#   'Slovakia',
#   'Tanzania',
#   'Iran',
#   'World',
#   'Czech Republic',
#   'Kenya',
#   'Australia',
#   'Bosnia and Herzegovina',
#   'Cuba',
#   'Kazakhstan',
#   'Turkey',
#   'Venezuela',
#   'Nigeria',
#   'Guatemala',
#   'Sweden',
#   'Korea, North',
#   'South Africa',
#   'Brazil',
#   'Zimbabwe',
#   'Liberia',
#   'Spain',
#   'Norway',
#   'United States',
#   'Yugoslavia',
#   'Pakistan',
#   'Albania',
#   'Colombia',
#   'Romania',
#   'Russia',
#   'Serbia and Montenegro',
#   'Portugal',
#   'France',
#   'Czechoslovakia',
#   'Germany: Western states',
#   'Azerbaijan',
#   'Mauritania',
#   'Thailand',
#   'Mexico',
#   'U.S.S.R.',
#   'Morocco',
#   'Tunisia',
#   'Argentina',
#   'Uganda',
#   'Ukraine',
#   'Canada',
#   'Egypt',
#   'Peru',
#   'Poland'],
#  'Jet Aircraft': ['Boeing'],
#  'Latent heat storage': ['United States',
#   'United Kingdom',
#   'Ireland',
#   'Canada'],
#  'Laundry Dryers': ['US', 'World'],
#  'Lead mine production': ['Vietnam',
#   'Austria',
#   'Bulgaria',
#   'Slovenia',
#   'India',
#   'China',
#   'Tajikistan',
#   'Germany',
#   'Zambia',
#   'Greece',
#   'Finland',
#   'United Kingdom',
#   'Korea, Republic of',
#   'Chile',
#   'Bolivia',
#   'Japan',
#   'Macedonia',
#   'Algeria',
#   'Slovakia',
#   'Saudi Arabia',
#   'Iran',
#   'World',
#   'Czech Republic',
#   'Kenya',
#   'Australia',
#   'Bosnia and Herzegovina',
#   'Georgia',
#   'Honduras',
#   'Kazakhstan',
#   'Turkey',
#   'Uzbekistan',
#   'Nigeria',
#   'Guatemala',
#   'Sweden',
#   'Korea, North',
#   'Serbia',
#   'South Africa',
#   'Brazil',
#   'Burma',
#   'Spain',
#   'Norway',
#   'United States',
#   'Yugoslavia',
#   'Italy',
#   'Greenland',
#   'Russia',
#   'Colombia',
#   'Romania',
#   'Ecuador',
#   'Serbia and Montenegro',
#   'Ireland',
#   'France',
#   'Czechoslovakia',
#   'Germany: Western states',
#   'Thailand',
#   'Mexico',
#   'U.S.S.R.',
#   'Morocco',
#   'Namibia',
#   'Argentina',
#   'Canada',
#   'Tunisia',
#   'Peru',
#   'Poland'],
#  'Lead-acid battery storage': ['Madagascar',
#   'Japan',
#   'South Africa',
#   'Brazil',
#   'Antarctica',
#   'India',
#   'South Korea',
#   'Spain',
#   'United States',
#   'Germany',
#   'Cape Verde',
#   'Kenya',
#   'Australia',
#   'New Zealand',
#   'United Kingdom',
#   'Vanuatu',
#   'Taiwan',
#   'Ireland'],
#  'Liquefied natural gas': ['United States'],
#  'Liquid Biofuels': ['United States of America',
#   'Denmark',
#   'Austria',
#   'Brazil',
#   'Sweden',
#   'Slovenia',
#   'New Caledonia',
#   'Belgium',
#   'Republic of Korea',
#   'Germany',
#   'Spain',
#   'Türkiye',
#   'Italy',
#   'Solomon Islands',
#   'Vanuatu',
#   'Netherlands',
#   'France',
#   'Poland'],
#  'Lithium Mine Production': ['Brazil',
#   'Zimbabwe',
#   'World',
#   'China',
#   'Argentina',
#   'Australia',
#   'US',
#   'Portugal',
#   'Chile'],
#  'Lithium-ion battery storage': ['Hong Kong',
#   'Niger',
#   'Philippines',
#   'India',
#   'China',
#   'Burkina-Faso',
#   'Martinique',
#   'Hungary',
#   'Germany',
#   'New Zealand',
#   'Finland',
#   'United Kingdom',
#   'Chile',
#   'Bolivia',
#   'Japan',
#   'Switzerland',
#   'Saudi Arabia',
#   'Faroe Islands',
# ...
#  'Shale production': ['United States'],
#  'Shipping container port infrastructure': ['United States'],
#  'Shotgun Sanger DNA Sequencing': ['World'],
#  'Silver': ['Phillipine',
#   'South Africa',
#   'Myanmar',
#   'Japan',
#   'Namibia',
#   'South Korea',
#   'China',
#   'New Zealand',
#   'Australia',
#   'Indonesia',
#   'Zaire',
#   'Korea'],
#  'Smartphone usage': ['United States'],
#  'Social media usage': ['United States'],
#  'Sodium': ['World'],
#  'Sodium Chlorate': ['World'],
#  'Sodium-based battery storage': ['Japan',
#   'South Korea',
#   'United States',
#   'China',
#   'Equatorial Guinea',
#   'Martinique',
#   'Germany',
#   'Italy',
#   'French Guiana',
#   'Australia',
#   'United Kingdom',
#   'Greece',
#   'Maldives',
#   'Canada',
#   'France',
#   'United Arab Emirates'],
#  'Solar Photovoltaic': ['Samoa',
#   'Republic of Moldova',
#   'Bulgaria',
#   'India',
#   'Tuvalu',
#   'Belarus',
#   'Hungary',
#   'Mayotte',
#   'French Guiana',
#   'Greece',
#   'Seychelles',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Japan',
#   'United States Virgin Islands',
#   'Slovakia',
#   'Eswatini',
#   'Kenya',
#   'Brunei Darussalam',
#   'Cuba',
#   'Kazakhstan',
#   'Puerto Rico',
#   'Togo',
#   'Uzbekistan',
#   'Papua New Guinea',
#   'Republic of North Macedonia',
#   'Serbia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'Guadeloupe',
#   'France',
#   'Mexico',
#   'Saint Lucia',
#   'Lesotho',
#   'Burundi',
#   'Ukraine',
#   'Egypt',
#   'Saint Martin (French Part)',
#   'Haiti',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Venezuela (Bolivarian Republic of)',
#   'Tonga',
#   'Niger',
#   'Nepal',
#   'Belgium',
#   'Luxembourg',
#   'Micronesia (Federated States of)',
#   'Turks and Caicos Islands',
#   'Indonesia',
#   'Saint Vincent and the Grenadines',
#   'Chile',
#   'Nauru',
#   'Chinese Taipei',
#   'Armenia',
#   'Honduras',
#   'Guinea',
#   'Nigeria',
#   'Saint Kitts and Nevis',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'South Africa',
#   'Kiribati',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'Montenegro',
#   'Syrian Arab Republic',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'United States of America',
#   'Antigua and Barbuda',
#   "Democratic People's Republic of Korea",
#   'Jordan',
#   'New Caledonia',
#   'Afghanistan',
#   'British Virgin Islands',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Sri Lanka',
#   'Réunion',
#   'Peru',
#   'Malaysia',
#   'Madagascar',
#   'Iran (Islamic Republic of)',
#   'Lithuania',
#   'Myanmar',
#   'Aruba',
#   'Slovenia',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Martinique',
#   'Zambia',
#   'Palau',
#   'Lebanon',
#   'Curaçao',
#   'Mongolia',
#   'Oman',
#   'Bonaire, Sint Eustatius and Saba',
#   'Jamaica',
#   'Switzerland',
#   'Russian Federation',
#   'Botswana',
#   'Bosnia and Herzegovina',
#   'Gambia',
#   'Chad',
#   'Guatemala',
#   'Bahrain',
#   'Dominican Republic',
#   'Tokelau',
#   'Brazil',
#   'Kuwait',
#   'Guam',
#   'Sierra Leone',
#   'Uruguay',
#   'French Polynesia',
#   'Bahamas',
#   'Albania',
#   'Cayman Islands',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Mauritius',
#   'Qatar',
#   'Andorra',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Anguilla',
#   'Panama',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Belize',
#   'Vanuatu',
#   'Grenada',
#   'Mozambique',
#   'Cabo Verde',
#   'Nicaragua',
#   'Barbados',
#   'Suriname',
#   'Saudi Arabia',
#   'Faroe Islands',
#   'Türkiye',
#   'Australia',
#   'Solomon Islands',
#   'Montserrat',
#   'Viet Nam',
#   'Kosovo',
#   'Niue',
#   'Cyprus',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'American Samoa',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Ireland',
#   'Marshall Islands',
#   'Trinidad and Tobago',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Dominica',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'State of Palestine',
#   'Bangladesh',
#   'Burkina Faso',
#   'Saint Barthélemy',
#   'Malta',
#   'Tunisia',
#   'Cook Islands'],
#  'Solar Thermal Energy': ['India',
#   'China',
#   'Germany',
#   'Chile',
#   'United Arab Emirates',
#   'Algeria',
#   'Saudi Arabia',
#   'Türkiye',
#   'Australia',
#   'South Africa',
#   'Kuwait',
#   'Republic of Korea',
#   'Spain',
#   'Italy',
#   'Romania',
#   'France',
#   'Thailand',
#   'United States of America',
#   'Israel',
#   'Mexico',
#   'Morocco',
#   'Egypt'],
#  'Solid Biofuels': ['Samoa',
#   'Bulgaria',
#   'India',
#   'Belarus',
#   'Hungary',
#   'French Guiana',
#   'Greece',
#   'Costa Rica',
#   'Singapore',
#   'Japan',
#   'Slovakia',
#   'Eswatini',
#   'Kenya',
#   'Cuba',
#   'Puerto Rico',
#   'Republic of North Macedonia',
#   'Serbia',
#   'Norway',
#   'Czechia',
#   'Guyana',
#   'Fiji',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Pakistan',
#   'Romania',
#   'Guadeloupe',
#   'France',
#   'Mexico',
#   'Ukraine',
#   'Egypt',
#   "Lao People's Democratic Republic",
#   'Poland',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'Chinese Taipei',
#   'Honduras',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Zimbabwe',
#   'Spain',
#   'Senegal',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'United States of America',
#   'Croatia',
#   'Uganda',
#   'Sri Lanka',
#   'Réunion',
#   'Peru',
#   'Ethiopia',
#   'Malaysia',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Martinique',
#   'Zambia',
#   'Jamaica',
#   'Russian Federation',
#   'Bosnia and Herzegovina',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Dominican Republic',
#   'Brazil',
#   'Sierra Leone',
#   'Uruguay',
#   'Namibia',
#   'Congo',
#   'El Salvador',
#   'Mauritius',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Belize',
#   'Mozambique',
#   'Nicaragua',
#   'Türkiye',
#   'Australia',
#   'Viet Nam',
#   'Rwanda',
#   'United Republic of Tanzania',
#   'Republic of Korea',
#   'Italy',
#   'Bolivia (Plurinational State of)',
#   'Ireland',
#   'Trinidad and Tobago',
#   'Denmark',
#   'Cambodia',
#   'Estonia'],
#  'Space Launches': ['Bulgaria',
#   'India',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Slovakia',
#   'Kenya',
#   'Kazakhstan',
#   'Papua New Guinea',
#   'Norway',
#   'Czechia',
#   'Pakistan',
#   'Romania',
#   'Ghana',
#   'France',
#   'Mexico',
#   'South Korea',
#   'Ukraine',
#   'Egypt',
#   'Poland',
#   'Vietnam',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'Intelsat',
#   'Armenia',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Laos',
#   'Spain',
#   'United States',
#   'Russia',
#   'Colombia',
#   'Bhutan',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Jordan',
#   'European Union',
#   'Sri Lanka',
#   'Peru',
#   'Ethiopia',
#   'Malaysia',
#   'Lithuania',
#   'Slovenia',
#   'Latvia',
#   'Germany',
#   'Mongolia',
#   'World',
#   'Switzerland',
#   'Venezuela',
#   'Guatemala',
#   'Angola',
#   'Brazil',
#   'Uruguay',
#   'North Korea',
#   'Mauritius',
#   'Qatar',
#   'Argentina',
#   'Canada',
#   'Taiwan',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Moldova',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Monaco',
#   'Australia',
#   'Turkey',
#   'Rwanda',
#   'Italy',
#   'Denmark',
#   'Israel',
#   'Morocco',
#   'Estonia',
#   'Bangladesh',
#   'Tunisia'],
#  'Stationary Steam Engines': ['World'],
#  'Steam Locomotives': ['World'],
#  'Steam ships': ['Austria',
#   'Belgium',
#   'Germany',
#   'Hungary',
#   'Greece',
#   'Finland',
#   'United Kingdom',
#   'Chile',
#   'Cuba',
#   'Netherlands',
#   'Sweden',
#   'Spain',
#   'Norway',
#   'Italy',
#   'Russia',
#   'Ireland',
#   'France',
#   'Denmark',
#   'Mexico',
#   'Canada'],
#  'Stove': ['United States'],
#  'Styrene': ['World'],
#  'Submarine Cables': ['World'],
#  'Sulphuric Acid': ['Austria',
#   'Bulgaria',
#   'India',
#   'China',
#   'Belgium',
#   'Germany',
#   'Hungary',
#   'Zambia',
#   'Greece',
#   'Finland',
#   'United Kingdom',
#   'Indonesia',
#   'Zaire',
#   'Chile',
#   'Japan',
#   'Algeria',
#   'Switzerland',
#   'Iran',
#   'Australia',
#   'Cuba',
#   'Turkey',
#   'Venezuela',
#   'Netherlands',
#   'Sweden',
#   'Brazil',
#   'Norway',
#   'Yugoslavia',
#   'Italy',
#   'Pakistan',
#   'Russia',
#   'Colombia',
#   'Romania',
#   'Ireland',
#   'Portugal',
#   'France',
#   'Thailand',
#   'Czechoslovakia',
#   'United States of America',
#   'Denmark',
#   'Israel',
#   'Mexico',
#   'Morocco',
#   'South Korea',
#   'West Germany',
#   'Phillipines',
#   'Argentina',
#   'Canada',
#   'Tunisia',
#   'Peru',
#   'Egypt',
#   'East Germany',
#   'Poland'],
#  'Synthetic Filaments': ['Malaysia',
#   'Austria',
#   'India',
#   'China',
#   'Belgium',
#   'Germany',
#   'Finland',
#   'United Kingdom',
#   'Indonesia',
#   'Japan',
#   'Switzerland',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Brazil',
#   'Spain',
#   'Norway',
#   'Yugoslavia',
#   'Italy',
#   'Pakistan',
#   'Russia',
#   'Colombia',
#   'Romania',
#   'France',
#   'Czechoslovakia',
#   'Thailand',
#   'United States of America',
#   'Mexico',
#   'South Korea',
#   'West Germany',
#   'Phillipines',
#   'Argentina',
#   'Canada',
#   'Egypt',
#   'East Germany',
#   'Poland'],
#  'Tablet': ['United States'],
#  'Telegraph Traffic': ['India',
#   'South Vietnam',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Singapore',
#   'Japan',
#   'Kenya',
#   'Togo',
#   'Syria',
#   'Serbia',
#   'Burma',
#   'Norway',
#   'Ivory Coast',
#   'Guyana',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'South Korea',
#   'Egypt',
#   'Poland',
#   'Vietnam',
#   'Belgium',
#   'Indonesia',
#   'Chile',
#   'Czech Republic',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'South Africa',
#   'Zimbabwe',
#   'Spain',
#   'United States',
#   'Russia',
#   'Colombia',
#   'Portugal',
#   'Thailand',
#   'Uganda',
#   'Indochina',
#   'Sri Lanka',
#   'Peru',
#   'Malaysia',
#   'Madagascar',
#   'Democratic Republic of the Congo',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Lebanon',
#   'Tanzania',
#   'Switzerland',
#   'Venezuela',
#   'Angola',
#   'Brazil',
#   'Uruguay',
#   'Iraq',
#   'El Salvador',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Taiwan',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Mozambique',
#   'Algeria',
#   'Australia',
#   'Turkey',
#   'Italy',
#   'Cameroon',
#   'Ireland',
#   'Czechoslovakia',
#   'Denmark',
#   'Israel',
#   'Morocco',
#   'Tunisia'],
#  'Telephones': ['Bulgaria',
#   'India',
#   'Tajikistan',
#   'South Vietnam',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Kenya',
#   'Togo',
#   'Cuba',
#   'Syria',
#   'Uzbekistan',
#   'Kazakhstan',
#   'Papua New Guinea',
#   'Eritrea',
#   'Burma',
#   'Somalia',
#   'Liberia',
#   'Norway',
#   'Ivory Coast',
#   'Guyana',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'South Korea',
#   'Lesotho',
#   'Burundi',
#   'Bosnia-Herzegovina',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   'Poland',
#   'Vietnam',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'Yemen',
#   'Armenia',
#   'Czech Republic',
#   'Honduras',
#   'Georgia',
#   'Guinea',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'South Africa',
#   'Zimbabwe',
#   'Laos',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Russia',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Indochina',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Lithuania',
#   'Hong Kong',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   'Tanzania',
#   'Switzerland',
#   'South Yemen',
#   'Botswana',
#   'Gambia',
#   'Venezuela',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Dominican Republic',
#   'Kuwait',
#   'Brazil',
#   'Sierra Leone',
#   'Uruguay',
#   'Albania',
#   'Slovak Republic',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Mauritius',
#   'Equatorial Guinea',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Taiwan',
#   'Panama',
#   'Swaziland',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Moldova',
#   'Mozambique',
#   'Nicaragua',
#   'Macedonia',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Rwanda',
#   'Italy',
#   'Cameroon',
#   'Ireland',
#   'Czechoslovakia',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Israel',
#   'Morocco',
#   'Republic of the Congo',
#   'Estonia',
#   'Bangladesh',
#   'Burkina Faso',
#   'Tunisia',
#   'Gabon'],
#  'Television': ['Bulgaria',
#   'India',
#   'Tajikistan',
#   'South Vietnam',
#   'Belarus',
#   'Hungary',
#   'Greece',
#   'United Kingdom',
#   'Costa Rica',
#   'Singapore',
#   'United Arab Emirates',
#   'Bolivia',
#   'Japan',
#   'Turkmenistan',
#   'Kenya',
#   'Togo',
#   'Cuba',
#   'Syria',
#   'Uzbekistan',
#   'Kazakhstan',
#   'Papua New Guinea',
#   'Eritrea',
#   'Burma',
#   'Somalia',
#   'Liberia',
#   'Norway',
#   'Ivory Coast',
#   'Guyana',
#   'Pakistan',
#   'Ghana',
#   'Romania',
#   'France',
#   'Mexico',
#   'Guinea-Bissau',
#   'South Korea',
#   'Lesotho',
#   'Burundi',
#   'Bosnia-Herzegovina',
#   'Ukraine',
#   'Egypt',
#   'Haiti',
#   'Poland',
#   'Vietnam',
#   'Niger',
#   'Nepal',
#   'Paraguay',
#   'Belgium',
#   'Luxembourg',
#   'Indonesia',
#   'Chile',
#   'Yemen',
#   'Armenia',
#   'Czech Republic',
#   'Honduras',
#   'Georgia',
#   'Guinea',
#   'Nigeria',
#   'Netherlands',
#   'Sweden',
#   'Mali',
#   'South Africa',
#   'Zimbabwe',
#   'Laos',
#   'Spain',
#   'Senegal',
#   'United States',
#   'Iceland',
#   'Russia',
#   'Colombia',
#   'Ecuador',
#   'Portugal',
#   'Thailand',
#   'Azerbaijan',
#   'Jordan',
#   'Afghanistan',
#   'Croatia',
#   'Uganda',
#   'Benin',
#   'Indochina',
#   'Sri Lanka',
#   'Ethiopia',
#   'Peru',
#   'Central African Republic',
#   'Malaysia',
#   'Madagascar',
#   'Lithuania',
#   'Hong Kong',
#   'Slovenia',
#   'Democratic Republic of the Congo',
#   'Latvia',
#   'Sudan',
#   'Germany',
#   'Zambia',
#   'Lebanon',
#   'Mongolia',
#   'Oman',
#   'Tanzania',
#   'Switzerland',
#   'South Yemen',
#   'Botswana',
#   'Gambia',
#   'Venezuela',
#   'Chad',
#   'Guatemala',
#   'Angola',
#   'Dominican Republic',
#   'Kuwait',
#   'Brazil',
#   'Sierra Leone',
#   'Uruguay',
#   'Albania',
#   'Slovak Republic',
#   'Namibia',
#   'Iraq',
#   'El Salvador',
#   'Mauritius',
#   'Equatorial Guinea',
#   'Argentina',
#   'Malawi',
#   'Canada',
#   'Taiwan',
#   'Panama',
#   'Swaziland',
#   'Philippines',
#   'Austria',
#   'China',
#   'New Zealand',
#   'Finland',
#   'Libya',
#   'Kyrgyzstan',
#   'Belize',
#   'Moldova',
#   'Mozambique',
#   'Nicaragua',
#   'Macedonia',
#   'Suriname',
#   'Algeria',
#   'Saudi Arabia',
#   'Iran',
#   'Australia',
#   'Turkey',
#   'Rwanda',
#   'Italy',
#   'Cameroon',
#   'Ireland',
#   'Czechoslovakia',
#   'Mauritania',
#   'Denmark',
#   'Cambodia',
#   'Israel',
#   'Morocco',
#   'Republic of the Congo',
#   'Estonia',
#   'Bangladesh',
#   'Burkina Faso',
#   'Tunisia',
#   'Gabon'],
#  'Tin': ['Malaysia',
#   'Bolivia',
#   'Nigeria',
#   'Brazil',
#   'China',
#   'Australia',
#   'Indonesia',
#   'Thailand'],
#  'Titanium Sponge': ['World'],
#  'Transistors per Microprocessor': ['World'],
#  'Urea': ['World'],
#  'Vacuums': ['United States'],
#  'Videocassette recorder': ['United States'],
#  'Vinyl Acetate': ['World'],
#  'Vinyl Chloride': ['World'],
#  'Washing Machines': ['US', 'World'],
#  'Water Heater': ['United States'],
#  'Wet flue gas desulfurization systems': ['World',
#   'United States',
#   'Japan',
#   'Germany'],
#  'YFV Vaccine': ['Venezuela (Bolivarian Republic of)',
#   'Niger',
#   'Paraguay',
#   'Democratic Republic of the Congo',
#   'Suriname',
#   "Cote d'Ivoire",
#   'Sao Tome and Principe',
#   'Kenya',
#   'Togo',
#   'Gambia',
#   'Guinea',
#   'Nigeria',
#   'Chad',
#   'Angola',
#   'Mali',
#   'Panama',
#   'Brazil',
#   'Liberia',
#   'Senegal',
#   'Sierra Leone',
#   'Guyana',
#   'Colombia',
#   'Bolivia (Plurinational State of)',
#   'Ecuador',
#   'Cameroon',
#   'Ghana',
#   'Trinidad and Tobago',
#   'Guinea-Bissau',
#   'Congo',
#   'Equatorial Guinea',
#   'Argentina',
#   'Burkina Faso',
#   'Benin',
#   'Peru',
#   'Gabon',
#   'Central African Republic'],
#  'Zinc': ['United States of America',
#   'Japan',
#   'Mexico',
#   'North Korea',
#   'Algeria',
#   'Brazil',
#   'India',
#   'China',
#   'South Korea',
#   'Zambia',
#   'Argentina',
#   'Australia',
#   'Canada',
#   'Peru',
#   'Zaire',
#   'Korea'],
#  'Zinc-based battery': ['Madagascar', 'United States', 'Indonesia']}

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict
# Out:
# {'Acrylic Fiber': 1,
#  'Acrylonitrile': 1,
#  'Air-Source Heat Pumps': 1,
#  'Amazon Prime users': 1,
#  'Aniline': 1,
#  'Automatic transmission': 1,
#  'Benzene': 1,
#  'Bicycles': 1,
#  'Bisphenol A': 1,
#  'CFLs': 1,
#  'Cable TV': 1,
#  'Canals': 1,
#  'Caprolactam': 1,
#  'Carbon Capture & Sequestration': 1,
#  'Central heating': 1,
#  'Coal Power': 1,
#  'Colour TV': 1,
#  'Computing Growth': 1,
#  'Concentrated Solar Power': 1,
#  'Cyclohexane': 1,
#  'Desalination capacity': 1,
#  'Dishwashers': 1,
#  'Disk brakes': 1,
#  'Ebook reader': 1,
#  'Electric Range': 1,
#  'Electronic ignition': 1,
#  'Ethanolamine': 1,
#  'Ethyl Alcohol': 1,
#  'Ethylene': 1,
#  'Ethylene Glycol': 1,
#  'Flush toilet': 1,
#  'Formaldehyde': 1,
#  'Freezer': 1,
#  'Ground Source Heat Pumps': 1,
#  'Herbicide-Tolerant Corn': 1,
#  'Herbicide-Tolerant Cotton': 1,
#  'Herbicide-Tolerant Soybeans': 1,
#  'High-speed rail': 1,
#  'Home air conditioning': 1,
#  'Home computers': 1,
#  'Household Internet access': 1,
#  'Households with only mobile phones (no landlines)': 1,
#  'Hydrofluoric Acid': 1,
#  'Insect-Resistant Corn': 1,
#  'Insect-Resistant Cotton': 1,
#  'Internet Backbone Bandwidth': 1,
#  'Internet Traffic': 1,
#  'Iron': 1,
#  'Jet Aircraft': 1,
#  'Liquefied natural gas': 1,
#  'Magnesium': 1,
#  'Magnetic Data Storage': 1,
#  'Maleic Anhydride': 1,
#  'Methanol': 1,
#  'Microcomputers': 1,
#  'Microprocessor Clock Speed': 1,
#  'Microwaves': 1,
#  'Motor Gasoline': 1,
#  'Motorcycles': 1,
#  'NatGas Power': 1,
#  'Natural gas pipeline': 1,
#  'Neoprene Rubber': 1,
#  'Nox pollution controls (boilers)': 1,
#  'Oil pipeline': 1,
#  'Paraxylene': 1,
#  'Pentaerythritol': 1,
#  'Phenol': 1,
#  'Phthalic Anhydride': 1,
#  'Podcasting': 1,
#  'Polyester Fiber': 1,
#  'Polyethylene HD': 1,
#  'Polyethylene LD': 1,
#  'Polystyrene': 1,
#  'Polyvinylchloride': 1,
#  'Power steering': 1,
#  'Primary Magnesium': 1,
#  'Processor Performance': 1,
#  'Public roads': 1,
#  'RTGS adoption': 1,
#  'Radial tires': 1,
#  'Random Access Memory': 1,
#  'Running water': 1,
#  'Shale production': 1,
#  'Shipping container port infrastructure': 1,
#  'Shotgun Sanger DNA Sequencing': 1,
#  'Smartphone usage': 1,
#  'Social media usage': 1,
#  'Sodium': 1,
#  'Sodium Chlorate': 1,
#  'Stationary Steam Engines': 1,
#  'Steam Locomotives': 1,
#  'Stove': 1,
#  'Styrene': 1,
#  'Submarine Cables': 1,
#  'Tablet': 1,
#  'Titanium Sponge': 1,
#  'Transistors per Microprocessor': 1,
#  'Urea': 1,
#  'Vacuums': 1,
#  'Videocassette recorder': 1,
#  'Vinyl Acetate': 1,
#  'Vinyl Chloride': 1,
#  'Water Heater': 1,
#  'Cement production': 2,
#  'Electric Bicycles': 2,
#  'FCC-Refineries': 2,
#  'Laundry Dryers': 2,
#  'Primary copper production': 2,
#  'Refrigerators': 2,
#  'Sand and gravel production (construction)': 2,
#  'Sand and gravel production (industrial)': 2,
#  'Washing Machines': 2,
#  'Zinc-based battery': 3,
#  'Latent heat storage': 4,
#  'Nickel-based battery': 4,
#  'Wet flue gas desulfurization systems': 4,
#  'Electro-chemical capacitor': 6,
#  'Hydrogen storage': 6,
#  'Compressed air energy storage': 7,
#  'Nuclear weapons': 8,
#  'Tin': 8,
#  'Lithium Mine Production': 9,
#  'Nitric Acid': 9,
#  'Rare Earth Mine Production': 9,
#  'Sensible heat storage': 10,
#  'Heat thermal battery storage': 11,
#  'Nickel production': 12,
#  'Silver': 12,
#  'Graphite Mine Production': 13,
#  'Hydrochloric Acid': 13,
#  'Cobalt Mine Production': 14,
#  'Caustic Soda': 15,
#  'Flywheel battery storage': 15,
#  'Gold production': 16,
#  'Sodium-based battery storage': 16,
#  'Zinc': 16,
#  'Lead-acid battery storage': 18,
#  'Liquid Biofuels': 18,
#  'On-Grid Offshore Wind Energy': 18,
#  'Marine Energy': 19,
#  'Steam ships': 20,
#  'Solar Thermal Energy': 22,
#  'All Biofuels': 24,
#  'Flow battery storage': 25,
#  'Geothermal Energy': 31,
#  'Coal Production': 36,
#  'YFV Vaccine': 36,
#  'Primary bauxite production': 37,
#  'Synthetic Filaments': 39,
#  'Cadmium Refining': 41,
#  'Cane Sugar Production': 42,
#  'Pumped hydro storage': 44,
#  'Off-Grid Onshore Wind Energy': 46,
#  'Lithium-ion battery storage': 47,
#  'Natural Gas Production': 51,
#  'Oil Production': 51,
#  'Sulphuric Acid': 52,
#  'Copper Refining': 58,
#  'Primary aluminum production': 58,
#  'Crude Oil': 62,
#  'Lead mine production': 64,
#  'Iron ore': 66,
#  'Copper Mining': 69,
#  'Oil Refining Capacity': 75,
#  'Telegraph Traffic': 79,
#  'Electricity': 80,
#  'Hydroelectricity': 81,
#  'Nuclear Energy': 81,
#  'Postal Traffic': 81,
#  'Renewable Power': 81,
#  'Space Launches': 94,
#  'Biogas': 95,
#  'Milk production': 100,
#  'Beer Production': 102,
#  'Solid Biofuels': 102,
#  'HEPBB Vaccine': 105,
#  'Raw steel production': 108,
#  'ROTAC Vaccine': 118,
#  'Crop harvester': 121,
#  'Salt production': 127,
#  'Railroad': 129,
#  'On-Grid Onshore Wind Energy': 133,
#  'PCV3 Vaccine': 153,
#  'Cellphones': 157,
#  'Passenger Cars': 157,
#  'Radio': 157,
#  'Telephones': 157,
#  'Television': 157,
#  'BCG Vaccine': 168,
#  'Potash Fertilizer': 171,
#  'RCV1 Vaccine': 173,
#  'Nitrogen Fertilizer': 175,
#  'Phosphate Fertilizer': 175,
#  'MCV2 Vaccine': 183,
#  'Solar Photovoltaic': 190,
#  'HEPB3 Vaccine': 191,
#  'HIB3 Vaccine': 193,
#  'DTP1 Vaccine': 195,
#  'DTP3 Vaccine': 195,
#  'IPV1 Vaccine': 195,
#  'MCV1 Vaccine': 195,
#  'POL3 Vaccine': 195,
#  'Aquaculture production': 196,
#  'Capture fisheries production': 216}

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)
# Out:
# Zinc-based battery
# Latent heat storage
# Nickel-based battery
# Wet flue gas desulfurization systems
# Electro-chemical capacitor
# Hydrogen storage
# Compressed air energy storage
# Nuclear weapons
# Tin
# Lithium Mine Production
# Nitric Acid
# Rare Earth Mine Production
# Sensible heat storage
# Heat thermal battery storage
# Nickel production
# Silver
# Graphite Mine Production
# Hydrochloric Acid
# Cobalt Mine Production
# Caustic Soda
# Flywheel battery storage
# Gold production
# Sodium-based battery storage
# Zinc
# Lead-acid battery storage
# Liquid Biofuels
# On-Grid Offshore Wind Energy
# Marine Energy
# Steam ships
# Solar Thermal Energy
# All Biofuels
# Flow battery storage
# Geothermal Energy
# Coal Production
# YFV Vaccine
# Primary bauxite production
# Synthetic Filaments
# Cadmium Refining
# Cane Sugar Production
# Pumped hydro storage
# Off-Grid Onshore Wind Energy
# Lithium-ion battery storage
# Natural Gas Production
# Oil Production
# Sulphuric Acid
# Copper Refining
# Primary aluminum production
# Crude Oil
# Lead mine production
# Iron ore
# Copper Mining
# Oil Refining Capacity
# Telegraph Traffic
# Electricity
# Hydroelectricity
# Nuclear Energy
# Postal Traffic
# Renewable Power
# Space Launches
# Biogas
# Milk production
# Beer Production
# Solid Biofuels
# HEPBB Vaccine
# Raw steel production
# ROTAC Vaccine
# Crop harvester
# Salt production
# Railroad
# On-Grid Onshore Wind Energy
# PCV3 Vaccine
# Cellphones
# Passenger Cars
# Radio
# Telephones
# Television
# BCG Vaccine
# Potash Fertilizer
# RCV1 Vaccine
# Nitrogen Fertilizer
# Phosphate Fertilizer
# MCV2 Vaccine
# Solar Photovoltaic
# HEPB3 Vaccine
# HIB3 Vaccine
# DTP1 Vaccine
# DTP3 Vaccine
# IPV1 Vaccine
# MCV1 Vaccine
# POL3 Vaccine
# Aquaculture production
# Capture fisheries production

# %%
cost_data = all_tech[all_tech['Metric']=='Price']
for x in list(set(cost_data['Technology Name'])):
    print(x)
# Out:
# Polystyrene
# Crude Oil
# Titanium Sponge
# Polyester Fiber
# Phthalic Anhydride
# Ethylene
# Phenol
# Neoprene Rubber
# Formaldehyde
# Primary copper production
# Cement production
# Motor Gasoline
# Shotgun Sanger DNA Sequencing
# Methanol
# Primary Magnesium
# Paraxylene
# Maleic Anhydride
# Hydrofluoric Acid
# Acrylonitrile
# Nickel production
# Ethanolamine
# Cyclohexane
# Vinyl Chloride
# Magnesium
# Vinyl Acetate
# Sodium Chlorate
# Urea
# Polyethylene HD
# Sand and gravel production (industrial)
# Sand and gravel production (construction)
# Ethyl Alcohol
# Bisphenol A
# Sodium
# Polyethylene LD
# Caprolactam
# Gold production
# Acrylic Fiber
# Ethylene Glycol
# Polyvinylchloride
# Pentaerythritol
# Benzene
# Aniline
# Styrene

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-1972'

# %%
time_span('Beer Production')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1750-2007'

# %%
time_span('Aquaculture production')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-2020'

# %%
timespan_dict = {}
for tech in tech_list:
    timespan_dict[tech] = time_span(tech)
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_19416/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)

# %%
timespan_dict
# Out:
# {'Acrylic Fiber': '1960-1972',
#  'Acrylonitrile': '1959-1972',
#  'Air-Source Heat Pumps': '2003-2022',
#  'All Biofuels': '1990-2021',
#  'Amazon Prime users': '2014-2018',
#  'Aniline': '1961-1972',
#  'Aquaculture production': '1960-2020',
#  'Automatic transmission': '1910-1984',
#  'BCG Vaccine': '1980-2021',
#  'Beer Production': '1750-2007',
#  'Benzene': '1952-1968',
#  'Bicycles': '1861-2007',
#  'Biogas': '2000-2021',
#  'Bisphenol A': '1959-1972',
#  'CFLs': '1990-2003',
#  'Cable TV': '1968-1997',
#  'Cadmium Refining': '1990-2012',
#  'Canals': '1794-1861',
#  'Cane Sugar Production': '1750-2010',
#  'Caprolactam': '1962-1972',
#  'Capture fisheries production': '1960-2020',
#  'Carbon Capture & Sequestration': '1971-2019',
#  'Caustic Soda': '1899-2008',
#  'Cellphones': '1975-2010',
#  'Cement production': '1900-2019',
#  'Central heating': '1900-1970',
#  'Coal Power': '1908-2000',
#  'Coal Production': '1981-2021',
#  'Cobalt Mine Production': '1995-2021',
#  'Colour TV': '1966-2005',
#  'Compressed air energy storage': '1991-2020',
#  'Computing Growth': '1900-1998',
#  'Concentrated Solar Power': '1985-2022',
#  'Copper Mining': '1990-2011',
#  'Copper Refining': '1990-2011',
#  'Crop harvester': '1961-2001',
#  'Crude Oil': '1860-2008',
#  'Cyclohexane': '1956-1972',
#  'DTP1 Vaccine': '1980-2021',
#  'DTP3 Vaccine': '1980-2021',
#  'Desalination capacity': '1960-2020',
#  'Dishwashers': '1922-2011',
#  'Disk brakes': '1966-1984',
#  'Ebook reader': '2009-2018',
#  'Electric Bicycles': '1997-2010',
#  'Electric Range': '1933-1986',
#  'Electricity': '1985-2021',
#  'Electro-chemical capacitor': '2012-2016',
#  'Electronic ignition': '1962-1984',
#  'Ethanolamine': '1955-1972',
#  'Ethyl Alcohol': '1958-1972',
#  'Ethylene': '1953-1968',
#  'Ethylene Glycol': '1960-1972',
#  'FCC-Refineries': '1940-2007',
#  'Flow battery storage': '2000-2018',
#  'Flush toilet': '1860-1989',
#  'Flywheel battery storage': '2006-2020',
#  'Formaldehyde': '1962-1972',
#  'Freezer': '1950-2011',
#  'Geothermal Energy': '2000-2021',
#  'Gold production': '1851-2018',
#  'Graphite Mine Production': '1995-2021',
#  'Ground Source Heat Pumps': '1995-2020',
#  'HEPB3 Vaccine': '1989-2021',
#  'HEPBB Vaccine': '2000-2021',
#  'HIB3 Vaccine': '1991-2021',
#  'Heat thermal battery storage': '2007-2017',
#  'Herbicide-Tolerant Corn': '1996-2022',
#  'Herbicide-Tolerant Cotton': '1996-2022',
#  'Herbicide-Tolerant Soybeans': '1996-2022',
#  'High-speed rail': '1964-2021',
#  'Home air conditioning': '1957-2011',
#  'Home computers': '1992-2016',
#  'Household Internet access': '1993-2016',
#  'Households with only mobile phones (no landlines)': '2013-2018',
#  'Hydrochloric Acid': '1929-2003',
#  'Hydroelectricity': '1965-2021',
#  'Hydrofluoric Acid': '1962-1972',
#  'Hydrogen storage': '2012-2017',
#  'IPV1 Vaccine': '2015-2021',
#  'Insect-Resistant Corn': '1996-2022',
#  'Insect-Resistant Cotton': '1996-2022',
#  'Internet Backbone Bandwidth': '1968-2004',
#  'Internet Traffic': '1984-2014',
#  'Iron': '1933-1970',
#  'Iron ore': '1990-2011',
#  'Jet Aircraft': '1958-2007',
#  'Latent heat storage': '1991-2017',
#  'Laundry Dryers': '1920-2006',
#  'Lead mine production': '1990-2012',
#  'Lead-acid battery storage': '1987-2020',
#  'Liquefied natural gas': '1985-2021',
#  'Liquid Biofuels': '2001-2021',
#  'Lithium Mine Production': '1995-2021',
#  'Lithium-ion battery storage': '2008-2021',
#  'MCV1 Vaccine': '1980-2021',
#  'MCV2 Vaccine': '2000-2021',
#  'Magnesium': '1954-1972',
#  'Magnetic Data Storage': '1952-2004',
#  'Maleic Anhydride': '1959-1972',
#  'Marine Energy': '2000-2021',
#  'Methanol': '1957-1972',
#  'Microcomputers': '1984-2016',
#  'Microprocessor Clock Speed': '1976-2016',
#  'Microwaves': '1975-2017',
#  'Milk production': '1889-2010',
#  'Motor Gasoline': '1946-1968',
#  'Motorcycles': '1900-2008',
#  'NatGas Power': '1903-2000',
#  'Natural Gas Production': '1970-2021',
#  'Natural gas pipeline': '1960-2021',
#  'Neoprene Rubber': '1960-1972',
#  'Nickel production': '1889-2018',
#  'Nickel-based battery': '2003-2015',
#  'Nitric Acid': '1929-2003',
#  'Nitrogen Fertilizer': '1961-2020',
#  'Nox pollution controls (boilers)': '1990-2005',
#  'Nuclear Energy': '1965-2021',
#  'Nuclear weapons': '1945-2010',
#  'Off-Grid Onshore Wind Energy': '2000-2021',
#  'Oil Production': '1965-2021',
#  'Oil Refining Capacity': '1965-2021',
#  'Oil pipeline': '2001-2021',
#  'On-Grid Offshore Wind Energy': '2000-2021',
#  'On-Grid Onshore Wind Energy': '2000-2021',
#  'PCV3 Vaccine': '2008-2021',
#  'POL3 Vaccine': '1980-2021',
#  'Paraxylene': '1957-1968',
#  'Passenger Cars': '1895-2005',
#  'Pentaerythritol': '1952-1972',
#  'Phenol': '1959-1972',
#  'Phosphate Fertilizer': '1961-2020',
#  'Phthalic Anhydride': '1955-1972',
#  'Podcasting': '2006-2015',
#  'Polyester Fiber': '1960-1972',
#  'Polyethylene HD': '1958-1972',
#  'Polyethylene LD': '1958-1972',
#  'Polystyrene': '1943-1968',
#  'Polyvinylchloride': '1946-1968',
#  'Postal Traffic': '1830-2000',
#  'Potash Fertilizer': '1961-2020',
#  'Power steering': '1951-1984',
#  'Primary Magnesium': '1929-1968',
#  'Primary aluminum production': '1990-2012',
#  'Primary bauxite production': '1990-2012',
#  'Primary copper production': '1900-2018',
#  'Processor Performance': '1971-2002',
#  'Public roads': '1900-2020',
#  'Pumped hydro storage': '1944-2020',
#  'RCV1 Vaccine': '1980-2021',
#  'ROTAC Vaccine': '2006-2021',
#  'RTGS adoption': '1970-2005',
#  'Radial tires': '1972-1984',
#  'Radio': '1815-2005',
#  'Railroad': '1825-2004',
#  'Random Access Memory': '1949-2004',
#  'Rare Earth Mine Production': '1995-2021',
#  'Raw steel production': '1990-2011',
#  'Refrigerators': '1918-2009',
#  'Renewable Power': '1965-2021',
#  'Running water': '1890-1989',
#  'Salt production': '1990-2012',
#  'Sand and gravel production (construction)': '1902-2019',
#  'Sand and gravel production (industrial)': '1902-2019',
#  'Sensible heat storage': '1982-2018',
#  'Shale production': '2007-2019',
#  'Shipping container port infrastructure': '1964-1986',
#  'Shotgun Sanger DNA Sequencing': '2001-2009',
#  'Silver': '1874-2008',
#  'Smartphone usage': '2011-2019',
#  'Social media usage': '2005-2019',
#  'Sodium': '1957-1972',
#  'Sodium Chlorate': '1958-1972',
#  'Sodium-based battery storage': '1999-2019',
#  'Solar Photovoltaic': '2000-2021',
#  'Solar Thermal Energy': '2000-2021',
#  'Solid Biofuels': '2000-2021',
#  'Space Launches': '1957-2022',
#  'Stationary Steam Engines': '1710-1920',
#  'Steam Locomotives': '1830-1940',
#  'Steam ships': '1814-1998',
#  'Stove': '1900-2011',
#  'Styrene': '1958-1972',
#  'Submarine Cables': '1989-2021',
#  'Sulphuric Acid': '1860-2003',
#  'Synthetic Filaments': '1910-2003',
#  'Tablet': '2010-2017',
#  'Telegraph Traffic': '1830-2000',
#  'Telephones': '1876-2003',
#  'Television': '1946-2018',
#  'Tin': '1910-2003',
#  'Titanium Sponge': '1950-1968',
#  'Transistors per Microprocessor': '1971-2003',
#  'Urea': '1961-1972',
#  'Vacuums': '1922-1978',
#  'Videocassette recorder': '1992-2011',
#  'Vinyl Acetate': '1960-1972',
#  'Vinyl Chloride': '1962-1972',
#  'Washing Machines': '1920-2008',
#  'Water Heater': '1933-1986',
#  'Wet flue gas desulfurization systems': '1972-1999',
#  'YFV Vaccine': '1997-2021',
#  'Zinc': '1860-2008',
#  'Zinc-based battery': '2013-2020'}

# %%
timespan_dict_lower = {}
for item in timespan_dict:
    timespan_dict_lower[item.lower()] = timespan_dict[item]
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air-source heat pumps': '2003-2022',
#  'all biofuels': '1990-2021',
#  'amazon prime users': '2014-2018',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'biogas': '2000-2021',
#  'bisphenol a': '1959-1972',
#  'cfls': '1990-2003',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1990-2012',
#  'canals': '1794-1861',
#  'cane sugar production': '1750-2010',
#  'caprolactam': '1962-1972',
#  'capture fisheries production': '1960-2020',
#  'carbon capture & sequestration': '1971-2019',
#  'caustic soda': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement production': '1900-2019',
#  'central heating': '1900-1970',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt mine production': '1995-2021',
#  'colour tv': '1966-2005',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'copper mining': '1990-2011',
#  'copper refining': '1990-2011',
#  'crop harvester': '1961-2001',
#  'crude oil': '1860-2008',
#  'cyclohexane': '1956-1972',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanolamine': '1955-1972',
#  'ethyl alcohol': '1958-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'fcc-refineries': '1940-2007',
#  'flow battery storage': '2000-2018',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold production': '1851-2018',
#  'graphite mine production': '1995-2021',
#  'ground source heat pumps': '1995-2020',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'hib3 vaccine': '1991-2021',
#  'heat thermal battery storage': '2007-2017',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'ipv1 vaccine': '2015-2021',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'iron': '1933-1970',
#  'iron ore': '1990-2011',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead mine production': '1990-2012',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1985-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1995-2021',
#  'lithium-ion battery storage': '2008-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwaves': '1975-2017',
#  'milk production': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'natgas power': '1903-2000',
#  'natural gas production': '1970-2021',
#  'natural gas pipeline': '1960-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel production': '1889-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'off-grid onshore wind energy': '2000-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'oil pipeline': '2001-2021',
#  'on-grid offshore wind energy': '2000-2021',
#  'on-grid onshore wind energy': '2000-2021',
#  'pcv3 vaccine': '2008-2021',
#  'pol3 vaccine': '1980-2021',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2005',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'polyester fiber': '1960-1972',
#  'polyethylene hd': '1958-1972',
#  'polyethylene ld': '1958-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'power steering': '1951-1984',
#  'primary magnesium': '1929-1968',
#  'primary aluminum production': '1990-2012',
#  'primary bauxite production': '1990-2012',
#  'primary copper production': '1900-2018',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'rcv1 vaccine': '1980-2021',
#  'rotac vaccine': '2006-2021',
#  'rtgs adoption': '1970-2005',
#  'radial tires': '1972-1984',
#  'radio': '1815-2005',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1995-2021',
#  'raw steel production': '1990-2011',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'running water': '1890-1989',
#  'salt production': '1990-2012',
#  'sand and gravel production (construction)': '1902-2019',
#  'sand and gravel production (industrial)': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shipping container port infrastructure': '1964-1986',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'space launches': '1957-2022',
#  'stationary steam engines': '1710-1920',
#  'steam locomotives': '1830-1940',
#  'steam ships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sulphuric acid': '1860-2003',
#  'synthetic filaments': '1910-2003',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'television': '1946-2018',
#  'tin': '1910-2003',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'urea': '1961-1972',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc-based battery': '2013-2020'}

# %%
timespan_dict_lower = dict(sorted(timespan_dict_lower.items(), key=lambda item: item[0])) 
timespan_dict_lower
# Out:
# {'acrylic fiber': '1960-1972',
#  'acrylonitrile': '1959-1972',
#  'air-source heat pumps': '2003-2022',
#  'all biofuels': '1990-2021',
#  'amazon prime users': '2014-2018',
#  'aniline': '1961-1972',
#  'aquaculture production': '1960-2020',
#  'automatic transmission': '1910-1984',
#  'bcg vaccine': '1980-2021',
#  'beer production': '1750-2007',
#  'benzene': '1952-1968',
#  'bicycles': '1861-2007',
#  'biogas': '2000-2021',
#  'bisphenol a': '1959-1972',
#  'cable tv': '1968-1997',
#  'cadmium refining': '1990-2012',
#  'canals': '1794-1861',
#  'cane sugar production': '1750-2010',
#  'caprolactam': '1962-1972',
#  'capture fisheries production': '1960-2020',
#  'carbon capture & sequestration': '1971-2019',
#  'caustic soda': '1899-2008',
#  'cellphones': '1975-2010',
#  'cement production': '1900-2019',
#  'central heating': '1900-1970',
#  'cfls': '1990-2003',
#  'coal power': '1908-2000',
#  'coal production': '1981-2021',
#  'cobalt mine production': '1995-2021',
#  'colour tv': '1966-2005',
#  'compressed air energy storage': '1991-2020',
#  'computing growth': '1900-1998',
#  'concentrated solar power': '1985-2022',
#  'copper mining': '1990-2011',
#  'copper refining': '1990-2011',
#  'crop harvester': '1961-2001',
#  'crude oil': '1860-2008',
#  'cyclohexane': '1956-1972',
#  'desalination capacity': '1960-2020',
#  'dishwashers': '1922-2011',
#  'disk brakes': '1966-1984',
#  'dtp1 vaccine': '1980-2021',
#  'dtp3 vaccine': '1980-2021',
#  'ebook reader': '2009-2018',
#  'electric bicycles': '1997-2010',
#  'electric range': '1933-1986',
#  'electricity': '1985-2021',
#  'electro-chemical capacitor': '2012-2016',
#  'electronic ignition': '1962-1984',
#  'ethanolamine': '1955-1972',
#  'ethyl alcohol': '1958-1972',
#  'ethylene': '1953-1968',
#  'ethylene glycol': '1960-1972',
#  'fcc-refineries': '1940-2007',
#  'flow battery storage': '2000-2018',
#  'flush toilet': '1860-1989',
#  'flywheel battery storage': '2006-2020',
#  'formaldehyde': '1962-1972',
#  'freezer': '1950-2011',
#  'geothermal energy': '2000-2021',
#  'gold production': '1851-2018',
#  'graphite mine production': '1995-2021',
#  'ground source heat pumps': '1995-2020',
#  'heat thermal battery storage': '2007-2017',
#  'hepb3 vaccine': '1989-2021',
#  'hepbb vaccine': '2000-2021',
#  'herbicide-tolerant corn': '1996-2022',
#  'herbicide-tolerant cotton': '1996-2022',
#  'herbicide-tolerant soybeans': '1996-2022',
#  'hib3 vaccine': '1991-2021',
#  'high-speed rail': '1964-2021',
#  'home air conditioning': '1957-2011',
#  'home computers': '1992-2016',
#  'household internet access': '1993-2016',
#  'households with only mobile phones (no landlines)': '2013-2018',
#  'hydrochloric acid': '1929-2003',
#  'hydroelectricity': '1965-2021',
#  'hydrofluoric acid': '1962-1972',
#  'hydrogen storage': '2012-2017',
#  'insect-resistant corn': '1996-2022',
#  'insect-resistant cotton': '1996-2022',
#  'internet backbone bandwidth': '1968-2004',
#  'internet traffic': '1984-2014',
#  'ipv1 vaccine': '2015-2021',
#  'iron': '1933-1970',
#  'iron ore': '1990-2011',
#  'jet aircraft': '1958-2007',
#  'latent heat storage': '1991-2017',
#  'laundry dryers': '1920-2006',
#  'lead mine production': '1990-2012',
#  'lead-acid battery storage': '1987-2020',
#  'liquefied natural gas': '1985-2021',
#  'liquid biofuels': '2001-2021',
#  'lithium mine production': '1995-2021',
#  'lithium-ion battery storage': '2008-2021',
#  'magnesium': '1954-1972',
#  'magnetic data storage': '1952-2004',
#  'maleic anhydride': '1959-1972',
#  'marine energy': '2000-2021',
#  'mcv1 vaccine': '1980-2021',
#  'mcv2 vaccine': '2000-2021',
#  'methanol': '1957-1972',
#  'microcomputers': '1984-2016',
#  'microprocessor clock speed': '1976-2016',
#  'microwaves': '1975-2017',
#  'milk production': '1889-2010',
#  'motor gasoline': '1946-1968',
#  'motorcycles': '1900-2008',
#  'natgas power': '1903-2000',
#  'natural gas pipeline': '1960-2021',
#  'natural gas production': '1970-2021',
#  'neoprene rubber': '1960-1972',
#  'nickel production': '1889-2018',
#  'nickel-based battery': '2003-2015',
#  'nitric acid': '1929-2003',
#  'nitrogen fertilizer': '1961-2020',
#  'nox pollution controls (boilers)': '1990-2005',
#  'nuclear energy': '1965-2021',
#  'nuclear weapons': '1945-2010',
#  'off-grid onshore wind energy': '2000-2021',
#  'oil pipeline': '2001-2021',
#  'oil production': '1965-2021',
#  'oil refining capacity': '1965-2021',
#  'on-grid offshore wind energy': '2000-2021',
#  'on-grid onshore wind energy': '2000-2021',
#  'paraxylene': '1957-1968',
#  'passenger cars': '1895-2005',
#  'pcv3 vaccine': '2008-2021',
#  'pentaerythritol': '1952-1972',
#  'phenol': '1959-1972',
#  'phosphate fertilizer': '1961-2020',
#  'phthalic anhydride': '1955-1972',
#  'podcasting': '2006-2015',
#  'pol3 vaccine': '1980-2021',
#  'polyester fiber': '1960-1972',
#  'polyethylene hd': '1958-1972',
#  'polyethylene ld': '1958-1972',
#  'polystyrene': '1943-1968',
#  'polyvinylchloride': '1946-1968',
#  'postal traffic': '1830-2000',
#  'potash fertilizer': '1961-2020',
#  'power steering': '1951-1984',
#  'primary aluminum production': '1990-2012',
#  'primary bauxite production': '1990-2012',
#  'primary copper production': '1900-2018',
#  'primary magnesium': '1929-1968',
#  'processor performance': '1971-2002',
#  'public roads': '1900-2020',
#  'pumped hydro storage': '1944-2020',
#  'radial tires': '1972-1984',
#  'radio': '1815-2005',
#  'railroad': '1825-2004',
#  'random access memory': '1949-2004',
#  'rare earth mine production': '1995-2021',
#  'raw steel production': '1990-2011',
#  'rcv1 vaccine': '1980-2021',
#  'refrigerators': '1918-2009',
#  'renewable power': '1965-2021',
#  'rotac vaccine': '2006-2021',
#  'rtgs adoption': '1970-2005',
#  'running water': '1890-1989',
#  'salt production': '1990-2012',
#  'sand and gravel production (construction)': '1902-2019',
#  'sand and gravel production (industrial)': '1902-2019',
#  'sensible heat storage': '1982-2018',
#  'shale production': '2007-2019',
#  'shipping container port infrastructure': '1964-1986',
#  'shotgun sanger dna sequencing': '2001-2009',
#  'silver': '1874-2008',
#  'smartphone usage': '2011-2019',
#  'social media usage': '2005-2019',
#  'sodium': '1957-1972',
#  'sodium chlorate': '1958-1972',
#  'sodium-based battery storage': '1999-2019',
#  'solar photovoltaic': '2000-2021',
#  'solar thermal energy': '2000-2021',
#  'solid biofuels': '2000-2021',
#  'space launches': '1957-2022',
#  'stationary steam engines': '1710-1920',
#  'steam locomotives': '1830-1940',
#  'steam ships': '1814-1998',
#  'stove': '1900-2011',
#  'styrene': '1958-1972',
#  'submarine cables': '1989-2021',
#  'sulphuric acid': '1860-2003',
#  'synthetic filaments': '1910-2003',
#  'tablet': '2010-2017',
#  'telegraph traffic': '1830-2000',
#  'telephones': '1876-2003',
#  'television': '1946-2018',
#  'tin': '1910-2003',
#  'titanium sponge': '1950-1968',
#  'transistors per microprocessor': '1971-2003',
#  'urea': '1961-1972',
#  'vacuums': '1922-1978',
#  'videocassette recorder': '1992-2011',
#  'vinyl acetate': '1960-1972',
#  'vinyl chloride': '1962-1972',
#  'washing machines': '1920-2008',
#  'water heater': '1933-1986',
#  'wet flue gas desulfurization systems': '1972-1999',
#  'yfv vaccine': '1997-2021',
#  'zinc': '1860-2008',
#  'zinc-based battery': '2013-2020'}

# %%
for item in timespan_dict_lower:
    print(timespan_dict_lower[item])
# Out:
# 1960-1972
# 1959-1972
# 2003-2022
# 1990-2021
# 2014-2018
# 1961-1972
# 1960-2020
# 1910-1984
# 1980-2021
# 1750-2007
# 1952-1968
# 1861-2007
# 2000-2021
# 1959-1972
# 1968-1997
# 1990-2012
# 1794-1861
# 1750-2010
# 1962-1972
# 1960-2020
# 1971-2019
# 1899-2008
# 1975-2010
# 1900-2019
# 1900-1970
# 1990-2003
# 1908-2000
# 1981-2021
# 1995-2021
# 1966-2005
# 1991-2020
# 1900-1998
# 1985-2022
# 1990-2011
# 1990-2011
# 1961-2001
# 1860-2008
# 1956-1972
# 1960-2020
# 1922-2011
# 1966-1984
# 1980-2021
# 1980-2021
# 2009-2018
# 1997-2010
# 1933-1986
# 1985-2021
# 2012-2016
# 1962-1984
# 1955-1972
# 1958-1972
# 1953-1968
# 1960-1972
# 1940-2007
# 2000-2018
# 1860-1989
# 2006-2020
# 1962-1972
# 1950-2011
# 2000-2021
# 1851-2018
# 1995-2021
# 1995-2020
# 2007-2017
# 1989-2021
# 2000-2021
# 1996-2022
# 1996-2022
# 1996-2022
# 1991-2021
# 1964-2021
# 1957-2011
# 1992-2016
# 1993-2016
# 2013-2018
# 1929-2003
# 1965-2021
# 1962-1972
# 2012-2017
# 1996-2022
# 1996-2022
# 1968-2004
# 1984-2014
# 2015-2021
# 1933-1970
# 1990-2011
# 1958-2007
# 1991-2017
# 1920-2006
# 1990-2012
# 1987-2020
# 1985-2021
# 2001-2021
# 1995-2021
# 2008-2021
# 1954-1972
# 1952-2004
# 1959-1972
# 2000-2021
# 1980-2021
# 2000-2021
# 1957-1972
# 1984-2016
# 1976-2016
# 1975-2017
# 1889-2010
# 1946-1968
# 1900-2008
# 1903-2000
# 1960-2021
# 1970-2021
# 1960-1972
# 1889-2018
# 2003-2015
# 1929-2003
# 1961-2020
# 1990-2005
# 1965-2021
# 1945-2010
# 2000-2021
# 2001-2021
# 1965-2021
# 1965-2021
# 2000-2021
# 2000-2021
# 1957-1968
# 1895-2005
# 2008-2021
# 1952-1972
# 1959-1972
# 1961-2020
# 1955-1972
# 2006-2015
# 1980-2021
# 1960-1972
# 1958-1972
# 1958-1972
# 1943-1968
# 1946-1968
# 1830-2000
# 1961-2020
# 1951-1984
# 1990-2012
# 1990-2012
# 1900-2018
# 1929-1968
# 1971-2002
# 1900-2020
# 1944-2020
# 1972-1984
# 1815-2005
# 1825-2004
# 1949-2004
# 1995-2021
# 1990-2011
# 1980-2021
# 1918-2009
# 1965-2021
# 2006-2021
# 1970-2005
# 1890-1989
# 1990-2012
# 1902-2019
# 1902-2019
# 1982-2018
# 2007-2019
# 1964-1986
# 2001-2009
# 1874-2008
# 2011-2019
# 2005-2019
# 1957-1972
# 1958-1972
# 1999-2019
# 2000-2021
# 2000-2021
# 2000-2021
# 1957-2022
# 1710-1920
# 1830-1940
# 1814-1998
# 1900-2011
# 1958-1972
# 1989-2021
# 1860-2003
# 1910-2003
# 2010-2017
# 1830-2000
# 1876-2003
# 1946-2018
# 1910-2003
# 1950-1968
# 1971-2003
# 1961-1972
# 1922-1978
# 1992-2011
# 1960-1972
# 1962-1972
# 1920-2008
# 1933-1986
# 1972-1999
# 1997-2021
# 1860-2008
# 2013-2020
