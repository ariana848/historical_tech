# %%
import pandas as pd
from pandas import Series, DataFrame

# %%
all_tech = pd.read_csv('all_tech_version 1.5.csv')
all_tech
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/2174381710.py:1: DtypeWarning: Columns (156,215,216,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,309,310,311,312,313,314,315,316,317,318,320,321,322,323,324,325,326,327,328,329,330) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_tech = pd.read_csv('all_tech_version 1.5.csv')
#                                                      ID Spatial Scale  \
# 0     Lithium-ion battery storage_Cumulative Rated C...      National
# 1     Lithium-ion battery storage_Cumulative Rated P...      National
# 2     Sensible heat storage_Cumulative Rated Capacit...      National
# 3       Sensible heat storage_Cumulative Rated Power_ZA      National
# 4     Pumped hydro storage_Cumulative Rated Capacity_CA      National
# ...                                                 ...           ...
# 7577       Raw steel production_Annual production_World        Global
# 7578                  Space Launches_Yearly Launches_UA      National
# 7579                  Space Launches_Yearly Launches_TM      National
# 7580                   Liquefied natural gas_Exports_US           NaN
# 7581                  Space Launches_Yearly Launches_CO      National
#
#      Country Code   Country Name              Technology Name  \
# 0              TG           Togo  Lithium-ion battery storage
# 1              TG           Togo  Lithium-ion battery storage
# 2              ZA   South Africa        Sensible heat storage
# 3              ZA   South Africa        Sensible heat storage
# 4              CA         Canada         Pumped hydro storage
# ...           ...            ...                          ...
# 7577        World          World         Raw steel production
# 7578           UA        Ukraine               Space Launches
# 7579           TM   Turkmenistan               Space Launches
# 7580           US  United States        Liquefied natural gas
# 7581           CO       Colombia               Space Launches
#
#                          Metric                                   Unit  \
# 0     Cumulative Rated Capacity                                    kWh
# 1        Cumulative Rated Power                                     kW
# 2     Cumulative Rated Capacity                                    kWh
# 3        Cumulative Rated Power                                     kW
# 4     Cumulative Rated Capacity                                    kWh
# ...                         ...                                    ...
# 7577          Annual production                            Metric tons
# 7578            Yearly Launches  Number of objects launched into space
# 7579            Yearly Launches  Number of objects launched into space
# 7580                    Exports                     Billion cubic feet
# 7581            Yearly Launches  Number of objects launched into space
#
#                                  Data Source  1700  1701  ...       2016  \
# 0         DOE Global Energy Storage Database   NaN   NaN  ...        NaN
# 1         DOE Global Energy Storage Database   NaN   NaN  ...        NaN
# 2         DOE Global Energy Storage Database   NaN   NaN  ...  1195000.0
# 3         DOE Global Energy Storage Database   NaN   NaN  ...   255000.0
# 4         DOE Global Energy Storage Database   NaN   NaN  ...  3044000.0
# ...                                      ...   ...   ...  ...        ...
# 7577                  U.S. Geological Survey   NaN   NaN  ...        NaN
# 7578                                  UNOOSA   NaN   NaN  ...        NaN
# 7579                                  UNOOSA   NaN   NaN  ...        NaN
# 7580  U.S. Energy Information Administration   NaN   NaN  ...     186.84
# 7581                                  UNOOSA   NaN   NaN  ...        NaN
#
#            2017       2018    2019     2020     2021  2022  2023  2024  2025
# 0         760.0     1160.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 1         190.0      290.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 2     1745000.0  2945000.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 3      355000.0   455000.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 4           NaN        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# ...         ...        ...     ...      ...      ...   ...   ...   ...   ...
# 7577        NaN        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 7578        NaN        NaN     NaN      NaN      NaN   1.0   NaN   NaN   NaN
# 7579        NaN        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN
# 7580     707.54    1083.12  1819.4  2389.84  3560.82   NaN   NaN   NaN   NaN
# 7581        NaN        1.0     NaN      NaN      NaN   NaN   NaN   NaN   NaN
#
# [7582 rows x 334 columns]

# %%
tech_list = sorted(list(set(all_tech['Technology Name'])))
len(tech_list)
tech_list
# Out:
# ['Acrylic Fiber',
#  'Acrylonitrile',
#  'Air-Source Heat Pumps',
#  'All Biofuels',
#  'Amazon Prime users',
#  'Aniline',
#  'Aquaculture production',
#  'Automatic transmission',
#  'BCG Vaccine',
#  'Beer Production',
#  'Benzene',
#  'Bicycles',
#  'Biogas',
#  'Bisphenol A',
#  'CFLs',
#  'Cable TV',
#  'Cadmium Refining',
#  'Canals',
#  'Cane Sugar Production',
#  'Caprolactam',
#  'Capture fisheries production',
#  'Carbon Capture & Sequestration',
#  'Caustic Soda',
#  'Cellphones',
#  'Cement production',
#  'Central heating',
#  'Coal Power',
#  'Coal Production',
#  'Cobalt Mine Production',
#  'Colour TV',
#  'Compressed air energy storage',
#  'Computing Growth',
#  'Concentrated Solar Power',
#  'Copper Mining',
#  'Copper Refining',
#  'Crop harvester',
#  'Crude Oil',
#  'Cyclohexane',
#  'DTP1 Vaccine',
#  'DTP3 Vaccine',
#  'Desalination capacity',
#  'Dishwashers',
#  'Disk brakes',
#  'Ebook reader',
#  'Electric Bicycles',
#  'Electric Range',
#  'Electricity',
#  'Electro-chemical capacitor',
#  'Electronic ignition',
#  'Ethanolamine',
#  'Ethyl Alcohol',
#  'Ethylene',
#  'Ethylene Glycol',
#  'FCC-Refineries',
#  'Flow battery storage',
#  'Flush toilet',
#  'Flywheel battery storage',
#  'Formaldehyde',
#  'Freezer',
#  'Geothermal Energy',
#  'Gold production',
#  'Graphite Mine Production',
#  'Ground Source Heat Pumps',
#  'HEPB3 Vaccine',
#  'HEPBB Vaccine',
#  'HIB3 Vaccine',
#  'Heat thermal battery storage',
#  'Herbicide-Tolerant Corn',
#  'Herbicide-Tolerant Cotton',
#  'Herbicide-Tolerant Soybeans',
#  'High-speed rail',
#  'Home air conditioning',
#  'Home computers',
#  'Household Internet access',
#  'Households with only mobile phones (no landlines)',
#  'Hydrochloric Acid',
#  'Hydroelectricity',
#  'Hydrofluoric Acid',
#  'Hydrogen storage',
#  'IPV1 Vaccine',
#  'Insect-Resistant Corn',
#  'Insect-Resistant Cotton',
#  'Internet Backbone Bandwidth',
#  'Internet Traffic',
#  'Iron',
#  'Iron ore',
#  'Jet Aircraft',
#  'Latent heat storage',
#  'Laundry Dryers',
#  'Lead mine production',
#  'Lead-acid battery storage',
#  'Liquefied natural gas',
#  'Liquid Biofuels',
#  'Lithium Mine Production',
#  'Lithium-ion battery storage',
#  'MCV1 Vaccine',
#  'MCV2 Vaccine',
#  'Magnesium',
#  'Magnetic Data Storage',
#  'Maleic Anhydride',
#  'Marine Energy',
#  'Methanol',
#  'Microcomputers',
#  'Microprocessor Clock Speed',
#  'Microwaves',
#  'Milk production',
#  'Motor Gasoline',
#  'Motorcycles',
#  'NatGas Power',
#  'Natural Gas Production',
#  'Natural gas pipeline',
#  'Neoprene Rubber',
#  'Nickel production',
#  'Nickel-based battery',
#  'Nitric Acid',
#  'Nitrogen Fertilizer',
#  'Nox pollution controls (boilers)',
#  'Nuclear Energy',
#  'Nuclear weapons',
#  'Off-Grid Onshore Wind Energy',
#  'Oil Production',
#  'Oil Refining Capacity',
#  'Oil pipeline',
#  'On-Grid Offshore Wind Energy',
#  'On-Grid Onshore Wind Energy',
#  'PCV3 Vaccine',
#  'POL3 Vaccine',
#  'Paraxylene',
#  'Passenger Cars',
#  'Pentaerythritol',
#  'Phenol',
#  'Phosphate Fertilizer',
#  'Phthalic Anhydride',
#  'Podcasting',
#  'Polyester Fiber',
#  'Polyethylene HD',
#  'Polyethylene LD',
#  'Polystyrene',
#  'Polyvinylchloride',
#  'Postal Traffic',
#  'Potash Fertilizer',
#  'Power steering',
#  'Primary Magnesium',
#  'Primary aluminum production',
#  'Primary bauxite production',
#  'Primary copper production',
#  'Processor Performance',
#  'Public roads',
#  'Pumped hydro storage',
#  'RCV1 Vaccine',
#  'ROTAC Vaccine',
#  'RTGS adoption',
#  'Radial tires',
#  'Radio',
#  'Railroad',
#  'Random Access Memory',
#  'Rare Earth Mine Production',
#  'Raw steel production',
#  'Refrigerators',
#  'Renewable Power',
#  'Running water',
#  'Salt production',
#  'Sand and gravel production (construction)',
#  'Sand and gravel production (industrial)',
#  'Sensible heat storage',
#  'Shale production',
#  'Shipping container port infrastructure',
#  'Shotgun Sanger DNA Sequencing',
#  'Silver',
#  'Smartphone usage',
#  'Social media usage',
#  'Sodium',
#  'Sodium Chlorate',
#  'Sodium-based battery storage',
#  'Solar Photovoltaic',
#  'Solar Thermal Energy',
#  'Solid Biofuels',
#  'Space Launches',
#  'Stationary Steam Engines',
#  'Steam Locomotives',
#  'Steam ships',
#  'Stove',
#  'Styrene',
#  'Submarine Cables',
#  'Sulphuric Acid',
#  'Synthetic Filaments',
#  'Tablet',
#  'Telegraph Traffic',
#  'Telephones',
#  'Television',
#  'Tin',
#  'Titanium Sponge',
#  'Transistors per Microprocessor',
#  'Urea',
#  'Vacuums',
#  'Videocassette recorder',
#  'Vinyl Acetate',
#  'Vinyl Chloride',
#  'Washing Machines',
#  'Water Heater',
#  'Wet flue gas desulfurization systems',
#  'YFV Vaccine',
#  'Zinc',
#  'Zinc-based battery']

# %%
len(tech_list)
# Out:
# 204

# %%
tech_us_global = {}
for tech in tech_list:
    country_names = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    country_codes = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Code']))
    if 'World' in country_names or 'US' in country_codes:
        tech_us_global[tech] = 'x'
    else:
        tech_us_global[tech] = ''
        
for entry in tech_us_global:
    if tech_us_global[entry] == '':
        print(entry)
# Out:
# BCG Vaccine
# Hydrogen storage
# Off-Grid Onshore Wind Energy
# Silver
# Steam ships
# Tin
# YFV Vaccine

# %%
tech_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    tech_country_dict[tech] = countries
tech_country_dict
# Out:
# {'Acrylic Fiber': ['World'],
#  'Acrylonitrile': ['World'],
#  'Air-Source Heat Pumps': ['United States'],
#  'All Biofuels': ['South Korea',
#   'France',
#   'Portugal',
#   'Austria',
#   'Colombia',
#   'Thailand',
#   'Australia',
#   'Spain',
#   'India',
#   'Germany',
#   'Finland',
#   'Argentina',
#   'Sweden',
#   'Belgium',
#   'Poland',
#   'Canada',
#   'Netherlands',
#   'Mexico',
#   'Italy',
#   'United Kingdom',
#   'China',
#   'Brazil',
#   'Indonesia',
#   'US'],
#  'Amazon Prime users': ['United States'],
#  'Aniline': ['World'],
#  'Aquaculture production': ['Lebanon',
#   'Vietnam',
#   'Northern Mariana Islands',
#   'Palau',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Virgin Islands (U.S.)',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Iran, Islamic Rep.',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Guam',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Saudi Arabia',
#   'Romania',
#   'Solomon Islands',
#   'Gambia, The',
#   'Haiti',
#   'Morocco',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Egypt, Arab Rep.',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Kyrgyz Republic',
#   'World',
#   'Spain',
#   'Turkiye',
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Trinidad and Tobago',
#   'Iceland',
#   'Lesotho',
#   'Eritrea',
#   'North Macedonia',
#   'Senegal',
#   'British Virgin Islands',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Aruba',
#   'Argentina',
#   'Micronesia, Fed. Sts.',
#   'Marshall Islands',
#   'Sweden',
#   'Nicaragua',
#   'Tajikistan',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'St. Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'St. Kitts and Nevis',
#   'United Kingdom',
#   'Croatia',
#   'Bangladesh',
#   'Burkina Faso',
#   'Ecuador',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Puerto Rico',
#   'Gabon',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Curacao',
#   'Colombia',
#   'Yemen, Rep.',
#   'Guinea',
#   'Jordan',
#   'Congo, Rep.',
#   'Cuba',
#   'Congo, Dem. Rep.',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   "Korea, Dem. People's Rep.",
#   'Venezuela, RB',
#   'Turks and Caicos Islands',
#   'Lao PDR',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Korea, Rep.',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'West Bank and Gaza',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Kuwait',
#   'Moldova',
#   'Tonga',
#   'American Samoa',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Dominican Republic',
#   'Costa Rica',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'New Caledonia',
#   'Austria',
#   'Switzerland',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'French Polynesia',
#   'Ireland',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'St. Lucia',
#   'Slovak Republic',
#   'Burundi',
#   'Tanzania',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Hungary',
#   'Benin',
#   'Botswana',
#   'Bolivia',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Hong Kong SAR, China',
#   'Bahamas, The',
#   'Faroe Islands',
#   'Afghanistan'],
#  'Automatic transmission': ['United States'],
#  'BCG Vaccine': ['Iran (Islamic Republic of)',
#   'Viet Nam',
#   'Saint Kitts and Nevis',
#   'Cameroon',
#   'Sudan',
#   'Cabo Verde',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'Comoros',
#   'China',
#   'Monaco',
#   'Saudi Arabia',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Lesotho',
#   'Eritrea',
#   'Senegal',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Tajikistan',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Maldives',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Congo',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Yemen',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Zambia',
#   'Greece',
#   'Paraguay',
#   'Latvia',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'Austria',
#   'Republic of North Macedonia',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Serbia',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   "Lao People's Democratic Republic",
#   'South Africa',
#   'Madagascar',
#   'Burundi',
#   'Libya',
#   'Sierra Leone',
#   'Djibouti',
#   'Benin',
#   'Botswana',
#   'United Republic of Tanzania',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Brazil',
#   'Türkiye',
#   'Hungary',
#   'Afghanistan'],
#  'Beer Production': ['Vietnam',
#   'Cameroon',
#   'Australia',
#   'Armenia',
#   'Korea',
#   'Lithuania',
#   'Zaire',
#   'Poland',
#   'Uruguay',
#   'Turkey',
#   'Turkmenistan',
#   'Mexico',
#   'China',
#   'Nigeria',
#   'Romania',
#   'Morocco',
#   'Russia',
#   'Ghana',
#   'Kenya',
#   'Belarus',
#   'Portugal',
#   'Estonia',
#   'Spain',
#   'El Salvador',
#   'Ethiopia',
#   'Czechoslovakia',
#   'Venezuela',
#   'Azerbaijan',
#   'Malawi',
#   'Sweden',
#   'Argentina',
#   'Tajikistan',
#   'Nicaragua',
#   'Chile',
#   'Georgia',
#   'Philippines',
#   'Croatia',
#   'Burkina Faso',
#   'Ecuador',
#   'Kyrgistan',
#   'Malaysia',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'East Germany',
#   'Mozambique',
#   'Yugoslavia',
#   'Rwanda',
#   'Colombia',
#   'Cuba',
#   'Jamaica',
#   'Slovenia',
#   'Congo',
#   'Japan',
#   'Egypt',
#   'Southern Vietnam',
#   'Algeria',
#   'Finland',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'USA',
#   'Zambia',
#   'Paraguay',
#   'Italy',
#   'Latvia',
#   'West Germany',
#   'New Zealand',
#   'Macedonia',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Moldova',
#   'France',
#   'Kazakhstan',
#   'Dominican Republic',
#   'Costa Rica',
#   'Zimbabwe',
#   'Guatemala',
#   'Switzerland',
#   'Austria',
#   'Honduras',
#   'Thailand',
#   'Denmark',
#   'Serbia',
#   'Ireland',
#   'UK',
#   'India',
#   'South Africa',
#   'Germany',
#   'Tanzania',
#   'Burundi',
#   'Czech Republic',
#   'Belgium',
#   'Ivory Coast',
#   'Canada',
#   'Bolivia',
#   'Netherlands',
#   'Peru',
#   'Uzbekistan',
#   'Brazil',
#   'Hungary'],
#  'Benzene': ['World'],
#  'Bicycles': ['World'],
#  'Biogas': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Australia',
#   'Armenia',
#   'Lithuania',
#   'Luxembourg',
#   'Martinique',
#   'Poland',
#   'Uruguay',
#   'Guadeloupe',
#   'Mexico',
#   'Faroe Islands',
#   'China',
#   'Malta',
#   'Pakistan',
#   'Romania',
#   'Morocco',
#   'Sri Lanka',
#   'Ghana',
#   'Mauritius',
#   'Kenya',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Réunion',
#   'Estonia',
#   'Spain',
#   'El Salvador',
#   'Iceland',
#   'Azerbaijan',
#   'Chinese Taipei',
#   'Argentina',
#   'Sweden',
#   'Czechia',
#   'Chile',
#   'Slovakia',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Croatia',
#   'Burkina Faso',
#   'Ecuador',
#   'Malaysia',
#   'Ukraine',
#   'Panama',
#   'Puerto Rico',
#   'Republic of Korea',
#   'Colombia',
#   'Jordan',
#   'Cuba',
#   'Syrian Arab Republic',
#   'Slovenia',
#   'Japan',
#   'Egypt',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Norway',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   'Indonesia',
#   'Israel',
#   'United States of America',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Republic of Moldova',
#   'France',
#   'Kazakhstan',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Austria',
#   'Republic of North Macedonia',
#   'Switzerland',
#   'Honduras',
#   'Thailand',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Ireland',
#   'India',
#   'South Africa',
#   'Germany',
#   'Belgium',
#   'United Republic of Tanzania',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'Brazil',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Türkiye',
#   'Hungary'],
#  'Bisphenol A': ['World'],
#  'CFLs': ['World'],
#  'Cable TV': ['United States'],
#  'Cadmium Refining': ['Serbia and Montenegro',
#   'Russia',
#   'Ukraine',
#   'France',
#   'Kazakhstan',
#   'Korea, Republic of',
#   'Yugoslavia',
#   'Austria',
#   'United States',
#   'Thailand',
#   'World',
#   'Australia',
#   'Germany: Eastern states',
#   'Spain',
#   'Japan',
#   'Germany: Western states',
#   'India',
#   'South Africa',
#   'Germany',
#   'Algeria',
#   'Finland',
#   'Namibia',
#   'Congo (Kinshasa)',
#   'Bulgaria',
#   'Argentina',
#   'Belgium',
#   'Norway',
#   'Poland',
#   'Canada',
#   'Netherlands',
#   'Turkey',
#   'Peru',
#   'Mexico',
#   'Italy',
#   'United Kingdom',
#   'China',
#   'U.S.S.R.',
#   'Macedonia',
#   'Brazil',
#   'Romania',
#   'Korea, North'],
#  'Canals': ['United States'],
#  'Cane Sugar Production': ['Trinidad & Tobago',
#   'Panama',
#   'Vietnam',
#   'Mauritius',
#   'Kenya',
#   'Dominican Republic',
#   'Costa Rica',
#   'Mozambique',
#   'Guatemala',
#   'Zimbabwe',
#   'Taiwan',
#   'Sudan',
#   'Honduras',
#   'Thailand',
#   'Cuba',
#   'Jamaica',
#   'Spain',
#   'Myanmar',
#   'Japan',
#   'El Salvador',
#   'Ethiopia',
#   'Egypt',
#   'India',
#   'South Africa',
#   'Madagascar',
#   'Tanzania',
#   'Malawi',
#   'Nicaragua',
#   'Ivory Coast',
#   'Swaziland',
#   'USA',
#   'Turkey',
#   'Philippines',
#   'Mexico',
#   'China',
#   'Bangladesh',
#   'Pakistan',
#   'Indonesia',
#   'Iran',
#   'Morocco',
#   'Haiti',
#   'Barbados'],
#  'Caprolactam': ['World'],
#  'Capture fisheries production': ['Lebanon',
#   'Vietnam',
#   'Northern Mariana Islands',
#   'Palau',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Gibraltar',
#   'Australia',
#   'Virgin Islands (U.S.)',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Iran, Islamic Rep.',
#   'Luxembourg',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Macao SAR, China',
#   'Mexico',
#   'Greenland',
#   'Turkmenistan',
#   'Comoros',
#   'China',
#   'Liechtenstein',
#   'Monaco',
#   'Guam',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Saudi Arabia',
#   'St. Martin (French part)',
#   'Romania',
#   'Solomon Islands',
#   'Gambia, The',
#   'Haiti',
#   'Morocco',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Bermuda',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Egypt, Arab Rep.',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Kyrgyz Republic',
#   'World',
#   'Spain',
#   'Turkiye',
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Trinidad and Tobago',
#   'Iceland',
#   'Isle of Man',
#   'Lesotho',
#   'Eritrea',
#   'North Macedonia',
#   'Senegal',
#   'British Virgin Islands',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Aruba',
#   'Argentina',
#   'Micronesia, Fed. Sts.',
#   'Marshall Islands',
#   'Sweden',
#   'Nicaragua',
#   'Tajikistan',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'St. Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'St. Kitts and Nevis',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Sint Maarten (Dutch part)',
#   'Bangladesh',
#   'Burkina Faso',
#   'Ecuador',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Puerto Rico',
#   'Gabon',
#   'Maldives',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Curacao',
#   'Colombia',
#   'Yemen, Rep.',
#   'Guinea',
#   'Jordan',
#   'Congo, Rep.',
#   'Cuba',
#   'Congo, Dem. Rep.',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   "Korea, Dem. People's Rep.",
#   'Venezuela, RB',
#   'Sao Tome and Principe',
#   'Turks and Caicos Islands',
#   'Lao PDR',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Korea, Rep.',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'West Bank and Gaza',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Kuwait',
#   'Moldova',
#   'Tonga',
#   'American Samoa',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'New Caledonia',
#   'Austria',
#   'Switzerland',
#   'Cayman Islands',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'French Polynesia',
#   'Ireland',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'San Marino',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'St. Lucia',
#   'Slovak Republic',
#   'Burundi',
#   'Tanzania',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Djibouti',
#   'Benin',
#   'Hungary',
#   'Botswana',
#   'Bolivia',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Hong Kong SAR, China',
#   'Bahamas, The',
#   'Faroe Islands',
#   'Afghanistan'],
#  'Carbon Capture & Sequestration': ['World'],
#  'Caustic Soda': ['South Korea',
#   'Mexico',
#   'Algeria',
#   'Australia',
#   'China',
#   'Egypt',
#   'Brazil',
#   'Pakistan',
#   'Argentina',
#   'Japan',
#   'Israel',
#   'United States of America',
#   'Canada',
#   'Turkey',
#   'India'],
#  'Cellphones': ['Lebanon',
#   'Vietnam',
#   'Cameroon',
#   'Suriname',
#   'Sudan',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Turkey',
#   'Tunisia',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Pakistan',
#   'Nigeria',
#   'Romania',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Indochina',
#   'Russia',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'World',
#   'Spain',
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Czechoslovakia',
#   'Bosnia-Herzegovina',
#   'Iceland',
#   'Lesotho',
#   'Venezuela',
#   'Eritrea',
#   'Senegal',
#   'Burma',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Tajikistan',
#   'Nicaragua',
#   'Chile',
#   'Georgia',
#   'Philippines',
#   'Guyana',
#   'United Kingdom',
#   'Croatia',
#   'Hong Kong',
#   'Mauritania',
#   'Bangladesh',
#   'Burkina Faso',
#   'Ecuador',
#   'Malaysia',
#   'South Korea',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Mozambique',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Slovenia',
#   'Yemen',
#   'Japan',
#   'South Yemen',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Swaziland',
#   'Zambia',
#   'Greece',
#   'Paraguay',
#   'Italy',
#   'Latvia',
#   'New Zealand',
#   'Democratic Republic of the Congo',
#   'Macedonia',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Kuwait',
#   'Moldova',
#   'France',
#   'Kazakhstan',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'Zimbabwe',
#   'Guatemala',
#   'Niger',
#   'Switzerland',
#   'United States',
#   'Austria',
#   'Honduras',
#   'Thailand',
#   'Denmark',
#   'Albania',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Central African Republic',
#   'Syria',
#   'India',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'Tanzania',
#   'Burundi',
#   'Slovak Republic',
#   'Libya',
#   'Czech Republic',
#   'Sierra Leone',
#   'Belgium',
#   'Ivory Coast',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'Bolivia',
#   'Netherlands',
#   'Peru',
#   'Republic of the Congo',
#   'Mali',
#   'South Vietnam',
#   'Uzbekistan',
#   'Laos',
#   'Brazil',
#   'Iran',
#   'Hungary',
#   'Afghanistan'],
#  'Cement production': ['World', 'United States'],
#  'Central heating': ['United States'],
#  'Coal Power': ['World'],
#  'Coal Production': ['South Korea',
#   'Ukraine',
#   'Vietnam',
#   'Kazakhstan',
#   'Mongolia',
#   'Zimbabwe',
#   'Colombia',
#   'Thailand',
#   'Serbia',
#   'Australia',
#   'World',
#   'Spain',
#   'Japan',
#   'India',
#   'South Africa',
#   'Venezuela',
#   'Germany',
#   'USSR',
#   'Bulgaria',
#   'Czech Republic',
#   'Russian Federation',
#   'Poland',
#   'Greece',
#   'Canada',
#   'Turkey',
#   'Mexico',
#   'New Zealand',
#   'Uzbekistan',
#   'United Kingdom',
#   'China',
#   'Brazil',
#   'Pakistan',
#   'Indonesia',
#   'Romania',
#   'Hungary',
#   'US'],
#  'Cobalt Mine Production': ['Philippines',
#   'South Africa',
#   'Madagascar',
#   'Cuba',
#   'Zambia',
#   'World',
#   'Australia',
#   'China',
#   'New Caledonia',
#   'Democratic Republic of Congo',
#   'Russian Federation',
#   'Morocco',
#   'Canada',
#   'Papua New Guinea'],
#  'Colour TV': ['United States'],
#  'Compressed air energy storage': ['Germany',
#   'United Kingdom',
#   'China',
#   'United States',
#   'Canada',
#   'Switzerland',
#   'Netherlands'],
#  'Computing Growth': ['World'],
#  'Concentrated Solar Power': ['World'],
#  'Copper Mining': ['Serbia and Montenegro',
#   'Zambia',
#   'Russia',
#   'Vietnam',
#   'France',
#   'Kazakhstan',
#   'Mongolia',
#   'Dominican Republic',
#   'Iran',
#   'Korea, Republic of',
#   'Mozambique',
#   'Yugoslavia',
#   'Zimbabwe',
#   'Morocco',
#   'Portugal',
#   'United States',
#   'Colombia',
#   'Honduras',
#   'Nepal',
#   'Cuba',
#   'Romania',
#   'Albania',
#   'Serbia',
#   'Australia',
#   'World',
#   'Cyprus',
#   'Spain',
#   'Japan',
#   'Armenia',
#   'Oman',
#   'Czechoslovakia',
#   'Papua New Guinea',
#   'India',
#   'South Africa',
#   'Germany',
#   'Burma',
#   'Finland',
#   'Namibia',
#   'Tanzania',
#   'Congo (Kinshasa)',
#   'Bulgaria',
#   'Argentina',
#   'Sweden',
#   'Norway',
#   'Poland',
#   'Botswana',
#   'Chile',
#   'Bolivia',
#   'Canada',
#   'Georgia',
#   'Peru',
#   'Slovakia',
#   'Philippines',
#   'Mexico',
#   'Turkey',
#   'Uzbekistan',
#   'United Kingdom',
#   'Laos',
#   'China',
#   'U.S.S.R.',
#   'Macedonia',
#   'Mauritania',
#   'Brazil',
#   'Saudi Arabia',
#   'Pakistan',
#   'Indonesia',
#   'Ecuador',
#   'Korea, North',
#   'Malaysia'],
#  'Copper Refining': ['Serbia and Montenegro',
#   'Russia',
#   'Ukraine',
#   'Vietnam',
#   'France',
#   'Kazakhstan',
#   'Mongolia',
#   'Korea, Republic of',
#   'Yugoslavia',
#   'Zimbabwe',
#   'Taiwan',
#   'Austria',
#   'Portugal',
#   'United States',
#   'Thailand',
#   'Romania',
#   'Albania',
#   'Serbia',
#   'Australia',
#   'World',
#   'Cyprus',
#   'Spain',
#   'Japan',
#   'Oman',
#   'Czechoslovakia',
#   'Egypt',
#   'India',
#   'South Africa',
#   'Germany',
#   'Burma',
#   'Finland',
#   'Congo (Kinshasa)',
#   'Bulgaria',
#   'Czech Republic',
#   'Argentina',
#   'Korea, North',
#   'Sweden',
#   'Belgium',
#   'Norway',
#   'Poland',
#   'Zambia',
#   'Chile',
#   'Canada',
#   'Slovakia',
#   'Turkey',
#   'Peru',
#   'Philippines',
#   'Mexico',
#   'Italy',
#   'Uzbekistan',
#   'United Kingdom',
#   'Laos',
#   'China',
#   'U.S.S.R.',
#   'Brazil',
#   'Indonesia',
#   'Iran',
#   'Hungary'],
#  'Crop harvester': ['Lebanon',
#   'Vietnam',
#   'Suriname',
#   'Sudan',
#   'Australia',
#   'Armenia',
#   'Papua New Guinea',
#   'Lithuania',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Turkey',
#   'Tunisia',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Pakistan',
#   'Romania',
#   'Morocco',
#   'Sri Lanka',
#   'Indochina',
#   'Russia',
#   'Ghana',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Estonia',
#   'Spain',
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Czechoslovakia',
#   'Bosnia-Herzegovina',
#   'Iceland',
#   'Lesotho',
#   'Venezuela',
#   'Eritrea',
#   'Senegal',
#   'Burma',
#   'Azerbaijan',
#   'Argentina',
#   'Sweden',
#   'Tajikistan',
#   'Chile',
#   'Georgia',
#   'Philippines',
#   'Guyana',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Ecuador',
#   'South Korea',
#   'Ukraine',
#   'Panama',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Slovenia',
#   'Yemen',
#   'Japan',
#   'South Yemen',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Bulgaria',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Macedonia',
#   'Indonesia',
#   'Israel',
#   'Moldova',
#   'France',
#   'Kazakhstan',
#   'Mongolia',
#   'Costa Rica',
#   'Zimbabwe',
#   'Guatemala',
#   'Switzerland',
#   'United States',
#   'Austria',
#   'Thailand',
#   'Denmark',
#   'Albania',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Central African Republic',
#   'Syria',
#   'India',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'Slovak Republic',
#   'Burundi',
#   'Libya',
#   'Czech Republic',
#   'Sierra Leone',
#   'Belgium',
#   'Ivory Coast',
#   'Botswana',
#   'Canada',
#   'Bolivia',
#   'Netherlands',
#   'Republic of the Congo',
#   'Mali',
#   'South Vietnam',
#   'Uzbekistan',
#   'Brazil',
#   'Iran',
#   'Hungary'],
#  'Crude Oil': ['Russia',
#   'Trinidad & Tobago',
#   'Kuwait',
#   'Gabon',
#   'Peru',
#   'Cameroon',
#   'Yugoslavia',
#   'Bahrain',
#   'Taiwan',
#   'Austria',
#   'Colombia',
#   'Thailand',
#   'Cuba',
#   'Romania',
#   'World',
#   'Australia',
#   'Myanmar',
#   'Japan',
#   'Iraq',
#   'Oman',
#   'Egypt',
#   'UK',
#   'Syria',
#   'India',
#   'Germany',
#   'Venezuela',
#   'Algeria',
#   'Ecuador',
#   'Libya',
#   'Qatar',
#   'Argentina',
#   'Zaire',
#   'Norway',
#   'Ivory Coast',
#   'Brunei',
#   'Poland',
#   'USA',
#   'Hungary',
#   'Bolivia',
#   'Chile',
#   'Turkey',
#   'Netherlands',
#   'Tunisia',
#   'Canada',
#   'Philippines',
#   'New Zealand',
#   'UAE',
#   'Mexico',
#   'Republic of the Congo',
#   'West Germany',
#   'Italy',
#   'Democratic Republic of the Congo',
#   'China',
#   'Brazil',
#   'Saudi Arabia',
#   'Pakistan',
#   'Nigeria',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Iran',
#   'Morocco'],
#  'Cyclohexane': ['World'],
#  'DTP1 Vaccine': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'Comoros',
#   'China',
#   'Monaco',
#   'Saudi Arabia',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Bahamas',
#   'Trinidad and Tobago',
#   'Iceland',
#   'Lesotho',
#   'Eritrea',
#   'Senegal',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Tajikistan',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Maldives',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Congo',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Yemen',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'Austria',
#   'Republic of North Macedonia',
#   'Switzerland',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'San Marino',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'Madagascar',
#   'South Africa',
#   'Burundi',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Djibouti',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'United Republic of Tanzania',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Türkiye',
#   'Hungary',
#   'Afghanistan'],
#  'DTP3 Vaccine': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'Comoros',
#   'China',
#   'Monaco',
#   'Saudi Arabia',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Bahamas',
#   'Trinidad and Tobago',
#   'Iceland',
#   'Lesotho',
#   'Eritrea',
#   'Senegal',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Tajikistan',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Maldives',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Congo',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Yemen',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'Austria',
#   'Republic of North Macedonia',
#   'Switzerland',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'San Marino',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'Madagascar',
#   'South Africa',
#   'Burundi',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Djibouti',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'United Republic of Tanzania',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Türkiye',
#   'Hungary',
#   'Afghanistan'],
#  'Desalination capacity': ['World'],
#  'Dishwashers': ['United States'],
#  'Disk brakes': ['United States'],
#  'Ebook reader': ['United States'],
#  'Electric Bicycles': ['World', 'China'],
#  'Electric Range': ['United States'],
#  'Electricity': ['Trinidad & Tobago',
#   'Vietnam',
#   'Australia',
#   'Lithuania',
#   'Luxembourg',
#   'Poland',
#   'Turkey',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Pakistan',
#   'Romania',
#   'Morocco',
#   'Sri Lanka',
#   'US',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Estonia',
#   'World',
#   'Spain',
#   'Iraq',
#   'Iceland',
#   'Venezuela',
#   'North Macedonia',
#   'Azerbaijan',
#   'Argentina',
#   'Sweden',
#   'Russian Federation',
#   'Chile',
#   'Slovakia',
#   'Philippines',
#   'United Kingdom',
#   'Croatia',
#   'Bangladesh',
#   'Ecuador',
#   'Malaysia',
#   'South Korea',
#   'Ukraine',
#   'Colombia',
#   'Slovenia',
#   'Japan',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'China Hong Kong SAR',
#   'Indonesia',
#   'Israel',
#   'Kuwait',
#   'France',
#   'Kazakhstan',
#   'Taiwan',
#   'Austria',
#   'Switzerland',
#   'Thailand',
#   'Denmark',
#   'Cyprus',
#   'Oman',
#   'Ireland',
#   'India',
#   'South Africa',
#   'Germany',
#   'Czech Republic',
#   'Belgium',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'Uzbekistan',
#   'Brazil',
#   'Iran',
#   'Hungary'],
#  'Electro-chemical capacitor': ['South Korea',
#   'Italy',
#   'China',
#   'Spain',
#   'Ireland',
#   'United States'],
#  'Electronic ignition': ['United States'],
#  'Ethanolamine': ['World'],
#  'Ethyl Alcohol': ['World'],
#  'Ethylene': ['World'],
#  'Ethylene Glycol': ['World'],
#  'FCC-Refineries': ['World', 'US'],
#  'Flow battery storage': ['South Korea',
#   'Russia',
#   'Kazakhstan',
#   'Switzerland',
#   'Portugal',
#   'Austria',
#   'United States',
#   'Denmark',
#   'Australia',
#   'Slovenia',
#   'Japan',
#   'French Polynesia',
#   'India',
#   'Antigua and Barbuda',
#   'Germany',
#   'South Africa',
#   'Czech Republic',
#   'Canada',
#   'Netherlands',
#   'New Zealand',
#   'Italy',
#   'United Kingdom',
#   'China',
#   'Indonesia',
#   'Israel'],
#  'Flush toilet': ['United States'],
#  'Flywheel battery storage': ['South Korea',
#   'Mexico',
#   'Germany',
#   'Netherlands',
#   'Antarctica',
#   'Romania',
#   'United Kingdom',
#   'France',
#   'Australia',
#   'Kenya',
#   'Spain',
#   'Czech Republic',
#   'Ireland',
#   'Canada',
#   'United States'],
#  'Formaldehyde': ['World'],
#  'Freezer': ['United States'],
#  'Geothermal Energy': ['France',
#   'Kenya',
#   'Costa Rica',
#   'Guatemala',
#   'Austria',
#   'Portugal',
#   'Honduras',
#   'Thailand',
#   'Australia',
#   'Japan',
#   'El Salvador',
#   'Ethiopia',
#   'Iceland',
#   'Germany',
#   'Chinese Taipei',
#   'Argentina',
#   'Nicaragua',
#   'Russian Federation',
#   'Chile',
#   'Philippines',
#   'Guadeloupe',
#   'Italy',
#   'Mexico',
#   'New Zealand',
#   'Croatia',
#   'China',
#   'Indonesia',
#   'Romania',
#   'Türkiye',
#   'United States of America',
#   'Hungary'],
#  'Gold production': ['Phillipines',
#   'Korea',
#   'South Korea',
#   'New Zealand',
#   'South Africa',
#   'Ghana',
#   'World',
#   'Australia',
#   'China',
#   'Japan',
#   'United States',
#   'Fiji',
#   'Zaire',
#   'Zimbabwe',
#   'Papua New Guinea',
#   'India'],
#  'Graphite Mine Production': ['Mexico',
#   'Madagascar',
#   'Ukraine',
#   'Turkey',
#   'China',
#   'World',
#   'Brazil',
#   'Mozambique',
#   'Norway',
#   'Russian Federation',
#   'Canada',
#   'Sri Lanka',
#   'India'],
#  'Ground Source Heat Pumps': ['World'],
#  'HEPB3 Vaccine': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'Comoros',
#   'China',
#   'Monaco',
#   'Saudi Arabia',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Bahamas',
#   'Trinidad and Tobago',
#   'Lesotho',
#   'Eritrea',
#   'Senegal',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Tajikistan',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Maldives',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Congo',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Yemen',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'Austria',
#   'Republic of North Macedonia',
#   'Switzerland',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'San Marino',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'Madagascar',
#   'South Africa',
#   'Burundi',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Djibouti',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'United Republic of Tanzania',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Türkiye',
#   'Afghanistan'],
#  'HEPBB Vaccine': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Bahrain',
#   'Suriname',
#   'Cabo Verde',
#   'Armenia',
#   'Papua New Guinea',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Gambia',
#   'Poland',
#   'Tunisia',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Belize',
#   'Cambodia',
#   'Andorra',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Senegal',
#   'Namibia',
#   'Azerbaijan',
#   'Argentina',
#   'Marshall Islands',
#   'Tajikistan',
#   'Chile',
#   'Georgia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Guyana',
#   'Timor-Leste',
#   'Croatia',
#   'Cook Islands',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Maldives',
#   'Republic of Korea',
#   'Colombia',
#   'Cuba',
#   'Kiribati',
#   'Bhutan',
#   'Fiji',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Latvia',
#   "Cote d'Ivoire",
#   'Indonesia',
#   'Israel',
#   'Samoa',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Republic of North Macedonia',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Serbia',
#   'Myanmar',
#   'Oman',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'India',
#   "Lao People's Democratic Republic",
#   'Djibouti',
#   'Benin',
#   'Peru',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Türkiye',
#   'Afghanistan'],
#  'HIB3 Vaccine': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'Comoros',
#   'Monaco',
#   'Saudi Arabia',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Bahamas',
#   'Trinidad and Tobago',
#   'Iceland',
#   'Lesotho',
#   'Eritrea',
#   'Senegal',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Tajikistan',
#   'Nicaragua',
#   'Czechia',
#   'Chile',
#   'Georgia',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Maldives',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Congo',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Yemen',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'Austria',
#   'Republic of North Macedonia',
#   'Switzerland',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'San Marino',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'Madagascar',
#   'South Africa',
#   'Burundi',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Djibouti',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'United Republic of Tanzania',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Türkiye',
#   'Hungary',
#   'Afghanistan'],
#  'Heat thermal battery storage': ['South Africa',
#   'Germany',
#   'United Kingdom',
#   'Australia',
#   'China',
#   'France',
#   'Spain',
#   'Morocco',
#   'Chile',
#   'United States',
#   'India'],
#  'Herbicide-Tolerant Corn': ['United States'],
#  'Herbicide-Tolerant Cotton': ['United States'],
#  'Herbicide-Tolerant Soybeans': ['United States'],
#  'High-speed rail': ['World'],
#  'Home air conditioning': ['United States'],
#  'Home computers': ['United States'],
#  'Household Internet access': ['United States'],
#  'Households with only mobile phones (no landlines)': ['United States'],
#  'Hydrochloric Acid': ['Phillipines',
#   'South Korea',
#   'South Africa',
#   'Algeria',
#   'China',
#   'Australia',
#   'Egypt',
#   'Japan',
#   'Indonesia',
#   'Iran',
#   'United States of America',
#   'Canada',
#   'India'],
#  'Hydroelectricity': ['Trinidad & Tobago',
#   'Vietnam',
#   'Australia',
#   'Lithuania',
#   'Luxembourg',
#   'Poland',
#   'Turkey',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Pakistan',
#   'Romania',
#   'Morocco',
#   'Sri Lanka',
#   'US',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Estonia',
#   'World',
#   'Spain',
#   'Iraq',
#   'Iceland',
#   'Venezuela',
#   'North Macedonia',
#   'USSR',
#   'Azerbaijan',
#   'Argentina',
#   'Sweden',
#   'Russian Federation',
#   'Chile',
#   'Slovakia',
#   'Philippines',
#   'United Kingdom',
#   'Croatia',
#   'Bangladesh',
#   'Ecuador',
#   'Malaysia',
#   'South Korea',
#   'Ukraine',
#   'Colombia',
#   'Slovenia',
#   'Japan',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'China Hong Kong SAR',
#   'Indonesia',
#   'Israel',
#   'Kuwait',
#   'France',
#   'Kazakhstan',
#   'Taiwan',
#   'Austria',
#   'Switzerland',
#   'Thailand',
#   'Denmark',
#   'Cyprus',
#   'Oman',
#   'Ireland',
#   'India',
#   'South Africa',
#   'Germany',
#   'Czech Republic',
#   'Belgium',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'Uzbekistan',
#   'Brazil',
#   'Iran',
#   'Hungary'],
#  'Hydrofluoric Acid': ['World'],
#  'Hydrogen storage': ['Germany',
#   'Italy',
#   'Thailand',
#   'Denmark',
#   'France',
#   'Canada'],
#  'IPV1 Vaccine': ['Iran (Islamic Republic of)',
#   'Lebanon',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Cameroon',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Tunisia',
#   'Eswatini',
#   'Mexico',
#   'Turkmenistan',
#   'Comoros',
#   'China',
#   'Monaco',
#   'Saudi Arabia',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Niue',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Bahamas',
#   'Trinidad and Tobago',
#   'Iceland',
#   'Lesotho',
#   'Eritrea',
#   'Senegal',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Tajikistan',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Georgia',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Timor-Leste',
#   'United Kingdom',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Maldives',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Congo',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Yemen',
#   'Sao Tome and Principe',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Paraguay',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'Austria',
#   'Republic of North Macedonia',
#   'Switzerland',
#   'United States',
#   'Honduras',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'South Sudan',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Seychelles',
#   'India',
#   'San Marino',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'Madagascar',
#   'South Africa',
#   'Burundi',
#   'Libya',
#   'Sierra Leone',
#   'Belgium',
#   'Djibouti',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'United Republic of Tanzania',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'Türkiye',
#   'Hungary',
#   'Afghanistan'],
#  'Insect-Resistant Corn': ['United States'],
#  'Insect-Resistant Cotton': ['United States'],
#  'Internet Backbone Bandwidth': ['World'],
#  'Internet Traffic': ['World'],
#  'Iron': ['United States'],
#  'Iron ore': ['Serbia and Montenegro',
#   'Russia',
#   'Ukraine',
#   'Vietnam',
#   'France',
#   'Kazakhstan',
#   'Kenya',
#   'Mongolia',
#   'Korea, Republic of',
#   'Yugoslavia',
#   'Guatemala',
#   'Zimbabwe',
#   'Morocco',
#   'Uganda',
#   'Austria',
#   'Portugal',
#   'United States',
#   'Colombia',
#   'Thailand',
#   'Cuba',
#   'Romania',
#   'Albania',
#   'World',
#   'Australia',
#   'Spain',
#   'Japan',
#   'Czechoslovakia',
#   'Egypt',
#   'Germany: Western states',
#   'India',
#   'South Africa',
#   'Germany',
#   'Venezuela',
#   'Algeria',
#   'Tanzania',
#   'Liberia',
#   'Azerbaijan',
#   'Bulgaria',
#   'Czech Republic',
#   'Argentina',
#   'Sweden',
#   'Norway',
#   'Poland',
#   'Chile',
#   'Canada',
#   'Bolivia',
#   'Greece',
#   'Peru',
#   'Slovakia',
#   'Tunisia',
#   'Mexico',
#   'Bosnia and Herzegovina',
#   'New Zealand',
#   'Turkey',
#   'United Kingdom',
#   'China',
#   'U.S.S.R.',
#   'Macedonia',
#   'Mauritania',
#   'Brazil',
#   'Pakistan',
#   'Nigeria',
#   'Indonesia',
#   'Iran',
#   'Korea, North',
#   'Malaysia'],
#  'Jet Aircraft': ['Boeing'],
#  'Latent heat storage': ['Ireland',
#   'Canada',
#   'United States',
#   'United Kingdom'],
#  'Laundry Dryers': ['World', 'US'],
#  'Lead mine production': ['Serbia and Montenegro',
#   'Russia',
#   'Vietnam',
#   'Turkey',
#   'France',
#   'Kazakhstan',
#   'Kenya',
#   'Iran',
#   'Korea, Republic of',
#   'Yugoslavia',
#   'Guatemala',
#   'Morocco',
#   'Austria',
#   'United States',
#   'Colombia',
#   'Honduras',
#   'Thailand',
#   'Romania',
#   'Serbia',
#   'Australia',
#   'World',
#   'Spain',
#   'Slovenia',
#   'Japan',
#   'Ireland',
#   'Czechoslovakia',
#   'Germany: Western states',
#   'India',
#   'South Africa',
#   'Germany',
#   'Algeria',
#   'Burma',
#   'Finland',
#   'Namibia',
#   'Bulgaria',
#   'Czech Republic',
#   'Argentina',
#   'Sweden',
#   'Tajikistan',
#   'Norway',
#   'Poland',
#   'Zambia',
#   'Chile',
#   'Georgia',
#   'Canada',
#   'Bolivia',
#   'Greece',
#   'Peru',
#   'Slovakia',
#   'Mexico',
#   'Bosnia and Herzegovina',
#   'Italy',
#   'Greenland',
#   'Tunisia',
#   'United Kingdom',
#   'Uzbekistan',
#   'China',
#   'U.S.S.R.',
#   'Macedonia',
#   'Brazil',
#   'Saudi Arabia',
#   'Nigeria',
#   'Ecuador',
#   'Korea, North'],
#  'Lead-acid battery storage': ['South Africa',
#   'South Korea',
#   'Germany',
#   'Antarctica',
#   'New Zealand',
#   'United Kingdom',
#   'Madagascar',
#   'Cape Verde',
#   'Australia',
#   'Vanuatu',
#   'Spain',
#   'Kenya',
#   'Brazil',
#   'Japan',
#   'Ireland',
#   'Taiwan',
#   'United States',
#   'India'],
#  'Liquefied natural gas': ['United States'],
#  'Liquid Biofuels': ['Solomon Islands',
#   'Germany',
#   'Italy',
#   'Denmark',
#   'France',
#   'Vanuatu',
#   'Republic of Korea',
#   'Spain',
#   'Brazil',
#   'Slovenia',
#   'Sweden',
#   'Belgium',
#   'Türkiye',
#   'Poland',
#   'United States of America',
#   'New Caledonia',
#   'Austria',
#   'Netherlands'],
#  'Lithium Mine Production': ['World',
#   'Australia',
#   'China',
#   'Brazil',
#   'Argentina',
#   'Zimbabwe',
#   'Chile',
#   'Portugal',
#   'US'],
#  'Lithium-ion battery storage': ['South Korea',
#   'Ukraine',
#   'Russia',
#   'Burkina-Faso',
#   'Gabon',
#   'France',
#   'Kenya',
#   'Cameroon',
#   'Niger',
#   'Taiwan',
#   'Portugal',
#   'Rwanda',
#   'Switzerland',
#   'United States',
#   'Guinea',
#   'Jordan',
#   'Denmark',
#   'Australia',
#   'Spain',
# ...
#   'India'],
#  'Shale production': ['United States'],
#  'Shipping container port infrastructure': ['United States'],
#  'Shotgun Sanger DNA Sequencing': ['World'],
#  'Silver': ['Korea',
#   'South Korea',
#   'New Zealand',
#   'South Africa',
#   'Namibia',
#   'China',
#   'Australia',
#   'Myanmar',
#   'Phillipine',
#   'Japan',
#   'Indonesia',
#   'Zaire'],
#  'Smartphone usage': ['United States'],
#  'Social media usage': ['United States'],
#  'Sodium': ['World'],
#  'Sodium Chlorate': ['World'],
#  'Sodium-based battery storage': ['South Korea',
#   'Germany',
#   'Italy',
#   'United Kingdom',
#   'Maldives',
#   'France',
#   'China',
#   'Australia',
#   'French Guiana',
#   'Japan',
#   'United Arab Emirates',
#   'Martinique',
#   'Greece',
#   'Canada',
#   'Equatorial Guinea',
#   'United States'],
#  'Solar Photovoltaic': ['Iran (Islamic Republic of)',
#   'Tokelau',
#   'Lebanon',
#   'Mayotte',
#   'Viet Nam',
#   'Palau',
#   'Saint Kitts and Nevis',
#   'Bahrain',
#   'Suriname',
#   'Sudan',
#   'Cabo Verde',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Antigua and Barbuda',
#   'Brunei Darussalam',
#   'Kosovo',
#   'Lithuania',
#   'Luxembourg',
#   'Martinique',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Tunisia',
#   'Eswatini',
#   'Guadeloupe',
#   'Mexico',
#   'Faroe Islands',
#   'China',
#   'Guam',
#   'Malta',
#   'Pakistan',
#   'Nigeria',
#   'Anguilla',
#   'Niue',
#   'Saudi Arabia',
#   'Romania',
#   'Solomon Islands',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Barbados',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Andorra',
#   'Chad',
#   'Dominica',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Réunion',
#   'Uganda',
#   'United States Virgin Islands',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   "Democratic People's Republic of Korea",
#   'El Salvador',
#   'Iraq',
#   'Bahamas',
#   'Trinidad and Tobago',
#   'Bonaire, Sint Eustatius and Saba',
#   'Lesotho',
#   'Senegal',
#   'British Virgin Islands',
#   'Curaçao',
#   'Namibia',
#   'Azerbaijan',
#   'Chinese Taipei',
#   'Aruba',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Marshall Islands',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Slovakia',
#   'Saint Vincent and the Grenadines',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Croatia',
#   'Mauritania',
#   'Bangladesh',
#   'Cook Islands',
#   'Burkina Faso',
#   'Ecuador',
#   'Saint Lucia',
#   'Malaysia',
#   'Nauru',
#   'Ukraine',
#   'Panama',
#   'Puerto Rico',
#   'Republic of Korea',
#   'Mozambique',
#   'Montenegro',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Jamaica',
#   'French Guiana',
#   'Syrian Arab Republic',
#   'Kiribati',
#   'Slovenia',
#   'Bhutan',
#   'Japan',
#   'Fiji',
#   'Turks and Caicos Islands',
#   'Egypt',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Latvia',
#   'Indonesia',
#   'Israel',
#   'Montserrat',
#   'United States of America',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'Micronesia (Federated States of)',
#   'Kuwait',
#   'Republic of Moldova',
#   'Tonga',
#   'American Samoa',
#   'France',
#   'Kazakhstan',
#   'Vanuatu',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'State of Palestine',
#   'Guatemala',
#   'Zimbabwe',
#   'Niger',
#   'New Caledonia',
#   'Austria',
#   'Republic of North Macedonia',
#   'Cayman Islands',
#   'Switzerland',
#   'Honduras',
#   'Saint Barthélemy',
#   'Thailand',
#   'Albania',
#   'Denmark',
#   'Serbia',
#   'Cyprus',
#   'Myanmar',
#   'Oman',
#   'French Polynesia',
#   'Ireland',
#   'Saint Martin (French Part)',
#   'Venezuela (Bolivarian Republic of)',
#   'Seychelles',
#   'India',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'Madagascar',
#   'South Africa',
#   'Burundi',
#   'Sierra Leone',
#   'Belgium',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'United Republic of Tanzania',
#   'Netherlands',
#   'Peru',
#   'Mali',
#   'Tuvalu',
#   'Uzbekistan',
#   'Grenada',
#   'Brazil',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Türkiye',
#   'Hungary',
#   'Afghanistan'],
#  'Solar Thermal Energy': ['Kuwait',
#   'France',
#   'Republic of Korea',
#   'United Arab Emirates',
#   'Thailand',
#   'Australia',
#   'Spain',
#   'Egypt',
#   'India',
#   'South Africa',
#   'Germany',
#   'Algeria',
#   'Chile',
#   'Israel',
#   'Mexico',
#   'Italy',
#   'China',
#   'Saudi Arabia',
#   'Romania',
#   'Türkiye',
#   'United States of America',
#   'Morocco'],
#  'Solid Biofuels': ['Viet Nam',
#   'Sudan',
#   'Australia',
#   'Lithuania',
#   'Luxembourg',
#   'Martinique',
#   'Poland',
#   'Uruguay',
#   'Eswatini',
#   'Guadeloupe',
#   'Mexico',
#   'China',
#   'Pakistan',
#   'Romania',
#   'Sri Lanka',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'Belarus',
#   'Portugal',
#   'Réunion',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   'El Salvador',
#   'Ethiopia',
#   'Trinidad and Tobago',
#   'Senegal',
#   'Namibia',
#   'Chinese Taipei',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Nicaragua',
#   'Czechia',
#   'Russian Federation',
#   'Chile',
#   'Slovakia',
#   'Philippines',
#   'Bosnia and Herzegovina',
#   'Guyana',
#   'Croatia',
#   'Ecuador',
#   'Malaysia',
#   'Ukraine',
#   'Puerto Rico',
#   'Republic of Korea',
#   'Mozambique',
#   'Rwanda',
#   'Colombia',
#   'Cuba',
#   'Jamaica',
#   'French Guiana',
#   'Slovenia',
#   'Congo',
#   'Japan',
#   'Fiji',
#   'Egypt',
#   'Finland',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'Paraguay',
#   'Italy',
#   'Latvia',
#   'New Zealand',
#   'Indonesia',
#   'Angola',
#   'United States of America',
#   'Samoa',
#   'Bolivia (Plurinational State of)',
#   'France',
#   'Dominican Republic',
#   'Costa Rica',
#   'Guatemala',
#   'Zimbabwe',
#   'Austria',
#   'Republic of North Macedonia',
#   'Honduras',
#   'Thailand',
#   'Denmark',
#   'Serbia',
#   'Ireland',
#   'India',
#   "Lao People's Democratic Republic",
#   'Germany',
#   'South Africa',
#   'Sierra Leone',
#   'Belgium',
#   'United Republic of Tanzania',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'Brazil',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Türkiye',
#   'Hungary'],
#  'Space Launches': ['Vietnam',
#   'Australia',
#   'Armenia',
#   'Papua New Guinea',
#   'Lithuania',
#   'Luxembourg',
#   'Poland',
#   'Uruguay',
#   'Turkey',
#   'Tunisia',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Monaco',
#   'Saudi Arabia',
#   'Pakistan',
#   'Nigeria',
#   'Romania',
#   'Morocco',
#   'Sri Lanka',
#   'Russia',
#   'Ghana',
#   'Mauritius',
#   'Kenya',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Nepal',
#   'Estonia',
#   'World',
#   'Spain',
#   'Ethiopia',
#   'Venezuela',
#   'Azerbaijan',
#   'Sweden',
#   'Argentina',
#   'Czechia',
#   'Chile',
#   'Slovakia',
#   'Philippines',
#   'European Union',
#   'United Kingdom',
#   'Bangladesh',
#   'Ecuador',
#   'Malaysia',
#   'South Korea',
#   'Ukraine',
#   'Rwanda',
#   'Colombia',
#   'Jordan',
#   'Slovenia',
#   'Japan',
#   'Bhutan',
#   'North Korea',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Qatar',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Greece',
#   'Intelsat',
#   'New Zealand',
#   'Paraguay',
#   'Italy',
#   'Latvia',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Moldova',
#   'Kazakhstan',
#   'France',
#   'Mongolia',
#   'Costa Rica',
#   'Guatemala',
#   'Taiwan',
#   'Austria',
#   'United States',
#   'Switzerland',
#   'Thailand',
#   'Denmark',
#   'India',
#   'South Africa',
#   'Germany',
#   'Belgium',
#   'Canada',
#   'Bolivia',
#   'Netherlands',
#   'Peru',
#   'Laos',
#   'Brazil',
#   'Iran',
#   'Hungary'],
#  'Stationary Steam Engines': ['World'],
#  'Steam Locomotives': ['World'],
#  'Steam ships': ['Russia',
#   'France',
#   'Austria',
#   'Cuba',
#   'Denmark',
#   'Spain',
#   'Ireland',
#   'Germany',
#   'Finland',
#   'Sweden',
#   'Belgium',
#   'Norway',
#   'Greece',
#   'Canada',
#   'Chile',
#   'Netherlands',
#   'Mexico',
#   'Italy',
#   'United Kingdom',
#   'Hungary'],
#  'Stove': ['United States'],
#  'Styrene': ['World'],
#  'Submarine Cables': ['World'],
#  'Sulphuric Acid': ['South Korea',
#   'Russia',
#   'France',
#   'East Germany',
#   'Iran',
#   'Yugoslavia',
#   'Morocco',
#   'Switzerland',
#   'Portugal',
#   'Austria',
#   'Colombia',
#   'Phillipines',
#   'Thailand',
#   'Cuba',
#   'Romania',
#   'Denmark',
#   'Australia',
#   'Japan',
#   'Ireland',
#   'Czechoslovakia',
#   'Egypt',
#   'India',
#   'Germany',
#   'Venezuela',
#   'Algeria',
#   'Finland',
#   'Bulgaria',
#   'Argentina',
#   'Sweden',
#   'Zaire',
#   'Belgium',
#   'Norway',
#   'Poland',
#   'Zambia',
#   'Chile',
#   'Canada',
#   'Turkey',
#   'Greece',
#   'Tunisia',
#   'Peru',
#   'Netherlands',
#   'Mexico',
#   'Italy',
#   'West Germany',
#   'United Kingdom',
#   'China',
#   'Brazil',
#   'Pakistan',
#   'Indonesia',
#   'Israel',
#   'United States of America',
#   'Hungary'],
#  'Synthetic Filaments': ['South Korea',
#   'Russia',
#   'France',
#   'East Germany',
#   'Yugoslavia',
#   'Switzerland',
#   'Austria',
#   'Colombia',
#   'Phillipines',
#   'Thailand',
#   'Romania',
#   'Australia',
#   'Spain',
#   'Japan',
#   'Czechoslovakia',
#   'Egypt',
#   'India',
#   'South Africa',
#   'Germany',
#   'Finland',
#   'Sweden',
#   'Argentina',
#   'Belgium',
#   'Norway',
#   'Poland',
#   'Canada',
#   'Netherlands',
#   'Turkey',
#   'West Germany',
#   'Mexico',
#   'Italy',
#   'United Kingdom',
#   'China',
#   'Brazil',
#   'Pakistan',
#   'Indonesia',
#   'Iran',
#   'United States of America',
#   'Malaysia'],
#  'Tablet': ['United States'],
#  'Telegraph Traffic': ['Lebanon',
#   'Vietnam',
#   'Cameroon',
#   'Sudan',
#   'Australia',
#   'Togo',
#   'Poland',
#   'Uruguay',
#   'Turkey',
#   'Tunisia',
#   'Mexico',
#   'China',
#   'Pakistan',
#   'Nigeria',
#   'Romania',
#   'Morocco',
#   'Sri Lanka',
#   'Indochina',
#   'Russia',
#   'Ghana',
#   'Kenya',
#   'Uganda',
#   'Portugal',
#   'Spain',
#   'El Salvador',
#   'Iraq',
#   'Czechoslovakia',
#   'Venezuela',
#   'Burma',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Chile',
#   'Philippines',
#   'Guyana',
#   'United Kingdom',
#   'Malaysia',
#   'South Korea',
#   'Mozambique',
#   'Colombia',
#   'Japan',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Singapore',
#   'Norway',
#   'Zambia',
#   'Greece',
#   'New Zealand',
#   'Italy',
#   'Democratic Republic of the Congo',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'France',
#   'Zimbabwe',
#   'Taiwan',
#   'Switzerland',
#   'United States',
#   'Austria',
#   'Thailand',
#   'Denmark',
#   'Serbia',
#   'Ireland',
#   'Syria',
#   'India',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'Tanzania',
#   'Czech Republic',
#   'Belgium',
#   'Ivory Coast',
#   'Canada',
#   'Netherlands',
#   'Peru',
#   'South Vietnam',
#   'Brazil',
#   'Hungary'],
#  'Telephones': ['Lebanon',
#   'Vietnam',
#   'Cameroon',
#   'Suriname',
#   'Sudan',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Turkey',
#   'Tunisia',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Pakistan',
#   'Nigeria',
#   'Romania',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Indochina',
#   'Russia',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Czechoslovakia',
#   'Bosnia-Herzegovina',
#   'Iceland',
#   'Lesotho',
#   'Venezuela',
#   'Eritrea',
#   'Senegal',
#   'Burma',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Tajikistan',
#   'Nicaragua',
#   'Chile',
#   'Georgia',
#   'Philippines',
#   'Guyana',
#   'United Kingdom',
#   'Croatia',
#   'Hong Kong',
#   'Mauritania',
#   'Bangladesh',
#   'Burkina Faso',
#   'Ecuador',
#   'Malaysia',
#   'South Korea',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Mozambique',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Slovenia',
#   'Yemen',
#   'Japan',
#   'South Yemen',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Swaziland',
#   'Zambia',
#   'Greece',
#   'Paraguay',
#   'Italy',
#   'Latvia',
#   'New Zealand',
#   'Democratic Republic of the Congo',
#   'Macedonia',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Kuwait',
#   'Moldova',
#   'France',
#   'Kazakhstan',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'Zimbabwe',
#   'Guatemala',
#   'Niger',
#   'Taiwan',
#   'Switzerland',
#   'United States',
#   'Austria',
#   'Honduras',
#   'Thailand',
#   'Denmark',
#   'Albania',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Central African Republic',
#   'Syria',
#   'India',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'Tanzania',
#   'Burundi',
#   'Slovak Republic',
#   'Libya',
#   'Czech Republic',
#   'Sierra Leone',
#   'Belgium',
#   'Ivory Coast',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'Bolivia',
#   'Netherlands',
#   'Peru',
#   'Republic of the Congo',
#   'Mali',
#   'South Vietnam',
#   'Uzbekistan',
#   'Laos',
#   'Brazil',
#   'Iran',
#   'Hungary',
#   'Afghanistan'],
#  'Television': ['Lebanon',
#   'Vietnam',
#   'Cameroon',
#   'Suriname',
#   'Sudan',
#   'Australia',
#   'Armenia',
#   'Togo',
#   'Papua New Guinea',
#   'Guinea-Bissau',
#   'Lithuania',
#   'Somalia',
#   'Luxembourg',
#   'Gambia',
#   'Poland',
#   'Uruguay',
#   'Equatorial Guinea',
#   'Turkey',
#   'Tunisia',
#   'Mexico',
#   'Turkmenistan',
#   'China',
#   'Saudi Arabia',
#   'Pakistan',
#   'Nigeria',
#   'Romania',
#   'Morocco',
#   'Haiti',
#   'Sri Lanka',
#   'Indochina',
#   'Russia',
#   'Ghana',
#   'Mauritius',
#   'Belize',
#   'Cambodia',
#   'Kenya',
#   'Chad',
#   'United Arab Emirates',
#   'Belarus',
#   'Portugal',
#   'Uganda',
#   'Nepal',
#   'Estonia',
#   'Spain',
#   'El Salvador',
#   'Iraq',
#   'Ethiopia',
#   'Czechoslovakia',
#   'Bosnia-Herzegovina',
#   'Iceland',
#   'Lesotho',
#   'Venezuela',
#   'Eritrea',
#   'Senegal',
#   'Burma',
#   'Namibia',
#   'Liberia',
#   'Azerbaijan',
#   'Malawi',
#   'Argentina',
#   'Sweden',
#   'Tajikistan',
#   'Nicaragua',
#   'Chile',
#   'Georgia',
#   'Philippines',
#   'Guyana',
#   'United Kingdom',
#   'Croatia',
#   'Hong Kong',
#   'Mauritania',
#   'Bangladesh',
#   'Burkina Faso',
#   'Ecuador',
#   'Malaysia',
#   'South Korea',
#   'Ukraine',
#   'Panama',
#   'Gabon',
#   'Mozambique',
#   'Rwanda',
#   'Colombia',
#   'Guinea',
#   'Jordan',
#   'Cuba',
#   'Slovenia',
#   'Yemen',
#   'Japan',
#   'South Yemen',
#   'Egypt',
#   'Algeria',
#   'Finland',
#   'Bulgaria',
#   'Singapore',
#   'Norway',
#   'Swaziland',
#   'Zambia',
#   'Greece',
#   'Paraguay',
#   'Italy',
#   'Latvia',
#   'New Zealand',
#   'Democratic Republic of the Congo',
#   'Macedonia',
#   'Indonesia',
#   'Angola',
#   'Israel',
#   'Kuwait',
#   'Moldova',
#   'France',
#   'Kazakhstan',
#   'Mongolia',
#   'Dominican Republic',
#   'Costa Rica',
#   'Zimbabwe',
#   'Guatemala',
#   'Niger',
#   'Taiwan',
#   'Switzerland',
#   'United States',
#   'Austria',
#   'Honduras',
#   'Thailand',
#   'Denmark',
#   'Albania',
#   'Oman',
#   'Ireland',
#   'Kyrgyzstan',
#   'Central African Republic',
#   'Syria',
#   'India',
#   'South Africa',
#   'Germany',
#   'Madagascar',
#   'Tanzania',
#   'Burundi',
#   'Slovak Republic',
#   'Libya',
#   'Czech Republic',
#   'Sierra Leone',
#   'Belgium',
#   'Ivory Coast',
#   'Benin',
#   'Botswana',
#   'Canada',
#   'Bolivia',
#   'Netherlands',
#   'Peru',
#   'Republic of the Congo',
#   'Mali',
#   'South Vietnam',
#   'Uzbekistan',
#   'Laos',
#   'Brazil',
#   'Iran',
#   'Hungary',
#   'Afghanistan'],
#  'Tin': ['Thailand',
#   'Australia',
#   'China',
#   'Brazil',
#   'Nigeria',
#   'Indonesia',
#   'Bolivia',
#   'Malaysia'],
#  'Titanium Sponge': ['World'],
#  'Transistors per Microprocessor': ['World'],
#  'Urea': ['World'],
#  'Vacuums': ['United States'],
#  'Videocassette recorder': ['United States'],
#  'Vinyl Acetate': ['World'],
#  'Vinyl Chloride': ['World'],
#  'Washing Machines': ['World', 'US'],
#  'Water Heater': ['United States'],
#  'Wet flue gas desulfurization systems': ['World',
#   'Japan',
#   'Germany',
#   'United States'],
#  'YFV Vaccine': ['Bolivia (Plurinational State of)',
#   'Ghana',
#   'Panama',
#   'Gabon',
#   'Kenya',
#   'Chad',
#   'Cameroon',
#   'Niger',
#   'Suriname',
#   'Colombia',
#   'Guinea',
#   'Congo',
#   'Sao Tome and Principe',
#   'Togo',
#   'Trinidad and Tobago',
#   'Venezuela (Bolivarian Republic of)',
#   'Central African Republic',
#   'Guinea-Bissau',
#   'Senegal',
#   'Liberia',
#   'Sierra Leone',
#   'Argentina',
#   'Benin',
#   'Gambia',
#   'Equatorial Guinea',
#   'Peru',
#   'Paraguay',
#   'Guyana',
#   'Mali',
#   "Cote d'Ivoire",
#   'Democratic Republic of the Congo',
#   'Brazil',
#   'Nigeria',
#   'Angola',
#   'Burkina Faso',
#   'Ecuador'],
#  'Zinc': ['Peru',
#   'Korea',
#   'South Korea',
#   'Mexico',
#   'Algeria',
#   'Australia',
#   'China',
#   'Brazil',
#   'Argentina',
#   'Japan',
#   'North Korea',
#   'Zaire',
#   'United States of America',
#   'Zambia',
#   'Canada',
#   'India'],
#  'Zinc-based battery': ['Indonesia', 'Madagascar', 'United States']}

# %%
num_country_dict = {}
for tech in tech_list:
    countries = list(set(all_tech[all_tech['Technology Name'] == tech]['Country Name']))
    num_country_dict[tech] = len(countries)
num_country_dict = dict(sorted(num_country_dict.items(), key=lambda item: item[1])) 
num_country_dict
# Out:
# {'Acrylic Fiber': 1,
#  'Acrylonitrile': 1,
#  'Air-Source Heat Pumps': 1,
#  'Amazon Prime users': 1,
#  'Aniline': 1,
#  'Automatic transmission': 1,
#  'Benzene': 1,
#  'Bicycles': 1,
#  'Bisphenol A': 1,
#  'CFLs': 1,
#  'Cable TV': 1,
#  'Canals': 1,
#  'Caprolactam': 1,
#  'Carbon Capture & Sequestration': 1,
#  'Central heating': 1,
#  'Coal Power': 1,
#  'Colour TV': 1,
#  'Computing Growth': 1,
#  'Concentrated Solar Power': 1,
#  'Cyclohexane': 1,
#  'Desalination capacity': 1,
#  'Dishwashers': 1,
#  'Disk brakes': 1,
#  'Ebook reader': 1,
#  'Electric Range': 1,
#  'Electronic ignition': 1,
#  'Ethanolamine': 1,
#  'Ethyl Alcohol': 1,
#  'Ethylene': 1,
#  'Ethylene Glycol': 1,
#  'Flush toilet': 1,
#  'Formaldehyde': 1,
#  'Freezer': 1,
#  'Ground Source Heat Pumps': 1,
#  'Herbicide-Tolerant Corn': 1,
#  'Herbicide-Tolerant Cotton': 1,
#  'Herbicide-Tolerant Soybeans': 1,
#  'High-speed rail': 1,
#  'Home air conditioning': 1,
#  'Home computers': 1,
#  'Household Internet access': 1,
#  'Households with only mobile phones (no landlines)': 1,
#  'Hydrofluoric Acid': 1,
#  'Insect-Resistant Corn': 1,
#  'Insect-Resistant Cotton': 1,
#  'Internet Backbone Bandwidth': 1,
#  'Internet Traffic': 1,
#  'Iron': 1,
#  'Jet Aircraft': 1,
#  'Liquefied natural gas': 1,
#  'Magnesium': 1,
#  'Magnetic Data Storage': 1,
#  'Maleic Anhydride': 1,
#  'Methanol': 1,
#  'Microcomputers': 1,
#  'Microprocessor Clock Speed': 1,
#  'Microwaves': 1,
#  'Motor Gasoline': 1,
#  'Motorcycles': 1,
#  'NatGas Power': 1,
#  'Natural gas pipeline': 1,
#  'Neoprene Rubber': 1,
#  'Nox pollution controls (boilers)': 1,
#  'Oil pipeline': 1,
#  'Paraxylene': 1,
#  'Pentaerythritol': 1,
#  'Phenol': 1,
#  'Phthalic Anhydride': 1,
#  'Podcasting': 1,
#  'Polyester Fiber': 1,
#  'Polyethylene HD': 1,
#  'Polyethylene LD': 1,
#  'Polystyrene': 1,
#  'Polyvinylchloride': 1,
#  'Power steering': 1,
#  'Primary Magnesium': 1,
#  'Processor Performance': 1,
#  'Public roads': 1,
#  'RTGS adoption': 1,
#  'Radial tires': 1,
#  'Random Access Memory': 1,
#  'Running water': 1,
#  'Shale production': 1,
#  'Shipping container port infrastructure': 1,
#  'Shotgun Sanger DNA Sequencing': 1,
#  'Smartphone usage': 1,
#  'Social media usage': 1,
#  'Sodium': 1,
#  'Sodium Chlorate': 1,
#  'Stationary Steam Engines': 1,
#  'Steam Locomotives': 1,
#  'Stove': 1,
#  'Styrene': 1,
#  'Submarine Cables': 1,
#  'Tablet': 1,
#  'Titanium Sponge': 1,
#  'Transistors per Microprocessor': 1,
#  'Urea': 1,
#  'Vacuums': 1,
#  'Videocassette recorder': 1,
#  'Vinyl Acetate': 1,
#  'Vinyl Chloride': 1,
#  'Water Heater': 1,
#  'Cement production': 2,
#  'Electric Bicycles': 2,
#  'FCC-Refineries': 2,
#  'Laundry Dryers': 2,
#  'Primary copper production': 2,
#  'Refrigerators': 2,
#  'Sand and gravel production (construction)': 2,
#  'Sand and gravel production (industrial)': 2,
#  'Washing Machines': 2,
#  'Zinc-based battery': 3,
#  'Latent heat storage': 4,
#  'Nickel-based battery': 4,
#  'Wet flue gas desulfurization systems': 4,
#  'Electro-chemical capacitor': 6,
#  'Hydrogen storage': 6,
#  'Compressed air energy storage': 7,
#  'Nuclear weapons': 8,
#  'Tin': 8,
#  'Lithium Mine Production': 9,
#  'Nitric Acid': 9,
#  'Rare Earth Mine Production': 9,
#  'Sensible heat storage': 10,
#  'Heat thermal battery storage': 11,
#  'Nickel production': 12,
#  'Silver': 12,
#  'Graphite Mine Production': 13,
#  'Hydrochloric Acid': 13,
#  'Cobalt Mine Production': 14,
#  'Caustic Soda': 15,
#  'Flywheel battery storage': 15,
#  'Gold production': 16,
#  'Sodium-based battery storage': 16,
#  'Zinc': 16,
#  'Lead-acid battery storage': 18,
#  'Liquid Biofuels': 18,
#  'On-Grid Offshore Wind Energy': 18,
#  'Marine Energy': 19,
#  'Steam ships': 20,
#  'Solar Thermal Energy': 22,
#  'All Biofuels': 24,
#  'Flow battery storage': 25,
#  'Geothermal Energy': 31,
#  'Coal Production': 36,
#  'YFV Vaccine': 36,
#  'Primary bauxite production': 37,
#  'Synthetic Filaments': 39,
#  'Cadmium Refining': 41,
#  'Cane Sugar Production': 42,
#  'Pumped hydro storage': 44,
#  'Off-Grid Onshore Wind Energy': 46,
#  'Lithium-ion battery storage': 47,
#  'Natural Gas Production': 51,
#  'Oil Production': 51,
#  'Sulphuric Acid': 52,
#  'Copper Refining': 58,
#  'Primary aluminum production': 58,
#  'Crude Oil': 62,
#  'Lead mine production': 64,
#  'Iron ore': 66,
#  'Copper Mining': 69,
#  'Oil Refining Capacity': 75,
#  'Telegraph Traffic': 79,
#  'Electricity': 80,
#  'Hydroelectricity': 81,
#  'Nuclear Energy': 81,
#  'Postal Traffic': 81,
#  'Renewable Power': 81,
#  'Space Launches': 94,
#  'Biogas': 95,
#  'Milk production': 100,
#  'Beer Production': 102,
#  'Solid Biofuels': 102,
#  'HEPBB Vaccine': 105,
#  'Raw steel production': 108,
#  'ROTAC Vaccine': 118,
#  'Crop harvester': 121,
#  'Salt production': 127,
#  'Railroad': 129,
#  'On-Grid Onshore Wind Energy': 133,
#  'PCV3 Vaccine': 153,
#  'Cellphones': 157,
#  'Passenger Cars': 157,
#  'Radio': 157,
#  'Telephones': 157,
#  'Television': 157,
#  'BCG Vaccine': 168,
#  'Potash Fertilizer': 171,
#  'RCV1 Vaccine': 173,
#  'Nitrogen Fertilizer': 175,
#  'Phosphate Fertilizer': 175,
#  'MCV2 Vaccine': 183,
#  'Solar Photovoltaic': 190,
#  'HEPB3 Vaccine': 191,
#  'HIB3 Vaccine': 193,
#  'DTP1 Vaccine': 195,
#  'DTP3 Vaccine': 195,
#  'IPV1 Vaccine': 195,
#  'MCV1 Vaccine': 195,
#  'POL3 Vaccine': 195,
#  'Aquaculture production': 196,
#  'Capture fisheries production': 216}

# %%
country_data = []
for x in num_country_dict:
    if num_country_dict[x] > 2:
        print(x)
# Out:
# Zinc-based battery
# Latent heat storage
# Nickel-based battery
# Wet flue gas desulfurization systems
# Electro-chemical capacitor
# Hydrogen storage
# Compressed air energy storage
# Nuclear weapons
# Tin
# Lithium Mine Production
# Nitric Acid
# Rare Earth Mine Production
# Sensible heat storage
# Heat thermal battery storage
# Nickel production
# Silver
# Graphite Mine Production
# Hydrochloric Acid
# Cobalt Mine Production
# Caustic Soda
# Flywheel battery storage
# Gold production
# Sodium-based battery storage
# Zinc
# Lead-acid battery storage
# Liquid Biofuels
# On-Grid Offshore Wind Energy
# Marine Energy
# Steam ships
# Solar Thermal Energy
# All Biofuels
# Flow battery storage
# Geothermal Energy
# Coal Production
# YFV Vaccine
# Primary bauxite production
# Synthetic Filaments
# Cadmium Refining
# Cane Sugar Production
# Pumped hydro storage
# Off-Grid Onshore Wind Energy
# Lithium-ion battery storage
# Natural Gas Production
# Oil Production
# Sulphuric Acid
# Copper Refining
# Primary aluminum production
# Crude Oil
# Lead mine production
# Iron ore
# Copper Mining
# Oil Refining Capacity
# Telegraph Traffic
# Electricity
# Hydroelectricity
# Nuclear Energy
# Postal Traffic
# Renewable Power
# Space Launches
# Biogas
# Milk production
# Beer Production
# Solid Biofuels
# HEPBB Vaccine
# Raw steel production
# ROTAC Vaccine
# Crop harvester
# Salt production
# Railroad
# On-Grid Onshore Wind Energy
# PCV3 Vaccine
# Cellphones
# Passenger Cars
# Radio
# Telephones
# Television
# BCG Vaccine
# Potash Fertilizer
# RCV1 Vaccine
# Nitrogen Fertilizer
# Phosphate Fertilizer
# MCV2 Vaccine
# Solar Photovoltaic
# HEPB3 Vaccine
# HIB3 Vaccine
# DTP1 Vaccine
# DTP3 Vaccine
# IPV1 Vaccine
# MCV1 Vaccine
# POL3 Vaccine
# Aquaculture production
# Capture fisheries production

# %%
cost_data = all_tech[all_tech['Metric']=='Price']
for x in list(set(cost_data['Technology Name'])):
    print(x)
# Out:
# Cyclohexane
# Magnesium
# Polyester Fiber
# Acrylonitrile
# Hydrofluoric Acid
# Acrylic Fiber
# Benzene
# Formaldehyde
# Sodium Chlorate
# Methanol
# Sand and gravel production (construction)
# Crude Oil
# Polystyrene
# Polyethylene LD
# Sand and gravel production (industrial)
# Primary Magnesium
# Sodium
# Polyethylene HD
# Vinyl Acetate
# Nickel production
# Polyvinylchloride
# Motor Gasoline
# Ethylene
# Aniline
# Pentaerythritol
# Urea
# Styrene
# Primary copper production
# Ethylene Glycol
# Caprolactam
# Shotgun Sanger DNA Sequencing
# Paraxylene
# Gold production
# Ethyl Alcohol
# Titanium Sponge
# Ethanolamine
# Cement production
# Phthalic Anhydride
# Vinyl Chloride
# Bisphenol A
# Phenol
# Maleic Anhydride
# Neoprene Rubber

# %%
def time_span(tech_name):
    tech_df = all_tech[all_tech['Technology Name']==tech_name]
    tech_df.dropna(axis=1, how='all', inplace=True)
    omit = []
    for col in tech_df.columns:
        if len(col) != 4 or col == 'Unit':
            omit.append(col)
    tech_df.drop(columns=omit, inplace=True)
    time_span = tech_df.columns[0] + '-' + tech_df.columns[-1]
    return time_span

# %%
time_span('Acrylic Fiber')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1960-1972'

# %%
time_span('Beer Production')
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# '1750-2007'

# %%
for tech in tech_list:
    print(time_span(tech))
# Out:
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.dropna(axis=1, how='all', inplace=True)
# /var/folders/4_/pdkx43_96v7dxssy4jtd5vyc0000gn/T/ipykernel_17371/554985407.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tech_df.drop(columns=omit, inplace=True)
