# %%
import pandas as pd
from pandas import Series, DataFrame
import os

# %%
path = '/Users/ariana/desktop/historical_tech'
os.chdir(path)

# %%
pd.read_excel('raw data/bp-stats-review-2022-all-data.xlsx')
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 0      bp Statistical Review of World Energy June 2022         NaN
# 1                                                  NaN         NaN
# 2     This workbook contains information presented ...         NaN
# 3     bp Statistical Review of World Energy, which ...         NaN
# 4                                         internet at:         NaN
# ..                                                 ...         ...
# 125                                                NaN         NaN
# 126                                                NaN         NaN
# 127                                                NaN         NaN
# 128                                                NaN         NaN
# 129                                                NaN         NaN
#
#      Unnamed: 2 Unnamed: 3
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# ...
